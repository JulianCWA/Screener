# %%
# This code successfully mimicked Factset for this call

import requests

def factset_equalsfdsfql_tqqq():
    """
    This script replicates the FactSet equalsfdsfql request exactly as captured in Fiddler.
    It uses every header and cookie from your capture and sends the request in the format 
    the server expects (SYMBOLS and EXPRS instead of FQL_STATE_ID).

    WARNING:
      - These cookies and header values are live session credentials. Handle with care.
      - verify=False disables SSL verification (for testing only).
    """
    
    # Base URL from Fiddler capture
    url = "https://my.apps.factset.com/services/equalsfdsfql"
    
    # Query parameters from the Fiddler capture
    params = {
        "string_na": "true",
        "APP": "DATA_REQUEST_STREAM"
    }
    
    # Headers exactly as in your Fiddler capture (Content-Length is omitted since requests calculates it)
    headers = {
        "Host": "my.apps.factset.com",
        "Connection": "keep-alive",
        "sec-ch-ua-platform": "\"Windows\"",
        "Accept-Language": "en-US",
        "sec-ch-ua": "\"Chromium\";v=\"133\", \"Microsoft Edge WebView2\";v=\"133\", \"Not(A:Brand\";v=\"99\", \"Microsoft Edge\";v=\"133\"",
        "X-Fdsa-Long-Request-Deadline": "29",
        "sec-ch-ua-mobile": "?0",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/133.0.0.0 Safari/537.36 Edg/133.0.0.0",
        "Accept": "application/json, text/plain, */*",
        "Content-Type": "application/x-www-form-urlencoded",
        "Origin": "https://my.apps.factset.com",
        "Sec-Fetch-Site": "same-origin",
        "Sec-Fetch-Mode": "cors",
        "Sec-Fetch-Dest": "empty",
        "Accept-Encoding": "gzip, deflate, br, zstd"
    }
    
    # Cookies exactly as in your Fiddler capture.
    cookies = {
        "FdsAuthScheme": "oidc",
        "FdsBrowserId": "6a94fb4a-3b8c-435e-b4ae-6154338c64ee",
        "FdsSessionId": "43cb2419-9e8f-4c76-8b77-ec347e13a69d",
        "AccessedApplications": "FactSet",
        "lightstep_guid%2Fid-widget": "430940a607367703",
        "lightstep_session_id": "0e062d6b44045c9a",
        "TS013442b8": "014dd04807b8df3fac66d3039876db97d9fe1ed4b8a3d0668235353f9b65762a69384c95b511f357169882efca4bbb94e8455cb8f5",
        "TS01742872": "014dd04807b8df3fac66d3039876db97d9fe1ed4b8a3d0668235353f9b65762a69384c95b511f357169882efca4bbb94e8455cb8f5"
    }
    
    # Instead of the FQL_STATE_ID from your capture (which causes a 400 error),
    # we use the expected payload format:
    #   SYMBOLS=<symbol>&EXPRS=<formula>
    # For a ticker like TQQQ-US with the expression ETP_COUNTERPARTY("HOLDS_DERIVATIVES","TEXT")
    data = 'SYMBOLS=TQQQ-US&EXPRS=ETP_COUNTERPARTY("HOLDS_DERIVATIVES","TEXT")'
    
    # Make the POST request with verify=False to bypass SSL verification for testing.
    response = requests.post(
        url,
        params=params,
        headers=headers,
        cookies=cookies,
        data=data,
        verify=False
    )
    
    # Print out response details
    print("HTTP Status Code:", response.status_code)
    print("Response Headers:", response.headers)
    try:
        print("Response JSON:", response.json())
    except Exception:
        print("Response Text:", response.text)

if __name__ == "__main__":
    factset_equalsfdsfql_tqqq()
# Out:
# HTTP Status Code: 200
# Response Headers: {'Content-Type': 'application/json; charset=UTF-8', 'Content-Length': '141', 'Connection': 'keep-alive', 'X-Fql-Service-Evaluation-Time': '74.792173', 'X-Fql-Service-State-Id': '', 'X-Fql-Service-Version': '1', 'Keep-Alive': 'timeout=30', 'X-DataDirect-Request-Key': '67BF475D1BBB97C3', 'Set-Cookie': 'FdsSessionId=43cb2419-9e8f-4c76-8b77-ec347e13a69d; Path=/; Domain=.factset.com; Expires=Thu, 27-Feb-2025 06:54:53 GMT; Secure; HttpOnly; SameSite=None, AccessedApplications=FactSet; Path=/; Domain=.factset.com; Secure; HttpOnly; SameSite=None, TS013442b8=014dd04807349bd4eac3c5058087e9a43043b5c5ecde27d08b8b0f1143169ebe0a6805477589a6b065e3c976428f8750a4e3823ef3; Path=/; Secure; HTTPOnly, TS01742872=014dd04807b8df3fac66d3039876db97d9fe1ed4b8a3d0668235353f9b65762a69384c95b511f357169882efca4bbb94e8455cb8f5; path=/; domain=.factset.com; HTTPonly; Secure'}
# Response JSON: [{'$error': 0, '$expression': 'ETP_COUNTERPARTY("HOLDS_DERIVATIVES","TEXT")', '$symbol': 'TQQQ-US', '$value': [['Yes']], '$wall_time_ms': 20.947}]
# C:\Users\JulianHeron\Software Projects\Database Administration\env\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'my.apps.factset.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
import requests
from sqlalchemy import create_engine, text

# Database connection string (adjust as needed)
connection_string = (
    "mssql+pyodbc://JULIANS_LAPTOP\\SQLEXPRESS/"
    "CWA_Fund_Database?driver=ODBC+Driver+18+for+SQL+Server"
    "&trusted_connection=yes&TrustServerCertificate=yes"
)

# Create SQLAlchemy engine
engine = create_engine(connection_string)

### Functions

def fetch_tickers_from_db():
    """Fetch tickers and their FS_insight from the database."""
    with engine.connect() as conn:
        result = conn.execute(text("SELECT SymbolCUSIP, FS_insight FROM Funds_to_Screen"))
        tickers_data = [{"ticker": row[0], "insight": row[1]} for row in result.fetchall()]
    return tickers_data

def update_fs_insight(ticker, insight):
    """Update the FS_insight column for a given ticker."""
    with engine.connect() as conn:
        query = text("UPDATE Funds_to_Screen SET FS_insight = :insight WHERE SymbolCUSIP = :ticker")
        conn.execute(query, {"insight": insight, "ticker": ticker})
        conn.commit()

def factset_equalsfdsfql_for_ticker(ticker):
    """Make a FactSet API call for a specific ticker."""
    url = "https://my.apps.factset.com/services/equalsfdsfql"
    params = {"string_na": "true", "APP": "DATA_REQUEST_STREAM"}
    headers = {
        "Host": "my.apps.factset.com",
        "Connection": "keep-alive",
        "Accept": "application/json, text/plain, */*",
        "Content-Type": "application/x-www-form-urlencoded",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36",
    }
    cookies = {
        "FdsAuthScheme": "oidc",
        "FdsSessionId": "your-session-id-here",  # Replace with your actual session ID
        # Add other cookies as needed
    }
    fql_state_id = "your-fql-state-id-here"  # Replace with your actual FQL state ID
    symbol_exprs = f"{ticker}%5EFFD_INSIGHT"  # URL-encoded '^' as %5E
    data = f"FQL_STATE_ID={fql_state_id}&SYMBOL_EXPRS={symbol_exprs}"

    response = requests.post(
        url, params=params, headers=headers, cookies=cookies, data=data, verify=False
    )

    if response.status_code == 200:
        try:
            json_data = response.json()
            insight = json_data[0]["$value"][0][0] if json_data and "$value" in json_data[0] else "No insight available"
            return insight
        except Exception as e:
            print(f"Error parsing response for {ticker}: {e}")
            return "Error parsing response"
    else:
        print(f"Failed for {ticker}: HTTP {response.status_code}")
        return "API call failed"

def main():
    """Fetch tickers and update insights only if FS_insight is missing."""
    tickers_data = fetch_tickers_from_db()
    for data in tickers_data:
        ticker = data["ticker"]
        insight = data["insight"]
        if insight is None or insight.strip() == "":
            print(f"Processing {ticker} (no existing insight)...")
            new_insight = factset_equalsfdsfql_for_ticker(ticker)
            update_fs_insight(ticker, new_insight)
            print(f"Updated {ticker} with insight: {new_insight[:50]}...")
        else:
            print(f"Skipping {ticker} (insight already exists)")

    print("All tickers have been processed.")

if __name__ == "__main__":
    main()
# Out:
# Skipping NTSX (insight already exists)
# Skipping HIPS (insight already exists)
# Skipping EAOA (insight already exists)
# Skipping AOM (insight already exists)
# Skipping AOK (insight already exists)
# Skipping EAOK (insight already exists)
# Skipping EAOM (insight already exists)
# Skipping INCM (insight already exists)
# Skipping ICVT (insight already exists)
# Skipping ZHDG (insight already exists)
# Skipping DYTA (insight already exists)
# Skipping LEXI (insight already exists)
# Skipping RORO (insight already exists)
# Skipping TFPN (insight already exists)
# Skipping BAMY (insight already exists)
# Skipping CGBL (insight already exists)
# Skipping AOR (insight already exists)
# Skipping EAOR (insight already exists)
# Skipping BAMO (insight already exists)
# Skipping GHTA (insight already exists)
# Skipping MPRO (insight already exists)
# Skipping HCMT (insight already exists)
# Skipping THY (insight already exists)
# Skipping SPAX (insight already exists)
# Skipping FMF (insight already exists)
# Skipping CTA (insight already exists)
# Skipping FAAR (insight already exists)
# Skipping VEGA (insight already exists)
# Skipping BUYW (insight already exists)
# Skipping FTLS (insight already exists)
# Skipping FFLS (insight already exists)
# Skipping CLSE (insight already exists)
# Skipping LBAY (insight already exists)
# Skipping EQLS (insight already exists)
# Skipping SPCX (insight already exists)
# Skipping HF (insight already exists)
# Skipping AMPD (insight already exists)
# Skipping QIS (insight already exists)
# Skipping CAOS (insight already exists)
# Skipping MSSS (insight already exists)
# Skipping SAMM (insight already exists)
# Skipping SOFR (insight already exists)
# Skipping CMDY (insight already exists)
# Skipping NBCM (insight already exists)
# Skipping CERY (insight already exists)
# Skipping EDGH (insight already exists)
# Skipping AAAU (insight already exists)
# Skipping GLDM (insight already exists)
# Skipping DBE (insight already exists)
# Skipping CPER (insight already exists)
# Skipping CORN (insight already exists)
# Skipping UGA (insight already exists)
# Skipping BNO (insight already exists)
# Skipping SOYB (insight already exists)
# Skipping WEAT (insight already exists)
# Skipping CANE (insight already exists)
# Skipping UNG (insight already exists)
# Skipping TAGS (insight already exists)
# Skipping FGDL (insight already exists)
# Skipping ZSL (insight already exists)
# Skipping KOLD (insight already exists)
# Skipping GDE (insight already exists)
# Skipping BBAX (insight already exists)
# Skipping FLAX (insight already exists)
# Skipping BBCA (insight already exists)
# Skipping FYEE (insight already exists)
# Skipping VMOT (insight already exists)
# Skipping DAX (insight already exists)
# Skipping EDEN (insight already exists)
# Skipping ENOR (insight already exists)
# Skipping GXG (insight already exists)
# Skipping FLRU (insight already exists)
# Skipping WBIG (insight already exists)
# Skipping AVXC (insight already exists)
# Skipping NSI (insight already exists)
# Skipping PCEM (insight already exists)
# Skipping XCNY (insight already exists)
# Skipping HEEM (insight already exists)
# Skipping AVEM (insight already exists)
# Skipping LDEM (insight already exists)
# Skipping JEMA (insight already exists)
# Skipping BBEM (insight already exists)
# Skipping AVSE (insight already exists)
# Skipping EMCS (insight already exists)
# Skipping EMCR (insight already exists)
# Skipping FMQQ (insight already exists)
# Skipping DEM (insight already exists)
# Skipping DIEM (insight already exists)
# Skipping DFEV (insight already exists)
# Skipping EYLD (insight already exists)
# Skipping EFAV (insight already exists)
# Skipping HFXI (insight already exists)
# Skipping IGRO (insight already exists)
# Skipping IQSI (insight already exists)
# Skipping EFAX (insight already exists)
# Skipping DINT (insight already exists)
# Skipping EASG (insight already exists)
# Skipping FDEV (insight already exists)
# Skipping AVDE (insight already exists)
# Skipping GSID (insight already exists)
# Skipping DFAI (insight already exists)
# Skipping LCTD (insight already exists)
# Skipping DFAX (insight already exists)
# Skipping DFIC (insight already exists)
# Skipping CVIE (insight already exists)
# Skipping GXUS (insight already exists)
# Skipping AVSD (insight already exists)
# Skipping OVF (insight already exists)
# Skipping DWMF (insight already exists)
# Skipping INTL (insight already exists)
# Skipping VIGI (insight already exists)
# Skipping PID (insight already exists)
# Skipping EFV (insight already exists)
# Skipping FIDI (insight already exists)
# Skipping FIVA (insight already exists)
# Skipping SCHY (insight already exists)
# Skipping KLMT (insight already exists)
# Skipping EDGI (insight already exists)
# Skipping ACWV (insight already exists)
# Skipping TOK (insight already exists)
# Skipping CRBN (insight already exists)
# Skipping GLOF (insight already exists)
# Skipping WRND (insight already exists)
# Skipping KOCG (insight already exists)
# Skipping DWLD (insight already exists)
# Skipping FLMX (insight already exists)
# Skipping ISCF (insight already exists)
# Skipping PCCE (insight already exists)
# Skipping FLCH (insight already exists)
# Skipping FLTW (insight already exists)
# Skipping INDH (insight already exists)
# Skipping IOPP (insight already exists)
# Skipping FLIN (insight already exists)
# Skipping NDIA (insight already exists)
# Skipping HEWJ (insight already exists)
# Skipping BBJP (insight already exists)
# Skipping EWJV (insight already exists)
# Skipping FLBR (insight already exists)
# Skipping FLLA (insight already exists)
# Skipping AGOX (insight already exists)
# Skipping GMET (insight already exists)
# Skipping SIXH (insight already exists)
# Skipping DISO (insight already exists)
# Skipping JPMO (insight already exists)
# Skipping XOMO (insight already exists)
# Skipping PYPY (insight already exists)
# Skipping MSFO (insight already exists)
# Skipping TSLP (insight already exists)
# Skipping NFLP (insight already exists)
# Skipping MSFY (insight already exists)
# Skipping AAPY (insight already exists)
# Skipping GOOP (insight already exists)
# Skipping SQY (insight already exists)
# Skipping TSLY (insight already exists)
# Skipping AMZY (insight already exists)
# Skipping APLY (insight already exists)
# Skipping NVDY (insight already exists)
# Skipping CONY (insight already exists)
# Skipping ULTY (insight already exists)
# Skipping IDVO (insight already exists)
# Skipping SPYC (insight already exists)
# Skipping SPD (insight already exists)
# Skipping SPUC (insight already exists)
# Skipping BLOK (insight already exists)
# Skipping VOX (insight already exists)
# Skipping VCR (insight already exists)
# Skipping IEDI (insight already exists)
# Skipping BEDZ (insight already exists)
# Skipping EATZ (insight already exists)
# Skipping VDC (insight already exists)
# Skipping AMZA (insight already exists)
# Skipping HSBH (insight already exists)
# Skipping VDE (insight already exists)
# Skipping PXE (insight already exists)
# Skipping PXJ (insight already exists)
# Skipping KSEA (insight already exists)
# Skipping YOLO (insight already exists)
# Skipping TOKE (insight already exists)
# Skipping SHEH (insight already exists)
# Skipping VFH (insight already exists)
# Skipping GABF (insight already exists)
# Skipping BIZD (insight already exists)
# Skipping PBDC (insight already exists)
# Skipping EMQQ (insight already exists)
# Skipping IFV (insight already exists)
# Skipping AZNH (insight already exists)
# Skipping VHT (insight already exists)
# Skipping IBBQ (insight already exists)
# Skipping INQQ (insight already exists)
# Skipping DGIN (insight already exists)
# Skipping VIS (insight already exists)
# Skipping HAP (insight already exists)
# Skipping FIW (insight already exists)
# Skipping MOO (insight already exists)
# Skipping VAW (insight already exists)
# Skipping REET (insight already exists)
# Skipping HAUZ (insight already exists)
# Skipping ICF (insight already exists)
# Skipping PPTY (insight already exists)
# Skipping DFAR (insight already exists)
# Skipping CRED (insight already exists)
# Skipping MORT (insight already exists)
# Skipping AGIX (insight already exists)
# Skipping TTEQ (insight already exists)
# Skipping CHPS (insight already exists)
# Skipping VGT (insight already exists)
# Skipping IETC (insight already exists)
# Skipping SOXQ (insight already exists)
# Skipping TIME (insight already exists)
# Skipping WUGI (insight already exists)
# Skipping GAST (insight already exists)
# Skipping ODDS (insight already exists)
# Skipping PSWD (insight already exists)
# Skipping PRNT (insight already exists)
# Skipping PP (insight already exists)
# Skipping GCAD (insight already exists)
# Skipping ILDR (insight already exists)
# Skipping VCAR (insight already exists)
# Skipping KOMP (insight already exists)
# Skipping PGF (insight already exists)
# Skipping FXU (insight already exists)
# Skipping VPU (insight already exists)
# Skipping CVY (insight already exists)
# Skipping SPBC (insight already exists)
# Skipping EATV (insight already exists)
# Skipping IPDP (insight already exists)
# Skipping RHRX (insight already exists)
# Skipping RHTX (insight already exists)
# Skipping WBIF (insight already exists)
# Skipping NXTE (insight already exists)
# Skipping SHDG (insight already exists)
# Skipping CCOR (insight already exists)
# Skipping RSSY (insight already exists)
# Skipping ZZZ (insight already exists)
# Skipping TOPT (insight already exists)
# Skipping DFVE (insight already exists)
# Skipping IWB (insight already exists)
# Skipping IWL (insight already exists)
# Skipping IYY (insight already exists)
# Skipping QUAL (insight already exists)
# Skipping VTHR (insight already exists)
# Skipping SPHQ (insight already exists)
# Skipping XLG (insight already exists)
# Skipping OEF (insight already exists)
# Skipping USMV (insight already exists)
# Skipping IWV (insight already exists)
# Skipping QUS (insight already exists)
# Skipping SPYX (insight already exists)
# Skipping LEAD (insight already exists)
# Skipping SHE (insight already exists)
# Skipping PSET (insight already exists)
# Skipping KRMA (insight already exists)
# Skipping FQAL (insight already exists)
# Skipping FDLO (insight already exists)
# Skipping ESGU (insight already exists)
# Skipping FLQL (insight already exists)
# Skipping JUST (insight already exists)
# Skipping USSG (insight already exists)
# Skipping SNPE (insight already exists)
# Skipping SUSL (insight already exists)
# Skipping AVUS (insight already exists)
# Skipping RECS (insight already exists)
# Skipping FCPI (insight already exists)
# Skipping BKLC (insight already exists)
# Skipping FLRG (insight already exists)
# Skipping EFIV (insight already exists)
# Skipping LCTU (insight already exists)
# Skipping CGUS (insight already exists)
# Skipping USNZ (insight already exists)
# Skipping DFSU (insight already exists)
# Skipping HDUS (insight already exists)
# Skipping CVLC (insight already exists)
# Skipping FELC (insight already exists)
# Skipping SEIQ (insight already exists)
# Skipping LRND (insight already exists)
# Skipping AVSU (insight already exists)
# Skipping ESMV (insight already exists)
# Skipping JCTR (insight already exists)
# Skipping OVL (insight already exists)
# Skipping AESR (insight already exists)
# Skipping SPMV (insight already exists)
# Skipping DCOR (insight already exists)
# Skipping AVLC (insight already exists)
# Skipping CDEI (insight already exists)
# Skipping SEIM (insight already exists)
# Skipping NANC (insight already exists)
# Skipping DGRW (insight already exists)
# Skipping QARP (insight already exists)
# Skipping BBLU (insight already exists)
# Skipping SELV (insight already exists)
# Skipping SIZE (insight already exists)
# Skipping ADPV (insight already exists)
# Skipping RSP (insight already exists)
# Skipping XVOL (insight already exists)
# Skipping ROUS (insight already exists)
# Skipping USMF (insight already exists)
# Skipping LGH (insight already exists)
# Skipping QNXT (insight already exists)
# Skipping QTOP (insight already exists)
# Skipping MTUM (insight already exists)
# Skipping DWUS (insight already exists)
# Skipping PABU (insight already exists)
# Skipping NZUS (insight already exists)
# Skipping QQQ (insight already exists)
# Skipping IWF (insight already exists)
# Skipping VOOG (insight already exists)
# Skipping IVW (insight already exists)
# Skipping IWY (insight already exists)
# Skipping FDMO (insight already exists)
# Skipping GARP (insight already exists)
# Skipping USXF (insight already exists)
# Skipping QQQM (insight already exists)
# Skipping QQMG (insight already exists)
# Skipping STXG (insight already exists)
# Skipping QGRW (insight already exists)
# Skipping TGRT (insight already exists)
# Skipping FELG (insight already exists)
# Skipping SXQG (insight already exists)
# Skipping FFND (insight already exists)
# Skipping EGUS (insight already exists)
# Skipping SNPG (insight already exists)
# Skipping CGCV (insight already exists)
# Skipping FFLV (insight already exists)
# Skipping DVDN (insight already exists)
# Skipping DTD (insight already exists)
# Skipping DLN (insight already exists)
# Skipping IVE (insight already exists)
# Skipping VOOV (insight already exists)
# Skipping IWX (insight already exists)
# Skipping IWD (insight already exists)
# Skipping VLUE (insight already exists)
# Skipping PWV (insight already exists)
# Skipping PY (insight already exists)
# Skipping FVAL (insight already exists)
# Skipping FDRR (insight already exists)
# Skipping FDVV (insight already exists)
# Skipping IUS (insight already exists)
# Skipping REVS (insight already exists)
# Skipping AVLV (insight already exists)
# Skipping CGDV (insight already exists)
# Skipping STXV (insight already exists)
# Skipping TVAL (insight already exists)
# Skipping FELV (insight already exists)
# Skipping EVUS (insight already exists)
# Skipping SNPV (insight already exists)
# Skipping DHS (insight already exists)
# Skipping DVY (insight already exists)
# Skipping QDIV (insight already exists)
# Skipping ULVM (insight already exists)
# Skipping SEIV (insight already exists)
# Skipping RSPE (insight already exists)
# Skipping COWS (insight already exists)
# Skipping STXM (insight already exists)
# Skipping AVMC (insight already exists)
# Skipping IWR (insight already exists)
# Skipping EQAL (insight already exists)
# Skipping ONEO (insight already exists)
# Skipping IQSM (insight already exists)
# Skipping FMDE (insight already exists)
# Skipping CVMC (insight already exists)
# Skipping LOPP (insight already exists)
# Skipping VFMF (insight already exists)
# Skipping IVOO (insight already exists)
# Skipping QVMM (insight already exists)
# Skipping FDLS (insight already exists)
# Skipping MIDE (insight already exists)
# Skipping QMID (insight already exists)
# Skipping IWP (insight already exists)
# Skipping QQQJ (insight already exists)
# Skipping QQJG (insight already exists)
# Skipping PFUT (insight already exists)
# Skipping IVOG (insight already exists)
# Skipping MDYG (insight already exists)
# Skipping AVMV (insight already exists)
# Skipping DXUV (insight already exists)
# Skipping IWS (insight already exists)
# Skipping AIVL (insight already exists)
# Skipping PEY (insight already exists)
# Skipping JPUS (insight already exists)
# Skipping ONEY (insight already exists)
# Skipping ONEV (insight already exists)
# Skipping SNPD (insight already exists)
# Skipping DON (insight already exists)
# Skipping IVOV (insight already exists)
# Skipping IJJ (insight already exists)
# Skipping EZM (insight already exists)
# Skipping MDYV (insight already exists)
# Skipping VTWO (insight already exists)
# Skipping IWM (insight already exists)
# Skipping VIOO (insight already exists)
# Skipping SMLF (insight already exists)
# Skipping GSSC (insight already exists)
# Skipping SMMV (insight already exists)
# Skipping PSC (insight already exists)
# Skipping FSMD (insight already exists)
# Skipping STXK (insight already exists)
# Skipping FESM (insight already exists)
# Skipping NSCS (insight already exists)
# Skipping QVMS (insight already exists)
# Skipping QQQS (insight already exists)
# Skipping QSML (insight already exists)
# Skipping CBSE (insight already exists)
# Skipping VIOG (insight already exists)
# Skipping VTWG (insight already exists)
# Skipping IJT (insight already exists)
# Skipping SLYG (insight already exists)
# Skipping DES (insight already exists)
# Skipping VIOV (insight already exists)
# Skipping DGRS (insight already exists)
# Skipping IJS (insight already exists)
# Skipping SLYV (insight already exists)
# Skipping EES (insight already exists)
# Skipping VTWV (insight already exists)
# Skipping SVAL (insight already exists)
# Skipping DFAT (insight already exists)
# Skipping DFCA (insight already exists)
# Skipping PWZ (insight already exists)
# Skipping AVMU (insight already exists)
# Skipping ITM (insight already exists)
# Skipping MUST (insight already exists)
# Skipping JMUB (insight already exists)
# Skipping JMSI (insight already exists)
# Skipping MBNE (insight already exists)
# Skipping ZTAX (insight already exists)
# Skipping TAFM (insight already exists)
# Skipping GENM (insight already exists)
# Skipping OVM (insight already exists)
# Skipping TFI (insight already exists)
# Skipping RVNU (insight already exists)
# Skipping PZA (insight already exists)
# Skipping RTAI (insight already exists)
# Skipping TAFL (insight already exists)
# Skipping SHM (insight already exists)
# Skipping EVSM (insight already exists)
# Skipping JMST (insight already exists)
# Skipping PUSH (insight already exists)
# Skipping PZT (insight already exists)
# Skipping CALI (insight already exists)
# Skipping VWOB (insight already exists)
# Skipping BEMB (insight already exists)
# Skipping EMHC (insight already exists)
# Skipping GAEM (insight already exists)
# Skipping AGZD (insight already exists)
# Skipping HYZD (insight already exists)
# Skipping GRNB (insight already exists)
# Skipping BGRN (insight already exists)
# Skipping DGCB (insight already exists)
# Skipping DFGX (insight already exists)
# Skipping LQD (insight already exists)
# Skipping LQDI (insight already exists)
# Skipping ELQD (insight already exists)
# Skipping SKOR (insight already exists)
# Skipping QLTA (insight already exists)
# Skipping QIG (insight already exists)
# Skipping GIGB (insight already exists)
# Skipping SUSC (insight already exists)
# Skipping IGEB (insight already exists)
# Skipping IG (insight already exists)
# Skipping LQDB (insight already exists)
# Skipping MIG (insight already exists)
# Skipping LDRC (insight already exists)
# Skipping BBBI (insight already exists)
# Skipping BBHY (insight already exists)
# Skipping XBB (insight already exists)
# Skipping QHY (insight already exists)
# Skipping SHYL (insight already exists)
# Skipping HYDW (insight already exists)
# Skipping HYRM (insight already exists)
# Skipping HYUP (insight already exists)
# Skipping LTPZ (insight already exists)
# Skipping TIP (insight already exists)
# Skipping TIPZ (insight already exists)
# Skipping TDTF (insight already exists)
# Skipping LDRI (insight already exists)
# Skipping OVB (insight already exists)
# Skipping TUA (insight already exists)
# Skipping PAB (insight already exists)
# Skipping GBF (insight already exists)
# Skipping EAGG (insight already exists)
# Skipping FLCB (insight already exists)
# Skipping BKAG (insight already exists)
# Skipping AVIG (insight already exists)
# Skipping BAMB (insight already exists)
# Skipping UNIY (insight already exists)
# Skipping VCRB (insight already exists)
# Skipping GENT (insight already exists)
# Skipping JCPB (insight already exists)
# Skipping PMBS (insight already exists)
# Skipping KDRN (insight already exists)
# Skipping CPLS (insight already exists)
# Skipping VPLS (insight already exists)
# Skipping BRTR (insight already exists)
# Skipping MBSD (insight already exists)
# Skipping IEI (insight already exists)
# Skipping GNMA (insight already exists)
# Skipping JMBS (insight already exists)
# Skipping UFIV (insight already exists)
# Skipping USVN (insight already exists)
# Skipping TLH (insight already exists)
# Skipping GOVI (insight already exists)
# Skipping TLT (insight already exists)
# Skipping ZROZ (insight already exists)
# Skipping GOVZ (insight already exists)
# Skipping BNDD (insight already exists)
# Skipping TYA (insight already exists)
# Skipping IEF (insight already exists)
# Skipping UTEN (insight already exists)
# Skipping UTWY (insight already exists)
# Skipping UTHY (insight already exists)
# Skipping TLTP (insight already exists)
# Skipping USIN (insight already exists)
# Skipping BAB (insight already exists)
# Skipping LKOR (insight already exists)
# Skipping BBBL (insight already exists)
# Skipping ZTEN (insight already exists)
# Skipping XFLX (insight already exists)
# Skipping DIAL (insight already exists)
# Skipping DEED (insight already exists)
# Skipping AFIF (insight already exists)
# Skipping RMIF (insight already exists)
# Skipping BYLD (insight already exists)
# Skipping GHMS (insight already exists)
# Skipping FIAX (insight already exists)
# Skipping PFFD (insight already exists)
# Skipping PFFA (insight already exists)
# Skipping AGZ (insight already exists)
# Skipping SHY (insight already exists)
# Skipping OBIL (insight already exists)
# Skipping UTWO (insight already exists)
# Skipping UTRE (insight already exists)
# Skipping USSH (insight already exists)
# Skipping OVT (insight already exists)
# Skipping GVI (insight already exists)
# Skipping JSCP (insight already exists)
# Skipping AVSF (insight already exists)
# Skipping GSIG (insight already exists)
# Skipping QSIG (insight already exists)
# Skipping ZTWO (insight already exists)
# Skipping ZTRE (insight already exists)
# Skipping BBBS (insight already exists)
# Skipping TIPX (insight already exists)
# Skipping STPZ (insight already exists)
# Skipping TDTT (insight already exists)
# Skipping BOXX (insight already exists)
# Skipping CSHI (insight already exists)
# Skipping BIL (insight already exists)
# Skipping TFLO (insight already exists)
# Skipping BILS (insight already exists)
# Skipping CLOA (insight already exists)
# Skipping PAAA (insight already exists)
# Skipping BILZ (insight already exists)
# Skipping ICLO (insight already exists)
# Skipping LQDH (insight already exists)
# Skipping GSY (insight already exists)
# Skipping FLRN (insight already exists)
# Skipping FLTR (insight already exists)
# Skipping ULST (insight already exists)
# Skipping FLOT (insight already exists)
# Skipping IGBH (insight already exists)
# Skipping VNLA (insight already exists)
# Skipping JPST (insight already exists)
# Skipping PULS (insight already exists)
# Skipping FLDR (insight already exists)
# Skipping VUSB (insight already exists)
# Skipping DUSB (insight already exists)
# Skipping SHV (insight already exists)
# Skipping USFR (insight already exists)
# Skipping XBIL (insight already exists)
# Skipping TBIL (insight already exists)
# Skipping FSLD (insight already exists)
# Skipping FLUD (insight already exists)
# Skipping OPER (insight already exists)
# Skipping CLOX (insight already exists)
# Skipping CSHP (insight already exists)
# Skipping CGUI (insight already exists)
# Skipping KCSH (insight already exists)
# Skipping PSQA (insight already exists)
# Skipping SCUS (insight already exists)
# Skipping FLDB (insight already exists)
# Skipping ARSYX (insight already exists)
# Skipping CBSYX (insight already exists)
# Skipping ABIYX (insight already exists)
# Skipping AAZYX (insight already exists)
# Skipping AUUYX (insight already exists)
# Skipping ATTYX (insight already exists)
# Skipping GOPIX (insight already exists)
# Skipping ADVDX (insight already exists)
# Skipping GWLIX (insight already exists)
# Skipping AIGYX (insight already exists)
# Skipping GSCIX (insight already exists)
# Skipping ACAZX (insight already exists)
# Skipping AZEMX (insight already exists)
# Skipping ALZFX (insight already exists)
# Skipping ALMZX (insight already exists)
# Skipping ASPZX (insight already exists)
# Skipping MBFIX (insight already exists)
# Skipping EMGNX (insight already exists)
# Skipping EKHIX (insight already exists)
# Skipping WMBIX (insight already exists)
# Skipping EKGIX (insight already exists)
# Skipping WICIX (insight already exists)
# Skipping ESPNX (insight already exists)
# Skipping WGBIX (insight already exists)
# Skipping LPEIX (insight already exists)
# Skipping INDIX (insight already exists)
# Skipping TOVYX (insight already exists)
# Skipping SPWYX (insight already exists)
# Skipping ACFSX (insight already exists)
# Skipping ACIOX (insight already exists)
# Skipping AOVIX (insight already exists)
# Skipping ASCQX (insight already exists)
# Skipping ACCIX (insight already exists)
# Skipping BULIX (insight already exists)
# Skipping DWGHX (insight already exists)
# Skipping AHMFX (insight already exists)
# Skipping AHIFX (insight already exists)
# Skipping AMRFX (insight already exists)
# Skipping CAIFX (insight already exists)
# Skipping BFCGX (insight already exists)
# Skipping EBNFX (insight already exists)
# Skipping FINFX (insight already exists)
# Skipping SMCFX (insight already exists)
# Skipping AIVFX (insight already exists)
# Skipping MEQFX (insight already exists)
# Skipping ARIMX (insight already exists)
# Skipping TQTIX (insight already exists)
# Skipping YAFIX (insight already exists)
# Skipping ANGIX (insight already exists)
# Skipping AIMOX (insight already exists)
# Skipping AUEIX (insight already exists)
# Skipping ASMOX (insight already exists)
# Skipping PLHYX (insight already exists)
# Skipping PLCDX (insight already exists)
# Skipping APDOX (insight already exists)
# Skipping APDGX (insight already exists)
# Skipping ARDBX (insight already exists)
# Skipping APDJX (insight already exists)
# Skipping APDKX (insight already exists)
# Skipping BDFIX (insight already exists)
# Skipping BEXIX (insight already exists)
# Skipping BFTIX (insight already exists)
# Skipping BFGIX (insight already exists)
# Skipping BIOIX (insight already exists)
# Skipping BREIX (insight already exists)
# Skipping BICPX (insight already exists)
# Skipping BIMPX (insight already exists)
# Skipping BIGPX (insight already exists)
# Skipping MAEFX (insight already exists)
# Skipping MAILX (insight already exists)
# Skipping MANJX (insight already exists)
# Skipping MAPCX (insight already exists)
# Skipping DGIGX (insight already exists)
# Skipping DBIRX (insight already exists)
# Skipping DCMIX (insight already exists)
# Skipping DRLIX (insight already exists)
# Skipping MIEGX (insight already exists)
# Skipping DFLIX (insight already exists)
# Skipping DGIEX (insight already exists)
# Skipping MIISX (insight already exists)
# Skipping DSPIX (insight already exists)
# Skipping MIMSX (insight already exists)
# Skipping DOPIX (insight already exists)
# Skipping SSETX (insight already exists)
# Skipping STSVX (insight already exists)
# Skipping BEMIX (insight already exists)
# Skipping BGVIX (insight already exists)
# Skipping BGHIX (insight already exists)
# Skipping BGLYX (insight already exists)
# Skipping BAFFX (insight already exists)
# Skipping BAFLX (insight already exists)
# Skipping BAISX (insight already exists)
# Skipping BUIOX (insight already exists)
# Skipping BUIBX (insight already exists)
# Skipping CXGCX (insight already exists)
# Skipping CIGEX (insight already exists)
# Skipping CBAIX (insight already exists)
# Skipping CBDIX (insight already exists)
# Skipping CFAIX (insight already exists)
# Skipping CVMIX (insight already exists)
# Skipping CAGIX (insight already exists)
# Skipping CYBIX (insight already exists)
# Skipping FICHX (insight already exists)
# Skipping CCCNX (insight already exists)
# Skipping CIPNX (insight already exists)
# Skipping SMBYX (insight already exists)
# Skipping LBGIX (insight already exists)
# Skipping LBFIX (insight already exists)
# Skipping CSUIX (insight already exists)
# Skipping IRFIX (insight already exists)
# Skipping CAEZX (insight already exists)
# Skipping NBGPX (insight already exists)
# Skipping SRINX (insight already exists)
# Skipping UMEMX (insight already exists)
# Skipping CFRZX (insight already exists)
# Skipping LNGZX (insight already exists)
# Skipping CUGZX (insight already exists)
# Skipping CREEX (insight already exists)
# Skipping CDGRX (insight already exists)
# Skipping CRIEX (insight already exists)
# Skipping CRIMX (insight already exists)
# Skipping CEMFX (insight already exists)
# Skipping CIHIX (insight already exists)
# Skipping CUSIX (insight already exists)
# Skipping DEMIX (insight already exists)
# Skipping FIVUX (insight already exists)
# Skipping DEVIX (insight already exists)
# Skipping FTOTX (insight already exists)
# Skipping DPIIX (insight already exists)
# Skipping COMZX (insight already exists)
# Skipping KDHIX (insight already exists)
# Skipping BTIIX (insight already exists)
# Skipping TOLIX (insight already exists)
# Skipping PPILX (insight already exists)
# Skipping NOTIX (insight already exists)
# Skipping SNWIX (insight already exists)
# Skipping EIAZX (insight already exists)
# Skipping EILGX (insight already exists)
# Skipping EIUTX (insight already exists)
# Skipping EICOX (insight already exists)
# Skipping EIGOX (insight already exists)
# Skipping EICGX (insight already exists)
# Skipping EIHYX (insight already exists)
# Skipping EIMDX (insight already exists)
# Skipping EINAX (insight already exists)
# Skipping EACPX (insight already exists)
# Skipping ETIEX (insight already exists)
# Skipping ETIHX (insight already exists)
# Skipping SBFIX (insight already exists)
# Skipping IVFIX (insight already exists)
# Skipping KAUIX (insight already exists)
# Skipping QIBGX (insight already exists)
# Skipping PAMIX (insight already exists)
# Skipping FGCIX (insight already exists)
# Skipping FSTYX (insight already exists)
# Skipping FTRGX (insight already exists)
# Skipping FFNIX (insight already exists)
# Skipping FCMQX (insight already exists)
# Skipping FICCX (insight already exists)
# Skipping FZIIX (insight already exists)
# Skipping FALIX (insight already exists)
# Skipping FEMIX (insight already exists)
# Skipping FCVIX (insight already exists)
# Skipping SGIIX (insight already exists)
# Skipping FEHIX (insight already exists)
# Skipping FESCX (insight already exists)
# Skipping FOVIX (insight already exists)
# Skipping FDHIX (insight already exists)
# Skipping FRAAX (insight already exists)
# Skipping FNRAX (insight already exists)
# Skipping LMSIX (insight already exists)
# Skipping FRVZX (insight already exists)
# Skipping CCAPX (insight already exists)
# Skipping GBMIX (insight already exists)
# Skipping GSAEX (insight already exists)
# Skipping GCEJX (insight already exists)
# Skipping GIRPX (insight already exists)
# Skipping GHIRX (insight already exists)
# Skipping GRGTX (insight already exists)
# Skipping GSTPX (insight already exists)
# Skipping GSPTX (insight already exists)
# Skipping GSVTX (insight already exists)
# Skipping GSRIX (insight already exists)
# Skipping GPPOX (insight already exists)
# Skipping GGIRX (insight already exists)
# Skipping GIUSX (insight already exists)
# Skipping GIOIX (insight already exists)
# Skipping HABDX (insight already exists)
# Skipping HBLIX (insight already exists)
# Skipping HERIX (insight already exists)
# Skipping HGHIX (insight already exists)
# Skipping HDVIX (insight already exists)
# Skipping HFHIX (insight already exists)
# Skipping HMVJX (insight already exists)
# Skipping HBAIX (insight already exists)
# Skipping HRLIX (insight already exists)
# Skipping SEMNX (insight already exists)
# Skipping SIDNX (insight already exists)
# Skipping HSEIX (insight already exists)
# Skipping IHSIX (insight already exists)
# Skipping ITBIX (insight already exists)
# Skipping IOEZX (insight already exists)
# Skipping IOBZX (insight already exists)
# Skipping ICTEX (insight already exists)
# Skipping MSEFX (insight already exists)
# Skipping ODVYX (insight already exists)
# Skipping ASIYX (insight already exists)
# Skipping GTDYX (insight already exists)
# Skipping AEDYX (insight already exists)
# Skipping ESMYX (insight already exists)
# Skipping QGRYX (insight already exists)
# Skipping AWSYX (insight already exists)
# Skipping GLVYX (insight already exists)
# Skipping ARGYX (insight already exists)
# Skipping ASRYX (insight already exists)
# Skipping OGMYX (insight already exists)
# Skipping ACTDX (insight already exists)
# Skipping OFIYX (insight already exists)
# Skipping OIDYX (insight already exists)
# Skipping OSMYX (insight already exists)
# Skipping OIGYX (insight already exists)
# Skipping IARYX (insight already exists)
# Skipping ONYYX (insight already exists)
# Skipping RMUYX (insight already exists)
# Skipping OYAIX (insight already exists)
# Skipping SMEYX (insight already exists)
# Skipping MLPOX (insight already exists)
# Skipping MAIIX (insight already exists)
# Skipping BSPIX (insight already exists)
# Skipping BMOIX (insight already exists)
# Skipping JBALX (insight already exists)
# Skipping JMGRX (insight already exists)
# Skipping JGCIX (insight already exists)
# Skipping JEUIX (insight already exists)
# Skipping JATIX (insight already exists)
# Skipping JSCOX (insight already exists)
# Skipping JVTIX (insight already exists)
# Skipping JOEMX (insight already exists)
# Skipping JEVIX (insight already exists)
# Skipping JFGIX (insight already exists)
# Skipping JGEFX (insight already exists)
# Skipping JSTIX (insight already exists)
# Skipping JSCIX (insight already exists)
# Skipping JTAIX (insight already exists)
# Skipping JSCBX (insight already exists)
# Skipping HLEIX (insight already exists)
# Skipping JLPSX (insight already exists)
# Skipping LSHUX (insight already exists)
# Skipping KNPYX (insight already exists)
# Skipping KSCYX (insight already exists)
# Skipping LZISX (insight already exists)
# Skipping LCAIX (insight already exists)
# Skipping LEVIX (insight already exists)
# Skipping LCRIX (insight already exists)
# Skipping ASCGX (insight already exists)
# Skipping ALFYX (insight already exists)
# Skipping LGLIX (insight already exists)
# Skipping LAUYX (insight already exists)
# Skipping LIFIX (insight already exists)
# Skipping LINYX (insight already exists)
# Skipping LAIDX (insight already exists)
# Skipping LMIYX (insight already exists)
# Skipping LUBYX (insight already exists)
# Skipping EXEYX (insight already exists)
# Skipping MNHAX (insight already exists)
# Skipping MNHIX (insight already exists)
# Skipping MFCIX (insight already exists)
# Skipping MISGX (insight already exists)
# Skipping MIAGX (insight already exists)
# Skipping MEMIX (insight already exists)
# Skipping MFWIX (insight already exists)
# Skipping MWNIX (insight already exists)
# Skipping MQLIX (insight already exists)
# Skipping MVGIX (insight already exists)
# Skipping MMSTX (insight already exists)
# Skipping MNDIX (insight already exists)
# Skipping MDOEX (insight already exists)
# Skipping MSSGX (insight already exists)
# Skipping MFAIX (insight already exists)
# Skipping NWXVX (insight already exists)
# Skipping NWSIX (insight already exists)
# Skipping NCRLX (insight already exists)
# Skipping NMIIX (insight already exists)
# Skipping NBRIX (insight already exists)
# Skipping GILIX (insight already exists)
# Skipping GIUIX (insight already exists)
# Skipping PORYX (insight already exists)
# Skipping NMMEX (insight already exists)
# Skipping NMIEX (insight already exists)
# Skipping NOEMX (insight already exists)
# Skipping NOINX (insight already exists)
# Skipping NOMIX (insight already exists)
# Skipping NSGRX (insight already exists)
# Skipping NSIDX (insight already exists)
# Skipping NOSGX (insight already exists)
# Skipping NOUGX (insight already exists)
# Skipping NMARX (insight already exists)
# Skipping TCBPX (insight already exists)
# Skipping NQGIX (insight already exists)
# Skipping TGROX (insight already exists)
# Skipping NCOIX (insight already exists)
# Skipping TSORX (insight already exists)
# Skipping THCVX (insight already exists)
# Skipping TSGHX (insight already exists)
# Skipping TSMHX (insight already exists)
# Skipping FLTRX (insight already exists)
# Skipping FTLRX (insight already exists)
# Skipping NMMDX (insight already exists)
# Skipping FORCX (insight already exists)
# Skipping NVHIX (insight already exists)
# Skipping NSMRX (insight already exists)
# Skipping MCYIX (insight already exists)
# Skipping CSHZX (insight already exists)
# Skipping MYIIX (insight already exists)
# Skipping OFSFX (insight already exists)
# Skipping PREQX (insight already exists)
# Skipping PCEMX (insight already exists)
# Skipping PCGTX (insight already exists)
# Skipping PCSVX (insight already exists)
# Skipping EIEMX (insight already exists)
# Skipping PYCBX (insight already exists)
# Skipping PYACX (insight already exists)
# Skipping PYGSX (insight already exists)
# Skipping PYSBX (insight already exists)
# Skipping QFVIX (insight already exists)
# Skipping PTCRX (insight already exists)
# Skipping PTIAX (insight already exists)
# Skipping PAGRX (insight already exists)
# Skipping PRVBX (insight already exists)
# Skipping TAIBX (insight already exists)
# Skipping PRPZX (insight already exists)
# Skipping PFSZX (insight already exists)
# Skipping PGJZX (insight already exists)
# Skipping PHSZX (insight already exists)
# Skipping PJIZX (insight already exists)
# Skipping PUDZX (insight already exists)
# Skipping SREZX (insight already exists)
# Skipping PJEZX (insight already exists)
# Skipping PCIPX (insight already exists)
# Skipping PCDPX (insight already exists)
# Skipping PUCPX (insight already exists)
# Skipping PELPX (insight already exists)
# Skipping PEMPX (insight already exists)
# Skipping PEDPX (insight already exists)
# Skipping PGSAX (insight already exists)
# Skipping PGAPX (insight already exists)
# Skipping PYMPX (insight already exists)
# Skipping PLRPX (insight already exists)
# Skipping PLCPX (insight already exists)
# Skipping PMOPX (insight already exists)
# Skipping PMZPX (insight already exists)
# Skipping PNYPX (insight already exists)
# Skipping PFPNX (insight already exists)
# Skipping PEFPX (insight already exists)
# Skipping PIXPX (insight already exists)
# Skipping PTIPX (insight already exists)
# Skipping PCCPX (insight already exists)
# Skipping PSDPX (insight already exists)
# Skipping PPLPX (insight already exists)
# Skipping PCKPX (insight already exists)
# Skipping PVFYX (insight already exists)
# Skipping FUNYX (insight already exists)
# Skipping TYHYX (insight already exists)
# Skipping INVYX (insight already exists)
# Skipping PMFYX (insight already exists)
# Skipping PBCKX (insight already exists)
# Skipping PNIIX (insight already exists)
# Skipping PCMFX (insight already exists)
# Skipping PMRIX (insight already exists)
# Skipping PIDIX (insight already exists)
# Skipping PIREX (insight already exists)
# Skipping PCCIX (insight already exists)
# Skipping PSWIX (insight already exists)
# Skipping PGRTX (insight already exists)
# Skipping PCIYX (insight already exists)
# Skipping PAGYX (insight already exists)
# Skipping PGILX (insight already exists)
# Skipping PIVYX (insight already exists)
# Skipping PMNYX (insight already exists)
# Skipping POTYX (insight already exists)
# Skipping PURYX (insight already exists)
# Skipping RNSIX (insight already exists)
# Skipping RDVIX (insight already exists)
# Skipping RYOTX (insight already exists)
# Skipping RVVHX (insight already exists)
# Skipping RYPNX (insight already exists)
# Skipping RYTRX (insight already exists)
# Skipping RVPHX (insight already exists)
# Skipping REMSX (insight already exists)
# Skipping RGISX (insight already exists)
# Skipping RRESX (insight already exists)
# Skipping RELSX (insight already exists)
# Skipping RTNSX (insight already exists)
# Skipping RTSSX (insight already exists)
# Skipping RLESX (insight already exists)
# Skipping RSESX (insight already exists)
# Skipping RCMFX (insight already exists)
# Skipping NEXIX (insight already exists)
# Skipping SGISX (insight already exists)
# Skipping TRAOX (insight already exists)
# Skipping PRDMX (insight already exists)
# Skipping PREIX (insight already exists)
# Skipping PRESX (insight already exists)
# Skipping PRIDX (insight already exists)
# Skipping PRJPX (insight already exists)
# Skipping PRLAX (insight already exists)
# Skipping PRMDX (insight already exists)
# Skipping RPMGX (insight already exists)
# Skipping PRASX (insight already exists)
# Skipping PRNYX (insight already exists)
# Skipping PRFHX (insight already exists)
# Skipping PRFSX (insight already exists)
# Skipping POMIX (insight already exists)
# Skipping TEFEX (insight already exists)
# Skipping TDADX (insight already exists)
# Skipping TGSAX (insight already exists)
# Skipping TFSCX (insight already exists)
# Skipping REIFX (insight already exists)
# Skipping TAREX (insight already exists)
# Skipping TASCX (insight already exists)
# Skipping TAVFX (insight already exists)
# Skipping THPMX (insight already exists)
# Skipping THDIX (insight already exists)
# Skipping TEGYX (insight already exists)
# Skipping TSEMX (insight already exists)
# Skipping TAGIX (insight already exists)
# Skipping TABGX (insight already exists)
# Skipping TFLIX (insight already exists)
# Skipping THYIX (insight already exists)
# Skipping TSWIX (insight already exists)
# Skipping TBLIX (insight already exists)
# Skipping BPGLX (insight already exists)
# Skipping BNUEX (insight already exists)
# Skipping PWTYX (insight already exists)
# Skipping EMRYX (insight already exists)
# Skipping GHAYX (insight already exists)
# Skipping NEJYX (insight already exists)
# Skipping UIAGX (insight already exists)
# Skipping USBSX (insight already exists)
# Skipping USCRX (insight already exists)
# Skipping UCMCX (insight already exists)
# Skipping VDSYX (insight already exists)
# Skipping RSNYX (insight already exists)
# Skipping UIGIX (insight already exists)
# Skipping RSYYX (insight already exists)
# Skipping MMEYX (insight already exists)
# Skipping UIIFX (insight already exists)
# Skipping MGOYX (insight already exists)
# Skipping UIPMX (insight already exists)
# Skipping RIFYX (insight already exists)
# Skipping RSSYX (insight already exists)
# Skipping RSVYX (insight already exists)
# Skipping VBFIX (insight already exists)
# Skipping UIWGX (insight already exists)
# Skipping CUHIX (insight already exists)
# Skipping SCETX (insight already exists)
# Skipping VGISX (insight already exists)
# Skipping PHRIX (insight already exists)
# Skipping ALOIX (insight already exists)
# Skipping VIISX (insight already exists)
# Skipping PICMX (insight already exists)
# Skipping PKSFX (insight already exists)
# Skipping PXSGX (insight already exists)
# Skipping HIEMX (insight already exists)
# Skipping DRMCX (insight already exists)
# Skipping AZBIX (insight already exists)
# Skipping IEDIX (insight already exists)
# Skipping IEMGX (insight already exists)
# Skipping NAPIX (insight already exists)
# Skipping IISIX (insight already exists)
# Skipping WCMIX (insight already exists)
# Skipping SGSYX (insight already exists)
# Skipping SBSYX (insight already exists)
# Skipping WAARX (insight already exists)
# Skipping WHGMX (insight already exists)
# Skipping KIFYX (insight already exists)
# Skipping SMLPX (insight already exists)
# Skipping BESIX (insight already exists)
# Skipping APGRX (insight already exists)
# Skipping SPY (insight already exists)
# Skipping AGG (insight already exists)
# Skipping MDIV (insight already exists)
# Skipping ROMO (insight already exists)
# Skipping RISN (insight already exists)
# Skipping MAPP (insight already exists)
# Skipping GAL (insight already exists)
# Skipping AOA (insight already exists)
# Skipping NTSI (insight already exists)
# Skipping PPI (insight already exists)
# Skipping PCEF (insight already exists)
# Skipping GAA (insight already exists)
# Skipping DSCF (insight already exists)
# Skipping HNDL (insight already exists)
# Skipping RPAR (insight already exists)
# Skipping TWIO (insight already exists)
# Skipping CWB (insight already exists)
# Skipping CVRT (insight already exists)
# Skipping FCVT (insight already exists)
# Skipping QCON (insight already exists)
# Skipping DRAI (insight already exists)
# Skipping RLY (insight already exists)
# Skipping TBFC (insight already exists)
# Skipping TBFG (insight already exists)
# Skipping GMMA (insight already exists)
# Skipping MOOD (insight already exists)
# Skipping TDSC (insight already exists)
# Skipping CEFS (insight already exists)
# Skipping PWS (insight already exists)
# Skipping BSR (insight already exists)
# Skipping TDSB (insight already exists)
# Skipping TACK (insight already exists)
# Skipping DALI (insight already exists)
# Skipping NTSE (insight already exists)
# Skipping ASET (insight already exists)
# Skipping CCEF (insight already exists)
# Skipping NDAA (insight already exists)
# Skipping NDOW (insight already exists)
# Skipping RSSB (insight already exists)
# Skipping FCEF (insight already exists)
# Skipping GYLD (insight already exists)
# Skipping MVFD (insight already exists)
# Skipping MFUL (insight already exists)
# Skipping GDMA (insight already exists)
# Skipping OCIO (insight already exists)
# Skipping BAMA (insight already exists)
# Skipping QVOY (insight already exists)
# Skipping CLSM (insight already exists)
# Skipping MKAM (insight already exists)
# Skipping RULE (insight already exists)
# Skipping TUG (insight already exists)
# Skipping TUGN (insight already exists)
# Skipping MPAY (insight already exists)
# Skipping AVMA (insight already exists)
# Skipping UPAR (insight already exists)
# Skipping FIG (insight already exists)
# Skipping FDAT (insight already exists)
# Skipping INKM (insight already exists)
# Skipping RAAX (insight already exists)
# Skipping LCR (insight already exists)
# Skipping YYY (insight already exists)
# Skipping DWAT (insight already exists)
# Skipping XRLX (insight already exists)
# Skipping HEGD (insight already exists)
# Skipping MRSK (insight already exists)
# Skipping IQRA (insight already exists)
# Skipping IVRA (insight already exists)
# Skipping DFNV (insight already exists)
# Skipping BDGS (insight already exists)
# Skipping WLTG (insight already exists)
# Skipping BTR (insight already exists)
# Skipping FTIF (insight already exists)
# Skipping QPX (insight already exists)
# Skipping XCOR (insight already exists)
# Skipping XNAV (insight already exists)
# Skipping DFRA (insight already exists)
# Skipping VRAI (insight already exists)
# Skipping JOJO (insight already exists)
# Skipping GOLY (insight already exists)
# Skipping BFIX (insight already exists)
# Skipping ALTY (insight already exists)
# Skipping LALT (insight already exists)
# Skipping IYLD (insight already exists)
# Skipping SPYI (insight already exists)
# Skipping QQQI (insight already exists)
# Skipping ASMF (insight already exists)
# Skipping MFUT (insight already exists)
# Skipping AHLT (insight already exists)
# Skipping WTMF (insight already exists)
# Skipping DBMF (insight already exists)
# Skipping KMLM (insight already exists)
# Skipping HARD (insight already exists)
# Skipping BWET (insight already exists)
# Skipping USE (insight already exists)
# Skipping PBP (insight already exists)
# Skipping BALI (insight already exists)
# Skipping IVVW (insight already exists)
# Skipping RSEE (insight already exists)
# Skipping HTUS (insight already exists)
# Skipping PHDG (insight already exists)
# Skipping CBLS (insight already exists)
# Skipping HIDE (insight already exists)
# Skipping BDRY (insight already exists)
# Skipping FPXE (insight already exists)
# Skipping SPC (insight already exists)
# Skipping SPCZ (insight already exists)
# Skipping HYKE (insight already exists)
# Skipping RYSE (insight already exists)
# Skipping ARP (insight already exists)
# Skipping TRTY (insight already exists)
# Skipping KOOL (insight already exists)
# Skipping RNRG (insight already exists)
# Skipping SPAQ (insight already exists)
# Skipping LSEQ (insight already exists)
# Skipping EHLS (insight already exists)
# Skipping DFND (insight already exists)
# Skipping CLIX (insight already exists)
# Skipping BTAL (insight already exists)
# Skipping ARB (insight already exists)
# Skipping MRGR (insight already exists)
# Skipping MNA (insight already exists)
# Skipping EVNT (insight already exists)
# Skipping MARB (insight already exists)
# Skipping CANQ (insight already exists)
# Skipping QAI (insight already exists)
# Skipping FLSP (insight already exists)
# Skipping HFND (insight already exists)
# Skipping HDG (insight already exists)
# Skipping MSTB (insight already exists)
# Skipping GTR (insight already exists)
# Skipping SPQ (insight already exists)
# Skipping PRMN (insight already exists)
# Skipping CSM (insight already exists)
# Skipping SAMT (insight already exists)
# Skipping TPMN (insight already exists)
# Skipping SVOL (insight already exists)
# Skipping PRAE (insight already exists)
# Skipping ABEQ (insight already exists)
# Skipping SHUS (insight already exists)
# Skipping FCUS (insight already exists)
# Skipping ZIG (insight already exists)
# Skipping IWMW (insight already exists)
# Skipping CEW (insight already exists)
# Skipping SSFI (insight already exists)
# Skipping UCON (insight already exists)
# Skipping USDX (insight already exists)
# Skipping NFLT (insight already exists)
# Skipping OGSP (insight already exists)
# Skipping OOSP (insight already exists)
# Skipping USCI (insight already exists)
# Skipping HCOM (insight already exists)
# Skipping ZSC (insight already exists)
# Skipping CMDT (insight already exists)
# Skipping PDBC (insight already exists)
# Skipping FTGC (insight already exists)
# Skipping DBC (insight already exists)
# Skipping COMT (insight already exists)
# Skipping GCC (insight already exists)
# Skipping GSG (insight already exists)
# Skipping COM (insight already exists)
# Skipping BCI (insight already exists)
# Skipping COMB (insight already exists)
# Skipping HGER (insight already exists)
# Skipping CCRV (insight already exists)
# ...
# Skipping PACYX (insight already exists)
# Skipping PEMYX (insight already exists)
# Skipping PFRYX (insight already exists)
# Skipping PEQYX (insight already exists)
# Skipping PHSYX (insight already exists)
# Skipping PGGYX (insight already exists)
# Skipping PGTYX (insight already exists)
# Skipping PHAYX (insight already exists)
# Skipping PNCYX (insight already exists)
# Skipping POVYX (insight already exists)
# Skipping PNGYX (insight already exists)
# Skipping PGOYX (insight already exists)
# Skipping PEIYX (insight already exists)
# Skipping PMAYX (insight already exists)
# Skipping PMOYX (insight already exists)
# Skipping PUSYX (insight already exists)
# Skipping PNJYX (insight already exists)
# Skipping PNYYX (insight already exists)
# Skipping PPTYX (insight already exists)
# Skipping PARYX (insight already exists)
# Skipping PSMYX (insight already exists)
# Skipping PSYGX (insight already exists)
# Skipping PYSVX (insight already exists)
# Skipping PAMYX (insight already exists)
# Skipping PMVYX (insight already exists)
# Skipping PNOYX (insight already exists)
# Skipping PTEYX (insight already exists)
# Skipping PTFYX (insight already exists)
# Skipping PSDYX (insight already exists)
# Skipping RLIIX (insight already exists)
# Skipping RIPNX (insight already exists)
# Skipping RYPRX (insight already exists)
# Skipping PENNX (insight already exists)
# Skipping RYSEX (insight already exists)
# Skipping RGESX (insight already exists)
# Skipping RGCSX (insight already exists)
# Skipping RINTX (insight already exists)
# Skipping RFATX (insight already exists)
# Skipping RBLSX (insight already exists)
# Skipping RCLSX (insight already exists)
# Skipping RALSX (insight already exists)
# Skipping RMLSX (insight already exists)
# Skipping RMHSX (insight already exists)
# Skipping RMGSX (insight already exists)
# Skipping RMYSX (insight already exists)
# Skipping RFBSX (insight already exists)
# Skipping RFCTX (insight already exists)
# Skipping REQTX (insight already exists)
# Skipping RLVSX (insight already exists)
# Skipping RTHSX (insight already exists)
# Skipping RTXSX (insight already exists)
# Skipping RETSX (insight already exists)
# Skipping RLISX (insight already exists)
# Skipping SISEX (insight already exists)
# Skipping BBISX (insight already exists)
# Skipping BEGIX (insight already exists)
# Skipping BBGVX (insight already exists)
# Skipping STRGX (insight already exists)
# Skipping OVEIX (insight already exists)
# Skipping BBNTX (insight already exists)
# Skipping STMDX (insight already exists)
# Skipping BSCIX (insight already exists)
# Skipping BBSGX (insight already exists)
# Skipping SPSCX (insight already exists)
# Skipping STSCX (insight already exists)
# Skipping BOPIX (insight already exists)
# Skipping BIBTX (insight already exists)
# Skipping BVATX (insight already exists)
# Skipping OWVAX (insight already exists)
# Skipping SJCIX (insight already exists)
# Skipping SJGIX (insight already exists)
# Skipping SJVIX (insight already exists)
# Skipping SEACX (insight already exists)
# Skipping SEECX (insight already exists)
# Skipping SCECX (insight already exists)
# Skipping SRGIX (insight already exists)
# Skipping TRAMX (insight already exists)
# Skipping PRWAX (insight already exists)
# Skipping RPBAX (insight already exists)
# Skipping TRBCX (insight already exists)
# Skipping PRXCX (insight already exists)
# Skipping PRCFX (insight already exists)
# Skipping PRWCX (insight already exists)
# Skipping PRMTX (insight already exists)
# Skipping PRPIX (insight already exists)
# Skipping PRCPX (insight already exists)
# Skipping PRDGX (insight already exists)
# Skipping RPIEX (insight already exists)
# Skipping PRELX (insight already exists)
# Skipping PREMX (insight already exists)
# Skipping TRECX (insight already exists)
# Skipping PRMSX (insight already exists)
# Skipping PRIJX (insight already exists)
# Skipping PRFDX (insight already exists)
# Skipping PEXMX (insight already exists)
# Skipping PRISX (insight already exists)
# Skipping PRFRX (insight already exists)
# Skipping GTFBX (insight already exists)
# Skipping RPGAX (insight already exists)
# Skipping PGLOX (insight already exists)
# Skipping RPGEX (insight already exists)
# Skipping RPIHX (insight already exists)
# Skipping RPGIX (insight already exists)
# Skipping PRSNX (insight already exists)
# Skipping TRGRX (insight already exists)
# Skipping PRGSX (insight already exists)
# Skipping PRGTX (insight already exists)
# Skipping TRGVX (insight already exists)
# Skipping PRGMX (insight already exists)
# Skipping PRGFX (insight already exists)
# Skipping PRHSX (insight already exists)
# Skipping PRHYX (insight already exists)
# Skipping PRIPX (insight already exists)
# Skipping TQGEX (insight already exists)
# Skipping PRDSX (insight already exists)
# Skipping TQSMX (insight already exists)
# Skipping TQMVX (insight already exists)
# Skipping PRIHX (insight already exists)
# Skipping TNIBX (insight already exists)
# Skipping RPIBX (insight already exists)
# Skipping PRCNX (insight already exists)
# Skipping PIEQX (insight already exists)
# Skipping PRITX (insight already exists)
# Skipping TRIGX (insight already exists)
# Skipping TRBFX (insight already exists)
# Skipping MDXBX (insight already exists)
# Skipping TRMCX (insight already exists)
# Skipping PRNEX (insight already exists)
# Skipping PRNHX (insight already exists)
# Skipping PRCIX (insight already exists)
# Skipping NJTFX (insight already exists)
# Skipping TROSX (insight already exists)
# Skipping PBDIX (insight already exists)
# Skipping PRAFX (insight already exists)
# Skipping TRREX (insight already exists)
# Skipping TRRIX (insight already exists)
# Skipping PRSCX (insight already exists)
# Skipping PRWBX (insight already exists)
# Skipping OTCFX (insight already exists)
# Skipping PRSVX (insight already exists)
# Skipping PRSIX (insight already exists)
# Skipping PRSGX (insight already exists)
# Skipping RPSIX (insight already exists)
# Skipping PSILX (insight already exists)
# Skipping TRPBX (insight already exists)
# Skipping TRSGX (insight already exists)
# Skipping PRINX (insight already exists)
# Skipping PRSMX (insight already exists)
# Skipping PREFX (insight already exists)
# Skipping PRTAX (insight already exists)
# Skipping PTTFX (insight already exists)
# Skipping PRCOX (insight already exists)
# Skipping PRTIX (insight already exists)
# Skipping TRBUX (insight already exists)
# Skipping TUHYX (insight already exists)
# Skipping TRULX (insight already exists)
# Skipping PRULX (insight already exists)
# Skipping TRVLX (insight already exists)
# Skipping PRVAX (insight already exists)
# Skipping TEAFX (insight already exists)
# Skipping TEMZX (insight already exists)
# Skipping TFFAX (insight already exists)
# Skipping TZINX (insight already exists)
# Skipping TGBAX (insight already exists)
# Skipping TTRZX (insight already exists)
# Skipping TGADX (insight already exists)
# Skipping TFEQX (insight already exists)
# Skipping FIBZX (insight already exists)
# Skipping FEMZX (insight already exists)
# Skipping TWDAX (insight already exists)
# Skipping THOPX (insight already exists)
# Skipping THPGX (insight already exists)
# Skipping TBWIX (insight already exists)
# Skipping LTCIX (insight already exists)
# Skipping THOIX (insight already exists)
# Skipping THMIX (insight already exists)
# Skipping TGVIX (insight already exists)
# Skipping TINGX (insight already exists)
# Skipping TIBIX (insight already exists)
# Skipping THIIX (insight already exists)
# Skipping LTMIX (insight already exists)
# Skipping LTUIX (insight already exists)
# Skipping THNIX (insight already exists)
# Skipping TNYIX (insight already exists)
# Skipping TLMIX (insight already exists)
# Skipping TVIFX (insight already exists)
# Skipping THIGX (insight already exists)
# Skipping TSIIX (insight already exists)
# Skipping TSSIX (insight already exists)
# Skipping TSUMX (insight already exists)
# Skipping TLDIX (insight already exists)
# Skipping INFIX (insight already exists)
# Skipping TORIX (insight already exists)
# Skipping TOBYX (insight already exists)
# Skipping TMAYX (insight already exists)
# Skipping SIBLX (insight already exists)
# Skipping TOHYX (insight already exists)
# Skipping TQCYX (insight already exists)
# Skipping MXIIX (insight already exists)
# Skipping TFFYX (insight already exists)
# Skipping TGVYX (insight already exists)
# Skipping THYYX (insight already exists)
# Skipping TCPYX (insight already exists)
# Skipping SIIEX (insight already exists)
# Skipping SICWX (insight already exists)
# Skipping TLGYX (insight already exists)
# Skipping TMCPX (insight already exists)
# Skipping TCVYX (insight already exists)
# Skipping TIQIX (insight already exists)
# Skipping TPYYX (insight already exists)
# Skipping TSFYX (insight already exists)
# Skipping TVOYX (insight already exists)
# Skipping SIGWX (insight already exists)
# Skipping TSYYX (insight already exists)
# Skipping TVLYX (insight already exists)
# Skipping TACIX (insight already exists)
# Skipping TMGIX (insight already exists)
# Skipping TMMIX (insight already exists)
# Skipping TFXIX (insight already exists)
# Skipping TFOIX (insight already exists)
# Skipping EMTIX (insight already exists)
# Skipping TDHIX (insight already exists)
# Skipping ITIOX (insight already exists)
# Skipping TIMUX (insight already exists)
# Skipping TISVX (insight already exists)
# Skipping TIHBX (insight already exists)
# Skipping TWQIX (insight already exists)
# Skipping TLCJX (insight already exists)
# Skipping IMCGX (insight already exists)
# Skipping MVTIX (insight already exists)
# Skipping TSHIX (insight already exists)
# Skipping TSTIX (insight already exists)
# Skipping ISCGX (insight already exists)
# Skipping TSLIX (insight already exists)
# Skipping TSVIX (insight already exists)
# Skipping TDFIX (insight already exists)
# Skipping TUNIX (insight already exists)
# Skipping TDEIX (insight already exists)
# Skipping PORIX (insight already exists)
# Skipping UTBPX (insight already exists)
# Skipping BISCX (insight already exists)
# Skipping EMBYX (insight already exists)
# Skipping INIYX (insight already exists)
# Skipping VNVYX (insight already exists)
# Skipping VNSYX (insight already exists)
# Skipping UCBIX (insight already exists)
# Skipping UICGX (insight already exists)
# Skipping MUCYX (insight already exists)
# Skipping UIITX (insight already exists)
# Skipping UCAGX (insight already exists)
# Skipping USCCX (insight already exists)
# Skipping UCEQX (insight already exists)
# Skipping UIEMX (insight already exists)
# Skipping USMIX (insight already exists)
# Skipping VFFIX (insight already exists)
# Skipping UIGSX (insight already exists)
# Skipping UGTIX (insight already exists)
# Skipping UIGRX (insight already exists)
# Skipping UIHIX (insight already exists)
# Skipping RHMYX (insight already exists)
# Skipping UIINX (insight already exists)
# Skipping UIISX (insight already exists)
# Skipping MYIMX (insight already exists)
# Skipping VSVIX (insight already exists)
# Skipping MYISX (insight already exists)
# Skipping VICIX (insight already exists)
# Skipping RSDYX (insight already exists)
# Skipping MNNYX (insight already exists)
# Skipping UINQX (insight already exists)
# Skipping UNYIX (insight already exists)
# Skipping RGGYX (insight already exists)
# Skipping RGRYX (insight already exists)
# Skipping RSIGX (insight already exists)
# Skipping RSIYX (insight already exists)
# Skipping RCEYX (insight already exists)
# Skipping RMOYX (insight already exists)
# Skipping RSPYX (insight already exists)
# Skipping RSCYX (insight already exists)
# Skipping RSYEX (insight already exists)
# Skipping MUXYX (insight already exists)
# Skipping USSCX (insight already exists)
# Skipping UISBX (insight already exists)
# Skipping UISCX (insight already exists)
# Skipping RSENX (insight already exists)
# Skipping VEVIX (insight already exists)
# Skipping VSOIX (insight already exists)
# Skipping RSTYX (insight already exists)
# Skipping UITIX (insight already exists)
# Skipping ULTIX (insight already exists)
# Skipping USTIX (insight already exists)
# Skipping MICYX (insight already exists)
# Skipping MYSIX (insight already exists)
# Skipping UUSIX (insight already exists)
# Skipping UIVAX (insight already exists)
# Skipping UVAIX (insight already exists)
# Skipping STVTX (insight already exists)
# Skipping SMVTX (insight already exists)
# Skipping ANNPX (insight already exists)
# Skipping PGIUX (insight already exists)
# Skipping AWTIX (insight already exists)
# Skipping VADIX (insight already exists)
# Skipping PALLX (insight already exists)
# Skipping AZNIX (insight already exists)
# Skipping PLXGX (insight already exists)
# Skipping VIESX (insight already exists)
# Skipping PXIIX (insight already exists)
# Skipping PIPTX (insight already exists)
# Skipping DGSCX (insight already exists)
# Skipping HLHIX (insight already exists)
# Skipping VIMCX (insight already exists)
# Skipping PXQSX (insight already exists)
# Skipping VKSIX (insight already exists)
# Skipping SAVYX (insight already exists)
# Skipping HIBIX (insight already exists)
# Skipping VMFIX (insight already exists)
# Skipping PIMSX (insight already exists)
# Skipping PSFIX (insight already exists)
# Skipping ASHIX (insight already exists)
# Skipping NFJEX (insight already exists)
# Skipping ANVIX (insight already exists)
# Skipping PRNIX (insight already exists)
# Skipping STIGX (insight already exists)
# Skipping SAMBX (insight already exists)
# Skipping SCFTX (insight already exists)
# Skipping SAMHX (insight already exists)
# Skipping STTBX (insight already exists)
# Skipping HXBIX (insight already exists)
# Skipping SAMFX (insight already exists)
# Skipping SIGVX (insight already exists)
# Skipping STITX (insight already exists)
# Skipping STCAX (insight already exists)
# Skipping DRGTX (insight already exists)
# Skipping VYCCX (insight already exists)
# Skipping LEXCX (insight already exists)
# Skipping IFRIX (insight already exists)
# Skipping IGBIX (insight already exists)
# Skipping NAWIX (insight already exists)
# Skipping VYGLX (insight already exists)
# Skipping LEINX (insight already exists)
# Skipping IHYIX (insight already exists)
# Skipping IICIX (insight already exists)
# Skipping PLCIX (insight already exists)
# Skipping NMCIX (insight already exists)
# Skipping VYMSX (insight already exists)
# Skipping VCFIX (insight already exists)
# Skipping VVJCX (insight already exists)
# Skipping TCMSX (insight already exists)
# Skipping VYSAX (insight already exists)
# Skipping WMFFX (insight already exists)
# Skipping WCMEX (insight already exists)
# Skipping WCMSX (insight already exists)
# Skipping WBAIX (insight already exists)
# Skipping WCPBX (insight already exists)
# Skipping WVAIX (insight already exists)
# Skipping WPVIX (insight already exists)
# Skipping WNTFX (insight already exists)
# Skipping WEFIX (insight already exists)
# Skipping REIIX (insight already exists)
# Skipping LMCUX (insight already exists)
# Skipping WATFX (insight already exists)
# Skipping WACPX (insight already exists)
# Skipping SIGYX (insight already exists)
# Skipping WAHYX (insight already exists)
# Skipping SDSYX (insight already exists)
# Skipping WAIIX (insight already exists)
# Skipping WATIX (insight already exists)
# Skipping SICYX (insight already exists)
# Skipping SBTYX (insight already exists)
# Skipping SMMYX (insight already exists)
# Skipping LHMIX (insight already exists)
# Skipping LMHIX (insight already exists)
# Skipping LNJIX (insight already exists)
# Skipping SNPYX (insight already exists)
# Skipping LMOOX (insight already exists)
# Skipping LPPIX (insight already exists)
# Skipping SHIYX (insight already exists)
# Skipping SMDYX (insight already exists)
# Skipping SBAYX (insight already exists)
# Skipping WHGIX (insight already exists)
# Skipping WHGHX (insight already exists)
# Skipping WHGSX (insight already exists)
# Skipping WHGLX (insight already exists)
# Skipping WBEIX (insight already exists)
# Skipping WBELX (insight already exists)
# Skipping WGFIX (insight already exists)
# Skipping BGFIX (insight already exists)
# Skipping BIGIX (insight already exists)
# Skipping WILIX (insight already exists)
# Skipping WISIX (insight already exists)
# Skipping LCGFX (insight already exists)
# Skipping WBSIX (insight already exists)
# Skipping ICSCX (insight already exists)
# Skipping WSMDX (insight already exists)
# Skipping WPGTX (insight already exists)
# Skipping APIIX (insight already exists)
# Skipping APIBX (insight already exists)
# Skipping RSBT (insight already exists)
# Skipping RSST (insight already exists)
# Skipping RSBY (insight already exists)
# All tickers have been processed.

# %%
# This script is a test for Return Drivers a category in fund categorization to see if scoring will work

import pandas as pd
from sqlalchemy import create_engine

# Define the five fund categories
FUND_CATEGORIES = [
    "Index Based",
    "Factor/Smart Beta",
    "Active Discretionary",
    "Quant/Systematic",
    "Multi-Strategy"
]

# Database connection string
connection_string = (
    "mssql+pyodbc://JULIANS_LAPTOP\\SQLEXPRESS/"
    "CWA_Fund_Database?driver=ODBC+Driver+18+for+SQL+Server"
    "&trusted_connection=yes&TrustServerCertificate=yes"
)

# Create SQLAlchemy engine
engine = create_engine(connection_string)

# SQL query with additional columns
query = """
SELECT 
    fs.SymbolCUSIP,
    fs.ProductName,
    fs.fund_family,
    fs.investment_strategy,
    fs.index_fund,
    fs.inverse_fund,
    fs.leveraged_fund,
    fs.socially_responsible_fund,
    fs.synthetic_replication_fund,
    fs.fund_of_funds,
    fs.ycharts_url,
    yc_ba.Broad_Asset_Class_Name,
    yc_bc.Broad_Category_Name,
    yc_gc.Global_Category_Name,
    yc_c.Category_Name,
    cwa_bc.CWA_Broad_Category_Name,
    ff.Shop_Style,
    ff.Likely_Fund_Type
FROM 
    Funds_to_Screen fs
LEFT JOIN 
    FundFamily_Data ff ON fs.fund_family = ff.Fund_Family
LEFT JOIN 
    YC_Broad_Asset_Class_List yc_ba ON fs.YC_Broad_Asset_Class_ID = yc_ba.ID
LEFT JOIN 
    YC_Broad_Category_List yc_bc ON fs.YC_Broad_Category_ID = yc_bc.ID
LEFT JOIN 
    YC_Global_Category_List yc_gc ON fs.YC_Global_Category_ID = yc_gc.ID
LEFT JOIN 
    YC_Category_List yc_c ON fs.YC_Category_ID = yc_c.ID
LEFT JOIN 
    CWA_Broad_Category_List cwa_bc ON fs.CWA_Broad_Category_ID = cwa_bc.ID
"""

# Load data into a DataFrame
df = pd.read_sql(query, engine)

# Function to score based on keywords in investment_strategy
def keyword_score(description, category):
    if pd.isna(description):
        return 0
    description = description.lower()
    keywords = {
        "Index Based": ["index", "passive", "tracks", "replicates"],
        "Factor/Smart Beta": ["factor", "smart beta", "tilt", "weighted"],
        "Active Discretionary": ["active", "discretionary", "manager", "selection"],
        "Quant/Systematic": ["quantitative", "systematic", "model", "algorithm"],
        "Multi-Strategy": ["multi-strategy", "diversified", "blend", "multiple"]
    }
    category_keywords = keywords.get(category, [])
    return sum(keyword in description for keyword in category_keywords)

# Function to adjust score based on boolean flags
def boolean_adjustment(row, category):
    score = 0
    if category in ["Index Based", "Factor/Smart Beta"] and row['index_fund'] == 'True':
        score += 2
    if category in ["Quant/Systematic", "Multi-Strategy"] and (
        row['leveraged_fund'] == 'True' or row['inverse_fund'] == 'True' or 
        row['synthetic_replication_fund'] == 'True'
    ):
        score += 1
    if category == "Multi-Strategy" and row['fund_of_funds'] == 'True':
        score += 1
    return score

# Function to map category names to the five categories
def category_mapping(row):
    category_cols = [
        'Broad_Asset_Class_Name', 'Broad_Category_Name', 'Global_Category_Name',
        'Category_Name', 'CWA_Broad_Category_Name'
    ]
    for col in category_cols:
        if pd.notna(row[col]):
            value = row[col].lower()
            if "passive" in value or "index" in value:
                return "Index Based"
            elif "smart beta" in value or "factor" in value:
                return "Factor/Smart Beta"
            elif "active" in value:
                return "Active Discretionary"
            elif "quantitative" in value or "systematic" in value:
                return "Quant/Systematic"
            elif "multi" in value or "blend" in value:
                return "Multi-Strategy"
    return None

# Main classification function returning classification and scores
def classify_fund(row):
    scores = {category: 0 for category in FUND_CATEGORIES}
    
    # Score from investment_strategy keywords
    for category in scores:
        scores[category] += keyword_score(row['investment_strategy'], category)
    
    # Adjust scores based on boolean flags
    for category in scores:
        scores[category] += boolean_adjustment(row, category)
    
    # Add weight from category mapping
    mapped_category = category_mapping(row)
    if mapped_category:
        scores[mapped_category] += 3
    
    # Incorporate Likely_Fund_Type from FundFamily_Data
    if pd.notna(row['Likely_Fund_Type']) and row['Likely_Fund_Type'] in FUND_CATEGORIES:
        scores[row['Likely_Fund_Type']] += 2
    
    # Determine classification
    classification = max(scores, key=scores.get)
    
    # Return classification and scores
    return pd.Series({
        'Classification': classification,
        'Index Based Score': scores['Index Based'],
        'Factor/Smart Beta Score': scores['Factor/Smart Beta'],
        'Active Discretionary Score': scores['Active Discretionary'],
        'Quant/Systematic Score': scores['Quant/Systematic'],
        'Multi-Strategy Score': scores['Multi-Strategy']
    })

# Apply classification and add new columns
classification_results = df.apply(classify_fund, axis=1)
df = pd.concat([df, classification_results], axis=1)

# Select columns for the Excel file
columns_to_save = [
    'SymbolCUSIP', 'ProductName', 'fund_family', 'Classification', 'investment_strategy',
    'index_fund', 'inverse_fund', 'leveraged_fund', 'socially_responsible_fund',
    'synthetic_replication_fund', 'fund_of_funds', 'Broad_Asset_Class_Name',
    'Broad_Category_Name', 'Global_Category_Name', 'Category_Name', 'CWA_Broad_Category_Name',
    'Shop_Style', 'Likely_Fund_Type', 'ycharts_url', 'Index Based Score',
    'Factor/Smart Beta Score', 'Active Discretionary Score', 'Quant/Systematic Score',
    'Multi-Strategy Score'
]

# Save to Excel
df[columns_to_save].to_excel('classified_funds.xlsx', index=False)
print("Results saved to 'classified_funds.xlsx'")
# Out:
# Results saved to 'classified_funds.xlsx'

# %%
# updated script to incorporate risk overlays test and the return drivers
# This update also includes the larger keyword list that grok missed in the last test.
# This update also includes logic for big firms that are listed as "both" in the FundFamily_Data style
# Update also scan's fund name for keywords in risk and return drivers

import pandas as pd
from sqlalchemy import create_engine

# Define categories
RETURN_CATEGORIES = ["Index Based", "Factor/Smart Beta", "Active Discretionary", "Quant/Systematic", "Multi-Strategy"]
RISK_CATEGORIES = ["None", "Moderate", "Heavy / Persistent", "Offensive / Levered"]

# Updated keyword lists for return drivers
keywords = {
    "Index Based": [
        "tracks", "replicates", "mirrors", "follows", "indexes", "passive", "benchmark",
        "market-cap weighted", "equal-weighted index", "low tracking error", "high correlation",
        "beta", "etf", "index fund", "closely matches", "minimal deviation", "broad market exposure",
        "cost-efficient", "low-cost", "transparent", "rules-based replication", "market index",
        "sector index", "fixed income index", "commodity index", "currency index", "rules-based", "index",
        "bond index", "aggregate bond", "treasury index", "corporate bond index", "correspond", "underlying index"
    ],
    "Factor/Smart Beta": [
        "factor", "smart beta", "value", "growth", "momentum", "quality", "low volatility",
        "dividend", "fundamental weighting", "equal weighting", "rules-based", "enhanced returns",
        "risk-adjusted", "academic strategies", "tactical", "alternative weighting", "optimized",
        "factor tilt", "multi-factor", "single-factor", "thematic", "sector rotation", "style-based",
        "esg factors", "minimum variance", "quantitative screens", "proprietary index",
        "custom index", "enhanced index", "revenue weighted", "dividend weighted", "yield weighted",
        "dividend yield weighted", "factor weighted", "alternative beta", "tilt"
    ],
    "Active Discretionary": [
        "active", "discretionary", "fundamental", "research-driven", "stock picking",
        "portfolio manager", "judgment", "analysis", "insight", "conviction", "opportunistic",
        "tactical allocation", "high conviction", "concentrated portfolio", "bottom-up", "top-down",
        "macro-driven", "event-driven", "catalyst-driven", "long-term horizon", "short-term trading",
        "active share", "alpha generation", "outperform", "undervalued", "overvalued", "market timing",
        "sector selection", "security selection", "active risk", "active bets", "manager expertise",
        "proprietary research", "in-depth analysis", "qualitative assessment", "quantitative assessment",
        "active bond management", "credit analysis", "duration management", "yield curve positioning",
        "bond selection", "policy", "capital growth", "current income", "manager", "believes", "research",
        "selection", "actively managed", "capital appreciation", "capital preservation", "benchmark", "deemed",
        "select", "manager", "strategically"
    ],
    "Quant/Systematic": [
        "quantitative", "systematic", "algorithm", "model-based", "data-driven", "statistical",
        "machine learning", "ai", "rules-driven", "backtested", "factor models", "risk parity",
        "momentum strategies", "mean-variance optimization", "arbitrage", "high-frequency",
        "low-frequency", "trend-following", "mean-reversion", "quantitative screens",
        "proprietary models", "signal-based", "factor timing", "dynamic factor weighting",
        "quantitative overlay", "automated trading", "algorithmic trading", "robo-advisor",
        "systematic risk management", "quantitative risk models", "factor decomposition",
        "style analysis", "attribution analysis", "monte carlo simulation", "optimization algorithms",
        "long/short", "sell puts", "sell calls", "straddle", "options strategy", "derivatives-based",
        "quantitative fixed income", "bond factor models", "systematic trading", "algorithmic options"
    ],
    "Multi-Strategy": [
        "multi-strategy", "blended", "diverse", "combination", "hybrid", "integrated", "multi-manager",
        "multi-asset", "allocation across strategies", "dynamic allocation", "tactical overlay",
        "risk-managed", "diversified", "cross-asset", "cross-strategy", "strategy rotation", "adaptive",
        "flexible", "multi-style", "balanced", "mixed approach", "overlay strategy", "core-satellite",
        "barbell strategy", "hedged", "long-short", "market-neutral", "absolute return", "relative value",
        "global macro", "managed futures", "alternative beta", "risk premia", "portable alpha",
        "long/short equity", "options overlay", "derivatives hedging", "multi-asset class",
        "cross-strategy allocation", "alternative strategies"
    ]
}

# Shop lookup for "both" styles
SHOP_BOTH_LOOKUP = {
    "T. Rowe Price": {"Active Discretionary": 3, "Index Based": 1, "Quant/Systematic": 1},
    "Fidelity Investments": {"Active Discretionary": 2, "Index Based": 2, "Quant/Systematic": 1},
    "BlackRock": {"Index Based": 2, "Factor/Smart Beta": 2, "Active Discretionary": 1, "Quant/Systematic": 1},
    "Invesco": {"Active Discretionary": 2, "Index Based": 1, "Factor/Smart Beta": 1, "Quant/Systematic": 1},
    "WisdomTree": {"Factor/Smart Beta": 3, "Index Based": 1},
    "First Trust": {"Active Discretionary": 2, "Index Based": 1, "Factor/Smart Beta": 2, "Quant/Systematic": 1, "Multi-Strategy": 1},
    "AllianceBernstein": {"Active Discretionary": 3, "Factor/Smart Beta": 1, "Quant/Systematic": 1, "Multi-Strategy": 1},
    "JPMorgan": {"Active Discretionary": 3, "Index Based": 1, "Factor/Smart Beta": 2, "Quant/Systematic": 1, "Multi-Strategy": 1},
    "John Hancock": {"Active Discretionary": 2, "Index Based": 1, "Factor/Smart Beta": 2, "Quant/Systematic": 1, "Multi-Strategy": 1},
    "Victory Capital": {"Active Discretionary": 2, "Index Based": 1, "Factor/Smart Beta": 2, "Quant/Systematic": 1, "Multi-Strategy": 1},
    "Columbia Threadneedle": {"Active Discretionary": 3, "Index Based": 1, "Factor/Smart Beta": 1, "Quant/Systematic": 1, "Multi-Strategy": 1},
    "Federated": {"Active Discretionary": 2, "Factor/Smart Beta": 1, "Quant/Systematic": 1},
    "Hartford Mutual Funds": {"Active Discretionary": 2, "Index Based": 1, "Factor/Smart Beta": 2, "Quant/Systematic": 1, "Multi-Strategy": 1},
    "Allspring Global Investments": {"Active Discretionary": 3, "Index Based": 1, "Factor/Smart Beta": 1, "Quant/Systematic": 1, "Multi-Strategy": 1}
}

# Database connection
connection_string = (
    "mssql+pyodbc://JULIANS_LAPTOP\\SQLEXPRESS/"
    "CWA_Fund_Database?driver=ODBC+Driver+18+for+SQL+Server"
    "&trusted_connection=yes&TrustServerCertificate=yes"
)
engine = create_engine(connection_string)

# SQL query
query = """
SELECT 
    fs.SymbolCUSIP, fs.ProductName, fs.fund_family, fs.investment_strategy,
    fs.index_fund, fs.inverse_fund, fs.leveraged_fund, fs.socially_responsible_fund,
    fs.synthetic_replication_fund, fs.fund_of_funds, fs.ycharts_url,
    yc_ba.Broad_Asset_Class_Name, yc_bc.Broad_Category_Name, yc_gc.Global_Category_Name,
    yc_c.Category_Name, cwa_bc.CWA_Broad_Category_Name, ff.Shop_Style, ff.Likely_Fund_Type
FROM Funds_to_Screen fs
LEFT JOIN FundFamily_Data ff ON fs.fund_family = ff.Fund_Family
LEFT JOIN YC_Broad_Asset_Class_List yc_ba ON fs.YC_Broad_Asset_Class_ID = yc_ba.ID
LEFT JOIN YC_Broad_Category_List yc_bc ON fs.YC_Broad_Category_ID = yc_bc.ID
LEFT JOIN YC_Global_Category_List yc_gc ON fs.YC_Global_Category_ID = yc_gc.ID
LEFT JOIN YC_Category_List yc_c ON fs.YC_Category_ID = yc_c.ID
LEFT JOIN CWA_Broad_Category_List cwa_bc ON fs.CWA_Broad_Category_ID = cwa_bc.ID
"""
df = pd.read_sql(query, engine)

# --- Return Generation Classification ---

def keyword_score_return(row, category):
    product_name = row['ProductName'].lower() if pd.notna(row['ProductName']) else ""
    description = row['investment_strategy'].lower() if pd.notna(row['investment_strategy']) else ""
    text = product_name + " " + description
    return sum(keyword in text for keyword in keywords.get(category, []))

def boolean_adjustment_return(row, category):
    score = 0
    if category in ["Index Based", "Factor/Smart Beta"] and row['index_fund'] == 'True':
        score += 2
    if category in ["Quant/Systematic", "Multi-Strategy"] and (
        row['leveraged_fund'] == 'True' or row['inverse_fund'] == 'True' or 
        row['synthetic_replication_fund'] == 'True'
    ):
        score += 1
    if category == "Multi-Strategy" and row['fund_of_funds'] == 'True':
        score += 1
    return score

def category_mapping_return(row):
    category_cols = ['Broad_Asset_Class_Name', 'Broad_Category_Name', 'Global_Category_Name', 'Category_Name', 'CWA_Broad_Category_Name']
    scores = {category: 0 for category in RETURN_CATEGORIES}
    for col in category_cols:
        if pd.notna(row[col]):
            value = row[col].lower()
            if "trading tool" in value or value in ["quantitative/tactical", "systematic trend", "tactical allocation", "trading tools", "options trading"]:
                scores["Quant/Systematic"] += 3
            elif value in ["municipal", "muni national", "muni single state"]:
                scores["Index Based"] += 2
                scores["Active Discretionary"] += 2
            elif value in ["nontraditional", "nontraditional bond"]:
                scores["Quant/Systematic"] += 2
                scores["Multi-Strategy"] += 2
                scores["Active Discretionary"] += 1
                scores["Factor/Smart Beta"] += 1
            elif value in ["sector/industry", "communications", "energy", "financials", "healthcare", "industrials", "technology", "utilities"]:
                scores["Index Based"] += 3
            elif value in ["single stock"]:
                scores["Index Based"] += 2
                scores["Quant/Systematic"] += 2
            elif value in ["target maturity", "muni target maturity"]:
                scores["Index Based"] += 3
            elif value in ["digital asset", "digital assets"]:
                scores["Index Based"] += 3
                scores["Factor/Smart Beta"] += 1
                scores["Multi-Strategy"] += 1
            elif value in ["commodity", "commodities broad basket", "commodities specified"]:
                if row['CWA_Broad_Category_Name'] == "Commodity":
                    scores["Index Based"] += 3
                elif "active" in row.get('investment_strategy', '').lower():
                    scores["Active Discretionary"] += 3
                elif "quantitative" in row.get('investment_strategy', '').lower():
                    scores["Quant/Systematic"] += 3
            elif value in ["alternative", "defined outcome", "multialternative", "multistrategy"]:
                scores["Multi-Strategy"] += 3
            elif value in ["currency", "single currency"]:
                scores["Quant/Systematic"] += 3
            elif value in ["strategic", "bond strategy"]:
                scores["Active Discretionary"] += 3
    max_score = max(scores.values())
    if max_score > 0:
        return max(scores, key=scores.get)
    return None

def classify_return(row):
    scores = {category: 0 for category in RETURN_CATEGORIES}
    for category in scores:
        scores[category] += keyword_score_return(row, category)
        scores[category] += boolean_adjustment_return(row, category)
    mapped_category = category_mapping_return(row)
    if mapped_category:
        scores[mapped_category] += 2
    if pd.notna(row['Shop_Style']) and row['Shop_Style'].lower() == "both":
        shop_weights = SHOP_BOTH_LOOKUP.get(row['fund_family'], {})
        for category, weight in shop_weights.items():
            if category in RETURN_CATEGORIES:
                scores[category] += weight
    else:
        if pd.notna(row['Likely_Fund_Type']) and row['Likely_Fund_Type'] in RETURN_CATEGORIES:
            scores[row['Likely_Fund_Type']] += 2
    return pd.Series({
        'Return_Category': max(scores, key=scores.get),
        'Index Based Score': scores['Index Based'],
        'Factor/Smart Beta Score': scores['Factor/Smart Beta'],
        'Active Discretionary Score': scores['Active Discretionary'],
        'Quant/Systematic Score': scores['Quant/Systematic'],
        'Multi-Strategy Score': scores['Multi-Strategy']
    })

# --- Risk Management Overlay Classification ---

def keyword_score_risk(row, category):
    product_name = row['ProductName'].lower() if pd.notna(row['ProductName']) else ""
    description = row['investment_strategy'].lower() if pd.notna(row['investment_strategy']) else ""
    text = product_name + " " + description
    keywords = {
        "None": ["long-only", "no derivatives", "no short", "straight equity"],
        "Moderate": ["hedging", "derivatives", "borrowings", "contracts", "futures", "options", "partial hedge", "covered call", "duration management", "hedge"],
        "Heavy / Persistent": ["persistent hedges", "borrowings", "contracts", "futures", "tail-risk", "protective", "overlay", "derivatives", "systematic hedging", "hedge"],
        "Offensive / Levered": ["leverage", "amplified", "geared", "borrowings", "contracts", "futures", "derivatives", "2x", "3x", "hedge"]
    }
    return sum(keyword in text for keyword in keywords.get(category, []))

def boolean_adjustment_risk(row, category):
    score = 0
    if category == "Offensive / Levered" and row['leveraged_fund'] == 'True':
        score += 3
    if category in ["Heavy / Persistent", "Offensive / Levered"] and row['inverse_fund'] == 'True':
        score += 2
    if category in ["Moderate", "Heavy / Persistent"] and row['synthetic_replication_fund'] == 'True':
        score += 1
    if category == "None" and all(row[col] == 'False' for col in ['leveraged_fund', 'inverse_fund', 'synthetic_replication_fund']):
        score += 2
    return score

def category_mapping_risk(row):
    category_cols = ['Broad_Asset_Class_Name', 'Broad_Category_Name', 'Global_Category_Name', 'Category_Name', 'CWA_Broad_Category_Name']
    for col in category_cols:
        if pd.notna(row[col]):
            value = row[col].lower()
            if value in ["us equity", "municipal", "taxable fixed income", "target date"]:
                return "None"
            elif value in ["allocation", "bond strategy", "strategic", "target maturity", "convertibles"]:
                return "Moderate"
            elif value in ["alternative", "defined outcome", "nontraditional", "specialty", "derivative income"]:
                return "Heavy / Persistent"
            elif value in ["trading/tactical", "quantitative/tactical", "commodity", "currency", "digital asset", "trading--leveraged", "trading--inverse"]:
                return "Offensive / Levered"
    return None

def classify_risk(row):
    scores = {category: 0 for category in RISK_CATEGORIES}
    for category in scores:
        scores[category] += keyword_score_risk(row, category)
        scores[category] += boolean_adjustment_risk(row, category)
    mapped_category = category_mapping_risk(row)
    if mapped_category:
        scores[mapped_category] += 2
    if pd.notna(row['Shop_Style']):
        if row['Shop_Style'] == 'Quant' and row['Likely_Fund_Type'] in ['Quant/Systematic', 'Multi-Strategy']:
            scores['Heavy / Persistent'] += 1
            scores['Offensive / Levered'] += 1
        elif row['Shop_Style'] == 'Active':
            scores['None'] += 1
    return pd.Series({
        'Risk_Overlay': max(scores, key=scores.get),
        'None Score': scores['None'],
        'Moderate Score': scores['Moderate'],
        'Heavy / Persistent Score': scores['Heavy / Persistent'],
        'Offensive / Levered Score': scores['Offensive / Levered']
    })

# Apply classifications
return_results = df.apply(classify_return, axis=1)
df = pd.concat([df, return_results], axis=1)
risk_results = df.apply(classify_risk, axis=1)
df = pd.concat([df, risk_results], axis=1)

# Select columns for Excel output
columns_to_save = [
    'SymbolCUSIP', 'ProductName', 'fund_family', 'Return_Category', 'Risk_Overlay',
    'ycharts_url','investment_strategy', 'index_fund', 'inverse_fund', 'leveraged_fund',
    'socially_responsible_fund', 'synthetic_replication_fund', 'fund_of_funds',
    'Broad_Asset_Class_Name', 'Broad_Category_Name', 'Global_Category_Name',
    'Category_Name', 'CWA_Broad_Category_Name', 'Shop_Style', 'Likely_Fund_Type',
    'Index Based Score', 'Factor/Smart Beta Score', 'Active Discretionary Score',
    'Quant/Systematic Score', 'Multi-Strategy Score', 'None Score', 'Moderate Score',
    'Heavy / Persistent Score', 'Offensive / Levered Score'
]

# Save to Excel
df[columns_to_save].to_excel('classified_funds_v3.xlsx', index=False)
print("Results saved to 'classified_funds_v3.xlsx'")
# Out:
# Results saved to 'classified_funds_v3.xlsx'

# %%
# updated script to incorporate risk overlays test and the return drivers
# This update also includes the larger keyword list that grok missed in the last test.
# This update also includes logic for big firms that are listed as "both" in the FundFamily_Data style
# Update also scan's fund name for keywords in risk and return drivers
# This update added the ability to skew shop overlay likelihoods

import pandas as pd
from sqlalchemy import create_engine

# Define categories
RETURN_CATEGORIES = ["Index Based", "Factor/Smart Beta", "Active Discretionary", "Quant/Systematic", "Multi-Strategy"]
RISK_CATEGORIES = ["None", "Moderate", "Heavy / Persistent", "Offensive / Levered"]

# Updated keyword lists for return drivers
return_keywords = {
    "Index Based": [
        "tracks", "replicates", "mirrors", "follows", "indexes", "passive", "benchmark",
        "market-cap weighted", "equal-weighted index", "low tracking error", "high correlation",
        "beta", "etf", "index fund", "closely matches", "minimal deviation", "broad market exposure",
        "cost-efficient", "low-cost", "transparent", "rules-based replication", "market index",
        "sector index", "fixed income index", "commodity index", "currency index", "rules-based", "index",
        "bond index", "aggregate bond", "treasury index", "corporate bond index", "correspond", "underlying index"
    ],
    "Factor/Smart Beta": [
        "factor", "smart beta", "value", "growth", "momentum", "quality", "low volatility",
        "dividend", "fundamental weighting", "equal weighting", "rules-based", "enhanced returns",
        "risk-adjusted", "academic strategies", "tactical", "alternative weighting", "optimized",
        "factor tilt", "multi-factor", "single-factor", "thematic", "sector rotation", "style-based",
        "esg factors", "minimum variance", "quantitative screens", "proprietary index",
        "custom index", "enhanced index", "revenue weighted", "dividend weighted", "yield weighted",
        "dividend yield weighted", "factor weighted", "alternative beta", "tilt"
    ],
    "Active Discretionary": [
        "active", "discretionary", "fundamental", "research-driven", "stock picking",
        "portfolio manager", "judgment", "analysis", "insight", "conviction", "opportunistic",
        "tactical allocation", "high conviction", "concentrated portfolio", "bottom-up", "top-down",
        "macro-driven", "event-driven", "catalyst-driven", "long-term horizon", "short-term trading",
        "active share", "alpha generation", "outperform", "undervalued", "overvalued", "market timing",
        "sector selection", "security selection", "active risk", "active bets", "manager expertise",
        "proprietary research", "in-depth analysis", "qualitative assessment", "quantitative assessment",
        "active bond management", "credit analysis", "duration management", "yield curve positioning",
        "bond selection", "policy", "capital growth", "current income", "manager", "believes", "research",
        "selection", "strategically", "managed"
    ],
    "Quant/Systematic": [
        "quantitative", "systematic", "algorithm", "model-based", "data-driven", "statistical",
        "machine learning", "ai", "rules-driven", "backtested", "factor models", "risk parity",
        "momentum strategies", "mean-variance optimization", "arbitrage", "high-frequency",
        "low-frequency", "trend-following", "mean-reversion", "quantitative screens",
        "proprietary models", "signal-based", "factor timing", "dynamic factor weighting",
        "quantitative overlay", "automated trading", "algorithmic trading", "robo-advisor",
        "systematic risk management", "quantitative risk models", "factor decomposition",
        "style analysis", "attribution analysis", "monte carlo simulation", "optimization algorithms",
        "long/short", "sell puts", "sell calls", "straddle", "options strategy", "derivatives-based",
        "quantitative fixed income", "bond factor models", "systematic trading", "algorithmic options"
    ],
    "Multi-Strategy": [
        "multi-strategy", "blended", "diverse", "combination", "hybrid", "integrated", "multi-manager",
        "multi-asset", "allocation across strategies", "dynamic allocation", "tactical overlay",
        "risk-managed", "diversified", "cross-asset", "cross-strategy", "strategy rotation", "adaptive",
        "flexible", "multi-style", "balanced", "mixed approach", "overlay strategy", "core-satellite",
        "barbell strategy", "hedged", "long-short", "market-neutral", "absolute return", "relative value",
        "global macro", "managed futures", "alternative beta", "risk premia", "portable alpha",
        "long/short equity", "options overlay", "derivatives hedging", "multi-asset class",
        "cross-strategy allocation", "alternative strategies"
    ]
}

# Updated keyword lists for risk overlays
risk_keywords = {
    "None": ["long-only", "no derivatives", "no short", "straight equity"],
    "Moderate": ["hedging", "derivatives", "borrowings", "contracts", "futures", "options", "partial hedge", "covered call", "duration management", "hedge"],
    "Heavy / Persistent": ["persistent hedges", "borrowings", "contracts", "futures", "tail-risk", "protective", "overlay", "derivatives", "systematic hedging", "hedge"],
    "Offensive / Levered": ["leverage", "amplified", "geared", "borrowings", "contracts", "futures", "derivatives", "2x", "3x", "hedge"]
}

# Updated shop lookup for return drivers
SHOP_BOTH_LOOKUP = {
    "T. Rowe Price": {"Active Discretionary": 3, "Index Based": 1, "Quant/Systematic": 1},
    "Fidelity Investments": {"Active Discretionary": 2, "Index Based": 2, "Quant/Systematic": 1},
    "BlackRock": {"Index Based": 2, "Factor/Smart Beta": 2, "Active Discretionary": 1, "Quant/Systematic": 1},
    "Invesco": {"Active Discretionary": 2, "Index Based": 1, "Factor/Smart Beta": 1, "Quant/Systematic": 1},
    "WisdomTree": {"Factor/Smart Beta": 3, "Index Based": 1},
    "First Trust": {"Active Discretionary": 2, "Index Based": 1, "Factor/Smart Beta": 2, "Quant/Systematic": 1, "Multi-Strategy": 1},
    "AllianceBernstein": {"Active Discretionary": 3, "Factor/Smart Beta": 1, "Quant/Systematic": 1, "Multi-Strategy": 1},
    "JPMorgan": {"Active Discretionary": 3, "Index Based": 1, "Factor/Smart Beta": 2, "Quant/Systematic": 1, "Multi-Strategy": 1},
    "John Hancock": {"Active Discretionary": 2, "Index Based": 1, "Factor/Smart Beta": 2, "Quant/Systematic": 1, "Multi-Strategy": 1},
    "Victory Capital": {"Active Discretionary": 2, "Index Based": 1, "Factor/Smart Beta": 2, "Quant/Systematic": 1, "Multi-Strategy": 1},
    "Columbia Threadneedle": {"Active Discretionary": 3, "Index Based": 1, "Factor/Smart Beta": 1, "Quant/Systematic": 1, "Multi-Strategy": 1},
    "Federated": {"Active Discretionary": 2, "Factor/Smart Beta": 1, "Quant/Systematic": 1},
    "Hartford Mutual Funds": {"Active Discretionary": 2, "Index Based": 1, "Factor/Smart Beta": 2, "Quant/Systematic": 1, "Multi-Strategy": 1},
    "Allspring Global Investments": {"Active Discretionary": 3, "Index Based": 1, "Factor/Smart Beta": 1, "Quant/Systematic": 1, "Multi-Strategy": 1}
}

# New shop lookup for risk overlays (rough estimates, adjust as needed)
SHOP_RISK_LOOKUP = {
    "Simplify": {"None": 0, "Moderate": 2, "Heavy / Persistent": 1, "Offensive / Levered": 1},
    "Guggenheim Investments": {"None": 0, "Moderate": 1, "Heavy / Persistent": 1, "Offensive / Levered": 1},
    "ProShares": {"None": 0, "Moderate": 1, "Heavy / Persistent": 1, "Offensive / Levered": 1},
    "Direxion Funds": {"None": 1, "Moderate": 1, "Heavy / Persistent": 1, "Offensive / Levered": 0},
}

# Database connection
connection_string = (
    "mssql+pyodbc://JULIANS_LAPTOP\\SQLEXPRESS/"
    "CWA_Fund_Database?driver=ODBC+Driver+18+for+SQL+Server"
    "&trusted_connection=yes&TrustServerCertificate=yes"
)
engine = create_engine(connection_string)

# SQL query
query = """
SELECT 
    fs.SymbolCUSIP, fs.ProductName, fs.fund_family, fs.investment_strategy,
    fs.index_fund, fs.inverse_fund, fs.leveraged_fund, fs.socially_responsible_fund,
    fs.synthetic_replication_fund, fs.fund_of_funds, fs.ycharts_url,
    yc_ba.Broad_Asset_Class_Name, yc_bc.Broad_Category_Name, yc_gc.Global_Category_Name,
    yc_c.Category_Name, cwa_bc.CWA_Broad_Category_Name, ff.Shop_Style, ff.Likely_Fund_Type
FROM Funds_to_Screen fs
LEFT JOIN FundFamily_Data ff ON fs.fund_family = ff.Fund_Family
LEFT JOIN YC_Broad_Asset_Class_List yc_ba ON fs.YC_Broad_Asset_Class_ID = yc_ba.ID
LEFT JOIN YC_Broad_Category_List yc_bc ON fs.YC_Broad_Category_ID = yc_bc.ID
LEFT JOIN YC_Global_Category_List yc_gc ON fs.YC_Global_Category_ID = yc_gc.ID
LEFT JOIN YC_Category_List yc_c ON fs.YC_Category_ID = yc_c.ID
LEFT JOIN CWA_Broad_Category_List cwa_bc ON fs.CWA_Broad_Category_ID = cwa_bc.ID
"""
df = pd.read_sql(query, engine)

# --- Return Generation Classification ---

def keyword_score_return(row, category):
    product_name = row['ProductName'].lower() if pd.notna(row['ProductName']) else ""
    description = row['investment_strategy'].lower() if pd.notna(row['investment_strategy']) else ""
    text = product_name + " " + description
    return sum(keyword in text for keyword in return_keywords.get(category, []))

def boolean_adjustment_return(row, category):
    score = 0
    if category in ["Index Based", "Factor/Smart Beta"] and row['index_fund'] == 'True':
        score += 2
    if category in ["Quant/Systematic", "Multi-Strategy"] and (
        row['leveraged_fund'] == 'True' or row['inverse_fund'] == 'True' or 
        row['synthetic_replication_fund'] == 'True'
    ):
        score += 1
    if category == "Multi-Strategy" and row['fund_of_funds'] == 'True':
        score += 1
    return score

def category_mapping_return(row):
    category_cols = ['Broad_Asset_Class_Name', 'Broad_Category_Name', 'Global_Category_Name', 'Category_Name', 'CWA_Broad_Category_Name']
    scores = {category: 0 for category in RETURN_CATEGORIES}
    bond_related = ["municipal", "muni national", "muni single state", "global bond", "taxable fixed income", "fixed income"]
    
    for col in category_cols:
        if pd.notna(row[col]):
            value = row[col].lower()
            # Bond-related categories (except "bond strategy")
            if value in bond_related and value != "bond strategy":
                scores["Index Based"] += 1
                scores["Active Discretionary"] += 1
            # Specific actionable tags
            if "trading tool" in value or value in ["quantitative/tactical", "systematic trend", "tactical allocation", "trading tools", "options trading"]:
                scores["Quant/Systematic"] += 3
            elif value in ["municipal", "muni national", "muni single state"]:
                scores["Index Based"] += 1
                scores["Active Discretionary"] += 2
            elif value in ["nontraditional", "nontraditional bond"]:
                scores["Quant/Systematic"] += 2
                scores["Multi-Strategy"] += 2
                scores["Active Discretionary"] += 1
                scores["Factor/Smart Beta"] += 1
            elif value in ["sector/industry", "communications", "energy", "financials", "healthcare", "industrials", "technology", "utilities"]:
                scores["Index Based"] += 3
            elif value in ["single stock"]:
                scores["Index Based"] += 2
                scores["Quant/Systematic"] += 2
            elif value in ["target maturity", "muni target maturity"]:
                scores["Index Based"] += 3
            elif value in ["digital asset", "digital assets"]:
                scores["Index Based"] += 3
                scores["Factor/Smart Beta"] += 1
                scores["Multi-Strategy"] += 1
            elif value in ["commodity", "commodities broad basket", "commodities specified"]:
                if row['CWA_Broad_Category_Name'] == "Commodity":
                    scores["Index Based"] += 3
                elif "active" in row.get('investment_strategy', '').lower():
                    scores["Active Discretionary"] += 3
                elif "quantitative" in row.get('investment_strategy', '').lower():
                    scores["Quant/Systematic"] += 3
            elif value in ["alternative", "defined outcome", "multialternative", "multistrategy"]:
                scores["Multi-Strategy"] += 3
            elif value in ["currency", "single currency"]:
                scores["Quant/Systematic"] += 3
            elif value in ["strategic", "bond strategy"]:
                scores["Active Discretionary"] += 3
    
    max_score = max(scores.values())
    if max_score > 0:
        return max(scores, key=scores.get)
    return None

def classify_return(row):
    scores = {category: 0 for category in RETURN_CATEGORIES}
    for category in scores:
        scores[category] += keyword_score_return(row, category)
        scores[category] += boolean_adjustment_return(row, category)
    mapped_category = category_mapping_return(row)
    if mapped_category:
        scores[mapped_category] += 2
    if pd.notna(row['Shop_Style']) and row['Shop_Style'].lower() == "both":
        shop_weights = SHOP_BOTH_LOOKUP.get(row['fund_family'], {})
        for category, weight in shop_weights.items():
            if category in RETURN_CATEGORIES:
                scores[category] += weight
    else:
        if pd.notna(row['Likely_Fund_Type']) and row['Likely_Fund_Type'] in RETURN_CATEGORIES:
            scores[row['Likely_Fund_Type']] += 2
    return pd.Series({
        'Return_Category': max(scores, key=scores.get),
        'Index Based Score': scores['Index Based'],
        'Factor/Smart Beta Score': scores['Factor/Smart Beta'],
        'Active Discretionary Score': scores['Active Discretionary'],
        'Quant/Systematic Score': scores['Quant/Systematic'],
        'Multi-Strategy Score': scores['Multi-Strategy']
    })

# --- Risk Management Overlay Classification ---

def keyword_score_risk(row, category):
    product_name = row['ProductName'].lower() if pd.notna(row['ProductName']) else ""
    description = row['investment_strategy'].lower() if pd.notna(row['investment_strategy']) else ""
    text = product_name + " " + description
    return sum(keyword in text for keyword in risk_keywords.get(category, []))

def boolean_adjustment_risk(row, category):
    score = 0
    if category == "Offensive / Levered" and row['leveraged_fund'] == 'True':
        score += 3
    if category in ["Heavy / Persistent", "Offensive / Levered"] and row['inverse_fund'] == 'True':
        score += 2
    if category in ["Moderate", "Heavy / Persistent"] and row['synthetic_replication_fund'] == 'True':
        score += 1
    if category == "None" and all(row[col] == 'False' for col in ['leveraged_fund', 'inverse_fund', 'synthetic_replication_fund']):
        score += 2
    return score

def category_mapping_risk(row):
    category_cols = ['Broad_Asset_Class_Name', 'Broad_Category_Name', 'Global_Category_Name', 'Category_Name', 'CWA_Broad_Category_Name']
    for col in category_cols:
        if pd.notna(row[col]):
            value = row[col].lower()
            if value in ["us equity", "municipal", "taxable fixed income", "target date"]:
                return "None"
            elif value in ["allocation", "bond strategy", "strategic", "target maturity", "convertibles"]:
                return "Moderate"
            elif value in ["alternative", "defined outcome", "nontraditional", "specialty", "derivative income"]:
                return "Heavy / Persistent"
            elif value in ["trading/tactical", "quantitative/tactical", "commodity", "currency", "digital asset", "trading--leveraged", "trading--inverse"]:
                return "Offensive / Levered"
    return None

def classify_risk(row):
    scores = {category: 0 for category in RISK_CATEGORIES}
    for category in scores:
        scores[category] += keyword_score_risk(row, category)
        scores[category] += boolean_adjustment_risk(row, category)
    mapped_category = category_mapping_risk(row)
    if mapped_category:
        scores[mapped_category] += 2
    if pd.notna(row['Shop_Style']) and row['Shop_Style'].lower() == "both":
        shop_weights = SHOP_RISK_LOOKUP.get(row['fund_family'], {})
        for category, weight in shop_weights.items():
            if category in RISK_CATEGORIES:
                scores[category] += weight
    elif pd.notna(row['Shop_Style']):
        if row['Shop_Style'] == 'Quant' and row['Likely_Fund_Type'] in ['Quant/Systematic', 'Multi-Strategy']:
            scores['Heavy / Persistent'] += 1
            scores['Offensive / Levered'] += 1
        elif row['Shop_Style'] == 'Active':
            scores['None'] += 1
    return pd.Series({
        'Risk_Overlay': max(scores, key=scores.get),
        'None Score': scores['None'],
        'Moderate Score': scores['Moderate'],
        'Heavy / Persistent Score': scores['Heavy / Persistent'],
        'Offensive / Levered Score': scores['Offensive / Levered']
    })

# Apply classifications
return_results = df.apply(classify_return, axis=1)
df = pd.concat([df, return_results], axis=1)
risk_results = df.apply(classify_risk, axis=1)
df = pd.concat([df, risk_results], axis=1)

# Select columns for Excel output with ycharts_url moved after Risk_Overlay
columns_to_save = [
    'SymbolCUSIP', 'ProductName', 'fund_family', 'Return_Category', 'Risk_Overlay', 'ycharts_url',
    'investment_strategy', 'index_fund', 'inverse_fund', 'leveraged_fund',
    'socially_responsible_fund', 'synthetic_replication_fund', 'fund_of_funds',
    'Broad_Asset_Class_Name', 'Broad_Category_Name', 'Global_Category_Name',
    'Category_Name', 'CWA_Broad_Category_Name', 'Shop_Style', 'Likely_Fund_Type',
    'Index Based Score', 'Factor/Smart Beta Score', 'Active Discretionary Score',
    'Quant/Systematic Score', 'Multi-Strategy Score', 'None Score', 'Moderate Score',
    'Heavy / Persistent Score', 'Offensive / Levered Score'
]

# Save to Excel with new filename
df[columns_to_save].to_excel('classified_funds_v3.xlsx', index=False)
print("Results saved to 'classified_funds_v3.xlsx'")

# %%
# Separated Return Drivers Script
# updated script to incorporate risk overlays test and the return drivers
# This update also includes the larger keyword list that grok missed in the last test.
# This update also includes logic for big firms that are listed as "both" in the FundFamily_Data style
# Update also scan's fund name for keywords in risk and return drivers
# This update added the ability to skew shop overlay likelihoods

import pandas as pd
from sqlalchemy import create_engine

# Define return generation categories
RETURN_CATEGORIES = ["Index Based", "Factor/Smart Beta", "Active Discretionary", "Quant/Systematic", "Multi-Strategy"]

# Keyword lists for return drivers
return_keywords = {
    "Index Based": [
        "tracks", "replicates", "mirrors", "follows", "indexes", "passive", "benchmark",
        "market-cap weighted", "equal-weighted index", "low tracking error", "high correlation",
        "beta", "etf", "index fund", "closely matches", "minimal deviation", "broad market exposure",
        "cost-efficient", "low-cost", "transparent", "rules-based replication", "market index",
        "sector index", "fixed income index", "commodity index", "currency index", "rules-based", "index",
        "bond index", "aggregate bond", "treasury index", "corporate bond index", "correspond", "underlying index"
    ],
    "Factor/Smart Beta": [
        "factor", "smart beta", "value", "growth", "momentum", "quality", "low volatility",
        "dividend", "fundamental weighting", "equal weighting", "rules-based", "enhanced returns",
        "risk-adjusted", "academic strategies", "tactical", "alternative weighting", "optimized",
        "factor tilt", "multi-factor", "single-factor", "thematic", "sector rotation", "style-based",
        "esg factors", "minimum variance", "quantitative screens", "proprietary index",
        "custom index", "enhanced index", "revenue weighted", "dividend weighted", "yield weighted",
        "dividend yield weighted", "factor weighted", "alternative beta", "tilt", "ishares"
    ],
    "Active Discretionary": [
        "active", "discretionary", "fundamental", "research-driven", "stock picking",
        "portfolio manager", "judgment", "analysis", "insight", "conviction", "opportunistic",
        "tactical allocation", "high conviction", "concentrated portfolio", "bottom-up", "top-down",
        "macro-driven", "event-driven", "catalyst-driven", "long-term horizon", "short-term trading",
        "active share", "alpha generation", "outperform", "undervalued", "overvalued", "market timing",
        "sector selection", "security selection", "active risk", "active bets", "manager expertise",
        "proprietary research", "in-depth analysis", "qualitative assessment", "quantitative assessment",
        "active bond management", "credit analysis", "duration management", "yield curve positioning",
        "bond selection", "policy", "capital growth", "current income", "manager", "believes", "research",
        "selection", "strategically", "managed", "actively managed", "blackrock"
    ],
    "Quant/Systematic": [
        "quantitative", "systematic", "algorithm", "model-based", "data-driven", "statistical",
        "machine learning", "ai", "rules-driven", "backtested", "factor models", "risk parity",
        "momentum strategies", "mean-variance optimization", "arbitrage", "high-frequency",
        "low-frequency", "trend-following", "mean-reversion", "quantitative screens",
        "proprietary models", "signal-based", "factor timing", "dynamic factor weighting",
        "quantitative overlay", "automated trading", "algorithmic trading", "robo-advisor",
        "systematic risk management", "quantitative risk models", "factor decomposition",
        "style analysis", "attribution analysis", "monte carlo simulation", "optimization algorithms",
        "long/short", "sell puts", "sell calls", "straddle", "options strategy", "derivatives-based",
        "quantitative fixed income", "bond factor models", "systematic trading", "algorithmic options"
    ],
    "Multi-Strategy": [
        "multi-strategy", "blended", "diverse", "combination", "hybrid", "integrated", "multi-manager",
        "multi-asset", "allocation across strategies", "dynamic allocation", "tactical overlay",
        "risk-managed", "diversified", "cross-asset", "cross-strategy", "strategy rotation", "adaptive",
        "flexible", "multi-style", "balanced", "mixed approach", "overlay strategy", "core-satellite",
        "barbell strategy", "hedged", "long-short", "market-neutral", "absolute return", "relative value",
        "global macro", "managed futures", "alternative beta", "risk premia", "portable alpha",
        "long/short equity", "options overlay", "derivatives hedging", "multi-asset class",
        "cross-strategy allocation", "alternative strategies"
    ]
}

# Shop lookup for return drivers
SHOP_BOTH_LOOKUP = {
    "T. Rowe Price": {"Active Discretionary": 3, "Index Based": 1, "Quant/Systematic": 1},
    "Fidelity Investments": {"Active Discretionary": 2, "Index Based": 2, "Quant/Systematic": 1},
    "BlackRock": {"Index Based": 2, "Factor/Smart Beta": 2, "Active Discretionary": 1, "Quant/Systematic": 1},
    "Invesco": {"Active Discretionary": 2, "Index Based": 1, "Factor/Smart Beta": 1, "Quant/Systematic": 1},
    "WisdomTree": {"Factor/Smart Beta": 3, "Index Based": 1},
    "First Trust": {"Active Discretionary": 2, "Index Based": 1, "Factor/Smart Beta": 3, "Quant/Systematic": 1, "Multi-Strategy": 1},
    "AllianceBernstein": {"Active Discretionary": 3, "Factor/Smart Beta": 1, "Quant/Systematic": 1, "Multi-Strategy": 1},
    "JPMorgan": {"Active Discretionary": 3, "Index Based": 1, "Factor/Smart Beta": 2, "Quant/Systematic": 1, "Multi-Strategy": 1},
    "John Hancock": {"Active Discretionary": 2, "Index Based": 1, "Factor/Smart Beta": 2, "Quant/Systematic": 1, "Multi-Strategy": 1},
    "Victory Capital": {"Active Discretionary": 2, "Index Based": 1, "Factor/Smart Beta": 2, "Quant/Systematic": 1, "Multi-Strategy": 1},
    "Columbia Threadneedle": {"Active Discretionary": 3, "Index Based": 1, "Factor/Smart Beta": 1, "Quant/Systematic": 1, "Multi-Strategy": 1},
    "Federated": {"Active Discretionary": 2, "Factor/Smart Beta": 1, "Quant/Systematic": 1},
    "Hartford Mutual Funds": {"Active Discretionary": 2, "Index Based": 1, "Factor/Smart Beta": 2, "Quant/Systematic": 1, "Multi-Strategy": 1},
    "Allspring Global Investments": {"Active Discretionary": 3, "Index Based": 1, "Factor/Smart Beta": 1, "Quant/Systematic": 1, "Multi-Strategy": 1}
    "American Funds": {"Active Discretionary": 2},
    "AMG Funds": {"Active Discretionary": 2},
    "AQR Funds": {"Quant/Systematic": 1},
    "Amundi US": {"Active Discretionary": 1},
    "AQR Funds": {"Quant/Systematic": 2},
}

# Category lookup for return drivers
CATEGORY_LOOKUP = {
    "trading tool": {"Quant/Systematic": 3},
    "quantitative/tactical": {"Quant/Systematic": 3},
    "systematic trend": {"Quant/Systematic": 3},
    "tactical allocation": {"Quant/Systematic": 3},
    "trading tools": {"Quant/Systematic": 3},
    "options trading": {"Quant/Systematic": 3},
    "municipal": {"Index Based": 1, "Active Discretionary": 2},  # Reduced Index from +2 to +1
    "muni national": {"Index Based": 1, "Active Discretionary": 2},
    "muni single state": {"Index Based": 1, "Active Discretionary": 2},
    "nontraditional": {"Quant/Systematic": 2, "Multi-Strategy": 2, "Active Discretionary": 1, "Factor/Smart Beta": 1},
    "nontraditional bond": {"Quant/Systematic": 2, "Multi-Strategy": 2, "Active Discretionary": 1, "Factor/Smart Beta": 1},
    "sector/industry": {"Index Based": 3},
    "communications": {"Index Based": 3},
    "energy": {"Index Based": 3},
    "financials": {"Index Based": 3},
    "healthcare": {"Index Based": 3},
    "industrials": {"Index Based": 3},
    "technology": {"Index Based": 3},
    "utilities": {"Index Based": 3},
    "single stock": {"Index Based": 2, "Quant/Systematic": 2},
    "target maturity": {"Index Based": 3},
    "muni target maturity": {"Index Based": 3},
    "digital asset": {"Index Based": 3, "Factor/Smart Beta": 1, "Multi-Strategy": 1},
    "digital assets": {"Index Based": 3, "Factor/Smart Beta": 1, "Multi-Strategy": 1},
    "commodity": {"Index Based": 3},  # Conditional logic handled separately
    "commodities broad basket": {"Index Based": 3},
    "commodities specified": {"Index Based": 3},
    "alternative": {"Multi-Strategy": 3},
    "defined outcome": {"Multi-Strategy": 3},
    "multialternative": {"Multi-Strategy": 3},
    "multistrategy": {"Multi-Strategy": 3},
    "currency": {"Quant/Systematic": 3},
    "single currency": {"Quant/Systematic": 3},
    "strategic": {"Active Discretionary": 3},
    "bond strategy": {"Active Discretionary": 3},
    "global bond": {"Index Based": 1, "Active Discretionary": 1},
    "taxable fixed income": {"Index Based": 1, "Active Discretionary": 1},
    "fixed income": {"Index Based": 1, "Active Discretionary": 1}
}

# Database connection
connection_string = (
    "mssql+pyodbc://JULIANS_LAPTOP\\SQLEXPRESS/"
    "CWA_Fund_Database?driver=ODBC+Driver+18+for+SQL+Server"
    "&trusted_connection=yes&TrustServerCertificate=yes"
)
engine = create_engine(connection_string)

# SQL query
query = """
SELECT 
    fs.SymbolCUSIP, fs.ProductName, fs.fund_family, fs.investment_strategy,
    fs.index_fund, fs.inverse_fund, fs.leveraged_fund, fs.socially_responsible_fund,
    fs.synthetic_replication_fund, fs.fund_of_funds, fs.ycharts_url,
    yc_ba.Broad_Asset_Class_Name, yc_bc.Broad_Category_Name, yc_gc.Global_Category_Name,
    yc_c.Category_Name, cwa_bc.CWA_Broad_Category_Name, ff.Shop_Style, ff.Likely_Fund_Type
FROM Funds_to_Screen fs
LEFT JOIN FundFamily_Data ff ON fs.fund_family = ff.Fund_Family
LEFT JOIN YC_Broad_Asset_Class_List yc_ba ON fs.YC_Broad_Asset_Class_ID = yc_ba.ID
LEFT JOIN YC_Broad_Category_List yc_bc ON fs.YC_Broad_Category_ID = yc_bc.ID
LEFT JOIN YC_Global_Category_List yc_gc ON fs.YC_Global_Category_ID = yc_gc.ID
LEFT JOIN YC_Category_List yc_c ON fs.YC_Category_ID = yc_c.ID
LEFT JOIN CWA_Broad_Category_List cwa_bc ON fs.CWA_Broad_Category_ID = cwa_bc.ID
"""
df = pd.read_sql(query, engine)

# --- Return Generation Classification ---

def keyword_score_return(row, category):
    product_name = row['ProductName'].lower() if pd.notna(row['ProductName']) else ""
    description = row['investment_strategy'].lower() if pd.notna(row['investment_strategy']) else ""
    text = product_name + " " + description
    return sum(keyword in text for keyword in return_keywords.get(category, []))

def boolean_adjustment_return(row, category):
    score = 0
    if category in ["Index Based", "Factor/Smart Beta"] and row['index_fund'] == 'True':
        score += 2
    if category in ["Quant/Systematic", "Multi-Strategy"] and (
        row['leveraged_fund'] == 'True' or row['inverse_fund'] == 'True' or 
        row['synthetic_replication_fund'] == 'True'
    ):
        score += 1
    if category == "Multi-Strategy" and row['fund_of_funds'] == 'True':
        score += 1
    return score

def category_mapping_return(row):
    category_cols = ['Broad_Asset_Class_Name', 'Broad_Category_Name', 'Global_Category_Name', 'Category_Name', 'CWA_Broad_Category_Name']
    scores = {category: 0 for category in RETURN_CATEGORIES}
    
    for col in category_cols:
        if pd.notna(row[col]):
            value = row[col].lower()
            for keyword, category_weights in CATEGORY_LOOKUP.items():
                if keyword in value:
                    for cat, points in category_weights.items():
                        scores[cat] += points
            # Special case for "commodity" conditional logic
            if value in ["commodity", "commodities broad basket", "commodities specified"]:
                if row['CWA_Broad_Category_Name'] == "Commodity":
                    scores["Index Based"] = max(scores["Index Based"], 3)
                elif "active" in row.get('investment_strategy', '').lower():
                    scores["Active Discretionary"] = max(scores["Active Discretionary"], 3)
                elif "quantitative" in row.get('investment_strategy', '').lower():
                    scores["Quant/Systematic"] = max(scores["Quant/Systematic"], 3)
    
    max_score = max(scores.values())
    if max_score > 0:
        return max(scores, key=scores.get)
    return None

def classify_return(row):
    scores = {category: 0 for category in RETURN_CATEGORIES}
    product_name = row['ProductName'].lower() if pd.notna(row['ProductName']) else ""
    description = row['investment_strategy'].lower() if pd.notna(row['investment_strategy']) else ""
    text = product_name + " " + description
    
    # Base keyword scoring
    for category in scores:
        scores[category] += keyword_score_return(row, category)
        scores[category] += boolean_adjustment_return(row, category)
    
    # Bonus points for strong indicators
    if "actively managed" in text:
        scores["Active Discretionary"] += 2  # Bonus for explicit "actively managed"
    if "rules-based" in text:
        scores["Factor/Smart Beta"] += 2  # Bonus for explicit "rules-based" (corrected from Index Based)
    
    # Category mapping
    mapped_category = category_mapping_return(row)
    if mapped_category:
        scores[mapped_category] += 2
    
    # Shop tilt
    if pd.notna(row['Shop_Style']) and row['Shop_Style'].lower() == "both":
        shop_weights = SHOP_BOTH_LOOKUP.get(row['fund_family'], {})
        for category, weight in shop_weights.items():
            if category in RETURN_CATEGORIES:
                scores[category] += weight
    else:
        if pd.notna(row['Likely_Fund_Type']) and row['Likely_Fund_Type'] in RETURN_CATEGORIES:
            scores[row['Likely_Fund_Type']] += 2
    
    return pd.Series({
        'Return_Category': max(scores, key=scores.get),
        'Index Based Score': scores['Index Based'],
        'Factor/Smart Beta Score': scores['Factor/Smart Beta'],
        'Active Discretionary Score': scores['Active Discretionary'],
        'Quant/Systematic Score': scores['Quant/Systematic'],
        'Multi-Strategy Score': scores['Multi-Strategy']
    })

# Apply classification
return_results = df.apply(classify_return, axis=1)
df = pd.concat([df, return_results], axis=1)

# Select columns for Excel output with updated order
columns_to_save = [
    'SymbolCUSIP', 'ProductName', 'fund_family', 'Return_Category', 'ycharts_url',
    'Shop_Style', 'Likely_Fund_Type', 'Index Based Score', 'Factor/Smart Beta Score', 'Active Discretionary Score',
    'Quant/Systematic Score', 'Multi-Strategy Score', 'investment_strategy', 'index_fund', 'inverse_fund', 'leveraged_fund',
    'socially_responsible_fund', 'synthetic_replication_fund', 'fund_of_funds',
    'Broad_Asset_Class_Name', 'Broad_Category_Name', 'Global_Category_Name',
    'Category_Name', 'CWA_Broad_Category_Name'
]

# Save to Excel with new filename
df[columns_to_save].to_excel('classified_return_funds_v3.xlsx', index=False)
print("Results saved to 'classified_return_funds_v3.xlsx'")
# Out:
# Results saved to 'classified_return_funds_v3.xlsx'

# %%
# Separated Risk Overlays screen

import pandas as pd
from sqlalchemy import create_engine

# Define risk management overlay categories
RISK_CATEGORIES = ["None", "Moderate", "Heavy / Persistent", "Offensive / Levered"]

# Updated keyword lists for risk overlays
risk_keywords = {
    "None": ["long-only", "no derivatives", "no short", "straight equity"],
    "Moderate": ["hedging", "derivatives", "borrowings", "contracts", "futures", "options", "partial hedge", "covered call", "duration management", "hedge"],
    "Heavy / Persistent": ["persistent hedges", "borrowings", "contracts", "futures", "tail-risk", "protective", "overlay", "derivatives", "systematic hedging", "hedge"],
    "Offensive / Levered": ["leverage", "amplified", "geared", "borrowings", "contracts", "futures", "derivatives", "2x", "3x", "hedge"]
}

# Shop lookup for risk overlays
SHOP_RISK_LOOKUP = {
    "T. Rowe Price": {"None": 2, "Moderate": 1},
    "Fidelity Investments": {"None": 2, "Moderate": 1, "Heavy / Persistent": 1},
    "BlackRock": {"None": 2, "Moderate": 1, "Offensive / Levered": 1},
    "Invesco": {"None": 2, "Moderate": 1, "Heavy / Persistent": 1},
    "WisdomTree": {"None": 2, "Moderate": 1},
    "First Trust": {"None": 1, "Moderate": 2, "Heavy / Persistent": 1},
    "AllianceBernstein": {"None": 1, "Moderate": 2, "Heavy / Persistent": 1},
    "JPMorgan": {"None": 1, "Moderate": 2, "Heavy / Persistent": 1, "Offensive / Levered": 1},
    "John Hancock": {"None": 1, "Moderate": 2, "Heavy / Persistent": 1},
    "Victory Capital": {"None": 1, "Moderate": 2, "Heavy / Persistent": 1},
    "Columbia Threadneedle": {"None": 1, "Moderate": 2, "Heavy / Persistent": 1},
    "Federated": {"None": 2, "Moderate": 1},
    "Hartford Mutual Funds": {"None": 1, "Moderate": 2, "Heavy / Persistent": 1},
    "Allspring Global Investments": {"None": 1, "Moderate": 2, "Heavy / Persistent": 1}
}

# Category lookup for risk overlays
RISK_CATEGORY_LOOKUP = {
    "us equity": {"None": 2},
    "municipal": {"None": 2},
    "taxable fixed income": {"None": 2},
    "target date": {"None": 2},
    "allocation": {"Moderate": 2},
    "bond strategy": {"Moderate": 2},
    "strategic": {"Moderate": 2},
    "target maturity": {"Moderate": 2},
    "convertibles": {"Moderate": 2},
    "alternative": {"Heavy / Persistent": 2},
    "defined outcome": {"Heavy / Persistent": 2},
    "nontraditional": {"Heavy / Persistent": 2},
    "specialty": {"Heavy / Persistent": 2},
    "derivative income": {"Heavy / Persistent": 2},
    "trading/tactical": {"Offensive / Levered": 2},
    "quantitative/tactical": {"Offensive / Levered": 2},
    "commodity": {"Offensive / Levered": 2},
    "currency": {"Offensive / Levered": 2},
    "digital asset": {"Offensive / Levered": 2},
    "trading--leveraged": {"Offensive / Levered": 3},
    "trading--inverse": {"Offensive / Levered": 3}
}

# Database connection
connection_string = (
    "mssql+pyodbc://JULIANS_LAPTOP\\SQLEXPRESS/"
    "CWA_Fund_Database?driver=ODBC+Driver+18+for+SQL+Server"
    "&trusted_connection=yes&TrustServerCertificate=yes"
)
engine = create_engine(connection_string)

# SQL query
query = """
SELECT 
    fs.SymbolCUSIP, fs.ProductName, fs.fund_family, fs.investment_strategy,
    fs.index_fund, fs.inverse_fund, fs.leveraged_fund, fs.socially_responsible_fund,
    fs.synthetic_replication_fund, fs.fund_of_funds, fs.ycharts_url,
    yc_ba.Broad_Asset_Class_Name, yc_bc.Broad_Category_Name, yc_gc.Global_Category_Name,
    yc_c.Category_Name, cwa_bc.CWA_Broad_Category_Name, ff.Shop_Style, ff.Likely_Fund_Type
FROM Funds_to_Screen fs
LEFT JOIN FundFamily_Data ff ON fs.fund_family = ff.Fund_Family
LEFT JOIN YC_Broad_Asset_Class_List yc_ba ON fs.YC_Broad_Asset_Class_ID = yc_ba.ID
LEFT JOIN YC_Broad_Category_List yc_bc ON fs.YC_Broad_Category_ID = yc_bc.ID
LEFT JOIN YC_Global_Category_List yc_gc ON fs.YC_Global_Category_ID = yc_gc.ID
LEFT JOIN YC_Category_List yc_c ON fs.YC_Category_ID = yc_c.ID
LEFT JOIN CWA_Broad_Category_List cwa_bc ON fs.CWA_Broad_Category_ID = cwa_bc.ID
"""
df = pd.read_sql(query, engine)

# --- Risk Management Overlay Classification ---

def keyword_score_risk(row, category):
    product_name = row['ProductName'].lower() if pd.notna(row['ProductName']) else ""
    description = row['investment_strategy'].lower() if pd.notna(row['investment_strategy']) else ""
    text = product_name + " " + description
    return sum(keyword in text for keyword in risk_keywords.get(category, []))

def boolean_adjustment_risk(row, category):
    score = 0
    if category == "Offensive / Levered" and row['leveraged_fund'] == 'True':
        score += 3
    if category in ["Heavy / Persistent", "Offensive / Levered"] and row['inverse_fund'] == 'True':
        score += 2
    if category in ["Moderate", "Heavy / Persistent"] and row['synthetic_replication_fund'] == 'True':
        score += 1
    if category == "None" and all(row[col] == 'False' for col in ['leveraged_fund', 'inverse_fund', 'synthetic_replication_fund']):
        score += 2
    return score

def category_mapping_risk(row):
    category_cols = ['Broad_Asset_Class_Name', 'Broad_Category_Name', 'Global_Category_Name', 'Category_Name', 'CWA_Broad_Category_Name']
    scores = {category: 0 for category in RISK_CATEGORIES}
    
    for col in category_cols:
        if pd.notna(row[col]):
            value = row[col].lower()
            for keyword, category_weights in RISK_CATEGORY_LOOKUP.items():
                if keyword in value:
                    for cat, points in category_weights.items():
                        scores[cat] += points
    
    max_score = max(scores.values())
    if max_score > 0:
        return max(scores, key=scores.get)
    return None

def classify_risk(row):
    scores = {category: 0 for category in RISK_CATEGORIES}
    for category in scores:
        scores[category] += keyword_score_risk(row, category)
        scores[category] += boolean_adjustment_risk(row, category)
    mapped_category = category_mapping_risk(row)
    if mapped_category:
        scores[mapped_category] += 2
    if pd.notna(row['Shop_Style']) and row['Shop_Style'].lower() == "both":
        shop_weights = SHOP_RISK_LOOKUP.get(row['fund_family'], {})
        for category, weight in shop_weights.items():
            if category in RISK_CATEGORIES:
                scores[category] += weight
    elif pd.notna(row['Shop_Style']):
        if row['Shop_Style'] == 'Quant' and row['Likely_Fund_Type'] in ['Quant/Systematic', 'Multi-Strategy']:
            scores['Heavy / Persistent'] += 1
            scores['Offensive / Levered'] += 1
        elif row['Shop_Style'] == 'Active':
            scores['None'] += 1
    return pd.Series({
        'Risk_Overlay': max(scores, key=scores.get),
        'None Score': scores['None'],
        'Moderate Score': scores['Moderate'],
        'Heavy / Persistent Score': scores['Heavy / Persistent'],
        'Offensive / Levered Score': scores['Offensive / Levered']
    })

# Apply classification
risk_results = df.apply(classify_risk, axis=1)
df = pd.concat([df, risk_results], axis=1)

# Select columns for Excel output
columns_to_save = [
    'SymbolCUSIP', 'ProductName', 'fund_family', 'Risk_Overlay', 'ycharts_url',
    'investment_strategy', 'index_fund', 'inverse_fund', 'leveraged_fund',
    'socially_responsible_fund', 'synthetic_replication_fund', 'fund_of_funds',
    'Broad_Asset_Class_Name', 'Broad_Category_Name', 'Global_Category_Name',
    'Category_Name', 'CWA_Broad_Category_Name', 'Shop_Style', 'Likely_Fund_Type',
    'None Score', 'Moderate Score', 'Heavy / Persistent Score', 'Offensive / Levered Score'
]

# Save to Excel
df[columns_to_save].to_excel('classified_funds_v3_risk.xlsx', index=False)
print("Results saved to 'classified_funds_v3_risk.xlsx'")

# %%
# Version 4, now with tiers, confidence intervals per data type etc

import pandas as pd
from sqlalchemy import create_engine

"""
classify_return_drivers.py (V5)

This script classifies investment funds into one of five return generation strategies:
- Index Based
- Factor/Smart Beta
- Active Discretionary
- Quant/Systematic
- Multi-Strategy

Overview:
- Uses a tiered confidence system (High, Medium, Low) to score funds based on keywords, fund family, categories, and metadata.
- Metadata flags (e.g., index_fund) are scored once, outside the tier system, to avoid overweighting.
- Supports a "Dry Run" mode for testing specific funds.

Tunable Parameters and Switches:
- Clustered at the top for easy adjustment.

Output:
- 'classified_return_funds_v4.xlsx': Contains classified return categories and tier-specific scores.
"""

# --- Tunable Parameters and Dry Run Switches (Adjust Here) ---
TIER_CAP = 100  # Maximum points per tier
FUND_FAMILY_WEIGHT = 40  # Points allocated to fund family tendencies
KEYWORDS_WEIGHT = 30  # Points allocated to keywords
CATEGORIES_WEIGHT = 15  # Points allocated to category labels
METADATA_WEIGHT = 15  # Points allocated to metadata flags (scored once)
HIGH_CONF_THRESHOLD = 50  # Threshold for classification in High Confidence tier
LIKELY_FUND_TYPE_WEIGHT = 0.5  # Proportion of FUND_FAMILY_WEIGHT for Likely_Fund_Type
DRY_RUN = False  # Enable dry-run mode for testing
TEST_FUNDS = ["VOO", "DFSVX", "BSIIX", "IVV", "FBALX", "LCEAX", "JSMBX"]  # Funds to test in dry-run mode

# Tier weights for final score normalization
TIER_WEIGHTS = {"High": 1.0, "Medium": 0.5, "Low": 0.25}

# --- Constants ---
RETURN_CATEGORIES = ["Index Based", "Factor/Smart Beta", "Active Discretionary", "Quant/Systematic", "Multi-Strategy"]

# --- Keyword Lists (Insert Updated Keywords Here) ---
# Points for keywords are calculated via: hits * (Max points/# of keywords in tier)
# Therefore # keywords matters, less for high confidence, more in medium, whatever in low to try to "get there"

# High Confidence: Definitive terms
high_conf_keywords = {
    "Index Based": ["index fund", "tracks", "replicates", "indexed", "underlying index", "thematic"],
    "Factor/Smart Beta": ["rules-based", "factor-based", "factor tilt", "multi-factor", "factor investing"],
    "Active Discretionary": ["actively managed", "actively-managed", "manager believes", "manager's judgment"],
    "Quant/Systematic": ["quantitative", "algorithm-driven", "systematic", "levered"],
    "Multi-Strategy": ["multi-strategy", "multi-asset", "hybrid strategy"]
}

# Medium Confidence: Suggestive terms
med_conf_keywords = {
    "Index Based": ["bond index", "market-cap weighted", "low tracking error", "high correlation", "benchmark", "low-cost", "broad market exposure", "passive",
    "broad market exposure", "aggregate bond", "passive"],
    "Factor/Smart Beta": ["enhanced index", "revenue weighted", "dividend weighted", "enhanced returns", "thematic", "fundamental weighting",
    "yield weighted", "quality factor", "low volatility", "rotation"],
    "Active Discretionary": ["machine learning", "ai","research-driven", "fundamental", "strategically", "tactical allocation", "active", "rotation"],
    "Quant/Systematic": ["data-driven", "systematic", "backtested", "long-short", "model-based", "Rotation"],
    "Multi-Strategy": ["multi-manager", "dynamic allocation", "multi-asset", "absolute return", "blended"]
}

# Low Confidence: Broad or ambiguous terms
low_conf_keywords = {
    "Index Based": ["index", "mirrors", "equal-weighted", "bond index", "beta", "etf","value index", "growth index", "value index"],
    "Factor/Smart Beta": ["fundamental weighting", "enhanced index", "thematic", "tilt", "optimized"],
    "Active Discretionary": ["discretionary", "judgment", "analysis", "outperform", "selection", "tactical", "trend-following", "trend following"],
    "Quant/Systematic": ["quantitative", "algorithm", "statistical", "rules-driven", "trend-following", "trend following", "tactical"],
    "Multi-Strategy": ["combination", "hybrid", "multi-asset", "flexible", "alternative"]
}

# --- Shop Lookup for "Both" Shops Across Tiers (Insert Updated Mappings Below) ---
SHOP_BOTH_LOOKUP = {
    "High": {
        "Vanguard": {"Index Based": 30},
        "Dimensional Fund Advisors": {"Factor/Smart Beta": 40},
        "American Funds": {"Active Discretionary": 40},
        "AMG Funds": {"Active Discretionary": 30},
        "AQR Funds": {"Quant/Systematic": 35},
        "Amundi US": {"Active Discretionary": 20},
        "iShares": {"Active Discretionary": 0, "Index Based": 18, "Factor/Smart Beta": 18, "Quant/Systematic": 2, "Multi-Strategy": 2},
        "wisdomtree": {"Active Discretionary": 0, "Index Based": 18, "Factor/Smart Beta": 18, "Quant/Systematic": 2, "Multi-Strategy": 2},
    },
    "Medium": {
        "T. Rowe Price": {"Active Discretionary": 25, "Index Based": 10, "Quant/Systematic": 5},
        "Fidelity Investments": {"Active Discretionary": 25, "Index Based": 10, "Quant/Systematic": 5},
        "Invesco": {"Active Discretionary": 20, "Index Based": 10, "Factor/Smart Beta": 10},
        "JPMorgan": {"Active Discretionary": 20, "Index Based": 5, "Factor/Smart Beta": 10, "Quant/Systematic": 0, "Multi-Strategy": 5},
        "John Hancock": {"Active Discretionary": 20, "Index Based": 0, "Factor/Smart Beta": 10, "Quant/Systematic": 0, "Multi-Strategy": 10},
        "Victory Capital": {"Active Discretionary": 15, "Index Based": 0, "Factor/Smart Beta": 15, "Quant/Systematic": 5, "Multi-Strategy": 5},
        "Columbia Threadneedle": {"Active Discretionary": 30, "Index Based": 0, "Factor/Smart Beta": 5, "Quant/Systematic": 0, "Multi-Strategy": 5},
        "Federated": {"Active Discretionary": 20, "Factor/Smart Beta": 10, "Quant/Systematic": 10},
        "Hartford Mutual Funds": {"Active Discretionary": 20, "Index Based": 0, "Factor/Smart Beta": 20, "Quant/Systematic": 0, "Multi-Strategy": 0},
        "Allspring Global Investments": {"Active Discretionary": 30, "Index Based": 0, "Factor/Smart Beta": 0, "Quant/Systematic": 0, "Multi-Strategy": 0},
        "BlackRock": {"Active Discretionary": 25,"Index Based": 0, "Factor/Smart Beta": 0, "Quant/Systematic": 5, "Multi-Strategy": 10}
    },
    "Low": {
    "AdvisorShares": {"Active Discretionary": 15,"Index Based": 5, "Factor/Smart Beta": 15, "Quant/Systematic": 5, "Multi-Strategy": 5}
    }
}

# --- Category Lookup Across Tiers (Insert Updated Mappings Below) ---
CATEGORY_LOOKUP = {
    "High": {
        "Defined Outcome": {"Quant/Systematic": 15},
        "actively managed": {"Active Discretionary": 15},
        "Quantitative/Tactical": {"Quant/Systematic": 15},
        "Trading/Tactical": {"Quant/Systematic": 10},
        "Digital Asset": {"Index Based": 15},
        "Currency": {"Index Based": 15},
        "Target Maturity": {"Index Based": 15},
        "Systematic Trend": {"Quant/Systematic": 15}
    },
    "Medium": {
        "Bond Strategy": {"Active Discretionary": 5, "Factor/Smart Beta": 5, "Quant/Systematic": 5},
        "Trading Tools": {"Quant/Systematic": 10},
        "Trading": {"Quant/Systematic": 10},
        "Target Date": {"Active Discretionary": 5, "Index Based": 2, "Multi-Strategy": 8,},
        "Options Trading": {"Active Discretionary": 5, "Factor/Smart Beta": 5, "Quant/Systematic": 5},
        "Long/Short Equity": {"Active Discretionary": 5, "Quant/Systematic": 5},
        "Commodities": {"Active Discretionary": 4, "Factor/Smart Beta": 1, "Quant/Systematic": 4, "Index Based": 4, "Multi-Strategy": 1},
        "Municipal": {"Active Discretionary": 6, "Factor/Smart Beta": 2, "Index Based": 6, "Multi-Strategy": 1},
        "Derivative Income": {"Active Discretionary": 5, "Quant/Systematic": 4, "Factor/Smart Beta": 2, "Index Based": 4},
        "Event Driven": {"Active Discretionary": 8, "Quant/Systematic": 7},
        "Inflation-Protected Bond": {"Active Discretionary": 6, "Index Based": 9}
    },
    "Low": {
        "Multialternative": {"Quant/Systematic": 7, "Active Discretionary": 8},
        "Specialty": {"Multi-Strategy": 4, "Quant/Systematic": 4, "Active Discretionary": 5},
        "Strategic": {"Multi-Strategy": 4, "Quant/Systematic": 4, "Active Discretionary": 5},
        "Nontraditional": {"Multi-Strategy": 2, "Quant/Systematic": 3, "Active Discretionary": 3, "Factor/Smart Beta": 3},
        "Equity Hedged": {"Active Discretionary": 5, "Quant/Systematic": 3, "Factor/Smart Beta": 2, "Index Based": 5},
        "Multisector Bond": {"Active Discretionary": 5, "Quant/Systematic": 3, "Factor/Smart Beta": 2, "Index Based": 5},
        "Nontraditional Bond": {"Active Discretionary": 5, "Quant/Systematic": 3, "Factor/Smart Beta": 2, "Index Based": 5}
    }
}

# --- Database Connection ---
connection_string = (
    "mssql+pyodbc://JULIANS_LAPTOP\\SQLEXPRESS/"
    "CWA_Fund_Database?driver=ODBC+Driver+18+for+SQL+Server"
    "&trusted_connection=yes&TrustServerCertificate=yes"
)
engine = create_engine(connection_string)

# --- SQL Query ---
query = """
SELECT 
    fs.SymbolCUSIP, fs.ProductName, fs.fund_family, fs.investment_strategy, fs.FS_insight,
    fs.index_fund, fs.inverse_fund, fs.leveraged_fund, fs.socially_responsible_fund,
    fs.synthetic_replication_fund, fs.fund_of_funds, fs.ycharts_url,
    yc_ba.Broad_Asset_Class_Name, yc_bc.Broad_Category_Name, yc_gc.Global_Category_Name,
    yc_c.Category_Name, cwa_bc.CWA_Broad_Category_Name, ff.Shop_Style, ff.Likely_Fund_Type
FROM Funds_to_Screen fs
LEFT JOIN FundFamily_Data ff ON fs.fund_family = ff.Fund_Family
LEFT JOIN YC_Broad_Asset_Class_List yc_ba ON fs.YC_Broad_Asset_Class_ID = yc_ba.ID
LEFT JOIN YC_Broad_Category_List yc_bc ON fs.YC_Broad_Category_ID = yc_bc.ID
LEFT JOIN YC_Global_Category_List yc_gc ON fs.YC_Global_Category_ID = yc_gc.ID
LEFT JOIN YC_Category_List yc_c ON fs.YC_Category_ID = yc_c.ID
LEFT JOIN CWA_Broad_Category_List cwa_bc ON fs.CWA_Broad_Category_ID = cwa_bc.ID
"""
df = pd.read_sql(query, engine)

# --- Apply Dry-Run Filter ---
if DRY_RUN:
    df = df[df['SymbolCUSIP'].isin(TEST_FUNDS)]

# --- Function Definitions ---

## Score Keywords
def score_keywords(text, keyword_dict, max_points):
    scores = {cat: 0 for cat in RETURN_CATEGORIES}
    for category, keywords in keyword_dict.items():
        hits = sum(keyword in text for keyword in keywords)
        if len(keywords) > 0:
            scores[category] = min(hits * (max_points / len(keywords)), max_points)
    return scores

## Score Categories
def score_categories(row, tier_dict, max_points):
    category_cols = ['Broad_Asset_Class_Name', 'Broad_Category_Name', 'Global_Category_Name', 'Category_Name', 'CWA_Broad_Category_Name']
    scores = {cat: 0 for cat in RETURN_CATEGORIES}
    for col in category_cols:
        if pd.notna(row[col]):
            value = row[col].lower()
            for keyword, weights in tier_dict.items():
                if keyword in value:
                    for cat, points in weights.items():
                        scores[cat] += points
    for cat in scores:
        scores[cat] = min(scores[cat], max_points)
    return scores

## Score Metadata (Once, Outside Tiers)
def score_metadata(row, max_points):
    scores = {cat: 0 for cat in RETURN_CATEGORIES}
    if row['index_fund'] == 'True':
        scores["Index Based"] += max_points / 1
    if row['leveraged_fund'] == 'True' or row['inverse_fund'] == 'True':
        scores["Quant/Systematic"] += max_points / 2
    if row['fund_of_funds'] == 'True':
        scores["Active Discretionary"] and ["Factor/Smart Beta"] and ["Index Based"] += max_points / 3
    return scores

## Score Fund Family
def score_fund_family(row, tier, max_points):
    scores = {cat: 0 for cat in RETURN_CATEGORIES}
    if pd.notna(row['Shop_Style']) and row['Shop_Style'].lower() != "both":
        if pd.notna(row['Likely_Fund_Type']) and row['Likely_Fund_Type'] in RETURN_CATEGORIES:
            if tier in ["High", "Medium"]:
                scores[row['Likely_Fund_Type']] += max_points * LIKELY_FUND_TYPE_WEIGHT
    else:
        shop_weights = SHOP_BOTH_LOOKUP.get(tier, {}).get(row['fund_family'], {})
        for cat, points in shop_weights.items():
            scores[cat] += points
        if row['fund_family'] == "BlackRock" and pd.notna(row['ProductName']):
            product_name = row['ProductName'].lower()
            if "ishares" in product_name and tier == "High":
                scores["Index Based"] += 30
                scores["Factor/Smart Beta"] += 10
            elif "ishares" not in product_name and tier == "Medium":
                scores["Active Discretionary"] += 20
    return scores

## Classify Return Drivers
def classify_return(row):
    # Combine text fields for keyword matching
    product_name = row['ProductName'].lower() if pd.notna(row['ProductName']) else ""
    investment_strategy = row['investment_strategy'].lower() if pd.notna(row['investment_strategy']) else ""
    fs_insight = row['FS_insight'].lower() if pd.notna(row['FS_insight']) else ""
    text = product_name + " " + investment_strategy + " " + fs_insight

    # Initialize final scores dictionary
    final_scores = {cat: 0 for cat in RETURN_CATEGORIES}

    # Initialize dictionaries to store tier-specific and metadata scores
    tier_scores = {tier: {cat: 0 for cat in RETURN_CATEGORIES} for tier in TIER_WEIGHTS}
    metadata_scores = {cat: 0 for cat in RETURN_CATEGORIES}

    # --- Step 1: Score Keywords Across Tiers ---
    # High Confidence Tier
    high_keyword_scores = score_keywords(text, high_conf_keywords, KEYWORDS_WEIGHT)
    for cat in RETURN_CATEGORIES:
        tier_scores['High'][cat] += high_keyword_scores[cat]

    # Medium Confidence Tier
    med_keyword_scores = score_keywords(text, med_conf_keywords, KEYWORDS_WEIGHT)
    for cat in RETURN_CATEGORIES:
        tier_scores['Medium'][cat] += med_keyword_scores[cat]

    # Low Confidence Tier
    low_keyword_scores = score_keywords(text, low_conf_keywords, KEYWORDS_WEIGHT)
    for cat in RETURN_CATEGORIES:
        tier_scores['Low'][cat] += low_keyword_scores[cat]

    # --- Step 2: Score Fund Family Across Tiers ---
    # High Confidence Tier
    high_ff_scores = score_fund_family(row, 'High', FUND_FAMILY_WEIGHT)
    for cat in RETURN_CATEGORIES:
        tier_scores['High'][cat] += high_ff_scores[cat]

    # Medium Confidence Tier
    med_ff_scores = score_fund_family(row, 'Medium', FUND_FAMILY_WEIGHT)
    for cat in RETURN_CATEGORIES:
        tier_scores['Medium'][cat] += med_ff_scores[cat]

    # Low Confidence Tier
    low_ff_scores = score_fund_family(row, 'Low', FUND_FAMILY_WEIGHT)
    for cat in RETURN_CATEGORIES:
        tier_scores['Low'][cat] += low_ff_scores[cat]

    # --- Step 3: Score Categories Across Tiers ---
    # High Confidence Tier
    high_cat_scores = score_categories(row, CATEGORY_LOOKUP['High'], CATEGORIES_WEIGHT)
    for cat in RETURN_CATEGORIES:
        tier_scores['High'][cat] += high_cat_scores[cat]

    # Medium Confidence Tier
    med_cat_scores = score_categories(row, CATEGORY_LOOKUP['Medium'], CATEGORIES_WEIGHT)
    for cat in RETURN_CATEGORIES:
        tier_scores['Medium'][cat] += med_cat_scores[cat]

    # Low Confidence Tier
    low_cat_scores = score_categories(row, CATEGORY_LOOKUP['Low'], CATEGORIES_WEIGHT)
    for cat in RETURN_CATEGORIES:
        tier_scores['Low'][cat] += low_cat_scores[cat]

    # --- Step 4: Score Metadata (Once, Outside Tiers) ---
    metadata_scores = score_metadata(row, METADATA_WEIGHT)

    # --- Step 5: Compute Final Scores ---
    for cat in RETURN_CATEGORIES:
        weighted_score = sum(tier_scores[tier][cat] * TIER_WEIGHTS[tier] for tier in TIER_WEIGHTS)
        weighted_score += metadata_scores[cat]
        final_scores[cat] = weighted_score

    # --- Step 6: Determine Predicted Category ---
    # If all scores are 0, assign "Unclassified" (or handle as needed)
    if all(score == 0 for score in final_scores.values()):
        predicted_category = "Unclassified"
    else:
        predicted_category = max(final_scores, key=final_scores.get)

    # --- Step 7: Prepare Output as a pandas Series ---
    result = {'Return_Category': predicted_category}
    
    # Add tier-specific scores
    for tier in TIER_WEIGHTS:
        for cat in RETURN_CATEGORIES:
            result[f"{tier}_{cat}_Score"] = tier_scores[tier][cat]
    
    # Add metadata scores
    for cat in RETURN_CATEGORIES:
        result[f"Metadata_{cat}_Score"] = metadata_scores[cat]

    return pd.Series(result)
    
# --- Apply Classification ---
result_cols = ['Return_Category'] + [f"{tier}_{cat}_Score" for tier in TIER_WEIGHTS for cat in RETURN_CATEGORIES] + [f"Metadata_{cat}_Score" for cat in RETURN_CATEGORIES]
df[result_cols] = df.apply(classify_return, axis=1)

# --- Prepare Output ---
output_cols = [
    'SymbolCUSIP', 'ProductName', 'fund_family', 'Return_Category', 'ycharts_url',
    'Shop_Style', 'Likely_Fund_Type'] + [col for col in df.columns if '_Score' in col] + [
    'investment_strategy', 'FS_insight', 'index_fund', 'inverse_fund', 'leveraged_fund', 'socially_responsible_fund',
    'synthetic_replication_fund', 'fund_of_funds', 'Broad_Asset_Class_Name', 'Broad_Category_Name',
    'Global_Category_Name', 'Category_Name', 'CWA_Broad_Category_Name'
]
df[output_cols].to_excel('classified_return_funds_v4.xlsx', index=False)
print("Classification complete. Results saved to 'classified_return_funds_v4.xlsx'.")
# Out:
# Classification complete. Results saved to 'classified_return_funds_v4.xlsx'.

# %%
# Version 5, enhanced with granular scoring output

import pandas as pd
from sqlalchemy import create_engine

"""
classify_return_drivers.py (V5)

Classifies investment funds into return generation strategies:
- Index Based
- Factor/Smart Beta
- Active Discretionary
- Quant/Systematic
- Multi-Strategy

Enhancements in V5:
- Outputs granular scoring details (component-wise scores per tier, total tier scores, final scores) to the Excel file.
- Improves debugging and verification of scoring logic.
"""

# --- Tunable Parameters and Dry Run Switches ---
TIER_CAP = 100
FUND_FAMILY_WEIGHT = 40
KEYWORDS_WEIGHT = 30
CATEGORIES_WEIGHT = 15
METADATA_WEIGHT = 15
HIGH_CONF_THRESHOLD = 50
LIKELY_FUND_TYPE_WEIGHT = 0.5
DRY_RUN = False
TEST_FUNDS = ["VOO", "DFSVX", "BSIIX", "IVV", "FBALX", "LCEAX", "JSMBX"]

TIER_WEIGHTS = {"High": 1.0, "Medium": 0.5, "Low": 0.25}

# --- Constants ---
RETURN_CATEGORIES = ["Index Based", "Factor/Smart Beta", "Active Discretionary", "Quant/Systematic", "Multi-Strategy"]

# --- Keyword Lists ---
high_conf_keywords = {
    "Index Based": ["index fund", "tracks", "replicates", "indexed", "underlying index", "thematic"],
    "Factor/Smart Beta": ["rules-based", "factor-based", "factor tilt", "multi-factor", "factor investing"],
    "Active Discretionary": ["actively managed", "actively-managed", "manager believes", "manager's judgment"],
    "Quant/Systematic": ["quantitative", "algorithm-driven", "systematic", "levered"],
    "Multi-Strategy": ["multi-strategy", "multi-asset", "hybrid strategy"]
}

med_conf_keywords = {
    "Index Based": ["bond index", "market-cap weighted", "low tracking error", "high correlation", "benchmark", "low-cost", "broad market exposure", "passive",
                    "broad market exposure", "aggregate bond", "passive"],
    "Factor/Smart Beta": ["enhanced index", "revenue weighted", "dividend weighted", "enhanced returns", "thematic", "fundamental weighting",
                          "yield weighted", "quality factor", "low volatility", "rotation"],
    "Active Discretionary": ["machine learning", "ai", "research-driven", "fundamental", "strategically", "tactical allocation", "active", "rotation"],
    "Quant/Systematic": ["data-driven", "systematic", "backtested", "long-short", "model-based", "Rotation"],
    "Multi-Strategy": ["multi-manager", "dynamic allocation", "multi-asset", "absolute return", "blended"]
}

low_conf_keywords = {
    "Index Based": ["index", "mirrors", "equal-weighted", "bond index", "beta", "etf", "value index", "growth index", "value index"],
    "Factor/Smart Beta": ["fundamental weighting", "enhanced index", "thematic", "tilt", "optimized"],
    "Active Discretionary": ["discretionary", "judgment", "analysis", "outperform", "selection", "tactical", "trend-following", "trend following"],
    "Quant/Systematic": ["quantitative", "algorithm", "statistical", "rules-driven", "trend-following", "trend following", "tactical"],
    "Multi-Strategy": ["combination", "hybrid", "multi-asset", "flexible", "alternative"]
}

# --- Shop Lookup ---
SHOP_BOTH_LOOKUP = {
    "High": {
        "Vanguard": {"Index Based": 30},
        "Dimensional Fund Advisors": {"Factor/Smart Beta": 40},
        "American Funds": {"Active Discretionary": 40},
        "AMG Funds": {"Active Discretionary": 30},
        "AQR Funds": {"Quant/Systematic": 35},
        "Amundi US": {"Active Discretionary": 20},
        "iShares": {"Active Discretionary": 0, "Index Based": 18, "Factor/Smart Beta": 18, "Quant/Systematic": 2, "Multi-Strategy": 2},
        "wisdomtree": {"Active Discretionary": 0, "Index Based": 18, "Factor/Smart Beta": 18, "Quant/Systematic": 2, "Multi-Strategy": 2},
    },
    "Medium": {
        "T. Rowe Price": {"Active Discretionary": 25, "Index Based": 10, "Quant/Systematic": 5},
        "Fidelity Investments": {"Active Discretionary": 25, "Index Based": 10, "Quant/Systematic": 5},
        "Invesco": {"Active Discretionary": 20, "Index Based": 10, "Factor/Smart Beta": 10},
        "JPMorgan": {"Active Discretionary": 20, "Index Based": 5, "Factor/Smart Beta": 10, "Quant/Systematic": 0, "Multi-Strategy": 5},
        "John Hancock": {"Active Discretionary": 20, "Index Based": 0, "Factor/Smart Beta": 10, "Quant/Systematic": 0, "Multi-Strategy": 10},
        "Victory Capital": {"Active Discretionary": 15, "Index Based": 0, "Factor/Smart Beta": 15, "Quant/Systematic": 5, "Multi-Strategy": 5},
        "Columbia Threadneedle": {"Active Discretionary": 30, "Index Based": 0, "Factor/Smart Beta": 5, "Quant/Systematic": 0, "Multi-Strategy": 5},
        "Federated": {"Active Discretionary": 20, "Factor/Smart Beta": 10, "Quant/Systematic": 10},
        "Hartford Mutual Funds": {"Active Discretionary": 20, "Index Based": 0, "Factor/Smart Beta": 20, "Quant/Systematic": 0, "Multi-Strategy": 0},
        "Allspring Global Investments": {"Active Discretionary": 30, "Index Based": 0, "Factor/Smart Beta": 0, "Quant/Systematic": 0, "Multi-Strategy": 0},
        "BlackRock": {"Active Discretionary": 25, "Index Based": 0, "Factor/Smart Beta": 0, "Quant/Systematic": 5, "Multi-Strategy": 10}
    },
    "Low": {
        "AdvisorShares": {"Active Discretionary": 15, "Index Based": 5, "Factor/Smart Beta": 15, "Quant/Systematic": 5, "Multi-Strategy": 5}
    }
}

# --- Category Lookup ---
CATEGORY_LOOKUP = {
    "High": {
        "Defined Outcome": {"Quant/Systematic": 15},
        "actively managed": {"Active Discretionary": 15},
        "Quantitative/Tactical": {"Quant/Systematic": 15},
        "Trading/Tactical": {"Quant/Systematic": 10},
        "Digital Asset": {"Index Based": 15},
        "Currency": {"Index Based": 15},
        "Target Maturity": {"Index Based": 15},
        "Systematic Trend": {"Quant/Systematic": 15}
    },
    "Medium": {
        "Bond Strategy": {"Active Discretionary": 5, "Factor/Smart Beta": 5, "Quant/Systematic": 5},
        "Trading Tools": {"Quant/Systematic": 10},
        "Trading": {"Quant/Systematic": 10},
        "Target Date": {"Active Discretionary": 5, "Index Based": 2, "Multi-Strategy": 8},
        "Options Trading": {"Active Discretionary": 5, "Factor/Smart Beta": 5, "Quant/Systematic": 5},
        "Long/Short Equity": {"Active Discretionary": 5, "Quant/Systematic": 5},
        "Commodities": {"Active Discretionary": 4, "Factor/Smart Beta": 1, "Quant/Systematic": 4, "Index Based": 4, "Multi-Strategy": 1},
        "Municipal": {"Active Discretionary": 6, "Factor/Smart Beta": 2, "Index Based": 6, "Multi-Strategy": 1},
        "Derivative Income": {"Active Discretionary": 5, "Quant/Systematic": 4, "Factor/Smart Beta": 2, "Index Based": 4},
        "Event Driven": {"Active Discretionary": 8, "Quant/Systematic": 7},
        "Inflation-Protected Bond": {"Active Discretionary": 6, "Index Based": 9}
    },
    "Low": {
        "Multialternative": {"Quant/Systematic": 7, "Active Discretionary": 8},
        "Specialty": {"Multi-Strategy": 4, "Quant/Systematic": 4, "Active Discretionary": 5},
        "Strategic": {"Multi-Strategy": 4, "Quant/Systematic": 4, "Active Discretionary": 5},
        "Nontraditional": {"Multi-Strategy": 2, "Quant/Systematic": 3, "Active Discretionary": 3, "Factor/Smart Beta": 3},
        "Equity Hedged": {"Active Discretionary": 5, "Quant/Systematic": 3, "Factor/Smart Beta": 2, "Index Based": 5},
        "Multisector Bond": {"Active Discretionary": 5, "Quant/Systematic": 3, "Factor/Smart Beta": 2, "Index Based": 5},
        "Nontraditional Bond": {"Active Discretionary": 5, "Quant/Systematic": 3, "Factor/Smart Beta": 2, "Index Based": 5}
    }
}

# --- Database Connection ---
connection_string = (
    "mssql+pyodbc://JULIANS_LAPTOP\\SQLEXPRESS/"
    "CWA_Fund_Database?driver=ODBC+Driver+18+for+SQL+Server"
    "&trusted_connection=yes&TrustServerCertificate=yes"
)
engine = create_engine(connection_string)

# --- SQL Query ---
query = """
SELECT 
    fs.SymbolCUSIP, fs.ProductName, fs.fund_family, fs.investment_strategy, fs.FS_insight,
    fs.index_fund, fs.inverse_fund, fs.leveraged_fund, fs.socially_responsible_fund,
    fs.synthetic_replication_fund, fs.fund_of_funds, fs.ycharts_url,
    yc_ba.Broad_Asset_Class_Name, yc_bc.Broad_Category_Name, yc_gc.Global_Category_Name,
    yc_c.Category_Name, cwa_bc.CWA_Broad_Category_Name, ff.Shop_Style, ff.Likely_Fund_Type
FROM Funds_to_Screen fs
LEFT JOIN FundFamily_Data ff ON fs.fund_family = ff.Fund_Family
LEFT JOIN YC_Broad_Asset_Class_List yc_ba ON fs.YC_Broad_Asset_Class_ID = yc_ba.ID
LEFT JOIN YC_Broad_Category_List yc_bc ON fs.YC_Broad_Category_ID = yc_bc.ID
LEFT JOIN YC_Global_Category_List yc_gc ON fs.YC_Global_Category_ID = yc_gc.ID
LEFT JOIN YC_Category_List yc_c ON fs.YC_Category_ID = yc_c.ID
LEFT JOIN CWA_Broad_Category_List cwa_bc ON fs.CWA_Broad_Category_ID = cwa_bc.ID
"""
df = pd.read_sql(query, engine)

if DRY_RUN:
    df = df[df['SymbolCUSIP'].isin(TEST_FUNDS)]

# --- Function Definitions ---

def score_keywords(text, keyword_dict, max_points):
    scores = {cat: 0 for cat in RETURN_CATEGORIES}
    for category, keywords in keyword_dict.items():
        hits = sum(keyword in text for keyword in keywords)
        if len(keywords) > 0:
            scores[category] = min(hits * (max_points / len(keywords)), max_points)
    return scores

def score_categories(row, tier_dict, max_points):
    category_cols = ['Broad_Asset_Class_Name', 'Broad_Category_Name', 'Global_Category_Name', 'Category_Name', 'CWA_Broad_Category_Name']
    scores = {cat: 0 for cat in RETURN_CATEGORIES}
    for col in category_cols:
        if pd.notna(row[col]):
            value = row[col].lower()
            for keyword, weights in tier_dict.items():
                if keyword in value:
                    for cat, points in weights.items():
                        scores[cat] += points
    for cat in scores:
        scores[cat] = min(scores[cat], max_points)
    return scores

def score_metadata(row, max_points):
    scores = {cat: 0 for cat in RETURN_CATEGORIES}
    if row['index_fund'] == 'True':
        scores["Index Based"] += max_points / 1
    if row['leveraged_fund'] == 'True' or row['inverse_fund'] == 'True':
        scores["Quant/Systematic"] += max_points / 2
    if row['fund_of_funds'] == 'True':
        scores["Active Discretionary"] += max_points / 3  # Fixed syntax
        scores["Factor/Smart Beta"] += max_points / 3
        scores["Index Based"] += max_points / 3
    return scores

def score_fund_family(row, tier, max_points):
    scores = {cat: 0 for cat in RETURN_CATEGORIES}
    if pd.notna(row['Shop_Style']) and row['Shop_Style'].lower() != "both":
        if pd.notna(row['Likely_Fund_Type']) and row['Likely_Fund_Type'] in RETURN_CATEGORIES:
            if tier in ["High", "Medium"]:
                scores[row['Likely_Fund_Type']] += max_points * LIKELY_FUND_TYPE_WEIGHT
    else:
        shop_weights = SHOP_BOTH_LOOKUP.get(tier, {}).get(row['fund_family'], {})
        for cat, points in shop_weights.items():
            scores[cat] += points
        if row['fund_family'] == "BlackRock" and pd.notna(row['ProductName']):
            product_name = row['ProductName'].lower()
            if "ishares" in product_name and tier == "High":
                scores["Index Based"] += 30
                scores["Factor/Smart Beta"] += 10
            elif "ishares" not in product_name and tier == "Medium":
                scores["Active Discretionary"] += 20
    return scores

def classify_return(row):
    # Combine text fields
    product_name = row['ProductName'].lower() if pd.notna(row['ProductName']) else ""
    investment_strategy = row['investment_strategy'].lower() if pd.notna(row['investment_strategy']) else ""
    fs_insight = row['FS_insight'].lower() if pd.notna(row['FS_insight']) else ""
    text = product_name + " " + investment_strategy + " " + fs_insight

    # Initialize scoring dictionaries
    final_scores = {cat: 0 for cat in RETURN_CATEGORIES}
    tier_scores = {tier: {cat: 0 for cat in RETURN_CATEGORIES} for tier in TIER_WEIGHTS}
    component_scores = {
        'Keywords': {tier: {cat: 0 for cat in RETURN_CATEGORIES} for tier in TIER_WEIGHTS},
        'FundFamily': {tier: {cat: 0 for cat in RETURN_CATEGORIES} for tier in TIER_WEIGHTS},
        'Categories': {tier: {cat: 0 for cat in RETURN_CATEGORIES} for tier in TIER_WEIGHTS},
    }
    metadata_scores = {cat: 0 for cat in RETURN_CATEGORIES}

    # Step 1: Score Keywords
    component_scores['Keywords']['High'] = score_keywords(text, high_conf_keywords, KEYWORDS_WEIGHT)
    component_scores['Keywords']['Medium'] = score_keywords(text, med_conf_keywords, KEYWORDS_WEIGHT)
    component_scores['Keywords']['Low'] = score_keywords(text, low_conf_keywords, KEYWORDS_WEIGHT)

    # Step 2: Score Fund Family
    component_scores['FundFamily']['High'] = score_fund_family(row, 'High', FUND_FAMILY_WEIGHT)
    component_scores['FundFamily']['Medium'] = score_fund_family(row, 'Medium', FUND_FAMILY_WEIGHT)
    component_scores['FundFamily']['Low'] = score_fund_family(row, 'Low', FUND_FAMILY_WEIGHT)

    # Step 3: Score Categories
    component_scores['Categories']['High'] = score_categories(row, CATEGORY_LOOKUP['High'], CATEGORIES_WEIGHT)
    component_scores['Categories']['Medium'] = score_categories(row, CATEGORY_LOOKUP['Medium'], CATEGORIES_WEIGHT)
    component_scores['Categories']['Low'] = score_categories(row, CATEGORY_LOOKUP['Low'], CATEGORIES_WEIGHT)

    # Step 4: Compute Total Tier Scores
    for tier in TIER_WEIGHTS:
        for cat in RETURN_CATEGORIES:
            tier_scores[tier][cat] = (
                component_scores['Keywords'][tier][cat] +
                component_scores['FundFamily'][tier][cat] +
                component_scores['Categories'][tier][cat]
            )

    # Step 5: Score Metadata
    metadata_scores = score_metadata(row, METADATA_WEIGHT)

    # Step 6: Determine Predicted Category
    if all(score == 0 for score in final_scores.values()):
        predicted_category = "Unclassified"
    else:
        predicted_category = max(final_scores, key=final_scores.get)

    # Debugging: Print scores and predicted category for verification
    if row['SymbolCUSIP'] in ['RORO', 'TFPN']:
        print(f"{row['SymbolCUSIP']}: final_scores = {final_scores}")
        print(f"{row['SymbolCUSIP']}: predicted_category = {predicted_category}")

    # Step 7: Prepare Output as a pandas Series
    result = {'Return_Category': predicted_category}
    
    # Add tier-specific scores
    for tier in TIER_WEIGHTS:
        for cat in RETURN_CATEGORIES:
            result[f"{tier}_{cat}_Score"] = tier_scores[tier][cat]
    
    # Add metadata scores
    for cat in RETURN_CATEGORIES:
        result[f"Metadata_{cat}_Score"] = metadata_scores[cat]

    return pd.Series(result)

# --- Apply Classification ---
result_cols = (
    ['Return_Category'] +
    [f"{tier}_{comp}_{cat}_Score" for tier in TIER_WEIGHTS for comp in ['Keywords', 'FundFamily', 'Categories'] for cat in RETURN_CATEGORIES] +
    [f"{tier}_Total_{cat}_Score" for tier in TIER_WEIGHTS for cat in RETURN_CATEGORIES] +
    [f"Metadata_{cat}_Score" for cat in RETURN_CATEGORIES] +
    [f"Final_{cat}_Score" for cat in RETURN_CATEGORIES]
)
df[result_cols] = df.apply(classify_return, axis=1)

# --- Prepare Output ---
output_cols = [
    'SymbolCUSIP', 'ProductName', 'fund_family', 'Return_Category', 'ycharts_url',
    'Shop_Style', 'Likely_Fund_Type'] + [col for col in df.columns if '_Score' in col] + [
    'investment_strategy', 'FS_insight', 'index_fund', 'inverse_fund', 'leveraged_fund', 'socially_responsible_fund',
    'synthetic_replication_fund', 'fund_of_funds', 'Broad_Asset_Class_Name', 'Broad_Category_Name',
    'Global_Category_Name', 'Category_Name', 'CWA_Broad_Category_Name'
]
df[output_cols].to_excel('classified_return_funds_v5.xlsx', index=False)
print("Classification complete. Results saved to 'classified_return_funds_v5.xlsx'.")
# Out:
# Classification complete. Results saved to 'classified_return_funds_v5.xlsx'.

# %%
# Version 5, enhanced with granular scoring output, integrated FundFamilyData distributions,
# increased keyword weight, and updated keyword and category lookup lists.

import pandas as pd
from sqlalchemy import create_engine

"""
classify_return_drivers.py (V5 - Updated Keywords & Category Lookup)

Classifies investment funds into return generation strategies:
- Index Based
- Factor/Smart Beta
- Active Discretionary
- Quant/Systematic
- Multi-Strategy

Enhancements:
- Uses FundFamilyData distribution fields for scoring fund family signals.
- Increased KEYWORDS_WEIGHT to 50.
- Updated keyword lists (high, medium, low) for improved matching.
- Updated CATEGORY_LOOKUP (High tier portion updated as provided).
"""

# --- Tunable Parameters and Dry Run Switches ---
TIER_CAP = 100
FUND_FAMILY_WEIGHT = 40
KEYWORDS_WEIGHT = 70    # Increased to 50
CATEGORIES_WEIGHT = 15
METADATA_WEIGHT = 15
HIGH_CONF_THRESHOLD = 50
LIKELY_FUND_TYPE_WEIGHT = 0.5
DRY_RUN = False
TEST_FUNDS = ["VOO", "DFSVX", "BSIIX", "IVV", "FBALX", "LCEAX", "JSMBX"]

# We'll continue to use tier weights for keywords and categories.
TIER_WEIGHTS = {"High": 1.0, "Medium": 0.5, "Low": 0.25}

# --- Constants ---
RETURN_CATEGORIES = ["Index Based", "Factor/Smart Beta", "Active Discretionary", "Quant/Systematic", "Multi-Strategy"]

# --- Updated Keyword Lists ---
high_conf_keywords = {
    "Index Based": [
        "index fund", "tracks", "replicates", "indexed", "underlying index",
        "thematic", "passive", "economic characteristics that are substantially"
    ],
    "Factor/Smart Beta": [
        "rules-based", "factor-based", "factor tilt", "multi-factor", "factor investing",
        "momentum", "low volatility", "low vol", "value factor", "quality", "quality factor",
        "free cash flow", "fcf", "factor", "objective", "time tested", "relatively", "go up",
        "certain fundamental metrics", "momentum index", "quality index", "relatively lower valuations",
        "factors", "minimum volatility", "high dividend yield"
    ],
    "Active Discretionary": [
        "actively managed", "actively-managed", "manager believes", "manager's judgment",
        "active bottom‑up", "active strategy", "discretionary", "active management", "active-management"
    ],
    "Quant/Systematic": [
        "quantitative", "algorithm-driven", "systematic", "levered", "algorithm", "implied volatility"
    ],
    "Multi-Strategy": [
        "multi-strategy", "multi-asset", "hybrid strategy"
    ]
}

med_conf_keywords = {
    "Index Based": [
        "bond index", "market-cap weighted", "low tracking error", "high correlation", "benchmark",
        "low-cost", "broad market exposure", "passive", "aggregate bond", "passive", "broad"
    ],
    "Factor/Smart Beta": [
        "enhanced index", "revenue weighted", "dividend weighted", "enhanced returns", "thematic",
        "fundamental weighting", "yield weighted", "quality factor", "low volatility", "rotation",
        "rules based methodology", "cash cows", "alphaDEX", "ranked", "lower volatility"
    ],
    "Active Discretionary": [
        "machine learning", "ai", "research-driven", "fundamental", "strategically",
        "tactical allocation", "active", "rotation"
    ],
    "Quant/Systematic": [
        "data-driven", "systematic", "backtested", "long-short", "model-based", "rotation"
    ],
    "Multi-Strategy": [
        "multi-manager", "dynamic allocation", "multi-asset", "absolute return", "blended"
    ]
}

low_conf_keywords = {
    "Index Based": [
        "index", "mirrors", "equal-weighted", "bond index", "beta", "etf", "value index", "growth index"
    ],
    "Factor/Smart Beta": [
        "fundamental weighting", "enhanced index", "thematic", "tilt", "optimized", "component securities",
        "economic characteristics", "free cash flow yield", "objective", "high dividend yields",
        "ranking system", "consistantly increased dividends", "dividend", "dividend yield", "dividends",
        "strong cash", "low debt", "increasing earnings", "earnings", "rising dividend", "acheivers",
        "volatility weighted", "long/cash", "low beta", "low size"
    ],
    "Active Discretionary": [
        "discretionary", "judgment", "analysis", "outperform", "selection", "tactical",
        "trend-following", "trend following"
    ],
    "Quant/Systematic": [
        "quantitative", "algorithm", "statistical", "rules-driven", "trend-following",
        "trend following", "tactical"
    ],
    "Multi-Strategy": [
        "combination", "hybrid", "multi-asset", "flexible", "alternative"
    ]
}

# --- Updated Category Lookup ---
CATEGORY_LOOKUP = {
    "High": {
        "Defined Outcome": {"Quant/Systematic": 15},
        "Quantitative/Tactical": {"Quant/Systematic": 15},
        "Trading/Tactical": {"Quant/Systematic": 10},
        "Digital Asset": {"Index Based": 15},
        "Currency": {"Index Based": 15},
        "Target Maturity": {"Index Based": 15},
        "Systematic Trend": {"Quant/Systematic": 15}
    },
    # Medium and Low tiers remain as before (or update as needed)
    "Medium": {
        "Bond Strategy": {"Active Discretionary": 5, "Factor/Smart Beta": 5, "Quant/Systematic": 5},
        "Trading Tools": {"Quant/Systematic": 10},
        "Trading": {"Quant/Systematic": 10},
        "Target Date": {"Active Discretionary": 5, "Index Based": 2, "Multi-Strategy": 8},
        "Options Trading": {"Active Discretionary": 5, "Factor/Smart Beta": 5, "Quant/Systematic": 5},
        "Long/Short Equity": {"Active Discretionary": 5, "Quant/Systematic": 5},
        "Commodities": {"Active Discretionary": 4, "Factor/Smart Beta": 1, "Quant/Systematic": 4, "Index Based": 4, "Multi-Strategy": 1},
        "Municipal": {"Active Discretionary": 6, "Factor/Smart Beta": 2, "Index Based": 6, "Multi-Strategy": 1},
        "Derivative Income": {"Active Discretionary": 5, "Quant/Systematic": 4, "Factor/Smart Beta": 2, "Index Based": 4},
        "Event Driven": {"Active Discretionary": 8, "Quant/Systematic": 7},
        "Inflation-Protected Bond": {"Active Discretionary": 6, "Index Based": 9}
    },
    "Low": {
        "Multialternative": {"Quant/Systematic": 7, "Active Discretionary": 8},
        "Specialty": {"Multi-Strategy": 4, "Quant/Systematic": 4, "Active Discretionary": 5},
        "Strategic": {"Multi-Strategy": 4, "Quant/Systematic": 4, "Active Discretionary": 5},
        "Nontraditional": {"Multi-Strategy": 2, "Quant/Systematic": 3, "Active Discretionary": 3, "Factor/Smart Beta": 3},
        "Equity Hedged": {"Active Discretionary": 5, "Quant/Systematic": 3, "Factor/Smart Beta": 2, "Index Based": 5},
        "Multisector Bond": {"Active Discretionary": 5, "Quant/Systematic": 3, "Factor/Smart Beta": 2, "Index Based": 5},
        "Nontraditional Bond": {"Active Discretionary": 5, "Quant/Systematic": 3, "Factor/Smart Beta": 2, "Index Based": 5}
    }
}

# --- Database Connection ---
connection_string = (
    "mssql+pyodbc://JULIANS_LAPTOP\\SQLEXPRESS/"
    "CWA_Fund_Database?driver=ODBC+Driver+18+for+SQL+Server"
    "&trusted_connection=yes&TrustServerCertificate=yes"
)
engine = create_engine(connection_string)

# --- SQL Query ---
query = """
SELECT 
    fs.SymbolCUSIP, fs.ProductName, fs.fund_family, fs.investment_strategy, fs.FS_insight,
    fs.index_fund, fs.inverse_fund, fs.leveraged_fund, fs.socially_responsible_fund,
    fs.synthetic_replication_fund, fs.fund_of_funds, fs.ycharts_url,
    yc_ba.Broad_Asset_Class_Name, yc_bc.Broad_Category_Name, yc_gc.Global_Category_Name,
    yc_c.Category_Name, cwa_bc.CWA_Broad_Category_Name,
    ff.Dist_Index, ff.Dist_Active, ff.Dist_Rules_Based, ff.Dist_Quant, ff.Dist_Multi
FROM Funds_to_Screen fs
LEFT JOIN FundFamilyData ff ON fs.fund_family = ff.[Fund Family Name]
LEFT JOIN YC_Broad_Asset_Class_List yc_ba ON fs.YC_Broad_Asset_Class_ID = yc_ba.ID
LEFT JOIN YC_Broad_Category_List yc_bc ON fs.YC_Broad_Category_ID = yc_bc.ID
LEFT JOIN YC_Global_Category_List yc_gc ON fs.YC_Global_Category_ID = yc_gc.ID
LEFT JOIN YC_Category_List yc_c ON fs.YC_Category_ID = yc_c.ID
LEFT JOIN CWA_Broad_Category_List cwa_bc ON fs.CWA_Broad_Category_ID = cwa_bc.ID
"""
df = pd.read_sql(query, engine)

if DRY_RUN:
    df = df[df['SymbolCUSIP'].isin(TEST_FUNDS)]

# --- Function Definitions ---

def score_keywords(text, keyword_dict, max_points):
    scores = {cat: 0 for cat in RETURN_CATEGORIES}
    for category, keywords in keyword_dict.items():
        hits = sum(keyword in text for keyword in keywords)
        if len(keywords) > 0:
            scores[category] = min(hits * (max_points / len(keywords)), max_points)
    return scores

def score_categories(row, tier_dict, max_points):
    category_cols = ['Broad_Asset_Class_Name', 'Broad_Category_Name', 'Global_Category_Name', 'Category_Name', 'CWA_Broad_Category_Name']
    scores = {cat: 0 for cat in RETURN_CATEGORIES}
    for col in category_cols:
        if pd.notna(row[col]):
            value = row[col].lower()
            for keyword, weights in tier_dict.items():
                if keyword in value:
                    for cat, points in weights.items():
                        scores[cat] += points
    for cat in scores:
        scores[cat] = min(scores[cat], max_points)
    return scores

def score_metadata(row, max_points):
    # Retained for reference; metadata bonus not added to final score.
    scores = {cat: 0 for cat in RETURN_CATEGORIES}
    if row['index_fund'] == 'True':
        scores["Index Based"] += max_points
    if row['leveraged_fund'] == 'True' or row['inverse_fund'] == 'True':
        scores["Quant/Systematic"] += max_points / 2
    if row['fund_of_funds'] == 'True':
        scores["Active Discretionary"] += max_points / 3
        scores["Factor/Smart Beta"] += max_points / 3
        scores["Index Based"] += max_points / 3
    return scores

def score_fund_family(row, max_points):
    """
    Updated scoring for Fund Family using FundFamilyData distribution columns.
    Expected columns from FundFamilyData join:
      - Dist_Index, Dist_Active, Dist_Rules_Based, Dist_Quant, Dist_Multi
    Returns a dictionary with bonus scores for each category.
    """
    scores = {cat: 0 for cat in RETURN_CATEGORIES}
    try:
        dist_index = float(row.get('Dist_Index', 0))
        dist_active = float(row.get('Dist_Active', 0))
        dist_rules_based = float(row.get('Dist_Rules_Based', 0))
        dist_quant = float(row.get('Dist_Quant', 0))
        dist_multi = float(row.get('Dist_Multi', 0))
    except Exception:
        dist_index = dist_active = dist_rules_based = dist_quant = dist_multi = 0

    scores["Index Based"] += (dist_index / 100.0) * max_points
    scores["Active Discretionary"] += (dist_active / 100.0) * max_points
    scores["Factor/Smart Beta"] += (dist_rules_based / 100.0) * max_points
    scores["Quant/Systematic"] += (dist_quant / 100.0) * max_points
    scores["Multi-Strategy"] += (dist_multi / 100.0) * max_points

    if (dist_index + dist_active + dist_rules_based + dist_quant + dist_multi) == 0:
        scores["Active Discretionary"] += max_points * 0.5

    return scores

def classify_return(row):
    # Combine text fields (lowercased)
    product_name = row['ProductName'].lower() if pd.notna(row['ProductName']) else ""
    investment_strategy = row['investment_strategy'].lower() if pd.notna(row['investment_strategy']) else ""
    fs_insight = row['FS_insight'].lower() if pd.notna(row['FS_insight']) else ""
    text = product_name + " " + investment_strategy + " " + fs_insight

    # --- Compute Tiered Scores for Keywords and Categories ---
    keywords_scores = {tier: score_keywords(text, kw_dict, KEYWORDS_WEIGHT)
                       for tier, kw_dict in zip(TIER_WEIGHTS, [high_conf_keywords, med_conf_keywords, low_conf_keywords])}
    categories_scores = {tier: score_categories(row, CATEGORY_LOOKUP[tier], CATEGORIES_WEIGHT)
                         for tier in TIER_WEIGHTS}

    tier_total_scores = {cat: 0 for cat in RETURN_CATEGORIES}
    for tier in TIER_WEIGHTS:
        for cat in RETURN_CATEGORIES:
            tier_total_scores[cat] += keywords_scores[tier][cat] + categories_scores[tier][cat]
    
    # --- (Metadata scores are computed but not added to final score) ---
    # metadata_scores = score_metadata(row, METADATA_WEIGHT)
    # for cat in RETURN_CATEGORIES:
    #     tier_total_scores[cat] += metadata_scores[cat]
    
    # --- Fund Family Scores (using new distribution) ---
    fund_family_scores = score_fund_family(row, FUND_FAMILY_WEIGHT)
    for cat in RETURN_CATEGORIES:
        tier_total_scores[cat] += fund_family_scores[cat]

    # --- Decision Tree Rules Adjustments ---
    decision_scores = {cat: 0 for cat in RETURN_CATEGORIES}

    def to_bool(val):
        return str(val).strip().lower() in ["true", "1"]

    index_flag          = to_bool(row.get("index_fund", False))
    esg_flag            = to_bool(row.get("socially_responsible_fund", False))
    leveraged_flag      = to_bool(row.get("leveraged_fund", False))
    synthetic_flag      = to_bool(row.get("synthetic_replication_fund", False))
    currency_hedged_flag = to_bool(row.get("currency_hedged_fund", False))
    fund_of_funds_flag  = to_bool(row.get("fund_of_funds", False))

    # 1. Index Flag Bonus:
    # For any indexed fund, add a balanced bonus: +50 to "Index Based" and +50 to "Factor/Smart Beta."
    if index_flag:
        decision_scores["Index Based"] += 50
        decision_scores["Factor/Smart Beta"] += 50
    # Additional bonus: if index and any of (esg, leveraged, synthetic) then add extra +100 to "Index Based."
    if index_flag and (esg_flag or leveraged_flag or synthetic_flag):
        decision_scores["Index Based"] += 100
    # 2. No Index Classification: If not index, eliminate Index Based.
    if not index_flag:
        decision_scores["Index Based"] = -9999
    # 3. Fund of Funds:
    if fund_of_funds_flag:
        if index_flag:
            decision_scores["Active Discretionary"] -= 100
            decision_scores["Quant/Systematic"] -= 100
        else:
            decision_scores["Active Discretionary"] += 30
            decision_scores["Quant/Systematic"] += 10
            decision_scores["Multi-Strategy"] += 20
    # 4. Currency Hedged:
    if currency_hedged_flag:
        decision_scores["Factor/Smart Beta"] = -9999
        decision_scores["Active Discretionary"] += 20
        decision_scores["Index Based"] += 20
    # 5. Socially Responsible (ESG):
    if esg_flag:
        decision_scores["Factor/Smart Beta"] = -9999
    # 6. Leveraged or Synthetic with Index:
    if index_flag and (leveraged_flag or synthetic_flag):
        decision_scores["Active Discretionary"] = -9999
        decision_scores["Multi-Strategy"] = -9999
        decision_scores["Quant/Systematic"] = -9999
        decision_scores["Factor/Smart Beta"] = -9999
        decision_scores["Index Based"] += 50

    # --- Category-Based Decision Rules ---
    category_text = ""
    for col in ['Broad_Asset_Class_Name', 'Broad_Category_Name', 'Global_Category_Name', 'Category_Name', 'CWA_Broad_Category_Name']:
        if pd.notna(row[col]):
            category_text += " " + row[col].lower()

    if "defined outcome" in category_text:
        decision_scores["Quant/Systematic"] += 100
    if "target maturity" in category_text:
        decision_scores["Index Based"] += 100
    trading_keywords = ["trading tools", "trading/tactical"]
    trading_categories = ["trading--inverse commodities", "trading--inverse debt", "trading--inverse equity",
                          "trading--leveraged commodities", "trading--leveraged debt", "trading--leveraged equity", "trading--miscellaneous"]
    if any(kw in category_text for kw in trading_keywords) or any(tc in category_text for tc in trading_categories):
        decision_scores["Quant/Systematic"] += 100
    if "target date" in category_text or "target-date" in category_text:
        decision_scores["Factor/Smart Beta"] = -9999
        decision_scores["Quant/Systematic"] = -9999
    if "digital asset" in category_text or "currency" in category_text:
        decision_scores["Index Based"] += 100
    if "commodity" in category_text:
        decision_scores["Factor/Smart Beta"] = -9999
    if "single stock" in category_text:
        decision_scores["Index Based"] += 100
    if "municipal" in category_text:
        decision_scores["Multi-Strategy"] = -9999
    if "systematic trend" in category_text:
        decision_scores["Quant/Systematic"] += 100
    if ("long/short equity" in category_text or "event driven" in category_text) and not index_flag:
        decision_scores["Active Discretionary"] += 50
        decision_scores["Quant/Systematic"] += 50
    if "inflation-protected bond" in category_text:
        decision_scores["Active Discretionary"] += 50
        decision_scores["Index Based"] += 50

    # --- Active Management Variants ---
    active_management_terms = [
        "actively managed",
        "actively-managed",
        "active management",
        "active bottom‑up approach",
        "actively trades",
        "active management strategy",
        "actively managed etf",
        "actively managed fund of funds",
        "actively managed strategy",
        "active allocation",
        "actively allocates",
        "tactically allocates assets",
        "active trading",
        "trade securities actively",
        "active trading strategy",
        "bottom‑up approach"
    ]
    for term in active_management_terms:
        if term in text:
            decision_scores["Active Discretionary"] += 100
            break

    # --- Combine All Scores ---
    final_combined_scores = {cat: tier_total_scores.get(cat, 0) + decision_scores.get(cat, 0)
                             for cat in RETURN_CATEGORIES}
    viable_scores = {cat: score for cat, score in final_combined_scores.items() if score > -9999}
    if not viable_scores:
        predicted_category = "Unclassified"
    else:
        predicted_category = max(viable_scores, key=viable_scores.get)

    # --- Prepare Output ---
    result = {'Return_Category': predicted_category}
    for cat in RETURN_CATEGORIES:
        result[f"Final_{cat}_Score"] = final_combined_scores[cat]

    return pd.Series(result)

# --- Apply Classification ---
result_cols = ['Return_Category'] + [f"Final_{cat}_Score" for cat in RETURN_CATEGORIES]
df[result_cols] = df.apply(classify_return, axis=1)

# --- Prepare Output Excel File ---
output_cols = [
    'SymbolCUSIP', 'ProductName', 'fund_family', 'Return_Category', 'ycharts_url'
] + [col for col in df.columns if 'Score' in col] + [
    'investment_strategy', 'FS_insight', 'index_fund', 'inverse_fund', 'leveraged_fund', 'socially_responsible_fund',
    'synthetic_replication_fund', 'fund_of_funds', 'Broad_Asset_Class_Name', 'Broad_Category_Name',
    'Global_Category_Name', 'Category_Name', 'CWA_Broad_Category_Name'
]
df[output_cols].to_excel('classified_return_funds_v5.xlsx', index=False)
print("Classification complete. Results saved to 'classified_return_funds_v5.xlsx'.")
# Out:
# Classification complete. Results saved to 'classified_return_funds_v5.xlsx'.

# %%
# Version 6: Enhanced with updated FundFamilyData distributions, increased keyword weight,
# and adjusted decision tree bonuses (metadata bonus removed)

import pandas as pd
from sqlalchemy import create_engine

"""
classify_return_drivers.py (V6)

Classifies investment funds into return generation strategies:
- Index Based
- Factor/Smart Beta
- Active Discretionary
- Quant/Systematic
- Multi-Strategy

Enhancements in V6:
- Uses FundFamilyData distribution fields (Dist_Index, Dist_Active, Dist_Rules_Based, Dist_Quant, Dist_Multi)
  for scoring fund family signals.
- KEYWORDS_WEIGHT is increased to 50.
- Metadata bonus points are removed.
- Decision-tree adjustments:
    * If index_fund is true, a balanced bonus of +50 is added to "Index Based" and +50 to "Factor/Smart Beta."
    * Additionally, if index_fund is true and any of (esg, leveraged, synthetic) flags are true, an extra +100 is added to "Index Based."
- All other scoring components (keywords, category lookup) remain as before.
"""

# --- Tunable Parameters and Dry Run Switches ---
TIER_CAP = 100
FUND_FAMILY_WEIGHT = 40
KEYWORDS_WEIGHT = 50    # Increased to 50
CATEGORIES_WEIGHT = 15
# METADATA_WEIGHT is defined but its scores will not be added.
METADATA_WEIGHT = 15
HIGH_CONF_THRESHOLD = 50
LIKELY_FUND_TYPE_WEIGHT = 0.5
DRY_RUN = False
TEST_FUNDS = ["VOO", "DFSVX", "BSIIX", "IVV", "FBALX", "LCEAX", "JSMBX"]

# We'll continue to use tier weights for keywords and categories.
TIER_WEIGHTS = {"High": 1.0, "Medium": 0.5, "Low": 0.25}

# --- Constants ---
RETURN_CATEGORIES = ["Index Based", "Factor/Smart Beta", "Active Discretionary", "Quant/Systematic", "Multi-Strategy"]

# --- Updated Keyword Lists ---
high_conf_keywords = {
    "Index Based": [
        "index fund", "tracks", "replicates", "indexed", "underlying index",
        "thematic", "passive", "economic characteristics that are substantially"
    ],
    "Factor/Smart Beta": [
        "rules-based", "factor-based", "factor tilt", "multi-factor", "factor investing",
        "momentum", "low volatility", "low vol", "value factor", "quality", "quality factor",
        "free cash flow", "fcf", "factor", "objective", "time tested", "relatively", "go up",
        "certain fundamental metrics", "momentum index", "quality index", "relatively lower valuations",
        "factors", "minimum volatility", "high dividend yield"
    ],
    "Active Discretionary": [
        "actively managed", "actively-managed", "manager believes", "manager's judgment",
        "active bottom‑up", "active strategy", "discretionary", "active management", "active-management"
    ],
    "Quant/Systematic": [
        "quantitative", "algorithm-driven", "systematic", "levered", "algorithm", "implied volatility"
    ],
    "Multi-Strategy": [
        "multi-strategy", "multi-asset", "hybrid strategy"
    ]
}

med_conf_keywords = {
    "Index Based": [
        "bond index", "market-cap weighted", "low tracking error", "high correlation", "benchmark",
        "low-cost", "broad market exposure", "passive", "aggregate bond", "passive", "broad"
    ],
    "Factor/Smart Beta": [
        "enhanced index", "revenue weighted", "dividend weighted", "enhanced returns", "thematic",
        "fundamental weighting", "yield weighted", "quality factor", "low volatility", "rotation",
        "rules based methodology", "cash cows", "alphaDEX", "ranked", "lower volatility"
    ],
    "Active Discretionary": [
        "machine learning", "ai", "research-driven", "fundamental", "strategically",
        "tactical allocation", "active", "rotation"
    ],
    "Quant/Systematic": [
        "data-driven", "systematic", "backtested", "long-short", "model-based", "rotation"
    ],
    "Multi-Strategy": [
        "multi-manager", "dynamic allocation", "multi-asset", "absolute return", "blended"
    ]
}

low_conf_keywords = {
    "Index Based": [
        "index", "mirrors", "equal-weighted", "bond index", "beta", "etf", "value index", "growth index"
    ],
    "Factor/Smart Beta": [
        "fundamental weighting", "enhanced index", "thematic", "tilt", "optimized", "component securities",
        "economic characteristics", "free cash flow yield", "objective", "high dividend yields",
        "ranking system", "consistantly increased dividends", "dividend", "dividend yield", "dividends",
        "strong cash", "low debt", "increasing earnings", "earnings", "rising dividend", "acheivers",
        "volatility weighted", "long/cash", "low beta", "low size"
    ],
    "Active Discretionary": [
        "discretionary", "judgment", "analysis", "outperform", "selection", "tactical",
        "trend-following", "trend following"
    ],
    "Quant/Systematic": [
        "quantitative", "algorithm", "statistical", "rules-driven", "trend-following",
        "trend following", "tactical"
    ],
    "Multi-Strategy": [
        "combination", "hybrid", "multi-asset", "flexible", "alternative"
    ]
}

# --- Updated Category Lookup ---
CATEGORY_LOOKUP = {
    "High": {
        "Defined Outcome": {"Quant/Systematic": 15},
        "Quantitative/Tactical": {"Quant/Systematic": 15},
        "Trading/Tactical": {"Quant/Systematic": 10},
        "Digital Asset": {"Index Based": 15},
        "Currency": {"Index Based": 15},
        "Target Maturity": {"Index Based": 15},
        "Systematic Trend": {"Quant/Systematic": 15}
    },
    "Medium": {
        "Bond Strategy": {"Active Discretionary": 5, "Factor/Smart Beta": 5, "Quant/Systematic": 5},
        "Trading Tools": {"Quant/Systematic": 10},
        "Trading": {"Quant/Systematic": 10},
        "Target Date": {"Active Discretionary": 5, "Index Based": 2, "Multi-Strategy": 8},
        "Options Trading": {"Active Discretionary": 5, "Factor/Smart Beta": 5, "Quant/Systematic": 5},
        "Long/Short Equity": {"Active Discretionary": 5, "Quant/Systematic": 5},
        "Commodities": {"Active Discretionary": 4, "Factor/Smart Beta": 1, "Quant/Systematic": 4, "Index Based": 4, "Multi-Strategy": 1},
        "Municipal": {"Active Discretionary": 6, "Factor/Smart Beta": 2, "Index Based": 6, "Multi-Strategy": 1},
        "Derivative Income": {"Active Discretionary": 5, "Quant/Systematic": 4, "Factor/Smart Beta": 2, "Index Based": 4},
        "Event Driven": {"Active Discretionary": 8, "Quant/Systematic": 7},
        "Inflation-Protected Bond": {"Active Discretionary": 6, "Index Based": 9}
    },
    "Low": {
        "Multialternative": {"Quant/Systematic": 7, "Active Discretionary": 8},
        "Specialty": {"Multi-Strategy": 4, "Quant/Systematic": 4, "Active Discretionary": 5},
        "Strategic": {"Multi-Strategy": 4, "Quant/Systematic": 4, "Active Discretionary": 5},
        "Nontraditional": {"Multi-Strategy": 2, "Quant/Systematic": 3, "Active Discretionary": 3, "Factor/Smart Beta": 3},
        "Equity Hedged": {"Active Discretionary": 5, "Quant/Systematic": 3, "Factor/Smart Beta": 2, "Index Based": 5},
        "Multisector Bond": {"Active Discretionary": 5, "Quant/Systematic": 3, "Factor/Smart Beta": 2, "Index Based": 5},
        "Nontraditional Bond": {"Active Discretionary": 5, "Quant/Systematic": 3, "Factor/Smart Beta": 2, "Index Based": 5}
    }
}

# --- Database Connection ---
connection_string = (
    "mssql+pyodbc://JULIANS_LAPTOP\\SQLEXPRESS/"
    "CWA_Fund_Database?driver=ODBC+Driver+18+for+SQL+Server"
    "&trusted_connection=yes&TrustServerCertificate=yes"
)
engine = create_engine(connection_string)

# --- SQL Query ---
query = """
SELECT 
    fs.SymbolCUSIP, fs.ProductName, fs.fund_family, fs.investment_strategy, fs.FS_insight,
    fs.index_fund, fs.inverse_fund, fs.leveraged_fund, fs.socially_responsible_fund,
    fs.synthetic_replication_fund, fs.fund_of_funds, fs.ycharts_url,
    yc_ba.Broad_Asset_Class_Name, yc_bc.Broad_Category_Name, yc_gc.Global_Category_Name,
    yc_c.Category_Name, cwa_bc.CWA_Broad_Category_Name,
    ff.Dist_Index, ff.Dist_Active, ff.Dist_Rules_Based, ff.Dist_Quant, ff.Dist_Multi
FROM Funds_to_Screen fs
LEFT JOIN FundFamilyData ff ON fs.fund_family = ff.[Fund_Family_Name]
LEFT JOIN YC_Broad_Asset_Class_List yc_ba ON fs.YC_Broad_Asset_Class_ID = yc_ba.ID
LEFT JOIN YC_Broad_Category_List yc_bc ON fs.YC_Broad_Category_ID = yc_bc.ID
LEFT JOIN YC_Global_Category_List yc_gc ON fs.YC_Global_Category_ID = yc_gc.ID
LEFT JOIN YC_Category_List yc_c ON fs.YC_Category_ID = yc_c.ID
LEFT JOIN CWA_Broad_Category_List cwa_bc ON fs.CWA_Broad_Category_ID = cwa_bc.ID
"""
df = pd.read_sql(query, engine)

if DRY_RUN:
    df = df[df['SymbolCUSIP'].isin(TEST_FUNDS)]

# --- Function Definitions ---

def score_keywords(text, keyword_dict, max_points):
    scores = {cat: 0 for cat in RETURN_CATEGORIES}
    for category, keywords in keyword_dict.items():
        hits = sum(keyword in text for keyword in keywords)
        if len(keywords) > 0:
            scores[category] = min(hits * (max_points / len(keywords)), max_points)
    return scores

def score_categories(row, tier_dict, max_points):
    category_cols = ['Broad_Asset_Class_Name', 'Broad_Category_Name', 'Global_Category_Name', 'Category_Name', 'CWA_Broad_Category_Name']
    scores = {cat: 0 for cat in RETURN_CATEGORIES}
    for col in category_cols:
        if pd.notna(row[col]):
            value = row[col].lower()
            for keyword, weights in tier_dict.items():
                if keyword in value:
                    for cat, points in weights.items():
                        scores[cat] += points
    for cat in scores:
        scores[cat] = min(scores[cat], max_points)
    return scores

def score_metadata(row, max_points):
    # Retained for reference; metadata bonus not added to final score.
    scores = {cat: 0 for cat in RETURN_CATEGORIES}
    if row['index_fund'] == 'True':
        scores["Index Based"] += max_points
    if row['leveraged_fund'] == 'True' or row['inverse_fund'] == 'True':
        scores["Quant/Systematic"] += max_points / 2
    if row['fund_of_funds'] == 'True':
        scores["Active Discretionary"] += max_points / 3
        scores["Factor/Smart Beta"] += max_points / 3
        scores["Index Based"] += max_points / 3
    return scores

def score_fund_family(row, max_points):
    """
    Updated scoring for Fund Family using FundFamilyData distribution columns.
    Expected columns from FundFamilyData join:
      - Dist_Index, Dist_Active, Dist_Rules_Based, Dist_Quant, Dist_Multi
    Returns a dictionary with bonus scores for each category.
    """
    scores = {cat: 0 for cat in RETURN_CATEGORIES}
    try:
        dist_index = float(row.get('Dist_Index', 0))
        dist_active = float(row.get('Dist_Active', 0))
        dist_rules_based = float(row.get('Dist_Rules_Based', 0))
        dist_quant = float(row.get('Dist_Quant', 0))
        dist_multi = float(row.get('Dist_Multi', 0))
    except Exception:
        dist_index = dist_active = dist_rules_based = dist_quant = dist_multi = 0

    scores["Index Based"] += (dist_index / 100.0) * max_points
    scores["Active Discretionary"] += (dist_active / 100.0) * max_points
    scores["Factor/Smart Beta"] += (dist_rules_based / 100.0) * max_points
    scores["Quant/Systematic"] += (dist_quant / 100.0) * max_points
    scores["Multi-Strategy"] += (dist_multi / 100.0) * max_points

    if (dist_index + dist_active + dist_rules_based + dist_quant + dist_multi) == 0:
        scores["Active Discretionary"] += max_points * 0.5

    return scores

def classify_return(row):
    # Combine text fields (lowercased)
    product_name = row['ProductName'].lower() if pd.notna(row['ProductName']) else ""
    investment_strategy = row['investment_strategy'].lower() if pd.notna(row['investment_strategy']) else ""
    fs_insight = row['FS_insight'].lower() if pd.notna(row['FS_insight']) else ""
    text = product_name + " " + investment_strategy + " " + fs_insight

    # --- Compute Tiered Scores for Keywords and Categories ---
    keywords_scores = {tier: score_keywords(text, kw_dict, KEYWORDS_WEIGHT)
                       for tier, kw_dict in zip(TIER_WEIGHTS, [high_conf_keywords, med_conf_keywords, low_conf_keywords])}
    categories_scores = {tier: score_categories(row, CATEGORY_LOOKUP[tier], CATEGORIES_WEIGHT)
                         for tier in TIER_WEIGHTS}

    tier_total_scores = {cat: 0 for cat in RETURN_CATEGORIES}
    for tier in TIER_WEIGHTS:
        for cat in RETURN_CATEGORIES:
            tier_total_scores[cat] += keywords_scores[tier][cat] + categories_scores[tier][cat]
    
    # --- (Metadata scores are computed but not added to final score) ---
    # metadata_scores = score_metadata(row, METADATA_WEIGHT)
    # for cat in RETURN_CATEGORIES:
    #     tier_total_scores[cat] += metadata_scores[cat]
    
    # --- Fund Family Scores (using new distribution) ---
    fund_family_scores = score_fund_family(row, FUND_FAMILY_WEIGHT)
    for cat in RETURN_CATEGORIES:
        tier_total_scores[cat] += fund_family_scores[cat]

    # --- Decision Tree Rules Adjustments ---
    decision_scores = {cat: 0 for cat in RETURN_CATEGORIES}

    def to_bool(val):
        return str(val).strip().lower() in ["true", "1"]

    index_flag          = to_bool(row.get("index_fund", False))
    esg_flag            = to_bool(row.get("socially_responsible_fund", False))
    leveraged_flag      = to_bool(row.get("leveraged_fund", False))
    synthetic_flag      = to_bool(row.get("synthetic_replication_fund", False))
    currency_hedged_flag = to_bool(row.get("currency_hedged_fund", False))
    fund_of_funds_flag  = to_bool(row.get("fund_of_funds", False))

    # 1. Index Flag Bonus:
    # For any indexed fund, add a balanced bonus: +50 to "Index Based" and +50 to "Factor/Smart Beta."
    if index_flag:
        decision_scores["Index Based"] += 50
        decision_scores["Factor/Smart Beta"] += 50
    # Additional bonus: if index and any of (esg, leveraged, synthetic) then add extra +100 to "Index Based."
    if index_flag and (esg_flag or leveraged_flag or synthetic_flag):
        decision_scores["Index Based"] += 100
    # 2. No Index Classification: If not index, eliminate Index Based.
    if not index_flag:
        decision_scores["Index Based"] = -9999
    # 3. Fund of Funds:
    if fund_of_funds_flag:
        if index_flag:
            decision_scores["Active Discretionary"] -= 100
            decision_scores["Quant/Systematic"] -= 100
        else:
            decision_scores["Active Discretionary"] += 30
            decision_scores["Quant/Systematic"] += 10
            decision_scores["Multi-Strategy"] += 10
    # 4. Currency Hedged:
    if currency_hedged_flag:
        decision_scores["Factor/Smart Beta"] = -9999
        decision_scores["Active Discretionary"] += 20
        decision_scores["Index Based"] += 20
    # 5. Socially Responsible (ESG):
    if esg_flag:
        decision_scores["Factor/Smart Beta"] = -9999
    # 6. Leveraged or Synthetic with Index:
    if index_flag and (leveraged_flag or synthetic_flag):
        decision_scores["Active Discretionary"] = -9999
        decision_scores["Multi-Strategy"] = -9999
        decision_scores["Quant/Systematic"] = -9999
        decision_scores["Factor/Smart Beta"] = -9999
        decision_scores["Index Based"] += 50

    # --- Category-Based Decision Rules ---
    category_text = ""
    for col in ['Broad_Asset_Class_Name', 'Broad_Category_Name', 'Global_Category_Name', 'Category_Name', 'CWA_Broad_Category_Name']:
        if pd.notna(row[col]):
            category_text += " " + row[col].lower()

    if "defined outcome" in category_text:
        decision_scores["Quant/Systematic"] += 100
    if "target maturity" in category_text:
        decision_scores["Index Based"] += 100
    trading_keywords = ["trading tools", "trading/tactical"]
    trading_categories = ["trading--inverse commodities", "trading--inverse debt", "trading--inverse equity",
                          "trading--leveraged commodities", "trading--leveraged debt", "trading--leveraged equity", "trading--miscellaneous"]
    if any(kw in category_text for kw in trading_keywords) or any(tc in category_text for tc in trading_categories):
        decision_scores["Quant/Systematic"] += 100
    if "target date" in category_text or "target-date" in category_text:
        decision_scores["Factor/Smart Beta"] = -9999
        decision_scores["Quant/Systematic"] = -9999
    if "digital asset" in category_text or "currency" in category_text:
        decision_scores["Index Based"] += 100
    if "commodity" in category_text:
        decision_scores["Factor/Smart Beta"] = -9999
    if "single stock" in category_text:
        decision_scores["Index Based"] += 100
    if "municipal" in category_text:
        decision_scores["Multi-Strategy"] = -9999
    if "systematic trend" in category_text:
        decision_scores["Quant/Systematic"] += 100
    if ("long/short equity" in category_text or "event driven" in category_text) and not index_flag:
        decision_scores["Active Discretionary"] += 50
        decision_scores["Quant/Systematic"] += 50
    if "inflation-protected bond" in category_text:
        decision_scores["Active Discretionary"] += 50
        decision_scores["Index Based"] += 50

    # --- Active Management Variants ---
    active_management_terms = [
        "actively managed",
        "actively-managed",
        "active management",
        "active bottom‑up approach",
        "actively trades",
        "active management strategy",
        "actively managed etf",
        "actively managed fund of funds",
        "actively managed strategy",
        "active allocation",
        "actively allocates",
        "tactically allocates assets",
        "active trading",
        "trade securities actively",
        "active trading strategy",
        "bottom‑up approach"
    ]
    for term in active_management_terms:
        if term in text:
            decision_scores["Active Discretionary"] += 100
            break

    # --- Combine All Scores ---
    final_combined_scores = {cat: tier_total_scores.get(cat, 0) + decision_scores.get(cat, 0)
                             for cat in RETURN_CATEGORIES}
    viable_scores = {cat: score for cat, score in final_combined_scores.items() if score > -9999}
    if not viable_scores:
        predicted_category = "Unclassified"
    else:
        predicted_category = max(viable_scores, key=viable_scores.get)

    # --- Prepare Output ---
    result = {'Return_Category': predicted_category}
    for cat in RETURN_CATEGORIES:
        result[f"Final_{cat}_Score"] = final_combined_scores[cat]

    return pd.Series(result)

# --- Apply Classification ---
result_cols = ['Return_Category'] + [f"Final_{cat}_Score" for cat in RETURN_CATEGORIES]
df[result_cols] = df.apply(classify_return, axis=1)

# --- Prepare Output Excel File ---
output_cols = [
    'SymbolCUSIP', 'ProductName', 'fund_family', 'Return_Category', 'ycharts_url'
] + [col for col in df.columns if 'Score' in col] + [
    'investment_strategy', 'FS_insight', 'index_fund', 'inverse_fund', 'leveraged_fund', 'socially_responsible_fund',
    'synthetic_replication_fund', 'fund_of_funds', 'Broad_Asset_Class_Name', 'Broad_Category_Name',
    'Global_Category_Name', 'Category_Name', 'CWA_Broad_Category_Name'
]
df[output_cols].to_excel('classified_return_funds_v6.xlsx', index=False)
print("Classification complete. Results saved to 'classified_return_funds_v6.xlsx'.")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File ~\Software Projects\Database Administration\env\Lib\site-packages\sqlalchemy\engine\base.py:1964, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1963     if not evt_handled:
# -> 1964         self.dialect.do_execute(
#    1965             cursor, str_statement, effective_parameters, context
#    1966         )
#    1968 if self._has_events or self.engine._has_events:
#
# File ~\Software Projects\Database Administration\env\Lib\site-packages\sqlalchemy\engine\default.py:942, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     941 def do_execute(self, cursor, statement, parameters, context=None):
# --> 942     cursor.execute(statement, parameters)
#
# ProgrammingError: ('42S22', "[42S22] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Invalid column name 'Fund_Family_Name'. (207) (SQLExecDirectW); [42S22] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Invalid column name 'Broad_Asset_Class_Name'. (207)")
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[2], line 177
#     160 # --- SQL Query ---
#     161 query = """
#     162 SELECT
#     163     fs.SymbolCUSIP, fs.ProductName, fs.fund_family, fs.investment_strategy, fs.FS_insight,
#    (...)
#     175 LEFT JOIN CWA_Broad_Category_List cwa_bc ON fs.CWA_Broad_Category_ID = cwa_bc.ID
#     176 """
# --> 177 df = pd.read_sql(query, engine)
#     179 if DRY_RUN:
#     180     df = df[df['SymbolCUSIP'].isin(TEST_FUNDS)]
#
# File ~\Software Projects\Database Administration\env\Lib\site-packages\pandas\io\sql.py:734, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     724     return pandas_sql.read_table(
#     725         sql,
#     726         index_col=index_col,
#    (...)
#     731         dtype_backend=dtype_backend,
#     732     )
#     733 else:
# --> 734     return pandas_sql.read_query(
#     735         sql,
#     736         index_col=index_col,
#     737         params=params,
#     738         coerce_float=coerce_float,
#     739         parse_dates=parse_dates,
#     740         chunksize=chunksize,
#     741         dtype_backend=dtype_backend,
#     742         dtype=dtype,
#     743     )
#
# File ~\Software Projects\Database Administration\env\Lib\site-packages\pandas\io\sql.py:1836, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    1779 def read_query(
#    1780     self,
#    1781     sql: str,
#    (...)
#    1788     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    1789 ) -> DataFrame | Iterator[DataFrame]:
#    1790     """
#    1791     Read SQL query into a DataFrame.
#    1792
#    (...)
#    1834
#    1835     """
# -> 1836     result = self.execute(sql, params)
#    1837     columns = result.keys()
#    1839     if chunksize is not None:
#
# File ~\Software Projects\Database Administration\env\Lib\site-packages\pandas\io\sql.py:1659, in SQLDatabase.execute(self, sql, params)
#    1657 args = [] if params is None else [params]
#    1658 if isinstance(sql, str):
# -> 1659     return self.con.exec_driver_sql(sql, *args)
#    1660 return self.con.execute(sql, *args)
#
# File ~\Software Projects\Database Administration\env\Lib\site-packages\sqlalchemy\engine\base.py:1776, in Connection.exec_driver_sql(self, statement, parameters, execution_options)
#    1771 execution_options = self._execution_options.merge_with(
#    1772     execution_options
#    1773 )
#    1775 dialect = self.dialect
# -> 1776 ret = self._execute_context(
#    1777     dialect,
#    1778     dialect.execution_ctx_cls._init_statement,
#    1779     statement,
#    1780     None,
#    1781     execution_options,
#    1782     statement,
#    1783     distilled_parameters,
#    1784 )
#    1786 return ret
#
# File ~\Software Projects\Database Administration\env\Lib\site-packages\sqlalchemy\engine\base.py:1843, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1841     return self._exec_insertmany_context(dialect, context)
#    1842 else:
# -> 1843     return self._exec_single_context(
#    1844         dialect, context, statement, parameters
#    1845     )
#
# File ~\Software Projects\Database Administration\env\Lib\site-packages\sqlalchemy\engine\base.py:1983, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1980     result = context._setup_result_proxy()
#    1982 except BaseException as e:
# -> 1983     self._handle_dbapi_exception(
#    1984         e, str_statement, effective_parameters, cursor, context
#    1985     )
#    1987 return result
#
# File ~\Software Projects\Database Administration\env\Lib\site-packages\sqlalchemy\engine\base.py:2352, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2350 elif should_wrap:
#    2351     assert sqlalchemy_exception is not None
# -> 2352     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2353 else:
#    2354     assert exc_info[1] is not None
#
# File ~\Software Projects\Database Administration\env\Lib\site-packages\sqlalchemy\engine\base.py:1964, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1962                 break
#    1963     if not evt_handled:
# -> 1964         self.dialect.do_execute(
#    1965             cursor, str_statement, effective_parameters, context
#    1966         )
#    1968 if self._has_events or self.engine._has_events:
#    1969     self.dispatch.after_cursor_execute(
#    1970         self,
#    1971         cursor,
#    (...)
#    1975         context.executemany,
#    1976     )
#
# File ~\Software Projects\Database Administration\env\Lib\site-packages\sqlalchemy\engine\default.py:942, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     941 def do_execute(self, cursor, statement, parameters, context=None):
# --> 942     cursor.execute(statement, parameters)
#
# ProgrammingError: (pyodbc.ProgrammingError) ('42S22', "[42S22] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Invalid column name 'Fund_Family_Name'. (207) (SQLExecDirectW); [42S22] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Invalid column name 'Broad_Asset_Class_Name'. (207)")
# [SQL:
# SELECT
#     fs.SymbolCUSIP, fs.ProductName, fs.fund_family, fs.investment_strategy, fs.FS_insight,
#     fs.index_fund, fs.inverse_fund, fs.leveraged_fund, fs.socially_responsible_fund,
#     fs.synthetic_replication_fund, fs.fund_of_funds, fs.ycharts_url,
#     yc_ba.Broad_Asset_Class_Name, yc_bc.Broad_Category_Name, yc_gc.Global_Category_Name,
#     yc_c.Category_Name, cwa_bc.CWA_Broad_Category_Name,
#     ff.Dist_Index, ff.Dist_Active, ff.Dist_Rules_Based, ff.Dist_Quant, ff.Dist_Multi
# FROM Funds_to_Screen fs
# LEFT JOIN FundFamilyData ff ON fs.fund_family = ff.[Fund_Family_Name]
# LEFT JOIN YC_Broad_Asset_Class_List yc_ba ON fs.YC_Broad_Asset_Class_ID = yc_ba.ID
# LEFT JOIN YC_Broad_Category_List yc_bc ON fs.YC_Broad_Category_ID = yc_bc.ID
# LEFT JOIN YC_Global_Category_List yc_gc ON fs.YC_Global_Category_ID = yc_gc.ID
# LEFT JOIN YC_Category_List yc_c ON fs.YC_Category_ID = yc_c.ID
# LEFT JOIN CWA_Broad_Category_List cwa_bc ON fs.CWA_Broad_Category_ID = cwa_bc.ID
# ]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
import requests
import time
import logging
import threading
import urllib3
import sqlalchemy
import pandas as pd
from concurrent.futures import ThreadPoolExecutor, as_completed

# Disable SSL warnings
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# Configure logging
logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")

# YCharts API configuration for YCI style requests
headers_YCI = {
    "X-YCHARTSAUTHORIZATION": "yIIphqbsQysnTvWWxfW33w",  # Replace with your API key
    "X-YCHARTSEXCELSESSION": "b645cd897b2446bfa3796acfa3a879db",
    "X-YCHARTSEXCELVERSION": "4.4",
    "X-YCHARTSOPERATINGSYSTEM": "Microsoft Windows NT 10.0.26100.0",
    "X-YCHARTSIP": "",
    "Host": "api.ycharts.com",
    "Connection": "Keep-Alive"
}
yc_base_url = "https://api.ycharts.com/v3/"

# Configure the Database Connection (SQL Server)
connection_string = (
    "mssql+pyodbc://JULIANS_LAPTOP\\SQLEXPRESS/CWA_Fund_Database?"
    "driver=ODBC+Driver+18+for+SQL+Server&trusted_connection=yes&TrustServerCertificate=yes"
)
engine = sqlalchemy.create_engine(connection_string)

# Simple rate limiter to allow at most 13 calls per second across threads
class RateLimiter:
    def __init__(self, rate):
        self.rate = rate
        self.interval = 1.0 / rate
        self.lock = threading.Lock()
        self.last_time = time.time()

    def wait(self):
        with self.lock:
            now = time.time()
            elapsed = now - self.last_time
            wait_time = self.interval - elapsed
            if wait_time > 0:
                time.sleep(wait_time)
            self.last_time = time.time()

rate_limiter = RateLimiter(rate=13)

def fetch_currency_hedged_fund(symbol, fund_type_id):
    """
    Fetch the 'currency_hedged_fund' metric for a given fund symbol using YCI style API.
    Returns a tuple (symbol, value) where value is the raw string (e.g., "TRUE", "FALSE").
    """
    rate_limiter.wait()  # Ensure we don't exceed 13 calls/sec
    # Build the endpoint; mutual funds (Fund_Type_ID = 3) use "M:" prefix
    if fund_type_id == 3:
        endpoint = f"mutual_funds/M:{symbol}/info/currency_hedged_fund?retrieve_ttl=true"
    else:
        endpoint = f"companies/{symbol}/info/currency_hedged_fund?retrieve_ttl=true"
    url = f"{yc_base_url}{endpoint}"
    logging.info(f"Fetching {symbol}: {url}")
    try:
        response = requests.get(url, headers=headers_YCI, verify=False)
        if response.status_code != 200:
            logging.error(f"HTTP error for {symbol}: {response.status_code}")
            return symbol, None

        data = response.json()
        response_key = f"M:{symbol}" if fund_type_id == 3 else symbol
        if "response" not in data or response_key not in data["response"]:
            logging.warning(f"No response data for {symbol} (expected key: {response_key})")
            return symbol, None

        results = data["response"][response_key].get("results", {})
        if "currency_hedged_fund" not in results:
            logging.warning(f"'currency_hedged_fund' metric not found for {symbol}")
            return symbol, None

        metric_data = results["currency_hedged_fund"]
        value = metric_data.get("data")
        logging.info(f"Fetched {symbol}: {value}")
        return symbol, value
    except Exception as e:
        logging.error(f"Error fetching {symbol}: {e}")
        return symbol, None

def update_database(results, batch_size=500):
    """
    Update the Funds_to_Screen table with the fetched currency_hedged_fund values in batches.
    'results' is expected to be a list of (SymbolCUSIP, currency_hedged_fund) tuples.
    """
    df = pd.DataFrame(results, columns=["SymbolCUSIP", "currency_hedged_fund"])
    total = len(df)
    logging.info(f"Updating database for {total} funds...")
    with engine.begin() as conn:
        for i in range(0, total, batch_size):
            batch = df.iloc[i:i + batch_size]
            updates = [{"symbol": row["SymbolCUSIP"], "value": row["currency_hedged_fund"]} for _, row in batch.iterrows()]
            conn.execute(
                sqlalchemy.text("""
                    UPDATE Funds_to_Screen 
                    SET currency_hedged_fund = :value 
                    WHERE SymbolCUSIP = :symbol
                """),
                updates
            )
    logging.info("Database update complete.")

def main():
    # Retrieve all funds that need the currency_hedged_fund update
    query = "SELECT SymbolCUSIP, Fund_Type_ID FROM Funds_to_Screen WHERE currency_hedged_fund IS NULL"
    funds = pd.read_sql(query, engine)
    logging.info(f"Found {len(funds)} funds needing currency_hedged_fund update.")

    results = []
    # Use a ThreadPoolExecutor with a max of 13 workers to respect our rate limit
    with ThreadPoolExecutor(max_workers=13) as executor:
        future_to_symbol = {
            executor.submit(fetch_currency_hedged_fund, row["SymbolCUSIP"], row["Fund_Type_ID"]): row["SymbolCUSIP"]
            for _, row in funds.iterrows()
        }
        for future in as_completed(future_to_symbol):
            symbol, value = future.result()
            results.append((symbol, value))

    # Update the database in batches
    update_database(results, batch_size=500)
    print("Updating Database")

    #end script
    print("All funds processed")

if __name__ == "__main__":
    main()
# Out:
# 2025-03-01 18:14:06,752 - INFO - Found 40 funds needing currency_hedged_fund update.
# 2025-03-01 18:14:06,805 - INFO - Fetching AMPD: https://api.ycharts.com/v3/companies/AMPD/info/currency_hedged_fund?retrieve_ttl=true
# 2025-03-01 18:14:06,883 - INFO - Fetching VMOT: https://api.ycharts.com/v3/companies/VMOT/info/currency_hedged_fund?retrieve_ttl=true
# 2025-03-01 18:14:06,961 - INFO - Fetching PP: https://api.ycharts.com/v3/companies/PP/info/currency_hedged_fund?retrieve_ttl=true
# 2025-03-01 18:14:07,050 - INFO - Fetching VCAR: https://api.ycharts.com/v3/companies/VCAR/info/currency_hedged_fund?retrieve_ttl=true
# 2025-03-01 18:14:07,127 - INFO - Fetching OFIYX: https://api.ycharts.com/v3/mutual_funds/M:OFIYX/info/currency_hedged_fund?retrieve_ttl=true
# 2025-03-01 18:14:07,200 - WARNING - 'currency_hedged_fund' metric not found for AMPD
# 2025-03-01 18:14:07,219 - INFO - Fetching TWIO: https://api.ycharts.com/v3/companies/TWIO/info/currency_hedged_fund?retrieve_ttl=true
# 2025-03-01 18:14:07,223 - WARNING - 'currency_hedged_fund' metric not found for VMOT
# 2025-03-01 18:14:07,301 - INFO - Fetching DFNV: https://api.ycharts.com/v3/companies/DFNV/info/currency_hedged_fund?retrieve_ttl=true
# 2025-03-01 18:14:07,327 - WARNING - 'currency_hedged_fund' metric not found for PP
# 2025-03-01 18:14:07,379 - INFO - Fetching DFRA: https://api.ycharts.com/v3/companies/DFRA/info/currency_hedged_fund?retrieve_ttl=true
# 2025-03-01 18:14:07,419 - WARNING - 'currency_hedged_fund' metric not found for VCAR
# 2025-03-01 18:14:07,462 - INFO - Fetching TTAI: https://api.ycharts.com/v3/companies/TTAI/info/currency_hedged_fund?retrieve_ttl=true
# 2025-03-01 18:14:07,488 - WARNING - 'currency_hedged_fund' metric not found for OFIYX
# 2025-03-01 18:14:07,547 - INFO - Fetching IQDE: https://api.ycharts.com/v3/companies/IQDE/info/currency_hedged_fund?retrieve_ttl=true
# 2025-03-01 18:14:07,573 - WARNING - 'currency_hedged_fund' metric not found for TWIO
# 2025-03-01 18:14:07,625 - INFO - Fetching XYLE: https://api.ycharts.com/v3/companies/XYLE/info/currency_hedged_fund?retrieve_ttl=true
# 2025-03-01 18:14:07,670 - WARNING - 'currency_hedged_fund' metric not found for DFNV
# 2025-03-01 18:14:07,702 - INFO - Fetching QYLE: https://api.ycharts.com/v3/companies/QYLE/info/currency_hedged_fund?retrieve_ttl=true
# 2025-03-01 18:14:07,722 - WARNING - 'currency_hedged_fund' metric not found for DFRA
# 2025-03-01 18:14:07,788 - INFO - Fetching EMCC: https://api.ycharts.com/v3/companies/EMCC/info/currency_hedged_fund?retrieve_ttl=true
# 2025-03-01 18:14:07,808 - WARNING - 'currency_hedged_fund' metric not found for TTAI
# 2025-03-01 18:14:07,866 - INFO - Fetching NUSI: https://api.ycharts.com/v3/companies/NUSI/info/currency_hedged_fund?retrieve_ttl=true
# 2025-03-01 18:14:07,911 - WARNING - 'currency_hedged_fund' metric not found for IQDE
# 2025-03-01 18:14:07,943 - INFO - Fetching FYLG: https://api.ycharts.com/v3/companies/FYLG/info/currency_hedged_fund?retrieve_ttl=true
# 2025-03-01 18:14:07,999 - WARNING - 'currency_hedged_fund' metric not found for XYLE
# 2025-03-01 18:14:08,021 - INFO - Fetching HYLG: https://api.ycharts.com/v3/companies/HYLG/info/currency_hedged_fund?retrieve_ttl=true
# 2025-03-01 18:14:08,062 - WARNING - 'currency_hedged_fund' metric not found for QYLE
# 2025-03-01 18:14:08,102 - INFO - Fetching GPOW: https://api.ycharts.com/v3/companies/GPOW/info/currency_hedged_fund?retrieve_ttl=true
# 2025-03-01 18:14:08,143 - WARNING - 'currency_hedged_fund' metric not found for EMCC
# 2025-03-01 18:14:08,180 - INFO - Fetching OCTA: https://api.ycharts.com/v3/companies/OCTA/info/currency_hedged_fund?retrieve_ttl=true
# 2025-03-01 18:14:08,198 - WARNING - 'currency_hedged_fund' metric not found for NUSI
# 2025-03-01 18:14:08,269 - INFO - Fetching GCLN: https://api.ycharts.com/v3/companies/GCLN/info/currency_hedged_fund?retrieve_ttl=true
# 2025-03-01 18:14:08,288 - WARNING - 'currency_hedged_fund' metric not found for FYLG
# 2025-03-01 18:14:08,358 - INFO - Fetching GREI: https://api.ycharts.com/v3/companies/GREI/info/currency_hedged_fund?retrieve_ttl=true
# 2025-03-01 18:14:08,360 - WARNING - 'currency_hedged_fund' metric not found for HYLG
# 2025-03-01 18:14:08,442 - INFO - Fetching MJUS: https://api.ycharts.com/v3/companies/MJUS/info/currency_hedged_fund?retrieve_ttl=true
# 2025-03-01 18:14:08,445 - WARNING - 'currency_hedged_fund' metric not found for GPOW
# 2025-03-01 18:14:08,524 - INFO - Fetching TTAC: https://api.ycharts.com/v3/companies/TTAC/info/currency_hedged_fund?retrieve_ttl=true
# 2025-03-01 18:14:08,525 - WARNING - 'currency_hedged_fund' metric not found for OCTA
# 2025-03-01 18:14:08,602 - INFO - Fetching NETZ: https://api.ycharts.com/v3/companies/NETZ/info/currency_hedged_fund?retrieve_ttl=true
# 2025-03-01 18:14:08,630 - WARNING - 'currency_hedged_fund' metric not found for GCLN
# 2025-03-01 18:14:08,684 - INFO - Fetching USCF: https://api.ycharts.com/v3/companies/USCF/info/currency_hedged_fund?retrieve_ttl=true
# 2025-03-01 18:14:08,691 - WARNING - 'currency_hedged_fund' metric not found for GREI
# 2025-03-01 18:14:08,769 - INFO - Fetching HYMU: https://api.ycharts.com/v3/companies/HYMU/info/currency_hedged_fund?retrieve_ttl=true
# 2025-03-01 18:14:08,796 - WARNING - 'currency_hedged_fund' metric not found for MJUS
# 2025-03-01 18:14:08,847 - INFO - Fetching IMSI: https://api.ycharts.com/v3/companies/IMSI/info/currency_hedged_fund?retrieve_ttl=true
# 2025-03-01 18:14:08,874 - WARNING - 'currency_hedged_fund' metric not found for TTAC
# 2025-03-01 18:14:08,924 - INFO - Fetching WBND: https://api.ycharts.com/v3/companies/WBND/info/currency_hedged_fund?retrieve_ttl=true
# 2025-03-01 18:14:08,930 - WARNING - 'currency_hedged_fund' metric not found for NETZ
# 2025-03-01 18:14:09,003 - INFO - Fetching DFHY: https://api.ycharts.com/v3/companies/DFHY/info/currency_hedged_fund?retrieve_ttl=true
# 2025-03-01 18:14:09,003 - WARNING - 'currency_hedged_fund' metric not found for USCF
# 2025-03-01 18:14:09,092 - INFO - Fetching ISDB: https://api.ycharts.com/v3/companies/ISDB/info/currency_hedged_fund?retrieve_ttl=true
# 2025-03-01 18:14:09,126 - WARNING - 'currency_hedged_fund' metric not found for HYMU
# 2025-03-01 18:14:09,182 - INFO - Fetching ABQYX: https://api.ycharts.com/v3/mutual_funds/M:ABQYX/info/currency_hedged_fund?retrieve_ttl=true
# 2025-03-01 18:14:09,202 - WARNING - 'currency_hedged_fund' metric not found for IMSI
# 2025-03-01 18:14:09,261 - INFO - Fetching JIEIX: https://api.ycharts.com/v3/mutual_funds/M:JIEIX/info/currency_hedged_fund?retrieve_ttl=true
# 2025-03-01 18:14:09,261 - WARNING - 'currency_hedged_fund' metric not found for WBND
# 2025-03-01 18:14:09,349 - INFO - Fetching MAYHX: https://api.ycharts.com/v3/mutual_funds/M:MAYHX/info/currency_hedged_fund?retrieve_ttl=true
# 2025-03-01 18:14:09,350 - WARNING - 'currency_hedged_fund' metric not found for DFHY
# 2025-03-01 18:14:09,427 - INFO - Fetching FGTBX: https://api.ycharts.com/v3/mutual_funds/M:FGTBX/info/currency_hedged_fund?retrieve_ttl=true
# 2025-03-01 18:14:09,429 - WARNING - 'currency_hedged_fund' metric not found for ISDB
# 2025-03-01 18:14:09,499 - WARNING - 'currency_hedged_fund' metric not found for ABQYX
# 2025-03-01 18:14:09,512 - INFO - Fetching FSMZX: https://api.ycharts.com/v3/mutual_funds/M:FSMZX/info/currency_hedged_fund?retrieve_ttl=true
# 2025-03-01 18:14:09,586 - WARNING - 'currency_hedged_fund' metric not found for JIEIX
# 2025-03-01 18:14:09,590 - INFO - Fetching AMCYX: https://api.ycharts.com/v3/mutual_funds/M:AMCYX/info/currency_hedged_fund?retrieve_ttl=true
# 2025-03-01 18:14:09,667 - INFO - Fetching JGIFX: https://api.ycharts.com/v3/mutual_funds/M:JGIFX/info/currency_hedged_fund?retrieve_ttl=true
# 2025-03-01 18:14:09,719 - WARNING - 'currency_hedged_fund' metric not found for MAYHX
# 2025-03-01 18:14:09,753 - INFO - Fetching FPPJX: https://api.ycharts.com/v3/mutual_funds/M:FPPJX/info/currency_hedged_fund?retrieve_ttl=true
# 2025-03-01 18:14:09,757 - WARNING - 'currency_hedged_fund' metric not found for FGTBX
# 2025-03-01 18:14:09,837 - INFO - Fetching MUIBX: https://api.ycharts.com/v3/mutual_funds/M:MUIBX/info/currency_hedged_fund?retrieve_ttl=true
# 2025-03-01 18:14:09,870 - WARNING - 'currency_hedged_fund' metric not found for FSMZX
# 2025-03-01 18:14:09,922 - INFO - Fetching NHYMX: https://api.ycharts.com/v3/mutual_funds/M:NHYMX/info/currency_hedged_fund?retrieve_ttl=true
# 2025-03-01 18:14:09,957 - WARNING - 'currency_hedged_fund' metric not found for AMCYX
# 2025-03-01 18:14:10,000 - WARNING - 'currency_hedged_fund' metric not found for JGIFX
# 2025-03-01 18:14:10,000 - INFO - Fetching PYHIX: https://api.ycharts.com/v3/mutual_funds/M:PYHIX/info/currency_hedged_fund?retrieve_ttl=true
# 2025-03-01 18:14:10,083 - WARNING - 'currency_hedged_fund' metric not found for FPPJX
# 2025-03-01 18:14:10,186 - WARNING - 'currency_hedged_fund' metric not found for MUIBX
# 2025-03-01 18:14:10,250 - WARNING - 'currency_hedged_fund' metric not found for NHYMX
# 2025-03-01 18:14:10,318 - WARNING - 'currency_hedged_fund' metric not found for PYHIX
# 2025-03-01 18:14:10,320 - INFO - Updating database for 40 funds...
# 2025-03-01 18:14:10,339 - INFO - Database update complete.
# Updating Database
# All funds processed

# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy.types import Integer, Float, String, DateTime, Boolean

# Step 1: Load the Excel file into a pandas DataFrame
df = pd.read_excel(r"C:\Users\JulianHeron\Software Projects\Fund family table upload.xlsx")

# Step 2: Determine SQL data types based on the DataFrame's data
dtype_dict = {}
for col in df.columns:
    if pd.api.types.is_integer_dtype(df[col]):
        # Use INT for integer columns
        dtype_dict[col] = Integer()
    elif pd.api.types.is_float_dtype(df[col]):
        # Use FLOAT for floating-point numbers
        dtype_dict[col] = Float()
    elif pd.api.types.is_string_dtype(df[col]):
        # Use VARCHAR with the maximum length of strings in the column
        max_len = df[col].str.len().max()
        dtype_dict[col] = String(length=max_len)
    elif pd.api.types.is_datetime64_any_dtype(df[col]):
        # Use DATETIME for date and time values
        dtype_dict[col] = DateTime()
    elif pd.api.types.is_bool_dtype(df[col]):
        # Use BIT for boolean values (SQL Server equivalent)
        dtype_dict[col] = Boolean()

# Step 3: Create a connection to the SQL Server database
connection_string = (
    "mssql+pyodbc://JULIANS_LAPTOP\\SQLEXPRESS/"
    "CWA_Fund_Database?driver=ODBC+Driver+18+for+SQL+Server"
    "&trusted_connection=yes&TrustServerCertificate=yes"
)
engine = create_engine(connection_string)

# Step 4: Create the table "FundFamilyData" and insert the data
df.to_sql('FundFamilyData', engine, if_exists='replace', index=False, dtype=dtype_dict)
# Out:
# 163
