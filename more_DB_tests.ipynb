# %%
#Fixing funds with missing data not originally imported into database due to grok script error

import pandas as pd
from sqlalchemy import create_engine, text
from concurrent.futures import ThreadPoolExecutor, as_completed
import logging
from datetime import datetime
import json
import requests
import urllib3

# Disable InsecureRequestWarning
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# Setup logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    filename='C:\\Users\\JulianHeron\\Software Projects\\Database Project Files\\funds_update_log.txt',
    filemode='w'
)
console = logging.StreamHandler()
console.setLevel(logging.INFO)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
console.setFormatter(formatter)
logging.getLogger('').addHandler(console)

# Database connection
connection_string = (
    "mssql+pyodbc://JULIANS_LAPTOP\\SQLEXPRESS/"
    "CWA_Fund_Database?driver=ODBC+Driver+18+for+SQL+Server"
    "&trusted_connection=yes&TrustServerCertificate=yes"
)
engine = create_engine(
    connection_string,
    connect_args={
        'pool_size': 20,
        'max_overflow': 50,
        'pool_timeout': 300
    }
)

# Constants for YCharts API (you'll need to replace with your actual API key)
API_KEY = "yIIphqbsQysnTvWWxfW33w"  # Placeholder, use your actual API key securely
BASE_URL = "https://api.ycharts.com/v3"
HEADERS = {
    'X-YCHARTSAUTHORIZATION': API_KEY,
    'X-YCHARTSEXCELSESSION': 'b645cd897b2446bfa3796acfa3a879db',
    'X-YCHARTSEXCELVERSION': '4.4',
    'X-YCHARTSOPERATINGSYSTEM': 'Microsoft Windows NT 10.0.26100.0',
    'X-YCHARTSIP': '',
    'Host': 'api.ycharts.com',
    'Content-Type': 'application/x-www-form-urlencoded',
    'Connection': 'Keep-Alive'
}

def construct_url(product_type, call_type, symbol, function, **kwargs):
    base_path = {
        'ETF': '/companies',
        'mutual_fund': '/mutual_funds',
        'index': '/indices'
    }.get(product_type, '/companies')
    
    if call_type == 'YCI':
        url = f"{BASE_URL}{base_path}/{symbol}/info/{function}"
    elif call_type == 'YCP':
        url = f"{BASE_URL}/excel/points"
    elif call_type == 'YCS':
        url = f"{BASE_URL}{base_path}/{symbol}/series/{function}"
    
    if kwargs:
        url += '?' + '&'.join([f"{k}={v}" for k, v in kwargs.items()])
    
    return url

def handle_response(response):
    try:
        data = response.json()
        if data['meta']['status'] != 'ok':
            error_msg = data['meta'].get('error_message', 'Unknown error')
            logging.error(f"API Error: {error_msg}")
            raise ValueError(error_msg)
        return data['response']
    except json.JSONDecodeError:
        logging.error("Invalid JSON response")
        raise ValueError("Invalid JSON response")

def get_info(product_type, symbol, function):
    url = construct_url(product_type, 'YCI', symbol, function)
    try:
        response = requests.get(url, headers=HEADERS, verify=False)
        response.raise_for_status()
        return handle_response(response)
    except requests.RequestException as e:
        logging.error(f"Request failed for {url}: {str(e)}")
        return None

def get_data_point(product_type, symbol, function):
    url = construct_url(product_type, 'YCP', symbol, function)
    data = {'points': f"{symbol},{function}"}
    try:
        response = requests.post(url, headers=HEADERS, data=data, verify=False)
        response.raise_for_status()
        result = handle_response(response)
        if result and symbol in result and function in result[symbol]['results']:
            # Extract the value safely
            try:
                return result[symbol]['results'][function]['']['results'][1]  # Assuming [date, value]
            except (KeyError, IndexError):
                # Handle case where expected structure is not present
                logging.info(f"No data for {function} for symbol {symbol}")
                return None
        else:
            logging.info(f"No data for {function} for symbol {symbol}")
            return None
    except requests.RequestException as e:
        logging.error(f"Request failed for {url}: {str(e)}")
        return None

def get_fund_type(symbol):
    with engine.connect() as conn:
        result = conn.execute(text("SELECT Fund_Type_ID FROM Funds_to_Screen WHERE SymbolCUSIP = :symbol"), {'symbol': symbol}).fetchone()
        if result:
            fund_type_id = result[0]
            return 'ETF' if fund_type_id == 2 else 'mutual_fund' if fund_type_id == 3 else 'unknown'
        else:
            # Fallback based on symbol prefix if not in the database
            return 'mutual_fund' if symbol.startswith('M:') else 'ETF'

def update_fund_data(symbol):
    fund_type = get_fund_type(symbol)
    if fund_type == 'unknown':
        logging.warning(f"Unknown fund type for {symbol}, skipping.")
        return

    with engine.connect() as conn:
        # Check if the symbol already exists with data
        check = conn.execute(text("SELECT COUNT(*) FROM Funds_to_Screen WHERE SymbolCUSIP = :symbol AND InceptionDate IS NOT NULL"), {'symbol': symbol}).fetchone()
        if check[0] > 0:
            logging.info(f"Symbol {symbol} already has data, skipping update.")
            return

        try:
            # Fetch all relevant data from YCharts first
            raw_data = {
                'InceptionDate': get_info(fund_type, symbol, 'inception_date'),
                'EarliestPerformanceDate': get_info(fund_type, symbol, 'earliest_performance_date'),
                'LCG': get_data_point(fund_type, symbol, 'equity_stylebox_large_cap_growth_exposure'),
                'LCB': get_data_point(fund_type, symbol, 'equity_stylebox_large_cap_blend_exposure'),
                'LCV': get_data_point(fund_type, symbol, 'equity_stylebox_large_cap_value_exposure'),
                'MCG': get_data_point(fund_type, symbol, 'equity_stylebox_mid_cap_growth_exposure'),
                'MCB': get_data_point(fund_type, symbol, 'equity_stylebox_mid_cap_blend_exposure'),
                'MCV': get_data_point(fund_type, symbol, 'equity_stylebox_mid_cap_value_exposure'),
                'SCG': get_data_point(fund_type, symbol, 'equity_stylebox_small_cap_growth_exposure'),
                'SCB': get_data_point(fund_type, symbol, 'equity_stylebox_small_cap_blend_exposure'),
                'SCV': get_data_point(fund_type, symbol, 'equity_stylebox_small_cap_value_exposure'),
                'Giant_Cap_Exposure': get_data_point(fund_type, symbol, 'giant_cap_exposure'),
                'Large_Cap_Exposure': get_data_point(fund_type, symbol, 'large_cap_exposure'),
                'Medium_Cap_Exposure': get_data_point(fund_type, symbol, 'medium_cap_exposure'),
                'Micro_Cap_Exposure': get_data_point(fund_type, symbol, 'micro_cap_exposure'),
                'Sensitive_Exposure': get_data_point(fund_type, symbol, 'sensitive_exposure'),
                'Small_Cap_Exposure': get_data_point(fund_type, symbol, 'small_cap_exposure'),
                'Cyclical_Exposure': get_data_point(fund_type, symbol, 'cyclical_exposure'),
                'Defensive_Exposure': get_data_point(fund_type, symbol, 'defensive_exposure'),
                'AAA_Rated': get_data_point(fund_type, symbol, 'aaa_bond_exposure'),
                'AA_Rated': get_data_point(fund_type, symbol, 'aa_bond_exposure'),
                'A_Rated': get_data_point(fund_type, symbol, 'a_bond_exposure'),
                'BBB_Rated': get_data_point(fund_type, symbol, 'bbb_bond_exposure'),
                'B_Rated': get_data_point(fund_type, symbol, 'b_bond_exposure'),
                'BB_Rated': get_data_point(fund_type, symbol, 'bb_bond_exposure'),
                'Below_B_Rated': get_data_point(fund_type, symbol, 'below_b_bond_exposure'),
                'Not_Rated': get_data_point(fund_type, symbol, 'not_rated_bond_exposure'),
                'Term_10_15_Y': get_data_point(fund_type, symbol, '10_to_15_years_maturity_bond_exposure'),
                'Term_1_3_Y': get_data_point(fund_type, symbol, '1_to_3_years_maturity_bond_exposure'),
                'Term_15_20_Y': get_data_point(fund_type, symbol, '15_to_20_years_maturity_bond_exposure'),
                'Term_1_7_D': get_data_point(fund_type, symbol, '1_to_7_days_maturity_bond_exposure'),
                'Term_183_364_D': get_data_point(fund_type, symbol, '183_to_364_days_maturity_bond_exposure'),
                'Term_20_30_Y': get_data_point(fund_type, symbol, '20_to_30_years_maturity_bond_exposure'),
                'Term_30_Plus_Y': get_data_point(fund_type, symbol, 'over_30_years_maturity_bond_exposure'),
                'Term_31_90_D': get_data_point(fund_type, symbol, '31_to_90_days_maturity_bond_exposure'),
                'Term_3_5_Y': get_data_point(fund_type, symbol, '3_to_5_years_maturity_bond_exposure'),
                'Term_5_7_Y': get_data_point(fund_type, symbol, '5_to_7_years_maturity_bond_exposure'),
                'Term_7_10_Y': get_data_point(fund_type, symbol, '7_to_10_years_maturity_bond_exposure'),
                'Term_8_30_D': get_data_point(fund_type, symbol, '8_to_30_days_maturity_bond_exposure'),
                'Term_91_182_D': get_data_point(fund_type, symbol, '91_to_182_days_maturity_bond_exposure'),
                'LT_Exposure': get_data_point(fund_type, symbol, 'long_term_exposure'),
                'Interm_Exposure': get_data_point(fund_type, symbol, 'intermediate_term_exposure'),
                'ST_Exposure': get_data_point(fund_type, symbol, 'short_term_exposure'),
                'aum_usd': get_info(fund_type, symbol, 'aum_usd'),
                'average_manager_tenure': get_data_point(fund_type, symbol, 'average_manager_tenure'),
                'max_manager_tenure': get_data_point(fund_type, symbol, 'max_manager_tenure'),
                'median_manager_tenure': get_data_point(fund_type, symbol, 'median_manager_tenure'),
                'min_manager_tenure': get_data_point(fund_type, symbol, 'min_manager_tenure'),
                'index_fund': get_info(fund_type, symbol, 'index_fund'),
                'inverse_fund': get_info(fund_type, symbol, 'inverse_fund'),
                'leveraged_fund': get_info(fund_type, symbol, 'leveraged_fund'),
                'socially_responsible_fund': get_info(fund_type, symbol, 'socially_responsible_fund'),
                'synthetic_replication_fund': get_info(fund_type, symbol, 'synthetic_replication_fund'),
                'open_to_existing_investors': get_info(fund_type, symbol, 'open_to_existing_investors'),
                'open_to_new_investors': get_info(fund_type, symbol, 'open_to_new_investors'),
                'ycharts_url': get_info(fund_type, symbol, 'ycharts_url'),
                'years_since_inception': get_data_point(fund_type, symbol, 'years_since_inception'),
                'investment_strategy': get_info(fund_type, symbol, 'investment_strategy'),
                'related_securities': get_info(fund_type, symbol, 'related_securities'),
                'fund_family': get_info(fund_type, symbol, 'fund_family'),
                'fund_of_funds': get_info(fund_type, symbol, 'fund_of_funds'),
            }
            
            # Now calculate fields based on the fetched data
            data = raw_data.copy()
            data.update({
                'Inv_Grade': sum(filter(None, [raw_data.get('AAA_Rated'), raw_data.get('AA_Rated'), raw_data.get('A_Rated'), raw_data.get('BBB_Rated')])),
                'NINV_Grade': sum(filter(None, [raw_data.get('B_Rated'), raw_data.get('BB_Rated'), raw_data.get('Below_B_Rated'), raw_data.get('Not_Rated')])),
                'Growth_Exposure': sum(filter(None, [raw_data.get('LCG'), raw_data.get('MCG'), raw_data.get('SCG'), raw_data.get('LCB', 0)/2, raw_data.get('MCB', 0)/2, raw_data.get('SCB', 0)/2])),
                'Value_Exposure': sum(filter(None, [raw_data.get('LCV'), raw_data.get('MCV'), raw_data.get('SCV'), raw_data.get('LCB', 0)/2, raw_data.get('MCB', 0)/2, raw_data.get('SCB', 0)/2])),
            })

            # Handle null values for database insertion
            for key in data:
                if data[key] is None:
                    data[key] = None  # SQLAlchemy or pyodbc will handle this as NULL in SQL
                elif isinstance(data[key], dict):
                    data[key] = data[key].get('data')
                elif isinstance(data[key], list):
                    data[key] = json.dumps(data[key])  # Convert list to JSON string for storage
                # Convert boolean to 'true'/'false' for database storage
                if key in ['index_fund', 'inverse_fund', 'leveraged_fund', 'socially_responsible_fund', 'synthetic_replication_fund', 'open_to_existing_investors', 'open_to_new_investors']:
                    data[key] = 'true' if data[key] else 'false'

            # Convert dates to SQL compatible format
            for key in ['InceptionDate', 'EarliestPerformanceDate']:
                if data[key] is not None:
                    if isinstance(data[key], str):
                        try:
                            data[key] = datetime.strptime(data[key], '%Y-%m-%d').date()
                        except ValueError:
                            data[key] = None
                    else:
                        data[key] = None  # If it's not a string, assume it's not a valid date

            # SQL Update query (for new or incomplete records)
            update_fields = ', '.join([f"{col} = :{col}" for col in data.keys()])
            query = text(f"""
            UPDATE Funds_to_Screen
            SET 
                {update_fields}
            WHERE SymbolCUSIP = :symbol
            """)
            
            conn.execute(query, **data, symbol=symbol)
            conn.commit()
            logging.info(f"Updated data for {symbol}.")

        except Exception as e:
            logging.error(f"Error updating data for {symbol}: {str(e)}")
            conn.rollback()

def main():
    # Read symbols from Excel file
    df = pd.read_excel('C:\\Users\\JulianHeron\\blank_YC_BM_Symbols.xlsx', usecols=[0], skiprows=1, names=['Symbol'])
    symbols = df['Symbol'].tolist()
    
    with ThreadPoolExecutor(max_workers=20) as executor:
        futures = {executor.submit(update_fund_data, symbol): symbol for symbol in symbols}
        for future in as_completed(futures):
            symbol = futures[future]
            try:
                future.result()
            except Exception as e:
                logging.error(f"Thread for {symbol} raised an exception: {str(e)}")

if __name__ == "__main__":
    main()
# Out:
# 2025-02-13 14:05:11,905 - ERROR - Error updating data for TWIO: 'results'

# %%
import pandas as pd
import sqlalchemy
from sqlalchemy import text
import logging
from concurrent.futures import ThreadPoolExecutor, as_completed
import time
import json
from tenacity import retry, stop_after_attempt, wait_exponential
import ssl
import certifi
from requests.adapters import HTTPAdapter
import requests

# Setup logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s', handlers=[
    logging.StreamHandler()  # Log to console
])
logger = logging.getLogger(__name__)

# Database Connection Configuration
connection_string = (
    "mssql+pyodbc://JULIANS_LAPTOP\\SQLEXPRESS/"
    "CWA_Fund_Database?driver=ODBC+Driver+18+for+SQL+Server"
    "&trusted_connection=yes&TrustServerCertificate=yes"
)
engine = sqlalchemy.create_engine(
    connection_string,
    pool_size=50,  # Increased pool size to avoid timeouts
    max_overflow=100,  # Adjust based on your system capabilities
    pool_timeout=300  # Increased timeout to handle long-running queries
)

# YCharts API Configuration
YCHARTS_API_URL = "https://api.ycharts.com"
API_HEADERS = {
    "X-YCHARTSAUTHORIZATION": "yIIphqbsQysnTvWWxfW33w",  # Replace with your actual API key
    "X-YCHARTSEXCELSESSION": "b645cd897b2446bfa3796acfa3a879db",
    "X-YCHARTSEXCELVERSION": "4.4",
    "X-YCHARTSOPERATINGSYSTEM": "Microsoft Windows NT 10.0.26100.0",
    "Content-Type": "application/x-www-form-urlencoded"
}

# SSL Context for HTTPS connections
context = ssl.create_default_context(cafile=certifi.where())
context.check_hostname = False
context.verify_mode = ssl.CERT_NONE  # Use CERT_REQUIRED in production

class CustomHTTPAdapter(HTTPAdapter):
    def init_poolmanager(self, *args, **kwargs):
        kwargs['ssl_context'] = context
        return super().init_poolmanager(*args, **kwargs)

session = requests.Session()
session.mount('https://', CustomHTTPAdapter())

# Metrics mapping 
column_to_ycharts_mapping = [
    ("FundID", None, None),  # No direct YCharts function for FundID
    ("ProductName", None, None),  # No direct YCharts function for ProductName
    ("SymbolCUSIP", None, None),  # No direct YCharts function for SymbolCUSIP
    ("ETFComplianceCategory", None, None),  # No direct YCharts function for ETFComplianceCategory
    ("ExpenseRatio", None, None), #Data mapped from custodian, do not use Ycharts data here
    ("Fund_Type_ID", None, None),  # Assuming this is an internal ID, not from YCharts
    ("YC_Broad_Category_ID", None, None),  # Likely internal, not from YCharts
    ("YC_Broad_Asset_Class_ID", None, None),  # Likely internal, not from YCharts
    ("YC_Global_Category_ID", None, None),  # Likely internal, not from YCharts
    ("YC_Category_ID", None, None),  # Likely internal, not from YCharts
    ("CWA_Broad_Category_ID", None, None),  # Likely internal, not from YCharts
    ("ScreeningStatus", None, None),  # No direct YCharts function for ScreeningStatus
    ("LastScreenedDate", None, None),  # No direct YCharts function for LastScreenedDate
    ("InceptionDate", "inception_date", "YCI"),
    ("EarliestPerformanceDate", "earliest_performance_date", "YCI"),
    ("LCG", "equity_stylebox_large_cap_growth_exposure", "YCP"),
    ("LCB", "equity_stylebox_large_cap_blend_exposure", "YCP"),
    ("LCV", "equity_stylebox_large_cap_value_exposure", "YCP"),
    ("MCG", "equity_stylebox_mid_cap_growth_exposure", "YCP"),
    ("MCB", "equity_stylebox_mid_cap_blend_exposure", "YCP"),
    ("MCV", "equity_stylebox_mid_cap_value_exposure", "YCP"),
    ("SCG", "equity_stylebox_small_cap_growth_exposure", "YCP"),
    ("SCB", "equity_stylebox_small_cap_blend_exposure", "YCP"),
    ("SCV", "equity_stylebox_small_cap_value_exposure", "YCP"),
    ("Giant_Cap_Exposure", "giant_cap_exposure", "YCP"),
    ("Large_Cap_Exposure", "large_cap_exposure", "YCP"),
    ("Medium_Cap_Exposure", "medium_cap_exposure", "YCP"),
    ("Micro_Cap_Exposure", "micro_cap_exposure", "YCP"),
    ("Sensitive_Exposure", "sensitive_exposure", "YCP"),
    ("Small_Cap_Exposure", "small_cap_exposure", "YCP"),
    ("Cyclical_Exposure", "cyclical_exposure", "YCP"),
    ("Defensive_Exposure", "defensive_exposure", "YCP"),
    ("AAA_Rated", "aaa_bond_exposure", "YCP"),
    ("AA_Rated", "aa_bond_exposure", "YCP"),
    ("A_Rated", "a_bond_exposure", "YCP"),
    ("BBB_Rated", "bbb_bond_exposure", "YCP"),
    ("B_Rated", "b_bond_exposure", "YCP"),
    ("BB_Rated", "bb_bond_exposure", "YCP"),
    ("Below_B_Rated", "below_b_bond_exposure", "YCP"),
    ("Not_Rated", "not_rated_bond_exposure", "YCP"),
    ("Term_10_15_Y", "10_to_15_years_maturity_bond_exposure", "YCP"),
    ("Term_1_3_Y", "1_to_3_years_maturity_bond_exposure", "YCP"),
    ("Term_15_20_Y", "15_to_20_years_maturity_bond_exposure", "YCP"),
    ("Term_1_7_D", "1_to_7_days_maturity_bond_exposure", "YCP"),
    ("Term_183_364_D", "183_to_364_days_maturity_bond_exposure", "YCP"),
    ("Term_20_30_Y", "20_to_30_years_maturity_bond_exposure", "YCP"),
    ("Term_30_Plus_Y", "over_30_years_maturity_bond_exposure", "YCP"),
    ("Term_31_90_D", "31_to_90_days_maturity_bond_exposure", "YCP"),
    ("Term_3_5_Y", "3_to_5_years_maturity_bond_exposure", "YCP"),
    ("Term_5_7_Y", "5_to_7_years_maturity_bond_exposure", "YCP"),
    ("Term_7_10_Y", "7_to_10_years_maturity_bond_exposure", "YCP"),
    ("Term_8_30_D", "8_to_30_days_maturity_bond_exposure", "YCP"),
    ("Term_91_182_D", "91_to_182_days_maturity_bond_exposure", "YCP"),
    ("LT_Exposure", "long_term_exposure", "YCP"),
    ("Interm_Exposure", "intermediate_term_exposure", "YCP"),
    ("ST_Exposure", "short_term_exposure", "YCP"),
    ("Inv_Grade", None, None),  # Calculated field, no direct YCharts function
    ("NINV_Grade", None, None),  # Calculated field, no direct YCharts function
    ("Growth_Exposure", None, None),  # Calculated field, no direct YCharts function
    ("Value_Exposure", None, None),  # Calculated field, no direct YCharts function
    ("pct_top_10", "percent_of_assets_in_top_10_holdings", "YCP"),
    ("pct_top_25", "percent_of_assets_in_top_25_holdings", "YCP"),
    ("materials", "basic_materials_exposure", "YCP"),
    ("comsvc", "communication_services_exposure", "YCP"),
    ("concyc", "consumer_cyclical_exposure", "YCP"),
    ("condef", "consumer_defensive_exposure", "YCP"),
    ("energy", "energy_exposure", "YCP"),
    ("finsvc", "financial_services_exposure", "YCP"),
    ("healthcare", "healthcare_exposure", "YCP"),
    ("industrials", "industrials_exposure", "YCP"),
    ("realestate", "real_estate_exposure", "YCP"),
    ("technology", "technology_exposure", "YCP"),
    ("utilities", "utilities_exposure", "YCP"),
    ("relative_composition", "relative_composition", "YCP"),
    ("num_bonds", "number_of_bond_holdings", "YCP"),
    ("num_stocks", "number_of_stock_holdings", "YCP"),
    ("dev_mkt", "developed_market_exposure", "YCP"),
    ("em_mkt", "emerging_market_exposure", "YCP"),
    ("europe", "greater_europe_total_exposure", "YCP"),
    ("lat_america", "latin_america_total_exposure", "YCP"),
    ("namerica", "north_america_total_exposure", "YCP"),
    ("africa_mideast", "africa_middle_east_total_exposure", "YCP"),
    ("asia_em", "asia_emerging_total_exposure", "YCP"),
    ("asia_dev", "asia_developed_total_exposure", "YCP"),
    ("australia", "australasia_total_exposure", "YCP"),
    ("india", "india_total_exposure", "YCP"),
    ("w_avg_dc", "weighted_average_debt_to_capital", "YCP"),
    ("avg_mkt_cap", "average_market_cap", "YCP"),
    ("avg_pe_ratio", "weighted_average_pe_ratio", "YCP"),
    ("avg_pb_ratio", "weighted_average_price_to_book_ratio", "YCP"),
    ("avg_pcf_ratio", "weighted_average_price_to_cash_flow", "YCP"),
    ("avg_ps_ratio", "weighted_average_price_to_sales_ratio", "YCP"),
    ("avg_net_margin", "weighted_median_net_margin", "YCP"),
    ("avg_roa", "weighted_median_return_on_assets", "YCP"),
    ("avg_roe", "weighted_median_return_on_equity", "YCP"),
    ("preferreds", "preferred_stock_exposure", "YCP"),
    ("securitized", "securitized_fixed_income_exposure", "YCP"),
    ("muni_exempt", "municipal_tax_exempt_bond_exposure", "YCP"),
    ("muni_tax", "municipal_taxable_bond_exposure", "YCP"),
    ("muni_exposure", "municipal_fixed_income_exposure", "YCP"),
    ("corp_exposure", "corporate_bond_exposure", "YCP"),
    ("corp_fi", "corporate_fixed_income_exposure", "YCP"),
    ("govi_exp", "government_bond_exposure", "YCP"),
    ("govi_fi", "government_fixed_income_exposure", "YCP"),
    ("covered_bond", "covered_bond_exposure", "YCP"),
    ("gov_bond", "government_related_bond_exposure", "YCP"),
    ("converts", "convertible_bond_exposure", "YCP"),
    ("asset_backed_sec", "asset_backed_security_exposure", "YCP"),
    ("index_fund", "index_fund", "YCI"),
    ("inverse_fund", "inverse_fund", "YCI"),
    ("leveraged_fund", "leveraged_fund", "YCI"),
    ("socially_responsible_fund", "socially_responsible_fund", "YCI"),
    ("synthetic_replication_fund", "synthetic_replication_fund", "YCI"),
    ("aum_usd", "aum_usd", "YCI"),
    ("average_manager_tenure", "average_manager_tenure", "YCP"),
    ("max_manager_tenure", "max_manager_tenure", "YCP"),
    ("median_manager_tenure", "median_manager_tenure", "YCP"),
    ("min_manager_tenure", "min_manager_tenure", "YCP"),
    ("open_to_existing_investors", "open_to_existing_investors", "YCI"),
    ("open_to_new_investors", "open_to_new_investors", "YCI"),
    ("ycharts_url", "ycharts_url", "YCI"),
    ("years_since_inception", "years_since_inception", "YCP"),
    ("investment_strategy", "investment_strategy", "YCI"),
    ("related_securities", "related_securities", "YCI"), #returns both symbols and names, only need symbols
    ("fund_family", "fund_family", "YCI")
]

# Extract metrics that should be fetched
METRICS = [(col, code, api) for col, code, api in column_to_ycharts_mapping if api in ["YCP", "YCI"]]

# YCP Functions
def build_points_lines(symbol, yc_code, is_mutual):
    symbol_for_api = f"M:{symbol}" if is_mutual else symbol
    return f"{symbol_for_api},{yc_code}"

@retry(stop=stop_after_attempt(3), wait=wait_exponential(multiplier=1, min=4, max=10))
def fetch_ycp_data_point(symbol, metric, fund_type_id):
    is_mutual = (fund_type_id == 3)
    for col, yc_code, api_type in METRICS:
        if col == metric and api_type == "YCP":
            points_line = build_points_lines(symbol, yc_code, is_mutual)
            payload = f"points={points_line}"
            api_url = f"{YCHARTS_API_URL}/v3/excel/points"
            try:
                response = session.post(api_url, headers=API_HEADERS, data=payload, timeout=60)
                response.raise_for_status()
                data = response.json()
                symbol_for_api = f"M:{symbol}" if is_mutual else symbol
                if 'response' in data and symbol_for_api in data['response']:
                    results = data['response'][symbol_for_api].get("results", {})
                    if yc_code in results:
                        datapoints = results[yc_code].get("data")
                        if datapoints and isinstance(datapoints, list):
                            last_point = datapoints[-1]
                            if isinstance(last_point, list) and len(last_point) > 1:
                                return last_point[1]
                logger.warning(f"No valid data returned for symbol '{symbol}' on metric '{metric}'")
                return None
            except requests.exceptions.RequestException as e:
                logger.error(f"API error for symbol '{symbol}' on metric '{metric}': {e}")
                return None
    return None

# YCI Functions
@retry(stop=stop_after_attempt(3), wait=wait_exponential(multiplier=1, min=4, max=10))
def fetch_yci_metric(symbol, fund_type_id, metric):
    for col, yc_code, api_type in METRICS:
        if col == metric and api_type == "YCI":
            if fund_type_id == 3:
                symbol_for_api = f"M:{symbol}"
                endpoint = "mutual_funds"
            else:
                symbol_for_api = symbol
                endpoint = "companies"
            api_url = f"{YCHARTS_API_URL}/v3/{endpoint}/{symbol_for_api}/info/{yc_code}?retrieve_ttl=true"
            logger.info(f"Fetching {metric} for {symbol} using URL: {api_url}")
            try:
                response = session.get(api_url, headers=API_HEADERS, timeout=30)
                response.raise_for_status()
                data = response.json()
                response_key = f"M:{symbol}" if fund_type_id == 3 else symbol
                metric_value = data.get("response", {}).get(response_key, {}).get("results", {}).get(yc_code, {}).get("data")
                
                if metric == "related_securities" and isinstance(metric_value, list):
                    metric_value = [sec.get('security_id') for sec in metric_value if isinstance(sec, dict) and 'security_id' in sec]
                return metric_value
            except Exception as e:
                logger.error(f"Error fetching {metric} for {symbol}: {e}")
                return None
    return None

def process_fund(row):
    symbol, fund_type_id = row['Symbol'], row['Fund_Type_ID']
    data = {"symbol": symbol}
    
    # Check if symbol exists in DB
    with engine.connect() as conn:
        result = conn.execute(text("SELECT 1 FROM Funds_to_Screen WHERE SymbolCUSIP = :symbol"), {'symbol': symbol}).fetchone()
    
    if result:  # If exists, we might want to skip or update based on your requirements
        logger.info(f"Symbol {symbol} already exists in DB, skipping insert.")
        return {'symbol': symbol, 'status': 'exists'}  # or update code here
    
    for metric, _, api_type in METRICS:
        if api_type == "YCP":
            data[metric] = fetch_ycp_data_point(symbol, metric, fund_type_id)
        elif api_type == "YCI":
            data[metric] = fetch_yci_metric(symbol, fund_type_id, metric)
    
    # Prepare data for DB insertion, convert lists to JSON for 'related_securities'
    data = {k: json.dumps(v) if k == 'related_securities' and isinstance(v, list) else v for k, v in data.items()}
    
    # Insert or update in DB
    try:
        with engine.begin() as conn:
            columns = ', '.join(data.keys())
            placeholders = ', '.join(':' + k for k in data.keys())
            insert_sql = f"INSERT INTO Funds_to_Screen ({columns}) VALUES ({placeholders})"
            conn.execute(text(insert_sql), data)
        return {'symbol': symbol, 'status': 'inserted'}
    except Exception as e:
        logger.error(f"Database error for {symbol}: {e}")
        return {'symbol': symbol, 'status': 'error'}

def main():
    start_time = time.time()
    logger.info("Starting data fetch and insertion process.")

    # Load symbols from Excel - now using the actual headers from the Excel file
    df = pd.read_excel('C:\\Users\\JulianHeron\\fund_type_and_symbol.xlsx', usecols=["SymbolCUSIP", "Fund_Type_ID"])
    
    processed_count = 0
    error_count = 0
    with ThreadPoolExecutor(max_workers=20) as executor:
        futures = {executor.submit(process_fund, row): row for _, row in df.iterrows()}
        
        for future in as_completed(futures):
            try:
                result = future.result()
                if result['status'] == 'inserted':
                    processed_count += 1
                elif result['status'] == 'error':
                    error_count += 1
                logger.info(f"Processed {result['symbol']}: {result['status']}")
            except Exception as e:
                error_count += 1
                logger.error(f"Exception in processing {futures[future]['SymbolCUSIP']}: {e}")
    
    # Call the stored procedure here after all processing is done
    try:
        with engine.begin() as conn:
            conn.execute(text("EXEC UpdateDerivedMetrics"))
        logger.info("Successfully executed UpdateDerivedMetrics stored procedure.")
    except Exception as e:
        logger.error(f"Failed to execute UpdateDerivedMetrics stored procedure: {e}")

    total_time = time.time() - start_time
    logger.info(f"Completed processing. Processed: {processed_count}, Errors: {error_count}, Total Time: {total_time:.2f} seconds")

if __name__ == "__main__":
    main()
# Out:
# 2025-02-13 15:59:20,180 - INFO - Starting data fetch and insertion process.
# 2025-02-13 15:59:20,572 - ERROR - Exception in processing ATHIX: 'Symbol'
# 2025-02-13 15:59:20,578 - ERROR - Exception in processing MRGR: 'Symbol'
# 2025-02-13 15:59:20,579 - ERROR - Exception in processing DEEF: 'Symbol'
# 2025-02-13 15:59:20,579 - ERROR - Exception in processing RAYJ: 'Symbol'
# 2025-02-13 15:59:20,581 - ERROR - Exception in processing CXSE: 'Symbol'
# 2025-02-13 15:59:20,582 - ERROR - Exception in processing PLDR: 'Symbol'
# 2025-02-13 15:59:20,582 - ERROR - Exception in processing CRFIX: 'Symbol'
# 2025-02-13 15:59:20,583 - ERROR - Exception in processing SMCF: 'Symbol'
# 2025-02-13 15:59:20,583 - ERROR - Exception in processing OILT: 'Symbol'
# 2025-02-13 15:59:20,583 - ERROR - Exception in processing TWGIX: 'Symbol'
# 2025-02-13 15:59:20,584 - ERROR - Exception in processing ARB: 'Symbol'
# 2025-02-13 15:59:20,584 - ERROR - Exception in processing GSIE: 'Symbol'
# 2025-02-13 15:59:20,586 - ERROR - Exception in processing OBOR: 'Symbol'
# 2025-02-13 15:59:20,586 - ERROR - Exception in processing FFLG: 'Symbol'
# 2025-02-13 15:59:20,587 - ERROR - Exception in processing CUBIX: 'Symbol'
# 2025-02-13 15:59:20,587 - ERROR - Exception in processing SCAP: 'Symbol'
# 2025-02-13 15:59:20,588 - ERROR - Exception in processing LNGZ: 'Symbol'
# 2025-02-13 15:59:20,589 - ERROR - Exception in processing ABHTX: 'Symbol'
# 2025-02-13 15:59:22,621 - ERROR - Exception in processing DTINX: 'Symbol'
# 2025-02-13 15:59:22,621 - ERROR - Exception in processing DMHIX: 'Symbol'
# 2025-02-13 15:59:22,621 - ERROR - Exception in processing DVHIX: 'Symbol'
# 2025-02-13 15:59:22,622 - ERROR - Exception in processing IREIX: 'Symbol'
# 2025-02-13 15:59:22,623 - ERROR - Exception in processing DCCIX: 'Symbol'
# 2025-02-13 15:59:22,624 - ERROR - Exception in processing DUGIX: 'Symbol'
# 2025-02-13 15:59:22,624 - ERROR - Exception in processing DCTIX: 'Symbol'
# 2025-02-13 15:59:22,625 - ERROR - Exception in processing DCOIX: 'Symbol'
# 2025-02-13 15:59:22,625 - ERROR - Exception in processing DTIDX: 'Symbol'
# 2025-02-13 15:59:22,625 - ERROR - Exception in processing DMNIX: 'Symbol'
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
import pandas as pd
import sqlalchemy
from sqlalchemy import text
import logging
from concurrent.futures import ThreadPoolExecutor, as_completed
import time
import json
from tenacity import retry, stop_after_attempt, wait_exponential
import ssl
import certifi
from requests.adapters import HTTPAdapter
import requests

# Setup logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s', handlers=[
    logging.StreamHandler()  # Log to console
])
logger = logging.getLogger(__name__)

# Database Connection Configuration
connection_string = (
    "mssql+pyodbc://JULIANS_LAPTOP\\SQLEXPRESS/"
    "CWA_Fund_Database?driver=ODBC+Driver+18+for+SQL+Server"
    "&trusted_connection=yes&TrustServerCertificate=yes"
)
engine = sqlalchemy.create_engine(
    connection_string,
    pool_size=50,  # Increased pool size to avoid timeouts
    max_overflow=100,  # Adjust based on your system capabilities
    pool_timeout=300  # Increased timeout to handle long-running queries
)

# YCharts API Configuration
YCHARTS_API_URL = "https://api.ycharts.com"
API_HEADERS = {
    "X-YCHARTSAUTHORIZATION": "yIIphqbsQysnTvWWxfW33w",  # Replace with your actual API key
    "X-YCHARTSEXCELSESSION": "b645cd897b2446bfa3796acfa3a879db",
    "X-YCHARTSEXCELVERSION": "4.4",
    "X-YCHARTSOPERATINGSYSTEM": "Microsoft Windows NT 10.0.26100.0",
    "Content-Type": "application/x-www-form-urlencoded"
}

# SSL Context for HTTPS connections
context = ssl.create_default_context(cafile=certifi.where())
context.check_hostname = False
context.verify_mode = ssl.CERT_NONE  # Use CERT_REQUIRED in production

class CustomHTTPAdapter(HTTPAdapter):
    def init_poolmanager(self, *args, **kwargs):
        kwargs['ssl_context'] = context
        return super().init_poolmanager(*args, **kwargs)

session = requests.Session()
session.mount('https://', CustomHTTPAdapter())

# Metrics mapping 
column_to_ycharts_mapping = [
    ("InceptionDate", "inception_date", "YCI"),
    ("EarliestPerformanceDate", "earliest_performance_date", "YCI"),
    ("LCG", "equity_stylebox_large_cap_growth_exposure", "YCP"),
    ("LCB", "equity_stylebox_large_cap_blend_exposure", "YCP"),
    ("LCV", "equity_stylebox_large_cap_value_exposure", "YCP"),
    ("MCG", "equity_stylebox_mid_cap_growth_exposure", "YCP"),
    ("MCB", "equity_stylebox_mid_cap_blend_exposure", "YCP"),
    ("MCV", "equity_stylebox_mid_cap_value_exposure", "YCP"),
    ("SCG", "equity_stylebox_small_cap_growth_exposure", "YCP"),
    ("SCB", "equity_stylebox_small_cap_blend_exposure", "YCP"),
    ("SCV", "equity_stylebox_small_cap_value_exposure", "YCP"),
    ("Giant_Cap_Exposure", "giant_cap_exposure", "YCP"),
    ("Large_Cap_Exposure", "large_cap_exposure", "YCP"),
    ("Medium_Cap_Exposure", "medium_cap_exposure", "YCP"),
    ("Micro_Cap_Exposure", "micro_cap_exposure", "YCP"),
    ("Sensitive_Exposure", "sensitive_exposure", "YCP"),
    ("Small_Cap_Exposure", "small_cap_exposure", "YCP"),
    ("Cyclical_Exposure", "cyclical_exposure", "YCP"),
    ("Defensive_Exposure", "defensive_exposure", "YCP"),
    ("AAA_Rated", "aaa_bond_exposure", "YCP"),
    ("AA_Rated", "aa_bond_exposure", "YCP"),
    ("A_Rated", "a_bond_exposure", "YCP"),
    ("BBB_Rated", "bbb_bond_exposure", "YCP"),
    ("B_Rated", "b_bond_exposure", "YCP"),
    ("BB_Rated", "bb_bond_exposure", "YCP"),
    ("Below_B_Rated", "below_b_bond_exposure", "YCP"),
    ("Not_Rated", "not_rated_bond_exposure", "YCP"),
    ("Term_10_15_Y", "10_to_15_years_maturity_bond_exposure", "YCP"),
    ("Term_1_3_Y", "1_to_3_years_maturity_bond_exposure", "YCP"),
    ("Term_15_20_Y", "15_to_20_years_maturity_bond_exposure", "YCP"),
    ("Term_1_7_D", "1_to_7_days_maturity_bond_exposure", "YCP"),
    ("Term_183_364_D", "183_to_364_days_maturity_bond_exposure", "YCP"),
    ("Term_20_30_Y", "20_to_30_years_maturity_bond_exposure", "YCP"),
    ("Term_30_Plus_Y", "over_30_years_maturity_bond_exposure", "YCP"),
    ("Term_31_90_D", "31_to_90_days_maturity_bond_exposure", "YCP"),
    ("Term_3_5_Y", "3_to_5_years_maturity_bond_exposure", "YCP"),
    ("Term_5_7_Y", "5_to_7_years_maturity_bond_exposure", "YCP"),
    ("Term_7_10_Y", "7_to_10_years_maturity_bond_exposure", "YCP"),
    ("Term_8_30_D", "8_to_30_days_maturity_bond_exposure", "YCP"),
    ("Term_91_182_D", "91_to_182_days_maturity_bond_exposure", "YCP"),
    ("LT_Exposure", "long_term_exposure", "YCP"),
    ("Interm_Exposure", "intermediate_term_exposure", "YCP"),
    ("ST_Exposure", "short_term_exposure", "YCP"),
    ("pct_top_10", "percent_of_assets_in_top_10_holdings", "YCP"),
    ("pct_top_25", "percent_of_assets_in_top_25_holdings", "YCP"),
    ("materials", "basic_materials_exposure", "YCP"),
    ("comsvc", "communication_services_exposure", "YCP"),
    ("concyc", "consumer_cyclical_exposure", "YCP"),
    ("condef", "consumer_defensive_exposure", "YCP"),
    ("energy", "energy_exposure", "YCP"),
    ("finsvc", "financial_services_exposure", "YCP"),
    ("healthcare", "healthcare_exposure", "YCP"),
    ("industrials", "industrials_exposure", "YCP"),
    ("realestate", "real_estate_exposure", "YCP"),
    ("technology", "technology_exposure", "YCP"),
    ("utilities", "utilities_exposure", "YCP"),
    ("relative_composition", "relative_composition", "YCP"),
    ("num_bonds", "number_of_bond_holdings", "YCP"),
    ("num_stocks", "number_of_stock_holdings", "YCP"),
    ("dev_mkt", "developed_market_exposure", "YCP"),
    ("em_mkt", "emerging_market_exposure", "YCP"),
    ("europe", "greater_europe_total_exposure", "YCP"),
    ("lat_america", "latin_america_total_exposure", "YCP"),
    ("namerica", "north_america_total_exposure", "YCP"),
    ("africa_mideast", "africa_middle_east_total_exposure", "YCP"),
    ("asia_em", "asia_emerging_total_exposure", "YCP"),
    ("asia_dev", "asia_developed_total_exposure", "YCP"),
    ("australia", "australasia_total_exposure", "YCP"),
    ("india", "india_total_exposure", "YCP"),
    ("w_avg_dc", "weighted_average_debt_to_capital", "YCP"),
    ("avg_mkt_cap", "average_market_cap", "YCP"),
    ("avg_pe_ratio", "weighted_average_pe_ratio", "YCP"),
    ("avg_pb_ratio", "weighted_average_price_to_book_ratio", "YCP"),
    ("avg_pcf_ratio", "weighted_average_price_to_cash_flow", "YCP"),
    ("avg_ps_ratio", "weighted_average_price_to_sales_ratio", "YCP"),
    ("avg_net_margin", "weighted_median_net_margin", "YCP"),
    ("avg_roa", "weighted_median_return_on_assets", "YCP"),
    ("avg_roe", "weighted_median_return_on_equity", "YCP"),
    ("preferreds", "preferred_stock_exposure", "YCP"),
    ("securitized", "securitized_fixed_income_exposure", "YCP"),
    ("muni_exempt", "municipal_tax_exempt_bond_exposure", "YCP"),
    ("muni_tax", "municipal_taxable_bond_exposure", "YCP"),
    ("muni_exposure", "municipal_fixed_income_exposure", "YCP"),
    ("corp_exposure", "corporate_bond_exposure", "YCP"),
    ("corp_fi", "corporate_fixed_income_exposure", "YCP"),
    ("govi_exp", "government_bond_exposure", "YCP"),
    ("govi_fi", "government_fixed_income_exposure", "YCP"),
    ("covered_bond", "covered_bond_exposure", "YCP"),
    ("gov_bond", "government_related_bond_exposure", "YCP"),
    ("converts", "convertible_bond_exposure", "YCP"),
    ("asset_backed_sec", "asset_backed_security_exposure", "YCP"),
    ("index_fund", "index_fund", "YCI"),
    ("inverse_fund", "inverse_fund", "YCI"),
    ("leveraged_fund", "leveraged_fund", "YCI"),
    ("socially_responsible_fund", "socially_responsible_fund", "YCI"),
    ("synthetic_replication_fund", "synthetic_replication_fund", "YCI"),
    ("aum_usd", "aum_usd", "YCI"),
    ("average_manager_tenure", "average_manager_tenure", "YCP"),
    ("max_manager_tenure", "max_manager_tenure", "YCP"),
    ("median_manager_tenure", "median_manager_tenure", "YCP"),
    ("min_manager_tenure", "min_manager_tenure", "YCP"),
    ("open_to_existing_investors", "open_to_existing_investors", "YCI"),
    ("open_to_new_investors", "open_to_new_investors", "YCI"),
    ("ycharts_url", "ycharts_url", "YCI"),
    ("years_since_inception", "years_since_inception", "YCP"),
    ("investment_strategy", "investment_strategy", "YCI"),
    ("related_securities", "related_securities", "YCI"), #returns both symbols and names, only need symbols
    ("fund_family", "fund_family", "YCI")
]

# Extract metrics that should be fetched
METRICS = [(col, code, api) for col, code, api in column_to_ycharts_mapping if api in ["YCP", "YCI"]]

# YCP Functions
def build_points_lines(symbol, yc_code, is_mutual):
    symbol_for_api = f"M:{symbol}" if is_mutual else symbol
    return f"{symbol_for_api},{yc_code}"

@retry(stop=stop_after_attempt(3), wait=wait_exponential(multiplier=1, min=4, max=10))
def fetch_ycp_data_point(symbol, metric, fund_type_id):
    is_mutual = (fund_type_id == 3)
    for col, yc_code, api_type in METRICS:
        if col == metric and api_type == "YCP":
            points_line = build_points_lines(symbol, yc_code, is_mutual)
            payload = f"points={points_line}"
            api_url = f"{YCHARTS_API_URL}/v3/excel/points"
            try:
                response = session.post(api_url, headers=API_HEADERS, data=payload, timeout=60)
                response.raise_for_status()
                data = response.json()
                symbol_for_api = f"M:{symbol}" if is_mutual else symbol
                if 'response' in data and symbol_for_api in data['response']:
                    results = data['response'][symbol_for_api].get("results", {})
                    if yc_code in results:
                        datapoints = results[yc_code].get("data")
                        if datapoints and isinstance(datapoints, list):
                            last_point = datapoints[-1]
                            if isinstance(last_point, list) and len(last_point) > 1:
                                return last_point[1]
                logger.warning(f"No valid data returned for symbol '{symbol}' on metric '{metric}'")
                return None
            except requests.exceptions.RequestException as e:
                logger.error(f"API error for symbol '{symbol}' on metric '{metric}': {e}")
                return None
    return None

# YCI Functions
@retry(stop=stop_after_attempt(3), wait=wait_exponential(multiplier=1, min=4, max=10))
def fetch_yci_metric(symbol, fund_type_id, metric):
    for col, yc_code, api_type in METRICS:
        if col == metric and api_type == "YCI":
            if fund_type_id == 3:
                symbol_for_api = f"M:{symbol}"
                endpoint = "mutual_funds"
            else:
                symbol_for_api = symbol
                endpoint = "companies"
            api_url = f"{YCHARTS_API_URL}/v3/{endpoint}/{symbol_for_api}/info/{yc_code}?retrieve_ttl=true"
            logger.info(f"Fetching {metric} for {symbol} using URL: {api_url}")
            try:
                response = session.get(api_url, headers=API_HEADERS, timeout=30)
                response.raise_for_status()
                data = response.json()
                response_key = f"M:{symbol}" if fund_type_id == 3 else symbol
                metric_value = data.get("response", {}).get(response_key, {}).get("results", {}).get(yc_code, {}).get("data")
                
                if metric == "related_securities" and isinstance(metric_value, list):
                    metric_value = [sec.get('security_id') for sec in metric_value if isinstance(sec, dict) and 'security_id' in sec]
                return metric_value
            except Exception as e:
                logger.error(f"Error fetching {metric} for {symbol}: {e}")
                return None
    return None

def process_fund(row):
    symbol, fund_type_id = row['SymbolCUSIP'], row['Fund_Type_ID']
    data = {"symbol": symbol}
    
    for metric, _, api_type in METRICS:
        if api_type == "YCP":
            data[metric] = fetch_ycp_data_point(symbol, metric, fund_type_id)
        elif api_type == "YCI":
            data[metric] = fetch_yci_metric(symbol, fund_type_id, metric)
    
    # Prepare data for DB update, convert lists to JSON for 'related_securities'
    data = {k: json.dumps(v) if k == 'related_securities' and isinstance(v, list) else v for k, v in data.items()}
    
    try:
        with engine.begin() as conn:
            # Update existing record
            update_sql = f"UPDATE Funds_to_Screen SET {', '.join([f'{col} = :{col}' for col in data.keys() if col != 'symbol'])} WHERE SymbolCUSIP = :symbol"
            result = conn.execute(text(update_sql), data)
            
            # Check if any rows were affected by the UPDATE operation
            if result.rowcount > 0:
                logger.info(f"Updated metrics for symbol {symbol}")
                return {'symbol': symbol, 'status': 'updated'}
            else:
                logger.warning(f"No rows updated for symbol {symbol}, symbol might not exist in the database")
                return {'symbol': symbol, 'status': 'not_updated'}

    except Exception as e:
        logger.error(f"Database error for {symbol}: {e}")
        return {'symbol': symbol, 'status': 'error'}

def main():
    start_time = time.time()
    logger.info("Starting data fetch and update process.")

    # Load symbols from Excel
    df = pd.read_excel('C:\\Users\\JulianHeron\\fund_type_and_symbol.xlsx', usecols=["SymbolCUSIP", "Fund_Type_ID"])
    
    processed_count = 0
    error_count = 0
    not_updated_count = 0
    with ThreadPoolExecutor(max_workers=20) as executor:
        futures = {executor.submit(process_fund, row): row for _, row in df.iterrows()}
        
        for future in as_completed(futures):
            try:
                result = future.result()
                if result['status'] == 'updated':
                    processed_count += 1
                elif result['status'] == 'not_updated':
                    not_updated_count += 1
                elif result['status'] == 'error':
                    error_count += 1
                logger.info(f"Processed {result['symbol']}: {result['status']}")
            except Exception as e:
                error_count += 1
                logger.error(f"Exception in processing {futures[future]['SymbolCUSIP']}: {e}")
    
    # Call the stored procedure here after all processing is done
    try:
        with engine.begin() as conn:
            conn.execute(text("EXEC UpdateDerivedMetrics"))
        logger.info("Successfully executed UpdateDerivedMetrics stored procedure.")
    except Exception as e:
        logger.error(f"Failed to execute UpdateDerivedMetrics stored procedure: {e}")

    total_time = time.time() - start_time
    logger.info(f"Completed processing. Updated: {processed_count}, Not Updated: {not_updated_count}, Errors: {error_count}, Total Time: {total_time:.2f} seconds")

if __name__ == "__main__":
    main()
# Out:
# 2025-02-13 16:11:39,552 - INFO - Starting data fetch and update process.
# 2025-02-13 16:11:39,636 - INFO - Fetching InceptionDate for MDIV using URL: https://api.ycharts.com/v3/companies/MDIV/info/inception_date?retrieve_ttl=true
# 2025-02-13 16:11:39,638 - INFO - Fetching InceptionDate for ROMO using URL: https://api.ycharts.com/v3/companies/ROMO/info/inception_date?retrieve_ttl=true
# 2025-02-13 16:11:39,654 - INFO - Fetching InceptionDate for RISN using URL: https://api.ycharts.com/v3/companies/RISN/info/inception_date?retrieve_ttl=true
# 2025-02-13 16:11:39,655 - INFO - Fetching InceptionDate for MAPP using URL: https://api.ycharts.com/v3/companies/MAPP/info/inception_date?retrieve_ttl=true
# 2025-02-13 16:11:39,657 - INFO - Fetching InceptionDate for GAL using URL: https://api.ycharts.com/v3/companies/GAL/info/inception_date?retrieve_ttl=true
# 2025-02-13 16:11:39,659 - INFO - Fetching InceptionDate for AOA using URL: https://api.ycharts.com/v3/companies/AOA/info/inception_date?retrieve_ttl=true
# 2025-02-13 16:11:39,661 - INFO - Fetching InceptionDate for NTSI using URL: https://api.ycharts.com/v3/companies/NTSI/info/inception_date?retrieve_ttl=true
# 2025-02-13 16:11:39,666 - INFO - Fetching InceptionDate for PPI using URL: https://api.ycharts.com/v3/companies/PPI/info/inception_date?retrieve_ttl=true
# 2025-02-13 16:11:39,667 - INFO - Fetching InceptionDate for PCEF using URL: https://api.ycharts.com/v3/companies/PCEF/info/inception_date?retrieve_ttl=true
# 2025-02-13 16:11:39,671 - INFO - Fetching InceptionDate for GAA using URL: https://api.ycharts.com/v3/companies/GAA/info/inception_date?retrieve_ttl=true
# 2025-02-13 16:11:39,674 - INFO - Fetching InceptionDate for DSCF using URL: https://api.ycharts.com/v3/companies/DSCF/info/inception_date?retrieve_ttl=true
# 2025-02-13 16:11:39,675 - INFO - Fetching InceptionDate for HNDL using URL: https://api.ycharts.com/v3/companies/HNDL/info/inception_date?retrieve_ttl=true
# 2025-02-13 16:11:39,680 - INFO - Fetching InceptionDate for RPAR using URL: https://api.ycharts.com/v3/companies/RPAR/info/inception_date?retrieve_ttl=true
# 2025-02-13 16:11:39,687 - INFO - Fetching InceptionDate for TWIO using URL: https://api.ycharts.com/v3/companies/TWIO/info/inception_date?retrieve_ttl=true
# 2025-02-13 16:11:39,688 - INFO - Fetching InceptionDate for CWB using URL: https://api.ycharts.com/v3/companies/CWB/info/inception_date?retrieve_ttl=true
# 2025-02-13 16:11:39,690 - INFO - Fetching InceptionDate for CVRT using URL: https://api.ycharts.com/v3/companies/CVRT/info/inception_date?retrieve_ttl=true
# 2025-02-13 16:11:39,692 - INFO - Fetching InceptionDate for FCVT using URL: https://api.ycharts.com/v3/companies/FCVT/info/inception_date?retrieve_ttl=true
# 2025-02-13 16:11:39,695 - INFO - Fetching InceptionDate for QCON using URL: https://api.ycharts.com/v3/companies/QCON/info/inception_date?retrieve_ttl=true
# 2025-02-13 16:11:39,696 - INFO - Fetching InceptionDate for DRAI using URL: https://api.ycharts.com/v3/companies/DRAI/info/inception_date?retrieve_ttl=true
# 2025-02-13 16:11:39,701 - INFO - Fetching InceptionDate for RLY using URL: https://api.ycharts.com/v3/companies/RLY/info/inception_date?retrieve_ttl=true
# 2025-02-13 16:11:40,369 - INFO - Fetching EarliestPerformanceDate for MDIV using URL: https://api.ycharts.com/v3/companies/MDIV/info/earliest_performance_date?retrieve_ttl=true
# 2025-02-13 16:11:40,371 - INFO - Fetching EarliestPerformanceDate for GAA using URL: https://api.ycharts.com/v3/companies/GAA/info/earliest_performance_date?retrieve_ttl=true
# 2025-02-13 16:11:40,373 - INFO - Fetching EarliestPerformanceDate for PCEF using URL: https://api.ycharts.com/v3/companies/PCEF/info/earliest_performance_date?retrieve_ttl=true
# 2025-02-13 16:11:40,376 - INFO - Fetching EarliestPerformanceDate for MAPP using URL: https://api.ycharts.com/v3/companies/MAPP/info/earliest_performance_date?retrieve_ttl=true
# 2025-02-13 16:11:40,381 - INFO - Fetching EarliestPerformanceDate for PPI using URL: https://api.ycharts.com/v3/companies/PPI/info/earliest_performance_date?retrieve_ttl=true
# 2025-02-13 16:11:40,383 - INFO - Fetching EarliestPerformanceDate for AOA using URL: https://api.ycharts.com/v3/companies/AOA/info/earliest_performance_date?retrieve_ttl=true
# 2025-02-13 16:11:40,387 - INFO - Fetching EarliestPerformanceDate for DSCF using URL: https://api.ycharts.com/v3/companies/DSCF/info/earliest_performance_date?retrieve_ttl=true
# 2025-02-13 16:11:40,387 - INFO - Fetching EarliestPerformanceDate for RISN using URL: https://api.ycharts.com/v3/companies/RISN/info/earliest_performance_date?retrieve_ttl=true
# 2025-02-13 16:11:40,390 - INFO - Fetching EarliestPerformanceDate for GAL using URL: https://api.ycharts.com/v3/companies/GAL/info/earliest_performance_date?retrieve_ttl=true
# 2025-02-13 16:11:40,429 - INFO - Fetching EarliestPerformanceDate for ROMO using URL: https://api.ycharts.com/v3/companies/ROMO/info/earliest_performance_date?retrieve_ttl=true
# 2025-02-13 16:11:40,439 - INFO - Fetching EarliestPerformanceDate for NTSI using URL: https://api.ycharts.com/v3/companies/NTSI/info/earliest_performance_date?retrieve_ttl=true
# 2025-02-13 16:11:40,442 - INFO - Fetching EarliestPerformanceDate for HNDL using URL: https://api.ycharts.com/v3/companies/HNDL/info/earliest_performance_date?retrieve_ttl=true
# 2025-02-13 16:11:40,444 - INFO - Fetching EarliestPerformanceDate for RPAR using URL: https://api.ycharts.com/v3/companies/RPAR/info/earliest_performance_date?retrieve_ttl=true
# 2025-02-13 16:11:40,618 - INFO - Fetching EarliestPerformanceDate for CVRT using URL: https://api.ycharts.com/v3/companies/CVRT/info/earliest_performance_date?retrieve_ttl=true
# 2025-02-13 16:11:40,620 - INFO - Fetching EarliestPerformanceDate for CWB using URL: https://api.ycharts.com/v3/companies/CWB/info/earliest_performance_date?retrieve_ttl=true
# 2025-02-13 16:11:40,623 - INFO - Fetching EarliestPerformanceDate for TWIO using URL: https://api.ycharts.com/v3/companies/TWIO/info/earliest_performance_date?retrieve_ttl=true
# 2025-02-13 16:11:40,627 - INFO - Fetching EarliestPerformanceDate for QCON using URL: https://api.ycharts.com/v3/companies/QCON/info/earliest_performance_date?retrieve_ttl=true
# 2025-02-13 16:11:40,631 - INFO - Fetching EarliestPerformanceDate for FCVT using URL: https://api.ycharts.com/v3/companies/FCVT/info/earliest_performance_date?retrieve_ttl=true
# 2025-02-13 16:11:40,633 - INFO - Fetching EarliestPerformanceDate for RLY using URL: https://api.ycharts.com/v3/companies/RLY/info/earliest_performance_date?retrieve_ttl=true
# 2025-02-13 16:11:40,635 - INFO - Fetching EarliestPerformanceDate for DRAI using URL: https://api.ycharts.com/v3/companies/DRAI/info/earliest_performance_date?retrieve_ttl=true
# 2025-02-13 16:11:40,706 - WARNING - No valid data returned for symbol 'MAPP' on metric 'LCG'
# 2025-02-13 16:11:40,709 - WARNING - No valid data returned for symbol 'GAL' on metric 'LCG'
# 2025-02-13 16:11:40,709 - WARNING - No valid data returned for symbol 'PPI' on metric 'LCG'
# 2025-02-13 16:11:40,709 - WARNING - No valid data returned for symbol 'PCEF' on metric 'LCG'
# 2025-02-13 16:11:43,139 - WARNING - No valid data returned for symbol 'CWB' on metric 'AA_Rated'
# 2025-02-13 16:11:43,140 - WARNING - No valid data returned for symbol 'RPAR' on metric 'A_Rated'
# 2025-02-13 16:11:43,144 - WARNING - No valid data returned for symbol 'FCVT' on metric 'AA_Rated'
# 2025-02-13 16:11:43,149 - WARNING - No valid data returned for symbol 'TWIO' on metric 'BBB_Rated'
# 2025-02-13 16:11:43,158 - WARNING - No valid data returned for symbol 'DSCF' on metric 'B_Rated'
# 2025-02-13 16:11:43,159 - WARNING - No valid data returned for symbol 'NTSI' on metric 'BBB_Rated'
# 2025-02-13 16:11:43,160 - WARNING - No valid data returned for symbol 'MAPP' on metric 'B_Rated'
# 2025-02-13 16:11:43,162 - WARNING - No valid data returned for symbol 'CVRT' on metric 'AAA_Rated'
# 2025-02-13 16:11:43,163 - WARNING - No valid data returned for symbol 'AOA' on metric 'BB_Rated'
# 2025-02-13 16:11:43,164 - WARNING - No valid data returned for symbol 'PCEF' on metric 'B_Rated'
# 2025-02-13 16:11:43,172 - WARNING - No valid data returned for symbol 'GAL' on metric 'BB_Rated'
# 2025-02-13 16:11:43,199 - WARNING - No valid data returned for symbol 'GAA' on metric 'B_Rated'
# 2025-02-13 16:11:43,204 - WARNING - No valid data returned for symbol 'RISN' on metric 'B_Rated'
# 2025-02-13 16:11:43,208 - WARNING - No valid data returned for symbol 'QCON' on metric 'AA_Rated'
# ...
# 2025-02-13 16:11:58,305 - WARNING - No valid data returned for symbol 'GYLD' on metric 'BB_Rated'
# 2025-02-13 16:11:58,320 - WARNING - No valid data returned for symbol 'TDSC' on metric 'realestate'
# 2025-02-13 16:11:58,321 - WARNING - No valid data returned for symbol 'NDAA' on metric 'pct_top_25'
# 2025-02-13 16:11:58,324 - WARNING - No valid data returned for symbol 'RSSB' on metric 'pct_top_25'
# 2025-02-13 16:11:58,327 - WARNING - No valid data returned for symbol 'ASET' on metric 'materials'
# 2025-02-13 16:11:58,333 - WARNING - No valid data returned for symbol 'TDSB' on metric 'energy'
# 2025-02-13 16:11:58,334 - WARNING - No valid data returned for symbol 'TACK' on metric 'condef'
# 2025-02-13 16:11:58,339 - WARNING - No valid data returned for symbol 'BSR' on metric 'energy'
# 2025-02-13 16:11:58,341 - WARNING - No valid data returned for symbol 'TBFC' on metric 'num_stocks'
# 2025-02-13 16:11:58,343 - WARNING - No valid data returned for symbol 'GMMA' on metric 'realestate'
# 2025-02-13 16:11:58,349 - WARNING - No valid data returned for symbol 'CEFS' on metric 'industrials'
# 2025-02-13 16:11:58,349 - WARNING - No valid data returned for symbol 'MVFD' on metric 'Defensive_Exposure'
# 2025-02-13 16:11:58,354 - WARNING - No valid data returned for symbol 'FCEF' on metric 'pct_top_25'
# 2025-02-13 16:11:58,355 - WARNING - No valid data returned for symbol 'NTSE' on metric 'condef'
# 2025-02-13 16:11:58,357 - WARNING - No valid data returned for symbol 'DALI' on metric 'condef'
# 2025-02-13 16:11:58,371 - WARNING - No valid data returned for symbol 'TBFG' on metric 'realestate'
# 2025-02-13 16:11:58,388 - WARNING - No valid data returned for symbol 'PWS' on metric 'industrials'
# 2025-02-13 16:11:58,391 - WARNING - No valid data returned for symbol 'NDOW' on metric 'concyc'
# 2025-02-13 16:11:58,393 - WARNING - No valid data returned for symbol 'CCEF' on metric 'materials'
# 2025-02-13 16:11:58,403 - WARNING - No valid data returned for symbol 'GYLD' on metric 'Below_B_Rated'
# 2025-02-13 16:11:58,410 - WARNING - No valid data returned for symbol 'MOOD' on metric 'technology'
# 2025-02-13 16:11:58,412 - WARNING - No valid data returned for symbol 'NDAA' on metric 'materials'
# 2025-02-13 16:11:58,418 - WARNING - No valid data returned for symbol 'TDSC' on metric 'technology'
# 2025-02-13 16:11:58,433 - WARNING - No valid data returned for symbol 'TDSB' on metric 'finsvc'
# 2025-02-13 16:11:58,434 - WARNING - No valid data returned for symbol 'ASET' on metric 'comsvc'
# 2025-02-13 16:11:58,438 - WARNING - No valid data returned for symbol 'RSSB' on metric 'materials'
# 2025-02-13 16:11:58,438 - WARNING - No valid data returned for symbol 'TACK' on metric 'energy'
# 2025-02-13 16:11:58,440 - WARNING - No valid data returned for symbol 'TBFC' on metric 'dev_mkt'
# 2025-02-13 16:11:58,444 - WARNING - No valid data returned for symbol 'GMMA' on metric 'technology'
# 2025-02-13 16:11:58,446 - WARNING - No valid data returned for symbol 'BSR' on metric 'finsvc'
# 2025-02-13 16:11:58,450 - WARNING - No valid data returned for symbol 'CEFS' on metric 'realestate'
# 2025-02-13 16:11:58,451 - WARNING - No valid data returned for symbol 'NTSE' on metric 'energy'
# 2025-02-13 16:11:58,454 - WARNING - No valid data returned for symbol 'FCEF' on metric 'materials'
# 2025-02-13 16:11:58,458 - WARNING - No valid data returned for symbol 'DALI' on metric 'energy'
# 2025-02-13 16:11:58,458 - WARNING - No valid data returned for symbol 'MVFD' on metric 'AAA_Rated'
# 2025-02-13 16:11:58,499 - WARNING - No valid data returned for symbol 'NDOW' on metric 'condef'
# 2025-02-13 16:11:58,499 - WARNING - No valid data returned for symbol 'PWS' on metric 'realestate'
# 2025-02-13 16:11:58,500 - WARNING - No valid data returned for symbol 'CCEF' on metric 'comsvc'
# 2025-02-13 16:11:58,500 - WARNING - No valid data returned for symbol 'TBFG' on metric 'technology'
# 2025-02-13 16:11:58,505 - WARNING - No valid data returned for symbol 'MOOD' on metric 'utilities'
# 2025-02-13 16:11:58,514 - WARNING - No valid data returned for symbol 'NDAA' on metric 'comsvc'
# 2025-02-13 16:11:58,514 - WARNING - No valid data returned for symbol 'TDSC' on metric 'utilities'
# 2025-02-13 16:11:58,515 - WARNING - No valid data returned for symbol 'GYLD' on metric 'Not_Rated'
# 2025-02-13 16:11:58,532 - WARNING - No valid data returned for symbol 'ASET' on metric 'concyc'
# 2025-02-13 16:11:58,546 - WARNING - No valid data returned for symbol 'TDSB' on metric 'healthcare'
# 2025-02-13 16:11:58,546 - WARNING - No valid data returned for symbol 'TACK' on metric 'finsvc'
# 2025-02-13 16:11:58,548 - WARNING - No valid data returned for symbol 'RSSB' on metric 'comsvc'
# 2025-02-13 16:11:58,551 - WARNING - No valid data returned for symbol 'BSR' on metric 'healthcare'
# 2025-02-13 16:11:58,553 - WARNING - No valid data returned for symbol 'FCEF' on metric 'comsvc'
# 2025-02-13 16:11:58,555 - WARNING - No valid data returned for symbol 'CEFS' on metric 'technology'
# 2025-02-13 16:11:58,556 - WARNING - No valid data returned for symbol 'GMMA' on metric 'utilities'
# 2025-02-13 16:11:58,559 - WARNING - No valid data returned for symbol 'MVFD' on metric 'AA_Rated'
# 2025-02-13 16:11:58,562 - WARNING - No valid data returned for symbol 'DALI' on metric 'finsvc'
# 2025-02-13 16:11:58,562 - WARNING - No valid data returned for symbol 'TBFC' on metric 'em_mkt'
# 2025-02-13 16:11:58,564 - WARNING - No valid data returned for symbol 'NTSE' on metric 'finsvc'
# 2025-02-13 16:11:58,601 - WARNING - No valid data returned for symbol 'MOOD' on metric 'relative_composition'
# 2025-02-13 16:11:58,604 - WARNING - No valid data returned for symbol 'NDOW' on metric 'energy'
# 2025-02-13 16:11:58,605 - WARNING - No valid data returned for symbol 'TBFG' on metric 'utilities'
# 2025-02-13 16:11:58,607 - WARNING - No valid data returned for symbol 'PWS' on metric 'technology'
# 2025-02-13 16:11:58,610 - WARNING - No valid data returned for symbol 'NDAA' on metric 'concyc'
# 2025-02-13 16:11:58,613 - WARNING - No valid data returned for symbol 'GYLD' on metric 'Term_10_15_Y'
# 2025-02-13 16:11:58,618 - WARNING - No valid data returned for symbol 'CCEF' on metric 'concyc'
# 2025-02-13 16:11:58,620 - WARNING - No valid data returned for symbol 'TDSC' on metric 'relative_composition'
# 2025-02-13 16:11:58,635 - WARNING - No valid data returned for symbol 'ASET' on metric 'condef'
# 2025-02-13 16:11:58,644 - WARNING - No valid data returned for symbol 'TDSB' on metric 'industrials'
# 2025-02-13 16:11:58,647 - WARNING - No valid data returned for symbol 'FCEF' on metric 'concyc'
# 2025-02-13 16:11:58,648 - WARNING - No valid data returned for symbol 'TACK' on metric 'healthcare'
# 2025-02-13 16:11:58,656 - WARNING - No valid data returned for symbol 'RSSB' on metric 'concyc'
# 2025-02-13 16:11:58,658 - WARNING - No valid data returned for symbol 'BSR' on metric 'industrials'
# 2025-02-13 16:11:58,661 - WARNING - No valid data returned for symbol 'GMMA' on metric 'relative_composition'
# 2025-02-13 16:11:58,664 - WARNING - No valid data returned for symbol 'MVFD' on metric 'A_Rated'
# 2025-02-13 16:11:58,665 - WARNING - No valid data returned for symbol 'NTSE' on metric 'healthcare'
# 2025-02-13 16:11:58,667 - WARNING - No valid data returned for symbol 'CEFS' on metric 'utilities'
# 2025-02-13 16:11:58,672 - WARNING - No valid data returned for symbol 'TBFC' on metric 'europe'
# 2025-02-13 16:11:58,684 - WARNING - No valid data returned for symbol 'DALI' on metric 'healthcare'
# 2025-02-13 16:11:58,700 - WARNING - No valid data returned for symbol 'MOOD' on metric 'num_bonds'
# 2025-02-13 16:11:58,701 - WARNING - No valid data returned for symbol 'NDOW' on metric 'finsvc'
# 2025-02-13 16:11:58,710 - WARNING - No valid data returned for symbol 'NDAA' on metric 'condef'
# 2025-02-13 16:11:58,711 - WARNING - No valid data returned for symbol 'PWS' on metric 'utilities'
# 2025-02-13 16:11:58,712 - WARNING - No valid data returned for symbol 'TBFG' on metric 'relative_composition'
# 2025-02-13 16:11:58,716 - WARNING - No valid data returned for symbol 'GYLD' on metric 'Term_1_3_Y'
# 2025-02-13 16:11:58,720 - WARNING - No valid data returned for symbol 'TDSC' on metric 'num_bonds'
# 2025-02-13 16:11:58,725 - WARNING - No valid data returned for symbol 'CCEF' on metric 'condef'
# 2025-02-13 16:11:58,734 - WARNING - No valid data returned for symbol 'ASET' on metric 'energy'
# 2025-02-13 16:11:58,736 - WARNING - No valid data returned for symbol 'TDSB' on metric 'realestate'
# 2025-02-13 16:11:58,745 - WARNING - No valid data returned for symbol 'FCEF' on metric 'condef'
# 2025-02-13 16:11:58,749 - WARNING - No valid data returned for symbol 'BSR' on metric 'realestate'
# 2025-02-13 16:11:58,751 - WARNING - No valid data returned for symbol 'TACK' on metric 'industrials'
# 2025-02-13 16:11:58,762 - WARNING - No valid data returned for symbol 'GMMA' on metric 'num_bonds'
# 2025-02-13 16:11:58,766 - WARNING - No valid data returned for symbol 'RSSB' on metric 'condef'
# 2025-02-13 16:11:58,767 - WARNING - No valid data returned for symbol 'NTSE' on metric 'industrials'
# 2025-02-13 16:11:58,769 - WARNING - No valid data returned for symbol 'CEFS' on metric 'relative_composition'
# 2025-02-13 16:11:58,772 - WARNING - No valid data returned for symbol 'MVFD' on metric 'BBB_Rated'
# 2025-02-13 16:11:58,782 - WARNING - No valid data returned for symbol 'TBFC' on metric 'lat_america'
# 2025-02-13 16:11:58,785 - WARNING - No valid data returned for symbol 'DALI' on metric 'industrials'
# 2025-02-13 16:11:58,792 - WARNING - No valid data returned for symbol 'MOOD' on metric 'num_stocks'
# 2025-02-13 16:11:58,808 - WARNING - No valid data returned for symbol 'PWS' on metric 'relative_composition'
# 2025-02-13 16:11:58,813 - WARNING - No valid data returned for symbol 'NDAA' on metric 'energy'
# 2025-02-13 16:11:58,813 - WARNING - No valid data returned for symbol 'NDOW' on metric 'healthcare'
# 2025-02-13 16:11:58,813 - WARNING - No valid data returned for symbol 'TBFG' on metric 'num_bonds'
# 2025-02-13 16:11:58,822 - WARNING - No valid data returned for symbol 'GYLD' on metric 'Term_15_20_Y'
# 2025-02-13 16:11:58,824 - WARNING - No valid data returned for symbol 'TDSC' on metric 'num_stocks'
# 2025-02-13 16:11:58,827 - WARNING - No valid data returned for symbol 'CCEF' on metric 'energy'
# 2025-02-13 16:11:58,829 - WARNING - No valid data returned for symbol 'ASET' on metric 'finsvc'
# 2025-02-13 16:11:58,840 - WARNING - No valid data returned for symbol 'TDSB' on metric 'technology'
# 2025-02-13 16:11:58,842 - WARNING - No valid data returned for symbol 'FCEF' on metric 'energy'
# 2025-02-13 16:11:58,854 - WARNING - No valid data returned for symbol 'BSR' on metric 'technology'
# 2025-02-13 16:11:58,854 - WARNING - No valid data returned for symbol 'TACK' on metric 'realestate'
# 2025-02-13 16:11:58,860 - WARNING - No valid data returned for symbol 'CEFS' on metric 'num_bonds'
# 2025-02-13 16:11:58,867 - WARNING - No valid data returned for symbol 'RSSB' on metric 'energy'
# 2025-02-13 16:11:58,869 - WARNING - No valid data returned for symbol 'NTSE' on metric 'realestate'
# 2025-02-13 16:11:58,872 - WARNING - No valid data returned for symbol 'GMMA' on metric 'num_stocks'
# 2025-02-13 16:11:58,883 - WARNING - No valid data returned for symbol 'MVFD' on metric 'B_Rated'
# 2025-02-13 16:11:58,886 - WARNING - No valid data returned for symbol 'DALI' on metric 'realestate'
# 2025-02-13 16:11:58,890 - WARNING - No valid data returned for symbol 'TBFC' on metric 'namerica'
# 2025-02-13 16:11:58,891 - WARNING - No valid data returned for symbol 'MOOD' on metric 'dev_mkt'
# 2025-02-13 16:11:58,905 - WARNING - No valid data returned for symbol 'NDAA' on metric 'finsvc'
# 2025-02-13 16:11:58,913 - WARNING - No valid data returned for symbol 'TBFG' on metric 'num_stocks'
# 2025-02-13 16:11:58,918 - WARNING - No valid data returned for symbol 'NDOW' on metric 'industrials'
# 2025-02-13 16:11:58,922 - WARNING - No valid data returned for symbol 'PWS' on metric 'num_bonds'
# 2025-02-13 16:11:58,924 - WARNING - No valid data returned for symbol 'TDSC' on metric 'dev_mkt'
# 2025-02-13 16:11:58,924 - WARNING - No valid data returned for symbol 'GYLD' on metric 'Term_1_7_D'
# 2025-02-13 16:11:58,925 - WARNING - No valid data returned for symbol 'CCEF' on metric 'finsvc'
# 2025-02-13 16:11:58,926 - WARNING - No valid data returned for symbol 'ASET' on metric 'healthcare'
# 2025-02-13 16:11:58,935 - WARNING - No valid data returned for symbol 'TDSB' on metric 'utilities'
# 2025-02-13 16:11:58,946 - WARNING - No valid data returned for symbol 'FCEF' on metric 'finsvc'
# 2025-02-13 16:11:58,949 - WARNING - No valid data returned for symbol 'CEFS' on metric 'num_stocks'
# 2025-02-13 16:11:58,951 - WARNING - No valid data returned for symbol 'TACK' on metric 'technology'
# 2025-02-13 16:11:58,953 - WARNING - No valid data returned for symbol 'BSR' on metric 'utilities'
# 2025-02-13 16:11:58,973 - WARNING - No valid data returned for symbol 'RSSB' on metric 'finsvc'
# 2025-02-13 16:11:58,975 - WARNING - No valid data returned for symbol 'GMMA' on metric 'dev_mkt'
# 2025-02-13 16:11:58,977 - WARNING - No valid data returned for symbol 'NTSE' on metric 'technology'
# 2025-02-13 16:11:58,979 - WARNING - No valid data returned for symbol 'MVFD' on metric 'BB_Rated'
# 2025-02-13 16:11:58,988 - WARNING - No valid data returned for symbol 'TBFC' on metric 'africa_mideast'
# 2025-02-13 16:11:58,995 - WARNING - No valid data returned for symbol 'MOOD' on metric 'em_mkt'
# 2025-02-13 16:11:58,995 - WARNING - No valid data returned for symbol 'DALI' on metric 'technology'
# 2025-02-13 16:11:59,007 - WARNING - No valid data returned for symbol 'TBFG' on metric 'dev_mkt'
# 2025-02-13 16:11:59,007 - WARNING - No valid data returned for symbol 'NDAA' on metric 'healthcare'
# 2025-02-13 16:11:59,023 - WARNING - No valid data returned for symbol 'CCEF' on metric 'healthcare'
# 2025-02-13 16:11:59,025 - WARNING - No valid data returned for symbol 'NDOW' on metric 'realestate'
# 2025-02-13 16:11:59,028 - WARNING - No valid data returned for symbol 'GYLD' on metric 'Term_183_364_D'
# 2025-02-13 16:11:59,029 - WARNING - No valid data returned for symbol 'TDSC' on metric 'em_mkt'
# 2025-02-13 16:11:59,043 - WARNING - No valid data returned for symbol 'PWS' on metric 'num_stocks'
# 2025-02-13 16:11:59,044 - WARNING - No valid data returned for symbol 'ASET' on metric 'industrials'
# 2025-02-13 16:11:59,045 - WARNING - No valid data returned for symbol 'TDSB' on metric 'relative_composition'
# 2025-02-13 16:11:59,049 - WARNING - No valid data returned for symbol 'CEFS' on metric 'dev_mkt'
# 2025-02-13 16:11:59,051 - WARNING - No valid data returned for symbol 'TACK' on metric 'utilities'
# 2025-02-13 16:11:59,053 - WARNING - No valid data returned for symbol 'FCEF' on metric 'healthcare'
# 2025-02-13 16:11:59,055 - WARNING - No valid data returned for symbol 'BSR' on metric 'relative_composition'
# 2025-02-13 16:11:59,077 - WARNING - No valid data returned for symbol 'GMMA' on metric 'em_mkt'
# 2025-02-13 16:11:59,077 - WARNING - No valid data returned for symbol 'RSSB' on metric 'healthcare'
# 2025-02-13 16:11:59,081 - WARNING - No valid data returned for symbol 'MVFD' on metric 'Below_B_Rated'
# 2025-02-13 16:11:59,085 - WARNING - No valid data returned for symbol 'TBFC' on metric 'asia_em'
# 2025-02-13 16:11:59,087 - WARNING - No valid data returned for symbol 'NTSE' on metric 'utilities'
# 2025-02-13 16:11:59,096 - WARNING - No valid data returned for symbol 'MOOD' on metric 'europe'
# 2025-02-13 16:11:59,105 - WARNING - No valid data returned for symbol 'DALI' on metric 'utilities'
# 2025-02-13 16:11:59,106 - WARNING - No valid data returned for symbol 'NDAA' on metric 'industrials'
# 2025-02-13 16:11:59,108 - WARNING - No valid data returned for symbol 'TBFG' on metric 'em_mkt'
# 2025-02-13 16:11:59,123 - WARNING - No valid data returned for symbol 'GYLD' on metric 'Term_20_30_Y'
# 2025-02-13 16:11:59,123 - WARNING - No valid data returned for symbol 'CCEF' on metric 'industrials'
# 2025-02-13 16:11:59,124 - WARNING - No valid data returned for symbol 'TDSC' on metric 'europe'

# %%
import pandas as pd
import sqlalchemy
from sqlalchemy import text
import logging
import time
import json
from tenacity import retry, stop_after_attempt, wait_exponential
import ssl
import certifi
from requests.adapters import HTTPAdapter
import requests

# Setup logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s', handlers=[
    logging.StreamHandler()  # Log to console
])
logger = logging.getLogger(__name__)

# Database Connection Configuration
connection_string = (
    "mssql+pyodbc://JULIANS_LAPTOP\\SQLEXPRESS/"
    "CWA_Fund_Database?driver=ODBC+Driver+18+for+SQL+Server"
    "&trusted_connection=yes&TrustServerCertificate=yes"
)
engine = sqlalchemy.create_engine(
    connection_string,
    pool_size=50,  # Increased pool size to avoid timeouts
    max_overflow=100,  # Adjust based on your system capabilities
    pool_timeout=300  # Increased timeout to handle long-running queries
)

# YCharts API Configuration
YCHARTS_API_URL = "https://api.ycharts.com"
API_HEADERS = {
    "X-YCHARTSAUTHORIZATION": "yIIphqbsQysnTvWWxfW33w",  # Replace with your actual API key
    "X-YCHARTSEXCELSESSION": "b645cd897b2446bfa3796acfa3a879db",
    "X-YCHARTSEXCELVERSION": "4.4",
    "X-YCHARTSOPERATINGSYSTEM": "Microsoft Windows NT 10.0.26100.0",
    "Content-Type": "application/x-www-form-urlencoded"
}

# SSL Context for HTTPS connections
context = ssl.create_default_context(cafile=certifi.where())
context.check_hostname = False
context.verify_mode = ssl.CERT_NONE  # Use CERT_REQUIRED in production

class CustomHTTPAdapter(HTTPAdapter):
    def init_poolmanager(self, *args, **kwargs):
        kwargs['ssl_context'] = context
        return super().init_poolmanager(*args, **kwargs)

session = requests.Session()
session.mount('https://', CustomHTTPAdapter())

# Metrics mapping 
column_to_ycharts_mapping = [
    # ... (all your mappings here as in the previous code blocks)
]

# Extract metrics that should be fetched
METRICS = [(col, code, api) for col, code, api in column_to_ycharts_mapping if api in ["YCP", "YCI"]]

# YCP Functions
def build_points_lines(symbol, yc_code, is_mutual):
    symbol_for_api = f"M:{symbol}" if is_mutual else symbol
    return f"{symbol_for_api},{yc_code}"

@retry(stop=stop_after_attempt(3), wait=wait_exponential(multiplier=1, min=4, max=10))
def fetch_ycp_data_point(symbol, metric, fund_type_id):
    is_mutual = (fund_type_id == 3)
    for col, yc_code, api_type in METRICS:
        if col == metric and api_type == "YCP":
            points_line = build_points_lines(symbol, yc_code, is_mutual)
            payload = f"points={points_line}"
            api_url = f"{YCHARTS_API_URL}/v3/excel/points"
            try:
                response = session.post(api_url, headers=API_HEADERS, data=payload, timeout=60)
                response.raise_for_status()
                data = response.json()
                symbol_for_api = f"M:{symbol}" if is_mutual else symbol
                if 'response' in data and symbol_for_api in data['response']:
                    results = data['response'][symbol_for_api].get("results", {})
                    if yc_code in results:
                        datapoints = results[yc_code].get("data")
                        if datapoints and isinstance(datapoints, list) and len(datapoints) > 0:
                            last_point = datapoints[-1]
                            if isinstance(last_point, list) and len(last_point) > 1:
                                return last_point[1]
                logger.warning(f"No valid data returned for symbol '{symbol}' on metric '{metric}'")
                return None
            except requests.exceptions.RequestException as e:
                logger.error(f"API error for symbol '{symbol}' on metric '{metric}': {e}")
                return None
    return None

# YCI Functions
@retry(stop=stop_after_attempt(3), wait=wait_exponential(multiplier=1, min=4, max=10))
def fetch_yci_metric(symbol, fund_type_id, metric):
    for col, yc_code, api_type in METRICS:
        if col == metric and api_type == "YCI":
            if fund_type_id == 3:
                symbol_for_api = f"M:{symbol}"
                endpoint = "mutual_funds"
            else:
                symbol_for_api = symbol
                endpoint = "companies"
            api_url = f"{YCHARTS_API_URL}/v3/{endpoint}/{symbol_for_api}/info/{yc_code}?retrieve_ttl=true"
            logger.info(f"Fetching {metric} for {symbol} using URL: {api_url}")
            try:
                response = session.get(api_url, headers=API_HEADERS, timeout=30)
                response.raise_for_status()
                data = response.json()
                response_key = f"M:{symbol}" if fund_type_id == 3 else symbol
                metric_value = data.get("response", {}).get(response_key, {}).get("results", {}).get(yc_code, {}).get("data")
                
                if metric == "related_securities" and isinstance(metric_value, list):
                    metric_value = [sec.get('security_id') for sec in metric_value if isinstance(sec, dict) and 'security_id' in sec]
                
                if metric_value is None:
                    logger.warning(f"No valid data returned for symbol '{symbol}' on metric '{metric}'")
                    return None
                return metric_value
            except Exception as e:
                logger.error(f"Error fetching {metric} for {symbol}: {e}")
                return None
    return None

def process_symbol(symbol, fund_type_id):
    data = {"symbol": symbol}
    for metric, _, api_type in METRICS:
        if api_type == "YCP":
            data[metric] = fetch_ycp_data_point(symbol, metric, fund_type_id)
        elif api_type == "YCI":
            data[metric] = fetch_yci_metric(symbol, fund_type_id, metric)
        
        # Log the result of each metric fetch
        if data[metric] is None:
            logger.warning(f"No data for {symbol} on {metric}")
        else:
            logger.info(f"{symbol} - {metric}: {data[metric]}")

    # Update or insert data into the database
    try:
        with engine.begin() as conn:
            # Check if symbol exists, then update or insert
            result = conn.execute(text("SELECT 1 FROM Funds_to_Screen WHERE SymbolCUSIP = :symbol"), {'symbol': symbol}).fetchone()
            if result:
                update_sql = f"UPDATE Funds_to_Screen SET {', '.join([f'{col} = :{col}' for col in data.keys() if col != 'symbol'])} WHERE SymbolCUSIP = :symbol"
                conn.execute(text(update_sql), data)
                logger.info(f"Updated data for {symbol}")
            else:
                insert_sql = f"INSERT INTO Funds_to_Screen ({', '.join(data.keys())}) VALUES ({', '.join([':' + k for k in data.keys()])})"
                conn.execute(text(insert_sql), data)
                logger.info(f"Inserted data for {symbol}")
    except Exception as e:
        logger.error(f"Database error for {symbol}: {e}")

def main():
    start_time = time.time()
    logger.info("Starting data fetch and processing one symbol at a time.")

    # Load symbols from Excel
    df = pd.read_excel('C:\\Users\\JulianHeron\\fund_type_and_symbol.xlsx', usecols=["SymbolCUSIP", "Fund_Type_ID"])
    
    processed_count = 0
    error_count = 0
    for _, row in df.iterrows():
        symbol, fund_type_id = row['SymbolCUSIP'], row['Fund_Type_ID']
        try:
            process_symbol(symbol, fund_type_id)
            processed_count += 1
        except Exception as e:
            logger.error(f"Unhandled error processing {symbol}: {e}")
            error_count += 1

    # Call the stored procedure here after all processing is done
    try:
        with engine.begin() as conn:
            conn.execute(text("EXEC UpdateDerivedMetrics"))
        logger.info("Successfully executed UpdateDerivedMetrics stored procedure.")
    except Exception as e:
        logger.error(f"Failed to execute UpdateDerivedMetrics stored procedure: {e}")

    total_time = time.time() - start_time
    logger.info(f"Completed processing. Processed: {processed_count}, Errors: {error_count}, Total Time: {total_time:.2f} seconds")

if __name__ == "__main__":
    main()
# Out:
#   Cell In[1], line 72
#     if col == metric and api_type == "
#                                      ^
# SyntaxError: unterminated string literal (detected at line 72)

# %%
import pandas as pd
import sqlalchemy
from sqlalchemy import text
import logging
from concurrent.futures import ThreadPoolExecutor, as_completed
import time
import json
from tenacity import retry, stop_after_attempt, wait_exponential
import ssl
import certifi
from requests.adapters import HTTPAdapter
import requests

# Setup logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s', handlers=[
    logging.StreamHandler()  # Log to console
])
logger = logging.getLogger(__name__)

# Database Connection Configuration
connection_string = (
    "mssql+pyodbc://JULIANS_LAPTOP\\SQLEXPRESS/"
    "CWA_Fund_Database?driver=ODBC+Driver+18+for+SQL+Server"
    "&trusted_connection=yes&TrustServerCertificate=yes"
)
engine = sqlalchemy.create_engine(
    connection_string,
    pool_size=50,  # Increased pool size to avoid timeouts
    max_overflow=100,  # Adjust based on your system capabilities
    pool_timeout=300  # Increased timeout to handle long-running queries
)

# YCharts API Configuration
YCHARTS_API_URL = "https://api.ycharts.com"
API_HEADERS = {
    "X-YCHARTSAUTHORIZATION": "yIIphqbsQysnTvWWxfW33w",  # Replace with your actual API key
    "X-YCHARTSEXCELSESSION": "b645cd897b2446bfa3796acfa3a879db",
    "X-YCHARTSEXCELVERSION": "4.4",
    "X-YCHARTSOPERATINGSYSTEM": "Microsoft Windows NT 10.0.26100.0",
    "Content-Type": "application/x-www-form-urlencoded"
}

# SSL Context for HTTPS connections
context = ssl.create_default_context(cafile=certifi.where())
context.check_hostname = False
context.verify_mode = ssl.CERT_NONE  # Use CERT_REQUIRED in production

class CustomHTTPAdapter(HTTPAdapter):
    def init_poolmanager(self, *args, **kwargs):
        kwargs['ssl_context'] = context
        return super().init_poolmanager(*args, **kwargs)

session = requests.Session()
session.mount('https://', CustomHTTPAdapter())

# Metrics mapping 
column_to_ycharts_mapping = [
    ("InceptionDate", "inception_date", "YCI"),
    ("EarliestPerformanceDate", "earliest_performance_date", "YCI"),
    ("LCG", "equity_stylebox_large_cap_growth_exposure", "YCP"),
    ("LCB", "equity_stylebox_large_cap_blend_exposure", "YCP"),
    ("LCV", "equity_stylebox_large_cap_value_exposure", "YCP"),
    ("MCG", "equity_stylebox_mid_cap_growth_exposure", "YCP"),
    ("MCB", "equity_stylebox_mid_cap_blend_exposure", "YCP"),
    ("MCV", "equity_stylebox_mid_cap_value_exposure", "YCP"),
    ("SCG", "equity_stylebox_small_cap_growth_exposure", "YCP"),
    ("SCB", "equity_stylebox_small_cap_blend_exposure", "YCP"),
    ("SCV", "equity_stylebox_small_cap_value_exposure", "YCP"),
    ("Giant_Cap_Exposure", "giant_cap_exposure", "YCP"),
    ("Large_Cap_Exposure", "large_cap_exposure", "YCP"),
    ("Medium_Cap_Exposure", "medium_cap_exposure", "YCP"),
    ("Micro_Cap_Exposure", "micro_cap_exposure", "YCP"),
    ("Sensitive_Exposure", "sensitive_exposure", "YCP"),
    ("Small_Cap_Exposure", "small_cap_exposure", "YCP"),
    ("Cyclical_Exposure", "cyclical_exposure", "YCP"),
    ("Defensive_Exposure", "defensive_exposure", "YCP"),
    ("AAA_Rated", "aaa_bond_exposure", "YCP"),
    ("AA_Rated", "aa_bond_exposure", "YCP"),
    ("A_Rated", "a_bond_exposure", "YCP"),
    ("BBB_Rated", "bbb_bond_exposure", "YCP"),
    ("B_Rated", "b_bond_exposure", "YCP"),
    ("BB_Rated", "bb_bond_exposure", "YCP"),
    ("Below_B_Rated", "below_b_bond_exposure", "YCP"),
    ("Not_Rated", "not_rated_bond_exposure", "YCP"),
    ("Term_10_15_Y", "10_to_15_years_maturity_bond_exposure", "YCP"),
    ("Term_1_3_Y", "1_to_3_years_maturity_bond_exposure", "YCP"),
    ("Term_15_20_Y", "15_to_20_years_maturity_bond_exposure", "YCP"),
    ("Term_1_7_D", "1_to_7_days_maturity_bond_exposure", "YCP"),
    ("Term_183_364_D", "183_to_364_days_maturity_bond_exposure", "YCP"),
    ("Term_20_30_Y", "20_to_30_years_maturity_bond_exposure", "YCP"),
    ("Term_30_Plus_Y", "over_30_years_maturity_bond_exposure", "YCP"),
    ("Term_31_90_D", "31_to_90_days_maturity_bond_exposure", "YCP"),
    ("Term_3_5_Y", "3_to_5_years_maturity_bond_exposure", "YCP"),
    ("Term_5_7_Y", "5_to_7_years_maturity_bond_exposure", "YCP"),
    ("Term_7_10_Y", "7_to_10_years_maturity_bond_exposure", "YCP"),
    ("Term_8_30_D", "8_to_30_days_maturity_bond_exposure", "YCP"),
    ("Term_91_182_D", "91_to_182_days_maturity_bond_exposure", "YCP"),
    ("LT_Exposure", "long_term_exposure", "YCP"),
    ("Interm_Exposure", "intermediate_term_exposure", "YCP"),
    ("ST_Exposure", "short_term_exposure", "YCP"),
    ("pct_top_10", "percent_of_assets_in_top_10_holdings", "YCP"),
    ("pct_top_25", "percent_of_assets_in_top_25_holdings", "YCP"),
    ("materials", "basic_materials_exposure", "YCP"),
    ("comsvc", "communication_services_exposure", "YCP"),
    ("concyc", "consumer_cyclical_exposure", "YCP"),
    ("condef", "consumer_defensive_exposure", "YCP"),
    ("energy", "energy_exposure", "YCP"),
    ("finsvc", "financial_services_exposure", "YCP"),
    ("healthcare", "healthcare_exposure", "YCP"),
    ("industrials", "industrials_exposure", "YCP"),
    ("realestate", "real_estate_exposure", "YCP"),
    ("technology", "technology_exposure", "YCP"),
    ("utilities", "utilities_exposure", "YCP"),
    ("relative_composition", "relative_composition", "YCP"),
    ("num_bonds", "number_of_bond_holdings", "YCP"),
    ("num_stocks", "number_of_stock_holdings", "YCP"),
    ("dev_mkt", "developed_market_exposure", "YCP"),
    ("em_mkt", "emerging_market_exposure", "YCP"),
    ("europe", "greater_europe_total_exposure", "YCP"),
    ("lat_america", "latin_america_total_exposure", "YCP"),
    ("namerica", "north_america_total_exposure", "YCP"),
    ("africa_mideast", "africa_middle_east_total_exposure", "YCP"),
    ("asia_em", "asia_emerging_total_exposure", "YCP"),
    ("asia_dev", "asia_developed_total_exposure", "YCP"),
    ("australia", "australasia_total_exposure", "YCP"),
    ("india", "india_total_exposure", "YCP"),
    ("w_avg_dc", "weighted_average_debt_to_capital", "YCP"),
    ("avg_mkt_cap", "average_market_cap", "YCP"),
    ("avg_pe_ratio", "weighted_average_pe_ratio", "YCP"),
    ("avg_pb_ratio", "weighted_average_price_to_book_ratio", "YCP"),
    ("avg_pcf_ratio", "weighted_average_price_to_cash_flow", "YCP"),
    ("avg_ps_ratio", "weighted_average_price_to_sales_ratio", "YCP"),
    ("avg_net_margin", "weighted_median_net_margin", "YCP"),
    ("avg_roa", "weighted_median_return_on_assets", "YCP"),
    ("avg_roe", "weighted_median_return_on_equity", "YCP"),
    ("preferreds", "preferred_stock_exposure", "YCP"),
    ("securitized", "securitized_fixed_income_exposure", "YCP"),
    ("muni_exempt", "municipal_tax_exempt_bond_exposure", "YCP"),
    ("muni_tax", "municipal_taxable_bond_exposure", "YCP"),
    ("muni_exposure", "municipal_fixed_income_exposure", "YCP"),
    ("corp_exposure", "corporate_bond_exposure", "YCP"),
    ("corp_fi", "corporate_fixed_income_exposure", "YCP"),
    ("govi_exp", "government_bond_exposure", "YCP"),
    ("govi_fi", "government_fixed_income_exposure", "YCP"),
    ("covered_bond", "covered_bond_exposure", "YCP"),
    ("gov_bond", "government_related_bond_exposure", "YCP"),
    ("converts", "convertible_bond_exposure", "YCP"),
    ("asset_backed_sec", "asset_backed_security_exposure", "YCP"),
    ("index_fund", "index_fund", "YCI"),
    ("inverse_fund", "inverse_fund", "YCI"),
    ("leveraged_fund", "leveraged_fund", "YCI"),
    ("socially_responsible_fund", "socially_responsible_fund", "YCI"),
    ("synthetic_replication_fund", "synthetic_replication_fund", "YCI"),
    ("aum_usd", "aum_usd", "YCI"),
    ("average_manager_tenure", "average_manager_tenure", "YCP"),
    ("max_manager_tenure", "max_manager_tenure", "YCP"),
    ("median_manager_tenure", "median_manager_tenure", "YCP"),
    ("min_manager_tenure", "min_manager_tenure", "YCP"),
    ("open_to_existing_investors", "open_to_existing_investors", "YCI"),
    ("open_to_new_investors", "open_to_new_investors", "YCI"),
    ("ycharts_url", "ycharts_url", "YCI"),
    ("years_since_inception", "years_since_inception", "YCP"),
    ("investment_strategy", "investment_strategy", "YCI"),
    ("related_securities", "related_securities", "YCI"), #returns both symbols and names, only need symbols
    ("fund_family", "fund_family", "YCI")
]

# Extract metrics that should be fetched
METRICS = [(col, code, api) for col, code, api in column_to_ycharts_mapping if api in ["YCP", "YCI"]]

# YCP Functions
def build_points_lines(symbol, yc_code, is_mutual):
    symbol_for_api = f"M:{symbol}" if is_mutual else symbol
    return f"{symbol_for_api},{yc_code}"

def fetch_ycp_data_point(symbol, metric, is_mutual):
    symbol_for_api = f"M:{symbol}" if is_mutual else symbol
    points_line = f"{symbol_for_api},{metric}"
    payload = f"points={points_line}"
    api_url = f"{YCHARTS_API_URL}/v3/excel/points"
    
    try:
        response = session.post(api_url, headers=API_HEADERS, data=payload, timeout=60)
        response.raise_for_status()
        data = response.json()
        logger.info(f"API response for {symbol} on {metric}: {data}")

        if 'response' in data and symbol_for_api in data['response']:
            results = data['response'][symbol_for_api].get("results", {})
            if metric in results and "" in results[metric]:
                datapoints = results[metric][""].get("results")
                if datapoints and isinstance(datapoints, list) and len(datapoints) > 0:
                    # Assuming the last element in the list contains the latest data
                    last_point = datapoints[-1]
                    if isinstance(last_point, list) and len(last_point) > 1:
                        value = last_point[1]
                        if value is not None:
                            return value
                        else:
                            logger.warning(f"Data returned for {symbol} on {metric} is None")
                    else:
                        logger.warning(f"Unexpected data format for {symbol} on {metric}")
                else:
                    logger.warning(f"No valid data points for {symbol} on {metric}")
            else:
                logger.warning(f"Metric '{metric}' not found or empty for {symbol}")
        else:
            logger.error(f"API response does not contain expected data for '{symbol}' on metric '{metric}': {data}")
        return None
    except requests.RequestException as e:
        logger.error(f"API error for symbol '{symbol}' on metric '{metric}': {e}")
        return None

# YCI Functions
@retry(stop=stop_after_attempt(3), wait=wait_exponential(multiplier=1, min=4, max=10))
def fetch_yci_metric(symbol, fund_type_id, metric):
    for col, yc_code, api_type in METRICS:
        if col == metric and api_type == "YCI":
            if fund_type_id == 3:
                symbol_for_api = f"M:{symbol}"
                endpoint = "mutual_funds"
            else:
                symbol_for_api = symbol
                endpoint = "companies"
            api_url = f"{YCHARTS_API_URL}/v3/{endpoint}/{symbol_for_api}/info/{yc_code}?retrieve_ttl=true"
            logger.info(f"Fetching {metric} for {symbol} using URL: {api_url}")
            try:
                response = session.get(api_url, headers=API_HEADERS, timeout=30)
                response.raise_for_status()
                data = response.json()
                logger.debug(f"API response for {symbol} on {yc_code}: {data}")
                
                response_key = f"M:{symbol}" if fund_type_id == 3 else symbol
                metric_value = data.get("response", {}).get(response_key, {}).get("results", {}).get(yc_code, {}).get("data")
                
                if metric == "related_securities" and isinstance(metric_value, list):
                    metric_value = [sec.get('security_id') for sec in metric_value if isinstance(sec, dict) and 'security_id' in sec]
                return metric_value
            except Exception as e:
                logger.error(f"Error fetching {metric} for {symbol}: {e}")
                return None
    return None

def process_fund(row):
    symbol, fund_type_id = row['SymbolCUSIP'], row['Fund_Type_ID']
    data = {"symbol": symbol}
    
    for metric, _, api_type in METRICS:
        if api_type == "YCP":
            data[metric] = fetch_ycp_data_point(symbol, metric, fund_type_id)
        elif api_type == "YCI":
            data[metric] = fetch_yci_metric(symbol, fund_type_id, metric)
    
    # Prepare data for DB update, convert lists to JSON for 'related_securities'
    data = {k: json.dumps(v) if k == 'related_securities' and isinstance(v, list) else v for k, v in data.items()}
    
    try:
        with engine.begin() as conn:
            # Update existing record
            update_sql = f"UPDATE Funds_to_Screen SET {', '.join([f'{col} = :{col}' for col in data.keys() if col != 'symbol'])} WHERE SymbolCUSIP = :symbol"
            result = conn.execute(text(update_sql), data)
            
            # Check if any rows were affected by the UPDATE operation
            if result.rowcount > 0:
                logger.info(f"Updated metrics for symbol {symbol}")
                return {'symbol': symbol, 'status': 'updated'}
            else:
                logger.warning(f"No rows updated for symbol {symbol}, symbol might not exist in the database")
                return {'symbol': symbol, 'status': 'not_updated'}

    except Exception as e:
        logger.error(f"Database error for {symbol}: {e}")
        return {'symbol': symbol, 'status': 'error'}

def main():
    start_time = time.time()
    logger.info("Starting data fetch and update process.")

    # Load symbols from Excel
    df = pd.read_excel('C:\\Users\\JulianHeron\\fund_type_and_symbol.xlsx', usecols=["SymbolCUSIP", "Fund_Type_ID"])
    
    processed_count = 0
    error_count = 0
    not_updated_count = 0
    with ThreadPoolExecutor(max_workers=20) as executor:
        futures = {executor.submit(process_fund, row): row for _, row in df.iterrows()}
        
        for future in as_completed(futures):
            try:
                result = future.result()
                if result['status'] == 'updated':
                    processed_count += 1
                elif result['status'] == 'not_updated':
                    not_updated_count += 1
                elif result['status'] == 'error':
                    error_count += 1
                logger.info(f"Processed {result['symbol']}: {result['status']}")
            except Exception as e:
                error_count += 1
                logger.error(f"Exception in processing {futures[future]['SymbolCUSIP']}: {e}")
    
    # Call the stored procedure here after all processing is done
    try:
        with engine.begin() as conn:
            conn.execute(text("EXEC UpdateDerivedMetrics"))
        logger.info("Successfully executed UpdateDerivedMetrics stored procedure.")
    except Exception as e:
        logger.error(f"Failed to execute UpdateDerivedMetrics stored procedure: {e}")

    total_time = time.time() - start_time
    logger.info(f"Completed processing. Updated: {processed_count}, Not Updated: {not_updated_count}, Errors: {error_count}, Total Time: {total_time:.2f} seconds")

if __name__ == "__main__":
    main()
# Out:
# 2025-02-13 16:43:37,756 - INFO - Starting data fetch and update process.
# 2025-02-13 16:43:38,072 - INFO - Fetching InceptionDate for MDIV using URL: https://api.ycharts.com/v3/companies/MDIV/info/inception_date?retrieve_ttl=true
# 2025-02-13 16:43:38,074 - INFO - Fetching InceptionDate for ROMO using URL: https://api.ycharts.com/v3/companies/ROMO/info/inception_date?retrieve_ttl=true
# 2025-02-13 16:43:38,074 - INFO - Fetching InceptionDate for RISN using URL: https://api.ycharts.com/v3/companies/RISN/info/inception_date?retrieve_ttl=true
# 2025-02-13 16:43:38,074 - INFO - Fetching InceptionDate for MAPP using URL: https://api.ycharts.com/v3/companies/MAPP/info/inception_date?retrieve_ttl=true
# 2025-02-13 16:43:38,077 - INFO - Fetching InceptionDate for GAL using URL: https://api.ycharts.com/v3/companies/GAL/info/inception_date?retrieve_ttl=true
# 2025-02-13 16:43:38,079 - INFO - Fetching InceptionDate for AOA using URL: https://api.ycharts.com/v3/companies/AOA/info/inception_date?retrieve_ttl=true
# 2025-02-13 16:43:38,080 - INFO - Fetching InceptionDate for NTSI using URL: https://api.ycharts.com/v3/companies/NTSI/info/inception_date?retrieve_ttl=true
# 2025-02-13 16:43:38,082 - INFO - Fetching InceptionDate for PPI using URL: https://api.ycharts.com/v3/companies/PPI/info/inception_date?retrieve_ttl=true
# 2025-02-13 16:43:38,082 - INFO - Fetching InceptionDate for PCEF using URL: https://api.ycharts.com/v3/companies/PCEF/info/inception_date?retrieve_ttl=true
# 2025-02-13 16:43:38,083 - INFO - Fetching InceptionDate for GAA using URL: https://api.ycharts.com/v3/companies/GAA/info/inception_date?retrieve_ttl=true
# 2025-02-13 16:43:38,084 - INFO - Fetching InceptionDate for DSCF using URL: https://api.ycharts.com/v3/companies/DSCF/info/inception_date?retrieve_ttl=true
# 2025-02-13 16:43:38,085 - INFO - Fetching InceptionDate for HNDL using URL: https://api.ycharts.com/v3/companies/HNDL/info/inception_date?retrieve_ttl=true
# 2025-02-13 16:43:38,086 - INFO - Fetching InceptionDate for RPAR using URL: https://api.ycharts.com/v3/companies/RPAR/info/inception_date?retrieve_ttl=true
# 2025-02-13 16:43:38,089 - INFO - Fetching InceptionDate for TWIO using URL: https://api.ycharts.com/v3/companies/TWIO/info/inception_date?retrieve_ttl=true
# 2025-02-13 16:43:38,091 - INFO - Fetching InceptionDate for CWB using URL: https://api.ycharts.com/v3/companies/CWB/info/inception_date?retrieve_ttl=true
# 2025-02-13 16:43:38,092 - INFO - Fetching InceptionDate for CVRT using URL: https://api.ycharts.com/v3/companies/CVRT/info/inception_date?retrieve_ttl=true
# 2025-02-13 16:43:38,093 - INFO - Fetching InceptionDate for FCVT using URL: https://api.ycharts.com/v3/companies/FCVT/info/inception_date?retrieve_ttl=true
# 2025-02-13 16:43:38,095 - INFO - Fetching InceptionDate for QCON using URL: https://api.ycharts.com/v3/companies/QCON/info/inception_date?retrieve_ttl=true
# 2025-02-13 16:43:38,097 - INFO - Fetching InceptionDate for DRAI using URL: https://api.ycharts.com/v3/companies/DRAI/info/inception_date?retrieve_ttl=true
# 2025-02-13 16:43:38,098 - INFO - Fetching InceptionDate for RLY using URL: https://api.ycharts.com/v3/companies/RLY/info/inception_date?retrieve_ttl=true
# 2025-02-13 16:43:38,836 - INFO - Fetching EarliestPerformanceDate for ROMO using URL: https://api.ycharts.com/v3/companies/ROMO/info/earliest_performance_date?retrieve_ttl=true
# 2025-02-13 16:43:38,840 - INFO - Fetching EarliestPerformanceDate for MAPP using URL: https://api.ycharts.com/v3/companies/MAPP/info/earliest_performance_date?retrieve_ttl=true
# 2025-02-13 16:43:38,845 - INFO - Fetching EarliestPerformanceDate for AOA using URL: https://api.ycharts.com/v3/companies/AOA/info/earliest_performance_date?retrieve_ttl=true
# 2025-02-13 16:43:38,848 - INFO - Fetching EarliestPerformanceDate for RISN using URL: https://api.ycharts.com/v3/companies/RISN/info/earliest_performance_date?retrieve_ttl=true
# 2025-02-13 16:43:38,859 - INFO - Fetching EarliestPerformanceDate for GAL using URL: https://api.ycharts.com/v3/companies/GAL/info/earliest_performance_date?retrieve_ttl=true
# 2025-02-13 16:43:38,866 - INFO - Fetching EarliestPerformanceDate for MDIV using URL: https://api.ycharts.com/v3/companies/MDIV/info/earliest_performance_date?retrieve_ttl=true
# 2025-02-13 16:43:38,867 - INFO - Fetching EarliestPerformanceDate for NTSI using URL: https://api.ycharts.com/v3/companies/NTSI/info/earliest_performance_date?retrieve_ttl=true
# 2025-02-13 16:43:38,903 - INFO - Fetching EarliestPerformanceDate for RLY using URL: https://api.ycharts.com/v3/companies/RLY/info/earliest_performance_date?retrieve_ttl=true
# 2025-02-13 16:43:38,908 - INFO - Fetching EarliestPerformanceDate for CWB using URL: https://api.ycharts.com/v3/companies/CWB/info/earliest_performance_date?retrieve_ttl=true
# 2025-02-13 16:43:38,927 - INFO - Fetching EarliestPerformanceDate for QCON using URL: https://api.ycharts.com/v3/companies/QCON/info/earliest_performance_date?retrieve_ttl=true
# 2025-02-13 16:43:38,928 - INFO - Fetching EarliestPerformanceDate for DSCF using URL: https://api.ycharts.com/v3/companies/DSCF/info/earliest_performance_date?retrieve_ttl=true
# 2025-02-13 16:43:38,932 - INFO - Fetching EarliestPerformanceDate for DRAI using URL: https://api.ycharts.com/v3/companies/DRAI/info/earliest_performance_date?retrieve_ttl=true
# 2025-02-13 16:43:38,933 - INFO - Fetching EarliestPerformanceDate for HNDL using URL: https://api.ycharts.com/v3/companies/HNDL/info/earliest_performance_date?retrieve_ttl=true
# 2025-02-13 16:43:38,935 - INFO - Fetching EarliestPerformanceDate for PPI using URL: https://api.ycharts.com/v3/companies/PPI/info/earliest_performance_date?retrieve_ttl=true
# 2025-02-13 16:43:38,936 - INFO - Fetching EarliestPerformanceDate for TWIO using URL: https://api.ycharts.com/v3/companies/TWIO/info/earliest_performance_date?retrieve_ttl=true
# 2025-02-13 16:43:38,940 - INFO - Fetching EarliestPerformanceDate for PCEF using URL: https://api.ycharts.com/v3/companies/PCEF/info/earliest_performance_date?retrieve_ttl=true
# 2025-02-13 16:43:38,942 - INFO - Fetching EarliestPerformanceDate for RPAR using URL: https://api.ycharts.com/v3/companies/RPAR/info/earliest_performance_date?retrieve_ttl=true
# 2025-02-13 16:43:38,945 - INFO - Fetching EarliestPerformanceDate for GAA using URL: https://api.ycharts.com/v3/companies/GAA/info/earliest_performance_date?retrieve_ttl=true
# 2025-02-13 16:43:38,947 - INFO - Fetching EarliestPerformanceDate for CVRT using URL: https://api.ycharts.com/v3/companies/CVRT/info/earliest_performance_date?retrieve_ttl=true
# 2025-02-13 16:43:38,949 - INFO - Fetching EarliestPerformanceDate for FCVT using URL: https://api.ycharts.com/v3/companies/FCVT/info/earliest_performance_date?retrieve_ttl=true
# 2025-02-13 16:43:39,100 - WARNING - No valid data returned for symbol 'ROMO' on metric 'LCG'
# 2025-02-13 16:43:39,181 - WARNING - No valid data returned for symbol 'RISN' on metric 'LCG'
# 2025-02-13 16:43:39,184 - WARNING - No valid data returned for symbol 'MAPP' on metric 'LCG'
# 2025-02-13 16:43:39,196 - WARNING - No valid data returned for symbol 'NTSI' on metric 'LCG'
# 2025-02-13 16:43:39,199 - WARNING - No valid data returned for symbol 'GAL' on metric 'LCG'
# 2025-02-13 16:43:39,208 - WARNING - No valid data returned for symbol 'ROMO' on metric 'LCB'
# 2025-02-13 16:43:39,292 - WARNING - No valid data returned for symbol 'RISN' on metric 'LCB'
# 2025-02-13 16:43:39,292 - WARNING - No valid data returned for symbol 'MAPP' on metric 'LCB'
# 2025-02-13 16:43:39,312 - WARNING - No valid data returned for symbol 'ROMO' on metric 'LCV'
# 2025-02-13 16:43:39,314 - WARNING - No valid data returned for symbol 'MDIV' on metric 'LCG'
# 2025-02-13 16:43:39,315 - WARNING - No valid data returned for symbol 'NTSI' on metric 'LCB'
# 2025-02-13 16:43:39,316 - WARNING - No valid data returned for symbol 'RLY' on metric 'LCG'
on metric 'BBB_Rated'
# 2025-02-13 16:43:41,620 - WARNING - No valid data returned for symbol 'CVRT' on metric 'BBB_Rated'
# 2025-02-13 16:43:41,636 - WARNING - No valid data returned for symbol 'GAA' on metric 'BBB_Rated'
# 2025-02-13 16:43:41,637 - WARNING - No valid data returned for symbol 'DSCF' on metric 'B_Rated'
# 2025-02-13 16:43:41,640 - WARNING - No valid data returned for symbol 'DRAI' on metric 'B_Rated'
# 2025-02-13 16:43:41,647 - WARNING - No valid data returned for symbol 'MDIV' on metric 'B_Rated'
# ...
# 2025-02-13 16:44:01,648 - WARNING - No valid data returned for symbol 'MVFD' on metric 'w_avg_dc'
# 2025-02-13 16:44:01,651 - INFO - Fetching index_fund for GYLD using URL: https://api.ycharts.com/v3/companies/GYLD/info/index_fund?retrieve_ttl=true
# 2025-02-13 16:44:01,651 - INFO - Fetching socially_responsible_fund for BSR using URL: https://api.ycharts.com/v3/companies/BSR/info/socially_responsible_fund?retrieve_ttl=true
# 2025-02-13 16:44:01,664 - WARNING - No valid data returned for symbol 'GMMA' on metric 'average_manager_tenure'
# 2025-02-13 16:44:01,667 - INFO - Fetching socially_responsible_fund for ASET using URL: https://api.ycharts.com/v3/companies/ASET/info/socially_responsible_fund?retrieve_ttl=true
# 2025-02-13 16:44:01,669 - WARNING - No valid data returned for symbol 'TBFG' on metric 'max_manager_tenure'
# 2025-02-13 16:44:01,673 - INFO - Fetching synthetic_replication_fund for CCEF using URL: https://api.ycharts.com/v3/companies/CCEF/info/synthetic_replication_fund?retrieve_ttl=true
# 2025-02-13 16:44:01,690 - INFO - Fetching leveraged_fund for RSSB using URL: https://api.ycharts.com/v3/companies/RSSB/info/leveraged_fund?retrieve_ttl=true
# 2025-02-13 16:44:01,691 - INFO - Fetching synthetic_replication_fund for NDOW using URL: https://api.ycharts.com/v3/companies/NDOW/info/synthetic_replication_fund?retrieve_ttl=true
# 2025-02-13 16:44:01,700 - INFO - Fetching synthetic_replication_fund for NTSE using URL: https://api.ycharts.com/v3/companies/NTSE/info/synthetic_replication_fund?retrieve_ttl=true
# 2025-02-13 16:44:01,710 - INFO - Fetching leveraged_fund for CEFS using URL: https://api.ycharts.com/v3/companies/CEFS/info/leveraged_fund?retrieve_ttl=true
# 2025-02-13 16:44:01,717 - INFO - Fetching synthetic_replication_fund for PWS using URL: https://api.ycharts.com/v3/companies/PWS/info/synthetic_replication_fund?retrieve_ttl=true
# 2025-02-13 16:44:01,729 - INFO - Fetching socially_responsible_fund for NDAA using URL: https://api.ycharts.com/v3/companies/NDAA/info/socially_responsible_fund?retrieve_ttl=true
# 2025-02-13 16:44:01,734 - INFO - Fetching socially_responsible_fund for DALI using URL: https://api.ycharts.com/v3/companies/DALI/info/socially_responsible_fund?retrieve_ttl=true
# 2025-02-13 16:44:01,738 - INFO - Fetching leveraged_fund for FCEF using URL: https://api.ycharts.com/v3/companies/FCEF/info/leveraged_fund?retrieve_ttl=true
# 2025-02-13 16:44:01,749 - INFO - Fetching synthetic_replication_fund for TACK using URL: https://api.ycharts.com/v3/companies/TACK/info/synthetic_replication_fund?retrieve_ttl=true
# 2025-02-13 16:44:01,753 - WARNING - No valid data returned for symbol 'MOOD' on metric 'average_manager_tenure'
# 2025-02-13 16:44:01,763 - INFO - Fetching aum_usd for TDSB using URL: https://api.ycharts.com/v3/companies/TDSB/info/aum_usd?retrieve_ttl=true
# 2025-02-13 16:44:01,764 - WARNING - No valid data returned for symbol 'MVFD' on metric 'avg_mkt_cap'
# 2025-02-13 16:44:01,772 - WARNING - No valid data returned for symbol 'GMMA' on metric 'max_manager_tenure'
# 2025-02-13 16:44:01,773 - INFO - Fetching inverse_fund for GYLD using URL: https://api.ycharts.com/v3/companies/GYLD/info/inverse_fund?retrieve_ttl=true
# 2025-02-13 16:44:01,778 - INFO - Fetching synthetic_replication_fund for ASET using URL: https://api.ycharts.com/v3/companies/ASET/info/synthetic_replication_fund?retrieve_ttl=true
# 2025-02-13 16:44:01,783 - INFO - Fetching synthetic_replication_fund for BSR using URL: https://api.ycharts.com/v3/companies/BSR/info/synthetic_replication_fund?retrieve_ttl=true
# 2025-02-13 16:44:01,784 - WARNING - No valid data returned for symbol 'TBFG' on metric 'median_manager_tenure'
# 2025-02-13 16:44:01,792 - INFO - Fetching aum_usd for CCEF using URL: https://api.ycharts.com/v3/companies/CCEF/info/aum_usd?retrieve_ttl=true
# 2025-02-13 16:44:01,811 - INFO - Fetching aum_usd for NDOW using URL: https://api.ycharts.com/v3/companies/NDOW/info/aum_usd?retrieve_ttl=true
# 2025-02-13 16:44:01,816 - INFO - Fetching socially_responsible_fund for RSSB using URL: https://api.ycharts.com/v3/companies/RSSB/info/socially_responsible_fund?retrieve_ttl=true
# 2025-02-13 16:44:01,823 - INFO - Fetching aum_usd for NTSE using URL: https://api.ycharts.com/v3/companies/NTSE/info/aum_usd?retrieve_ttl=true
# 2025-02-13 16:44:01,827 - INFO - Fetching socially_responsible_fund for CEFS using URL: https://api.ycharts.com/v3/companies/CEFS/info/socially_responsible_fund?retrieve_ttl=true
# 2025-02-13 16:44:01,827 - INFO - Fetching aum_usd for PWS using URL: https://api.ycharts.com/v3/companies/PWS/info/aum_usd?retrieve_ttl=true
# 2025-02-13 16:44:01,828 - WARNING - No valid data returned for symbol 'TDSC' on metric 'average_manager_tenure'
# 2025-02-13 16:44:01,841 - INFO - Fetching synthetic_replication_fund for NDAA using URL: https://api.ycharts.com/v3/companies/NDAA/info/synthetic_replication_fund?retrieve_ttl=true
# 2025-02-13 16:44:01,848 - INFO - Fetching socially_responsible_fund for FCEF using URL: https://api.ycharts.com/v3/companies/FCEF/info/socially_responsible_fund?retrieve_ttl=true
# 2025-02-13 16:44:01,852 - INFO - Fetching aum_usd for TACK using URL: https://api.ycharts.com/v3/companies/TACK/info/aum_usd?retrieve_ttl=true
# 2025-02-13 16:44:01,858 - INFO - Fetching synthetic_replication_fund for DALI using URL: https://api.ycharts.com/v3/companies/DALI/info/synthetic_replication_fund?retrieve_ttl=true
# 2025-02-13 16:44:01,871 - WARNING - No valid data returned for symbol 'MOOD' on metric 'max_manager_tenure'
# 2025-02-13 16:44:01,873 - WARNING - No valid data returned for symbol 'MVFD' on metric 'avg_pe_ratio'
# 2025-02-13 16:44:01,881 - WARNING - No valid data returned for symbol 'GMMA' on metric 'median_manager_tenure'
# 2025-02-13 16:44:01,890 - INFO - Fetching leveraged_fund for GYLD using URL: https://api.ycharts.com/v3/companies/GYLD/info/leveraged_fund?retrieve_ttl=true
# 2025-02-13 16:44:01,897 - INFO - Fetching aum_usd for ASET using URL: https://api.ycharts.com/v3/companies/ASET/info/aum_usd?retrieve_ttl=true
# 2025-02-13 16:44:01,901 - WARNING - No valid data returned for symbol 'TBFG' on metric 'min_manager_tenure'
# 2025-02-13 16:44:01,901 - INFO - Fetching aum_usd for BSR using URL: https://api.ycharts.com/v3/companies/BSR/info/aum_usd?retrieve_ttl=true
# 2025-02-13 16:44:01,902 - INFO - Fetching open_to_existing_investors for TBFG using URL: https://api.ycharts.com/v3/companies/TBFG/info/open_to_existing_investors?retrieve_ttl=true
# 2025-02-13 16:44:01,933 - INFO - Fetching synthetic_replication_fund for RSSB using URL: https://api.ycharts.com/v3/companies/RSSB/info/synthetic_replication_fund?retrieve_ttl=true
# 2025-02-13 16:44:01,949 - INFO - Fetching synthetic_replication_fund for CEFS using URL: https://api.ycharts.com/v3/companies/CEFS/info/synthetic_replication_fund?retrieve_ttl=true
# 2025-02-13 16:44:01,949 - WARNING - No valid data returned for symbol 'TDSC' on metric 'max_manager_tenure'
# 2025-02-13 16:44:01,956 - INFO - Fetching aum_usd for NDAA using URL: https://api.ycharts.com/v3/companies/NDAA/info/aum_usd?retrieve_ttl=true
# 2025-02-13 16:44:01,961 - INFO - Fetching synthetic_replication_fund for FCEF using URL: https://api.ycharts.com/v3/companies/FCEF/info/synthetic_replication_fund?retrieve_ttl=true
# 2025-02-13 16:44:01,974 - WARNING - No valid data returned for symbol 'MOOD' on metric 'median_manager_tenure'
# 2025-02-13 16:44:01,976 - INFO - Fetching aum_usd for DALI using URL: https://api.ycharts.com/v3/companies/DALI/info/aum_usd?retrieve_ttl=true
# 2025-02-13 16:44:01,980 - WARNING - No valid data returned for symbol 'GMMA' on metric 'min_manager_tenure'
# 2025-02-13 16:44:01,981 - WARNING - No valid data returned for symbol 'MVFD' on metric 'avg_pb_ratio'
# 2025-02-13 16:44:01,982 - INFO - Fetching open_to_existing_investors for GMMA using URL: https://api.ycharts.com/v3/companies/GMMA/info/open_to_existing_investors?retrieve_ttl=true
# 2025-02-13 16:44:01,988 - WARNING - No valid data returned for symbol 'TDSB' on metric 'average_manager_tenure'
# 2025-02-13 16:44:02,013 - WARNING - No valid data returned for symbol 'CCEF' on metric 'average_manager_tenure'
# 2025-02-13 16:44:02,016 - INFO - Fetching socially_responsible_fund for GYLD using URL: https://api.ycharts.com/v3/companies/GYLD/info/socially_responsible_fund?retrieve_ttl=true
# 2025-02-13 16:44:02,017 - INFO - Fetching open_to_new_investors for TBFG using URL: https://api.ycharts.com/v3/companies/TBFG/info/open_to_new_investors?retrieve_ttl=true
# 2025-02-13 16:44:02,021 - WARNING - No valid data returned for symbol 'NDOW' on metric 'average_manager_tenure'
# 2025-02-13 16:44:02,051 - INFO - Fetching aum_usd for RSSB using URL: https://api.ycharts.com/v3/companies/RSSB/info/aum_usd?retrieve_ttl=true
# 2025-02-13 16:44:02,056 - WARNING - No valid data returned for symbol 'NTSE' on metric 'average_manager_tenure'
# 2025-02-13 16:44:02,073 - INFO - Fetching aum_usd for FCEF using URL: https://api.ycharts.com/v3/companies/FCEF/info/aum_usd?retrieve_ttl=true
# 2025-02-13 16:44:02,074 - WARNING - No valid data returned for symbol 'TACK' on metric 'average_manager_tenure'
# 2025-02-13 16:44:02,077 - WARNING - No valid data returned for symbol 'PWS' on metric 'average_manager_tenure'
# 2025-02-13 16:44:02,078 - WARNING - No valid data returned for symbol 'TDSC' on metric 'median_manager_tenure'
# 2025-02-13 16:44:02,080 - INFO - Fetching aum_usd for CEFS using URL: https://api.ycharts.com/v3/companies/CEFS/info/aum_usd?retrieve_ttl=true
# 2025-02-13 16:44:02,093 - WARNING - No valid data returned for symbol 'MOOD' on metric 'min_manager_tenure'
# 2025-02-13 16:44:02,094 - INFO - Fetching open_to_existing_investors for MOOD using URL: https://api.ycharts.com/v3/companies/MOOD/info/open_to_existing_investors?retrieve_ttl=true
# 2025-02-13 16:44:02,101 - WARNING - No valid data returned for symbol 'TDSB' on metric 'max_manager_tenure'
# 2025-02-13 16:44:02,103 - INFO - Fetching open_to_new_investors for GMMA using URL: https://api.ycharts.com/v3/companies/GMMA/info/open_to_new_investors?retrieve_ttl=true
# 2025-02-13 16:44:02,104 - WARNING - No valid data returned for symbol 'MVFD' on metric 'avg_pcf_ratio'
# 2025-02-13 16:44:02,105 - WARNING - No valid data returned for symbol 'ASET' on metric 'average_manager_tenure'
# 2025-02-13 16:44:02,113 - WARNING - No valid data returned for symbol 'CCEF' on metric 'max_manager_tenure'
# 2025-02-13 16:44:02,123 - WARNING - No valid data returned for symbol 'BSR' on metric 'average_manager_tenure'
# 2025-02-13 16:44:02,125 - INFO - Fetching ycharts_url for TBFG using URL: https://api.ycharts.com/v3/companies/TBFG/info/ycharts_url?retrieve_ttl=true
# 2025-02-13 16:44:02,126 - WARNING - No valid data returned for symbol 'NDOW' on metric 'max_manager_tenure'
# 2025-02-13 16:44:02,137 - INFO - Fetching synthetic_replication_fund for GYLD using URL: https://api.ycharts.com/v3/companies/GYLD/info/synthetic_replication_fund?retrieve_ttl=true
# 2025-02-13 16:44:02,157 - WARNING - No valid data returned for symbol 'NTSE' on metric 'max_manager_tenure'
# 2025-02-13 16:44:02,179 - WARNING - No valid data returned for symbol 'TACK' on metric 'max_manager_tenure'
# 2025-02-13 16:44:02,184 - WARNING - No valid data returned for symbol 'NDAA' on metric 'average_manager_tenure'
# 2025-02-13 16:44:02,187 - WARNING - No valid data returned for symbol 'PWS' on metric 'max_manager_tenure'
# 2025-02-13 16:44:02,192 - WARNING - No valid data returned for symbol 'TDSC' on metric 'min_manager_tenure'
# 2025-02-13 16:44:02,197 - INFO - Fetching open_to_existing_investors for TDSC using URL: https://api.ycharts.com/v3/companies/TDSC/info/open_to_existing_investors?retrieve_ttl=true
# 2025-02-13 16:44:02,209 - WARNING - No valid data returned for symbol 'DALI' on metric 'average_manager_tenure'
# 2025-02-13 16:44:02,215 - INFO - Fetching open_to_new_investors for MOOD using URL: https://api.ycharts.com/v3/companies/MOOD/info/open_to_new_investors?retrieve_ttl=true
# 2025-02-13 16:44:02,216 - WARNING - No valid data returned for symbol 'TDSB' on metric 'median_manager_tenure'
# 2025-02-13 16:44:02,221 - WARNING - No valid data returned for symbol 'CCEF' on metric 'median_manager_tenure'
# 2025-02-13 16:44:02,222 - WARNING - No valid data returned for symbol 'MVFD' on metric 'avg_ps_ratio'
# 2025-02-13 16:44:02,222 - WARNING - No valid data returned for symbol 'ASET' on metric 'max_manager_tenure'
# 2025-02-13 16:44:02,231 - WARNING - No valid data returned for symbol 'BSR' on metric 'max_manager_tenure'
# 2025-02-13 16:44:02,234 - INFO - Fetching ycharts_url for GMMA using URL: https://api.ycharts.com/v3/companies/GMMA/info/ycharts_url?retrieve_ttl=true
# 2025-02-13 16:44:02,244 - WARNING - No valid data returned for symbol 'NDOW' on metric 'median_manager_tenure'
# 2025-02-13 16:44:02,251 - INFO - Fetching aum_usd for GYLD using URL: https://api.ycharts.com/v3/companies/GYLD/info/aum_usd?retrieve_ttl=true
# 2025-02-13 16:44:02,255 - WARNING - No valid data returned for symbol 'NTSE' on metric 'median_manager_tenure'
# 2025-02-13 16:44:02,259 - WARNING - No valid data returned for symbol 'TBFC' on metric 'years_since_inception'
# 2025-02-13 16:44:02,260 - INFO - Fetching investment_strategy for TBFC using URL: https://api.ycharts.com/v3/companies/TBFC/info/investment_strategy?retrieve_ttl=true
# 2025-02-13 16:44:02,265 - WARNING - No valid data returned for symbol 'RSSB' on metric 'average_manager_tenure'
# 2025-02-13 16:44:02,287 - WARNING - No valid data returned for symbol 'TACK' on metric 'median_manager_tenure'
# 2025-02-13 16:44:02,294 - WARNING - No valid data returned for symbol 'PWS' on metric 'median_manager_tenure'
# 2025-02-13 16:44:02,294 - WARNING - No valid data returned for symbol 'FCEF' on metric 'average_manager_tenure'
# 2025-02-13 16:44:02,297 - WARNING - No valid data returned for symbol 'NDAA' on metric 'max_manager_tenure'
# 2025-02-13 16:44:02,305 - WARNING - No valid data returned for symbol 'CEFS' on metric 'average_manager_tenure'
# 2025-02-13 16:44:02,309 - INFO - Fetching open_to_new_investors for TDSC using URL: https://api.ycharts.com/v3/companies/TDSC/info/open_to_new_investors?retrieve_ttl=true
# 2025-02-13 16:44:02,319 - WARNING - No valid data returned for symbol 'DALI' on metric 'max_manager_tenure'
# 2025-02-13 16:44:02,323 - WARNING - No valid data returned for symbol 'TDSB' on metric 'min_manager_tenure'
# 2025-02-13 16:44:02,323 - INFO - Fetching open_to_existing_investors for TDSB using URL: https://api.ycharts.com/v3/companies/TDSB/info/open_to_existing_investors?retrieve_ttl=true
# 2025-02-13 16:44:02,332 - WARNING - No valid data returned for symbol 'MVFD' on metric 'avg_net_margin'
# 2025-02-13 16:44:02,337 - WARNING - No valid data returned for symbol 'CCEF' on metric 'min_manager_tenure'
# 2025-02-13 16:44:02,337 - INFO - Fetching ycharts_url for MOOD using URL: https://api.ycharts.com/v3/companies/MOOD/info/ycharts_url?retrieve_ttl=true
# 2025-02-13 16:44:02,338 - INFO - Fetching open_to_existing_investors for CCEF using URL: https://api.ycharts.com/v3/companies/CCEF/info/open_to_existing_investors?retrieve_ttl=true
# 2025-02-13 16:44:02,339 - WARNING - No valid data returned for symbol 'ASET' on metric 'median_manager_tenure'
# 2025-02-13 16:44:02,356 - WARNING - No valid data returned for symbol 'NDOW' on metric 'min_manager_tenure'
# 2025-02-13 16:44:02,357 - WARNING - No valid data returned for symbol 'BSR' on metric 'median_manager_tenure'
# 2025-02-13 16:44:02,358 - INFO - Fetching open_to_existing_investors for NDOW using URL: https://api.ycharts.com/v3/companies/NDOW/info/open_to_existing_investors?retrieve_ttl=true
# 2025-02-13 16:44:02,362 - WARNING - No valid data returned for symbol 'NTSE' on metric 'min_manager_tenure'
# 2025-02-13 16:44:02,362 - INFO - Fetching open_to_existing_investors for NTSE using URL: https://api.ycharts.com/v3/companies/NTSE/info/open_to_existing_investors?retrieve_ttl=true
# 2025-02-13 16:44:02,374 - INFO - Fetching related_securities for TBFC using URL: https://api.ycharts.com/v3/companies/TBFC/info/related_securities?retrieve_ttl=true

# %%
import requests
import logging
import json

# Setup logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s', handlers=[
    logging.StreamHandler()  # Log to console
])
logger = logging.getLogger(__name__)

# Disable SSL certificate verification (for debugging only)
requests.packages.urllib3.disable_warnings()
session = requests.Session()
session.verify = False  # This disables SSL certificate verification

# YCharts API Configuration
YCHARTS_API_URL = "https://api.ycharts.com"
API_HEADERS = {
    "X-YCHARTSAUTHORIZATION": "yIIphqbsQysnTvWWxfW33w",  # Replace with your actual API key
    "X-YCHARTSEXCELSESSION": "b645cd897b2446bfa3796acfa3a879db",
    "X-YCHARTSEXCELVERSION": "4.4",
    "X-YCHARTSOPERATINGSYSTEM": "Microsoft Windows NT 10.0.26100.0",
    "Content-Type": "application/x-www-form-urlencoded"
}

# Metrics mapping 
column_to_ycharts_mapping = [
    ("InceptionDate", "inception_date", "YCI"),
    ("EarliestPerformanceDate", "earliest_performance_date", "YCI"),
    ("LCG", "equity_stylebox_large_cap_growth_exposure", "YCP"),
    ("LCB", "equity_stylebox_large_cap_blend_exposure", "YCP"),
    ("LCV", "equity_stylebox_large_cap_value_exposure", "YCP"),
    ("MCG", "equity_stylebox_mid_cap_growth_exposure", "YCP"),
    ("MCB", "equity_stylebox_mid_cap_blend_exposure", "YCP"),
    ("MCV", "equity_stylebox_mid_cap_value_exposure", "YCP"),
    ("SCG", "equity_stylebox_small_cap_growth_exposure", "YCP"),
    ("SCB", "equity_stylebox_small_cap_blend_exposure", "YCP"),
    ("SCV", "equity_stylebox_small_cap_value_exposure", "YCP"),
    ("Giant_Cap_Exposure", "giant_cap_exposure", "YCP"),
    ("Large_Cap_Exposure", "large_cap_exposure", "YCP"),
    ("Medium_Cap_Exposure", "medium_cap_exposure", "YCP"),
    ("Micro_Cap_Exposure", "micro_cap_exposure", "YCP"),
    ("Sensitive_Exposure", "sensitive_exposure", "YCP"),
    ("Small_Cap_Exposure", "small_cap_exposure", "YCP"),
    ("Cyclical_Exposure", "cyclical_exposure", "YCP"),
    ("Defensive_Exposure", "defensive_exposure", "YCP"),
    ("AAA_Rated", "aaa_bond_exposure", "YCP"),
    ("AA_Rated", "aa_bond_exposure", "YCP"),
    ("A_Rated", "a_bond_exposure", "YCP"),
    ("BBB_Rated", "bbb_bond_exposure", "YCP"),
    ("B_Rated", "b_bond_exposure", "YCP"),
    ("BB_Rated", "bb_bond_exposure", "YCP"),
    ("Below_B_Rated", "below_b_bond_exposure", "YCP"),
    ("Not_Rated", "not_rated_bond_exposure", "YCP"),
    ("Term_10_15_Y", "10_to_15_years_maturity_bond_exposure", "YCP"),
    ("Term_1_3_Y", "1_to_3_years_maturity_bond_exposure", "YCP"),
    ("Term_15_20_Y", "15_to_20_years_maturity_bond_exposure", "YCP"),
    ("Term_1_7_D", "1_to_7_days_maturity_bond_exposure", "YCP"),
    ("Term_183_364_D", "183_to_364_days_maturity_bond_exposure", "YCP"),
    ("Term_20_30_Y", "20_to_30_years_maturity_bond_exposure", "YCP"),
    ("Term_30_Plus_Y", "over_30_years_maturity_bond_exposure", "YCP"),
    ("Term_31_90_D", "31_to_90_days_maturity_bond_exposure", "YCP"),
    ("Term_3_5_Y", "3_to_5_years_maturity_bond_exposure", "YCP"),
    ("Term_5_7_Y", "5_to_7_years_maturity_bond_exposure", "YCP"),
    ("Term_7_10_Y", "7_to_10_years_maturity_bond_exposure", "YCP"),
    ("Term_8_30_D", "8_to_30_days_maturity_bond_exposure", "YCP"),
    ("Term_91_182_D", "91_to_182_days_maturity_bond_exposure", "YCP"),
    ("LT_Exposure", "long_term_exposure", "YCP"),
    ("Interm_Exposure", "intermediate_term_exposure", "YCP"),
    ("ST_Exposure", "short_term_exposure", "YCP"),
    ("pct_top_10", "percent_of_assets_in_top_10_holdings", "YCP"),
    ("pct_top_25", "percent_of_assets_in_top_25_holdings", "YCP"),
    ("materials", "basic_materials_exposure", "YCP"),
    ("comsvc", "communication_services_exposure", "YCP"),
    ("concyc", "consumer_cyclical_exposure", "YCP"),
    ("condef", "consumer_defensive_exposure", "YCP"),
    ("energy", "energy_exposure", "YCP"),
    ("finsvc", "financial_services_exposure", "YCP"),
    ("healthcare", "healthcare_exposure", "YCP"),
    ("industrials", "industrials_exposure", "YCP"),
    ("realestate", "real_estate_exposure", "YCP"),
    ("technology", "technology_exposure", "YCP"),
    ("utilities", "utilities_exposure", "YCP"),
    ("relative_composition", "relative_composition", "YCP"),
    ("num_bonds", "number_of_bond_holdings", "YCP"),
    ("num_stocks", "number_of_stock_holdings", "YCP"),
    ("dev_mkt", "developed_market_exposure", "YCP"),
    ("em_mkt", "emerging_market_exposure", "YCP"),
    ("europe", "greater_europe_total_exposure", "YCP"),
    ("lat_america", "latin_america_total_exposure", "YCP"),
    ("namerica", "north_america_total_exposure", "YCP"),
    ("africa_mideast", "africa_middle_east_total_exposure", "YCP"),
    ("asia_em", "asia_emerging_total_exposure", "YCP"),
    ("asia_dev", "asia_developed_total_exposure", "YCP"),
    ("australia", "australasia_total_exposure", "YCP"),
    ("india", "india_total_exposure", "YCP"),
    ("w_avg_dc", "weighted_average_debt_to_capital", "YCP"),
    ("avg_mkt_cap", "average_market_cap", "YCP"),
    ("avg_pe_ratio", "weighted_average_pe_ratio", "YCP"),
    ("avg_pb_ratio", "weighted_average_price_to_book_ratio", "YCP"),
    ("avg_pcf_ratio", "weighted_average_price_to_cash_flow", "YCP"),
    ("avg_ps_ratio", "weighted_average_price_to_sales_ratio", "YCP"),
    ("avg_net_margin", "weighted_median_net_margin", "YCP"),
    ("avg_roa", "weighted_median_return_on_assets", "YCP"),
    ("avg_roe", "weighted_median_return_on_equity", "YCP"),
    ("preferreds", "preferred_stock_exposure", "YCP"),
    ("securitized", "securitized_fixed_income_exposure", "YCP"),
    ("muni_exempt", "municipal_tax_exempt_bond_exposure", "YCP"),
    ("muni_tax", "municipal_taxable_bond_exposure", "YCP"),
    ("muni_exposure", "municipal_fixed_income_exposure", "YCP"),
    ("corp_exposure", "corporate_bond_exposure", "YCP"),
    ("corp_fi", "corporate_fixed_income_exposure", "YCP"),
    ("govi_exp", "government_bond_exposure", "YCP"),
    ("govi_fi", "government_fixed_income_exposure", "YCP"),
    ("covered_bond", "covered_bond_exposure", "YCP"),
    ("gov_bond", "government_related_bond_exposure", "YCP"),
    ("converts", "convertible_bond_exposure", "YCP"),
    ("asset_backed_sec", "asset_backed_security_exposure", "YCP"),
    ("index_fund", "index_fund", "YCI"),
    ("inverse_fund", "inverse_fund", "YCI"),
    ("leveraged_fund", "leveraged_fund", "YCI"),
    ("socially_responsible_fund", "socially_responsible_fund", "YCI"),
    ("synthetic_replication_fund", "synthetic_replication_fund", "YCI"),
    ("aum_usd", "aum_usd", "YCI"),
    ("average_manager_tenure", "average_manager_tenure", "YCP"),
    ("max_manager_tenure", "max_manager_tenure", "YCP"),
    ("median_manager_tenure", "median_manager_tenure", "YCP"),
    ("min_manager_tenure", "min_manager_tenure", "YCP"),
    ("open_to_existing_investors", "open_to_existing_investors", "YCI"),
    ("open_to_new_investors", "open_to_new_investors", "YCI"),
    ("ycharts_url", "ycharts_url", "YCI"),
    ("years_since_inception", "years_since_inception", "YCP"),
    ("investment_strategy", "investment_strategy", "YCI"),
    ("related_securities", "related_securities", "YCI"), #returns both symbols and names, only need symbols
    ("fund_family", "fund_family", "YCI")
]

def fetch_ycp_data_point(symbol, metric, is_mutual):
    symbol_for_api = f"M:{symbol}" if is_mutual else symbol
    points_line = f"{symbol_for_api},{metric}"
    payload = f"points={points_line}"
    api_url = f"{YCHARTS_API_URL}/v3/excel/points"
    
    try:
        response = session.post(api_url, headers=API_HEADERS, data=payload, timeout=60)
        response.raise_for_status()
        data = response.json()
        logger.info(f"API response for {symbol} on {metric}: {data}")

        if 'response' in data and symbol_for_api in data['response']:
            results = data['response'][symbol_for_api].get("results", {})
            if metric in results and "" in results[metric]:
                datapoints = results[metric][""].get("results")
                if datapoints and isinstance(datapoints, list) and len(datapoints) > 0:
                    # Assuming the last element in the list contains the latest data
                    last_point = datapoints[-1]
                    if isinstance(last_point, list) and len(last_point) > 1:
                        value = last_point[1]
                        if value is not None:
                            return value
                        else:
                            logger.warning(f"Data returned for {symbol} on {metric} is None")
                    else:
                        logger.warning(f"Unexpected data format for {symbol} on {metric}")
                else:
                    logger.warning(f"No valid data points for {symbol} on {metric}")
            else:
                logger.warning(f"Metric '{metric}' not found or empty for {symbol}")
        else:
            logger.error(f"API response does not contain expected data for '{symbol}' on metric '{metric}': {data}")
        return None
    except requests.RequestException as e:
        logger.error(f"API error for symbol '{symbol}' on metric '{metric}': {e}")
        return None

def fetch_yci_metric(symbol, metric, is_mutual):
    endpoint = "mutual_funds" if is_mutual else "companies"
    symbol_for_api = f"M:{symbol}" if is_mutual else symbol
    api_url = f"{YCHARTS_API_URL}/v3/{endpoint}/{symbol_for_api}/info/{metric}?retrieve_ttl=true"
    
    try:
        response = session.get(api_url, headers=API_HEADERS, timeout=30)
        response.raise_for_status()
        data = response.json()
        logger.info(f"API response for {symbol} on {metric}: {data}")
        
        response_key = symbol_for_api
        metric_value = data.get("response", {}).get(response_key, {}).get("results", {}).get(metric, {}).get("data")
        
        if metric == "related_securities" and isinstance(metric_value, list):
            metric_value = [sec.get('security_id') for sec in metric_value if isinstance(sec, dict) and 'security_id' in sec]
        return metric_value
    except requests.RequestException as e:
        logger.error(f"Error fetching {metric} for {symbol}: {e}")
        return None

def main():
    symbols = [
        {"symbol": "RDVY", "is_mutual": False},  # ETF
        {"symbol": "FTBFX", "is_mutual": True}  # Mutual Fund
    ]
    results = {}

    for item in symbols:
        symbol, is_mutual = item['symbol'], item['is_mutual']
        results[symbol] = {}
        for db_col, yc_code, api_type in column_to_ycharts_mapping:
            if api_type == "YCP":
                results[symbol][db_col] = fetch_ycp_data_point(symbol, yc_code, is_mutual)
            elif api_type == "YCI":
                results[symbol][db_col] = fetch_yci_metric(symbol, yc_code, is_mutual)
            
            if results[symbol][db_col] is None:
                logger.warning(f"No data for {symbol} on metric {db_col} ({yc_code})")

    for symbol, metric_data in results.items():
        logger.info(f"Results for {symbol}:")
        for db_col, value in metric_data.items():
            if db_col == "related_securities" and value:
                logger.info(f"  {db_col}: {json.dumps(value)}")
            else:
                logger.info(f"  {db_col}: {value}")

if __name__ == "__main__":
    main()
# Out:
# 2025-02-13 17:53:58,151 - INFO - API response for RDVY on inception_date: {'response': {'RDVY': {'meta': {'status': 'ok'}, 'results': {'inception_date': {'meta': {'status': 'ok', 'ttl': 43200}, 'data': '2014-01-06'}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/companies/RDVY/info/inception_date?retrieve_ttl=true', 'status': 'ok'}}
# 2025-02-13 17:53:58,270 - INFO - API response for RDVY on earliest_performance_date: {'response': {'RDVY': {'meta': {'status': 'ok'}, 'results': {'earliest_performance_date': {'meta': {'status': 'ok', 'ttl': 43200}, 'data': '2014-01-06'}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/companies/RDVY/info/earliest_performance_date?retrieve_ttl=true', 'status': 'ok'}}
# 2025-02-13 17:53:58,392 - INFO - API response for RDVY on equity_stylebox_large_cap_growth_exposure: {'response': {'RDVY': {'meta': {'status': 'ok'}, 'results': {'equity_stylebox_large_cap_growth_exposure': {'meta': {'status': 'ok'}, '': {'results': ['2025-02-11', 0.01935], 'meta': {'status': 'ok', 'ttl': 14400}}}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/excel/points', 'status': 'ok'}}
# 2025-02-13 17:53:58,393 - WARNING - Unexpected data format for RDVY on equity_stylebox_large_cap_growth_exposure
# 2025-02-13 17:53:58,393 - WARNING - No data for RDVY on metric LCG (equity_stylebox_large_cap_growth_exposure)
# 2025-02-13 17:53:58,504 - INFO - API response for RDVY on equity_stylebox_large_cap_blend_exposure: {'response': {'RDVY': {'meta': {'status': 'ok'}, 'results': {'equity_stylebox_large_cap_blend_exposure': {'meta': {'status': 'ok'}, '': {'results': ['2025-02-11', 0.20151], 'meta': {'status': 'ok', 'ttl': 14400}}}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/excel/points', 'status': 'ok'}}
# 2025-02-13 17:53:58,504 - WARNING - Unexpected data format for RDVY on equity_stylebox_large_cap_blend_exposure
# 2025-02-13 17:53:58,505 - WARNING - No data for RDVY on metric LCB (equity_stylebox_large_cap_blend_exposure)
# 2025-02-13 17:53:58,610 - INFO - API response for RDVY on equity_stylebox_large_cap_value_exposure: {'response': {'RDVY': {'meta': {'status': 'ok'}, 'results': {'equity_stylebox_large_cap_value_exposure': {'meta': {'status': 'ok'}, '': {'results': ['2025-02-11', 0.1632], 'meta': {'status': 'ok', 'ttl': 14400}}}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/excel/points', 'status': 'ok'}}
# 2025-02-13 17:53:58,611 - WARNING - Unexpected data format for RDVY on equity_stylebox_large_cap_value_exposure
# 2025-02-13 17:53:58,611 - WARNING - No data for RDVY on metric LCV (equity_stylebox_large_cap_value_exposure)
# 2025-02-13 17:53:58,721 - INFO - API response for RDVY on equity_stylebox_mid_cap_growth_exposure: {'response': {'RDVY': {'meta': {'status': 'ok'}, 'results': {'equity_stylebox_mid_cap_growth_exposure': {'meta': {'status': 'ok'}, '': {'results': ['2025-02-11', 0.02132], 'meta': {'status': 'ok', 'ttl': 14400}}}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/excel/points', 'status': 'ok'}}
# 2025-02-13 17:53:58,722 - WARNING - Unexpected data format for RDVY on equity_stylebox_mid_cap_growth_exposure
# 2025-02-13 17:53:58,723 - WARNING - No data for RDVY on metric MCG (equity_stylebox_mid_cap_growth_exposure)
# 2025-02-13 17:53:58,840 - INFO - API response for RDVY on equity_stylebox_mid_cap_blend_exposure: {'response': {'RDVY': {'meta': {'status': 'ok'}, 'results': {'equity_stylebox_mid_cap_blend_exposure': {'meta': {'status': 'ok'}, '': {'results': ['2025-02-11', 0.14026], 'meta': {'status': 'ok', 'ttl': 14400}}}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/excel/points', 'status': 'ok'}}
# 2025-02-13 17:53:58,840 - WARNING - Unexpected data format for RDVY on equity_stylebox_mid_cap_blend_exposure
# 2025-02-13 17:53:58,842 - WARNING - No data for RDVY on metric MCB (equity_stylebox_mid_cap_blend_exposure)
# 2025-02-13 17:53:58,940 - INFO - API response for RDVY on equity_stylebox_mid_cap_value_exposure: {'response': {'RDVY': {'meta': {'status': 'ok'}, 'results': {'equity_stylebox_mid_cap_value_exposure': {'meta': {'status': 'ok'}, '': {'results': ['2025-02-11', 0.30068], 'meta': {'status': 'ok', 'ttl': 14400}}}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/excel/points', 'status': 'ok'}}
# 2025-02-13 17:53:58,941 - WARNING - Unexpected data format for RDVY on equity_stylebox_mid_cap_value_exposure
# 2025-02-13 17:53:58,941 - WARNING - No data for RDVY on metric MCV (equity_stylebox_mid_cap_value_exposure)
# 2025-02-13 17:53:59,040 - INFO - API response for RDVY on equity_stylebox_small_cap_growth_exposure: {'response': {'RDVY': {'meta': {'status': 'ok'}, 'results': {'equity_stylebox_small_cap_growth_exposure': {'meta': {'status': 'ok'}, '': {'results': ['2025-02-11', 0.0], 'meta': {'status': 'ok', 'ttl': 14400}}}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/excel/points', 'status': 'ok'}}
# 2025-02-13 17:53:59,040 - WARNING - Unexpected data format for RDVY on equity_stylebox_small_cap_growth_exposure
# 2025-02-13 17:53:59,042 - WARNING - No data for RDVY on metric SCG (equity_stylebox_small_cap_growth_exposure)
# 2025-02-13 17:53:59,146 - INFO - API response for RDVY on equity_stylebox_small_cap_blend_exposure: {'response': {'RDVY': {'meta': {'status': 'ok'}, 'results': {'equity_stylebox_small_cap_blend_exposure': {'meta': {'status': 'ok'}, '': {'results': ['2025-02-11', 0.03898], 'meta': {'status': 'ok', 'ttl': 14400}}}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/excel/points', 'status': 'ok'}}
# 2025-02-13 17:53:59,146 - WARNING - Unexpected data format for RDVY on equity_stylebox_small_cap_blend_exposure
# 2025-02-13 17:53:59,147 - WARNING - No data for RDVY on metric SCB (equity_stylebox_small_cap_blend_exposure)
# 2025-02-13 17:53:59,256 - INFO - API response for RDVY on equity_stylebox_small_cap_value_exposure: {'response': {'RDVY': {'meta': {'status': 'ok'}, 'results': {'equity_stylebox_small_cap_value_exposure': {'meta': {'status': 'ok'}, '': {'results': ['2025-02-11', 0.11468], 'meta': {'status': 'ok', 'ttl': 14400}}}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/excel/points', 'status': 'ok'}}
# 2025-02-13 17:53:59,258 - WARNING - Unexpected data format for RDVY on equity_stylebox_small_cap_value_exposure
# 2025-02-13 17:53:59,258 - WARNING - No data for RDVY on metric SCV (equity_stylebox_small_cap_value_exposure)
# 2025-02-13 17:53:59,358 - INFO - API response for RDVY on giant_cap_exposure: {'response': {'RDVY': {'meta': {'status': 'ok'}, 'results': {'giant_cap_exposure': {'meta': {'status': 'ok'}, '': {'results': ['2025-02-11', 0.13762684], 'meta': {'status': 'ok', 'ttl': 14400}}}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/excel/points', 'status': 'ok'}}
# 2025-02-13 17:53:59,359 - WARNING - Unexpected data format for RDVY on giant_cap_exposure
# 2025-02-13 17:53:59,360 - WARNING - No data for RDVY on metric Giant_Cap_Exposure (giant_cap_exposure)
# 2025-02-13 17:53:59,460 - INFO - API response for RDVY on large_cap_exposure: {'response': {'RDVY': {'meta': {'status': 'ok'}, 'results': {'large_cap_exposure': {'meta': {'status': 'ok'}, '': {'results': ['2025-02-11', 0.24644562], 'meta': {'status': 'ok', 'ttl': 14400}}}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/excel/points', 'status': 'ok'}}
# 2025-02-13 17:53:59,461 - WARNING - Unexpected data format for RDVY on large_cap_exposure
# 2025-02-13 17:53:59,461 - WARNING - No data for RDVY on metric Large_Cap_Exposure (large_cap_exposure)
# 2025-02-13 17:53:59,563 - INFO - API response for RDVY on medium_cap_exposure: {'response': {'RDVY': {'meta': {'status': 'ok'}, 'results': {'medium_cap_exposure': {'meta': {'status': 'ok'}, '': {'results': ['2025-02-11', 0.46226521], 'meta': {'status': 'ok', 'ttl': 14400}}}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/excel/points', 'status': 'ok'}}
# 2025-02-13 17:53:59,563 - WARNING - Unexpected data format for RDVY on medium_cap_exposure
# 2025-02-13 17:53:59,564 - WARNING - No data for RDVY on metric Medium_Cap_Exposure (medium_cap_exposure)
# 2025-02-13 17:53:59,671 - INFO - API response for RDVY on micro_cap_exposure: {'response': {'RDVY': {'meta': {'status': 'ok'}, 'results': {'micro_cap_exposure': {'meta': {'status': 'ok'}, '': {'results': ['2025-02-11', 0.0], 'meta': {'status': 'ok', 'ttl': 14400}}}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/excel/points', 'status': 'ok'}}
# 2025-02-13 17:53:59,672 - WARNING - Unexpected data format for RDVY on micro_cap_exposure
# 2025-02-13 17:53:59,673 - WARNING - No data for RDVY on metric Micro_Cap_Exposure (micro_cap_exposure)
# 2025-02-13 17:53:59,777 - INFO - API response for RDVY on sensitive_exposure: {'response': {'RDVY': {'meta': {'status': 'ok'}, 'results': {'sensitive_exposure': {'meta': {'status': 'ok'}, '': {'results': ['2025-02-11', 0.418108], 'meta': {'status': 'ok', 'ttl': 14400}}}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/excel/points', 'status': 'ok'}}
# 2025-02-13 17:53:59,777 - WARNING - Unexpected data format for RDVY on sensitive_exposure
# 2025-02-13 17:53:59,778 - WARNING - No data for RDVY on metric Sensitive_Exposure (sensitive_exposure)
# 2025-02-13 17:53:59,876 - INFO - API response for RDVY on small_cap_exposure: {'response': {'RDVY': {'meta': {'status': 'ok'}, 'results': {'small_cap_exposure': {'meta': {'status': 'ok'}, '': {'results': ['2025-02-11', 0.15366233], 'meta': {'status': 'ok', 'ttl': 14400}}}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/excel/points', 'status': 'ok'}}
# 2025-02-13 17:53:59,877 - WARNING - Unexpected data format for RDVY on small_cap_exposure
# 2025-02-13 17:53:59,877 - WARNING - No data for RDVY on metric Small_Cap_Exposure (small_cap_exposure)
# 2025-02-13 17:53:59,981 - INFO - API response for RDVY on cyclical_exposure: {'response': {'RDVY': {'meta': {'status': 'ok'}, 'results': {'cyclical_exposure': {'meta': {'status': 'ok'}, '': {'results': ['2025-02-11', 0.5615818], 'meta': {'status': 'ok', 'ttl': 14400}}}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/excel/points', 'status': 'ok'}}
# 2025-02-13 17
exposure: {'response': {'RDVY': {'meta': {'status': 'ok'}, 'results': {'energy_exposure': {'meta': {'status': 'ok'}, '': {'results': ['2025-02-11', 0.1002689], 'meta': {'status': 'ok', 'ttl': 14400}}}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/excel/points', 'status': 'ok'}}
# 2025-02-13 17:54:03,371 - WARNING - Unexpected data format for RDVY on energy_exposure
# 2025-02-13 17:54:03,372 - WARNING - No data for RDVY on metric energy (energy_exposure)
# 2025-02-13 17:54:03,473 - INFO - API response for RDVY on financial_services_exposure: {'response': {'RDVY': {'meta': {'status': 'ok'}, 'results': {'financial_services_exposure': {'meta': {'status': 'ok'}, '': {'results': ['2025-02-11', 0.4016461], 'meta': {'status': 'ok', 'ttl': 14400}}}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/excel/points', 'status': 'ok'}}
# 2025-02-13 17:54:03,473 - WARNING - Unexpected data format for RDVY on financial_services_exposure
# 2025-02-13 17:54:03,474 - WARNING - No data for RDVY on metric finsvc (financial_services_exposure)
# 2025-02-13 17:54:03,576 - INFO - API response for RDVY on healthcare_exposure: {'response': {'RDVY': {'meta': {'status': 'ok'}, 'results': {'healthcare_exposure': {'meta': {'status': 'ok'}, '': {'results': ['2025-02-11', 0.0203101], 'meta': {'status': 'ok', 'ttl': 14400}}}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/excel/points', 'status': 'ok'}}
# 2025-02-13 17:54:03,577 - WARNING - Unexpected data format for RDVY on healthcare_exposure
# 2025-02-13 17:54:03,578 - WARNING - No data for RDVY on metric healthcare (healthcare_exposure)
# 2025-02-13 17:54:03,689 - INFO - API response for RDVY on industrials_exposure: {'response': {'RDVY': {'meta': {'status': 'ok'}, 'results': {'industrials_exposure': {'meta': {'status': 'ok'}, '': {'results': ['2025-02-11', 0.0785463], 'meta': {'status': 'ok', 'ttl': 14400}}}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/excel/points', 'status': 'ok'}}
# 2025-02-13 17:54:03,690 - WARNING - Unexpected data format for RDVY on industrials_exposure
# 2025-02-13 17:54:03,691 - WARNING - No data for RDVY on metric industrials (industrials_exposure)
# 2025-02-13 17:54:03,788 - INFO - API response for RDVY on real_estate_exposure: {'response': {'RDVY': {'meta': {'status': 'ok'}, 'results': {'real_estate_exposure': {'meta': {'status': 'ok'}, '': {'results': ['2025-02-11', 0.0], 'meta': {'status': 'ok', 'ttl': 14400}}}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/excel/points', 'status': 'ok'}}
# 2025-02-13 17:54:03,790 - WARNING - Unexpected data format for RDVY on real_estate_exposure
# 2025-02-13 17:54:03,791 - WARNING - No data for RDVY on metric realestate (real_estate_exposure)
# 2025-02-13 17:54:03,889 - INFO - API response for RDVY on technology_exposure: {'response': {'RDVY': {'meta': {'status': 'ok'}, 'results': {'technology_exposure': {'meta': {'status': 'ok'}, '': {'results': ['2025-02-11', 0.2039305], 'meta': {'status': 'ok', 'ttl': 14400}}}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/excel/points', 'status': 'ok'}}
# 2025-02-13 17:54:03,891 - WARNING - Unexpected data format for RDVY on technology_exposure
# 2025-02-13 17:54:03,891 - WARNING - No data for RDVY on metric technology (technology_exposure)
# 2025-02-13 17:54:03,995 - INFO - API response for RDVY on utilities_exposure: {'response': {'RDVY': {'meta': {'status': 'ok'}, 'results': {'utilities_exposure': {'meta': {'status': 'ok'}, '': {'results': ['2025-02-11', 0.0], 'meta': {'status': 'ok', 'ttl': 14400}}}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/excel/points', 'status': 'ok'}}
# 2025-02-13 17:54:03,997 - WARNING - Unexpected data format for RDVY on utilities_exposure
# 2025-02-13 17:54:03,998 - WARNING - No data for RDVY on metric utilities (utilities_exposure)
# 2025-02-13 17:54:04,097 - INFO - API response for RDVY on relative_composition: {'response': {'RDVY': {'meta': {'status': 'ok'}, 'results': {'relative_composition': {'meta': {'status': 'ok'}, '': {'results': ['2025-02-13', 0.94055], 'meta': {'status': 'ok', 'ttl': 14400}}}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/excel/points', 'status': 'ok'}}
# 2025-02-13 17:54:04,099 - WARNING - Unexpected data format for RDVY on relative_composition
# 2025-02-13 17:54:04,100 - WARNING - No data for RDVY on metric relative_composition (relative_composition)
# 2025-02-13 17:54:04,206 - INFO - API response for RDVY on number_of_bond_holdings: {'response': {'RDVY': {'meta': {'status': 'ok'}, 'results': {'number_of_bond_holdings': {'meta': {'status': 'ok'}, '': {'results': ['2025-02-11', 0], 'meta': {'status': 'ok', 'ttl': 14400}}}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/excel/points', 'status': 'ok'}}
# 2025-02-13 17:54:04,208 - WARNING - Unexpected data format for RDVY on number_of_bond_holdings
# 2025-02-13 17:54:04,209 - WARNING - No data for RDVY on metric num_bonds (number_of_bond_holdings)
# 2025-02-13 17:54:04,317 - INFO - API response for RDVY on number_of_stock_holdings: {'response': {'RDVY': {'meta': {'status': 'ok'}, 'results': {'number_of_stock_holdings': {'meta': {'status': 'ok'}, '': {'results': ['2025-02-11', 50], 'meta': {'status': 'ok', 'ttl': 14400}}}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/excel/points', 'status': 'ok'}}
# 2025-02-13 17:54:04,319 - WARNING - Unexpected data format for RDVY on number_of_stock_holdings
# 2025-02-13 17:54:04,319 - WARNING - No data for RDVY on metric num_stocks (number_of_stock_holdings)
# 2025-02-13 17:54:04,432 - INFO - API response for RDVY on developed_market_exposure: {'response': {'RDVY': {'meta': {'status': 'ok'}, 'results': {'developed_market_exposure': {'meta': {'status': 'ok'}, '': {'results': ['2025-02-11', 1.0], 'meta': {'status': 'ok', 'ttl': 14400}}}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/excel/points', 'status': 'ok'}}
# 2025-02-13 17:54:04,434 - WARNING - Unexpected data format for RDVY on developed_market_exposure
# 2025-02-13 17:54:04,435 - WARNING - No data for RDVY on metric dev_mkt (developed_market_exposure)
# 2025-02-13 17:54:04,531 - INFO - API response for RDVY on emerging_market_exposure: {'response': {'RDVY': {'meta': {'status': 'ok'}, 'results': {'emerging_market_exposure': {'meta': {'status': 'ok'}, '': {'results': ['2025-02-11', 0.0], 'meta': {'status': 'ok', 'ttl': 14400}}}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/excel/points', 'status': 'ok'}}
# 2025-02-13 17:54
 'meta': {'status': 'ok', 'ttl': 14400}}}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/excel/points', 'status': 'ok'}}
# 2025-02-13 17:54:05,734 - WARNING - Unexpected data format for RDVY on weighted_average_pe_ratio
# 2025-02-13 17:54:05,734 - WARNING - No data for RDVY on metric avg_pe_ratio (weighted_average_pe_ratio)
# 2025-02-13 17:54:05,852 - INFO - API response for RDVY on weighted_average_price_to_book_ratio: {'response': {'RDVY': {'meta': {'status': 'ok'}, 'results': {'weighted_average_price_to_book_ratio': {'meta': {'status': 'ok'}, '': {'results': ['2025-02-11', 2.46554], 'meta': {'status': 'ok', 'ttl': 14400}}}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/excel/points', 'status': 'ok'}}
# 2025-02-13 17:54:05,853 - WARNING - Unexpected data format for RDVY on weighted_average_price_to_book_ratio
# 2025-02-13 17:54:05,853 - WARNING - No data for RDVY on metric avg_pb_ratio (weighted_average_price_to_book_ratio)
# 2025-02-13 17:54:05,955 - INFO - API response for RDVY on weighted_average_price_to_cash_flow: {'response': {'RDVY': {'meta': {'status': 'ok'}, 'results': {'weighted_average_price_to_cash_flow': {'meta': {'status': 'ok'}, '': {'results': ['2025-02-11', 12.43163], 'meta': {'status': 'ok', 'ttl': 14400}}}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/excel/points', 'status': 'ok'}}
# 2025-02-13 17:54:05,956 - WARNING - Unexpected data format for RDVY on weighted_average_price_to_cash_flow
# 2025-02-13 17:54:05,957 - WARNING - No data for RDVY on metric avg_pcf_ratio (weighted_average_price_to_cash_flow)
# 2025-02-13 17:54:06,072 - INFO - API response for RDVY on weighted_average_price_to_sales_ratio: {'response': {'RDVY': {'meta': {'status': 'ok'}, 'results': {'weighted_average_price_to_sales_ratio': {'meta': {'status': 'ok'}, '': {'results': ['2025-02-11', 2.304094], 'meta': {'status': 'ok', 'ttl': 14400}}}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/excel/points', 'status': 'ok'}}
# 2025-02-13 17:54:06,073 - WARNING - Unexpected data format for RDVY on weighted_average_price_to_sales_ratio
# 2025-02-13 17:54:06,075 - WARNING - No data for RDVY on metric avg_ps_ratio (weighted_average_price_to_sales_ratio)
# 2025-02-13 17:54:06,178 - INFO - API response for RDVY on weighted_median_net_margin: {'response': {'RDVY': {'meta': {'status': 'ok'}, 'results': {'weighted_median_net_margin': {'meta': {'status': 'ok'}, '': {'results': ['2025-02-11', 0.2034069], 'meta': {'status': 'ok', 'ttl': 14400}}}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/excel/points', 'status': 'ok'}}
# 2025-02-13 17:54:06,179 - WARNING - Unexpected data format for RDVY on weighted_median_net_margin
# 2025-02-13 17:54:06,180 - WARNING - No data for RDVY on metric avg_net_margin (weighted_median_net_margin)
# 2025-02-13 17:54:06,287 - INFO - API response for RDVY on weighted_median_return_on_assets: {'response': {'RDVY': {'meta': {'status': 'ok'}, 'results': {'weighted_median_return_on_assets': {'meta': {'status': 'ok'}, '': {'results': ['2025-02-11', 0.1018759], 'meta': {'status': 'ok', 'ttl': 14400}}}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/excel/points', 'status': 'ok'}}
# 2025-02-13 17:54:06,289 - WARNING - Unexpected data format for RDVY on weighted_median_return_on_assets
# 2025-02-13 17:54:06,290 - WARNING - No data for RDVY on metric avg_roa (weighted_median_return_on_assets)
# 2025-02-13 17:54:06,393 - INFO - API response for RDVY on weighted_median_return_on_equity: {'response': {'RDVY': {'meta': {'status': 'ok'}, 'results': {'weighted_median_return_on_equity': {'meta': {'status': 'ok'}, '': {'results': ['2025-02-11', 0.2418017], 'meta': {'status': 'ok', 'ttl': 14400}}}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/excel/points', 'status': 'ok'}}
# 2025-02-13 17:54:06,394 - WARNING - Unexpected data format for RDVY on weighted_median_return_on_equity
# 2025-02-13 17:54:06,394 - WARNING - No data for RDVY on metric avg_roe (weighted_median_return_on_equity)
# 2025-02-13 17:54:06,512 - INFO - API response for RDVY on preferred_stock_exposure: {'response': {'RDVY': {'meta': {'status': 'ok'}, 'results': {'preferred_stock_exposure': {'meta': {'status': 'ok'}, '': {'results': ['2025-02-11', 0.0], 'meta': {'status': 'ok', 'ttl': 14400}}}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/excel/points', 'status': 'ok'}}
# 2025-02-13 17:54:06,512 - WARNING - Unexpected data format for RDVY on preferred_stock_exposure
# 2025-02-13 17:54:06,513 - WARNING - No data for RDVY on metric preferreds (preferred_stock_exposure)
# 2025-02-13 17:54:06,617 - INFO - API response for RDVY on securitized_fixed_income_exposure: {'response': {'RDVY': {'meta': {'status': 'ok'}, 'results': {'securitized_fixed_income_exposure': {'meta': {'status': 'ok'}, '': {'results': ['2025-02-11', 0.0], 'meta': {'status': 'ok', 'ttl': 14400}}}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/excel/points', 'status': 'ok'}}
# 2025-02-13 17:54:06,618 - WARNING - Unexpected data format for RDVY on securitized_fixed_income_exposure
# 2025-02-13 17:54:06,619 - WARNING - No data for RDVY on metric securitized (securitized_fixed_income_exposure)
# 2025-02-13 17:54:06,724 - INFO - API response for RDVY on municipal_tax_exempt_bond_exposure: {'response': {'RDVY': {'meta': {'status': 'ok'}, 'results': {'municipal_tax_exempt_bond_exposure': {'meta': {'status': 'ok'}, '': {'results': ['2025-02-11', 0.0], 'meta': {'status': 'ok', 'ttl': 14400}}}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/excel/points', 'status': 'ok'}}
# 2025-02-13 17:54:06,725 - WARNING - Unexpected data format for RDVY on municipal_tax_exempt_bond_exposure
# 2025-02-13 17:54:06,726 - WARNING - No data for RDVY on metric muni_exempt (municipal_tax_exempt_bond_exposure)
# 2025-02-13 17:54:06,830 - INFO - API response for RDVY on municipal_taxable_bond_exposure: {'response': {'RDVY': {'meta': {'status': 'ok'}, 'results': {'municipal_taxable_bond_exposure': {'meta': {'status': 'ok'}, '': {'results': ['2025-02-11', 0.0], 'meta': {'status': 'ok', 'ttl': 14400}}}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/excel/points', 'status': 'ok'}}
# 2025-02-13 17:54:06,831 - WARNING - Unexpected data format for RDVY on municipal_taxable_bond_exposure
# 2025-02-13 17:54:06,832 - WARNING - No data for RDVY on metric muni_tax (municipal_taxable_bond_exposure)
# 2025-02-13 17:54:06,954 - INFO - API response for RDVY on municipal_fixed_income_exposure: {'response': {'RDVY': {'meta': {'status': 'ok'}, 'results': {'municipal_fixed_income_exposure': {'meta': {'status': 'ok'}, '': {'results': ['2025-02-11', 0.0], 'meta': {'status': 'ok', 'ttl': 14400}}}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/excel/points', 'status': 'ok'}}
# 2025-02-13 17:54:06,956 - WARNING - Unexpected data format for RDVY on municipal_fixed_income_exposure
# 2025-02-13 17:54:06,957 - WARNING - No data for RDVY on metric muni_exposure (municipal_fixed_income_exposure)
# 2025-02-13 17:54:07,061 - INFO - API response for RDVY on corporate_bond_exposure: {'response': {'RDVY': {'meta': {'status': 'ok'}, 'results': {'corporate_bond_exposure': {'meta': {'status': 'ok'}, '': {'results': ['2025-02-11', 0.0], 'meta': {'status': 'ok', 'ttl': 14400}}}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/excel/points', 'status': 'ok'}}
# 2025-02-13 17:54:07,062 - WARNING - Unexpected data format for RDVY on corporate_bond_exposure
# 2025-02-13 17:54:07,063 - WARNING - No data for RDVY on metric corp_exposure (corporate_bond_exposure)
# ...
# 2025-02-13 17:54:21,484 - INFO - API response for FTBFX on ycharts_url: {'response': {'M:FTBFX': {'meta': {'status': 'ok'}, 'results': {'ycharts_url': {'meta': {'status': 'ok', 'ttl': 43200}, 'data': 'https://ycharts.com/mutual_funds/M:FTBFX'}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/mutual_funds/M:FTBFX/info/ycharts_url?retrieve_ttl=true', 'status': 'ok'}}
# 2025-02-13 17:54:21,583 - INFO - API response for FTBFX on years_since_inception: {'response': {'M:FTBFX': {'meta': {'status': 'ok'}, 'results': {'years_since_inception': {'meta': {'status': 'ok'}, '': {'results': ['2014-10-03', 22.34], 'meta': {'status': 'ok', 'ttl': 14400}}}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/excel/points', 'status': 'ok'}}
# 2025-02-13 17:54:21,584 - WARNING - Unexpected data format for FTBFX on years_since_inception
# 2025-02-13 17:54:21,584 - WARNING - No data for FTBFX on metric years_since_inception (years_since_inception)
# 2025-02-13 17:54:21,714 - INFO - API response for FTBFX on investment_strategy: {'response': {'M:FTBFX': {'meta': {'status': 'ok'}, 'results': {'investment_strategy': {'meta': {'status': 'ok', 'ttl': 43200}, 'data': 'The investment seeks a high level of current income.\n The fund normally invests at least 80% of assets in debt securities of all types and repurchase agreements for those securities. The Bloomberg U.S. Aggregate Bond Index as a guide in structuring the fund and selecting its investments. It may invest up to 20% of assets in lower-quality debt securities (those of less than investment-grade quality, also referred to as high yield debt securities or junk bonds).'}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/mutual_funds/M:FTBFX/info/investment_strategy?retrieve_ttl=true', 'status': 'ok'}}
# 2025-02-13 17:54:21,831 - INFO - API response for FTBFX on related_securities: {'response': {'M:FTBFX': {'meta': {'status': 'ok'}, 'results': {'related_securities': {'meta': {'status': 'ok', 'ttl': 43200}, 'data': [{'name': 'Victory Core Plus Intermediate Bond Fund Fd', 'security_id': 'M:USIBX'}, {'name': 'VALIC Company Core Bond Fund', 'security_id': 'M:VCBDX'}, {'name': 'Fidelity Total Bond K6 Fund', 'security_id': 'M:FTKFX'}, {'name': 'JNL/Fidelity Institutional Asset Mgt Total Bond A', 'security_id': 'M:LP40022157'}, {'name': 'Fidelity SAI Total Bond Fund', 'security_id': 'M:FSMTX'}]}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/mutual_funds/M:FTBFX/info/related_securities?retrieve_ttl=true', 'status': 'ok'}}
# 2025-02-13 17:54:21,938 - INFO - API response for FTBFX on fund_family: {'response': {'M:FTBFX': {'meta': {'status': 'ok'}, 'results': {'fund_family': {'meta': {'status': 'ok', 'ttl': 43200}, 'data': 'Fidelity Investments'}}}}, 'meta': {'url': 'https://api.ycharts.com/v3/mutual_funds/M:FTBFX/info/fund_family?retrieve_ttl=true', 'status': 'ok'}}
# 2025-02-13 17:54:21,939 - INFO - Results for RDVY:
# 2025-02-13 17:54:21,940 - INFO -   InceptionDate: 2014-01-06
# 2025-02-13 17:54:21,940 - INFO -   EarliestPerformanceDate: 2014-01-06
# 2025-02-13 17:54:21,941 - INFO -   LCG: None
# 2025-02-13 17:54:21,941 - INFO -   LCB: None
# 2025-02-13 17:54:21,942 - INFO -   LCV: None
# 2025-02-13 17:54:21,942 - INFO -   MCG: None
# 2025-02-13 17:54:21,942 - INFO -   MCB: None
# 2025-02-13 17:54:21,942 - INFO -   MCV: None
# 2025-02-13 17:54:21,944 - INFO -   SCG: None
# 2025-02-13 17:54:21,944 - INFO -   SCB: None
# 2025-02-13 17:54:21,945 - INFO -   SCV: None
# 2025-02-13 17:54:21,945 - INFO -   Giant_Cap_Exposure: None
# 2025-02-13 17:54:21,945 - INFO -   Large_Cap_Exposure: None
# 2025-02-13 17:54:21,946 - INFO -   Medium_Cap_Exposure: None
# 2025-02-13 17:54:21,946 - INFO -   Micro_Cap_Exposure: None
# 2025-02-13 17:54:21,947 - INFO -   Sensitive_Exposure: None
# 2025-02-13 17:54:21,947 - INFO -   Small_Cap_Exposure: None
# 2025-02-13 17:54:21,947 - INFO -   Cyclical_Exposure: None
# 2025-02-13 17:54:21,948 - INFO -   Defensive_Exposure: None
# 2025-02-13 17:54:21,948 - INFO -   AAA_Rated: None
# 2025-02-13 17:54:21,949 - INFO -   AA_Rated: None
# 2025-02-13 17:54:21,949 - INFO -   A_Rated: None
# 2025-02-13 17:54:21,949 - INFO -   BBB_Rated: None
# 2025-02-13 17:54:21,950 - INFO -   B_Rated: None
# 2025-02-13 17:54:21,950 - INFO -   BB_Rated: None
# 2025-02-13 17:54:21,950 - INFO -   Below_B_Rated: None
# 2025-02-13 17:54:21,951 - INFO -   Not_Rated: None
# 2025-02-13 17:54:21,951 - INFO -   Term_10_15_Y: None
# 2025-02-13 17:54:21,951 - INFO -   Term_1_3_Y: None
# 2025-02-13 17:54:21,952 - INFO -   Term_15_20_Y: None
# 2025-02-13 17:54:21,952 - INFO -   Term_1_7_D: None
# 2025-02-13 17:54:21,952 - INFO -   Term_183_364_D: None
# 2025-02-13 17:54:21,953 - INFO -   Term_20_30_Y: None
# 2025-02-13 17:54:21,953 - INFO -   Term_30_Plus_Y: None
# 2025-02-13 17:54:21,953 - INFO -   Term_31_90_D: None
# 2025-02-13 17:54:21,957 - INFO -   Term_3_5_Y: None
# 2025-02-13 17:54:21,958 - INFO -   Term_5_7_Y: None
# 2025-02-13 17:54:21,958 - INFO -   Term_7_10_Y: None
# 2025-02-13 17:54:21,959 - INFO -   Term_8_30_D: None
# 2025-02-13 17:54:21,959 - INFO -   Term_91_182_D: None
# 2025-02-13 17:54:21,959 - INFO -   LT_Exposure: None
# 2025-02-13 17:54:21,960 - INFO -   Interm_Exposure: None
# 2025-02-13 17:54:21,960 - INFO -   ST_Exposure: None
# 2025-02-13 17:54:21,960 - INFO -   pct_top_10: None
# 2025-02-13 17:54:21,961 - INFO -   pct_top_25: None
# 2025-02-13 17:54:21,961 - INFO -   materials: None
# 2025-02-13 17:54:21,962 - INFO -   comsvc: None
# 2025-02-13 17:54:21,962 - INFO -   concyc: None
# 2025-02-13 17:54:21,962 - INFO -   condef: None
# 2025-02-13 17:54:21,963 - INFO -   energy: None
# 2025-02-13 17:54:21,965 - INFO -   finsvc: None
# 2025-02-13 17:54:21,965 - INFO -   healthcare: None
# 2025-02-13 17:54:21,966 - INFO -   industrials: None
# 2025-02-13 17:54:21,966 - INFO -   realestate: None
# 2025-02-13 17:54:21,966 - INFO -   technology: None
# 2025-02-13 17:54:21,967 - INFO -   utilities: None
# 2025-02-13 17:54:21,967 - INFO -   relative_composition: None
# 2025-02-13 17:54:21,967 - INFO -   num_bonds: None
# 2025-02-13 17:54:21,968 - INFO -   num_stocks: None
# 2025-02-13 17:54:21,969 - INFO -   dev_mkt: None
# 2025-02-13 17:54:21,969 - INFO -   em_mkt: None
# 2025-02-13 17:54:21,970 - INFO -   europe: None
# 2025-02-13 17:54:21,971 - INFO -   lat_america: None
# 2025-02-13 17:54:21,971 - INFO -   namerica: None
# 2025-02-13 17:54:21,971 - INFO -   africa_mideast: None
# 2025-02-13 17:54:21,972 - INFO -   asia_em: None
# 2025-02-13 17:54:21,973 - INFO -   asia_dev: None
# 2025-02-13 17:54:21,973 - INFO -   australia: None
# 2025-02-13 17:54:21,974 - INFO -   india: None
# 2025-02-13 17:54:21,974 - INFO -   w_avg_dc: None
# 2025-02-13 17:54:21,974 - INFO -   avg_mkt_cap: None
# 2025-02-13 17:54:21,975 - INFO -   avg_pe_ratio: None
# 2025-02-13 17:54:21,975 - INFO -   avg_pb_ratio: None
# 2025-02-13 17:54:21,976 - INFO -   avg_pcf_ratio: None
# 2025-02-13 17:54:21,976 - INFO -   avg_ps_ratio: None
# 2025-02-13 17:54:21,976 - INFO -   avg_net_margin: None
# 2025-02-13 17:54:21,977 - INFO -   avg_roa: None
# 2025-02-13 17:54:21,978 - INFO -   avg_roe: None
# 2025-02-13 17:54:21,978 - INFO -   preferreds: None
# 2025-02-13 17:54:21,979 - INFO -   securitized: None
# 2025-02-13 17:54:21,979 - INFO -   muni_exempt: None
# 2025-02-13 17:54:21,980 - INFO -   muni_tax: None
# 2025-02-13 17:54:21,980 - INFO -   muni_exposure: None
# 2025-02-13 17:54:21,980 - INFO -   corp_exposure: None
# 2025-02-13 17:54:21,981 - INFO -   corp_fi: None
# 2025-02-13 17:54:21,981 - INFO -   govi_exp: None
# 2025-02-13 17:54:21,982 - INFO -   govi_fi: None
# 2025-02-13 17:54:21,984 - INFO -   covered_bond: None
# 2025-02-13 17:54:21,984 - INFO -   gov_bond: None
# 2025-02-13 17:54:21,984 - INFO -   converts: None
# 2025-02-13 17:54:21,985 - INFO -   asset_backed_sec: None
# 2025-02-13 17:54:21,985 - INFO -   index_fund: True
# 2025-02-13 17:54:21,986 - INFO -   inverse_fund: False
# 2025-02-13 17:54:21,986 - INFO -   leveraged_fund: False
# 2025-02-13 17:54:21,986 - INFO -   socially_responsible_fund: False
# 2025-02-13 17:54:21,987 - INFO -   synthetic_replication_fund: False
# 2025-02-13 17:54:21,988 - INFO -   aum_usd: 13767419319.0
# 2025-02-13 17:54:21,988 - INFO -   average_manager_tenure: None
# 2025-02-13 17:54:21,989 - INFO -   max_manager_tenure: None
# 2025-02-13 17:54:21,989 - INFO -   median_manager_tenure: None
# 2025-02-13 17:54:21,990 - INFO -   min_manager_tenure: None
# 2025-02-13 17:54:21,991 - INFO -   open_to_existing_investors: True
# 2025-02-13 17:54:21,991 - INFO -   open_to_new_investors: True
# 2025-02-13 17:54:21,992 - INFO -   ycharts_url: https://ycharts.com/companies/RDVY
# 2025-02-13 17:54:21,992 - INFO -   years_since_inception: None
# 2025-02-13 17:54:21,993 - INFO -   investment_strategy: The investment seeks investment results that correspond generally to the price and yield (before fees and expenses) of the NASDAQ U.S. Rising Dividend Achievers TM Index.
#  The fund will normally invest at least 90% of its net assets (including investment borrowings) in the common stock and depositary receipts that comprise the index. The index is designed to provide access to a diversified portfolio of small, mid and large capitalization companies with a history of raising their dividends while exhibiting the characteristics to continue to do so in the future by including companies with strong cash balances, low debt and increasing earnings.
# 2025-02-13 17:54:21,993 - INFO -   related_securities: ["DHS", "DVY", "SDOG", "SPHD", "FTA"]
# 2025-02-13 17:54:21,994 - INFO -   fund_family: First Trust
# 2025-02-13 17:54:21,994 - INFO - Results for FTBFX:
# 2025-02-13 17:54:21,995 - INFO -   InceptionDate: 2002-10-15
# 2025-02-13 17:54:21,995 - INFO -   EarliestPerformanceDate: 2002-10-15
# 2025-02-13 17:54:21,996 - INFO -   LCG: None
# 2025-02-13 17:54:21,996 - INFO -   LCB: None
# 2025-02-13 17:54:21,996 - INFO -   LCV: None
# 2025-02-13 17:54:21,997 - INFO -   MCG: None
# 2025-02-13 17:54:21,997 - INFO -   MCB: None
# 2025-02-13 17:54:21,999 - INFO -   MCV: None
# 2025-02-13 17:54:21,999 - INFO -   SCG: None
# 2025-02-13 17:54:22,000 - INFO -   SCB: None
# 2025-02-13 17:54:22,000 - INFO -   SCV: None
# 2025-02-13 17:54:22,001 - INFO -   Giant_Cap_Exposure: None
# 2025-02-13 17:54:22,001 - INFO -   Large_Cap_Exposure: None
# 2025-02-13 17:54:22,002 - INFO -   Medium_Cap_Exposure: None
# 2025-02-13 17:54:22,002 - INFO -   Micro_Cap_Exposure: None
# 2025-02-13 17:54:22,002 - INFO -   Sensitive_Exposure: None
# 2025-02-13 17:54:22,003 - INFO -   Small_Cap_Exposure: None
# 2025-02-13 17:54:22,003 - INFO -   Cyclical_Exposure: None
# 2025-02-13 17:54:22,003 - INFO -   Defensive_Exposure: None
# 2025-02-13 17:54:22,004 - INFO -   AAA_Rated: None
# 2025-02-13 17:54:22,005 - INFO -   AA_Rated: None
# 2025-02-13 17:54:22,005 - INFO -   A_Rated: None
# 2025-02-13 17:54:22,005 - INFO -   BBB_Rated: None
# 2025-02-13 17:54:22,006 - INFO -   B_Rated: None
# 2025-02-13 17:54:22,006 - INFO -   BB_Rated: None
# 2025-02-13 17:54:22,006 - INFO -   Below_B_Rated: None
# 2025-02-13 17:54:22,006 - INFO -   Not_Rated: None
# 2025-02-13 17:54:22,008 - INFO -   Term_10_15_Y: None
# 2025-02-13 17:54:22,008 - INFO -   Term_1_3_Y: None
# 2025-02-13 17:54:22,008 - INFO -   Term_15_20_Y: None
# 2025-02-13 17:54:22,010 - INFO -   Term_1_7_D: None
# 2025-02-13 17:54:22,010 - INFO -   Term_183_364_D: None
# 2025-02-13 17:54:22,010 - INFO -   Term_20_30_Y: None
# 2025-02-13 17:54:22,011 - INFO -   Term_30_Plus_Y: None
# 2025-02-13 17:54:22,011 - INFO -   Term_31_90_D: None
# 2025-02-13 17:54:22,011 - INFO -   Term_3_5_Y: None
# 2025-02-13 17:54:22,012 - INFO -   Term_5_7_Y: None
# 2025-02-13 17:54:22,012 - INFO -   Term_7_10_Y: None
# 2025-02-13 17:54:22,013 - INFO -   Term_8_30_D: None
# 2025-02-13 17:54:22,013 - INFO -   Term_91_182_D: None
# 2025-02-13 17:54:22,013 - INFO -   LT_Exposure: None
# 2025-02-13 17:54:22,013 - INFO -   Interm_Exposure: None
# 2025-02-13 17:54:22,014 - INFO -   ST_Exposure: None
# 2025-02-13 17:54:22,014 - INFO -   pct_top_10: None
# 2025-02-13 17:54:22,014 - INFO -   pct_top_25: None
# 2025-02-13 17:54:22,015 - INFO -   materials: None
# 2025-02-13 17:54:22,015 - INFO -   comsvc: None
# 2025-02-13 17:54:22,016 - INFO -   concyc: None
# 2025-02-13 17:54:22,016 - INFO -   condef: None
# 2025-02-13 17:54:22,017 - INFO -   energy: None
# 2025-02-13 17:54:22,017 - INFO -   finsvc: None
# 2025-02-13 17:54:22,017 - INFO -   healthcare: None
# 2025-02-13 17:54:22,018 - INFO -   industrials: None
# 2025-02-13 17:54:22,019 - INFO -   realestate: None
# 2025-02-13 17:54:22,019 - INFO -   technology: None
# 2025-02-13 17:54:22,020 - INFO -   utilities: None
# 2025-02-13 17:54:22,020 - INFO -   relative_composition: None
# 2025-02-13 17:54:22,021 - INFO -   num_bonds: None
# 2025-02-13 17:54:22,021 - INFO -   num_stocks: None
# 2025-02-13 17:54:22,021 - INFO -   dev_mkt: None
# 2025-02-13 17:54:22,023 - INFO -   em_mkt: None
# 2025-02-13 17:54:22,023 - INFO -   europe: None
# 2025-02-13 17:54:22,023 - INFO -   lat_america: None
# 2025-02-13 17:54:22,024 - INFO -   namerica: None
# 2025-02-13 17:54:22,024 - INFO -   africa_mideast: None
# 2025-02-13 17:54:22,026 - INFO -   asia_em: None
# 2025-02-13 17:54:22,026 - INFO -   asia_dev: None
# 2025-02-13 17:54:22,026 - INFO -   australia: None
# 2025-02-13 17:54:22,026 - INFO -   india: None
# 2025-02-13 17:54:22,027 - INFO -   w_avg_dc: None
# 2025-02-13 17:54:22,027 - INFO -   avg_mkt_cap: None
# 2025-02-13 17:54:22,028 - INFO -   avg_pe_ratio: None
# 2025-02-13 17:54:22,028 - INFO -   avg_pb_ratio: None
# 2025-02-13 17:54:22,029 - INFO -   avg_pcf_ratio: None
# 2025-02-13 17:54:22,029 - INFO -   avg_ps_ratio: None
# 2025-02-13 17:54:22,030 - INFO -   avg_net_margin: None
# 2025-02-13 17:54:22,031 - INFO -   avg_roa: None
# 2025-02-13 17:54:22,032 - INFO -   avg_roe: None
# 2025-02-13 17:54:22,032 - INFO -   preferreds: None
# 2025-02-13 17:54:22,033 - INFO -   securitized: None
# 2025-02-13 17:54:22,033 - INFO -   muni_exempt: None
# 2025-02-13 17:54:22,034 - INFO -   muni_tax: None
# 2025-02-13 17:54:22,035 - INFO -   muni_exposure: None
# 2025-02-13 17:54:22,035 - INFO -   corp_exposure: None
# 2025-02-13 17:54:22,036 - INFO -   corp_fi: None
# 2025-02-13 17:54:22,036 - INFO -   govi_exp: None
# 2025-02-13 17:54:22,037 - INFO -   govi_fi: None
# 2025-02-13 17:54:22,037 - INFO -   covered_bond: None
# 2025-02-13 17:54:22,037 - INFO -   gov_bond: None
# 2025-02-13 17:54:22,038 - INFO -   converts: None
# 2025-02-13 17:54:22,038 - INFO -   asset_backed_sec: None
# 2025-02-13 17:54:22,039 - INFO -   index_fund: False
# 2025-02-13 17:54:22,040 - INFO -   inverse_fund: False
# 2025-02-13 17:54:22,040 - INFO -   leveraged_fund: False
# 2025-02-13 17:54:22,040 - INFO -   socially_responsible_fund: False
# 2025-02-13 17:54:22,041 - INFO -   synthetic_replication_fund: False
# 2025-02-13 17:54:22,042 - INFO -   aum_usd: 15423215550.0
# 2025-02-13 17:54:22,042 - INFO -   average_manager_tenure: None
# 2025-02-13 17:54:22,042 - INFO -   max_manager_tenure: None
# 2025-02-13 17:54:22,043 - INFO -   median_manager_tenure: None
# 2025-02-13 17:54:22,043 - INFO -   min_manager_tenure: None
# 2025-02-13 17:54:22,043 - INFO -   open_to_existing_investors: True
# 2025-02-13 17:54:22,045 - INFO -   open_to_new_investors: True
# 2025-02-13 17:54:22,045 - INFO -   ycharts_url: https://ycharts.com/mutual_funds/M:FTBFX
# 2025-02-13 17:54:22,045 - INFO -   years_since_inception: None
# 2025-02-13 17:54:22,046 - INFO -   investment_strategy: The investment seeks a high level of current income.
#  The fund normally invests at least 80% of assets in debt securities of all types and repurchase agreements for those securities. The Bloomberg U.S. Aggregate Bond Index as a guide in structuring the fund and selecting its investments. It may invest up to 20% of assets in lower-quality debt securities (those of less than investment-grade quality, also referred to as high yield debt securities or junk bonds).
# 2025-02-13 17:54:22,046 - INFO -   related_securities: ["M:USIBX", "M:VCBDX", "M:FTKFX", "M:LP40022157", "M:FSMTX"]
# 2025-02-13 17:54:22,046 - INFO -   fund_family: Fidelity Investments
