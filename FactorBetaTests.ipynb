# %%
# Version 1

# %%
# Version 4.2
import pandas as pd
import numpy as np
import os
import random
import logging
from datetime import timedelta, datetime
from dateutil.relativedelta import relativedelta
from concurrent.futures import ProcessPoolExecutor
from sqlalchemy import create_engine
from tqdm import tqdm
from statsmodels.regression.linear_model import OLS
from statsmodels.tools.tools import add_constant
import statsmodels.api as sm
import time

# Section 1: Configuration and Setup
connection_string = (
    "mssql+pyodbc://JULIANS_LAPTOP\\SQLEXPRESS/CWA_Fund_Database"
    "?driver=ODBC+Driver+18+for+SQL+Server"
    "&trusted_connection=yes&TrustServerCertificate=yes"
)
engine = create_engine(connection_string)

RETURN_METRIC = "1 Month Return"
ROLLING_PERIODS = [12, 24, 36, 48, 60]  # in months
DRY_RUN = True
SAMPLE_DRY_RUN = True
SAMPLE_SIZE = 100
CHUNK_SIZE = 5600
BATCH_INSERT_SIZE = 10000
MAX_WORKERS = 15  # Optimized for 16-core i9-185H

# Section 2: Helper Functions
def category_to_region(category):
    mapping = {
        "US Equity Large Cap Blend": ("USA", "US Equity Large Cap Blend"),
        "US Equity Large Cap Growth": ("USA", "US Equity Large Cap Growth"),
        "US Equity Large Cap Value": ("USA", "US Equity Large Cap Value"),
        "US Equity Mid Cap": ("USA", "US Equity Mid Cap"),
        "US Equity Small Cap": ("USA", "US Equity Small Cap"),
        "Global Equity Large Cap": ("Global", "Global Equity Large Cap"),
        "Global Equity Mid/Small Cap": ("Global", "Global Equity Mid/Small Cap"),
        "Global Emerging Markets Equity": ("Global", "Global Emerging Markets Equity"),
        "Europe Equity Large Cap": ("International", "Europe Equity Large Cap"),
        "Asia Equity": ("International", "Asia Equity"),
        "Japan Equity": ("International", "Japan Equity"),
        "Emerging Markets Fixed Income": ("International", "Emerging Markets Fixed Income"),
        "US Fixed Income": ("USA", "US Fixed Income"),
        "US Municipal Fixed Income": ("USA", "US Municipal Fixed Income"),
        "Global Fixed Income": ("Global", "Global Fixed Income"),
        "Flexible Allocation": ("Global", "Flexible Allocation"),
        "Aggressive Allocation": ("Global", "Aggressive Allocation"),
        "Moderate Allocation": ("Global", "Moderate Allocation"),
        "Cautious Allocation": ("Global", "Cautious Allocation"),
        "Commodities Broad Basket": ("Global", "Commodities Broad Basket"),
        "Commodities Specified": ("Global", "Commodities Specified"),
        "Options Trading": ("USA", "Options Trading"),
        "Multialternative": ("Global", "Multialternative"),
        "Market Neutral": ("Global", "Market Neutral"),
        "Long/Short Equity": ("Global", "Long/Short Equity"),
        "Alternative Miscellaneous": ("Global", "Alternative Miscellaneous"),
        "Energy Sector Equity": ("USA", "Energy Sector Equity"),
        "Equity Miscellaneous": ("USA", "Equity Miscellaneous"),
        "Financials Sector Equity": ("USA", "Financials Sector Equity"),
        "Healthcare Sector Equity": ("USA", "Healthcare Sector Equity"),
        "Consumer Goods & Services Sector Equity": ("USA", "Consumer Goods & Services Sector Equity"),
        "Communications Sector Equity": ("USA", "Communications Sector Equity"),
        "Industrials Sector Equity": ("USA", "Industrials Sector Equity"),
        "Other Sector Equity": ("USA", "Other Sector Equity"),
        "Real Estate Sector Equity": ("USA", "Real Estate Sector Equity"),
        "Precious Metals Sector Equity": ("USA", "Precious Metals Sector Equity"),
        "Technology Sector Equity": ("USA", "Technology Sector Equity"),
        "Utilities Sector Equity": ("USA", "Utilities Sector Equity"),
        "Asia ex-Japan Equity": ("International", "Asia ex-Japan Equity"),
        "Australia & New Zealand Equity": ("International", "Australia & New Zealand Equity"),
        "Canadian Equity Large Cap": ("International", "Canadian Equity Large Cap"),
        "Europe Equity Mid/Small Cap": ("International", "Europe Equity Mid/Small Cap"),
        "Greater China Equity": ("International", "Greater China Equity"),
        "India Equity": ("International", "India Equity"),
        "Mexico Equity": ("International", "Mexico Equity"),
        "Korea Equity": ("International", "Korea Equity"),
        "Latin America Equity": ("International", "Latin America Equity"),
        "UK Equity Large Cap": ("International", "UK Equity Large Cap"),
        "Thailand Equity": ("International", "Thailand Equity"),
        "Convertibles": ("USA", "Convertibles"),
        "Fixed Income Miscellaneous": ("USA", "Fixed Income Miscellaneous"),
        "Allocation Miscellaneous": ("Global", "Allocation Miscellaneous")
    }
    return mapping.get(category, ("Unknown", "Unknown"))

# Section 3: Data Loading Functions
def load_fund_metadata():
    query = """
    SELECT 
        f.SymbolCUSIP, 
        f.Region, 
        f.YC_Global_Category_ID, 
        c.Global_Category_Name,
        f.YC_Category_ID,
        y.YC_Category_Name,
        f.CWA_Broad_Category_ID,
        b.CWA_Broad_Category_Name
    FROM Funds_to_Screen f
    JOIN YC_Global_Category_List c ON f.YC_Global_Category_ID = c.ID
    JOIN YC_Category_List y ON f.YC_Category_ID = y.ID
    JOIN CWA_Broad_Category_Name b ON f.CWA_Broad_Category_ID = b.ID
    """
    df = pd.read_sql(query, engine)
    df[["Region", "FactorProfile"]] = df["Global_Category_Name"].map(category_to_region).apply(pd.Series)
    return df.dropna(subset=["Region", "FactorProfile"])

def load_fund_returns(fund_ids):
    placeholders = ",".join([f"'{fid}'" for fid in fund_ids])
    query = f"""
        SELECT SymbolCUSIP, Date, ReturnValue
        FROM Fund_Returns_Timeseries
        WHERE SymbolCUSIP IN ({placeholders})
        AND Metric = '{RETURN_METRIC}'
    """
    return pd.read_sql(query, engine, parse_dates=["Date"]).pivot(index="Date", columns="SymbolCUSIP", values="ReturnValue")

def load_db_factors(factor_list, region="Global", table="factor_returns", portfolio_filter=None):
    factor_in_clause = ','.join([f"'{f}'" for f in factor_list])
    portfolio_in_clause = ','.join([f"'{p}'" for p in portfolio_filter]) if portfolio_filter else ''
    query = f"""
        SELECT date AS Date, factor_symbol AS Factor, value AS Value
        FROM {table}
        WHERE region = ?
        AND factor_symbol IN ({factor_in_clause})
    """
    if portfolio_filter:
        query += f" AND portfolio IN ({portfolio_in_clause})"
    print(f"Executing query: {query} with param: {region}")
    df = pd.read_sql(query, engine, params=(region,), parse_dates=['Date'])
    print(f"DB factors loaded: {df.columns.tolist()} | Shape: {df.shape}")
    pivoted_df = df.pivot(index="Date", columns="Factor", values="Value").rename(
        columns={
            'MKT': 'mkt', 'SMB': 'smb', 'HML_Devil': 'hml', 'UMD': 'umd', 'QMJ': 'qmj',
            'BAB': 'bab', 'RF': 'rf', 'TSM-Com': 'tsm-com', 'TSM-EQ': 'tsm-eq',
            'TSM-FI': 'tsm-fi', 'TSM-FX': 'tsm-fx', 'TSM-MA': 'tsm-ma'
        }
    )
    print(f"DB factors columns after pivot: {pivoted_df.columns.tolist()}")
    return pivoted_df

def load_fixed_income_factors(factor_list):
    factor_in_clause = ','.join([f"'{f}'" for f in factor_list])
    query = f"""
        SELECT Date, Factor_Name, ReturnValue
        FROM Fixed_Income_Factor_Returns
        WHERE Factor_Name IN ({factor_in_clause})
    """
    return pd.read_sql(query, engine, parse_dates=["Date"]).pivot(index="Date", columns="Factor_Name", values="ReturnValue")

def load_century_factors(factor_list, portfolio, asset_class=None, region="Global"):
    factor_in_clause = ','.join([f"'{f}'" for f in factor_list])
    query = f"""
        SELECT date AS Date, factor AS Factor, value AS Value
        FROM aqr_century_factors
        WHERE factor IN ({factor_in_clause})
        AND portfolio = ?
    """
    params = [portfolio]
    if asset_class:
        query += " AND asset_class = ?"
        params.append(asset_class)
    if region != "Global":
        query += " AND region = ?"
        params.append(region)
    print(f"Executing query: {query} with params: {params}")
    df = pd.read_sql(query, engine, params=params, parse_dates=['Date'])
    print(f"Century factors loaded: {df.columns.tolist()} | Shape: {df.shape}")
    pivoted_df = df.pivot(index="Date", columns="Factor", values="Value")
    print(f"Century factors columns after pivot: {pivoted_df.columns.tolist()}")
    return pivoted_df

def load_commodity_factors(factor_list):
    factor_in_clause = ','.join([f"'{f}'" for f in factor_list])
    query = f"""
        SELECT date AS Date, {factor_in_clause} AS Factor, value AS Value
        FROM aqr_cmdty_factors
    """
    df = pd.read_sql(query, engine, parse_dates=['Date'])
    print(f"Commodity factors loaded: {df.columns.tolist()} | Shape: {df.shape}")
    return df.set_index("Date")

# Section 4: Rolling Regression Functions
def run_rolling_regression(fund, returns, factors, regression_type, factor_set):
    results = []
    returns.index = pd.to_datetime(returns.index)
    factors.index = pd.to_datetime(factors.index)
    viable_periods = [w for w in ROLLING_PERIODS if (returns.index.max() - relativedelta(months=w)) >= returns.index.min()]
    
    for window in viable_periods:
        start = returns.index.min() + relativedelta(months=window)
        for end_date in returns.loc[returns.index >= start].index:
            start_date = end_date - relativedelta(months=window - 1)
            y = returns.loc[start_date:end_date]
            X = factors.loc[start_date:end_date]
            X, y = X.align(y, join="inner", axis=0)
            if len(y) < window or y.isnull().any() or X.isnull().any().any():
                continue
            X_const = add_constant(X)
            model = OLS(y, X_const).fit()
            for factor in X.columns:
                results.append({
                    "SymbolCUSIP": fund,
                    "MonthEndDate": end_date,
                    "RollPeriod": f"{window}m",
                    "Factor_Name": factor,
                    "Coefficient": model.params.get(factor, np.nan),
                    "P_Value": model.pvalues.get(factor, np.nan),
                    "Regression_Type": regression_type,
                    "Factor_Set": factor_set
                })
    return results

# Section 5: Main Processing Pipeline
def process_region(region, fund_subset, regression_func):
    records = []
    
    for _, fund_row in fund_subset.iterrows():
        symbol = fund_row["SymbolCUSIP"]
        category = fund_row["Global_Category_Name"]
        broad_category = fund_row["CWA_Broad_Category_Name"]
        
        # Equity
        if category in [
            "Energy Sector Equity", "Equity Miscellaneous", "Financials Sector Equity",
            "Healthcare Sector Equity", "Consumer Goods & Services Sector Equity",
            "Communications Sector Equity", "Industrials Sector Equity", "Other Sector Equity",
            "Real Estate Sector Equity", "Precious Metals Sector Equity", "Technology Sector Equity",
            "Utilities Sector Equity", "US Equity Large Cap Blend", "US Equity Large Cap Growth",
            "US Equity Large Cap Value", "US Equity Mid Cap", "US Equity Small Cap", "Options Trading"
        ]:
            # Regression 1: USA, MKT-RF, HML-Devil, QMJ, SMB, UMD, TSM-EQ, BAB
            factors = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB', 'RF'], "USA")
            if 'mkt' in factors.columns and 'rf' in factors.columns:
                factors['mkt-rf'] = factors['mkt'] - factors['rf']
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors[['mkt-rf', 'hml', 'qmj', 'smb', 'umd', 'tsm-eq', 'bab']], "OLS", "Equity_USA_1"))
            
            # Regression 2: Century Factors, US Stock Selection
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "US Stock Selection", region="USA")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Equity_USA_2"))
            
            # Regression 3: Century Factors, All Macro
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "All Macro")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Equity_USA_3"))
            
            # Regression 4: Century Factors, Equity Indices
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Equity Indices")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Equity_USA_4"))
            
            if broad_category in ["Quantitative/Tactical", "Strategic", "Nontraditional"]:
                # Regression 5: Quantitative/Tactical, Strategic, Nontraditional
                factors = load_db_factors(['MKT', 'RF', 'TSM-FX', 'TSM-FI', 'BAB'], "USA")
                fi_factors = load_fixed_income_factors(['TERM', 'CREDIT'])
                cmdty_factors = load_commodity_factors(['excess_return_eqwt'])
                factors = pd.concat([factors, fi_factors, cmdty_factors], axis=1)
                if 'mkt' in factors.columns and 'rf' in factors.columns:
                    factors['mkt-rf'] = factors['mkt'] - factors['rf']
                records.extend(run_rolling_regression(symbol, fund_row["returns"], factors[['mkt-rf', 'tsm-fx', 'tsm-fi', 'bab', 'TERM', 'CREDIT', 'excess_return_eqwt']], "OLS", "Equity_USA_5"))
                
                # Regression 6: Quantitative/Tactical, Strategic, Nontraditional
                factors = load_db_factors(['MKT', 'TSM-EQ', 'SMB', 'BAB', 'TSM-Com'], "USA")
                fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT_HY'])
                factors = pd.concat([factors, fi_factors], axis=1)
                if 'mkt' in factors.columns:
                    factors['mkt-rf'] = factors['mkt'] - load_db_factors(['RF'], 'Global')['rf']
                records.extend(run_rolling_regression(symbol, fund_row["returns"], factors[['mkt-rf', 'tsm-eq', 'smb', 'bab', 'TERM_Int', 'TERM_Long', 'CREDIT_HY', 'tsm-com']], "OLS", "Equity_USA_6"))
                
                # Regression 7: Quantitative/Tactical, Strategic, Nontraditional
                factors = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'UMD', 'TSM-EQ', 'SMB', 'BAB', 'TSM-Com', 'TSM-FI', 'TSM-FX'], "USA")
                fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY'])
                factors = pd.concat([factors, fi_factors], axis=1)
                if 'mkt' in factors.columns:
                    factors['mkt-rf'] = factors['mkt'] - load_db_factors(['RF'], 'Global')['rf']
                records.extend(run_rolling_regression(symbol, fund_row["returns"], factors[['mkt-rf', 'hml', 'qmj', 'umd', 'tsm-eq', 'smb', 'bab', 'TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY', 'tsm-com', 'tsm-fi', 'tsm-fx']], "OLS", "Equity_USA_7"))
        
        elif category in [
            "Asia ex-Japan Equity", "Australia & New Zealand Equity", "Canadian Equity Large Cap",
            "Europe Equity Large Cap", "Europe Equity Mid/Small Cap", "Greater China Equity",
            "India Equity", "Mexico Equity", "Japan Equity", "Korea Equity", "Latin America Equity",
            "UK Equity Large Cap", "Thailand Equity"
        ]:
            # Regression 1: International
            factors = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB', 'RF'], "Intl")
            if 'mkt' in factors.columns and 'rf' in factors.columns:
                factors['mkt-rf'] = factors['mkt'] - factors['rf']
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors[['mkt-rf', 'hml', 'qmj', 'smb', 'umd', 'tsm-eq', 'bab']], "OLS", "Equity_Intl_1"))
            
            # Regression 2: Century Factors, Intl Stock Selection
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Intl Stock Selection", region="International")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Equity_Intl_2"))
            
            # Regression 3: Century Factors, All Macro
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "All Macro")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Equity_Intl_3"))
            
            # Regression 4: Century Factors, Equity Indices
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Equity Indices")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Equity_Intl_4"))
        
        elif category in ["Global Emerging Markets Equity", "Global Equity Large Cap", "Global Equity Mid/Small Cap"]:
            # Regression 1: Global
            factors = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB', 'RF'], "Global")
            if 'mkt' in factors.columns and 'rf' in factors.columns:
                factors['mkt-rf'] = factors['mkt'] - factors['rf']
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors[['mkt-rf', 'hml', 'qmj', 'smb', 'umd', 'tsm-eq', 'bab']], "OLS", "Equity_Global_1"))
            
            # Regression 2: Century Factors, All Stock Selection
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "All Stock Selection")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Equity_Global_2"))
            
            # Regression 3: Century Factors, All Macro
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "All Macro")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Equity_Global_3"))
            
            # Regression 4: Century Factors, Equity Indices
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Equity Indices")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Equity_Global_4"))
        
        # Fixed Income
        elif category in [
            "Convertibles", "Emerging Markets Fixed Income", "Fixed Income Miscellaneous",
            "US Fixed Income", "US Municipal Fixed Income"
        ]:
            # Regression 1: TERM_Int, TERM_Long, CREDIT, CREDIT_HY, TSM-FI, TSM-FX
            factors = load_db_factors(['TSM-FI', 'TSM-FX'])
            fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY'])
            factors = pd.concat([factors, fi_factors], axis=1)
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors[['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY', 'tsm-fi', 'tsm-fx']], "OLS", "FI_1"))
            
            # Regression 2: Century Factors, Fixed Income
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Fixed Income")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "FI_2"))
            
            # Regression 3: Century Factors, All Macro
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "All Macro")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "FI_3"))
            
            # Regression 4: Century Factors, Equity Indices
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Equity Indices")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "FI_4"))
        
        # Allocation
        elif category in [
            "Aggressive Allocation", "Allocation Miscellaneous", "Cautious Allocation",
            "Flexible Allocation", "Moderate Allocation"
        ]:
            # Regression 1: Global, MKT-RF, HML-Devil, QMJ, SMB, UMD, BAB, TSM-EQ, TSM-FI, TERM_Int, TERM_Long, CREDIT, CREDIT_HY
            factors = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ', 'TSM-FI', 'RF'], "Global")
            fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY'])
            factors = pd.concat([factors, fi_factors], axis=1)
            if 'mkt' in factors.columns and 'rf' in factors.columns:
                factors['mkt-rf'] = factors['mkt'] - factors['rf']
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors[['mkt-rf', 'hml', 'qmj', 'smb', 'umd', 'bab', 'tsm-eq', 'tsm-fi', 'TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY']], "OLS", "Allocation_1"))
            
            # Regression 2: Century Factors, Fixed Income and All Stock Selection
            fi_factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Fixed Income")
            stock_factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "All Stock Selection")
            factors = pd.concat([fi_factors, stock_factors], axis=1)
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Allocation_2"))
            
            # Regression 3: Century Factors, All Macro
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "All Macro")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Allocation_3"))
            
            # Regression 4: Century Factors, Equity Indices
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Equity Indices")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Allocation_4"))
        
        # Alternatives
        elif category in [
            "Alternative Miscellaneous", "Long/Short Equity", "Market Neutral", "Multialternative"
        ]:
            # Regression 1: Global, MKT-RF, HML-Devil, QMJ, SMB, UMD, BAB, TSM-EQ, TSM-FI, TERM_Int, TERM_Long, CREDIT, CREDIT_HY, TSM-COM, TSM-FX
            factors = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ', 'TSM-FI', 'TSM-Com', 'TSM-FX', 'RF'], "Global")
            fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY'])
            factors = pd.concat([factors, fi_factors], axis=1)
            if 'mkt' in factors.columns and 'rf' in factors.columns:
                factors['mkt-rf'] = factors['mkt'] - factors['rf']
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors[['mkt-rf', 'hml', 'qmj', 'smb', 'umd', 'bab', 'tsm-eq', 'tsm-fi', 'TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY', 'tsm-com', 'tsm-fx']], "OLS", "Alternative_1"))
            
            # Regression 2: Century Factors, Fixed Income, All Stock Selection, Commodities
            fi_factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Fixed Income")
            stock_factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "All Stock Selection")
            cmdty_factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Commodities")
            factors = pd.concat([fi_factors, stock_factors, cmdty_factors], axis=1)
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Alternative_2"))
            
            # Regression 3: Century Factors, All Macro
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "All Macro")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Alternative_3"))
            
            # Regression 4: Century Factors, Equity Indices
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Equity Indices")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Alternative_4"))
        
        # Commodities
        elif category in ["Commodities Broad Basket", "Commodities Specified"]:
            # Regression 1: All factors from aqr_cmdty_factors
            factors = load_commodity_factors(['excess_return_eqwt', 'excess_spot_return_eqwt', 'ir_adjusted_carry_eqwt', 'spot_return_eqwt', 'carry_eqwt', 'excess_return_long_short', 'excess_spot_return_long_short', 'ir_adjusted_carry_long_short', 'aggregate_backwardation_contango'])
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Commodity_1"))
    
    if records:
        if not DRY_RUN:
            insert_batch(records)
        else:
            print(f"ℹ️ Dry run: Would have written {len(records)} records for {region}")

def main():
    logging.basicConfig(level=logging.INFO)
    
    fund_meta = load_fund_metadata()
    regions = fund_meta["Region"].unique()
    print(f"🧠 Total mapped funds: {len(fund_meta)}")
    print(f"📍 Regions detected: {regions}\n")
    
    regression_func = run_rolling_regression
    
    for region in regions:
        fund_subset = fund_meta[fund_meta["Region"] == region]
        process_region(region, fund_subset, regression_func)

# Section 6: Database Output
def insert_batch(records):
    df = pd.DataFrame(records)
    if not DRY_RUN:
        for i in range(0, len(df), BATCH_INSERT_SIZE):
            batch = df.iloc[i:i + BATCH_INSERT_SIZE]
            batch.to_sql("AQRR_Factor_Attribution", engine, if_exists="append", index=False)
    else:
        print(f"ℹ️ Dry run: Skipped writing {len(df)} records")

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File ~\Software Projects\Database Administration\env\Lib\site-packages\sqlalchemy\engine\base.py:1964, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1963     if not evt_handled:
# -> 1964         self.dialect.do_execute(
#    1965             cursor, str_statement, effective_parameters, context
#    1966         )
#    1968 if self._has_events or self.engine._has_events:
#
# File ~\Software Projects\Database Administration\env\Lib\site-packages\sqlalchemy\engine\default.py:942, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     941 def do_execute(self, cursor, statement, parameters, context=None):
# --> 942     cursor.execute(statement, parameters)
#
# ProgrammingError: ('42S02', "[42S02] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Invalid object name 'CWA_Broad_Category_Name'. (208) (SQLExecDirectW)")
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[1], line 438
#     435         print(f"ℹ️ Dry run: Skipped writing {len(df)} records")
#     437 if __name__ == "__main__":
# --> 438     main()
#
# Cell In[1], line 416, in main()
#     413 def main():
#     414     logging.basicConfig(level=logging.INFO)
# --> 416     fund_meta = load_fund_metadata()
#     417     regions = fund_meta["Region"].unique()
#     418     print(f"🧠 Total mapped funds: {len(fund_meta)}")
#
# Cell In[1], line 109, in load_fund_metadata()
#      93 def load_fund_metadata():
#      94     query = """
#      95     SELECT
#      96         f.SymbolCUSIP,
#    (...)
#     107     JOIN CWA_Broad_Category_Name b ON f.CWA_Broad_Category_ID = b.ID
#     108     """
# --> 109     df = pd.read_sql(query, engine)
#     110     df[["Region", "FactorProfile"]] = df["Global_Category_Name"].map(category_to_region).apply(pd.Series)
#     111     return df.dropna(subset=["Region", "FactorProfile"])
#
# File ~\Software Projects\Database Administration\env\Lib\site-packages\pandas\io\sql.py:734, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     724     return pandas_sql.read_table(
#     725         sql,
#     726         index_col=index_col,
#    (...)
#     731         dtype_backend=dtype_backend,
#     732     )
#     733 else:
# --> 734     return pandas_sql.read_query(
#     735         sql,
#     736         index_col=index_col,
#     737         params=params,
#     738         coerce_float=coerce_float,
#     739         parse_dates=parse_dates,
#     740         chunksize=chunksize,
#     741         dtype_backend=dtype_backend,
#     742         dtype=dtype,
#     743     )
#
# File ~\Software Projects\Database Administration\env\Lib\site-packages\pandas\io\sql.py:1836, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    1779 def read_query(
#    1780     self,
#    1781     sql: str,
#    (...)
#    1788     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    1789 ) -> DataFrame | Iterator[DataFrame]:
#    1790     """
#    1791     Read SQL query into a DataFrame.
#    1792
#    (...)
#    1834
#    1835     """
# -> 1836     result = self.execute(sql, params)
#    1837     columns = result.keys()
#    1839     if chunksize is not None:
#
# File ~\Software Projects\Database Administration\env\Lib\site-packages\pandas\io\sql.py:1659, in SQLDatabase.execute(self, sql, params)
#    1657 args = [] if params is None else [params]
#    1658 if isinstance(sql, str):
# -> 1659     return self.con.exec_driver_sql(sql, *args)
#    1660 return self.con.execute(sql, *args)
#
# File ~\Software Projects\Database Administration\env\Lib\site-packages\sqlalchemy\engine\base.py:1776, in Connection.exec_driver_sql(self, statement, parameters, execution_options)
#    1771 execution_options = self._execution_options.merge_with(
#    1772     execution_options
#    1773 )
#    1775 dialect = self.dialect
# -> 1776 ret = self._execute_context(
#    1777     dialect,
#    1778     dialect.execution_ctx_cls._init_statement,
#    1779     statement,
#    1780     None,
#    1781     execution_options,
#    1782     statement,
#    1783     distilled_parameters,
#    1784 )
#    1786 return ret
#
# File ~\Software Projects\Database Administration\env\Lib\site-packages\sqlalchemy\engine\base.py:1843, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1841     return self._exec_insertmany_context(dialect, context)
#    1842 else:
# -> 1843     return self._exec_single_context(
#    1844         dialect, context, statement, parameters
#    1845     )
#
# File ~\Software Projects\Database Administration\env\Lib\site-packages\sqlalchemy\engine\base.py:1983, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1980     result = context._setup_result_proxy()
#    1982 except BaseException as e:
# -> 1983     self._handle_dbapi_exception(
#    1984         e, str_statement, effective_parameters, cursor, context
#    1985     )
#    1987 return result
#
# File ~\Software Projects\Database Administration\env\Lib\site-packages\sqlalchemy\engine\base.py:2352, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2350 elif should_wrap:
#    2351     assert sqlalchemy_exception is not None
# -> 2352     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2353 else:
#    2354     assert exc_info[1] is not None
#
# File ~\Software Projects\Database Administration\env\Lib\site-packages\sqlalchemy\engine\base.py:1964, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1962                 break
#    1963     if not evt_handled:
# -> 1964         self.dialect.do_execute(
#    1965             cursor, str_statement, effective_parameters, context
#    1966         )
#    1968 if self._has_events or self.engine._has_events:
#    1969     self.dispatch.after_cursor_execute(
#    1970         self,
#    1971         cursor,
#    (...)
#    1975         context.executemany,
#    1976     )
#
# File ~\Software Projects\Database Administration\env\Lib\site-packages\sqlalchemy\engine\default.py:942, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     941 def do_execute(self, cursor, statement, parameters, context=None):
# --> 942     cursor.execute(statement, parameters)
#
# ProgrammingError: (pyodbc.ProgrammingError) ('42S02', "[42S02] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Invalid object name 'CWA_Broad_Category_Name'. (208) (SQLExecDirectW)")
# [SQL:
#     SELECT
#         f.SymbolCUSIP,
#         f.Region,
#         f.YC_Global_Category_ID,
#         c.Global_Category_Name,
#         f.YC_Category_ID,
#         y.YC_Category_Name,
#         f.CWA_Broad_Category_ID,
#         b.CWA_Broad_Category_Name
#     FROM Funds_to_Screen f
#     JOIN YC_Global_Category_List c ON f.YC_Global_Category_ID = c.ID
#     JOIN YC_Category_List y ON f.YC_Category_ID = y.ID
#     JOIN CWA_Broad_Category_Name b ON f.CWA_Broad_Category_ID = b.ID
#     ]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# Version 4.3
import pandas as pd
import numpy as np
import os
import random
import logging
from datetime import timedelta, datetime
from dateutil.relativedelta import relativedelta
from concurrent.futures import ProcessPoolExecutor
from sqlalchemy import create_engine
from tqdm import tqdm
from statsmodels.regression.linear_model import OLS
from statsmodels.tools.tools import add_constant
import statsmodels.api as sm
import time

# Section 1: Configuration and Setup
connection_string = (
    "mssql+pyodbc://JULIANS_LAPTOP\\SQLEXPRESS/CWA_Fund_Database"
    "?driver=ODBC+Driver+18+for+SQL+Server"
    "&trusted_connection=yes&TrustServerCertificate=yes"
)
engine = create_engine(connection_string)

RETURN_METRIC = "1 Month Return"
ROLLING_PERIODS = [12, 24, 36, 48, 60]  # in months
DRY_RUN = True
SAMPLE_DRY_RUN = True
SAMPLE_SIZE = 100
CHUNK_SIZE = 5600
BATCH_INSERT_SIZE = 10000
MAX_WORKERS = 15  # Optimized for 16-core i9-185H

# Section 2: Helper Functions
def category_to_region(category):
    mapping = {
        "US Equity Large Cap Blend": ("USA", "US Equity Large Cap Blend"),
        "US Equity Large Cap Growth": ("USA", "US Equity Large Cap Growth"),
        "US Equity Large Cap Value": ("USA", "US Equity Large Cap Value"),
        "US Equity Mid Cap": ("USA", "US Equity Mid Cap"),
        "US Equity Small Cap": ("USA", "US Equity Small Cap"),
        "Global Equity Large Cap": ("Global", "Global Equity Large Cap"),
        "Global Equity Mid/Small Cap": ("Global", "Global Equity Mid/Small Cap"),
        "Global Emerging Markets Equity": ("Global", "Global Emerging Markets Equity"),
        "Europe Equity Large Cap": ("International", "Europe Equity Large Cap"),
        "Asia Equity": ("International", "Asia Equity"),
        "Japan Equity": ("International", "Japan Equity"),
        "Emerging Markets Fixed Income": ("International", "Emerging Markets Fixed Income"),
        "US Fixed Income": ("USA", "US Fixed Income"),
        "US Municipal Fixed Income": ("USA", "US Municipal Fixed Income"),
        "Global Fixed Income": ("Global", "Global Fixed Income"),
        "Flexible Allocation": ("Global", "Flexible Allocation"),
        "Aggressive Allocation": ("Global", "Aggressive Allocation"),
        "Moderate Allocation": ("Global", "Moderate Allocation"),
        "Cautious Allocation": ("Global", "Cautious Allocation"),
        "Commodities Broad Basket": ("Global", "Commodities Broad Basket"),
        "Commodities Specified": ("Global", "Commodities Specified"),
        "Options Trading": ("USA", "Options Trading"),
        "Multialternative": ("Global", "Multialternative"),
        "Market Neutral": ("Global", "Market Neutral"),
        "Long/Short Equity": ("Global", "Long/Short Equity"),
        "Alternative Miscellaneous": ("Global", "Alternative Miscellaneous"),
        "Energy Sector Equity": ("USA", "Energy Sector Equity"),
        "Equity Miscellaneous": ("USA", "Equity Miscellaneous"),
        "Financials Sector Equity": ("USA", "Financials Sector Equity"),
        "Healthcare Sector Equity": ("USA", "Healthcare Sector Equity"),
        "Consumer Goods & Services Sector Equity": ("USA", "Consumer Goods & Services Sector Equity"),
        "Communications Sector Equity": ("USA", "Communications Sector Equity"),
        "Industrials Sector Equity": ("USA", "Industrials Sector Equity"),
        "Other Sector Equity": ("USA", "Other Sector Equity"),
        "Real Estate Sector Equity": ("USA", "Real Estate Sector Equity"),
        "Precious Metals Sector Equity": ("USA", "Precious Metals Sector Equity"),
        "Technology Sector Equity": ("USA", "Technology Sector Equity"),
        "Utilities Sector Equity": ("USA", "Utilities Sector Equity"),
        "Asia ex-Japan Equity": ("International", "Asia ex-Japan Equity"),
        "Australia & New Zealand Equity": ("International", "Australia & New Zealand Equity"),
        "Canadian Equity Large Cap": ("International", "Canadian Equity Large Cap"),
        "Europe Equity Mid/Small Cap": ("International", "Europe Equity Mid/Small Cap"),
        "Greater China Equity": ("International", "Greater China Equity"),
        "India Equity": ("International", "India Equity"),
        "Mexico Equity": ("International", "Mexico Equity"),
        "Korea Equity": ("International", "Korea Equity"),
        "Latin America Equity": ("International", "Latin America Equity"),
        "UK Equity Large Cap": ("International", "UK Equity Large Cap"),
        "Thailand Equity": ("International", "Thailand Equity"),
        "Convertibles": ("USA", "Convertibles"),
        "Fixed Income Miscellaneous": ("USA", "Fixed Income Miscellaneous"),
        "Allocation Miscellaneous": ("Global", "Allocation Miscellaneous")
    }
    return mapping.get(category, ("Unknown", "Unknown"))

# Section 3: Data Loading Functions
def load_fund_metadata():
    query = """
    SELECT 
        f.SymbolCUSIP, 
        f.Region, 
        f.YC_Global_Category_ID, 
        c.Global_Category_Name,
        f.YC_Category_ID,
        y.Category_Name,
        f.CWA_Broad_Category_ID,
        b.CWA_Broad_Category_Name
    FROM Funds_to_Screen f
    JOIN YC_Global_Category_List c ON f.YC_Global_Category_ID = c.ID
    JOIN YC_Category_List y ON f.YC_Category_ID = y.ID
    LEFT JOIN CWA_Broad_Category_List b ON f.CWA_Broad_Category_ID = b.ID
    """
    print("Executing metadata query...")
    try:
        df = pd.read_sql(query, engine)
        df[["Region", "FactorProfile"]] = df["Global_Category_Name"].map(category_to_region).apply(pd.Series)
        print(f"Metadata loaded: {df.columns.tolist()} | Shape: {df.shape}")
        if df["CWA_Broad_Category_Name"].isnull().all():
            print("⚠️ Warning: CWA_Broad_Category_Name is missing for all rows; Equity regressions 5-7 will be skipped")
        return df.dropna(subset=["Region", "FactorProfile"])
    except Exception as e:
        print(f"❌ Error loading metadata: {e}")
        raise

def load_fund_returns(fund_ids):
    placeholders = ",".join([f"'{fid}'" for fid in fund_ids])
    query = f"""
        SELECT SymbolCUSIP, Date, ReturnValue
        FROM Fund_Returns_Timeseries
        WHERE SymbolCUSIP IN ({placeholders})
        AND Metric = '{RETURN_METRIC}'
    """
    df = pd.read_sql(query, engine, parse_dates=["Date"])
    print(f"Fund returns loaded: {df.columns.tolist()} | Shape: {df.shape}")
    return df.pivot(index="Date", columns="SymbolCUSIP", values="ReturnValue")

def load_db_factors(factor_list, region="Global", table="factor_returns", portfolio_filter=None):
    factor_in_clause = ','.join([f"'{f}'" for f in factor_list])
    portfolio_in_clause = ','.join([f"'{p}'" for p in portfolio_filter]) if portfolio_filter else ''
    query = f"""
        SELECT date AS Date, factor_symbol AS Factor, value AS Value
        FROM {table}
        WHERE region = ?
        AND factor_symbol IN ({factor_in_clause})
    """
    if portfolio_filter:
        query += f" AND portfolio IN ({portfolio_in_clause})"
    print(f"Executing query: {query} with param: {region}")
    df = pd.read_sql(query, engine, params=(region,), parse_dates=['Date'])
    print(f"DB factors loaded: {df.columns.tolist()} | Shape: {df.shape}")
    pivoted_df = df.pivot(index="Date", columns="Factor", values="Value").rename(
        columns={
            'MKT': 'mkt', 'SMB': 'smb', 'HML_Devil': 'hml', 'UMD': 'umd', 'QMJ': 'qmj',
            'BAB': 'bab', 'RF': 'rf', 'TSM-Com': 'tsm-com', 'TSM-EQ': 'tsm-eq',
            'TSM-FI': 'tsm-fi', 'TSM-FX': 'tsm-fx', 'TSM-MA': 'tsm-ma'
        }
    )
    print(f"DB factors columns after pivot: {pivoted_df.columns.tolist()}")
    return pivoted_df

def load_fixed_income_factors(factor_list):
    factor_in_clause = ','.join([f"'{f}'" for f in factor_list])
    query = f"""
        SELECT Date, Factor_Name, ReturnValue
        FROM Fixed_Income_Factor_Returns
        WHERE Factor_Name IN ({factor_in_clause})
    """
    df = pd.read_sql(query, engine, parse_dates=["Date"])
    print(f"Fixed income factors loaded: {df.columns.tolist()} | Shape: {df.shape}")
    return df.pivot(index="Date", columns="Factor_Name", values="ReturnValue")

def load_century_factors(factor_list, portfolio, asset_class=None, region="Global"):
    factor_in_clause = ','.join([f"'{f}'" for f in factor_list])
    query = f"""
        SELECT date AS Date, factor AS Factor, value AS Value
        FROM aqr_century_factors
        WHERE factor IN ({factor_in_clause})
        AND portfolio = ?
    """
    params = [portfolio]
    if asset_class:
        query += " AND asset_class = ?"
        params.append(asset_class)
    if region != "Global":
        query += " AND region = ?"
        params.append(region)
    print(f"Executing query: {query} with params: {params}")
    df = pd.read_sql(query, engine, params=params, parse_dates=['Date'])
    print(f"Century factors loaded: {df.columns.tolist()} | Shape: {df.shape}")
    pivoted_df = df.pivot(index="Date", columns="Factor", values="Value")
    print(f"Century factors columns after pivot: {pivoted_df.columns.tolist()}")
    return pivoted_df

def load_commodity_factors():
    query = """
        SELECT date AS Date, 
               excess_return_eqwt, 
               excess_spot_return_eqwt, 
               ir_adjusted_carry_eqwt, 
               spot_return_eqwt, 
               carry_eqwt, 
               excess_return_long_short, 
               excess_spot_return_long_short, 
               ir_adjusted_carry_long_short, 
               aggregate_backwardation_contango
        FROM aqr_cmdty_factors
    """
    df = pd.read_sql(query, engine, parse_dates=['Date'])
    print(f"Commodity factors loaded: {df.columns.tolist()} | Shape: {df.shape}")
    return df.set_index("Date")

# Section 4: Rolling Regression Functions
def run_rolling_regression(fund, returns, factors, regression_type, factor_set):
    results = []
    returns.index = pd.to_datetime(returns.index)
    factors.index = pd.to_datetime(factors.index)
    viable_periods = [w for w in ROLLING_PERIODS if (returns.index.max() - relativedelta(months=w)) >= returns.index.min()]
    
    for window in viable_periods:
        start = returns.index.min() + relativedelta(months=window)
        for end_date in returns.loc[returns.index >= start].index:
            start_date = end_date - relativedelta(months=window - 1)
            y = returns.loc[start_date:end_date]
            X = factors.loc[start_date:end_date]
            X, y = X.align(y, join="inner", axis=0)
            if len(y) < window or y.isnull().any() or X.isnull().any().any():
                continue
            X_const = add_constant(X)
            model = OLS(y, X_const).fit()
            for factor in X.columns:
                results.append({
                    "SymbolCUSIP": fund,
                    "MonthEndDate": end_date,
                    "RollPeriod": f"{window}m",
                    "Factor_Name": factor,
                    "Coefficient": model.params.get(factor, np.nan),
                    "P_Value": model.pvalues.get(factor, np.nan),
                    "T_Stat": model.tvalues.get(factor, np.nan),
                    "Standard_Error": model.bse.get(factor, np.nan),
                    "CI_Lower": model.conf_int().loc[factor][0] if factor in model.params else np.nan,
                    "CI_Upper": model.conf_int().loc[factor][1] if factor in model.params else np.nan,
                    "Adj_R2": model.rsquared_adj,
                    "Correlation": np.corrcoef(y, model.fittedvalues)[0, 1] if len(y) > 1 else np.nan,
                    "Regression_Type": regression_type,
                    "Factor_Set": factor_set
                })
    return results

# Section 5: Main Processing Pipeline
def process_region(region, fund_subset):
    records = []
    
    for _, fund_row in fund_subset.iterrows():
        symbol = fund_row["SymbolCUSIP"]
        category = fund_row["Global_Category_Name"]
        broad_category = fund_row.get("CWA_Broad_Category_Name", None)
        
        # Equity
        if category in [
            "Energy Sector Equity", "Equity Miscellaneous", "Financials Sector Equity",
            "Healthcare Sector Equity", "Consumer Goods & Services Sector Equity",
            "Communications Sector Equity", "Industrials Sector Equity", "Other Sector Equity",
            "Real Estate Sector Equity", "Precious Metals Sector Equity", "Technology Sector Equity",
            "Utilities Sector Equity", "US Equity Large Cap Blend", "US Equity Large Cap Growth",
            "US Equity Large Cap Value", "US Equity Mid Cap", "US Equity Small Cap", "Options Trading"
        ]:
            # Regression 1: USA, MKT-RF, HML-Devil, QMJ, SMB, UMD, TSM-EQ, BAB
            factors = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB', 'RF'], "USA", portfolio_filter=["U.S. Large Cap"])
            if 'mkt' in factors.columns and 'rf' in factors.columns:
                factors['mkt-rf'] = factors['mkt'] - factors['rf']
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors[['mkt-rf', 'hml', 'qmj', 'smb', 'umd', 'tsm-eq', 'bab']], "OLS", "Equity_USA_1"))
            
            # Regression 2: Century Factors, US Stock Selection
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "US Stock Selection", region="USA")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Equity_USA_2"))
            
            # Regression 3: Century Factors, All Macro
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "All Macro")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Equity_USA_3"))
            
            # Regression 4: Century Factors, Equity Indices
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Equity Indices")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Equity_USA_4"))
            
            if broad_category in ["Quantitative/Tactical", "Strategic", "Nontraditional"]:
                # Regression 5: Quantitative/Tactical, Strategic, Nontraditional
                factors = load_db_factors(['MKT', 'RF', 'TSM-FX', 'TSM-FI', 'BAB'], "USA", portfolio_filter=["U.S. Large Cap"])
                fi_factors = load_fixed_income_factors(['TERM', 'CREDIT'])
                cmdty_factors = load_commodity_factors()
                factors = pd.concat([factors, fi_factors, cmdty_factors[['excess_return_eqwt']]], axis=1)
                if 'mkt' in factors.columns and 'rf' in factors.columns:
                    factors['mkt-rf'] = factors['mkt'] - factors['rf']
                records.extend(run_rolling_regression(symbol, fund_row["returns"], factors[['mkt-rf', 'tsm-fx', 'tsm-fi', 'bab', 'TERM', 'CREDIT', 'excess_return_eqwt']], "OLS", "Equity_USA_5"))
                
                # Regression 6: Quantitative/Tactical, Strategic, Nontraditional
                factors = load_db_factors(['MKT', 'TSM-EQ', 'SMB', 'BAB', 'TSM-Com'], "USA", portfolio_filter=["U.S. Large Cap"])
                fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT_HY'])
                factors = pd.concat([factors, fi_factors], axis=1)
                if 'mkt' in factors.columns:
                    factors['mkt-rf'] = factors['mkt'] - load_db_factors(['RF'], 'Global')['rf']
                records.extend(run_rolling_regression(symbol, fund_row["returns"], factors[['mkt-rf', 'tsm-eq', 'smb', 'bab', 'TERM_Int', 'TERM_Long', 'CREDIT_HY', 'tsm-com']], "OLS", "Equity_USA_6"))
                
                # Regression 7: Quantitative/Tactical, Strategic, Nontraditional
                factors = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'UMD', 'TSM-EQ', 'SMB', 'BAB', 'TSM-Com', 'TSM-FI', 'TSM-FX'], "USA", portfolio_filter=["U.S. Large Cap"])
                fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY'])
                factors = pd.concat([factors, fi_factors], axis=1)
                if 'mkt' in factors.columns:
                    factors['mkt-rf'] = factors['mkt'] - load_db_factors(['RF'], 'Global')['rf']
                records.extend(run_rolling_regression(symbol, fund_row["returns"], factors[['mkt-rf', 'hml', 'qmj', 'umd', 'tsm-eq', 'smb', 'bab', 'TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY', 'tsm-com', 'tsm-fi', 'tsm-fx']], "OLS", "Equity_USA_7"))
            else:
                print(f"Skipping Equity regressions 5-7 for {symbol}: CWA_Broad_Category_Name not available or not Quantitative/Tactical, Strategic, Nontraditional")
        
        # Equity (International)
        elif category in [
            "Asia ex-Japan Equity", "Australia & New Zealand Equity", "Canadian Equity Large Cap",
            "Europe Equity Large Cap", "Europe Equity Mid/Small Cap", "Greater China Equity",
            "India Equity", "Mexico Equity", "Japan Equity", "Korea Equity", "Latin America Equity",
            "UK Equity Large Cap", "Thailand Equity"
        ]:
            # Regression 1: International
            factors = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB', 'RF'], "Intl", portfolio_filter=["International"])
            if 'mkt' in factors.columns and 'rf' in factors.columns:
                factors['mkt-rf'] = factors['mkt'] - factors['rf']
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors[['mkt-rf', 'hml', 'qmj', 'smb', 'umd', 'tsm-eq', 'bab']], "OLS", "Equity_Intl_1"))
            
            # Regression 2: Century Factors, Intl Stock Selection
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Intl Stock Selection", region="International")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Equity_Intl_2"))
            
            # Regression 3: Century Factors, All Macro
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "All Macro")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Equity_Intl_3"))
            
            # Regression 4: Century Factors, Equity Indices
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Equity Indices")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Equity_Intl_4"))
        
        # Equity (Global)
        elif category in ["Global Emerging Markets Equity", "Global Equity Large Cap", "Global Equity Mid/Small Cap"]:
            # Regression 1: Global
            factors = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB', 'RF'], "Global", portfolio_filter=["Global"])
            if 'mkt' in factors.columns and 'rf' in factors.columns:
                factors['mkt-rf'] = factors['mkt'] - factors['rf']
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors[['mkt-rf', 'hml', 'qmj', 'smb', 'umd', 'tsm-eq', 'bab']], "OLS", "Equity_Global_1"))
            
            # Regression 2: Century Factors, All Stock Selection
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "All Stock Selection")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Equity_Global_2"))
            
            # Regression 3: Century Factors, All Macro
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "All Macro")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Equity_Global_3"))
            
            # Regression 4: Century Factors, Equity Indices
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Equity Indices")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Equity_Global_4"))
        
        # Fixed Income
        elif category in [
            "Convertibles", "Emerging Markets Fixed Income", "Fixed Income Miscellaneous",
            "US Fixed Income", "US Municipal Fixed Income"
        ]:
            # Regression 1: TERM_Int, TERM_Long, CREDIT, CREDIT_HY, TSM-FI, TSM-FX
            factors = load_db_factors(['TSM-FI', 'TSM-FX'], "Global")
            fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY'])
            factors = pd.concat([factors, fi_factors], axis=1)
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors[['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY', 'tsm-fi', 'tsm-fx']], "OLS", "FI_1"))
            
            # Regression 2: Century Factors, Fixed Income
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Fixed Income")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "FI_2"))
            
            # Regression 3: Century Factors, All Macro
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "All Macro")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "FI_3"))
            
            # Regression 4: Century Factors, Equity Indices
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Equity Indices")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "FI_4"))
        
        # Allocation
        elif category in [
            "Aggressive Allocation", "Allocation Miscellaneous", "Cautious Allocation",
            "Flexible Allocation", "Moderate Allocation"
        ]:
            # Regression 1: Global, MKT-RF, HML-Devil, QMJ, SMB, UMD, BAB, TSM-EQ, TSM-FI, TERM_Int, TERM_Long, CREDIT, CREDIT_HY
            factors = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ', 'TSM-FI', 'RF'], "Global", portfolio_filter=["Global"])
            fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY'])
            factors = pd.concat([factors, fi_factors], axis=1)
            if 'mkt' in factors.columns and 'rf' in factors.columns:
                factors['mkt-rf'] = factors['mkt'] - factors['rf']
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors[['mkt-rf', 'hml', 'qmj', 'smb', 'umd', 'bab', 'tsm-eq', 'tsm-fi', 'TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY']], "OLS", "Allocation_1"))
            
            # Regression 2: Century Factors, Fixed Income and All Stock Selection
            fi_factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Fixed Income")
            stock_factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "All Stock Selection")
            factors = pd.concat([fi_factors, stock_factors], axis=1)
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Allocation_2"))
            
            # Regression 3: Century Factors, All Macro
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "All Macro")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Allocation_3"))
            
            # Regression 4: Century Factors, Equity Indices
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Equity Indices")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Allocation_4"))
        
        # Alternatives
        elif category in [
            "Alternative Miscellaneous", "Long/Short Equity", "Market Neutral", "Multialternative"
        ]:
            # Regression 1: Global, MKT-RF, HML-Devil, QMJ, SMB, UMD, BAB, TSM-EQ, TSM-FI, TERM_Int, TERM_Long, CREDIT, CREDIT_HY, TSM-COM, TSM-FX
            factors = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ', 'TSM-FI', 'TSM-Com', 'TSM-FX', 'RF'], "Global", portfolio_filter=["Global"])
            fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY'])
            factors = pd.concat([factors, fi_factors], axis=1)
            if 'mkt' in factors.columns and 'rf' in factors.columns:
                factors['mkt-rf'] = factors['mkt'] - factors['rf']
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors[['mkt-rf', 'hml', 'qmj', 'smb', 'umd', 'bab', 'tsm-eq', 'tsm-fi', 'TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY', 'tsm-com', 'tsm-fx']], "OLS", "Alternative_1"))
            
            # Regression 2: Century Factors, Fixed Income, All Stock Selection, Commodities
            fi_factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Fixed Income")
            stock_factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "All Stock Selection")
            cmdty_factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Commodities")
            factors = pd.concat([fi_factors, stock_factors, cmdty_factors], axis=1)
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Alternative_2"))
            
            # Regression 3: Century Factors, All Macro
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "All Macro")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Alternative_3"))
            
            # Regression 4: Century Factors, Equity Indices
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Equity Indices")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Alternative_4"))
        
        # Commodities
        elif category in ["Commodities Broad Basket", "Commodities Specified"]:
            # Regression 1: All factors from aqr_cmdty_factors
            factors = load_commodity_factors()
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Commodity_1"))
    
    if records:
        if not DRY_RUN:
            insert_batch(records)
        else:
            print(f"ℹ️ Dry run: Would have written {len(records)} records for {region}")

def main():
    logging.basicConfig(level=logging.INFO)
    
    fund_meta = load_fund_metadata()
    regions = fund_meta["Region"].unique()
    print(f"🧠 Total mapped funds: {len(fund_meta)}")
    print(f"📍 Regions detected: {regions}\n")
    
    # Add returns to fund_meta for processing
    fund_ids = fund_meta["SymbolCUSIP"].tolist()
    if SAMPLE_DRY_RUN:
        fund_ids = random.sample(fund_ids, min(SAMPLE_SIZE, len(fund_ids)))
    returns = load_fund_returns(fund_ids)
    fund_meta["returns"] = fund_meta["SymbolCUSIP"].map(lambda x: returns[x] if x in returns.columns else pd.Series())
    
    for region in regions:
        fund_subset = fund_meta[fund_meta["Region"] == region]
        process_region(region, fund_subset)

# Section 6: Database Output
def insert_batch(records):
    df = pd.DataFrame(records)
    if not DRY_RUN:
        for i in range(0, len(df), BATCH_INSERT_SIZE):
            batch = df.iloc[i:i + BATCH_INSERT_SIZE]
            batch.to_sql("AQRR_Factor_Attribution", engine, if_exists="append", index=False)
    else:
        print(f"ℹ️ Dry run: Skipped writing {len(df)} records")

if __name__ == "__main__":
    main()
# Out:
# Executing metadata query...
# Metadata loaded: ['SymbolCUSIP', 'Region', 'YC_Global_Category_ID', 'Global_Category_Name', 'YC_Category_ID', 'Category_Name', 'CWA_Broad_Category_ID', 'CWA_Broad_Category_Name', 'FactorProfile'] | Shape: (5584, 9)
# 🧠 Total mapped funds: 5584
# 📍 Regions detected: ['Global' 'USA' 'Unknown' 'International']
#
# Fund returns loaded: ['SymbolCUSIP', 'Date', 'ReturnValue'] | Shape: (9955, 3)
# Executing query:
#         SELECT date AS Date, factor_symbol AS Factor, value AS Value
#         FROM factor_returns
#         WHERE region = ?
#         AND factor_symbol IN ('MKT','HML_Devil','QMJ','SMB','UMD','BAB','TSM-EQ','TSM-FI','RF')
#      AND portfolio IN ('Global') with param: Global
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File ~\Software Projects\Database Administration\env\Lib\site-packages\sqlalchemy\engine\base.py:1964, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1963     if not evt_handled:
# -> 1964         self.dialect.do_execute(
#    1965             cursor, str_statement, effective_parameters, context
#    1966         )
#    1968 if self._has_events or self.engine._has_events:
#
# File ~\Software Projects\Database Administration\env\Lib\site-packages\sqlalchemy\engine\default.py:942, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     941 def do_execute(self, cursor, statement, parameters, context=None):
# --> 942     cursor.execute(statement, parameters)
#
# ProgrammingError: ('42S22', "[42S22] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Invalid column name 'factor_symbol'. (207) (SQLExecDirectW); [42S22] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Invalid column name 'factor_symbol'. (207); [42S22] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Invalid column name 'factor_symbol'. (207); [42S22] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Invalid column name 'factor_symbol'. (207); [42S22] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Invalid column name 'factor_symbol'. (207); [42S22] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Invalid column name 'factor_symbol'. (207); [42S22] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Invalid column name 'factor_symbol'. (207); [42S22] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Invalid column name 'factor_symbol'. (207); [42S22] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Invalid column name 'factor_symbol'. (207); [42S22] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Invalid column name 'portfolio'. (207); [42S22] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Invalid column name 'factor_symbol'. (207); [42S22] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Statement(s) could not be prepared. (8180)")
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[3], line 473
#     470         print(f"ℹ️ Dry run: Skipped writing {len(df)} records")
#     472 if __name__ == "__main__":
# --> 473     main()
#
# Cell In[3], line 460, in main()
#     458 for region in regions:
#     459     fund_subset = fund_meta[fund_meta["Region"] == region]
# --> 460     process_region(region, fund_subset)
#
# Cell In[3], line 383, in process_region(region, fund_subset)
#     377 # Allocation
#     378 elif category in [
#     379     "Aggressive Allocation", "Allocation Miscellaneous", "Cautious Allocation",
#     380     "Flexible Allocation", "Moderate Allocation"
#     381 ]:
#     382     # Regression 1: Global, MKT-RF, HML-Devil, QMJ, SMB, UMD, BAB, TSM-EQ, TSM-FI, TERM_Int, TERM_Long, CREDIT, CREDIT_HY
# --> 383     factors = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ', 'TSM-FI', 'RF'], "Global", portfolio_filter=["Global"])
#     384     fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY'])
#     385     factors = pd.concat([factors, fi_factors], axis=1)
#
# Cell In[3], line 145, in load_db_factors(factor_list, region, table, portfolio_filter)
#     143     query += f" AND portfolio IN ({portfolio_in_clause})"
#     144 print(f"Executing query: {query} with param: {region}")
# --> 145 df = pd.read_sql(query, engine, params=(region,), parse_dates=['Date'])
#     146 print(f"DB factors loaded: {df.columns.tolist()} | Shape: {df.shape}")
#     147 pivoted_df = df.pivot(index="Date", columns="Factor", values="Value").rename(
#     148     columns={
#     149         'MKT': 'mkt', 'SMB': 'smb', 'HML_Devil': 'hml', 'UMD': 'umd', 'QMJ': 'qmj',
#    (...)
#     152     }
#     153 )
#
# File ~\Software Projects\Database Administration\env\Lib\site-packages\pandas\io\sql.py:734, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     724     return pandas_sql.read_table(
#     725         sql,
#     726         index_col=index_col,
#    (...)
#     731         dtype_backend=dtype_backend,
#     732     )
#     733 else:
# --> 734     return pandas_sql.read_query(
#     735         sql,
#     736         index_col=index_col,
#     737         params=params,
#     738         coerce_float=coerce_float,
#     739         parse_dates=parse_dates,
#     740         chunksize=chunksize,
#     741         dtype_backend=dtype_backend,
#     742         dtype=dtype,
#     743     )
#
# File ~\Software Projects\Database Administration\env\Lib\site-packages\pandas\io\sql.py:1836, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    1779 def read_query(
#    1780     self,
#    1781     sql: str,
#    (...)
#    1788     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    1789 ) -> DataFrame | Iterator[DataFrame]:
#    1790     """
#    1791     Read SQL query into a DataFrame.
#    1792
#    (...)
#    1834
#    1835     """
# -> 1836     result = self.execute(sql, params)
#    1837     columns = result.keys()
#    1839     if chunksize is not None:
#
# File ~\Software Projects\Database Administration\env\Lib\site-packages\pandas\io\sql.py:1659, in SQLDatabase.execute(self, sql, params)
#    1657 args = [] if params is None else [params]
#    1658 if isinstance(sql, str):
# -> 1659     return self.con.exec_driver_sql(sql, *args)
#    1660 return self.con.execute(sql, *args)
#
# File ~\Software Projects\Database Administration\env\Lib\site-packages\sqlalchemy\engine\base.py:1776, in Connection.exec_driver_sql(self, statement, parameters, execution_options)
#    1771 execution_options = self._execution_options.merge_with(
#    1772     execution_options
#    1773 )
#    1775 dialect = self.dialect
# -> 1776 ret = self._execute_context(
#    1777     dialect,
#    1778     dialect.execution_ctx_cls._init_statement,
#    1779     statement,
#    1780     None,
#    1781     execution_options,
#    1782     statement,
#    1783     distilled_parameters,
#    1784 )
#    1786 return ret
#
# File ~\Software Projects\Database Administration\env\Lib\site-packages\sqlalchemy\engine\base.py:1843, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1841     return self._exec_insertmany_context(dialect, context)
#    1842 else:
# -> 1843     return self._exec_single_context(
#    1844         dialect, context, statement, parameters
#    1845     )
#
# File ~\Software Projects\Database Administration\env\Lib\site-packages\sqlalchemy\engine\base.py:1983, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1980     result = context._setup_result_proxy()
#    1982 except BaseException as e:
# -> 1983     self._handle_dbapi_exception(
#    1984         e, str_statement, effective_parameters, cursor, context
#    1985     )
#    1987 return result
#
# File ~\Software Projects\Database Administration\env\Lib\site-packages\sqlalchemy\engine\base.py:2352, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2350 elif should_wrap:
#    2351     assert sqlalchemy_exception is not None
# -> 2352     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2353 else:
#    2354     assert exc_info[1] is not None
#
# File ~\Software Projects\Database Administration\env\Lib\site-packages\sqlalchemy\engine\base.py:1964, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1962                 break
#    1963     if not evt_handled:
# -> 1964         self.dialect.do_execute(
#    1965             cursor, str_statement, effective_parameters, context
#    1966         )
#    1968 if self._has_events or self.engine._has_events:
#    1969     self.dispatch.after_cursor_execute(
#    1970         self,
#    1971         cursor,
#    (...)
#    1975         context.executemany,
#    1976     )
#
# File ~\Software Projects\Database Administration\env\Lib\site-packages\sqlalchemy\engine\default.py:942, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     941 def do_execute(self, cursor, statement, parameters, context=None):
# --> 942     cursor.execute(statement, parameters)
#
# ProgrammingError: (pyodbc.ProgrammingError) ('42S22', "[42S22] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Invalid column name 'factor_symbol'. (207) (SQLExecDirectW); [42S22] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Invalid column name 'factor_symbol'. (207); [42S22] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Invalid column name 'factor_symbol'. (207); [42S22] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Invalid column name 'factor_symbol'. (207); [42S22] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Invalid column name 'factor_symbol'. (207); [42S22] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Invalid column name 'factor_symbol'. (207); [42S22] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Invalid column name 'factor_symbol'. (207); [42S22] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Invalid column name 'factor_symbol'. (207); [42S22] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Invalid column name 'factor_symbol'. (207); [42S22] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Invalid column name 'portfolio'. (207); [42S22] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Invalid column name 'factor_symbol'. (207); [42S22] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Statement(s) could not be prepared. (8180)")
# [SQL:
#         SELECT date AS Date, factor_symbol AS Factor, value AS Value
#         FROM factor_returns
#         WHERE region = ?
#         AND factor_symbol IN ('MKT','HML_Devil','QMJ','SMB','UMD','BAB','TSM-EQ','TSM-FI','RF')
#      AND portfolio IN ('Global')]
# [parameters: ('Global',)]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# Version 4.4
import pandas as pd
import numpy as np
import os
import random
import logging
from datetime import timedelta, datetime
from dateutil.relativedelta import relativedelta
from concurrent.futures import ProcessPoolExecutor
from sqlalchemy import create_engine
from tqdm import tqdm
from statsmodels.regression.linear_model import OLS
from statsmodels.tools.tools import add_constant
import statsmodels.api as sm
import time

# Section 1: Configuration and Setup
connection_string = (
    "mssql+pyodbc://JULIANS_LAPTOP\\SQLEXPRESS/CWA_Fund_Database"
    "?driver=ODBC+Driver+18+for+SQL+Server"
    "&trusted_connection=yes&TrustServerCertificate=yes"
)
engine = create_engine(connection_string)

RETURN_METRIC = "1 Month Return"
ROLLING_PERIODS = [12, 24, 36, 48, 60]  # in months
DRY_RUN = True
SAMPLE_DRY_RUN = True
SAMPLE_SIZE = 100
CHUNK_SIZE = 5600
BATCH_INSERT_SIZE = 10000
MAX_WORKERS = 15  # Optimized for 16-core i9-185H

# Section 2: Helper Functions
def category_to_region(category):
    mapping = {
        "US Equity Large Cap Blend": ("USA", "US Equity Large Cap Blend"),
        "US Equity Large Cap Growth": ("USA", "US Equity Large Cap Growth"),
        "US Equity Large Cap Value": ("USA", "US Equity Large Cap Value"),
        "US Equity Mid Cap": ("USA", "US Equity Mid Cap"),
        "US Equity Small Cap": ("USA", "US Equity Small Cap"),
        "Global Equity Large Cap": ("Global", "Global Equity Large Cap"),
        "Global Equity Mid/Small Cap": ("Global", "Global Equity Mid/Small Cap"),
        "Global Emerging Markets Equity": ("Global", "Global Emerging Markets Equity"),
        "Europe Equity Large Cap": ("International", "Europe Equity Large Cap"),
        "Asia Equity": ("International", "Asia Equity"),
        "Japan Equity": ("International", "Japan Equity"),
        "Emerging Markets Fixed Income": ("International", "Emerging Markets Fixed Income"),
        "US Fixed Income": ("USA", "US Fixed Income"),
        "US Municipal Fixed Income": ("USA", "US Municipal Fixed Income"),
        "Global Fixed Income": ("Global", "Global Fixed Income"),
        "Flexible Allocation": ("Global", "Flexible Allocation"),
        "Aggressive Allocation": ("Global", "Aggressive Allocation"),
        "Moderate Allocation": ("Global", "Moderate Allocation"),
        "Cautious Allocation": ("Global", "Cautious Allocation"),
        "Commodities Broad Basket": ("Global", "Commodities Broad Basket"),
        "Commodities Specified": ("Global", "Commodities Specified"),
        "Options Trading": ("USA", "Options Trading"),
        "Multialternative": ("Global", "Multialternative"),
        "Market Neutral": ("Global", "Market Neutral"),
        "Long/Short Equity": ("Global", "Long/Short Equity"),
        "Alternative Miscellaneous": ("Global", "Alternative Miscellaneous"),
        "Energy Sector Equity": ("USA", "Energy Sector Equity"),
        "Equity Miscellaneous": ("USA", "Equity Miscellaneous"),
        "Financials Sector Equity": ("USA", "Financials Sector Equity"),
        "Healthcare Sector Equity": ("USA", "Healthcare Sector Equity"),
        "Consumer Goods & Services Sector Equity": ("USA", "Consumer Goods & Services Sector Equity"),
        "Communications Sector Equity": ("USA", "Communications Sector Equity"),
        "Industrials Sector Equity": ("USA", "Industrials Sector Equity"),
        "Other Sector Equity": ("USA", "Other Sector Equity"),
        "Real Estate Sector Equity": ("USA", "Real Estate Sector Equity"),
        "Precious Metals Sector Equity": ("USA", "Precious Metals Sector Equity"),
        "Technology Sector Equity": ("USA", "Technology Sector Equity"),
        "Utilities Sector Equity": ("USA", "Utilities Sector Equity"),
        "Asia ex-Japan Equity": ("International", "Asia ex-Japan Equity"),
        "Australia & New Zealand Equity": ("International", "Australia & New Zealand Equity"),
        "Canadian Equity Large Cap": ("International", "Canadian Equity Large Cap"),
        "Europe Equity Mid/Small Cap": ("International", "Europe Equity Mid/Small Cap"),
        "Greater China Equity": ("International", "Greater China Equity"),
        "India Equity": ("International", "India Equity"),
        "Mexico Equity": ("International", "Mexico Equity"),
        "Korea Equity": ("International", "Korea Equity"),
        "Latin America Equity": ("International", "Latin America Equity"),
        "UK Equity Large Cap": ("International", "UK Equity Large Cap"),
        "Thailand Equity": ("International", "Thailand Equity"),
        "Convertibles": ("USA", "Convertibles"),
        "Fixed Income Miscellaneous": ("USA", "Fixed Income Miscellaneous"),
        "Allocation Miscellaneous": ("Global", "Allocation Miscellaneous")
    }
    return mapping.get(category, ("Unknown", "Unknown"))

# Section 3: Data Loading Functions
def load_fund_metadata():
    query = """
    SELECT 
        f.SymbolCUSIP, 
        f.Region, 
        f.YC_Global_Category_ID, 
        c.Global_Category_Name,
        f.YC_Category_ID,
        y.Category_Name,
        f.CWA_Broad_Category_ID,
        b.CWA_Broad_Category_Name
    FROM Funds_to_Screen f
    JOIN YC_Global_Category_List c ON f.YC_Global_Category_ID = c.ID
    JOIN YC_Category_List y ON f.YC_Category_ID = y.ID
    LEFT JOIN CWA_Broad_Category_List b ON f.CWA_Broad_Category_ID = b.ID
    """
    print("Executing metadata query...")
    try:
        df = pd.read_sql(query, engine)
        df[["Region", "FactorProfile"]] = df["Global_Category_Name"].map(category_to_region).apply(pd.Series)
        print(f"Metadata loaded: {df.columns.tolist()} | Shape: {df.shape}")
        if df["CWA_Broad_Category_Name"].isnull().all():
            print("⚠️ Warning: CWA_Broad_Category_Name is missing for all rows; Equity regressions 5-7 will be skipped")
        return df.dropna(subset=["Region", "FactorProfile"])
    except Exception as e:
        print(f"❌ Error loading metadata: {e}")
        raise

def load_fund_returns(fund_ids):
    placeholders = ",".join([f"'{fid}'" for fid in fund_ids])
    query = f"""
        SELECT SymbolCUSIP, Date, ReturnValue
        FROM Fund_Returns_Timeseries
        WHERE SymbolCUSIP IN ({placeholders})
        AND Metric = '{RETURN_METRIC}'
    """
    df = pd.read_sql(query, engine, parse_dates=["Date"])
    print(f"Fund returns loaded: {df.columns.tolist()} | Shape: {df.shape}")
    return df.pivot(index="Date", columns="SymbolCUSIP", values="ReturnValue")

def load_db_factors(factor_list, region="Global", table="factor_returns", asset_class=None):
    factor_in_clause = ','.join([f"'{f}'" for f in factor_list])
    query = f"""
        SELECT date AS Date, factor AS Factor, value AS Value
        FROM {table}
        WHERE region = ?
        AND factor IN ({factor_in_clause})
    """
    params = [region]
    if asset_class:
        query += " AND asset_class = ?"
        params.append(asset_class)
    print(f"Executing query: {query} with params: {params}")
    df = pd.read_sql(query, engine, params=params, parse_dates=['Date'])
    print(f"DB factors loaded: {df.columns.tolist()} | Shape: {df.shape}")
    pivoted_df = df.pivot(index="Date", columns="Factor", values="Value").rename(
        columns={
            'MKT': 'mkt', 'SMB': 'smb', 'HML_Devil': 'hml', 'UMD': 'umd', 'QMJ': 'qmj',
            'BAB': 'bab', 'RF': 'rf', 'TSM-Com': 'tsm-com', 'TSM-EQ': 'tsm-eq',
            'TSM-FI': 'tsm-fi', 'TSM-FX': 'tsm-fx', 'TSM-MA': 'tsm-ma'
        }
    )
    print(f"DB factors columns after pivot: {pivoted_df.columns.tolist()}")
    return pivoted_df

def load_fixed_income_factors(factor_list):
    factor_in_clause = ','.join([f"'{f}'" for f in factor_list])
    query = f"""
        SELECT Date, Factor_Name, ReturnValue
        FROM Fixed_Income_Factor_Returns
        WHERE Factor_Name IN ({factor_in_clause})
    """
    df = pd.read_sql(query, engine, parse_dates=["Date"])
    print(f"Fixed income factors loaded: {df.columns.tolist()} | Shape: {df.shape}")
    return df.pivot(index="Date", columns="Factor_Name", values="ReturnValue")

def load_century_factors(factor_list, portfolio, asset_class=None, region="Global"):
    factor_in_clause = ','.join([f"'{f}'" for f in factor_list])
    query = f"""
        SELECT date AS Date, factor AS Factor, value AS Value
        FROM aqr_century_factors
        WHERE factor IN ({factor_in_clause})
        AND portfolio = ?
    """
    params = [portfolio]
    if asset_class:
        query += " AND asset_class = ?"
        params.append(asset_class)
    if region != "Global":
        query += " AND region = ?"
        params.append(region)
    print(f"Executing query: {query} with params: {params}")
    df = pd.read_sql(query, engine, params=params, parse_dates=['Date'])
    print(f"Century factors loaded: {df.columns.tolist()} | Shape: {df.shape}")
    pivoted_df = df.pivot(index="Date", columns="Factor", values="Value")
    print(f"Century factors columns after pivot: {pivoted_df.columns.tolist()}")
    return pivoted_df

def load_commodity_factors():
    query = """
        SELECT date AS Date, 
               excess_return_eqwt, 
               excess_spot_return_eqwt, 
               ir_adjusted_carry_eqwt, 
               spot_return_eqwt, 
               carry_eqwt, 
               excess_return_long_short, 
               excess_spot_return_long_short, 
               ir_adjusted_carry_long_short, 
               aggregate_backwardation_contango
        FROM aqr_cmdty_factors
    """
    df = pd.read_sql(query, engine, parse_dates=['Date'])
    print(f"Commodity factors loaded: {df.columns.tolist()} | Shape: {df.shape}")
    return df.set_index("Date")

# Section 4: Rolling Regression Functions
def run_rolling_regression(fund, returns, factors, regression_type, factor_set):
    results = []
    returns.index = pd.to_datetime(returns.index)
    factors.index = pd.to_datetime(factors.index)
    viable_periods = [w for w in ROLLING_PERIODS if (returns.index.max() - relativedelta(months=w)) >= returns.index.min()]
    
    for window in viable_periods:
        start = returns.index.min() + relativedelta(months=window)
        for end_date in returns.loc[returns.index >= start].index:
            start_date = end_date - relativedelta(months=window - 1)
            y = returns.loc[start_date:end_date]
            X = factors.loc[start_date:end_date]
            X, y = X.align(y, join="inner", axis=0)
            if len(y) < window or y.isnull().any() or X.isnull().any().any():
                continue
            X_const = add_constant(X)
            model = OLS(y, X_const).fit()
            for factor in X.columns:
                results.append({
                    "SymbolCUSIP": fund,
                    "MonthEndDate": end_date,
                    "RollPeriod": f"{window}m",
                    "Factor_Name": factor,
                    "Coefficient": model.params.get(factor, np.nan),
                    "P_Value": model.pvalues.get(factor, np.nan),
                    "T_Stat": model.tvalues.get(factor, np.nan),
                    "Standard_Error": model.bse.get(factor, np.nan),
                    "CI_Lower": model.conf_int().loc[factor][0] if factor in model.params else np.nan,
                    "CI_Upper": model.conf_int().loc[factor][1] if factor in model.params else np.nan,
                    "Adj_R2": model.rsquared_adj,
                    "Correlation": np.corrcoef(y, model.fittedvalues)[0, 1] if len(y) > 1 else np.nan,
                    "Regression_Type": regression_type,
                    "Factor_Set": factor_set
                })
    return results

# Section 5: Main Processing Pipeline
def process_region(region, fund_subset):
    records = []
    
    for _, fund_row in fund_subset.iterrows():
        symbol = fund_row["SymbolCUSIP"]
        category = fund_row["Global_Category_Name"]
        broad_category = fund_row.get("CWA_Broad_Category_Name", None)
        
        # Equity
        if category in [
            "Energy Sector Equity", "Equity Miscellaneous", "Financials Sector Equity",
            "Healthcare Sector Equity", "Consumer Goods & Services Sector Equity",
            "Communications Sector Equity", "Industrials Sector Equity", "Other Sector Equity",
            "Real Estate Sector Equity", "Precious Metals Sector Equity", "Technology Sector Equity",
            "Utilities Sector Equity", "US Equity Large Cap Blend", "US Equity Large Cap Growth",
            "US Equity Large Cap Value", "US Equity Mid Cap", "US Equity Small Cap", "Options Trading"
        ]:
            # Regression 1: USA, MKT-RF, HML-Devil, QMJ, SMB, UMD, TSM-EQ, BAB
            factors = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB', 'RF'], "USA", asset_class="Equity")
            if 'mkt' in factors.columns and 'rf' in factors.columns:
                factors['mkt-rf'] = factors['mkt'] - factors['rf']
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors[['mkt-rf', 'hml', 'qmj', 'smb', 'umd', 'tsm-eq', 'bab']], "OLS", "Equity_USA_1"))
            
            # Regression 2: Century Factors, US Stock Selection
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "US Stock Selection", region="USA")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Equity_USA_2"))
            
            # Regression 3: Century Factors, All Macro
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "All Macro")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Equity_USA_3"))
            
            # Regression 4: Century Factors, Equity Indices
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Equity Indices")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Equity_USA_4"))
            
            if broad_category in ["Quantitative/Tactical", "Strategic", "Nontraditional"]:
                # Regression 5: Quantitative/Tactical, Strategic, Nontraditional
                factors = load_db_factors(['MKT', 'RF', 'TSM-FX', 'TSM-FI', 'BAB'], "USA", asset_class="Equity")
                fi_factors = load_fixed_income_factors(['TERM', 'CREDIT'])
                cmdty_factors = load_commodity_factors()
                factors = pd.concat([factors, fi_factors, cmdty_factors[['excess_return_eqwt']]], axis=1)
                if 'mkt' in factors.columns and 'rf' in factors.columns:
                    factors['mkt-rf'] = factors['mkt'] - factors['rf']
                records.extend(run_rolling_regression(symbol, fund_row["returns"], factors[['mkt-rf', 'tsm-fx', 'tsm-fi', 'bab', 'TERM', 'CREDIT', 'excess_return_eqwt']], "OLS", "Equity_USA_5"))
                
                # Regression 6: Quantitative/Tactical, Strategic, Nontraditional
                factors = load_db_factors(['MKT', 'TSM-EQ', 'SMB', 'BAB', 'TSM-Com'], "USA", asset_class="Equity")
                fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT_HY'])
                factors = pd.concat([factors, fi_factors], axis=1)
                if 'mkt' in factors.columns:
                    factors['mkt-rf'] = factors['mkt'] - load_db_factors(['RF'], 'Global', asset_class="Equity")['rf']
                records.extend(run_rolling_regression(symbol, fund_row["returns"], factors[['mkt-rf', 'tsm-eq', 'smb', 'bab', 'TERM_Int', 'TERM_Long', 'CREDIT_HY', 'tsm-com']], "OLS", "Equity_USA_6"))
                
                # Regression 7: Quantitative/Tactical, Strategic, Nontraditional
                factors = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'UMD', 'TSM-EQ', 'SMB', 'BAB', 'TSM-Com', 'TSM-FI', 'TSM-FX'], "USA", asset_class="Equity")
                fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY'])
                factors = pd.concat([factors, fi_factors], axis=1)
                if 'mkt' in factors.columns:
                    factors['mkt-rf'] = factors['mkt'] - load_db_factors(['RF'], 'Global', asset_class="Equity")['rf']
                records.extend(run_rolling_regression(symbol, fund_row["returns"], factors[['mkt-rf', 'hml', 'qmj', 'umd', 'tsm-eq', 'smb', 'bab', 'TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY', 'tsm-com', 'tsm-fi', 'tsm-fx']], "OLS", "Equity_USA_7"))
            else:
                print(f"Skipping Equity regressions 5-7 for {symbol}: CWA_Broad_Category_Name not Quantitative/Tactical, Strategic, Nontraditional")
        
        # Equity (International)
        elif category in [
            "Asia ex-Japan Equity", "Australia & New Zealand Equity", "Canadian Equity Large Cap",
            "Europe Equity Large Cap", "Europe Equity Mid/Small Cap", "Greater China Equity",
            "India Equity", "Mexico Equity", "Japan Equity", "Korea Equity", "Latin America Equity",
            "UK Equity Large Cap", "Thailand Equity"
        ]:
            # Regression 1: International
            factors = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB', 'RF'], "Intl", asset_class="Equity")
            if 'mkt' in factors.columns and 'rf' in factors.columns:
                factors['mkt-rf'] = factors['mkt'] - factors['rf']
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors[['mkt-rf', 'hml', 'qmj', 'smb', 'umd', 'tsm-eq', 'bab']], "OLS", "Equity_Intl_1"))
            
            # Regression 2: Century Factors, Intl Stock Selection
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Intl Stock Selection", region="International")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Equity_Intl_2"))
            
            # Regression 3: Century Factors, All Macro
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "All Macro")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Equity_Intl_3"))
            
            # Regression 4: Century Factors, Equity Indices
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Equity Indices")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Equity_Intl_4"))
        
        # Equity (Global)
        elif category in ["Global Emerging Markets Equity", "Global Equity Large Cap", "Global Equity Mid/Small Cap"]:
            # Regression 1: Global
            factors = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB', 'RF'], "Global", asset_class="Equity")
            if 'mkt' in factors.columns and 'rf' in factors.columns:
                factors['mkt-rf'] = factors['mkt'] - factors['rf']
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors[['mkt-rf', 'hml', 'qmj', 'smb', 'umd', 'tsm-eq', 'bab']], "OLS", "Equity_Global_1"))
            
            # Regression 2: Century Factors, All Stock Selection
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "All Stock Selection")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Equity_Global_2"))
            
            # Regression 3: Century Factors, All Macro
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "All Macro")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Equity_Global_3"))
            
            # Regression 4: Century Factors, Equity Indices
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Equity Indices")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Equity_Global_4"))
        
        # Fixed Income
        elif category in [
            "Convertibles", "Emerging Markets Fixed Income", "Fixed Income Miscellaneous",
            "US Fixed Income", "US Municipal Fixed Income"
        ]:
            # Regression 1: TERM_Int, TERM_Long, CREDIT, CREDIT_HY, TSM-FI, TSM-FX
            factors = load_db_factors(['TSM-FI', 'TSM-FX'], "Global", asset_class="Fixed Income")
            fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY'])
            factors = pd.concat([factors, fi_factors], axis=1)
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors[['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY', 'tsm-fi', 'tsm-fx']], "OLS", "FI_1"))
            
            # Regression 2: Century Factors, Fixed Income
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Fixed Income")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "FI_2"))
            
            # Regression 3: Century Factors, All Macro
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "All Macro")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "FI_3"))
            
            # Regression 4: Century Factors, Equity Indices
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Equity Indices")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "FI_4"))
        
        # Allocation
        elif category in [
            "Aggressive Allocation", "Allocation Miscellaneous", "Cautious Allocation",
            "Flexible Allocation", "Moderate Allocation"
        ]:
            # Regression 1: Global, MKT-RF, HML-Devil, QMJ, SMB, UMD, BAB, TSM-EQ, TSM-FI, TERM_Int, TERM_Long, CREDIT, CREDIT_HY
            factors = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ', 'TSM-FI', 'RF'], "Global", asset_class="Equity")
            fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY'])
            factors = pd.concat([factors, fi_factors], axis=1)
            if 'mkt' in factors.columns and 'rf' in factors.columns:
                factors['mkt-rf'] = factors['mkt'] - factors['rf']
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors[['mkt-rf', 'hml', 'qmj', 'smb', 'umd', 'bab', 'tsm-eq', 'tsm-fi', 'TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY']], "OLS", "Allocation_1"))
            
            # Regression 2: Century Factors, Fixed Income and All Stock Selection
            fi_factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Fixed Income")
            stock_factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "All Stock Selection")
            factors = pd.concat([fi_factors, stock_factors], axis=1)
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Allocation_2"))
            
            # Regression 3: Century Factors, All Macro
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "All Macro")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Allocation_3"))
            
            # Regression 4: Century Factors, Equity Indices
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Equity Indices")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Allocation_4"))
        
        # Alternatives
        elif category in [
            "Alternative Miscellaneous", "Long/Short Equity", "Market Neutral", "Multialternative"
        ]:
            # Regression 1: Global, MKT-RF, HML-Devil, QMJ, SMB, UMD, BAB, TSM-EQ, TSM-FI, TERM_Int, TERM_Long, CREDIT, CREDIT_HY, TSM-COM, TSM-FX
            factors = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ', 'TSM-FI', 'TSM-Com', 'TSM-FX', 'RF'], "Global", asset_class="Equity")
            fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY'])
            factors = pd.concat([factors, fi_factors], axis=1)
            if 'mkt' in factors.columns and 'rf' in factors.columns:
                factors['mkt-rf'] = factors['mkt'] - factors['rf']
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors[['mkt-rf', 'hml', 'qmj', 'smb', 'umd', 'bab', 'tsm-eq', 'tsm-fi', 'TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY', 'tsm-com', 'tsm-fx']], "OLS", "Alternative_1"))
            
            # Regression 2: Century Factors, Fixed Income, All Stock Selection, Commodities
            fi_factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Fixed Income")
            stock_factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "All Stock Selection")
            cmdty_factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Commodities")
            factors = pd.concat([fi_factors, stock_factors, cmdty_factors], axis=1)
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Alternative_2"))
            
            # Regression 3: Century Factors, All Macro
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "All Macro")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Alternative_3"))
            
            # Regression 4: Century Factors, Equity Indices
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Equity Indices")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Alternative_4"))
        
        # Commodities
        elif category in ["Commodities Broad Basket", "Commodities Specified"]:
            # Regression 1: All factors from aqr_cmdty_factors
            factors = load_commodity_factors()
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Commodity_1"))
    
    if records:
        if not DRY_RUN:
            insert_batch(records)
        else:
            print(f"ℹ️ Dry run: Would have written {len(records)} records for {region}")

def main():
    logging.basicConfig(level=logging.INFO)
    
    fund_meta = load_fund_metadata()
    regions = fund_meta["Region"].unique()
    print(f"🧠 Total mapped funds: {len(fund_meta)}")
    print(f"📍 Regions detected: {regions}\n")
    
    # Add returns to fund_meta for processing
    fund_ids = fund_meta["SymbolCUSIP"].tolist()
    if SAMPLE_DRY_RUN:
        fund_ids = random.sample(fund_ids, min(SAMPLE_SIZE, len(fund_ids)))
    returns = load_fund_returns(fund_ids)
    fund_meta["returns"] = fund_meta["SymbolCUSIP"].map(lambda x: returns[x] if x in returns.columns else pd.Series())
    
    for region in regions:
        fund_subset = fund_meta[fund_meta["Region"] == region]
        process_region(region, fund_subset)

# Section 6: Database Output
def insert_batch(records):
    df = pd.DataFrame(records)
    if not DRY_RUN:
        for i in range(0, len(df), BATCH_INSERT_SIZE):
            batch = df.iloc[i:i + BATCH_INSERT_SIZE]
            batch.to_sql("AQRR_Factor_Attribution", engine, if_exists="append", index=False)
    else:
        print(f"ℹ️ Dry run: Skipped writing {len(df)} records")

if __name__ == "__main__":
    main()
# Out:
# Executing metadata query...
# Metadata loaded: ['SymbolCUSIP', 'Region', 'YC_Global_Category_ID', 'Global_Category_Name', 'YC_Category_ID', 'Category_Name', 'CWA_Broad_Category_ID', 'CWA_Broad_Category_Name', 'FactorProfile'] | Shape: (5584, 9)
# 🧠 Total mapped funds: 5584
# 📍 Regions detected: ['Global' 'USA' 'Unknown' 'International']
#
# Fund returns loaded: ['SymbolCUSIP', 'Date', 'ReturnValue'] | Shape: (9582, 3)
# Executing query:
#         SELECT date AS Date, factor AS Factor, value AS Value
#         FROM factor_returns
#         WHERE region = ?
#         AND factor IN ('MKT','HML_Devil','QMJ','SMB','UMD','BAB','TSM-EQ','TSM-FI','RF')
#      AND asset_class = ? with params: ['Global', 'Equity']
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# Cell In[4], line 474
#     471         print(f"ℹ️ Dry run: Skipped writing {len(df)} records")
#     473 if __name__ == "__main__":
# --> 474     main()
#
# Cell In[4], line 461, in main()
#     459 for region in regions:
#     460     fund_subset = fund_meta[fund_meta["Region"] == region]
# --> 461     process_region(region, fund_subset)
#
# Cell In[4], line 384, in process_region(region, fund_subset)
#     378 # Allocation
#     379 elif category in [
#     380     "Aggressive Allocation", "Allocation Miscellaneous", "Cautious Allocation",
#     381     "Flexible Allocation", "Moderate Allocation"
#     382 ]:
#     383     # Regression 1: Global, MKT-RF, HML-Devil, QMJ, SMB, UMD, BAB, TSM-EQ, TSM-FI, TERM_Int, TERM_Long, CREDIT, CREDIT_HY
# --> 384     factors = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ', 'TSM-FI', 'RF'], "Global", asset_class="Equity")
#     385     fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY'])
#     386     factors = pd.concat([factors, fi_factors], axis=1)
#
# Cell In[4], line 146, in load_db_factors(factor_list, region, table, asset_class)
#     144     params.append(asset_class)
#     145 print(f"Executing query: {query} with params: {params}")
# --> 146 df = pd.read_sql(query, engine, params=params, parse_dates=['Date'])
#     147 print(f"DB factors loaded: {df.columns.tolist()} | Shape: {df.shape}")
#     148 pivoted_df = df.pivot(index="Date", columns="Factor", values="Value").rename(
#     149     columns={
#     150         'MKT': 'mkt', 'SMB': 'smb', 'HML_Devil': 'hml', 'UMD': 'umd', 'QMJ': 'qmj',
#    (...)
#     153     }
#     154 )
#
# File ~\Software Projects\Database Administration\env\Lib\site-packages\pandas\io\sql.py:734, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     724     return pandas_sql.read_table(
#     725         sql,
#     726         index_col=index_col,
#    (...)
#     731         dtype_backend=dtype_backend,
#     732     )
#     733 else:
# --> 734     return pandas_sql.read_query(
#     735         sql,
#     736         index_col=index_col,
#     737         params=params,
#     738         coerce_float=coerce_float,
#     739         parse_dates=parse_dates,
#     740         chunksize=chunksize,
#     741         dtype_backend=dtype_backend,
#     742         dtype=dtype,
#     743     )
#
# File ~\Software Projects\Database Administration\env\Lib\site-packages\pandas\io\sql.py:1836, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    1779 def read_query(
#    1780     self,
#    1781     sql: str,
#    (...)
#    1788     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    1789 ) -> DataFrame | Iterator[DataFrame]:
#    1790     """
#    1791     Read SQL query into a DataFrame.
#    1792
#    (...)
#    1834
#    1835     """
# -> 1836     result = self.execute(sql, params)
#    1837     columns = result.keys()
#    1839     if chunksize is not None:
#
# File ~\Software Projects\Database Administration\env\Lib\site-packages\pandas\io\sql.py:1659, in SQLDatabase.execute(self, sql, params)
#    1657 args = [] if params is None else [params]
#    1658 if isinstance(sql, str):
# -> 1659     return self.con.exec_driver_sql(sql, *args)
#    1660 return self.con.execute(sql, *args)
#
# File ~\Software Projects\Database Administration\env\Lib\site-packages\sqlalchemy\engine\base.py:1769, in Connection.exec_driver_sql(self, statement, parameters, execution_options)
#    1711 def exec_driver_sql(
#    1712     self,
#    1713     statement: str,
#    1714     parameters: Optional[_DBAPIAnyExecuteParams] = None,
#    1715     execution_options: Optional[CoreExecuteOptionsParameter] = None,
#    1716 ) -> CursorResult[Any]:
#    1717     r"""Executes a string SQL statement on the DBAPI cursor directly,
#    1718     without any SQL compilation steps.
#    1719
#    (...)
#    1766
#    1767     """
# -> 1769     distilled_parameters = _distill_raw_params(parameters)
#    1771     execution_options = self._execution_options.merge_with(
#    1772         execution_options
#    1773     )
#    1775     dialect = self.dialect
#
# File lib\\sqlalchemy\\cyextension\\util.pyx:44, in sqlalchemy.cyextension.util._distill_raw_params()
#
# File lib\\sqlalchemy\\cyextension\\util.pyx:23, in sqlalchemy.cyextension.util._check_item()
#
# ArgumentError: List argument must consist only of tuples or dictionaries

# %%
# Version 4.5
import pandas as pd
import numpy as np
import os
import random
import logging
from datetime import timedelta, datetime
from dateutil.relativedelta import relativedelta
from concurrent.futures import ProcessPoolExecutor
from sqlalchemy import create_engine
from tqdm import tqdm
from statsmodels.regression.linear_model import OLS
from statsmodels.tools.tools import add_constant
import statsmodels.api as sm
import time

# Section 1: Configuration and Setup
connection_string = (
    "mssql+pyodbc://JULIANS_LAPTOP\\SQLEXPRESS/CWA_Fund_Database"
    "?driver=ODBC+Driver+18+for+SQL+Server"
    "&trusted_connection=yes&TrustServerCertificate=yes"
)
engine = create_engine(connection_string)

RETURN_METRIC = "1 Month Return"
ROLLING_PERIODS = [12, 24, 36, 48, 60]  # in months
DRY_RUN = True
SAMPLE_DRY_RUN = True
SAMPLE_SIZE = 100
CHUNK_SIZE = 5600
BATCH_INSERT_SIZE = 10000
MAX_WORKERS = 15  # Optimized for 16-core i9-185H

# Section 2: Helper Functions
def category_to_region(category):
    mapping = {
        "US Equity Large Cap Blend": ("USA", "US Equity Large Cap Blend"),
        "US Equity Large Cap Growth": ("USA", "US Equity Large Cap Growth"),
        "US Equity Large Cap Value": ("USA", "US Equity Large Cap Value"),
        "US Equity Mid Cap": ("USA", "US Equity Mid Cap"),
        "US Equity Small Cap": ("USA", "US Equity Small Cap"),
        "Global Equity Large Cap": ("Global", "Global Equity Large Cap"),
        "Global Equity Mid/Small Cap": ("Global", "Global Equity Mid/Small Cap"),
        "Global Emerging Markets Equity": ("Global", "Global Emerging Markets Equity"),
        "Europe Equity Large Cap": ("International", "Europe Equity Large Cap"),
        "Asia Equity": ("International", "Asia Equity"),
        "Japan Equity": ("International", "Japan Equity"),
        "Emerging Markets Fixed Income": ("International", "Emerging Markets Fixed Income"),
        "US Fixed Income": ("USA", "US Fixed Income"),
        "US Municipal Fixed Income": ("USA", "US Municipal Fixed Income"),
        "Global Fixed Income": ("Global", "Global Fixed Income"),
        "Flexible Allocation": ("Global", "Flexible Allocation"),
        "Aggressive Allocation": ("Global", "Aggressive Allocation"),
        "Moderate Allocation": ("Global", "Moderate Allocation"),
        "Cautious Allocation": ("Global", "Cautious Allocation"),
        "Commodities Broad Basket": ("Global", "Commodities Broad Basket"),
        "Commodities Specified": ("Global", "Commodities Specified"),
        "Options Trading": ("USA", "Options Trading"),
        "Multialternative": ("Global", "Multialternative"),
        "Market Neutral": ("Global", "Market Neutral"),
        "Long/Short Equity": ("Global", "Long/Short Equity"),
        "Alternative Miscellaneous": ("Global", "Alternative Miscellaneous"),
        "Energy Sector Equity": ("USA", "Energy Sector Equity"),
        "Equity Miscellaneous": ("USA", "Equity Miscellaneous"),
        "Financials Sector Equity": ("USA", "Financials Sector Equity"),
        "Healthcare Sector Equity": ("USA", "Healthcare Sector Equity"),
        "Consumer Goods & Services Sector Equity": ("USA", "Consumer Goods & Services Sector Equity"),
        "Communications Sector Equity": ("USA", "Communications Sector Equity"),
        "Industrials Sector Equity": ("USA", "Industrials Sector Equity"),
        "Other Sector Equity": ("USA", "Other Sector Equity"),
        "Real Estate Sector Equity": ("USA", "Real Estate Sector Equity"),
        "Precious Metals Sector Equity": ("USA", "Precious Metals Sector Equity"),
        "Technology Sector Equity": ("USA", "Technology Sector Equity"),
        "Utilities Sector Equity": ("USA", "Utilities Sector Equity"),
        "Asia ex-Japan Equity": ("International", "Asia ex-Japan Equity"),
        "Australia & New Zealand Equity": ("International", "Australia & New Zealand Equity"),
        "Canadian Equity Large Cap": ("International", "Canadian Equity Large Cap"),
        "Europe Equity Mid/Small Cap": ("International", "Europe Equity Mid/Small Cap"),
        "Greater China Equity": ("International", "Greater China Equity"),
        "India Equity": ("International", "India Equity"),
        "Mexico Equity": ("International", "Mexico Equity"),
        "Korea Equity": ("International", "Korea Equity"),
        "Latin America Equity": ("International", "Latin America Equity"),
        "UK Equity Large Cap": ("International", "UK Equity Large Cap"),
        "Thailand Equity": ("International", "Thailand Equity"),
        "Convertibles": ("USA", "Convertibles"),
        "Fixed Income Miscellaneous": ("USA", "Fixed Income Miscellaneous"),
        "Allocation Miscellaneous": ("Global", "Allocation Miscellaneous")
    }
    return mapping.get(category, ("Unknown", "Unknown"))

# Section 3: Data Loading Functions
def load_fund_metadata():
    query = """
    SELECT 
        f.SymbolCUSIP, 
        f.Region, 
        f.YC_Global_Category_ID, 
        c.Global_Category_Name,
        f.YC_Category_ID,
        y.Category_Name,
        f.CWA_Broad_Category_ID,
        b.CWA_Broad_Category_Name
    FROM Funds_to_Screen f
    JOIN YC_Global_Category_List c ON f.YC_Global_Category_ID = c.ID
    JOIN YC_Category_List y ON f.YC_Category_ID = y.ID
    LEFT JOIN CWA_Broad_Category_List b ON f.CWA_Broad_Category_ID = b.ID
    """
    print("Executing metadata query...")
    try:
        df = pd.read_sql(query, engine)
        df[["Region", "FactorProfile"]] = df["Global_Category_Name"].map(category_to_region).apply(pd.Series)
        print(f"Metadata loaded: {df.columns.tolist()} | Shape: {df.shape}")
        if df["CWA_Broad_Category_Name"].isnull().all():
            print("⚠️ Warning: CWA_Broad_Category_Name is missing for all rows; Equity regressions 5-7 will be skipped")
        return df.dropna(subset=["Region", "FactorProfile"])
    except Exception as e:
        print(f"❌ Error loading metadata: {e}")
        raise

def load_fund_returns(fund_ids):
    placeholders = ",".join([f"'{fid}'" for fid in fund_ids])
    query = f"""
        SELECT SymbolCUSIP, Date, ReturnValue
        FROM Fund_Returns_Timeseries
        WHERE SymbolCUSIP IN ({placeholders})
        AND Metric = '{RETURN_METRIC}'
    """
    df = pd.read_sql(query, engine, parse_dates=["Date"])
    print(f"Fund returns loaded: {df.columns.tolist()} | Shape: {df.shape}")
    return df.pivot(index="Date", columns="SymbolCUSIP", values="ReturnValue")

def load_db_factors(factor_list, region="Global", table="factor_returns", asset_class=None):
    factor_in_clause = ','.join([f"'{f}'" for f in factor_list])
    query = f"""
        SELECT date AS Date, factor AS Factor, value AS Value
        FROM {table}
        WHERE factor IN ({factor_in_clause})
    """
    params = ()
    # Universal factors (RF, TSM-*) don't filter by region unless specified
    if region and not any(f.startswith('TSM-') or f == 'RF' for f in factor_list):
        query += " AND region = ?"
        params = (region,)
    elif 'RF' in factor_list:
        query += " AND region = 'USA'"  # RF is under USA per Query1
    if asset_class:
        query += " AND asset_class = ?"
        params += (asset_class,)
    df = pd.read_sql(query, engine, params=params, parse_dates=['Date'])
    if df.empty:
        logging.warning(f"No data for factors {factor_list} in {table} (region: {region}, asset_class: {asset_class})")
        return pd.DataFrame()
    pivoted_df = df.pivot(index="Date", columns="Factor", values="Value").rename(
        columns={
            'MKT': 'mkt', 'SMB': 'smb', 'HML_Devil': 'hml', 'UMD': 'umd', 'QMJ': 'qmj',
            'BAB': 'bab', 'RF': 'rf', 'TSM-Com': 'tsm-com', 'TSM-EQ': 'tsm-eq',
            'TSM-FI': 'tsm-fi', 'TSM-FX': 'tsm-fx', 'TSM-MA': 'tsm-ma'
        }
    )
    missing_factors = [f for f in factor_list if f.lower() not in pivoted_df.columns]
    if missing_factors:
        logging.warning(f"Missing factors in {table} (region: {region}): {missing_factors}")
    return pivoted_df

def load_fixed_income_factors(factor_list):
    factor_in_clause = ','.join([f"'{f}'" for f in factor_list])
    query = f"""
        SELECT Date, Factor_Name, ReturnValue
        FROM Fixed_Income_Factor_Returns
        WHERE Factor_Name IN ({factor_in_clause})
    """
    df = pd.read_sql(query, engine, parse_dates=["Date"])
    print(f"Fixed income factors loaded: {df.columns.tolist()} | Shape: {df.shape}")
    return df.pivot(index="Date", columns="Factor_Name", values="ReturnValue")

def load_century_factors(factor_list, portfolio, asset_class=None, region="Global"):
    factor_in_clause = ','.join([f"'{f}'" for f in factor_list])
    query = f"""
        SELECT date AS Date, factor AS Factor, value AS Value
        FROM aqr_century_factors
        WHERE factor IN ({factor_in_clause})
        AND portfolio = ?
    """
    params = (portfolio,)
    if asset_class:
        query += " AND asset_class = ?"
        params += (asset_class,)
    if region != "Global":
        query += " AND region = ?"
        params += (region,)
    print(f"Executing query: {query} with params: {params}")
    df = pd.read_sql(query, engine, params=params, parse_dates=['Date'])
    print(f"Century factors loaded: {df.columns.tolist()} | Shape: {df.shape}")
    pivoted_df = df.pivot(index="Date", columns="Factor", values="Value")
    print(f"Century factors columns after pivot: {pivoted_df.columns.tolist()}")
    return pivoted_df

def load_commodity_factors():
    query = """
        SELECT date AS Date, 
               excess_return_eqwt, 
               excess_spot_return_eqwt, 
               ir_adjusted_carry_eqwt, 
               spot_return_eqwt, 
               carry_eqwt, 
               excess_return_long_short, 
               excess_spot_return_long_short, 
               ir_adjusted_carry_long_short, 
               aggregate_backwardation_contango
        FROM aqr_cmdty_factors
    """
    df = pd.read_sql(query, engine, parse_dates=['Date'])
    print(f"Commodity factors loaded: {df.columns.tolist()} | Shape: {df.shape}")
    return df.set_index("Date")

# Section 4: Rolling Regression Functions
def run_rolling_regression(fund, returns, factors, regression_type, factor_set):
    results = []
    returns = returns.dropna()  # Drop NaN values
    factors = factors.dropna()  # Drop NaN values
    returns.index = pd.to_datetime(returns.index, errors='coerce')
    factors.index = pd.to_datetime(factors.index, errors='coerce')
    returns = returns[returns.index.notnull()]  # Remove NaT
    factors = factors[factors.index.notnull()]  # Remove NaT
    if returns.empty or factors.empty:
        print(f"⚠️ Warning: Empty returns or factors for {fund}; skipping regression")
        return results
    viable_periods = [w for w in ROLLING_PERIODS if (returns.index.max() - relativedelta(months=w)) >= returns.index.min()]
    
    for window in viable_periods:
        start = returns.index.min() + relativedelta(months=window)
        for end_date in returns.loc[returns.index >= start].index:
            start_date = end_date - relativedelta(months=window - 1)
            y = returns.loc[start_date:end_date]
            X = factors.loc[start_date:end_date]
            X, y = X.align(y, join="inner", axis=0)
            if len(y) < window or y.isnull().any() or X.isnull().any().any():
                continue
            X_const = add_constant(X)
            model = OLS(y, X_const).fit()
            for factor in X.columns:
                results.append({
                    "SymbolCUSIP": fund,
                    "MonthEndDate": end_date,
                    "RollPeriod": f"{window}m",
                    "Factor_Name": factor,
                    "Coefficient": model.params.get(factor, np.nan),
                    "P_Value": model.pvalues.get(factor, np.nan),
                    "T_Stat": model.tvalues.get(factor, np.nan),
                    "Standard_Error": model.bse.get(factor, np.nan),
                    "CI_Lower": model.conf_int().loc[factor][0] if factor in model.params else np.nan,
                    "CI_Upper": model.conf_int().loc[factor][1] if factor in model.params else np.nan,
                    "Adj_R2": model.rsquared_adj,
                    "Correlation": np.corrcoef(y, model.fittedvalues)[0, 1] if len(y) > 1 else np.nan,
                    "Regression_Type": regression_type,
                    "Factor_Set": factor_set
                })
    return results

def process_fund(fund_row):
    """Process regressions for a single fund, returning a list of records."""
    records = []
    symbol = fund_row["SymbolCUSIP"]
    category = fund_row["Global_Category_Name"]
    broad_category = fund_row.get("CWA_Broad_Category_Name", None)
    returns = fund_row["returns"].dropna()
    
    if returns.empty:
        logging.warning(f"No valid returns for {symbol}; skipping")
        return records

    # Equity (USA)
    if category in [
        "Energy Sector Equity", "Equity Miscellaneous", "Financials Sector Equity",
        "Healthcare Sector Equity", "Consumer Goods & Services Sector Equity",
        "Communications Sector Equity", "Industrials Sector Equity", "Other Sector Equity",
        "Real Estate Sector Equity", "Precious Metals Sector Equity", "Technology Sector Equity",
        "Utilities Sector Equity", "US Equity Large Cap Blend", "US Equity Large Cap Growth",
        "US Equity Large Cap Value", "US Equity Mid Cap", "US Equity Small Cap", "Options Trading"
    ]:
        # Regression 1: USA, MKT-RF, HML-Devil, QMJ, SMB, UMD, BAB
        factors_eq = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB'], "USA")
        rf_factors = load_db_factors(['RF'], "USA")
        factors = pd.concat([factors_eq, rf_factors], axis=1).dropna()
        if factors.empty:
            logging.warning(f"No valid factors for {symbol} (Equity_USA_1)")
            return records
        if 'mkt' in factors.columns and 'rf' in factors.columns:
            factors['mkt-rf'] = factors['mkt'] - factors['rf']
        elif 'mkt' not in factors.columns:
            logging.warning(f"No market factor for {symbol} (Equity_USA_1); skipping")
            return records
        factors, returns_aligned = factors.align(returns, join="inner", axis=0)
        if returns_aligned.empty:
            logging.warning(f"No overlapping dates for {symbol} (Equity_USA_1)")
            return records
        desired_factors = ['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'hml', 'qmj', 'smb', 'umd', 'bab']
        available_factors = [f for f in desired_factors if f in factors.columns]
        if available_factors:
            records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "Equity_USA_1"))
        else:
            logging.warning(f"No valid factors for {symbol} (Equity_USA_1)")

        # Regression 2-4: Century Factors
        for portfolio, factor_set in [
            ("US Stock Selection", "Equity_USA_2"),
            ("All Macro", "Equity_USA_3"),
            ("Equity Indices", "Equity_USA_4")
        ]:
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], portfolio, region="USA")
            if factors.empty:
                logging.warning(f"No century factors for {symbol} ({factor_set})")
                continue
            factors, returns_aligned = factors.align(returns, join="inner", axis=0)
            if returns_aligned.empty:
                logging.warning(f"No overlapping dates for {symbol} ({factor_set})")
                continue
            records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", factor_set))

        if broad_category in ["Quantitative/Tactical", "Strategic", "Nontraditional"]:
            # Regression 5
            factors_eq = load_db_factors(['MKT', 'BAB'], "USA")
            factors_fi = load_db_factors(['TSM-FI'])  # Universal
            factors_fx = load_db_factors(['TSM-FX'])  # Universal
            rf_factors = load_db_factors(['RF'], "USA")
            fi_factors = load_fixed_income_factors(['TERM', 'CREDIT'])
            cmdty_factors = load_commodity_factors()
            factors = pd.concat([factors_eq, factors_fi, factors_fx, rf_factors, fi_factors, cmdty_factors[['excess_return_eqwt']]], axis=1).dropna()
            if factors.empty:
                logging.warning(f"No valid factors for {symbol} (Equity_USA_5)")
            else:
                if 'mkt' in factors.columns and 'rf' in factors.columns:
                    factors['mkt-rf'] = factors['mkt'] - factors['rf']
                factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                if returns_aligned.empty:
                    logging.warning(f"No overlapping dates for {symbol} (Equity_USA_5)")
                else:
                    desired_factors = ['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'tsm-fx', 'tsm-fi', 'bab', 'TERM', 'CREDIT', 'excess_return_eqwt']
                    available_factors = [f for f in desired_factors if f in factors.columns]
                    if available_factors:
                        records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "Equity_USA_5"))

            # Regression 6
            factors_eq = load_db_factors(['MKT', 'SMB', 'BAB'], "USA")
            factors_com = load_db_factors(['TSM-Com'])  # Universal
            rf_factors = load_db_factors(['RF'], "USA")
            fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT_HY'])
            factors = pd.concat([factors_eq, factors_com, rf_factors, fi_factors], axis=1).dropna()
            if factors.empty:
                logging.warning(f"No valid factors for {symbol} (Equity_USA_6)")
            else:
                if 'mkt' in factors.columns and 'rf' in factors.columns:
                    factors['mkt-rf'] = factors['mkt'] - factors['rf']
                factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                if returns_aligned.empty:
                    logging.warning(f"No overlapping dates for {symbol} (Equity_USA_6)")
                else:
                    desired_factors = ['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'smb', 'bab', 'TERM_Int', 'TERM_Long', 'CREDIT_HY', 'tsm-com']
                    available_factors = [f for f in desired_factors if f in factors.columns]
                    if available_factors:
                        records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "Equity_USA_6"))

            # Regression 7
            factors_eq = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'UMD', 'SMB', 'BAB'], "USA")
            factors_com = load_db_factors(['TSM-Com'])  # Universal
            factors_fi = load_db_factors(['TSM-FI'])  # Universal
            factors_fx = load_db_factors(['TSM-FX'])  # Universal
            rf_factors = load_db_factors(['RF'], "USA")
            fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY'])
            factors = pd.concat([factors_eq, factors_com, factors_fi, factors_fx, rf_factors, fi_factors], axis=1).dropna()
            if factors.empty:
                logging.warning(f"No valid factors for {symbol} (Equity_USA_7)")
            else:
                if 'mkt' in factors.columns and 'rf' in factors.columns:
                    factors['mkt-rf'] = factors['mkt'] - factors['rf']
                factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                if returns_aligned.empty:
                    logging.warning(f"No overlapping dates for {symbol} (Equity_USA_7)")
                else:
                    desired_factors = ['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'hml', 'qmj', 'umd', 'smb', 'bab', 'TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY', 'tsm-com', 'tsm-fi', 'tsm-fx']
                    available_factors = [f for f in desired_factors if f in factors.columns]
                    if available_factors:
                        records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "Equity_USA_7"))
        else:
            logging.warning(f"Skipping Equity regressions 5-7 for {symbol}: Not Quantitative/Tactical, Strategic, or Nontraditional")

    # Equity (International)
    elif category in [
        "Asia ex-Japan Equity", "Australia & New Zealand Equity", "Canadian Equity Large Cap",
        "Europe Equity Large Cap", "Europe Equity Mid/Small Cap", "Greater China Equity",
        "India Equity", "Mexico Equity", "Japan Equity", "Korea Equity", "Latin America Equity",
        "UK Equity Large Cap", "Thailand Equity"
    ]:
        # Regression 1
        factors_eq = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB'], "Intl")
        rf_factors = load_db_factors(['RF'], "USA")
        factors = pd.concat([factors_eq, rf_factors], axis=1).dropna()
        if factors.empty:
            logging.warning(f"No valid factors for {symbol} (Equity_Intl_1)")
        else:
            if 'mkt' in factors.columns and 'rf' in factors.columns:
                factors['mkt-rf'] = factors['mkt'] - factors['rf']
            factors, returns_aligned = factors.align(returns, join="inner", axis=0)
            if returns_aligned.empty:
                logging.warning(f"No overlapping dates for {symbol} (Equity_Intl_1)")
            else:
                desired_factors = ['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'hml', 'qmj', 'smb', 'umd', 'tsm-eq', 'bab']
                available_factors = [f for f in desired_factors if f in factors.columns]
                if available_factors:
                    records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "Equity_Intl_1"))

        # Regression 2-4
        for portfolio, factor_set in [
            ("Intl Stock Selection", "Equity_Intl_2"),
            ("All Macro", "Equity_Intl_3"),
            ("Equity Indices", "Equity_Intl_4")
        ]:
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], portfolio, region="International")
            if factors.empty:
                logging.warning(f"No century factors for {symbol} ({factor_set})")
                continue
            factors, returns_aligned = factors.align(returns, join="inner", axis=0)
            if returns_aligned.empty:
                logging.warning(f"No overlapping dates for {symbol} ({factor_set})")
            else:
                records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", factor_set))

    # Equity (Global)
    elif category in ["Global Emerging Markets Equity", "Global Equity Large Cap", "Global Equity Mid/Small Cap"]:
        # Regression 1
        factors_eq = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB'], "Global")
        rf_factors = load_db_factors(['RF'], "USA")
        factors = pd.concat([factors_eq, rf_factors], axis=1).dropna()
        if factors.empty:
            logging.warning(f"No valid factors for {symbol} (Equity_Global_1)")
        else:
            if 'mkt' in factors.columns and 'rf' in factors.columns:
                factors['mkt-rf'] = factors['mkt'] - factors['rf']
            factors, returns_aligned = factors.align(returns, join="inner", axis=0)
            if returns_aligned.empty:
                logging.warning(f"No overlapping dates for {symbol} (Equity_Global_1)")
            else:
                desired_factors = ['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'hml', 'qmj', 'smb', 'umd', 'tsm-eq', 'bab']
                available_factors = [f for f in desired_factors if f in factors.columns]
                if available_factors:
                    records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "Equity_Global_1"))

        # Regression 2-4
        for portfolio, factor_set in [
            ("All Stock Selection", "Equity_Global_2"),
            ("All Macro", "Equity_Global_3"),
            ("Equity Indices", "Equity_Global_4")
        ]:
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], portfolio)
            if factors.empty:
                logging.warning(f"No century factors for {symbol} ({factor_set})")
                continue
            factors, returns_aligned = factors.align(returns, join="inner", axis=0)
            if returns_aligned.empty:
                logging.warning(f"No overlapping dates for {symbol} ({factor_set})")
            else:
                records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", factor_set))

    # Fixed Income
    elif category in [
        "Convertibles", "Emerging Markets Fixed Income", "Fixed Income Miscellaneous",
        "US Fixed Income", "US Municipal Fixed Income"
    ]:
        # Regression 1
        factors_fi = load_db_factors(['TSM-FI'])  # Universal
        factors_fx = load_db_factors(['TSM-FX'])  # Universal
        fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY'])
        factors = pd.concat([factors_fi, factors_fx, fi_factors], axis=1).dropna()
        if factors.empty:
            logging.warning(f"No valid factors for {symbol} (FI_1)")
        else:
            factors, returns_aligned = factors.align(returns, join="inner", axis=0)
            if returns_aligned.empty:
                logging.warning(f"No overlapping dates for {symbol} (FI_1)")
            else:
                desired_factors = ['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY', 'tsm-fi', 'tsm-fx']
                available_factors = [f for f in desired_factors if f in factors.columns]
                if available_factors:
                    records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "FI_1"))

        # Regression 2-4
        for portfolio, factor_set in [
            ("Fixed Income", "FI_2"),
            ("All Macro", "FI_3"),
            ("Equity Indices", "FI_4")
        ]:
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], portfolio)
            if factors.empty:
                logging.warning(f"No century factors for {symbol} ({factor_set})")
                continue
            factors, returns_aligned = factors.align(returns, join="inner", axis=0)
            if returns_aligned.empty:
                logging.warning(f"No overlapping dates for {symbol} ({factor_set})")
            else:
                records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", factor_set))

    # Allocation
    elif category in [
        "Aggressive Allocation", "Allocation Miscellaneous", "Cautious Allocation",
        "Flexible Allocation", "Moderate Allocation"
    ]:
        # Regression 1
        factors_eq = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ'], "Global")
        factors_fi = load_db_factors(['TSM-FI'])  # Universal
        rf_factors = load_db_factors(['RF'], "USA")
        fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY'])
        factors = pd.concat([factors_eq, factors_fi, rf_factors, fi_factors], axis=1).dropna()
        if factors.empty:
            logging.warning(f"No valid factors for {symbol} (Allocation_1)")
        else:
            if 'mkt' in factors.columns and 'rf' in factors.columns:
                factors['mkt-rf'] = factors['mkt'] - factors['rf']
            factors, returns_aligned = factors.align(returns, join="inner", axis=0)
            if returns_aligned.empty:
                logging.warning(f"No overlapping dates for {symbol} (Allocation_1)")
            else:
                desired_factors = ['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'hml', 'qmj', 'smb', 'umd', 'bab', 'tsm-eq', 'tsm-fi', 'TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY']
                available_factors = [f for f in desired_factors if f in factors.columns]
                if available_factors:
                    records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "Allocation_1"))

        # Regression 2
        fi_factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Fixed Income")
        stock_factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "All Stock Selection")
        factors = pd.concat([fi_factors, stock_factors], axis=1).dropna()
        if factors.empty:
            logging.warning(f"No valid factors for {symbol} (Allocation_2)")
        else:
            factors, returns_aligned = factors.align(returns, join="inner", axis=0)
            if returns_aligned.empty:
                logging.warning(f"No overlapping dates for {symbol} (Allocation_2)")
            else:
                records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", "Allocation_2"))

        # Regression 3-4
        for portfolio, factor_set in [
            ("All Macro", "Allocation_3"),
            ("Equity Indices", "Allocation_4")
        ]:
            factors =bea
            logging.warning(f"No century factors for {symbol} ({factor_set})")
            continue
        factors, returns_aligned = factors.align(returns, join="inner", axis=0)
        if returns_aligned.empty:
            logging.warning(f"No overlapping dates for {symbol} ({factor_set})")
        else:
            records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", factor_set))

    # Alternatives
    elif category in [
        "Alternative Miscellaneous", "Long/Short Equity", "Market Neutral", "Multialternative"
    ]:
        # Regression 1
        factors_eq = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ'], "Global")
        factors_com = load_db_factors(['TSM-Com'])  # Universal
        factors_fi = load_db_factors(['TSM-FI'])  # Universal
        factors_fx = load_db_factors(['TSM-FX'])  # Universal
        rf_factors = load_db_factors(['RF'], "USA")
        fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY'])
        factors = pd.concat([factors_eq, factors_com, factors_fi, factors_fx, rf_factors, fi_factors], axis=1).dropna()
        if factors.empty:
            logging.warning(f"No valid factors for {symbol} (Alternative_1)")
        else:
            if 'mkt' in factors.columns and 'rf' in factors.columns:
                factors['mkt-rf'] = factors['mkt'] - factors['rf']
            factors, returns_aligned = factors.align(returns, join="inner", axis=0)
            if returns_aligned.empty:
                logging.warning(f"No overlapping dates for {symbol} (Alternative_1)")
            else:
                desired_factors = ['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'hml', 'qmj', 'smb', 'umd', 'bab', 'tsm-eq', 'tsm-fi', 'TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY', 'tsm-com', 'tsm-fx']
                available_factors = [f for f in desired_factors if f in factors.columns]
                if available_factors:
                    records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "Alternative_1"))

        # Regression 2
        fi_factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Fixed Income")
        stock_factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "All Stock Selection")
        cmdty_factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Commodities")
        factors = pd.concat([fi_factors, stock_factors, cmdty_factors], axis=1).dropna()
        if factors.empty:
            logging.warning(f"No valid factors for {symbol} (Alternative_2)")
        else:
            factors, returns_aligned = factors.align(returns, join="inner", axis=0)
            if returns_aligned.empty:
                logging.warning(f"No overlapping dates for {symbol} (Alternative_2)")
            else:
                records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", "Alternative_2"))

        # Regression 3-4
        for portfolio, factor_set in [
            ("All Macro", "Alternative_3"),
            ("Equity Indices", "Alternative_4")
        ]:
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], portfolio)
            if factors.empty:
                logging.warning(f"No century factors for {symbol} ({factor_set})")
                continue
            factors, returns_aligned = factors.align(returns, join="inner", axis=0)
            if returns_aligned.empty:
                logging.warning(f"No overlapping dates for {symbol} ({factor_set})")
            else:
                records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", factor_set))

    # Commodities
    elif category in ["Commodities Broad Basket", "Commodities Specified"]:
        # Regression 1
        factors = load_commodity_factors()
        if factors.empty:
            logging.warning(f"No commodity factors for {symbol} (Commodity_1)")
        else:
            factors, returns_aligned = factors.align(returns, join="inner", axis=0)
            if returns_aligned.empty:
                logging.warning(f"No overlapping dates for {symbol} (Commodity_1)")
            else:
                records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", "Commodity_1"))

    return records

# Section 5: Main Processing Pipeline
def process_region(region, fund_subset):
    records = []
    
    for _, fund_row in fund_subset.iterrows():
        symbol = fund_row["SymbolCUSIP"]
        category = fund_row["Global_Category_Name"]
        broad_category = fund_row.get("CWA_Broad_Category_Name", None)
        
        # Equity
        if category in [
            "Energy Sector Equity", "Equity Miscellaneous", "Financials Sector Equity",
            "Healthcare Sector Equity", "Consumer Goods & Services Sector Equity",
            "Communications Sector Equity", "Industrials Sector Equity", "Other Sector Equity",
            "Real Estate Sector Equity", "Precious Metals Sector Equity", "Technology Sector Equity",
            "Utilities Sector Equity", "US Equity Large Cap Blend", "US Equity Large Cap Growth",
            "US Equity Large Cap Value", "US Equity Mid Cap", "US Equity Small Cap", "Options Trading"
        ]:
            # Regression 1: USA, MKT-RF, HML-Devil, QMJ, SMB, UMD, TSM-EQ, BAB
            factors_eq = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB'], "USA")
            rf_factors = load_db_factors(['RF'], None)  # No region/asset_class for RF
            factors = pd.concat([factors_eq, rf_factors], axis=1)
            if 'mkt' in factors.columns and 'rf' in factors.columns:
                factors['mkt-rf'] = factors['mkt'] - factors['rf']
            else:
                print(f"⚠️ Warning: Cannot calculate mkt-rf for {symbol} (Equity_USA_1); using mkt")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors[['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'hml', 'qmj', 'smb', 'umd', 'tsm-eq', 'bab']], "OLS", "Equity_USA_1"))
            
            # Regression 2: Century Factors, US Stock Selection
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "US Stock Selection", region="USA")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Equity_USA_2"))
            
            # Regression 3: Century Factors, All Macro
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "All Macro")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Equity_USA_3"))
            
            # Regression 4: Century Factors, Equity Indices
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Equity Indices")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Equity_USA_4"))
            
            if broad_category in ["Quantitative/Tactical", "Strategic", "Nontraditional"]:
                # Regression 5: Quantitative/Tactical, Strategic, Nontraditional
                factors_eq = load_db_factors(['MKT', 'BAB'], "USA")
                factors_fi = load_db_factors(['TSM-FI'], "USA", asset_class="Fixed Income")
                factors_fx = load_db_factors(['TSM-FX'], "USA", asset_class="Currencies")
                rf_factors = load_db_factors(['RF'], None)
                fi_factors = load_fixed_income_factors(['TERM', 'CREDIT'])
                cmdty_factors = load_commodity_factors()
                factors = pd.concat([factors_eq, factors_fi, factors_fx, rf_factors, fi_factors, cmdty_factors[['excess_return_eqwt']]], axis=1)
                if 'mkt' in factors.columns and 'rf' in factors.columns:
                    factors['mkt-rf'] = factors['mkt'] - factors['rf']
                else:
                    print(f"⚠️ Warning: Cannot calculate mkt-rf for {symbol} (Equity_USA_5); using mkt")
                records.extend(run_rolling_regression(symbol, fund_row["returns"], factors[['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'tsm-fx', 'tsm-fi', 'bab', 'TERM', 'CREDIT', 'excess_return_eqwt']], "OLS", "Equity_USA_5"))
                
                # Regression 6: Quantitative/Tactical, Strategic, Nontraditional
                factors_eq = load_db_factors(['MKT', 'TSM-EQ', 'SMB', 'BAB'], "USA")
                factors_com = load_db_factors(['TSM-Com'], "USA", asset_class="Commodities")
                rf_factors = load_db_factors(['RF'], None)
                fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT_HY'])
                factors = pd.concat([factors_eq, factors_com, rf_factors, fi_factors], axis=1)
                if 'mkt' in factors.columns and 'rf' in factors.columns:
                    factors['mkt-rf'] = factors['mkt'] - factors['rf']
                else:
                    print(f"⚠️ Warning: Cannot calculate mkt-rf for {symbol} (Equity_USA_6); using mkt")
                records.extend(run_rolling_regression(symbol, fund_row["returns"], factors[['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'tsm-eq', 'smb', 'bab', 'TERM_Int', 'TERM_Long', 'CREDIT_HY', 'tsm-com']], "OLS", "Equity_USA_6"))
                
                # Regression 7: Quantitative/Tactical, Strategic, Nontraditional
                factors_eq = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'UMD', 'TSM-EQ', 'SMB', 'BAB'], "USA")
                factors_com = load_db_factors(['TSM-Com'], "USA", asset_class="Commodities")
                factors_fi = load_db_factors(['TSM-FI'], "USA", asset_class="Fixed Income")
                factors_fx = load_db_factors(['TSM-FX'], "USA", asset_class="Currencies")
                rf_factors = load_db_factors(['RF'], None)
                fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY'])
                factors = pd.concat([factors_eq, factors_com, factors_fi, factors_fx, rf_factors, fi_factors], axis=1)
                if 'mkt' in factors.columns and 'rf' in factors.columns:
                    factors['mkt-rf'] = factors['mkt'] - factors['rf']
                else:
                    print(f"⚠️ Warning: Cannot calculate mkt-rf for {symbol} (Equity_USA_7); using mkt")
                records.extend(run_rolling_regression(symbol, fund_row["returns"], factors[['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'hml', 'qmj', 'umd', 'tsm-eq', 'smb', 'bab', 'TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY', 'tsm-com', 'tsm-fi', 'tsm-fx']], "OLS", "Equity_USA_7"))
            else:
                print(f"Skipping Equity regressions 5-7 for {symbol}: CWA_Broad_Category_Name not Quantitative/Tactical, Strategic, Nontraditional")
        
        # Equity (International)
        elif category in [
            "Asia ex-Japan Equity", "Australia & New Zealand Equity", "Canadian Equity Large Cap",
            "Europe Equity Large Cap", "Europe Equity Mid/Small Cap", "Greater China Equity",
            "India Equity", "Mexico Equity", "Japan Equity", "Korea Equity", "Latin America Equity",
            "UK Equity Large Cap", "Thailand Equity"
        ]:
            # Regression 1: International
            factors_eq = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB'], "Intl")
            rf_factors = load_db_factors(['RF'], None)
            factors = pd.concat([factors_eq, rf_factors], axis=1)
            if 'mkt' in factors.columns and 'rf' in factors.columns:
                factors['mkt-rf'] = factors['mkt'] - factors['rf']
            else:
                print(f"⚠️ Warning: Cannot calculate mkt-rf for {symbol} (Equity_Intl_1); using mkt")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors[['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'hml', 'qmj', 'smb', 'umd', 'tsm-eq', 'bab']], "OLS", "Equity_Intl_1"))
            
            # Regression 2: Century Factors, Intl Stock Selection
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Intl Stock Selection", region="International")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Equity_Intl_2"))
            
            # Regression 3: Century Factors, All Macro
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "All Macro")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Equity_Intl_3"))
            
            # Regression 4: Century Factors, Equity Indices
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Equity Indices")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Equity_Intl_4"))
        
        # Equity (Global)
        elif category in ["Global Emerging Markets Equity", "Global Equity Large Cap", "Global Equity Mid/Small Cap"]:
            # Regression 1: Global
            factors_eq = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB'], "Global")
            rf_factors = load_db_factors(['RF'], None)
            factors = pd.concat([factors_eq, rf_factors], axis=1)
            if 'mkt' in factors.columns and 'rf' in factors.columns:
                factors['mkt-rf'] = factors['mkt'] - factors['rf']
            else:
                print(f"⚠️ Warning: Cannot calculate mkt-rf for {symbol} (Equity_Global_1); using mkt")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors[['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'hml', 'qmj', 'smb', 'umd', 'tsm-eq', 'bab']], "OLS", "Equity_Global_1"))
            
            # Regression 2: Century Factors, All Stock Selection
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "All Stock Selection")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Equity_Global_2"))
            
            # Regression 3: Century Factors, All Macro
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "All Macro")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Equity_Global_3"))
            
            # Regression 4: Century Factors, Equity Indices
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Equity Indices")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Equity_Global_4"))
        
        # Fixed Income
        elif category in [
            "Convertibles", "Emerging Markets Fixed Income", "Fixed Income Miscellaneous",
            "US Fixed Income", "US Municipal Fixed Income"
        ]:
            # Regression 1: TERM_Int, TERM_Long, CREDIT, CREDIT_HY, TSM-FI, TSM-FX
            factors_fi = load_db_factors(['TSM-FI'], "Global", asset_class="Fixed Income")
            factors_fx = load_db_factors(['TSM-FX'], "Global", asset_class="Currencies")
            fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY'])
            factors = pd.concat([factors_fi, factors_fx, fi_factors], axis=1)
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors[['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY', 'tsm-fi', 'tsm-fx']], "OLS", "FI_1"))
            
            # Regression 2: Century Factors, Fixed Income
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Fixed Income")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "FI_2"))
            
            # Regression 3: Century Factors, All Macro
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "All Macro")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "FI_3"))
            
            # Regression 4: Century Factors, Equity Indices
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Equity Indices")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "FI_4"))
        
        # Allocation
        elif category in [
            "Aggressive Allocation", "Allocation Miscellaneous", "Cautious Allocation",
            "Flexible Allocation", "Moderate Allocation"
        ]:
            # Regression 1: Global, MKT-RF, HML-Devil, QMJ, SMB, UMD, BAB, TSM-EQ, TSM-FI, TERM_Int, TERM_Long, CREDIT, CREDIT_HY
            factors_eq = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ'], "Global")
            factors_fi = load_db_factors(['TSM-FI'], "Global", asset_class="Fixed Income")
            rf_factors = load_db_factors(['RF'], None)
            fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY'])
            factors = pd.concat([factors_eq, factors_fi, rf_factors, fi_factors], axis=1)
            if 'mkt' in factors.columns and 'rf' in factors.columns:
                factors['mkt-rf'] = factors['mkt'] - factors['rf']
            else:
                print(f"⚠️ Warning: Cannot calculate mkt-rf for {symbol} (Allocation_1); using mkt")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors[['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'hml', 'qmj', 'smb', 'umd', 'bab', 'tsm-eq', 'tsm-fi', 'TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY']], "OLS", "Allocation_1"))
            
            # Regression 2: Century Factors, Fixed Income and All Stock Selection
            fi_factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Fixed Income")
            stock_factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "All Stock Selection")
            factors = pd.concat([fi_factors, stock_factors], axis=1)
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Allocation_2"))
            
            # Regression 3: Century Factors, All Macro
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "All Macro")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Allocation_3"))
            
            # Regression 4: Century Factors, Equity Indices
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Equity Indices")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Allocation_4"))
        
        # Alternatives
        elif category in [
            "Alternative Miscellaneous", "Long/Short Equity", "Market Neutral", "Multialternative"
        ]:
            # Regression 1: Global, MKT-RF, HML-Devil, QMJ, SMB, UMD, BAB, TSM-EQ, TSM-FI, TERM_Int, TERM_Long, CREDIT, CREDIT_HY, TSM-COM, TSM-FX
            factors_eq = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ'], "Global")
            factors_com = load_db_factors(['TSM-Com'], "Global", asset_class="Commodities")
            factors_fi = load_db_factors(['TSM-FI'], "Global", asset_class="Fixed Income")
            factors_fx = load_db_factors(['TSM-FX'], "Global", asset_class="Currencies")
            rf_factors = load_db_factors(['RF'], None)
            fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY'])
            factors = pd.concat([factors_eq, factors_com, factors_fi, factors_fx, rf_factors, fi_factors], axis=1)
            if 'mkt' in factors.columns and 'rf' in factors.columns:
                factors['mkt-rf'] = factors['mkt'] - factors['rf']
            else:
                print(f"⚠️ Warning: Cannot calculate mkt-rf for {symbol} (Alternative_1); using mkt")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors[['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'hml', 'qmj', 'smb', 'umd', 'bab', 'tsm-eq', 'tsm-fi', 'TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY', 'tsm-com', 'tsm-fx']], "OLS", "Alternative_1"))
            
            # Regression 2: Century Factors, Fixed Income, All Stock Selection, Commodities
            fi_factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Fixed Income")
            stock_factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "All Stock Selection")
            cmdty_factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Commodities")
            factors = pd.concat([fi_factors, stock_factors, cmdty_factors], axis=1)
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Alternative_2"))
            
            # Regression 3: Century Factors, All Macro
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "All Macro")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Alternative_3"))
            
            # Regression 4: Century Factors, Equity Indices
            factors = load_century_factors(['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Equity Indices")
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Alternative_4"))
        
        # Commodities
        elif category in ["Commodities Broad Basket", "Commodities Specified"]:
            # Regression 1: All factors from aqr_cmdty_factors
            factors = load_commodity_factors()
            records.extend(run_rolling_regression(symbol, fund_row["returns"], factors, "OLS", "Commodity_1"))
    
    if records:
        if not DRY_RUN:
            insert_batch(records)
        else:
            print(f"ℹ️ Dry run: Would have written {len(records)} records for {region}")

def main():
    logging.basicConfig(level=logging.INFO)
    
    fund_meta = load_fund_metadata()
    regions = fund_meta["Region"].unique()
    print(f"🧠 Total mapped funds: {len(fund_meta)}")
    print(f"📍 Regions detected: {regions}\n")
    
    # Add returns to fund_meta for processing
    fund_ids = fund_meta["SymbolCUSIP"].tolist()
    if SAMPLE_DRY_RUN:
        fund_ids = random.sample(fund_ids, min(SAMPLE_SIZE, len(fund_ids)))
    returns = load_fund_returns(fund_ids)
    fund_meta["returns"] = fund_meta["SymbolCUSIP"].map(lambda x: returns[x] if x in returns.columns else pd.Series())
    
    for region in regions:
        fund_subset = fund_meta[fund_meta["Region"] == region]
        process_region(region, fund_subset)

# Section 6: Database Output
def insert_batch(records):
    df = pd.DataFrame(records)
    if not DRY_RUN:
        for i in range(0, len(df), BATCH_INSERT_SIZE):
            batch = df.iloc[i:i + BATCH_INSERT_SIZE]
            batch.to_sql("AQRR_Factor_Attribution", engine, if_exists="append", index=False)
    else:
        print(f"ℹ️ Dry run: Skipped writing {len(df)} records")

if __name__ == "__main__":
    main()
# Out:
# Executing metadata query...
# Metadata loaded: ['SymbolCUSIP', 'Region', 'YC_Global_Category_ID', 'Global_Category_Name', 'YC_Category_ID', 'Category_Name', 'CWA_Broad_Category_ID', 'CWA_Broad_Category_Name', 'FactorProfile'] | Shape: (5584, 9)
# 🧠 Total mapped funds: 5584
# 📍 Regions detected: ['Global' 'USA' 'Unknown' 'International']
#
# Fund returns loaded: ['SymbolCUSIP', 'Date', 'ReturnValue'] | Shape: (9449, 3)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 891
#     888         print(f"ℹ️ Dry run: Skipped writing {len(df)} records")
#     890 if __name__ == "__main__":
# --> 891     main()
#
# Cell In[9], line 878, in main()
#     876 for region in regions:
#     877     fund_subset = fund_meta[fund_meta["Region"] == region]
# --> 878     process_region(region, fund_subset)
#
# Cell In[9], line 791, in process_region(region, fund_subset)
#     785 # Allocation
#     786 elif category in [
#     787     "Aggressive Allocation", "Allocation Miscellaneous", "Cautious Allocation",
#     788     "Flexible Allocation", "Moderate Allocation"
#     789 ]:
#     790     # Regression 1: Global, MKT-RF, HML-Devil, QMJ, SMB, UMD, BAB, TSM-EQ, TSM-FI, TERM_Int, TERM_Long, CREDIT, CREDIT_HY
# --> 791     factors_eq = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ'], "Global")
#     792     factors_fi = load_db_factors(['TSM-FI'], "Global", asset_class="Fixed Income")
#     793     rf_factors = load_db_factors(['RF'], None)
#
# Cell In[9], line 154, in load_db_factors(factor_list, region, table, asset_class)
#     152     logging.warning(f"No data for factors {factor_list} in {table} (region: {region}, asset_class: {asset_class})")
#     153     return pd.DataFrame()
# --> 154 pivoted_df = df.pivot(index="Date", columns="Factor", values="Value").rename(
#     155     columns={
#     156         'MKT': 'mkt', 'SMB': 'smb', 'HML_Devil': 'hml', 'UMD': 'umd', 'QMJ': 'qmj',
#     157         'BAB': 'bab', 'RF': 'rf', 'TSM-Com': 'tsm-com', 'TSM-EQ': 'tsm-eq',
#     158         'TSM-FI': 'tsm-fi', 'TSM-FX': 'tsm-fx', 'TSM-MA': 'tsm-ma'
#     159     }
#     160 )
#     161 missing_factors = [f for f in factor_list if f.lower() not in pivoted_df.columns]
#     162 if missing_factors:
#
# File ~\Software Projects\Database Administration\env\Lib\site-packages\pandas\core\frame.py:9339, in DataFrame.pivot(self, columns, index, values)
#    9332 @Substitution("")
#    9333 @Appender(_shared_docs["pivot"])
#    9334 def pivot(
#    9335     self, *, columns, index=lib.no_default, values=lib.no_default
#    9336 ) -> DataFrame:
#    9337     from pandas.core.reshape.pivot import pivot
# -> 9339     return pivot(self, index=index, columns=columns, values=values)
#
# File ~\Software Projects\Database Administration\env\Lib\site-packages\pandas\core\reshape\pivot.py:570, in pivot(data, columns, index, values)
#     566         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
#     567 # error: Argument 1 to "unstack" of "DataFrame" has incompatible type "Union
#     568 # [List[Any], ExtensionArray, ndarray[Any, Any], Index, Series]"; expected
#     569 # "Hashable"
# --> 570 result = indexed.unstack(columns_listlike)  # type: ignore[arg-type]
#     571 result.index.names = [
#     572     name if name is not lib.no_default else None for name in result.index.names
#     573 ]
#     575 return result
#
# File ~\Software Projects\Database Administration\env\Lib\site-packages\pandas\core\series.py:4615, in Series.unstack(self, level, fill_value, sort)
#    4570 """
#    4571 Unstack, also known as pivot, Series with MultiIndex to produce DataFrame.
#    4572
#    (...)
#    4611 b    2    4
#    4612 """
#    4613 from pandas.core.reshape.reshape import unstack
# -> 4615 return unstack(self, level, fill_value, sort)
#
# File ~\Software Projects\Database Administration\env\Lib\site-packages\pandas\core\reshape\reshape.py:517, in unstack(obj, level, fill_value, sort)
#     515 if is_1d_only_ea_dtype(obj.dtype):
#     516     return _unstack_extension_series(obj, level, fill_value, sort=sort)
# --> 517 unstacker = _Unstacker(
#     518     obj.index, level=level, constructor=obj._constructor_expanddim, sort=sort
#     519 )
#     520 return unstacker.get_result(
#     521     obj._values, value_columns=None, fill_value=fill_value
#     522 )
#
# File ~\Software Projects\Database Administration\env\Lib\site-packages\pandas\core\reshape\reshape.py:154, in _Unstacker.__init__(self, index, level, constructor, sort)
#     146 if num_cells > np.iinfo(np.int32).max:
#     147     warnings.warn(
#     148         f"The following operation may generate {num_cells} cells "
#     149         f"in the resulting pandas object.",
#     150         PerformanceWarning,
#     151         stacklevel=find_stack_level(),
#     152     )
# --> 154 self._make_selectors()
#
# File ~\Software Projects\Database Administration\env\Lib\site-packages\pandas\core\reshape\reshape.py:210, in _Unstacker._make_selectors(self)
#     207 mask.put(selector, True)
#     209 if mask.sum() < len(self.index):
# --> 210     raise ValueError("Index contains duplicate entries, cannot reshape")
#     212 self.group_index = comp_index
#     213 self.mask = mask
#
# ValueError: Index contains duplicate entries, cannot reshape

# %%
# Version 4.6
import pandas as pd
import numpy as np
import os
import random
import logging
from datetime import timedelta, datetime
from dateutil.relativedelta import relativedelta
from concurrent.futures import ProcessPoolExecutor
from sqlalchemy import create_engine
from tqdm import tqdm
from statsmodels.regression.linear_model import OLS
from statsmodels.tools.tools import add_constant
import statsmodels.api as sm
import time

# Section 1: Configuration and Setup
connection_string = (
    "mssql+pyodbc://JULIANS_LAPTOP\\SQLEXPRESS/CWA_Fund_Database"
    "?driver=ODBC+Driver+18+for+SQL+Server"
    "&trusted_connection=yes&TrustServerCertificate=yes"
)
engine = create_engine(connection_string)

RETURN_METRIC = "1 Month Return"
ROLLING_PERIODS = [12, 24, 36, 48, 60]  # in months
DRY_RUN = True
SAMPLE_DRY_RUN = True
SAMPLE_SIZE = 50
CHUNK_SIZE = 5600
BATCH_INSERT_SIZE = 10000
MAX_WORKERS = 15  # Optimized for 16-core i9-185H

# Section 2: Helper Functions
def category_to_region(category):
    mapping = {
        "US Equity Large Cap Blend": ("USA", "US Equity Large Cap Blend"),
        "US Equity Large Cap Growth": ("USA", "US Equity Large Cap Growth"),
        "US Equity Large Cap Value": ("USA", "US Equity Large Cap Value"),
        "US Equity Mid Cap": ("USA", "US Equity Mid Cap"),
        "US Equity Small Cap": ("USA", "US Equity Small Cap"),
        "Global Equity Large Cap": ("Global", "Global Equity Large Cap"),
        "Global Equity Mid/Small Cap": ("Global", "Global Equity Mid/Small Cap"),
        "Global Emerging Markets Equity": ("Global", "Global Emerging Markets Equity"),
        "Europe Equity Large Cap": ("International", "Europe Equity Large Cap"),
        "Asia Equity": ("International", "Asia Equity"),
        "Japan Equity": ("International", "Japan Equity"),
        "Emerging Markets Fixed Income": ("International", "Emerging Markets Fixed Income"),
        "US Fixed Income": ("USA", "US Fixed Income"),
        "US Municipal Fixed Income": ("USA", "US Municipal Fixed Income"),
        "Global Fixed Income": ("Global", "Global Fixed Income"),
        "Flexible Allocation": ("Global", "Flexible Allocation"),
        "Aggressive Allocation": ("Global", "Aggressive Allocation"),
        "Moderate Allocation": ("Global", "Moderate Allocation"),
        "Cautious Allocation": ("Global", "Cautious Allocation"),
        "Commodities Broad Basket": ("Global", "Commodities Broad Basket"),
        "Commodities Specified": ("Global", "Commodities Specified"),
        "Options Trading": ("USA", "Options Trading"),
        "Multialternative": ("Global", "Multialternative"),
        "Market Neutral": ("Global", "Market Neutral"),
        "Long/Short Equity": ("Global", "Long/Short Equity"),
        "Alternative Miscellaneous": ("Global", "Alternative Miscellaneous"),
        "Energy Sector Equity": ("USA", "Energy Sector Equity"),
        "Equity Miscellaneous": ("USA", "Equity Miscellaneous"),
        "Financials Sector Equity": ("USA", "Financials Sector Equity"),
        "Healthcare Sector Equity": ("USA", "Healthcare Sector Equity"),
        "Consumer Goods & Services Sector Equity": ("USA", "Consumer Goods & Services Sector Equity"),
        "Communications Sector Equity": ("USA", "Communications Sector Equity"),
        "Industrials SectorEquity": ("USA", "Industrials Sector Equity"),
        "Other Sector Equity": ("USA", "Other Sector Equity"),
        "Real Estate Sector Equity": ("USA", "Real Estate Sector Equity"),
        "Precious Metals Sector Equity": ("USA", "Precious Metals Sector Equity"),
        "Technology Sector Equity": ("USA", "Technology Sector Equity"),
        "Utilities Sector Equity": ("USA", "Utilities Sector Equity"),
        "Asia ex-Japan Equity": ("International", "Asia ex-Japan Equity"),
        "Australia & New Zealand Equity": ("International", "Australia & New Zealand Equity"),
        "Canadian Equity Large Cap": ("International", "Canadian Equity Large Cap"),
        "Europe Equity Mid/Small Cap": ("International", "Europe Equity Mid/Small Cap"),
        "Greater China Equity": ("International", "Greater China Equity"),
        "India Equity": ("International", "India Equity"),
        "Mexico Equity": ("International", "Mexico Equity"),
        "Korea Equity": ("International", "Korea Equity"),
        "Latin America Equity": ("International", "Latin America Equity"),
        "UK Equity Large Cap": ("International", "UK Equity Large Cap"),
        "Thailand Equity": ("International", "Thailand Equity"),
        "Convertibles": ("USA", "Convertibles"),
        "Fixed Income Miscellaneous": ("USA", "Fixed Income Miscellaneous"),
        "Allocation Miscellaneous": ("Global", "Allocation Miscellaneous")
    }
    return mapping.get(category, ("Unknown", "Unknown"))

# Section 3: Data Loading Functions
def load_fund_metadata():
    query = """
    SELECT 
        f.SymbolCUSIP, 
        f.Region, 
        f.YC_Global_Category_ID, 
        c.Global_Category_Name,
        f.YC_Category_ID,
        y.Category_Name,
        f.CWA_Broad_Category_ID,
        b.CWA_Broad_Category_Name
    FROM Funds_to_Screen f
    JOIN YC_Global_Category_List c ON f.YC_Global_Category_ID = c.ID
    JOIN YC_Category_List y ON f.YC_Category_ID = y.ID
    LEFT JOIN CWA_Broad_Category_List b ON f.CWA_Broad_Category_ID = b.ID
    """
    try:
        df = pd.read_sql(query, engine)
        df[["Region", "FactorProfile"]] = df["Global_Category_Name"].map(category_to_region).apply(pd.Series)
        logging.warning(f"Loaded metadata for {len(df)} funds")
        if df["CWA_Broad_Category_Name"].isnull().all():
            logging.warning("CWA_Broad_Category_Name missing for all rows; Equity regressions 5-7 will be skipped")
        return df.dropna(subset=["Region", "FactorProfile"])
    except Exception as e:
        logging.error(f"Error loading metadata: {e}")
        raise

def load_fund_returns(fund_ids):
    placeholders = ",".join([f"'{fid}'" for fid in fund_ids])
    query = f"""
        SELECT SymbolCUSIP, Date, ReturnValue
        FROM Fund_Returns_Timeseries
        WHERE SymbolCUSIP IN ({placeholders})
        AND Metric = '{RETURN_METRIC}'
    """
    df = pd.read_sql(query, engine, parse_dates=["Date"])
    logging.warning(f"Loaded returns for {len(df['SymbolCUSIP'].unique())} funds")
    return df.pivot(index="Date", columns="SymbolCUSIP", values="ReturnValue")

def load_db_factors(factor_list, region="Global", table="factor_returns", asset_class=None):
    factor_in_clause = ','.join([f"'{f}'" for f in factor_list])
    query = f"""
        SELECT date AS Date, factor AS Factor, value AS Value
        FROM {table}
        WHERE factor IN ({factor_in_clause})
    """
    params = ()
    if region and not any(f.startswith('TSM-') or f == 'RF' for f in factor_list):
        query += " AND region = ?"
        params = (region,)
    elif 'RF' in factor_list:
        query += " AND region = 'USA'"
    if asset_class:
        query += " AND asset_class = ?"
        params += (asset_class,)
    df = pd.read_sql(query, engine, params=params, parse_dates=['Date'])
    if df.empty:
        logging.warning(f"No data for factors {factor_list} in {table} (region: {region}, asset_class: {asset_class})")
        return pd.DataFrame()
    
    # Handle duplicates
    duplicates = df.duplicated(subset=['Date', 'Factor']).sum()
    if duplicates > 0:
        logging.warning(f"Found {duplicates} duplicate Date-Factor pairs in {table} for {factor_list}; aggregating by mean")
        df = df.groupby(['Date', 'Factor'])['Value'].mean().reset_index()
    
    pivoted_df = df.pivot(index="Date", columns="Factor", values="Value").rename(
        columns={
            'MKT': 'mkt', 'SMB': 'smb', 'HML_Devil': 'hml', 'UMD': 'umd', 'QMJ': 'qmj',
            'BAB': 'bab', 'RF': 'rf', 'TSM-Com': 'tsm-com', 'TSM-EQ': 'tsm-eq',
            'TSM-FI': 'tsm-fi', 'TSM-FX': 'tsm-fx', 'TSM-MA': 'tsm-ma'
        }
    )
    missing_factors = [f for f in factor_list if f.lower() not in pivoted_df.columns]
    if missing_factors:
        logging.warning(f"Missing factors in {table} (region: {region}): {missing_factors}")
    return pivoted_df

def load_fixed_income_factors(factor_list):
    factor_in_clause = ','.join([f"'{f}'" for f in factor_list])
    query = f"""
        SELECT Date, Factor_Name, ReturnValue
        FROM Fixed_Income_Factor_Returns
        WHERE Factor_Name IN ({factor_in_clause})
    """
    df = pd.read_sql(query, engine, parse_dates=["Date"])
    if df.empty:
        logging.warning(f"No fixed income factors for {factor_list}")
        return pd.DataFrame()
    return df.pivot(index="Date", columns="Factor_Name", values="ReturnValue")

def load_century_factors(factor_list, portfolio_base, factor, asset_class=None, region="Global"):
    factor_in_clause = ','.join([f"'{f}'" for f in factor_list])
    portfolio = f"{portfolio_base} {factor}"  # e.g., "US Stock Selection Value"
    query = f"""
        SELECT date AS Date, factor AS Factor, value AS Value
        FROM aqr_century_factors
        WHERE factor IN ({factor_in_clause})
        AND portfolio = ?
    """
    params = (portfolio,)
    if asset_class:
        query += " AND asset_class = ?"
        params += (asset_class,)
    if region != "Global":
        query += " AND region = ?"
        params += (region,)
    df = pd.read_sql(query, engine, params=params, parse_dates=['Date'])
    if df.empty:
        logging.warning(f"No data for factors {factor_list} in aqr_century_factors (portfolio: {portfolio}, region: {region})")
        return pd.DataFrame()
    pivoted_df = df.pivot(index="Date", columns="Factor", values="Value")
    return pivoted_df

def load_commodity_factors():
    query = """
        SELECT date AS Date, 
               excess_return_eqwt, 
               excess_spot_return_eqwt, 
               ir_adjusted_carry_eqwt, 
               spot_return_eqwt, 
               carry_eqwt, 
               excess_return_long_short, 
               excess_spot_return_long_short, 
               ir_adjusted_carry_long_short, 
               aggregate_backwardation_contango
        FROM aqr_cmdty_factors
    """
    df = pd.read_sql(query, engine, parse_dates=['Date'])
    if df.empty:
        logging.warning("No commodity factors loaded")
        return pd.DataFrame()
    return df.set_index("Date")

# Section 4: Regression Functions
def run_rolling_regression(fund, returns, factors, regression_type, factor_set):
    results = []
    returns = returns.dropna()
    factors = factors.dropna()
    returns.index = pd.to_datetime(returns.index, errors='coerce')
    factors.index = pd.to_datetime(factors.index, errors='coerce')
    returns = returns[returns.index.notnull()]
    factors = factors[factors.index.notnull()]
    if returns.empty or factors.empty:
        logging.warning(f"Empty returns or factors for {fund} ({factor_set}); skipping")
        return results
    viable_periods = [w for w in ROLLING_PERIODS if (returns.index.max() - relativedelta(months=w)) >= returns.index.min()]
    
    for window in viable_periods:
        start = returns.index.min() + relativedelta(months=window)
        for end_date in returns.loc[returns.index >= start].index:
            start_date = end_date - relativedelta(months=window - 1)
            y = returns.loc[start_date:end_date]
            X = factors.loc[start_date:end_date]
            X, y = X.align(y, join="inner", axis=0)
            if len(y) < window or y.isnull().any() or X.isnull().any().any():
                continue
            X_const = add_constant(X)
            model = OLS(y, X_const).fit()
            for factor in X.columns:
                results.append({
                    "SymbolCUSIP": fund,
                    "MonthEndDate": end_date,
                    "RollPeriod": f"{window}m",
                    "Factor_Name": factor,
                    "Coefficient": model.params.get(factor, np.nan),
                    "P_Value": model.pvalues.get(factor, np.nan),
                    "T_Stat": model.tvalues.get(factor, np.nan),
                    "Standard_Error": model.bse.get(factor, np.nan),
                    "CI_Lower": model.conf_int().loc[factor][0] if factor in model.params else np.nan,
                    "CI_Upper": model.conf_int().loc[factor][1] if factor in model.params else np.nan,
                    "Adj_R2": model.rsquared_adj,
                    "Correlation": np.corrcoef(y, model.fittedvalues)[0, 1] if len(y) > 1 else np.nan,
                    "Regression_Type": regression_type,
                    "Factor_Set": factor_set
                })
    return results

# Section 5: Processing Functions
def process_fund(fund_row):
    """Process regressions for a single fund, returning a list of records."""
    records = []
    symbol = fund_row["SymbolCUSIP"]
    category = fund_row["Global_Category_Name"]
    broad_category = fund_row.get("CWA_Broad_Category_Name", None)
    returns = fund_row["returns"].dropna()
    
    if returns.empty:
        logging.warning(f"No valid returns for {symbol}; skipping")
        return records

    # Equity (USA)
    if category in [
        "Energy Sector Equity", "Equity Miscellaneous", "Financials Sector Equity",
        "Healthcare Sector Equity", "Consumer Goods & Services Sector Equity",
        "Communications Sector Equity", "Industrials Sector Equity", "Other Sector Equity",
        "Real Estate Sector Equity", "Precious Metals Sector Equity", "Technology Sector Equity",
        "Utilities Sector Equity", "US Equity Large Cap Blend", "US Equity Large Cap Growth",
        "US Equity Large Cap Value", "US Equity Mid Cap", "US Equity Small Cap", "Options Trading"
    ]:
        # Regression 1: USA, MKT-RF, HML-Devil, QMJ, SMB, UMD, BAB
        factors_eq = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB'], "USA")
        rf_factors = load_db_factors(['RF'], "USA")
        factors = pd.concat([factors_eq, rf_factors], axis=1).dropna()
        if factors.empty:
            logging.warning(f"No valid factors for {symbol} (Equity_USA_1)")
            return records
        if 'mkt' in factors.columns and 'rf' in factors.columns:
            factors['mkt-rf'] = factors['mkt'] - factors['rf']
        elif 'mkt' not in factors.columns:
            logging.warning(f"No market factor for {symbol} (Equity_USA_1); skipping")
            return records
        factors, returns_aligned = factors.align(returns, join="inner", axis=0)
        if returns_aligned.empty:
            logging.warning(f"No overlapping dates for {symbol} (Equity_USA_1)")
            return records
        desired_factors = ['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'hml', 'qmj', 'smb', 'umd', 'bab']
        available_factors = [f for f in desired_factors if f in factors.columns]
        if available_factors:
            records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "Equity_USA_1"))
        else:
            logging.warning(f"No valid factors for {symbol} (Equity_USA_1)")

        # Regression 2-4: Century Factors
        for portfolio_base, factor_set in [
            ("US Stock Selection", "Equity_USA_2"),
            ("All Macro", "Equity_USA_3"),
            ("Equity indices", "Equity_USA_4")
        ]:
            for factor in ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value']:
                factors = load_century_factors([factor], portfolio_base, factor, region="USA")
                if factors.empty:
                    logging.warning(f"No century factors for {symbol} ({factor_set}, factor: {factor})")
                    continue
                factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                if returns_aligned.empty:
                    logging.warning(f"No overlapping dates for {symbol} ({factor_set}, factor: {factor})")
                    continue
                records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", factor_set))

        if broad_category in ["Quantitative/Tactical", "Strategic", "Nontraditional"]:
            # Regression 5
            factors_eq = load_db_factors(['MKT', 'BAB'], "USA")
            factors_fi = load_db_factors(['TSM-FI'])  # Universal
            factors_fx = load_db_factors(['TSM-FX'])  # Universal
            rf_factors = load_db_factors(['RF'], "USA")
            fi_factors = load_fixed_income_factors(['TERM', 'CREDIT'])
            cmdty_factors = load_commodity_factors()
            factors = pd.concat([factors_eq, factors_fi, factors_fx, rf_factors, fi_factors, cmdty_factors[['excess_return_eqwt']]], axis=1).dropna()
            if factors.empty:
                logging.warning(f"No valid factors for {symbol} (Equity_USA_5)")
            else:
                if 'mkt' in factors.columns and 'rf' in factors.columns:
                    factors['mkt-rf'] = factors['mkt'] - factors['rf']
                factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                if returns_aligned.empty:
                    logging.warning(f"No overlapping dates for {symbol} (Equity_USA_5)")
                else:
                    desired_factors = ['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'tsm-fx', 'tsm-fi', 'bab', 'TERM', 'CREDIT', 'excess_return_eqwt']
                    available_factors = [f for f in desired_factors if f in factors.columns]
                    if available_factors:
                        records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "Equity_USA_5"))

            # Regression 6
            factors_eq = load_db_factors(['MKT', 'SMB', 'BAB'], "USA")
            factors_com = load_db_factors(['TSM-Com'])  # Universal
            rf_factors = load_db_factors(['RF'], "USA")
            fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT_HY'])
            factors = pd.concat([factors_eq, factors_com, rf_factors, fi_factors], axis=1).dropna()
            if factors.empty:
                logging.warning(f"No valid factors for {symbol} (Equity_USA_6)")
            else:
                if 'mkt' in factors.columns and 'rf' in factors.columns:
                    factors['mkt-rf'] = factors['mkt'] - factors['rf']
                factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                if returns_aligned.empty:
                    logging.warning(f"No overlapping dates for {symbol} (Equity_USA_6)")
                else:
                    desired_factors = ['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'smb', 'bab', 'TERM_Int', 'TERM_Long', 'CREDIT_HY', 'tsm-com']
                    available_factors = [f for f in desired_factors if f in factors.columns]
                    if available_factors:
                        records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "Equity_USA_6"))

            # Regression 7
            factors_eq = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'UMD', 'SMB', 'BAB'], "USA")
            factors_com = load_db_factors(['TSM-Com'])  # Universal
            factors_fi = load_db_factors(['TSM-FI'])  # Universal
            factors_fx = load_db_factors(['TSM-FX'])  # Universal
            rf_factors = load_db_factors(['RF'], "USA")
            fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY'])
            factors = pd.concat([factors_eq, factors_com, factors_fi, factors_fx, rf_factors, fi_factors], axis=1).dropna()
            if factors.empty:
                logging.warning(f"No valid factors for {symbol} (Equity_USA_7)")
            else:
                if 'mkt' in factors.columns and 'rf' in factors.columns:
                    factors['mkt-rf'] = factors['mkt'] - factors['rf']
                factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                if returns_aligned.empty:
                    logging.warning(f"No overlapping dates for {symbol} (Equity_USA_7)")
                else:
                    desired_factors = ['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'hml', 'qmj', 'umd', 'smb', 'bab', 'TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY', 'tsm-com', 'tsm-fi', 'tsm-fx']
                    available_factors = [f for f in desired_factors if f in factors.columns]
                    if available_factors:
                        records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "Equity_USA_7"))
        else:
            logging.warning(f"Skipping Equity regressions 5-7 for {symbol}: Not Quantitative/Tactical, Strategic, or Nontraditional")

    # Equity (International)
    elif category in [
        "Asia ex-Japan Equity", "Australia & New Zealand Equity", "Canadian Equity Large Cap",
        "Europe Equity Large Cap", "Europe Equity Mid/Small Cap", "Greater China Equity",
        "India Equity", "Mexico Equity", "Japan Equity", "Korea Equity", "Latin America Equity",
        "UK Equity Large Cap", "Thailand Equity"
    ]:
        # Regression 1
        factors_eq = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB'], "Intl")
        rf_factors = load_db_factors(['RF'], "USA")
        factors = pd.concat([factors_eq, rf_factors], axis=1).dropna()
        if factors.empty:
            logging.warning(f"No valid factors for {symbol} (Equity_Intl_1)")
        else:
            if 'mkt' in factors.columns and 'rf' in factors.columns:
                factors['mkt-rf'] = factors['mkt'] - factors['rf']
            factors, returns_aligned = factors.align(returns, join="inner", axis=0)
            if returns_aligned.empty:
                logging.warning(f"No overlapping dates for {symbol} (Equity_Intl_1)")
            else:
                desired_factors = ['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'hml', 'qmj', 'smb', 'umd', 'tsm-eq', 'bab']
                available_factors = [f for f in desired_factors if f in factors.columns]
                if available_factors:
                    records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "Equity_Intl_1"))

        # Regression 2-4
        for portfolio_base, factor_set in [
            ("Intl Stock Selection", "Equity_Intl_2"),
            ("All Macro", "Equity_Intl_3"),
            ("Equity indices", "Equity_Intl_4")
        ]:
            for factor in ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value']:
                factors = load_century_factors([factor], portfolio_base, factor, region="International")
                if factors.empty:
                    logging.warning(f"No century factors for {symbol} ({factor_set}, factor: {factor})")
                    continue
                factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                if returns_aligned.empty:
                    logging.warning(f"No overlapping dates for {symbol} ({factor_set}, factor: {factor})")
                    continue
                records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", factor_set))

    # Equity (Global)
    elif category in ["Global Emerging Markets Equity", "Global Equity Large Cap", "Global Equity Mid/Small Cap"]:
        # Regression 1
        factors_eq = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB'], "Global")
        rf_factors = load_db_factors(['RF'], "USA")
        factors = pd.concat([factors_eq, rf_factors], axis=1).dropna()
        if factors.empty:
            logging.warning(f"No valid factors for {symbol} (Equity_Global_1)")
        else:
            if 'mkt' in factors.columns and 'rf' in factors.columns:
                factors['mkt-rf'] = factors['mkt'] - factors['rf']
            factors, returns_aligned = factors.align(returns, join="inner", axis=0)
            if returns_aligned.empty:
                logging.warning(f"No overlapping dates for {symbol} (Equity_Global_1)")
            else:
                desired_factors = ['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'hml', 'qmj', 'smb', 'umd', 'tsm-eq', 'bab']
                available_factors = [f for f in desired_factors if f in factors.columns]
                if available_factors:
                    records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "Equity_Global_1"))

        # Regression 2-4
        for portfolio_base, factor_set in [
            ("All Stock Selection", "Equity_Global_2"),
            ("All Macro", "Equity_Global_3"),
            ("Equity indices", "Equity_Global_4")
        ]:
            for factor in ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value']:
                factors = load_century_factors([factor], portfolio_base, factor)
                if factors.empty:
                    logging.warning(f"No century factors for {symbol} ({factor_set}, factor: {factor})")
                    continue
                factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                if returns_aligned.empty:
                    logging.warning(f"No overlapping dates for {symbol} ({factor_set}, factor: {factor})")
                    continue
                records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", factor_set))

    # Fixed Income
    elif category in [
        "Convertibles", "Emerging Markets Fixed Income", "Fixed Income Miscellaneous",
        "US Fixed Income", "US Municipal Fixed Income"
    ]:
        # Regression 1
        factors_fi = load_db_factors(['TSM-FI'])  # Universal
        factors_fx = load_db_factors(['TSM-FX'])  # Universal
        fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY'])
        factors = pd.concat([factors_fi, factors_fx, fi_factors], axis=1).dropna()
        if factors.empty:
            logging.warning(f"No valid factors for {symbol} (FI_1)")
        else:
            factors, returns_aligned = factors.align(returns, join="inner", axis=0)
            if returns_aligned.empty:
                logging.warning(f"No overlapping dates for {symbol} (FI_1)")
            else:
                desired_factors = ['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY', 'tsm-fi', 'tsm-fx']
                available_factors = [f for f in desired_factors if f in factors.columns]
                if available_factors:
                    records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "FI_1"))

        # Regression 2-4
        for portfolio_base, factor_set in [
            ("Fixed income", "FI_2"),
            ("All Macro", "FI_3"),
            ("Equity indices", "FI_4")
        ]:
            for factor in ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value']:
                factors = load_century_factors([factor], portfolio_base, factor)
                if factors.empty:
                    logging.warning(f"No century factors for {symbol} ({factor_set}, factor: {factor})")
                    continue
                factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                if returns_aligned.empty:
                    logging.warning(f"No overlapping dates for {symbol} ({factor_set}, factor: {factor})")
                    continue
                records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", factor_set))

    # Allocation
    elif category in [
        "Aggressive Allocation", "Allocation Miscellaneous", "Cautious Allocation",
        "Flexible Allocation", "Moderate Allocation"
    ]:
        # Regression 1
        factors_eq = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ'], "Global")
        factors_fi = load_db_factors(['TSM-FI'])  # Universal
        rf_factors = load_db_factors(['RF'], "USA")
        fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY'])
        factors = pd.concat([factors_eq, factors_fi, rf_factors, fi_factors], axis=1).dropna()
        if factors.empty:
            logging.warning(f"No valid factors for {symbol} (Allocation_1)")
        else:
            if 'mkt' in factors.columns and 'rf' in factors.columns:
                factors['mkt-rf'] = factors['mkt'] - factors['rf']
            factors, returns_aligned = factors.align(returns, join="inner", axis=0)
            if returns_aligned.empty:
                logging.warning(f"No overlapping dates for {symbol} (Allocation_1)")
            else:
                desired_factors = ['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'hml', 'qmj', 'smb', 'umd', 'bab', 'tsm-eq', 'tsm-fi', 'TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY']
                available_factors = [f for f in desired_factors if f in factors.columns]
                if available_factors:
                    records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "Allocation_1"))

        # Regression 2
        for factor in ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value']:
            fi_factors = load_century_factors([factor], "Fixed income", factor)
            stock_factors = load_century_factors([factor], "All Stock Selection", factor)
            factors = pd.concat([fi_factors, stock_factors], axis=1).dropna()
            if factors.empty:
                logging.warning(f"No valid factors for {symbol} (Allocation_2, factor: {factor})")
                continue
            factors, returns_aligned = factors.align(returns, join="inner", axis=0)
            if returns_aligned.empty:
                logging.warning(f"No overlapping dates for {symbol} (Allocation_2, factor: {factor})")
                continue
            records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", "Allocation_2"))

        # Regression 3-4
        for portfolio_base, factor_set in [
            ("All Macro", "Allocation_3"),
            ("Equity indices", "Allocation_4")
        ]:
            for factor in ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value']:
                factors = load_century_factors([factor], portfolio_base, factor)
                if factors.empty:
                    logging.warning(f"No century factors for {symbol} ({factor_set}, factor: {factor})")
                    continue
                factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                if returns_aligned.empty:
                    logging.warning(f"No overlapping dates for {symbol} ({factor_set}, factor: {factor})")
                    continue
                records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", factor_set))

    # Alternatives
    elif category in [
        "Alternative Miscellaneous", "Long/Short Equity", "Market Neutral", "Multialternative"
    ]:
        # Regression 1
        factors_eq = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ'], "Global")
        factors_com = load_db_factors(['TSM-Com'])  # Universal
        factors_fi = load_db_factors(['TSM-FI'])  # Universal
        factors_fx = load_db_factors(['TSM-FX'])  # Universal
        rf_factors = load_db_factors(['RF'], "USA")
        fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY'])
        factors = pd.concat([factors_eq, factors_com, factors_fi, factors_fx, rf_factors, fi_factors], axis=1).dropna()
        if factors.empty:
            logging.warning(f"No valid factors for {symbol} (Alternative_1)")
        else:
            if 'mkt' in factors.columns and 'rf' in factors.columns:
                factors['mkt-rf'] = factors['mkt'] - factors['rf']
            factors, returns_aligned = factors.align(returns, join="inner", axis=0)
            if returns_aligned.empty:
                logging.warning(f"No overlapping dates for {symbol} (Alternative_1)")
            else:
                desired_factors = ['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'hml', 'qmj', 'smb', 'umd', 'bab', 'tsm-eq', 'tsm-fi', 'TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY', 'tsm-com', 'tsm-fx']
                available_factors = [f for f in desired_factors if f in factors.columns]
                if available_factors:
                    records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "Alternative_1"))

        # Regression 2
        for factor in ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value']:
            fi_factors = load_century_factors([factor], "Fixed income", factor)
            stock_factors = load_century_factors([factor], "All Stock Selection", factor)
            cmdty_factors = load_century_factors([factor], "Commodities", factor)
            factors = pd.concat([fi_factors, stock_factors, cmdty_factors], axis=1).dropna()
            if factors.empty:
                logging.warning(f"No valid factors for {symbol} (Alternative_2, factor: {factor})")
                continue
            factors, returns_aligned = factors.align(returns, join="inner", axis=0)
            if returns_aligned.empty:
                logging.warning(f"No overlapping dates for {symbol} (Alternative_2, factor: {factor})")
                continue
            records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", "Alternative_2"))

        # Regression 3-4
        for portfolio_base, factor_set in [
            ("All Macro", "Alternative_3"),
            ("Equity indices", "Alternative_4")
        ]:
            for factor in ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value']:
                factors = load_century_factors([factor], portfolio_base, factor)
                if factors.empty:
                    logging.warning(f"No century factors for {symbol} ({factor_set}, factor: {factor})")
                    continue
                factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                if returns_aligned.empty:
                    logging.warning(f"No overlapping dates for {symbol} ({factor_set}, factor: {factor})")
                    continue
                records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", factor_set))

    # Commodities
    elif category in ["Commodities Broad Basket", "Commodities Specified"]:
        # Regression 1
        factors = load_commodity_factors()
        if factors.empty:
            logging.warning(f"No commodity factors for {symbol} (Commodity_1)")
        else:
            factors, returns_aligned = factors.align(returns, join="inner", axis=0)
            if returns_aligned.empty:
                logging.warning(f"No overlapping dates for {symbol} (Commodity_1)")
            else:
                records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", "Commodity_1"))

    return records

def process_region(region, fund_subset):
    records = []
    with ProcessPoolExecutor(max_workers=MAX_WORKERS) as executor:
        future_to_fund = {executor.submit(process_fund, row): row["SymbolCUSIP"] for _, row in fund_subset.iterrows()}
        for future in tqdm(future_to_fund, total=len(fund_subset), desc=f"Processing {region}"):
            try:
                records.extend(future.result())
            except Exception as e:
                logging.warning(f"Error processing {future_to_fund[future]}: {e}")

    if records:
        if not DRY_RUN:
            insert_batch(records)
        else:
            logging.warning(f"Dry run: Would have written {len(records)} records for {region}")

# Section 6: Main Pipeline
def main():
    logging.basicConfig(level=logging.WARNING, format='%(asctime)s - %(levelname)s - %(message)s')
    
    fund_meta = load_fund_metadata()
    regions = fund_meta["Region"].unique()
    logging.warning(f"Total mapped funds: {len(fund_meta)}")
    logging.warning(f"Regions detected: {regions}")
    
    fund_ids = fund_meta["SymbolCUSIP"].tolist()
    if SAMPLE_DRY_RUN:
        fund_ids = random.sample(fund_ids, min(SAMPLE_SIZE, len(fund_ids)))
    returns = load_fund_returns(fund_ids)
    fund_meta["returns"] = fund_meta["SymbolCUSIP"].map(lambda x: returns[x] if x in returns.columns else pd.Series())
    
    for region in regions:
        fund_subset = fund_meta[fund_meta["Region"] == region]
        logging.warning(f"Processing {len(fund_subset)} funds in {region}")
        process_region(region, fund_subset)

# Section 7: Database Output
def insert_batch(records):
    df = pd.DataFrame(records)
    if not DRY_RUN:
        for i in range(0, len(df), BATCH_INSERT_SIZE):
            batch = df.iloc[i:i + BATCH_INSERT_SIZE]
            batch.to_sql("AQRR_Factor_Attribution", engine, if_exists="append", index=False)
    else:
        logging.warning(f"Dry run: Skipped writing {len(df)} records")

if __name__ == "__main__":
    main()
# Out:
# 2025-04-13 19:22:16,571 - WARNING - Loaded metadata for 5584 funds
# 2025-04-13 19:22:16,598 - WARNING - Total mapped funds: 5584
# 2025-04-13 19:22:16,599 - WARNING - Regions detected: ['Global' 'USA' 'Unknown' 'International']
# 2025-04-13 19:22:16,651 - WARNING - Loaded returns for 50 funds
# 2025-04-13 19:22:16,807 - WARNING - Processing 1348 funds in Global
# ---------------------------------------------------------------------------
# BrokenProcessPool                         Traceback (most recent call last)
# Cell In[1], line 692
#     689         logging.warning(f"Dry run: Skipped writing {len(df)} records")
#     691 if __name__ == "__main__":
# --> 692     main()
#
# Cell In[1], line 679, in main()
#     677 fund_subset = fund_meta[fund_meta["Region"] == region]
#     678 logging.warning(f"Processing {len(fund_subset)} funds in {region}")
# --> 679 process_region(region, fund_subset)
#
# Cell In[1], line 648, in process_region(region, fund_subset)
#     646 records = []
#     647 with ProcessPoolExecutor(max_workers=MAX_WORKERS) as executor:
# --> 648     future_to_fund = {executor.submit(process_fund, row): row["SymbolCUSIP"] for _, row in fund_subset.iterrows()}
#     649     for future in tqdm(future_to_fund, total=len(fund_subset), desc=f"Processing {region}"):
#     650         try:
#
# File ~\anaconda3\Lib\concurrent\futures\process.py:813, in ProcessPoolExecutor.submit(self, fn, *args, **kwargs)
#     811 with self._shutdown_lock:
#     812     if self._broken:
# --> 813         raise BrokenProcessPool(self._broken)
#     814     if self._shutdown_thread:
#     815         raise RuntimeError('cannot schedule new futures after shutdown')
#
# BrokenProcessPool: A child process terminated abruptly, the process pool is not usable anymore

# %%
# Version 4.7
import pandas as pd
import numpy as np
import os
import random
import logging
from datetime import timedelta, datetime
from dateutil.relativedelta import relativedelta
from concurrent.futures import ProcessPoolExecutor
from sqlalchemy import create_engine
from tqdm import tqdm
from statsmodels.regression.linear_model import OLS
from statsmodels.tools.tools import add_constant
import statsmodels.api as sm
import time

# Section 1: Configuration and Setup
connection_string = (
    "mssql+pyodbc://JULIANS_LAPTOP\\SQLEXPRESS/CWA_Fund_Database"
    "?driver=ODBC+Driver+18+for+SQL+Server"
    "&trusted_connection=yes&TrustServerCertificate=yes"
)
engine = create_engine(connection_string)

RETURN_METRIC = "1 Month Return"
ROLLING_PERIODS = [12, 24, 36, 48, 60]  # in months
DRY_RUN = True
SAMPLE_DRY_RUN = True
SAMPLE_SIZE = 50
CHUNK_SIZE = 5600
BATCH_INSERT_SIZE = 10000
MAX_WORKERS = 8  # Reduced to avoid resource overload

# Section 2: Helper Functions
def category_to_region(category):
    mapping = {
        "US Equity Large Cap Blend": ("USA", "US Equity Large Cap Blend"),
        "US Equity Large Cap Growth": ("USA", "US Equity Large Cap Growth"),
        "US Equity Large Cap Value": ("USA", "US Equity Large Cap Value"),
        "US Equity Mid Cap": ("USA", "US Equity Mid Cap"),
        "US Equity Small Cap": ("USA", "US Equity Small Cap"),
        "Global Equity Large Cap": ("Global", "Global Equity Large Cap"),
        "Global Equity Mid/Small Cap": ("Global", "Global Equity Mid/Small Cap"),
        "Global Emerging Markets Equity": ("Global", "Global Emerging Markets Equity"),
        "Europe Equity Large Cap": ("International", "Europe Equity Large Cap"),
        "Asia Equity": ("International", "Asia Equity"),
        "Japan Equity": ("International", "Japan Equity"),
        "Emerging Markets Fixed Income": ("International", "Emerging Markets Fixed Income"),
        "US Fixed Income": ("USA", "US Fixed Income"),
        "US Municipal Fixed Income": ("USA", "US Municipal Fixed Income"),
        "Global Fixed Income": ("Global", "Global Fixed Income"),
        "Flexible Allocation": ("Global", "Flexible Allocation"),
        "Aggressive Allocation": ("Global", "Aggressive Allocation"),
        "Moderate Allocation": ("Global", "Moderate Allocation"),
        "Cautious Allocation": ("Global", "Cautious Allocation"),
        "Commodities Broad Basket": ("Global", "Commodities Broad Basket"),
        "Commodities Specified": ("Global", "Commodities Specified"),
        "Options Trading": ("USA", "Options Trading"),
        "Multialternative": ("Global", "Multialternative"),
        "Market Neutral": ("Global", "Market Neutral"),
        "Long/Short Equity": ("Global", "Long/Short Equity"),
        "Alternative Miscellaneous": ("Global", "Alternative Miscellaneous"),
        "Energy Sector Equity": ("USA", "Energy Sector Equity"),
        "Equity Miscellaneous": ("USA", "Equity Miscellaneous"),
        "Financials Sector Equity": ("USA", "Financials Sector Equity"),
        "Healthcare Sector Equity": ("USA", "Healthcare Sector Equity"),
        "Consumer Goods & Services Sector Equity": ("USA", "Consumer Goods & Services Sector Equity"),
        "Communications Sector Equity": ("USA", "Communications Sector Equity"),
        "Industrials Sector Equity": ("USA", "Industrials Sector Equity"),
        "Other Sector Equity": ("USA", "Other Sector Equity"),
        "Real Estate Sector Equity": ("USA", "Real Estate Sector Equity"),
        "Precious Metals Sector Equity": ("USA", "Precious Metals Sector Equity"),
        "Technology Sector Equity": ("USA", "Technology Sector Equity"),
        "Utilities Sector Equity": ("USA", "Utilities Sector Equity"),
        "Asia ex-Japan Equity": ("International", "Asia ex-Japan Equity"),
        "Australia & New Zealand Equity": ("International", "Australia & New Zealand Equity"),
        "Canadian Equity Large Cap": ("International", "Canadian Equity Large Cap"),
        "Europe Equity Mid/Small Cap": ("International", "Europe Equity Mid/Small Cap"),
        "Greater China Equity": ("International", "Greater China Equity"),
        "India Equity": ("International", "India Equity"),
        "Mexico Equity": ("International", "Mexico Equity"),
        "Korea Equity": ("International", "Korea Equity"),
        "Latin America Equity": ("International", "Latin America Equity"),
        "UK Equity Large Cap": ("International", "UK Equity Large Cap"),
        "Thailand Equity": ("International", "Thailand Equity"),
        "Convertibles": ("USA", "Convertibles"),
        "Fixed Income Miscellaneous": ("USA", "Fixed Income Miscellaneous"),
        "Allocation Miscellaneous": ("Global", "Allocation Miscellaneous")
    }
    return mapping.get(category, ("Unknown", "Unknown"))

# Section 3: Data Loading Functions
def load_fund_metadata():
    query = """
    SELECT 
        f.SymbolCUSIP, 
        f.Region, 
        f.YC_Global_Category_ID, 
        c.Global_Category_Name,
        f.YC_Category_ID,
        y.Category_Name,
        f.CWA_Broad_Category_ID,
        b.CWA_Broad_Category_Name
    FROM Funds_to_Screen f
    JOIN YC_Global_Category_List c ON f.YC_Global_Category_ID = c.ID
    JOIN YC_Category_List y ON f.YC_Category_ID = y.ID
    LEFT JOIN CWA_Broad_Category_List b ON f.CWA_Broad_Category_ID = b.ID
    """
    try:
        df = pd.read_sql(query, engine)
        df[["Region", "FactorProfile"]] = df["Global_Category_Name"].map(category_to_region).apply(pd.Series)
        logging.warning(f"Loaded metadata for {len(df)} funds")
        if df["CWA_Broad_Category_Name"].isnull().all():
            logging.warning("CWA_Broad_Category_Name missing for all rows; Equity regressions 5-7 will be skipped")
        return df.dropna(subset=["Region", "FactorProfile"])
    except Exception as e:
        logging.error(f"Error loading metadata: {e}")
        raise

def load_fund_returns(fund_ids):
    placeholders = ",".join([f"'{fid}'" for fid in fund_ids])
    query = f"""
        SELECT SymbolCUSIP, Date, ReturnValue
        FROM Fund_Returns_Timeseries
        WHERE SymbolCUSIP IN ({placeholders})
        AND Metric = '{RETURN_METRIC}'
    """
    df = pd.read_sql(query, engine, parse_dates=["Date"])
    logging.warning(f"Loaded returns for {len(df['SymbolCUSIP'].unique())} funds")
    return df.pivot(index="Date", columns="SymbolCUSIP", values="ReturnValue")

def load_db_factors(factor_list, region="Global", table="factor_returns", asset_class=None):
    factor_in_clause = ','.join([f"'{f}'" for f in factor_list])
    query = f"""
        SELECT date AS Date, factor AS Factor, value AS Value
        FROM {table}
        WHERE factor IN ({factor_in_clause})
    """
    params = ()
    if region and not any(f.startswith('TSM-') or f == 'RF' for f in factor_list):
        query += " AND region = ?"
        params = (region,)
    elif 'RF' in factor_list:
        query += " AND region = 'USA'"
    if asset_class:
        query += " AND asset_class = ?"
        params += (asset_class,)
    df = pd.read_sql(query, engine, params=params, parse_dates=['Date'])
    if df.empty:
        logging.warning(f"No data for factors {factor_list} in {table} (region: {region}, asset_class: {asset_class})")
        return pd.DataFrame()
    
    # Handle duplicates
    duplicates = df.duplicated(subset=['Date', 'Factor']).sum()
    if duplicates > 0:
        logging.warning(f"Found {duplicates} duplicate Date-Factor pairs in {table} for {factor_list}; aggregating by mean")
        df = df.groupby(['Date', 'Factor'])['Value'].mean().reset_index()
    
    pivoted_df = df.pivot(index="Date", columns="Factor", values="Value").rename(
        columns={
            'MKT': 'mkt', 'SMB': 'smb', 'HML_Devil': 'hml', 'UMD': 'umd', 'QMJ': 'qmj',
            'BAB': 'bab', 'RF': 'rf', 'TSM-Com': 'tsm-com', 'TSM-EQ': 'tsm-eq',
            'TSM-FI': 'tsm-fi', 'TSM-FX': 'tsm-fx', 'TSM-MA': 'tsm-ma'
        }
    )
    missing_factors = [f for f in factor_list if f.lower() not in pivoted_df.columns]
    if missing_factors:
        logging.warning(f"Missing factors in {table} (region: {region}): {missing_factors}")
    return pivoted_df

def load_fixed_income_factors(factor_list):
    factor_in_clause = ','.join([f"'{f}'" for f in factor_list])
    query = f"""
        SELECT Date, Factor_Name, ReturnValue
        FROM Fixed_Income_Factor_Returns
        WHERE Factor_Name IN ({factor_in_clause})
    """
    df = pd.read_sql(query, engine, parse_dates=["Date"])
    if df.empty:
        logging.warning(f"No fixed income factors for {factor_list}")
        return pd.DataFrame()
    return df.pivot(index="Date", columns="Factor_Name", values="ReturnValue")

def load_century_factors(factor_list, portfolio_base, factor, asset_class=None, region="Global"):
    factor_in_clause = ','.join([f"'{f}'" for f in factor_list])
    portfolio = f"{portfolio_base} {factor}"  # e.g., "US Stock Selection Value"
    query = f"""
        SELECT date AS Date, factor AS Factor, value AS Value
        FROM aqr_century_factors
        WHERE factor IN ({factor_in_clause})
        AND portfolio = ?
    """
    params = (portfolio,)
    if asset_class:
        query += " AND asset_class = ?"
        params += (asset_class,)
    if region != "Global":
        query += " AND region = ?"
        params += (region,)
    df = pd.read_sql(query, engine, params=params, parse_dates=['Date'])
    if df.empty:
        logging.warning(f"No data for factors {factor_list} in aqr_century_factors (portfolio: {portfolio}, region: {region})")
        return pd.DataFrame()
    pivoted_df = df.pivot(index="Date", columns="Factor", values="Value")
    return pivoted_df

def load_commodity_factors():
    query = """
        SELECT date AS Date, 
               excess_return_eqwt, 
               excess_spot_return_eqwt, 
               ir_adjusted_carry_eqwt, 
               spot_return_eqwt, 
               carry_eqwt, 
               excess_return_long_short, 
               excess_spot_return_long_short, 
               ir_adjusted_carry_long_short, 
               aggregate_backwardation_contango
        FROM aqr_cmdty_factors
    """
    df = pd.read_sql(query, engine, parse_dates=['Date'])
    if df.empty:
        logging.warning("No commodity factors loaded")
        return pd.DataFrame()
    return df.set_index("Date")

# Section 4: Regression Functions
def run_rolling_regression(fund, returns, factors, regression_type, factor_set):
    results = []
    try:
        returns = returns.dropna()
        factors = factors.dropna()
        returns.index = pd.to_datetime(returns.index, errors='coerce')
        factors.index = pd.to_datetime(factors.index, errors='coerce')
        returns = returns[returns.index.notnull()]
        factors = factors[factors.index.notnull()]
        if returns.empty or factors.empty:
            logging.warning(f"Empty returns or factors for {fund} ({factor_set})")
            return results
        viable_periods = [w for w in ROLLING_PERIODS if (returns.index.max() - relativedelta(months=w)) >= returns.index.min()]
        
        for window in viable_periods:
            start = returns.index.min() + relativedelta(months=window)
            for end_date in returns.loc[returns.index >= start].index:
                start_date = end_date - relativedelta(months=window - 1)
                y = returns.loc[start_date:end_date]
                X = factors.loc[start_date:end_date]
                X, y = X.align(y, join="inner", axis=0)
                if len(y) < window or y.isnull().any() or X.isnull().any().any():
                    continue
                X_const = add_constant(X)
                model = OLS(y, X_const).fit()
                for factor in X.columns:
                    results.append({
                        "SymbolCUSIP": fund,
                        "MonthEndDate": end_date,
                        "RollPeriod": f"{window}m",
                        "Factor_Name": factor,
                        "Coefficient": model.params.get(factor, np.nan),
                        "P_Value": model.pvalues.get(factor, np.nan),
                        "T_Stat": model.tvalues.get(factor, np.nan),
                        "Standard_Error": model.bse.get(factor, np.nan),
                        "CI_Lower": model.conf_int().loc[factor][0] if factor in model.params else np.nan,
                        "CI_Upper": model.conf_int().loc[factor][1] if factor in model.params else np.nan,
                        "Adj_R2": model.rsquared_adj,
                        "Correlation": np.corrcoef(y, model.fittedvalues)[0, 1] if len(y) > 1 else np.nan,
                        "Regression_Type": regression_type,
                        "Factor_Set": factor_set
                    })
    except Exception as e:
        logging.warning(f"Error in run_rolling_regression for {fund} ({factor_set}): {e}")
        return results
    return results

# Section 5: Processing Functions
def process_fund(fund_row):
    """Process regressions for a single fund, returning a list of records."""
    records = []
    symbol = fund_row["SymbolCUSIP"]
    category = fund_row["Global_Category_Name"]
    broad_category = fund_row.get("CWA_Broad_Category_Name", None)
    
    try:
        returns = fund_row["returns"].dropna()
        if returns.empty:
            logging.warning(f"No valid returns for {symbol}")
            return records

        # Equity (USA)
        if category in [
            "Energy Sector Equity", "Equity Miscellaneous", "Financials Sector Equity",
            "Healthcare Sector Equity", "Consumer Goods & Services Sector Equity",
            "Communications Sector Equity", "Industrials Sector Equity", "Other Sector Equity",
            "Real Estate Sector Equity", "Precious Metals Sector Equity", "Technology Sector Equity",
            "Utilities Sector Equity", "US Equity Large Cap Blend", "US Equity Large Cap Growth",
            "US Equity Large Cap Value", "US Equity Mid Cap", "US Equity Small Cap", "Options Trading"
        ]:
            # Regression 1: USA, MKT-RF, HML-Devil, QMJ, SMB, UMD, BAB
            factors_eq = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB'], "USA")
            rf_factors = load_db_factors(['RF'], "USA")
            factors = pd.concat([factors_eq, rf_factors], axis=1).dropna()
            if factors.empty:
                logging.warning(f"No valid factors for {symbol} (Equity_USA_1)")
            else:
                if 'mkt' in factors.columns and 'rf' in factors.columns:
                    factors['mkt-rf'] = factors['mkt'] - factors['rf']
                elif 'mkt' not in factors.columns:
                    logging.warning(f"No market factor for {symbol} (Equity_USA_1)")
                else:
                    factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                    if returns_aligned.empty:
                        logging.warning(f"No overlapping dates for {symbol} (Equity_USA_1)")
                    else:
                        desired_factors = ['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'hml', 'qmj', 'smb', 'umd', 'bab']
                        available_factors = [f for f in desired_factors if f in factors.columns]
                        if available_factors:
                            records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "Equity_USA_1"))
                        else:
                            logging.warning(f"No valid factors for {symbol} (Equity_USA_1)")

            # Regression 2-4: Century Factors
            for portfolio_base, factor_set in [
                ("US Stock Selection", "Equity_USA_2"),
                ("All Macro", "Equity_USA_3"),
                ("Equity indices", "Equity_USA_4")
            ]:
                for factor in ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value']:
                    factors = load_century_factors([factor], portfolio_base, factor, region="USA")
                    if factors.empty:
                        logging.warning(f"No century factors for {symbol} ({factor_set}, factor: {factor})")
                        continue
                    factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                    if returns_aligned.empty:
                        logging.warning(f"No overlapping dates for {symbol} ({factor_set}, factor: {factor})")
                        continue
                    records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", factor_set))

            if broad_category in ["Quantitative/Tactical", "Strategic", "Nontraditional"]:
                # Regression 5
                factors_eq = load_db_factors(['MKT', 'BAB'], "USA")
                factors_fi = load_db_factors(['TSM-FI'])
                factors_fx = load_db_factors(['TSM-FX'])
                rf_factors = load_db_factors(['RF'], "USA")
                fi_factors = load_fixed_income_factors(['TERM', 'CREDIT'])
                cmdty_factors = load_commodity_factors()
                factors = pd.concat([factors_eq, factors_fi, factors_fx, rf_factors, fi_factors, cmdty_factors[['excess_return_eqwt']]], axis=1).dropna()
                if factors.empty:
                    logging.warning(f"No valid factors for {symbol} (Equity_USA_5)")
                else:
                    if 'mkt' in factors.columns and 'rf' in factors.columns:
                        factors['mkt-rf'] = factors['mkt'] - factors['rf']
                    factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                    if returns_aligned.empty:
                        logging.warning(f"No overlapping dates for {symbol} (Equity_USA_5)")
                    else:
                        desired_factors = ['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'tsm-fx', 'tsm-fi', 'bab', 'TERM', 'CREDIT', 'excess_return_eqwt']
                        available_factors = [f for f in desired_factors if f in factors.columns]
                        if available_factors:
                            records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "Equity_USA_5"))

                # Regression 6
                factors_eq = load_db_factors(['MKT', 'SMB', 'BAB'], "USA")
                factors_com = load_db_factors(['TSM-Com'])
                rf_factors = load_db_factors(['RF'], "USA")
                fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT_HY'])
                factors = pd.concat([factors_eq, factors_com, rf_factors, fi_factors], axis=1).dropna()
                if factors.empty:
                    logging.warning(f"No valid factors for {symbol} (Equity_USA_6)")
                else:
                    if 'mkt' in factors.columns and 'rf' in factors.columns:
                        factors['mkt-rf'] = factors['mkt'] - factors['rf']
                    factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                    if returns_aligned.empty:
                        logging.warning(f"No overlapping dates for {symbol} (Equity_USA_6)")
                    else:
                        desired_factors = ['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'smb', 'bab', 'TERM_Int', 'TERM_Long', 'CREDIT_HY', 'tsm-com']
                        available_factors = [f for f in desired_factors if f in factors.columns]
                        if available_factors:
                            records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "Equity_USA_6"))

                # Regression 7
                factors_eq = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'UMD', 'SMB', 'BAB'], "USA")
                factors_com = load_db_factors(['TSM-Com'])
                factors_fi = load_db_factors(['TSM-FI'])
                factors_fx = load_db_factors(['TSM-FX'])
                rf_factors = load_db_factors(['RF'], "USA")
                fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY'])
                factors = pd.concat([factors_eq, factors_com, factors_fi, factors_fx, rf_factors, fi_factors], axis=1).dropna()
                if factors.empty:
                    logging.warning(f"No valid factors for {symbol} (Equity_USA_7)")
                else:
                    if 'mkt' in factors.columns and 'rf' in factors.columns:
                        factors['mkt-rf'] = factors['mkt'] - factors['rf']
                    factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                    if returns_aligned.empty:
                        logging.warning(f"No overlapping dates for {symbol} (Equity_USA_7)")
                    else:
                        desired_factors = ['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'hml', 'qmj', 'umd', 'smb', 'bab', 'TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY', 'tsm-com', 'tsm-fi', 'tsm-fx']
                        available_factors = [f for f in desired_factors if f in factors.columns]
                        if available_factors:
                            records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "Equity_USA_7"))
            else:
                logging.warning(f"Skipping Equity regressions 5-7 for {symbol}: Not Quantitative/Tactical, Strategic, or Nontraditional")

        # Equity (International)
        elif category in [
            "Asia ex-Japan Equity", "Australia & New Zealand Equity", "Canadian Equity Large Cap",
            "Europe Equity Large Cap", "Europe Equity Mid/Small Cap", "Greater China Equity",
            "India Equity", "Mexico Equity", "Japan Equity", "Korea Equity", "Latin America Equity",
            "UK Equity Large Cap", "Thailand Equity"
        ]:
            # Regression 1
            factors_eq = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB'], "Intl")
            rf_factors = load_db_factors(['RF'], "USA")
            factors = pd.concat([factors_eq, rf_factors], axis=1).dropna()
            if factors.empty:
                logging.warning(f"No valid factors for {symbol} (Equity_Intl_1)")
            else:
                if 'mkt' in factors.columns and 'rf' in factors.columns:
                    factors['mkt-rf'] = factors['mkt'] - factors['rf']
                factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                if returns_aligned.empty:
                    logging.warning(f"No overlapping dates for {symbol} (Equity_Intl_1)")
                else:
                    desired_factors = ['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'hml', 'qmj', 'smb', 'umd', 'tsm-eq', 'bab']
                    available_factors = [f for f in desired_factors if f in factors.columns]
                    if available_factors:
                        records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "Equity_Intl_1"))

            # Regression 2-4
            for portfolio_base, factor_set in [
                ("Intl Stock Selection", "Equity_Intl_2"),
                ("All Macro", "Equity_Intl_3"),
                ("Equity indices", "Equity_Intl_4")
            ]:
                for factor in ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value']:
                    factors = load_century_factors([factor], portfolio_base, factor, region="International")
                    if factors.empty:
                        logging.warning(f"No century factors for {symbol} ({factor_set}, factor: {factor})")
                        continue
                    factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                    if returns_aligned.empty:
                        logging.warning(f"No overlapping dates for {symbol} ({factor_set}, factor: {factor})")
                        continue
                    records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", factor_set))

        # Equity (Global)
        elif category in ["Global Emerging Markets Equity", "Global Equity Large Cap", "Global Equity Mid/Small Cap"]:
            # Regression 1
            factors_eq = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB'], "Global")
            rf_factors = load_db_factors(['RF'], "USA")
            factors = pd.concat([factors_eq, rf_factors], axis=1).dropna()
            if factors.empty:
                logging.warning(f"No valid factors for {symbol} (Equity_Global_1)")
            else:
                if 'mkt' in factors.columns and 'rf' in factors.columns:
                    factors['mkt-rf'] = factors['mkt'] - factors['rf']
                factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                if returns_aligned.empty:
                    logging.warning(f"No overlapping dates for {symbol} (Equity_Global_1)")
                else:
                    desired_factors = ['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'hml', 'qmj', 'smb', 'umd', 'tsm-eq', 'bab']
                    available_factors = [f for f in desired_factors if f in factors.columns]
                    if available_factors:
                        records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "Equity_Global_1"))

            # Regression 2-4
            for portfolio_base, factor_set in [
                ("All Stock Selection", "Equity_Global_2"),
                ("All Macro", "Equity_Global_3"),
                ("Equity indices", "Equity_Global_4")
            ]:
                for factor in ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value']:
                    factors = load_century_factors([factor], portfolio_base, factor)
                    if factors.empty:
                        logging.warning(f"No century factors for {symbol} ({factor_set}, factor: {factor})")
                        continue
                    factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                    if returns_aligned.empty:
                        logging.warning(f"No overlapping dates for {symbol} ({factor_set}, factor: {factor})")
                        continue
                    records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", factor_set))

        # Fixed Income
        elif category in [
            "Convertibles", "Emerging Markets Fixed Income", "Fixed Income Miscellaneous",
            "US Fixed Income", "US Municipal Fixed Income"
        ]:
            # Regression 1
            factors_fi = load_db_factors(['TSM-FI'])
            factors_fx = load_db_factors(['TSM-FX'])
            fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY'])
            factors = pd.concat([factors_fi, factors_fx, fi_factors], axis=1).dropna()
            if factors.empty:
                logging.warning(f"No valid factors for {symbol} (FI_1)")
            else:
                factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                if returns_aligned.empty:
                    logging.warning(f"No overlapping dates for {symbol} (FI_1)")
                else:
                    desired_factors = ['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY', 'tsm-fi', 'tsm-fx']
                    available_factors = [f for f in desired_factors if f in factors.columns]
                    if available_factors:
                        records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "FI_1"))

            # Regression 2-4
            for portfolio_base, factor_set in [
                ("Fixed income", "FI_2"),
                ("All Macro", "FI_3"),
                ("Equity indices", "FI_4")
            ]:
                for factor in ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value']:
                    factors = load_century_factors([factor], portfolio_base, factor)
                    if factors.empty:
                        logging.warning(f"No century factors for {symbol} ({factor_set}, factor: {factor})")
                        continue
                    factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                    if returns_aligned.empty:
                        logging.warning(f"No overlapping dates for {symbol} ({factor_set}, factor: {factor})")
                        continue
                    records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", factor_set))

        # Allocation
        elif category in [
            "Aggressive Allocation", "Allocation Miscellaneous", "Cautious Allocation",
            "Flexible Allocation", "Moderate Allocation"
        ]:
            # Regression 1
            factors_eq = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ'], "Global")
            factors_fi = load_db_factors(['TSM-FI'])
            rf_factors = load_db_factors(['RF'], "USA")
            fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY'])
            factors = pd.concat([factors_eq, factors_fi, rf_factors, fi_factors], axis=1).dropna()
            if factors.empty:
                logging.warning(f"No valid factors for {symbol} (Allocation_1)")
            else:
                if 'mkt' in factors.columns and 'rf' in factors.columns:
                    factors['mkt-rf'] = factors['mkt'] - factors['rf']
                factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                if returns_aligned.empty:
                    logging.warning(f"No overlapping dates for {symbol} (Allocation_1)")
                else:
                    desired_factors = ['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'hml', 'qmj', 'smb', 'umd', 'bab', 'tsm-eq', 'tsm-fi', 'TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY']
                    available_factors = [f for f in desired_factors if f in factors.columns]
                    if available_factors:
                        records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "Allocation_1"))

            # Regression 2
            for factor in ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value']:
                fi_factors = load_century_factors([factor], "Fixed income", factor)
                stock_factors = load_century_factors([factor], "All Stock Selection", factor)
                factors = pd.concat([fi_factors, stock_factors], axis=1).dropna()
                if factors.empty:
                    logging.warning(f"No valid factors for {symbol} (Allocation_2, factor: {factor})")
                    continue
                factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                if returns_aligned.empty:
                    logging.warning(f"No overlapping dates for {symbol} (Allocation_2, factor: {factor})")
                    continue
                records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", "Allocation_2"))

            # Regression 3-4
            for portfolio_base, factor_set in [
                ("All Macro", "Allocation_3"),
                ("Equity indices", "Allocation_4")
            ]:
                for factor in ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value']:
                    factors = load_century_factors([factor], portfolio_base, factor)
                    if factors.empty:
                        logging.warning(f"No century factors for {symbol} ({factor_set}, factor: {factor})")
                        continue
                    factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                    if returns_aligned.empty:
                        logging.warning(f"No overlapping dates for {symbol} ({factor_set}, factor: {factor})")
                        continue
                    records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", factor_set))

        # Alternatives
        elif category in [
            "Alternative Miscellaneous", "Long/Short Equity", "Market Neutral", "Multialternative"
        ]:
            # Regression 1
            factors_eq = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ'], "Global")
            factors_com = load_db_factors(['TSM-Com'])
            factors_fi = load_db_factors(['TSM-FI'])
            factors_fx = load_db_factors(['TSM-FX'])
            rf_factors = load_db_factors(['RF'], "USA")
            fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY'])
            factors = pd.concat([factors_eq, factors_com, factors_fi, factors_fx, rf_factors, fi_factors], axis=1).dropna()
            if factors.empty:
                logging.warning(f"No valid factors for {symbol} (Alternative_1)")
            else:
                if 'mkt' in factors.columns and 'rf' in factors.columns:
                    factors['mkt-rf'] = factors['mkt'] - factors['rf']
                factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                if returns_aligned.empty:
                    logging.warning(f"No overlapping dates for {symbol} (Alternative_1)")
                else:
                    desired_factors = ['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'hml', 'qmj', 'smb', 'umd', 'bab', 'tsm-eq', 'tsm-fi', 'TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY', 'tsm-com', 'tsm-fx']
                    available_factors = [f for f in desired_factors if f in factors.columns]
                    if available_factors:
                        records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "Alternative_1"))

            # Regression 2
            for factor in ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value']:
                fi_factors = load_century_factors([factor], "Fixed income", factor)
                stock_factors = load_century_factors([factor], "All Stock Selection", factor)
                cmdty_factors = load_century_factors([factor], "Commodities", factor)
                factors = pd.concat([fi_factors, stock_factors, cmdty_factors], axis=1).dropna()
                if factors.empty:
                    logging.warning(f"No valid factors for {symbol} (Alternative_2, factor: {factor})")
                    continue
                factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                if returns_aligned.empty:
                    logging.warning(f"No overlapping dates for {symbol} (Alternative_2, factor: {factor})")
                    continue
                records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", "Alternative_2"))

            # Regression 3-4
            for portfolio_base, factor_set in [
                ("All Macro", "Alternative_3"),
                ("Equity indices", "Alternative_4")
            ]:
                for factor in ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value']:
                    factors = load_century_factors([factor], portfolio_base, factor)
                    if factors.empty:
                        logging.warning(f"No century factors for {symbol} ({factor_set}, factor: {factor})")
                        continue
                    factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                    if returns_aligned.empty:
                        logging.warning(f"No overlapping dates for {symbol} ({factor_set}, factor: {factor})")
                        continue
                    records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", factor_set))

        # Commodities
        elif category in ["Commodities Broad Basket", "Commodities Specified"]:
            # Regression 1
            factors = load_commodity_factors()
            if factors.empty:
                logging.warning(f"No commodity factors for {symbol} (Commodity_1)")
            else:
                factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                if returns_aligned.empty:
                    logging.warning(f"No overlapping dates for {symbol} (Commodity_1)")
                else:
                    records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", "Commodity_1"))

    except Exception as e:
        logging.warning(f"Error processing fund {symbol}: {e}")
        return records
    
    return records

def process_region(region, fund_subset):
    records = []
    # Apply sample size to fund_subset
    if SAMPLE_DRY_RUN:
        fund_subset = fund_subset.sample(n=min(SAMPLE_SIZE, len(fund_subset)), random_state=42)
        logging.warning(f"Sampled {len(fund_subset)} funds for {region}")
    
    with ProcessPoolExecutor(max_workers=MAX_WORKERS) as executor:
        future_to_fund = {executor.submit(process_fund, row): row["SymbolCUSIP"] for _, row in fund_subset.iterrows()}
        for future in tqdm(future_to_fund, total=len(fund_subset), desc=f"Processing {region}"):
            try:
                records.extend(future.result())
            except Exception as e:
                logging.warning(f"Error processing {future_to_fund[future]}: {e}")

    if records:
        if not DRY_RUN:
            insert_batch(records)
        else:
            logging.warning(f"Dry run: Would have written {len(records)} records for {region}")

# Section 6: Main Pipeline
def main():
    logging.basicConfig(level=logging.WARNING, format='%(asctime)s - %(levelname)s - %(message)s')
    
    fund_meta = load_fund_metadata()
    regions = fund_meta["Region"].unique()
    logging.warning(f"Total mapped funds: {len(fund_meta)}")
    logging.warning(f"Regions detected: {regions}")
    
    fund_ids = fund_meta["SymbolCUSIP"].tolist()
    if SAMPLE_DRY_RUN:
        fund_ids = random.sample(fund_ids, min(SAMPLE_SIZE, len(fund_ids)))
    returns = load_fund_returns(fund_ids)
    fund_meta["returns"] = fund_meta["SymbolCUSIP"].map(lambda x: returns[x] if x in returns.columns else pd.Series())
    
    for region in regions:
        fund_subset = fund_meta[fund_meta["Region"] == region]
        process_region(region, fund_subset)

# Section 7: Database Output
def insert_batch(records):
    try:
        df = pd.DataFrame(records)
        if not DRY_RUN:
            for i in range(0, len(df), BATCH_INSERT_SIZE):
                batch = df.iloc[i:i + BATCH_INSERT_SIZE]
                batch.to_sql("AQRR_Factor_Attribution", engine, if_exists="append", index=False)
        else:
            logging.warning(f"Dry run: Skipped writing {len(df)} records")
    except Exception as e:
        logging.error(f"Error inserting batch: {e}")

if __name__ == "__main__":
    main()
# Out:
# 2025-04-13 19:25:51,857 - WARNING - Loaded metadata for 5584 funds
# 2025-04-13 19:25:51,862 - WARNING - Total mapped funds: 5584
# 2025-04-13 19:25:51,862 - WARNING - Regions detected: ['Global' 'USA' 'Unknown' 'International']
# 2025-04-13 19:25:51,918 - WARNING - Loaded returns for 50 funds
# 2025-04-13 19:25:52,051 - WARNING - Sampled 50 funds for Global
# Processing Global:   0%|          | 0/50 [00:00<?, ?it/s]2025-04-13 19:25:52,255 - WARNING - Error processing RPAR: A process in the process pool was terminated abruptly while the future was running or pending.
# Processing Global:   2%|▏         | 1/50 [00:00<00:06,  7.41it/s]2025-04-13 19:25:52,258 - WARNING - Error processing AWAYX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,259 - WARNING - Error processing ABPYX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,260 - WARNING - Error processing AFGZX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,261 - WARNING - Error processing QMGYX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,262 - WARNING - Error processing BWX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,263 - WARNING - Error processing MGBJX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,264 - WARNING - Error processing APDEX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,265 - WARNING - Error processing PDEZX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,265 - WARNING - Error processing DFAI: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,266 - WARNING - Error processing WCMI: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,267 - WARNING - Error processing AHLT: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,268 - WARNING - Error processing BISMX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,269 - WARNING - Error processing AVIV: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,270 - WARNING - Error processing SSXU: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,270 - WARNING - Error processing SOYB: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,271 - WARNING - Error processing BPGLX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,271 - WARNING - Error processing CBSE: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,272 - WARNING - Error processing DNL: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,273 - WARNING - Error processing PEMYX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,273 - WARNING - Error processing DFAX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,275 - WARNING - Error processing AVXC: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,276 - WARNING - Error processing OYCIX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,277 - WARNING - Error processing IGOV: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,278 - WARNING - Error processing GSIE: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,279 - WARNING - Error processing MNBIX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,280 - WARNING - Error processing BAMA: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,280 - WARNING - Error processing TPMN: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,281 - WARNING - Error processing PAUPX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,282 - WARNING - Error processing TMAT: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,283 - WARNING - Error processing EAFG: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,284 - WARNING - Error processing MICYX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,284 - WARNING - Error processing JPIB: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,285 - WARNING - Error processing IXUS: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,286 - WARNING - Error processing PGSAX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,287 - WARNING - Error processing HFXI: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,288 - WARNING - Error processing MOOD: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,288 - WARNING - Error processing IVFIX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,289 - WARNING - Error processing ISHG: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,290 - WARNING - Error processing FLIA: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,290 - WARNING - Error processing WIP: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,291 - WARNING - Error processing PCEM: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,291 - WARNING - Error processing UCMCX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,291 - WARNING - Error processing JEUIX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,292 - WARNING - Error processing QLVD: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,294 - WARNING - Error processing CMDY: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,295 - WARNING - Error processing ICOW: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,296 - WARNING - Error processing FENI: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,297 - WARNING - Error processing GSFP: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,297 - WARNING - Error processing PMADX: A process in the process pool was terminated abruptly while the future was running or pending.
# Processing Global: 100%|██████████| 50/50 [00:00<00:00, 283.69it/s]
# 2025-04-13 19:25:52,308 - WARNING - Sampled 50 funds for USA
# Processing USA:   0%|          | 0/50 [00:00<?, ?it/s]2025-04-13 19:25:52,489 - WARNING - Error processing PRGTX: A process in the process pool was terminated abruptly while the future was running or pending.
# Processing USA:   2%|▏         | 1/50 [00:00<00:05,  9.07it/s]2025-04-13 19:25:52,491 - WARNING - Error processing CARZ: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,492 - WARNING - Error processing TIP: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,493 - WARNING - Error processing IQHI: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,493 - WARNING - Error processing FTCS: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,495 - WARNING - Error processing XFLX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,496 - WARNING - Error processing VBK: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,497 - WARNING - Error processing SZNE: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,497 - WARNING - Error processing DQIRX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,498 - WARNING - Error processing FAZZX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,499 - WARNING - Error processing ASDIX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,500 - WARNING - Error processing EDOW: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,501 - WARNING - Error processing SHIYX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,502 - WARNING - Error processing EGRIX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,503 - WARNING - Error processing GIGGX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,505 - WARNING - Error processing REQTX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,506 - WARNING - Error processing FDG: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,506 - WARNING - Error processing DAX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,507 - WARNING - Error processing IYG: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,507 - WARNING - Error processing GDIV: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,508 - WARNING - Error processing FBUF: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,509 - WARNING - Error processing AUUYX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,510 - WARNING - Error processing RSDYX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,511 - WARNING - Error processing WPGTX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,512 - WARNING - Error processing HYMB: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,513 - WARNING - Error processing TIPZ: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,514 - WARNING - Error processing DTINX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,515 - WARNING - Error processing SPVU: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,515 - WARNING - Error processing FSIG: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,516 - WARNING - Error processing THNQ: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,516 - WARNING - Error processing DLHIX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,517 - WARNING - Error processing LSAT: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,517 - WARNING - Error processing APLY: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,518 - WARNING - Error processing AREA: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,518 - WARNING - Error processing OPTZ: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,519 - WARNING - Error processing MNCPX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,520 - WARNING - Error processing HIMYX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,520 - WARNING - Error processing DDFLX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,521 - WARNING - Error processing AGGY: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,521 - WARNING - Error processing USMIX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,522 - WARNING - Error processing SMMU: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,522 - WARNING - Error processing TCVYX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,523 - WARNING - Error processing SELV: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,524 - WARNING - Error processing PJFZX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,525 - WARNING - Error processing IBRN: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,525 - WARNING - Error processing BRMIX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,526 - WARNING - Error processing PIMSX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,527 - WARNING - Error processing THTA: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,528 - WARNING - Error processing PRAPX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,529 - WARNING - Error processing NUSA: A process in the process pool was terminated abruptly while the future was running or pending.
# Processing USA: 100%|██████████| 50/50 [00:00<00:00, 333.08it/s]
# 2025-04-13 19:25:52,536 - WARNING - Sampled 50 funds for Unknown
# Processing Unknown:   0%|          | 0/50 [00:00<?, ?it/s]2025-04-13 19:25:52,715 - WARNING - Error processing GII: A process in the process pool was terminated abruptly while the future was running or pending.
# Processing Unknown:   2%|▏         | 1/50 [00:00<00:05,  9.23it/s]2025-04-13 19:25:52,716 - WARNING - Error processing FMAT: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,717 - WARNING - Error processing IYM: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,718 - WARNING - Error processing MXI: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,718 - WARNING - Error processing COPP: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,718 - WARNING - Error processing PXDIX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,719 - WARNING - Error processing GGINX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,719 - WARNING - Error processing MGNR: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,720 - WARNING - Error processing TOLIX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,721 - WARNING - Error processing ZSL: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,721 - WARNING - Error processing BOIL: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,721 - WARNING - Error processing BLLD: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,722 - WARNING - Error processing FFGIX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,722 - WARNING - Error processing GLIFX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,723 - WARNING - Error processing PYZ: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,724 - WARNING - Error processing FIW: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,724 - WARNING - Error processing URNJ: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,725 - WARNING - Error processing TOLZ: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,725 - WARNING - Error processing PGJZX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,725 - WARNING - Error processing HWAY: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,725 - WARNING - Error processing PNRZX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,726 - WARNING - Error processing IGE: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,726 - WARNING - Error processing OBOR: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,726 - WARNING - Error processing ION: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,727 - WARNING - Error processing COPA: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,727 - WARNING - Error processing SLX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,728 - WARNING - Error processing RSNYX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,728 - WARNING - Error processing NRES: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,729 - WARNING - Error processing UPGR: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,729 - WARNING - Error processing CSUIX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,729 - WARNING - Error processing DLDRX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,730 - WARNING - Error processing FNRAX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,730 - WARNING - Error processing RSBY: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,730 - WARNING - Error processing PSCM: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,730 - WARNING - Error processing GRID: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,731 - WARNING - Error processing NIKL: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,731 - WARNING - Error processing MOO: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,731 - WARNING - Error processing SETM: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,732 - WARNING - Error processing GNR: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,733 - WARNING - Error processing SIMS: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,733 - WARNING - Error processing RNEW: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,734 - WARNING - Error processing SCO: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,734 - WARNING - Error processing RSPM: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,735 - WARNING - Error processing PAVE: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,735 - WARNING - Error processing RSSY: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,736 - WARNING - Error processing EV: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,737 - WARNING - Error processing VEGI: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,739 - WARNING - Error processing XLB: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,739 - WARNING - Error processing BILD: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,739 - WARNING - Error processing UCO: A process in the process pool was terminated abruptly while the future was running or pending.
# Processing Unknown: 100%|██████████| 50/50 [00:00<00:00, 377.68it/s]
# 2025-04-13 19:25:52,742 - WARNING - Sampled 50 funds for International
# Processing International:   0%|          | 0/50 [00:00<?, ?it/s]2025-04-13 19:25:52,951 - WARNING - Error processing KGRN: A process in the process pool was terminated abruptly while the future was running or pending.
# Processing International:   2%|▏         | 1/50 [00:00<00:07,  6.85it/s]2025-04-13 19:25:52,952 - WARNING - Error processing INQQ: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,953 - WARNING - Error processing HLDIX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,953 - WARNING - Error processing FLHK: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,954 - WARNING - Error processing INDH: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,954 - WARNING - Error processing KSTR: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,955 - WARNING - Error processing NDIA: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,955 - WARNING - Error processing EUGDX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,956 - WARNING - Error processing GXC: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,956 - WARNING - Error processing MEDIX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,956 - WARNING - Error processing EMBD: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,957 - WARNING - Error processing INDE: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,958 - WARNING - Error processing ASIYX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,958 - WARNING - Error processing AGEYX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,958 - WARNING - Error processing MCHI: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,958 - WARNING - Error processing AIA: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,959 - WARNING - Error processing APDOX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,959 - WARNING - Error processing FHJMX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,959 - WARNING - Error processing RFEU: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,960 - WARNING - Error processing EMHC: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,960 - WARNING - Error processing FJPIX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,960 - WARNING - Error processing MCH: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,961 - WARNING - Error processing JPXN: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,961 - WARNING - Error processing FEMZX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,961 - WARNING - Error processing HEWJ: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,961 - WARNING - Error processing LCDIX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,963 - WARNING - Error processing EMB: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,963 - WARNING - Error processing PGJ: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,963 - WARNING - Error processing SPEU: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,964 - WARNING - Error processing MAEFX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,964 - WARNING - Error processing EWH: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,965 - WARNING - Error processing VEMY: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,965 - WARNING - Error processing EMTIX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,965 - WARNING - Error processing BEMB: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,966 - WARNING - Error processing EZU: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,966 - WARNING - Error processing FPA: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,966 - WARNING - Error processing FJP: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,967 - WARNING - Error processing FERIX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,967 - WARNING - Error processing CNYA: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,968 - WARNING - Error processing EUDG: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,968 - WARNING - Error processing FLEU: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,970 - WARNING - Error processing IDX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,971 - WARNING - Error processing DGIN: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,971 - WARNING - Error processing EWP: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,973 - WARNING - Error processing JEMB: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,973 - WARNING - Error processing CHIQ: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,974 - WARNING - Error processing PRLAX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,974 - WARNING - Error processing ASHS: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,974 - WARNING - Error processing XEMD: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:25:52,975 - WARNING - Error processing EGIIX: A process in the process pool was terminated abruptly while the future was running or pending.
# Processing International: 100%|██████████| 50/50 [00:00<00:00, 295.14it/s]

# %%
# Version 4.8
import pandas as pd
import numpy as np
import os
import random
import logging
from datetime import timedelta, datetime
from dateutil.relativedelta import relativedelta
from concurrent.futures import ProcessPoolExecutor, ThreadPoolExecutor
from sqlalchemy import create_engine
from tqdm import tqdm
from statsmodels.regression.linear_model import OLS
from statsmodels.tools.tools import add_constant
import statsmodels.api as sm
import time
import pickle

# Section 1: Configuration and Setup
connection_string = (
    "mssql+pyodbc://JULIANS_LAPTOP\\SQLEXPRESS/CWA_Fund_Database"
    "?driver=ODBC+Driver+18+for+SQL+Server"
    "&trusted_connection=yes&TrustServerCertificate=yes"
)
engine = create_engine(connection_string)

RETURN_METRIC = "1 Month Return"
ROLLING_PERIODS = [12, 24, 36, 48, 60]  # in months
DRY_RUN = True
SAMPLE_DRY_RUN = True
SAMPLE_SIZE = 50
CHUNK_SIZE = 5600
BATCH_INSERT_SIZE = 10000
MAX_WORKERS = 20  # Further reduced to avoid crashes
USE_THREADS = False  # Set to True to use ThreadPoolExecutor instead of ProcessPoolExecutor

# Section 2: Helper Functions
def category_to_region(category):
    mapping = {
        "US Equity Large Cap Blend": ("USA", "US Equity Large Cap Blend"),
        "US Equity Large Cap Growth": ("USA", "US Equity Large Cap Growth"),
        "US Equity Large Cap Value": ("USA", "US Equity Large Cap Value"),
        "US Equity Mid Cap": ("USA", "US Equity Mid Cap"),
        "US Equity Small Cap": ("USA", "US Equity Small Cap"),
        "Global Equity Large Cap": ("Global", "Global Equity Large Cap"),
        "Global Equity Mid/Small Cap": ("Global", "Global Equity Mid/Small Cap"),
        "Global Emerging Markets Equity": ("Global", "Global Emerging Markets Equity"),
        "Europe Equity Large Cap": ("International", "Europe Equity Large Cap"),
        "Asia Equity": ("International", "Asia Equity"),
        "Japan Equity": ("International", "Japan Equity"),
        "Emerging Markets Fixed Income": ("International", "Emerging Markets Fixed Income"),
        "US Fixed Income": ("USA", "US Fixed Income"),
        "US Municipal Fixed Income": ("USA", "US Municipal Fixed Income"),
        "Global Fixed Income": ("Global", "Global Fixed Income"),
        "Flexible Allocation": ("Global", "Flexible Allocation"),
        "Aggressive Allocation": ("Global", "Aggressive Allocation"),
        "Moderate Allocation": ("Global", "Moderate Allocation"),
        "Cautious Allocation": ("Global", "Cautious Allocation"),
        "Commodities Broad Basket": ("Global", "Commodities Broad Basket"),
        "Commodities Specified": ("Global", "Commodities Specified"),
        "Options Trading": ("USA", "Options Trading"),
        "Multialternative": ("Global", "Multialternative"),
        "Market Neutral": ("Global", "Market Neutral"),
        "Long/Short Equity": ("Global", "Long/Short Equity"),
        "Alternative Miscellaneous": ("Global", "Alternative Miscellaneous"),
        "Energy Sector Equity": ("USA", "Energy Sector Equity"),
        "Equity Miscellaneous": ("USA", "Equity Miscellaneous"),
        "Financials Sector Equity": ("USA", "Financials Sector Equity"),
        "Healthcare Sector Equity": ("USA", "Healthcare Sector Equity"),
        "Consumer Goods & Services Sector Equity": ("USA", "Consumer Goods & Services Sector Equity"),
        "Communications Sector Equity": ("USA", "Communications Sector Equity"),
        "Industrials Sector Equity": ("USA", "Industrials Sector Equity"),
        "Other Sector Equity": ("USA", "Other Sector Equity"),
        "Real Estate Sector Equity": ("USA", "Real Estate Sector Equity"),
        "Precious Metals Sector Equity": ("USA", "Precious Metals Sector Equity"),
        "Technology Sector Equity": ("USA", "Technology Sector Equity"),
        "Utilities Sector Equity": ("USA", "Utilities Sector Equity"),
        "Asia ex-Japan Equity": ("International", "Asia ex-Japan Equity"),
        "Australia & New Zealand Equity": ("International", "Australia & New Zealand Equity"),
        "Canadian Equity Large Cap": ("International", "Canadian Equity Large Cap"),
        "Europe Equity Mid/Small Cap": ("International", "Europe Equity Mid/Small Cap"),
        "Greater China Equity": ("International", "Greater China Equity"),
        "India Equity": ("International", "India Equity"),
        "Mexico Equity": ("International", "Mexico Equity"),
        "Korea Equity": ("International", "Korea Equity"),
        "Latin America Equity": ("International", "Latin America Equity"),
        "UK Equity Large Cap": ("International", "UK Equity Large Cap"),
        "Thailand Equity": ("International", "Thailand Equity"),
        "Convertibles": ("USA", "Convertibles"),
        "Fixed Income Miscellaneous": ("USA", "Fixed Income Miscellaneous"),
        "Allocation Miscellaneous": ("Global", "Allocation Miscellaneous")
    }
    return mapping.get(category, ("Unknown", "Unknown"))

# Section 3: Data Loading Functions
def load_fund_metadata():
    query = """
    SELECT 
        f.SymbolCUSIP, 
        f.Region, 
        f.YC_Global_Category_ID, 
        c.Global_Category_Name,
        f.YC_Category_ID,
        y.Category_Name,
        f.CWA_Broad_Category_ID,
        b.CWA_Broad_Category_Name
    FROM Funds_to_Screen f
    JOIN YC_Global_Category_List c ON f.YC_Global_Category_ID = c.ID
    JOIN YC_Category_List y ON f.YC_Category_ID = y.ID
    LEFT JOIN CWA_Broad_Category_List b ON f.CWA_Broad_Category_ID = b.ID
    """
    try:
        df = pd.read_sql(query, engine)
        df[["Region", "FactorProfile"]] = df["Global_Category_Name"].map(category_to_region).apply(pd.Series)
        logging.warning(f"Loaded metadata for {len(df)} funds")
        if df["CWA_Broad_Category_Name"].isnull().all():
            logging.warning("CWA_Broad_Category_Name missing for all rows; Equity regressions 5-7 will be skipped")
        return df.dropna(subset=["Region", "FactorProfile"])
    except Exception as e:
        logging.error(f"Error loading metadata: {e}")
        raise

def load_fund_returns(fund_ids):
    placeholders = ",".join([f"'{fid}'" for fid in fund_ids])
    query = f"""
        SELECT SymbolCUSIP, Date, ReturnValue
        FROM Fund_Returns_Timeseries
        WHERE SymbolCUSIP IN ({placeholders})
        AND Metric = '{RETURN_METRIC}'
    """
    df = pd.read_sql(query, engine, parse_dates=["Date"])
    logging.warning(f"Loaded returns for {len(df['SymbolCUSIP'].unique())} funds")
    return df.pivot(index="Date", columns="SymbolCUSIP", values="ReturnValue")

def load_db_factors(factor_list, region="Global", table="factor_returns", asset_class=None):
    factor_in_clause = ','.join([f"'{f}'" for f in factor_list])
    query = f"""
        SELECT date AS Date, factor AS Factor, value AS Value
        FROM {table}
        WHERE factor IN ({factor_in_clause})
    """
    params = ()
    if region and not any(f.startswith('TSM-') or f == 'RF' for f in factor_list):
        query += " AND region = ?"
        params = (region,)
    elif 'RF' in factor_list:
        query += " AND region = 'USA'"
    if asset_class:
        query += " AND asset_class = ?"
        params += (asset_class,)
    df = pd.read_sql(query, engine, params=params, parse_dates=['Date'])
    if df.empty:
        logging.warning(f"No data for factors {factor_list} in {table} (region: {region}, asset_class: {asset_class})")
        return pd.DataFrame()
    
    # Handle duplicates
    duplicates = df.duplicated(subset=['Date', 'Factor']).sum()
    if duplicates > 0:
        logging.warning(f"Found {duplicates} duplicate Date-Factor pairs in {table} for {factor_list}; aggregating by mean")
        df = df.groupby(['Date', 'Factor'])['Value'].mean().reset_index()
    
    pivoted_df = df.pivot(index="Date", columns="Factor", values="Value").rename(
        columns={
            'MKT': 'mkt', 'SMB': 'smb', 'HML_Devil': 'hml', 'UMD': 'umd', 'QMJ': 'qmj',
            'BAB': 'bab', 'RF': 'rf', 'TSM-Com': 'tsm-com', 'TSM-EQ': 'tsm-eq',
            'TSM-FI': 'tsm-fi', 'TSM-FX': 'tsm-fx', 'TSM-MA': 'tsm-ma'
        }
    )
    missing_factors = [f for f in factor_list if f.lower() not in pivoted_df.columns]
    if missing_factors:
        logging.warning(f"Missing factors in {table} (region: {region}): {missing_factors}")
    return pivoted_df

def load_fixed_income_factors(factor_list):
    factor_in_clause = ','.join([f"'{f}'" for f in factor_list])
    query = f"""
        SELECT Date, Factor_Name, ReturnValue
        FROM Fixed_Income_Factor_Returns
        WHERE Factor_Name IN ({factor_in_clause})
    """
    df = pd.read_sql(query, engine, parse_dates=["Date"])
    if df.empty:
        logging.warning(f"No fixed income factors for {factor_list}")
        return pd.DataFrame()
    return df.pivot(index="Date", columns="Factor_Name", values="ReturnValue")

def load_century_factors(factor_list, portfolio_base, factor, asset_class=None, region="Global"):
    factor_in_clause = ','.join([f"'{f}'" for f in factor_list])
    portfolio = f"{portfolio_base} {factor}"
    query = f"""
        SELECT date AS Date, factor AS Factor, value AS Value
        FROM aqr_century_factors
        WHERE factor IN ({factor_in_clause})
        AND portfolio = ?
    """
    params = (portfolio,)
    if asset_class:
        query += " AND asset_class = ?"
        params += (asset_class,)
    if region != "Global":
        query += " AND region = ?"
        params += (region,)
    df = pd.read_sql(query, engine, params=params, parse_dates=['Date'])
    if df.empty:
        logging.warning(f"No data for factors {factor_list} in aqr_century_factors (portfolio: {portfolio}, region: {region})")
        return pd.DataFrame()
    pivoted_df = df.pivot(index="Date", columns="Factor", values="Value")
    return pivoted_df

def load_commodity_factors():
    query = """
        SELECT date AS Date, 
               excess_return_eqwt, 
               excess_spot_return_eqwt, 
               ir_adjusted_carry_eqwt, 
               spot_return_eqwt, 
               carry_eqwt, 
               excess_return_long_short, 
               excess_spot_return_long_short, 
               ir_adjusted_carry_long_short, 
               aggregate_backwardation_contango
        FROM aqr_cmdty_factors
    """
    df = pd.read_sql(query, engine, parse_dates=['Date'])
    if df.empty:
        logging.warning("No commodity factors loaded")
        return pd.DataFrame()
    return df.set_index("Date")

# Section 4: Regression Functions
def run_rolling_regression(fund, returns, factors, regression_type, factor_set):
    results = []
    try:
        returns = pd.Series(returns).dropna()
        factors = pd.DataFrame(factors).dropna()
        returns.index = pd.to_datetime(returns.index, errors='coerce')
        factors.index = pd.to_datetime(factors.index, errors='coerce')
        returns = returns[returns.index.notnull()]
        factors = factors[factors.index.notnull()]
        if returns.empty or factors.empty:
            logging.warning(f"Empty returns or factors for {fund} ({factor_set})")
            return results
        viable_periods = [w for w in ROLLING_PERIODS if (returns.index.max() - relativedelta(months=w)) >= returns.index.min()]
        
        for window in viable_periods:
            start = returns.index.min() + relativedelta(months=window)
            for end_date in returns.loc[returns.index >= start].index:
                start_date = end_date - relativedelta(months=window - 1)
                y = returns.loc[start_date:end_date]
                X = factors.loc[start_date:end_date]
                X, y = X.align(y, join="inner", axis=0)
                if len(y) < window or y.isnull().any() or X.isnull().any().any():
                    continue
                X_const = add_constant(X)
                model = OLS(y, X_const).fit()
                for factor in X.columns:
                    results.append({
                        "SymbolCUSIP": fund,
                        "MonthEndDate": end_date,
                        "RollPeriod": f"{window}m",
                        "Factor_Name": factor,
                        "Coefficient": model.params.get(factor, np.nan),
                        "P_Value": model.pvalues.get(factor, np.nan),
                        "T_Stat": model.tvalues.get(factor, np.nan),
                        "Standard_Error": model.bse.get(factor, np.nan),
                        "CI_Lower": model.conf_int().loc[factor][0] if factor in model.params else np.nan,
                        "CI_Upper": model.conf_int().loc[factor][1] if factor in model.params else np.nan,
                        "Adj_R2": model.rsquared_adj,
                        "Correlation": np.corrcoef(y, model.fittedvalues)[0, 1] if len(y) > 1 else np.nan,
                        "Regression_Type": regression_type,
                        "Factor_Set": factor_set
                    })
    except Exception as e:
        logging.warning(f"Error in run_rolling_regression for {fund} ({factor_set}): {e}")
        return results
    return results

# Section 5: Processing Functions
def process_fund(fund_data):
    """Process regressions for a single fund, returning a list of records."""
    records = []
    symbol = fund_data["SymbolCUSIP"]
    category = fund_data["Global_Category_Name"]
    broad_category = fund_data["CWA_Broad_Category_Name"]
    returns = pd.Series(fund_data["returns"]).dropna()
    
    logging.debug(f"Starting process_fund for {symbol}")
    
    try:
        if returns.empty:
            logging.warning(f"No valid returns for {symbol}")
            return records

        # Equity (USA)
        if category in [
            "Energy Sector Equity", "Equity Miscellaneous", "Financials Sector Equity",
            "Healthcare Sector Equity", "Consumer Goods & Services Sector Equity",
            "Communications Sector Equity", "Industrials Sector Equity", "Other Sector Equity",
            "Real Estate Sector Equity", "Precious Metals Sector Equity", "Technology Sector Equity",
            "Utilities Sector Equity", "US Equity Large Cap Blend", "US Equity Large Cap Growth",
            "US Equity Large Cap Value", "US Equity Mid Cap", "US Equity Small Cap", "Options Trading"
        ]:
            # Regression 1: USA, MKT-RF, HML-Devil, QMJ, SMB, UMD, BAB
            factors_eq = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB'], "USA")
            rf_factors = load_db_factors(['RF'], "USA")
            factors = pd.concat([factors_eq, rf_factors], axis=1).dropna()
            if factors.empty:
                logging.warning(f"No valid factors for {symbol} (Equity_USA_1)")
            else:
                if 'mkt' in factors.columns and 'rf' in factors.columns:
                    factors['mkt-rf'] = factors['mkt'] - factors['rf']
                elif 'mkt' not in factors.columns:
                    logging.warning(f"No market factor for {symbol} (Equity_USA_1)")
                else:
                    factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                    if returns_aligned.empty:
                        logging.warning(f"No overlapping dates for {symbol} (Equity_USA_1)")
                    else:
                        desired_factors = ['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'hml', 'qmj', 'smb', 'umd', 'bab']
                        available_factors = [f for f in desired_factors if f in factors.columns]
                        if available_factors:
                            records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "Equity_USA_1"))
                        else:
                            logging.warning(f"No valid factors for {symbol} (Equity_USA_1)")

            # Regression 2-4: Century Factors
            for portfolio_base, factor_set in [
                ("US Stock Selection", "Equity_USA_2"),
                ("All Macro", "Equity_USA_3"),
                ("Equity indices", "Equity_USA_4")
            ]:
                for factor in ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value']:
                    factors = load_century_factors([factor], portfolio_base, factor, region="USA")
                    if factors.empty:
                        logging.warning(f"No century factors for {symbol} ({factor_set}, factor: {factor})")
                        continue
                    factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                    if returns_aligned.empty:
                        logging.warning(f"No overlapping dates for {symbol} ({factor_set}, factor: {factor})")
                        continue
                    records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", factor_set))

            if broad_category in ["Quantitative/Tactical", "Strategic", "Nontraditional"]:
                # Regression 5
                factors_eq = load_db_factors(['MKT', 'BAB'], "USA")
                factors_fi = load_db_factors(['TSM-FI'])
                factors_fx = load_db_factors(['TSM-FX'])
                rf_factors = load_db_factors(['RF'], "USA")
                fi_factors = load_fixed_income_factors(['TERM', 'CREDIT'])
                cmdty_factors = load_commodity_factors()
                factors = pd.concat([factors_eq, factors_fi, factors_fx, rf_factors, fi_factors, cmdty_factors[['excess_return_eqwt']]], axis=1).dropna()
                if factors.empty:
                    logging.warning(f"No valid factors for {symbol} (Equity_USA_5)")
                else:
                    if 'mkt' in factors.columns and 'rf' in factors.columns:
                        factors['mkt-rf'] = factors['mkt'] - factors['rf']
                    factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                    if returns_aligned.empty:
                        logging.warning(f"No overlapping dates for {symbol} (Equity_USA_5)")
                    else:
                        desired_factors = ['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'tsm-fx', 'tsm-fi', 'bab', 'TERM', 'CREDIT', 'excess_return_eqwt']
                        available_factors = [f for f in desired_factors if f in factors.columns]
                        if available_factors:
                            records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "Equity_USA_5"))

                # Regression 6
                factors_eq = load_db_factors(['MKT', 'SMB', 'BAB'], "USA")
                factors_com = load_db_factors(['TSM-Com'])
                rf_factors = load_db_factors(['RF'], "USA")
                fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT_HY'])
                factors = pd.concat([factors_eq, factors_com, rf_factors, fi_factors], axis=1).dropna()
                if factors.empty:
                    logging.warning(f"No valid factors for {symbol} (Equity_USA_6)")
                else:
                    if 'mkt' in factors.columns and 'rf' in factors.columns:
                        factors['mkt-rf'] = factors['mkt'] - factors['rf']
                    factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                    if returns_aligned.empty:
                        logging.warning(f"No overlapping dates for {symbol} (Equity_USA_6)")
                    else:
                        desired_factors = ['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'smb', 'bab', 'TERM_Int', 'TERM_Long', 'CREDIT_HY', 'tsm-com']
                        available_factors = [f for f in desired_factors if f in factors.columns]
                        if available_factors:
                            records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "Equity_USA_6"))

                # Regression 7
                factors_eq = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'UMD', 'SMB', 'BAB'], "USA")
                factors_com = load_db_factors(['TSM-Com'])
                factors_fi = load_db_factors(['TSM-FI'])
                factors_fx = load_db_factors(['TSM-FX'])
                rf_factors = load_db_factors(['RF'], "USA")
                fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY'])
                factors = pd.concat([factors_eq, factors_com, factors_fi, factors_fx, rf_factors, fi_factors], axis=1).dropna()
                if factors.empty:
                    logging.warning(f"No valid factors for {symbol} (Equity_USA_7)")
                else:
                    if 'mkt' in factors.columns and 'rf' in factors.columns:
                        factors['mkt-rf'] = factors['mkt'] - factors['rf']
                    factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                    if returns_aligned.empty:
                        logging.warning(f"No overlapping dates for {symbol} (Equity_USA_7)")
                    else:
                        desired_factors = ['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'hml', 'qmj', 'umd', 'smb', 'bab', 'TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY', 'tsm-com', 'tsm-fi', 'tsm-fx']
                        available_factors = [f for f in desired_factors if f in factors.columns]
                        if available_factors:
                            records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "Equity_USA_7"))
            else:
                logging.warning(f"Skipping Equity regressions 5-7 for {symbol}: Not Quantitative/Tactical, Strategic, or Nontraditional")

        # Equity (International)
        elif category in [
            "Asia ex-Japan Equity", "Australia & New Zealand Equity", "Canadian Equity Large Cap",
            "Europe Equity Large Cap", "Europe Equity Mid/Small Cap", "Greater China Equity",
            "India Equity", "Mexico Equity", "Japan Equity", "Korea Equity", "Latin America Equity",
            "UK Equity Large Cap", "Thailand Equity"
        ]:
            # Regression 1
            factors_eq = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB'], "Intl")
            rf_factors = load_db_factors(['RF'], "USA")
            factors = pd.concat([factors_eq, rf_factors], axis=1).dropna()
            if factors.empty:
                logging.warning(f"No valid factors for {symbol} (Equity_Intl_1)")
            else:
                if 'mkt' in factors.columns and 'rf' in factors.columns:
                    factors['mkt-rf'] = factors['mkt'] - factors['rf']
                factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                if returns_aligned.empty:
                    logging.warning(f"No overlapping dates for {symbol} (Equity_Intl_1)")
                else:
                    desired_factors = ['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'hml', 'qmj', 'smb', 'umd', 'tsm-eq', 'bab']
                    available_factors = [f for f in desired_factors if f in factors.columns]
                    if available_factors:
                        records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "Equity_Intl_1"))

            # Regression 2-4
            for portfolio_base, factor_set in [
                ("Intl Stock Selection", "Equity_Intl_2"),
                ("All Macro", "Equity_Intl_3"),
                ("Equity indices", "Equity_Intl_4")
            ]:
                for factor in ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value']:
                    factors = load_century_factors([factor], portfolio_base, factor, region="International")
                    if factors.empty:
                        logging.warning(f"No century factors for {symbol} ({factor_set}, factor: {factor})")
                        continue
                    factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                    if returns_aligned.empty:
                        logging.warning(f"No overlapping dates for {symbol} ({factor_set}, factor: {factor})")
                        continue
                    records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", factor_set))

        # Equity (Global)
        elif category in ["Global Emerging Markets Equity", "Global Equity Large Cap", "Global Equity Mid/Small Cap"]:
            # Regression 1
            factors_eq = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB'], "Global")
            rf_factors = load_db_factors(['RF'], "USA")
            factors = pd.concat([factors_eq, rf_factors], axis=1).dropna()
            if factors.empty:
                logging.warning(f"No valid factors for {symbol} (Equity_Global_1)")
            else:
                if 'mkt' in factors.columns and 'rf' in factors.columns:
                    factors['mkt-rf'] = factors['mkt'] - factors['rf']
                factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                if returns_aligned.empty:
                    logging.warning(f"No overlapping dates for {symbol} (Equity_Global_1)")
                else:
                    desired_factors = ['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'hml', 'qmj', 'smb', 'umd', 'tsm-eq', 'bab']
                    available_factors = [f for f in desired_factors if f in factors.columns]
                    if available_factors:
                        records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "Equity_Global_1"))

            # Regression 2-4
            for portfolio_base, factor_set in [
                ("All Stock Selection", "Equity_Global_2"),
                ("All Macro", "Equity_Global_3"),
                ("Equity indices", "Equity_Global_4")
            ]:
                for factor in ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value']:
                    factors = load_century_factors([factor], portfolio_base, factor)
                    if factors.empty:
                        logging.warning(f"No century factors for {symbol} ({factor_set}, factor: {factor})")
                        continue
                    factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                    if returns_aligned.empty:
                        logging.warning(f"No overlapping dates for {symbol} ({factor_set}, factor: {factor})")
                        continue
                    records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", factor_set))

        # Fixed Income
        elif category in [
            "Convertibles", "Emerging Markets Fixed Income", "Fixed Income Miscellaneous",
            "US Fixed Income", "US Municipal Fixed Income"
        ]:
            # Regression 1
            factors_fi = load_db_factors(['TSM-FI'])
            factors_fx = load_db_factors(['TSM-FX'])
            fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY'])
            factors = pd.concat([factors_fi, factors_fx, fi_factors], axis=1).dropna()
            if factors.empty:
                logging.warning(f"No valid factors for {symbol} (FI_1)")
            else:
                factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                if returns_aligned.empty:
                    logging.warning(f"No overlapping dates for {symbol} (FI_1)")
                else:
                    desired_factors = ['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY', 'tsm-fi', 'tsm-fx']
                    available_factors = [f for f in desired_factors if f in factors.columns]
                    if available_factors:
                        records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "FI_1"))

            # Regression 2-4
            for portfolio_base, factor_set in [
                ("Fixed income", "FI_2"),
                ("All Macro", "FI_3"),
                ("Equity indices", "FI_4")
            ]:
                for factor in ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value']:
                    factors = load_century_factors([factor], portfolio_base, factor)
                    if factors.empty:
                        logging.warning(f"No century factors for {symbol} ({factor_set}, factor: {factor})")
                        continue
                    factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                    if returns_aligned.empty:
                        logging.warning(f"No overlapping dates for {symbol} ({factor_set}, factor: {factor})")
                        continue
                    records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", factor_set))

        # Allocation
        elif category in [
            "Aggressive Allocation", "Allocation Miscellaneous", "Cautious Allocation",
            "Flexible Allocation", "Moderate Allocation"
        ]:
            # Regression 1
            factors_eq = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ'], "Global")
            factors_fi = load_db_factors(['TSM-FI'])
            rf_factors = load_db_factors(['RF'], "USA")
            fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY'])
            factors = pd.concat([factors_eq, factors_fi, rf_factors, fi_factors], axis=1).dropna()
            if factors.empty:
                logging.warning(f"No valid factors for {symbol} (Allocation_1)")
            else:
                if 'mkt' in factors.columns and 'rf' in factors.columns:
                    factors['mkt-rf'] = factors['mkt'] - factors['rf']
                factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                if returns_aligned.empty:
                    logging.warning(f"No overlapping dates for {symbol} (Allocation_1)")
                else:
                    desired_factors = ['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'hml', 'qmj', 'smb', 'umd', 'bab', 'tsm-eq', 'tsm-fi', 'TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY']
                    available_factors = [f for f in desired_factors if f in factors.columns]
                    if available_factors:
                        records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "Allocation_1"))

            # Regression 2
            for factor in ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value']:
                fi_factors = load_century_factors([factor], "Fixed income", factor)
                stock_factors = load_century_factors([factor], "All Stock Selection", factor)
                factors = pd.concat([fi_factors, stock_factors], axis=1).dropna()
                if factors.empty:
                    logging.warning(f"No valid factors for {symbol} (Allocation_2, factor: {factor})")
                    continue
                factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                if returns_aligned.empty:
                    logging.warning(f"No overlapping dates for {symbol} (Allocation_2, factor: {factor})")
                    continue
                records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", "Allocation_2"))

            # Regression 3-4
            for portfolio_base, factor_set in [
                ("All Macro", "Allocation_3"),
                ("Equity indices", "Allocation_4")
            ]:
                for factor in ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value']:
                    factors = load_century_factors([factor], portfolio_base, factor)
                    if factors.empty:
                        logging.warning(f"No century factors for {symbol} ({factor_set}, factor: {factor})")
                        continue
                    factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                    if returns_aligned.empty:
                        logging.warning(f"No overlapping dates for {symbol} ({factor_set}, factor: {factor})")
                        continue
                    records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", factor_set))

        # Alternatives
        elif category in [
            "Alternative Miscellaneous", "Long/Short Equity", "Market Neutral", "Multialternative"
        ]:
            # Regression 1
            factors_eq = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ'], "Global")
            factors_com = load_db_factors(['TSM-Com'])
            factors_fi = load_db_factors(['TSM-FI'])
            factors_fx = load_db_factors(['TSM-FX'])
            rf_factors = load_db_factors(['RF'], "USA")
            fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY'])
            factors = pd.concat([factors_eq, factors_com, factors_fi, factors_fx, rf_factors, fi_factors], axis=1).dropna()
            if factors.empty:
                logging.warning(f"No valid factors for {symbol} (Alternative_1)")
            else:
                if 'mkt' in factors.columns and 'rf' in factors.columns:
                    factors['mkt-rf'] = factors['mkt'] - factors['rf']
                factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                if returns_aligned.empty:
                    logging.warning(f"No overlapping dates for {symbol} (Alternative_1)")
                else:
                    desired_factors = ['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'hml', 'qmj', 'smb', 'umd', 'bab', 'tsm-eq', 'tsm-fi', 'TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY', 'tsm-com', 'tsm-fx']
                    available_factors = [f for f in desired_factors if f in factors.columns]
                    if available_factors:
                        records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "Alternative_1"))

            # Regression 2
            for factor in ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value']:
                fi_factors = load_century_factors([factor], "Fixed income", factor)
                stock_factors = load_century_factors([factor], "All Stock Selection", factor)
                cmdty_factors = load_century_factors([factor], "Commodities", factor)
                factors = pd.concat([fi_factors, stock_factors, cmdty_factors], axis=1).dropna()
                if factors.empty:
                    logging.warning(f"No valid factors for {symbol} (Alternative_2, factor: {factor})")
                    continue
                factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                if returns_aligned.empty:
                    logging.warning(f"No overlapping dates for {symbol} (Alternative_2, factor: {factor})")
                    continue
                records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", "Alternative_2"))

            # Regression 3-4
            for portfolio_base, factor_set in [
                ("All Macro", "Alternative_3"),
                ("Equity indices", "Alternative_4")
            ]:
                for factor in ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value']:
                    factors = load_century_factors([factor], portfolio_base, factor)
                    if factors.empty:
                        logging.warning(f"No century factors for {symbol} ({factor_set}, factor: {factor})")
                        continue
                    factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                    if returns_aligned.empty:
                        logging.warning(f"No overlapping dates for {symbol} ({factor_set}, factor: {factor})")
                        continue
                    records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", factor_set))

        # Commodities
        elif category in ["Commodities Broad Basket", "Commodities Specified"]:
            # Regression 1
            factors = load_commodity_factors()
            if factors.empty:
                logging.warning(f"No commodity factors for {symbol} (Commodity_1)")
            else:
                factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                if returns_aligned.empty:
                    logging.warning(f"No overlapping dates for {symbol} (Commodity_1)")
                else:
                    records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", "Commodity_1"))

    except Exception as e:
        logging.warning(f"Error processing fund {symbol}: {e}")
        return records
    
    logging.debug(f"Completed process_fund for {symbol} with {len(records)} records")
    return records

def process_region(region, fund_data_list):
    records = []
    logging.warning(f"Processing {len(fund_data_list)} funds in {region}")
    
    executor_class = ThreadPoolExecutor if USE_THREADS else ProcessPoolExecutor
    with executor_class(max_workers=MAX_WORKERS) as executor:
        future_to_fund = {executor.submit(process_fund, fund_data): fund_data["SymbolCUSIP"] for fund_data in fund_data_list}
        for future in tqdm(future_to_fund, total=len(fund_data_list), desc=f"Processing {region}"):
            try:
                records.extend(future.result())
            except Exception as e:
                logging.warning(f"Error processing {future_to_fund[future]}: {e}")

    if records:
        if not DRY_RUN:
            insert_batch(records)
        else:
            logging.warning(f"Dry run: Would have written {len(records)} records for {region}")

# Section 6: Main Pipeline
def main():
    logging.basicConfig(level=logging.WARNING, format='%(asctime)s - %(levelname)s - %(message)s')
    
    fund_meta = load_fund_metadata()
    regions = fund_meta["Region"].unique()
    logging.warning(f"Total mapped funds: {len(fund_meta)}")
    logging.warning(f"Regions detected: {regions}")
    
    fund_ids = fund_meta["SymbolCUSIP"].tolist()
    if SAMPLE_DRY_RUN:
        fund_ids = random.sample(fund_ids, min(SAMPLE_SIZE, len(fund_ids)))
    returns = load_fund_returns(fund_ids)
    
    # Validate returns
    for col in returns.columns:
        if not pd.api.types.is_numeric_dtype(returns[col]):
            logging.warning(f"Non-numeric returns for {col}; converting to numeric")
            returns[col] = pd.to_numeric(returns[col], errors='coerce')
    
    # Prepare fund data
    fund_data_list = []
    for _, row in fund_meta.iterrows():
        symbol = row["SymbolCUSIP"]
        if symbol in returns.columns:
            fund_data_list.append({
                "SymbolCUSIP": symbol,
                "Global_Category_Name": row["Global_Category_Name"],
                "CWA_Broad_Category_Name": row.get("CWA_Broad_Category_Name", None),
                "returns": returns[symbol].to_dict()
            })
    
    for region in regions:
        region_funds = [fd for fd in fund_data_list if fund_meta[fund_meta["SymbolCUSIP"] == fd["SymbolCUSIP"]]["Region"].iloc[0] == region]
        if SAMPLE_DRY_RUN and len(region_funds) > SAMPLE_SIZE:
            region_funds = random.sample(region_funds, SAMPLE_SIZE)
            logging.warning(f"Sampled {len(region_funds)} funds for {region}")
        process_region(region, region_funds)

# Section 7: Database Output
def insert_batch(records):
    try:
        df = pd.DataFrame(records)
        if not DRY_RUN:
            for i in range(0, len(df), BATCH_INSERT_SIZE):
                batch = df.iloc[i:i + BATCH_INSERT_SIZE]
                batch.to_sql("AQRR_Factor_Attribution", engine, if_exists="append", index=False)
        else:
            logging.warning(f"Dry run: Skipped writing {len(df)} records")
    except Exception as e:
        logging.error(f"Error inserting batch: {e}")

if __name__ == "__main__":
    try:
        main()
    except Exception as e:
        logging.error(f"Main execution failed: {e}")
        raise
# Out:
# 2025-04-13 19:42:10,265 - WARNING - Loaded metadata for 5584 funds
# 2025-04-13 19:42:10,268 - WARNING - Total mapped funds: 5584
# 2025-04-13 19:42:10,269 - WARNING - Regions detected: ['Global' 'USA' 'Unknown' 'International']
# 2025-04-13 19:42:10,327 - WARNING - Loaded returns for 50 funds
# 2025-04-13 19:42:10,484 - WARNING - Processing 12 funds in Global
# Processing Global:   0%|          | 0/12 [00:00<?, ?it/s]2025-04-13 19:42:10,710 - WARNING - Error processing CVIE: A process in the process pool was terminated abruptly while the future was running or pending.
# Processing Global:   8%|▊         | 1/12 [00:00<00:01,  7.13it/s]2025-04-13 19:42:10,711 - WARNING - Error processing KLMT: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:42:10,712 - WARNING - Error processing MFAIX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:42:10,712 - WARNING - Error processing RULE: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:42:10,713 - WARNING - Error processing OAEM: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:42:10,714 - WARNING - Error processing AVDV: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:42:10,714 - WARNING - Error processing EIRAX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:42:10,715 - WARNING - Error processing LMGIX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:42:10,715 - WARNING - Error processing NWWJX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:42:10,716 - WARNING - Error processing TSALX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:42:10,716 - WARNING - Error processing EIISX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 19:42:10,717 - WARNING - Error processing PAUPX: A process in the process pool was terminated abruptly while the future was running or pending.
# Processing Global: 100%|██████████| 12/12 [00:00<00:00, 81.74it/s]

# %%
#supergrok try

# %%
import pandas as pd
import numpy as np
import os
import random
import logging
from datetime import timedelta, datetime
from dateutil.relativedelta import relativedelta
from concurrent.futures import ProcessPoolExecutor, ThreadPoolExecutor
from sqlalchemy import create_engine, text
from tqdm import tqdm
from statsmodels.regression.linear_model import OLS
from statsmodels.tools.tools import add_constant
import statsmodels.api as sm
import time
import pickle
import json
import uuid
import psutil
import functools
import warnings
from contextlib import contextmanager

# Section 1: Configuration and Setup
with open("config.json", "r") as f:
    CONFIG = json.load(f)

DATABASE_CONFIG = CONFIG.get("database", {})
CONNECTION_STRING = (
    f"mssql+pyodbc://{DATABASE_CONFIG.get('server')}/{DATABASE_CONFIG.get('database')}"
    f"?driver={DATABASE_CONFIG.get('driver')}&trusted_connection=yes&TrustServerCertificate=yes"
)
engine = create_engine(CONNECTION_STRING)

RETURN_METRIC = CONFIG.get("return_metric", "1 Month Return")
ROLLING_PERIODS = CONFIG.get("rolling_periods", [12, 24, 36, 48, 60])  # in months
DRY_RUN = CONFIG.get("dry_run", True)
SAMPLE_DRY_RUN = CONFIG.get("sample_dry_run", True)
SAMPLE_SIZE = CONFIG.get("sample_size", 50)
CHUNK_SIZE = CONFIG.get("chunk_size", 5600)
BATCH_INSERT_SIZE = CONFIG.get("batch_insert_size", 10000)
MAX_WORKERS = min(CONFIG.get("max_workers", 16), psutil.cpu_count(logical=False))
USE_THREADS = CONFIG.get("use_threads", False)
MIN_OBSERVATIONS = CONFIG.get("min_observations", 0.8)  # Minimum fraction of expected data points

# Load category mappings
with open("category_mapping.json", "r") as f:
    CATEGORY_MAPPING = json.load(f)

# Factor configurations for different regressions
FACTOR_CONFIGS = {
    "Equity_USA_1": [
        {"source": "db", "factors": ["MKT", "HML_Devil", "QMJ", "SMB", "UMD", "BAB"], "region": "USA"},
        {"source": "db", "factors": ["RF"], "region": "USA"}
    ],
    "Equity_USA_2": [
        {"source": "century", "factors": ["Carry", "Defensive", "Market", "Momentum", "Multi-Style", "Value"],
         "portfolio_base": "US Stock Selection", "region": "USA"}
    ],
    # Add other configurations similarly
}

# Logging setup
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler("factor_attribution.log"),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger()

# Section 2: Helper Functions
def category_to_region(category):
    return CATEGORY_MAPPING.get(category, ("Unknown", "Unknown"))

@contextmanager
def database_transaction():
    """Context manager for database transactions."""
    connection = engine.connect()
    transaction = connection.begin()
    try:
        yield connection
        transaction.commit()
    except Exception as e:
        transaction.rollback()
        logger.error(f"Transaction failed: {e}")
        raise
    finally:
        connection.close()

def timer(func):
    """Decorator to log execution time of functions."""
    @functools.wraps(func)
    def wrapper(*args, **kwargs):
        start_time = time.time()
        result = func(*args, **kwargs)
        logger.info(f"{func.__name__} took {time.time() - start_time:.2f} seconds")
        return result
    return wrapper

# Section 3: Data Loading Functions
@timer
def load_fund_metadata():
    query = """
    SELECT 
        f.SymbolCUSIP, 
        f.Region, 
        f.YC_Global_Category_ID, 
        c.Global_Category_Name,
        f.YC_Category_ID,
        y.Category_Name,
        f.CWA_Broad_Category_ID,
        b.CWA_Broad_Category_Name
    FROM Funds_to_Screen f
    JOIN YC_Global_Category_List c ON f.YC_Global_Category_ID = c.ID
    JOIN YC_Category_List y ON f.YC_Category_ID = y.ID
    LEFT JOIN CWA_Broad_Category_List b ON f.CWA_Broad_Category_ID = b.ID
    """
    try:
        df = pd.read_sql(query, engine)
        df[["Region", "FactorProfile"]] = df["Global_Category_Name"].map(category_to_region).apply(pd.Series)
        logger.info(f"Loaded metadata for {len(df)} funds")
        if df["CWA_Broad_Category_Name"].isnull().all():
            logger.warning("CWA_Broad_Category_Name missing for all rows; Equity regressions 5-7 will be skipped")
        return df.dropna(subset=["Region", "FactorProfile"])
    except Exception as e:
        logger.error(f"Error loading metadata: {e}")
        raise

@timer
def load_fund_returns(fund_ids=None):
    query = """
    SELECT SymbolCUSIP, Date, ReturnValue
    FROM Fund_Returns_Timeseries
    WHERE Metric = :metric
    """
    params = {"metric": RETURN_METRIC}
    if fund_ids:
        query += " AND SymbolCUSIP IN :fund_ids"
        params["fund_ids"] = tuple(fund_ids)
    try:
        df = pd.read_sql(text(query), engine, params=params, parse_dates=["Date"])
        logger.info(f"Loaded returns for {len(df['SymbolCUSIP'].unique())} funds")
        pivoted = df.pivot(index="Date", columns="SymbolCUSIP", values="ReturnValue")
        # Validate numeric data
        for col in pivoted.columns:
            if not pd.api.types.is_numeric_dtype(pivoted[col]):
                logger.warning(f"Non-numeric returns for {col}; converting to numeric")
                pivoted[col] = pd.to_numeric(pivoted[col], errors='coerce')
        return pivoted
    except Exception as e:
        logger.error(f"Error loading returns: {e}")
        raise

@timer
def load_factors(factor_config, region="Global", asset_class=None):
    """
    Load factors from various sources.
    """
    source = factor_config.get("source")
    try:
        if source == "db":
            factor_in_clause = ','.join([f"'{f}'" for f in factor_config["factors"]])
            query = f"""
            SELECT date AS Date, factor AS Factor, value AS Value
            FROM {factor_config.get('table', 'factor_returns')}
            WHERE factor IN ({factor_in_clause})
            """
            params = []
            if region and not any(f.startswith('TSM-') or f == 'RF' for f in factor_config["factors"]):
                query += " AND region = ?"
                params.append(region)
            elif 'RF' in factor_config["factors"]:
                query += " AND region = 'USA'"
            if asset_class:
                query += " AND asset_class = ?"
                params.append(asset_class)
            df = pd.read_sql(query, engine, params=params, parse_dates=['Date'])
            if df.empty:
                logger.warning(f"No data for factors {factor_config['factors']} (region: {region})")
                return pd.DataFrame()
            
            if df.duplicated(subset=['Date', 'Factor']).sum() > 0:
                logger.error(f"Duplicate Date-Factor pairs in {factor_config['factors']}; please clean data")
                raise ValueError("Duplicate factor data detected")
            
            pivoted_df = df.pivot(index="Date", columns="Factor", values="Value").rename(
                columns={
                    'MKT': 'mkt', 'SMB': 'smb', 'HML_Devil': 'hml', 'UMD': 'umd', 'QMJ': 'qmj',
                    'BAB': 'bab', 'RF': 'rf', 'TSM-Com': 'tsm-com', 'TSM-EQ': 'tsm-eq',
                    'TSM-FI': 'tsm-fi', 'TSM-FX': 'tsm-fx', 'TSM-MA': 'tsm-ma'
                }
            )
            return pivoted_df

        elif source == "century":
            factor_in_clause = ','.join([f"'{f}'" for f in factor_config["factors"]])
            portfolio = f"{factor_config['portfolio_base']} {factor_config['factor']}"
            query = f"""
            SELECT date AS Date, factor AS Factor, value AS Value
            FROM aqr_century_factors
            WHERE factor IN ({factor_in_clause})
            AND portfolio = ?
            """
            params = [portfolio]
            if asset_class:
                query += " AND asset_class = ?"
                params.append(asset_class)
            if region != "Global":
                query += " AND region = ?"
                params.append(region)
            df = pd.read_sql(query, engine, params=params, parse_dates=['Date'])
            if df.empty:
                logger.warning(f"No data for century factors {factor_config['factors']} (portfolio: {portfolio})")
                return pd.DataFrame()
            return df.pivot(index="Date", columns="Factor", values="Value")

        elif source == "commodity":
            query = """
            SELECT date AS Date, 
                   excess_return_eqwt, 
                   excess_spot_return_eqwt, 
                   ir_adjusted_carry_eqwt, 
                   spot_return_eqwt, 
                   carry_eqwt, 
                   excess_return_long_short, 
                   excess_spot_return_long_short, 
                   ir_adjusted_carry_long_short, 
                   aggregate_backwardation_contango
            FROM aqr_cmdty_factors
            """
            df = pd.read_sql(query, engine, parse_dates=['Date'])
            if df.empty:
                logger.warning("No commodity factors loaded")
                return pd.DataFrame()
            return df.set_index("Date")

        elif source == "fixed_income":
            factor_in_clause = ','.join([f"'{f}'" for f in factor_config["factors"]])
            query = f"""
            SELECT Date, Factor_Name, ReturnValue
            FROM Fixed_Income_Factor_Returns
            WHERE Factor_Name IN ({factor_in_clause})
            """
            df = pd.read_sql(query, engine, parse_dates=["Date"])
            if df.empty:
                logger.warning(f"No fixed income factors for {factor_config['factors']}")
                return pd.DataFrame()
            return df.pivot(index="Date", columns="Factor_Name", values="ReturnValue")

        else:
            logger.error(f"Unknown factor source: {source}")
            return pd.DataFrame()
    except Exception as e:
        logger.error(f"Error loading factors {factor_config.get('factors', [])}: {e}")
        raise

# Section 4: Regression Functions
def run_rolling_regression(fund, returns, factors, regression_type, factor_set, min_observations=MIN_OBSERVATIONS):
    results = []
    try:
        returns = pd.Series(returns).dropna()
        factors = pd.DataFrame(factors).dropna()
        returns.index = pd.to_datetime(returns.index, errors='coerce')
        factors.index = pd.to_datetime(factors.index, errors='coerce')
        returns = returns[returns.index.notnull()]
        factors = factors[factors.index.notnull()]
        
        if returns.empty or factors.empty:
            logger.warning(f"Empty returns or factors for {fund} ({factor_set})")
            return results
        
        viable_periods = [w for w in ROLLING_PERIODS if (returns.index.max() - relativedelta(months=w)) >= returns.index.min()]
        
        for window in viable_periods:
            min_obs = int(window * min_observations)
            start = returns.index.min() + relativedelta(months=window)
            rolling_windows = returns.loc[returns.index >= start].rolling(window=f"{window}M", min_periods=min_obs)
            
            for end_date, y in rolling_windows:
                if y.index[0] < returns.index.min():
                    continue
                X = factors.loc[y.index]
                X, y = X.align(y, join="inner", axis=0)
                if len(y) < min_obs or y.isnull().any() or X.isnull().any().any():
                    continue
                X_const = add_constant(X)
                model = OLS(y, X_const).fit()
                for factor in X.columns:
                    results.append({
                        "SymbolCUSIP": fund,
                        "MonthEndDate": end_date,
                        "RollPeriod": f"{window}m",
                        "Factor_Name": factor,
                        "Coefficient": model.params.get(factor, np.nan),
                        "P_Value": model.pvalues.get(factor, np.nan),
                        "T_Stat": model.tvalues.get(factor, np.nan),
                        "Standard_Error": model.bse.get(factor, np.nan),
                        "CI_Lower": model.conf_int().loc[factor][0] if factor in model.params else np.nan,
                        "CI_Upper": model.conf_int().loc[factor][1] if factor in model.params else np.nan,
                        "Adj_R2": model.rsquared_adj,
                        "Correlation": np.corrcoef(y, model.fittedvalues)[0, 1] if len(y) > 1 else np.nan,
                        "Regression_Type": regression_type,
                        "Factor_Set": factor_set
                    })
    except Exception as e:
        logger.error(f"Error in regression for {fund} ({factor_set}): {e}")
        return results
    return results

# Section 5: Processing Functions
def process_regression(symbol, returns, category, broad_category, factor_set_key):
    records = []
    factor_configs = FACTOR_CONFIGS.get(factor_set_key, [])
    
    if not factor_configs:
        logger.warning(f"No factor configuration for {factor_set_key}")
        return records
    
    try:
        factors_list = []
        for config in factor_configs:
            factors = load_factors(config, region=config.get("region", "Global"), asset_class=config.get("asset_class"))
            if factors.empty:
                logger.warning(f"No factors loaded for {symbol} ({factor_set_key})")
                continue
            factors_list.append(factors)
        
        if not factors_list:
            return records
        
        factors = pd.concat(factors_list, axis=1).dropna()
        if 'mkt' in factors.columns and 'rf' in factors.columns:
            factors['mkt-rf'] = factors['mkt'] - factors['rf']
        
        factors, returns_aligned = factors.align(returns, join="inner", axis=0)
        if returns_aligned.empty:
            logger.warning(f"No overlapping dates for {symbol} ({factor_set_key})")
            return records
        
        desired_factors = factor_configs[0].get("desired_factors", factors.columns.tolist())
        available_factors = [f for f in desired_factors if f in factors.columns]
        if not available_factors:
            logger.warning(f"No valid factors for {symbol} ({factor_set_key})")
            return records
        
        records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", factor_set_key))
    except Exception as e:
        logger.error(f"Error processing {symbol} ({factor_set_key}): {e}")
    
    return records

def process_fund(fund_data):
    records = []
    symbol = fund_data["SymbolCUSIP"]
    category = fund_data["Global_Category_Name"]
    broad_category = fund_data.get("CWA_Broad_Category_Name")
    returns = pd.Series(fund_data["returns"]).dropna()
    
    logger.debug(f"Processing fund {symbol}")
    
    if returns.empty:
        logger.warning(f"No valid returns for {symbol}")
        return records
    
    # Define regression sets based on category
    regression_sets = []
    if category in [
        "Energy Sector Equity", "Equity Miscellaneous", "Financials Sector Equity",
        "Healthcare Sector Equity", "Consumer Goods & Services Sector Equity",
        "Communications Sector Equity", "Industrials Sector Equity", "Other Sector Equity",
        "Real Estate Sector Equity", "Precious Metals Sector Equity", "Technology Sector Equity",
        "Utilities Sector Equity", "US Equity Large Cap Blend", "US Equity Large Cap Growth",
        "US Equity Large Cap Value", "US Equity Mid Cap", "US Equity Small Cap", "Options Trading"
    ]:
        regression_sets.extend(["Equity_USA_1", "Equity_USA_2", "Equity_USA_3", "Equity_USA_4"])
        if broad_category in ["Quantitative/Tactical", "Strategic", "Nontraditional"]:
            regression_sets.extend(["Equity_USA_5", "Equity_USA_6", "Equity_USA_7"])
    
    # Add similar logic for other categories (International, Global, Fixed Income, etc.)
    
    for factor_set in regression_sets:
        records.extend(process_regression(symbol, returns, category, broad_category, factor_set))
    
    logger.debug(f"Completed {symbol} with {len(records)} records")
    return records

def process_region(region, fund_data_list):
    records = []
    logger.info(f"Processing {len(fund_data_list)} funds in {region}")
    
    executor_class = ThreadPoolExecutor if USE_THREADS else ProcessPoolExecutor
    with executor_class(max_workers=MAX_WORKERS) as executor:
        future_to_fund = {executor.submit(process_fund, fund_data): fund_data["SymbolCUSIP"] for fund_data in fund_data_list}
        for future in tqdm(future_to_fund, total=len(fund_data_list), desc=f"Processing {region}"):
            try:
                records.extend(future.result())
            except Exception as e:
                logger.error(f"Error processing {future_to_fund[future]}: {e}")
    
    if records:
        if not DRY_RUN:
            insert_batch(records)
        else:
            pd.DataFrame(records).to_csv(f"dry_run_{region}_{uuid.uuid4()}.csv", index=False)
            logger.info(f"Dry run: Saved {len(records)} records for {region} to CSV")
    
    return records

# Section 6: Main Pipeline
@timer
def main():
    fund_meta = load_fund_metadata()
    regions = fund_meta["Region"].unique()
    logger.info(f"Total mapped funds: {len(fund_meta)}")
    logger.info(f"Regions detected: {regions}")
    
    fund_ids = fund_meta["SymbolCUSIP"].tolist()
    if SAMPLE_DRY_RUN:
        fund_ids = random.sample(fund_ids, min(SAMPLE_SIZE, len(fund_ids)))
        logger.info(f"Sampled {len(fund_ids)} funds for dry run")
    
    returns = load_fund_returns(fund_ids)
    
    fund_data_list = [
        {
            "SymbolCUSIP": row["SymbolCUSIP"],
            "Global_Category_Name": row["Global_Category_Name"],
            "CWA_Broad_Category_Name": row.get("CWA_Broad_Category_Name"),
            "returns": returns[row["SymbolCUSIP"]].to_dict()
        }
        for _, row in fund_meta.iterrows() if row["SymbolCUSIP"] in returns.columns
    ]
    
    summary = {"total_funds": len(fund_data_list), "regions": {}, "errors": 0}
    for region in regions:
        region_funds = [fd for fd in fund_data_list if fund_meta[fund_meta["SymbolCUSIP"] == fd["SymbolCUSIP"]]["Region"].iloc[0] == region]
        if SAMPLE_DRY_RUN and len(region_funds) > SAMPLE_SIZE:
            region_funds = random.sample(region_funds, SAMPLE_SIZE)
            logger.info(f"Sampled {len(region_funds)} funds for {region}")
        records = process_region(region, region_funds)
        summary["regions"][region] = {"funds_processed": len(region_funds), "records": len(records)}
    
    logger.info(f"Pipeline summary: {summary}")
    return summary

# Section 7: Database Output
def insert_batch(records):
    try:
        df = pd.DataFrame(records)
        with database_transaction() as connection:
            df.to_sql("AQRR_Factor_Attribution", connection, if_exists="append", index=False, method="multi")
        logger.info(f"Inserted {len(df)} records")
    except Exception as e:
        logger.error(f"Error inserting batch: {e}")
        raise

if __name__ == "__main__":
    try:
        main()
    except Exception as e:
        logger.error(f"Main execution failed: {e}")
        raise

# %%
import pandas as pd
import numpy as np
import os
import random
import logging
from datetime import timedelta, datetime
from dateutil.relativedelta import relativedelta
from concurrent.futures import ThreadPoolExecutor
from sqlalchemy import create_engine, text
from sqlalchemy.exc import OperationalError
from tqdm import tqdm
from statsmodels.regression.linear_model import OLS
from statsmodels.tools.tools import add_constant
import statsmodels.api as sm
import time
import json
import uuid
import psutil
import functools
from contextlib import contextmanager
import sys

# Section 1: Configuration and Setup
CONFIG = {
    "database": {
        "server": "JULIANS_LAPTOP\\SQLEXPRESS",
        "database": "CWA_Fund_Database",
        "driver": "ODBC Driver 18 for SQL Server"
    },
    "return_metric": "1 Month Return",
    "rolling_periods": [12],
    "dry_run": True,
    "sample_dry_run": True,
    "sample_size": 10,
    "chunk_size": 1000,
    "batch_insert_size": 5000,
    "max_workers": 8,
    "use_threads": True,
    "min_observations": 0.8,
    "query_timeout": 30
}

CONNECTION_STRING = (
    f"mssql+pyodbc://{CONFIG['database']['server']}/{CONFIG['database']['database']}"
    f"?driver={CONFIG['database']['driver']}&trusted_connection=yes&TrustServerCertificate=yes"
)
try:
    engine = create_engine(CONNECTION_STRING, connect_args={"timeout": CONFIG["query_timeout"]})
except Exception as e:
    print(f"Database connection failed: {e}")
    raise

RETURN_METRIC = CONFIG["return_metric"]
ROLLING_PERIODS = CONFIG["rolling_periods"]
DRY_RUN = CONFIG["dry_run"]
SAMPLE_DRY_RUN = CONFIG["sample_dry_run"]
SAMPLE_SIZE = CONFIG["sample_size"]
CHUNK_SIZE = CONFIG["chunk_size"]
BATCH_INSERT_SIZE = CONFIG["batch_insert_size"]
MAX_WORKERS = min(CONFIG["max_workers"], psutil.cpu_count(logical=False))
USE_THREADS = CONFIG["use_threads"]
MIN_OBSERVATIONS = CONFIG["min_observations"]

# Simplified factor configuration for testing
FACTOR_CONFIGS = {
    "Equity_USA_1": [
        {"source": "db", "factors": ["MKT", "RF"], "region": "USA", "desired_factors": ["mkt-rf"]}
    ]
}

# Logging setup with immediate flushing
logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler("factor_attribution.log"),
        logging.StreamHandler(sys.stdout)
    ],
    force=True
)
logger = logging.getLogger()
logger.handlers[1].stream = sys.stdout  # Ensure console output
logger.handlers[1].setLevel(logging.INFO)  # Less verbose console

# Section 2: Helper Functions
def category_to_region(category):
    mapping = {
        "US Equity Large Cap Blend": ("USA", "US Equity Large Cap Blend"),
        "US Equity Large Cap Growth": ("USA", "US Equity Large Cap Growth"),
        "US Equity Large Cap Value": ("USA", "US Equity Large Cap Value"),
        "US Equity Mid Cap": ("USA", "US Equity Mid Cap"),
        "US Equity Small Cap": ("USA", "US Equity Small Cap"),
        "Global Equity Large Cap": ("Global", "Global Equity Large Cap"),
        "Global Equity Mid/Small Cap": ("Global", "Global Equity Mid/Small Cap"),
        "Global Emerging Markets Equity": ("Global", "Global Emerging Markets Equity"),
        "Europe Equity Large Cap": ("International", "Europe Equity Large Cap"),
        "Asia Equity": ("International", "Asia Equity"),
        "Japan Equity": ("International", "Japan Equity"),
        "Emerging Markets Fixed Income": ("International", "Emerging Markets Fixed Income"),
        "US Fixed Income": ("USA", "US Fixed Income"),
        "US Municipal Fixed Income": ("USA", "US Municipal Fixed Income"),
        "Global Fixed Income": ("Global", "Global Fixed Income"),
        "Flexible Allocation": ("Global", "Flexible Allocation"),
        "Aggressive Allocation": ("Global", "Aggressive Allocation"),
        "Moderate Allocation": ("Global", "Moderate Allocation"),
        "Cautious Allocation": ("Global", "Cautious Allocation"),
        "Commodities Broad Basket": ("Global", "Commodities Broad Basket"),
        "Commodities Specified": ("Global", "Commodities Specified"),
        "Options Trading": ("USA", "Options Trading"),
        "Multialternative": ("Global", "Multialternative"),
        "Market Neutral": ("Global", "Market Neutral"),
        "Long/Short Equity": ("Global", "Long/Short Equity"),
        "Alternative Miscellaneous": ("Global", "Alternative Miscellaneous"),
        "Energy Sector Equity": ("USA", "Energy Sector Equity"),
        "Equity Miscellaneous": ("USA", "Equity Miscellaneous"),
        "Financials Sector Equity": ("USA", "Financials Sector Equity"),
        "Healthcare Sector Equity": ("USA", "Healthcare Sector Equity"),
        "Consumer Goods & Services Sector Equity": ("USA", "Consumer Goods & Services Sector Equity"),
        "Communications Sector Equity": ("USA", "Communications Sector Equity"),
        "Industrials Sector Equity": ("USA", "Industrials Sector Equity"),
        "Other Sector Equity": ("USA", "Other Sector Equity"),
        "Real Estate Sector Equity": ("USA", "Real Estate Sector Equity"),
        "Precious Metals Sector Equity": ("USA", "Precious Metals Sector Equity"),
        "Technology Sector Equity": ("USA", "Technology Sector Equity"),
        "Utilities Sector Equity": ("USA", "Utilities Sector Equity"),
        "Asia ex-Japan Equity": ("International", "Asia ex-Japan Equity"),
        "Australia & New Zealand Equity": ("International", "Australia & New Zealand Equity"),
        "Canadian Equity Large Cap": ("International", "Canadian Equity Large Cap"),
        "Europe Equity Mid/Small Cap": ("International", "Europe Equity Mid/Small Cap"),
        "Greater China Equity": ("International", "Greater China Equity"),
        "India Equity": ("International", "India Equity"),
        "Mexico Equity": ("International", "Mexico Equity"),
        "Korea Equity": ("International", "Korea Equity"),
        "Latin America Equity": ("International", "Latin America Equity"),
        "UK Equity Large Cap": ("International", "UK Equity Large Cap"),
        "Thailand Equity": ("International", "Thailand Equity"),
        "Convertibles": ("USA", "Convertibles"),
        "Fixed Income Miscellaneous": ("USA", "Fixed Income Miscellaneous"),
        "Allocation Miscellaneous": ("Global", "Allocation Miscellaneous")
    }
    return mapping.get(category, ("Unknown", "Unknown"))

@contextmanager
def database_transaction():
    connection = engine.connect()
    transaction = connection.begin()
    try:
        yield connection
        transaction.commit()
    except Exception as e:
        transaction.rollback()
        logger.error(f"Transaction failed: {e}")
        raise
    finally:
        connection.close()

def timer(func):
    @functools.wraps(func)
    def wrapper(*args, **kwargs):
        start_time = time.time()
        logger.debug(f"Starting {func.__name__}")
        result = func(*args, **kwargs)
        logger.info(f"{func.__name__} took {time.time() - start_time:.2f} seconds")
        return result
    return wrapper

# Section 3: Data Loading Functions
@timer
def load_fund_metadata():
    query = """
    SELECT 
        f.SymbolCUSIP, 
        f.Region, 
        f.YC_Global_Category_ID, 
        c.Global_Category_Name,
        f.YC_Category_ID,
        y.Category_Name,
        f.CWA_Broad_Category_ID,
        b.CWA_Broad_Category_Name
    FROM Funds_to_Screen f
    JOIN YC_Global_Category_List c ON f.YC_Global_Category_ID = c.ID
    JOIN YC_Category_List y ON f.YC_Category_ID = y.ID
    LEFT JOIN CWA_Broad_Category_List b ON f.CWA_Broad_Category_ID = b.ID
    """
    try:
        df = pd.read_sql(text(query), engine)
        logger.info(f"Loaded metadata for {len(df)} fundus")
        df[["Region", "FactorProfile"]] = df["Global_Category_Name"].map(category_to_region).apply(pd.Series)
        if df["CWA_Broad_Category_Name"].isnull().all():
            logger.warning("CWA_Broad_Category_Name missing; some regressions may be skipped")
        return df.dropna(subset=["Region", "FactorProfile"])
    except OperationalError as e:
        logger.error(f"Database error loading metadata: {e}")
        raise
    except Exception as e:
        logger.error(f"Unexpected error loading metadata: {e}")
        raise

@timer
def load_fund_returns(fund_ids=None):
    query = """
    SELECT SymbolCUSIP, Date, ReturnValue
    FROM Fund_Returns_Timeseries
    WHERE Metric = :metric
    """
    params = {"metric": RETURN_METRIC}
    if fund_ids:
        query += " AND SymbolCUSIP IN :fund_ids"
        params["fund_ids"] = tuple(fund_ids)
    try:
        chunks = []
        for chunk in pd.read_sql(text(query), engine, params=params, parse_dates=["Date"], chunksize=CHUNK_SIZE):
            logger.debug(f"Loaded chunk of {len(chunk)} rows")
            chunks.append(chunk)
        df = pd.concat(chunks) if chunks else pd.DataFrame()
        if df.empty:
            logger.warning("No returns data loaded")
            return pd.DataFrame()
        logger.info(f"Loaded returns for {len(df['SymbolCUSIP'].unique())} funds")
        pivoted = df.pivot(index="Date", columns="SymbolCUSIP", values="ReturnValue")
        for col in pivoted.columns:
            if not pd.api.types.is_numeric_dtype(pivoted[col]):
                logger.warning(f"Non-numeric returns for {col}; converting")
                pivoted[col] = pd.to_numeric(pivoted[col], errors='coerce')
        return pivoted
    except OperationalError as e:
        logger.error(f"Database error loading returns: {e}")
        raise
    except Exception as e:
        logger.error(f"Unexpected error loading returns: {e}")
        raise

@timer
def load_factors(factor_config, region="Global", asset_class=None):
    source = factor_config.get("source")
    try:
        if source == "db":
            factor_in_clause = ','.join([f"'{f}'" for f in factor_config["factors"]])
            query = f"""
            SELECT date AS Date, factor AS Factor, value AS Value
            FROM {factor_config.get('table', 'factor_returns')}
            WHERE factor IN ({factor_in_clause})
            """
            params = []
            if region and not any(f.startswith('TSM-') or f == 'RF' for f in factor_config["factors"]):
                query += " AND region = ?"
                params.append(region)
            elif 'RF' in factor_config["factors"]:
                query += " AND region = 'USA'"
            if asset_class:
                query += " AND asset_class = ?"
                params.append(asset_class)
            df = pd.read_sql(query, engine, params=params, parse_dates=['Date'])
            if df.empty:
                logger.warning(f"No data for factors {factor_config['factors']}")
                return pd.DataFrame()
            if df.duplicated(subset=['Date', 'Factor']).sum() > 0:
                logger.error(f"Duplicate factors {factor_config['factors']}")
                raise ValueError("Duplicate factor data")
            pivoted_df = df.pivot(index="Date", columns="Factor", values="Value").rename(
                columns={'MKT': 'mkt', 'RF': 'rf'}
            )
            return pivoted_df
        else:
            logger.warning(f"Factor source {source} not implemented")
            return pd.DataFrame()
    except Exception as e:
        logger.error(f"Error loading factors {factor_config.get('factors', [])}: {e}")
        return pd.DataFrame()

# Section 4: Regression Functions
def run_rolling_regression(fund, returns, factors, regression_type, factor_set):
    results = []
    try:
        returns = pd.Series(returns).dropna()
        factors = pd.DataFrame(factors).dropna()
        returns.index = pd.to_datetime(returns.index, errors='coerce')
        factors.index = pd.to_datetime(factors.index, errors='coerce')
        returns = returns[returns.index.notnull()]
        factors = factors[factors.index.notnull()]
        
        if returns.empty or factors.empty:
            logger.warning(f"Empty data for {fund} ({factor_set})")
            return results
        
        viable_periods = [w for w in ROLLING_PERIODS if (returns.index.max() - relativedelta(months=w)) >= returns.index.min()]
        for window in viable_periods:
            min_obs = int(window * MIN_OBSERVATIONS)
            rolling_windows = returns.loc[returns.index >= (returns.index.min() + relativedelta(months=window))].rolling(window=f"{window}M", min_periods=min_obs)
            for end_date, y in rolling_windows:
                if y.index[0] < returns.index.min():
                    continue
                X = factors.loc[y.index]
                X, y = X.align(y, join="inner", axis=0)
                if len(y) < min_obs or y.isnull().any() or X.isnull().any().any():
                    continue
                X_const = add_constant(X)
                model = OLS(y, X_const).fit()
                for factor in X.columns:
                    results.append({
                        "SymbolCUSIP": fund,
                        "MonthEndDate": end_date,
                        "RollPeriod": f"{window}m",
                        "Factor_Name": factor,
                        "Coefficient": model.params.get(factor, np.nan),
                        "P_Value": model.pvalues.get(factor, np.nan),
                        "T_Stat": model.tvalues.get(factor, np.nan),
                        "Standard_Error": model.bse.get(factor, np.nan),
                        "CI_Lower": model.conf_int().loc[factor][0] if factor in model.params else np.nan,
                        "CI_Upper": model.conf_int().loc[factor][1] if factor in model.params else np.nan,
                        "Adj_R2": model.rsquared_adj,
                        "Correlation": np.corrcoef(y, model.fittedvalues)[0, 1] if len(y) > 1 else np.nan,
                        "Regression_Type": regression_type,
                        "Factor_Set": factor_set
                    })
    except Exception as e:
        logger.error(f"Regression error for {fund} ({factor_set}): {e}")
    return results

# Section 5: Processing Functions
def process_regression(symbol, returns, factor_set_key):
    records = []
    factor_configs = FACTOR_CONFIGS.get(factor_set_key, [])
    if not factor_configs:
        logger.warning(f"No config for {factor_set_key}")
        return records
    
    try:
        factors_list = [load_factors(config, region=config.get("region", "Global")) for config in factor_configs]
        factors = pd.concat([f for f in factors_list if not f.empty], axis=1).dropna()
        if factors.empty:
            logger.warning(f"No factors for {symbol} ({factor_set_key})")
            return records
        
        if 'mkt' in factors.columns and 'rf' in factors.columns:
            factors['mkt-rf'] = factors['mkt'] - factors['rf']
        
        factors, returns_aligned = factors.align(returns, join="inner", axis=0)
        if returns_aligned.empty:
            logger.warning(f"No overlapping data for {symbol} ({factor_set_key})")
            return records
        
        desired_factors = factor_configs[0].get("desired_factors", factors.columns.tolist())
        available_factors = [f for f in desired_factors if f in factors.columns]
        if not available_factors:
            logger.warning(f"No valid factors for {symbol} ({factor_set_key})")
            return records
        
        records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", factor_set_key))
    except Exception as e:
        logger.error(f"Error processing {symbol} ({factor_set_key}): {e}")
    
    return records

def process_fund(fund_data):
    records = []
    symbol = fund_data["SymbolCUSIP"]
    category = fund_data["Global_Category_Name"]
    returns = pd.Series(fund_data["returns"]).dropna()
    
    logger.debug(f"Processing fund {symbol}")
    
    if returns.empty:
        logger.warning(f"No returns for {symbol}")
        return records
    
    regression_sets = ["Equity_USA_1"] if category in [k for k, v in category_to_region().items() if v[0] == "USA"] else []
    for factor_set in regression_sets:
        records.extend(process_regression(symbol, returns, factor_set))
    
    if records and DRY_RUN:
        pd.DataFrame(records).to_csv(f"dry_run_{symbol}_{uuid.uuid4()}.csv", index=False)
        logger.info(f"Saved {len(records)} records for {symbol}")
    
    return records

def process_region(region, fund_data_list):
    records = []
    logger.info(f"Processing {len(fund_data_list)} funds in {region}")
    
    with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
        future_to_fund = {executor.submit(process_fund, fund_data): fund_data["SymbolCUSIP"] for fund_data in fund_data_list}
        for future in tqdm(future_to_fund, total=len(fund_data_list), desc=f"Processing {region}", file=sys.stdout):
            try:
                records.extend(future.result())
            except Exception as e:
                logger.error(f"Error processing {future_to_fund[future]}: {e}")
    
    if records and DRY_RUN:
        pd.DataFrame(records).to_csv(f"dry_run_{region}_{uuid.uuid4()}.csv", index=False)
        logger.info(f"Dry run: Saved {len(records)} records for {region}")
    
    return records

# Section 6: Main Pipeline
@timer
def main():
    logger.info("Starting main pipeline")
    try:
        fund_meta = load_fund_metadata()
    except Exception as e:
        logger.error(f"Failed to load metadata: {e}")
        return {"error": str(e)}
    
    regions = fund_meta["Region"].unique()
    logger.info(f"Total funds: {len(fund_meta)}, Regions: {regions}")
    
    fund_ids = fund_meta["SymbolCUSIP"].tolist()
    if SAMPLE_DRY_RUN:
        fund_ids = random.sample(fund_ids, min(SAMPLE_SIZE, len(fund_ids)))
        logger.info(f"Sampled {len(fund_ids)} funds")
    
    try:
        returns = load_fund_returns(fund_ids)
    except Exception as e:
        logger.error(f"Failed to load returns: {e}")
        return {"error": str(e)}
    
    fund_data_list = [
        {
            "SymbolCUSIP": row["SymbolCUSIP"],
            "Global_Category_Name": row["Global_Category_Name"],
            "returns": returns[row["SymbolCUSIP"]].to_dict()
        }
        for _, row in fund_meta.iterrows() if row["SymbolCUSIP"] in returns.columns
    ]
    
    summary = {"total_funds": len(fund_data_list), "regions": {}, "errors": 0}
    for region in regions:
        region_funds = [fd for fd in fund_data_list if fund_meta[fund_meta["SymbolCUSIP"] == fd["SymbolCUSIP"]]["Region"].iloc[0] == region]
        if SAMPLE_DRY_RUN and len(region_funds) > SAMPLE_SIZE:
            region_funds = random.sample(region_funds, SAMPLE_SIZE)
            logger.info(f"Sampled {len(region_funds)} funds for {region}")
        records = process_region(region, region_funds)
        summary["regions"][region] = {"funds_processed": len(region_funds), "records": len(records)}
    
    logger.info(f"Pipeline summary: {summary}")
    return summary

# Section 7: Database Output
def insert_batch(records):
    try:
        df = pd.DataFrame(records)
        with database_transaction() as connection:
            df.to_sql("AQRR_Factor_Attribution", connection, if_exists="append", index=False, method="multi")
        logger.info(f"Inserted {len(df)} records")
    except Exception as e:
        logger.error(f"Error inserting batch: {e}")
        raise

if __name__ == "__main__":
    try:
        main()
    except Exception as e:
        logger.error(f"Main execution failed: {e}")
        raise
# Out:
# 2025-04-13 19:56:08,848 - INFO - Starting main pipeline
# 2025-04-13 19:56:09,045 - INFO - Loaded metadata for 5584 fundus
# 2025-04-13 19:56:09,337 - INFO - load_fund_metadata took 0.49 seconds
# 2025-04-13 19:56:09,339 - INFO - Total funds: 5584, Regions: ['Global' 'USA' 'Unknown' 'International']
# 2025-04-13 19:56:09,339 - INFO - Sampled 10 funds
# 2025-04-13 19:56:09,341 - ERROR - Unexpected error loading returns: (pyodbc.ProgrammingError) ("A TVP's rows must all be the same size.", 'HY000')
# [SQL:
#     SELECT SymbolCUSIP, Date, ReturnValue
#     FROM Fund_Returns_Timeseries
#     WHERE Metric = ?
#      AND SymbolCUSIP IN ?]
# [parameters: ('1 Month Return', ('PLDR', 'VEGI', 'HYXF', 'ACAZX', 'DPTRX', 'LHMIX', 'CBLS', 'TRHBX', 'AIVI', 'GISTX'))]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# 2025-04-13 19:56:09,343 - ERROR - Failed to load returns: (pyodbc.ProgrammingError) ("A TVP's rows must all be the same size.", 'HY000')
# [SQL:
#     SELECT SymbolCUSIP, Date, ReturnValue
#     FROM Fund_Returns_Timeseries
#     WHERE Metric = ?
#      AND SymbolCUSIP IN ?]
# [parameters: ('1 Month Return', ('PLDR', 'VEGI', 'HYXF', 'ACAZX', 'DPTRX', 'LHMIX', 'CBLS', 'TRHBX', 'AIVI', 'GISTX'))]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# 2025-04-13 19:56:09,343 - INFO - main took 0.49 seconds

# %%
import pandas as pd
import numpy as np
import os
import random
import logging
from datetime import timedelta, datetime
from dateutil.relativedelta import relativedelta
from concurrent.futures import ThreadPoolExecutor
from sqlalchemy import create_engine, text
from sqlalchemy.exc import OperationalError
from tqdm import tqdm
from statsmodels.regression.linear_model import OLS
from statsmodels.tools.tools import add_constant
import statsmodels.api as sm
import time
import uuid
import psutil
import functools
from contextlib import contextmanager
import sys

# Section 1: Configuration and Setup
CONFIG = {
    "database": {
        "server": "JULIANS_LAPTOP\\SQLEXPRESS",
        "database": "CWA_Fund_Database",
        "driver": "ODBC Driver 18 for SQL Server"
    },
    "return_metric": "1 Month Return",
    "rolling_periods": [12],
    "dry_run": True,
    "sample_dry_run": True,
    "sample_size": 10,
    "chunk_size": 1000,
    "batch_insert_size": 5000,
    "max_workers": 8,
    "use_threads": True,
    "min_observations": 0.8,
    "query_timeout": 30
}

CONNECTION_STRING = (
    f"mssql+pyodbc://{CONFIG['database']['server']}/{CONFIG['database']['database']}"
    f"?driver={CONFIG['database']['driver']}&trusted_connection=yes&TrustServerCertificate=yes"
)
try:
    engine = create_engine(CONNECTION_STRING, connect_args={"timeout": CONFIG["query_timeout"]})
except Exception as e:
    print(f"Database connection failed: {e}")
    raise

RETURN_METRIC = CONFIG["return_metric"]
ROLLING_PERIODS = CONFIG["rolling_periods"]
DRY_RUN = CONFIG["dry_run"]
SAMPLE_DRY_RUN = CONFIG["sample_dry_run"]
SAMPLE_SIZE = CONFIG["sample_size"]
CHUNK_SIZE = CONFIG["chunk_size"]
BATCH_INSERT_SIZE = CONFIG["batch_insert_size"]
MAX_WORKERS = min(CONFIG["max_workers"], psutil.cpu_count(logical=False))
USE_THREADS = CONFIG["use_threads"]
MIN_OBSERVATIONS = CONFIG["min_observations"]

# Simplified factor configuration
FACTOR_CONFIGS = {
    "Equity_USA_1": [
        {"source": "db", "factors": ["MKT", "RF"], "region": "USA", "desired_factors": ["mkt-rf"]}
    ]
}

# Logging setup with immediate flushing
logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler("factor_attribution.log"),
        logging.StreamHandler(sys.stdout)
    ],
    force=True
)
logger = logging.getLogger()
logger.handlers[1].stream = sys.stdout
logger.handlers[1].setLevel(logging.INFO)

# Section 2: Helper Functions
def category_to_region(category):
    mapping = {
        "US Equity Large Cap Blend": ("USA", "US Equity Large Cap Blend"),
        "US Equity Large Cap Growth": ("USA", "US Equity Large Cap Growth"),
        "US Equity Large Cap Value": ("USA", "US Equity Large Cap Value"),
        "US Equity Mid Cap": ("USA", "US Equity Mid Cap"),
        "US Equity Small Cap": ("USA", "US Equity Small Cap"),
        "Global Equity Large Cap": ("Global", "Global Equity Large Cap"),
        "Global Equity Mid/Small Cap": ("Global", "Global Equity Mid/Small Cap"),
        "Global Emerging Markets Equity": ("Global", "Global Emerging Markets Equity"),
        "Europe Equity Large Cap": ("International", "Europe Equity Large Cap"),
        "Asia Equity": ("International", "Asia Equity"),
        "Japan Equity": ("International", "Japan Equity"),
        "Emerging Markets Fixed Income": ("International", "Emerging Markets Fixed Income"),
        "US Fixed Income": ("USA", "US Fixed Income"),
        "US Municipal Fixed Income": ("USA", "US Municipal Fixed Income"),
        "Global Fixed Income": ("Global", "Global Fixed Income"),
        "Flexible Allocation": ("Global", "Flexible Allocation"),
        "Aggressive Allocation": ("Global", "Aggressive Allocation"),
        "Moderate Allocation": ("Global", "Moderate Allocation"),
        "Cautious Allocation": ("Global", "Cautious Allocation"),
        "Commodities Broad Basket": ("Global", "Commodities Broad Basket"),
        "Commodities Specified": ("Global", "Commodities Specified"),
        "Options Trading": ("USA", "Options Trading"),
        "Multialternative": ("Global", "Multialternative"),
        "Market Neutral": ("Global", "Market Neutral"),
        "Long/Short Equity": ("Global", "Long/Short Equity"),
        "Alternative Miscellaneous": ("Global", "Alternative Miscellaneous"),
        "Energy Sector Equity": ("USA", "Energy Sector Equity"),
        "Equity Miscellaneous": ("USA", "Equity Miscellaneous"),
        "Financials Sector Equity": ("USA", "Financials Sector Equity"),
        "Healthcare Sector Equity": ("USA", "Healthcare Sector Equity"),
        "Consumer Goods & Services Sector Equity": ("USA", "Consumer Goods & Services Sector Equity"),
        "Communications Sector Equity": ("USA", "Communications Sector Equity"),
        "Industrials Sector Equity": ("USA", "Industrials Sector Equity"),
        "Other Sector Equity": ("USA", "Other Sector Equity"),
        "Real Estate Sector Equity": ("USA", "Real Estate Sector Equity"),
        "Precious Metals Sector Equity": ("USA", "Precious Metals Sector Equity"),
        "Technology Sector Equity": ("USA", "Technology Sector Equity"),
        "Utilities Sector Equity": ("USA", "Utilities Sector Equity"),
        "Asia ex-Japan Equity": ("International", "Asia ex-Japan Equity"),
        "Australia & New Zealand Equity": ("International", "Australia & New Zealand Equity"),
        "Canadian Equity Large Cap": ("International", "Canadian Equity Large Cap"),
        "Europe Equity Mid/Small Cap": ("International", "Europe Equity Mid/Small Cap"),
        "Greater China Equity": ("International", "Greater China Equity"),
        "India Equity": ("International", "India Equity"),
        "Mexico Equity": ("International", "Mexico Equity"),
        "Korea Equity": ("International", "Korea Equity"),
        "Latin America Equity": ("International", "Latin America Equity"),
        "UK Equity Large Cap": ("International", "UK Equity Large Cap"),
        "Thailand Equity": ("International", "Thailand Equity"),
        "Convertibles": ("USA", "Convertibles"),
        "Fixed Income Miscellaneous": ("USA", "Fixed Income Miscellaneous"),
        "Allocation Miscellaneous": ("Global", "Allocation Miscellaneous")
    }
    return mapping.get(category, ("Unknown", "Unknown"))

@contextmanager
def database_transaction():
    connection = engine.connect()
    transaction = connection.begin()
    try:
        yield connection
        transaction.commit()
    except Exception as e:
        transaction.rollback()
        logger.error(f"Transaction failed: {e}")
        raise
    finally:
        connection.close()

def timer(func):
    @functools.wraps(func)
    def wrapper(*args, **kwargs):
        start_time = time.time()
        logger.debug(f"Starting {func.__name__}")
        result = func(*args, **kwargs)
        logger.info(f"{func.__name__} took {time.time() - start_time:.2f} seconds")
        return result
    return wrapper

# Section 3: Data Loading Functions
@timer
def load_fund_metadata():
    query = """
    SELECT 
        f.SymbolCUSIP, 
        f.Region, 
        f.YC_Global_Category_ID, 
        c.Global_Category_Name,
        f.YC_Category_ID,
        y.Category_Name,
        f.CWA_Broad_Category_ID,
        b.CWA_Broad_Category_Name
    FROM Funds_to_Screen f
    JOIN YC_Global_Category_List c ON f.YC_Global_Category_ID = c.ID
    JOIN YC_Category_List y ON f.YC_Category_ID = y.ID
    LEFT JOIN CWA_Broad_Category_List b ON f.CWA_Broad_Category_ID = b.ID
    """
    try:
        df = pd.read_sql(text(query), engine)
        logger.info(f"Loaded metadata for {len(df)} funds")
        df[["Region", "FactorProfile"]] = df["Global_Category_Name"].map(category_to_region).apply(pd.Series)
        if df["CWA_Broad_Category_Name"].isnull().all():
            logger.warning("CWA_Broad_Category_Name missing; some regressions may be skipped")
        return df.dropna(subset=["Region", "FactorProfile"])
    except OperationalError as e:
        logger.error(f"Database error loading metadata: {e}")
        raise
    except Exception as e:
        logger.error(f"Unexpected error loading metadata: {e}")
        raise

@timer
def load_fund_returns(fund_ids=None):
    try:
        if not fund_ids:
            query = """
            SELECT SymbolCUSIP, Date, ReturnValue
            FROM Fund_Returns_Timeseries
            WHERE Metric = ?
            """
            params = [RETURN_METRIC]
        else:
            # Validate fund_ids
            fund_ids = [fid for fid in fund_ids if isinstance(fid, str) and fid.strip()]
            if not fund_ids:
                logger.warning("No valid fund IDs provided")
                return pd.DataFrame()
            # Manual construction to avoid TVP issues
            placeholders = ",".join([f"'{fid.replace('\'', '')}'" for fid in fund_ids])
            query = f"""
            SELECT SymbolCUSIP, Date, ReturnValue
            FROM Fund_Returns_Timeseries
            WHERE Metric = ?
            AND SymbolCUSIP IN ({placeholders})
            """
            params = [RETURN_METRIC]
            logger.debug(f"Querying returns for funds: {fund_ids}")
        
        chunks = []
        for chunk in pd.read_sql(query, engine, params=params, parse_dates=["Date"], chunksize=CHUNK_SIZE):
            logger.debug(f"Loaded chunk of {len(chunk)} rows")
            chunks.append(chunk)
        df = pd.concat(chunks) if chunks else pd.DataFrame()
        if df.empty:
            logger.warning("No returns data loaded")
            return pd.DataFrame()
        
        logger.info(f"Loaded returns for {len(df['SymbolCUSIP'].unique())} funds")
        pivoted = df.pivot(index="Date", columns="SymbolCUSIP", values="ReturnValue")
        for col in pivoted.columns:
            if not pd.api.types.is_numeric_dtype(pivoted[col]):
                logger.warning(f"Non-numeric returns for {col}; converting")
                pivoted[col] = pd.to_numeric(pivoted[col], errors='coerce')
        return pivoted
    except OperationalError as e:
        logger.error(f"Database error loading returns: {e}")
        # Fallback: Try individual fund queries
        if fund_ids:
            logger.info("Attempting individual fund queries")
            chunks = []
            for fid in fund_ids:
                try:
                    query = """
                    SELECT SymbolCUSIP, Date, ReturnValue
                    FROM Fund_Returns_Timeseries
                    WHERE Metric = ? AND SymbolCUSIP = ?
                    """
                    chunk = pd.read_sql(query, engine, params=[RETURN_METRIC, fid], parse_dates=["Date"])
                    chunks.append(chunk)
                    logger.debug(f"Loaded returns for {fid}")
                except Exception as e2:
                    logger.warning(f"Failed to load returns for {fid}: {e2}")
            df = pd.concat(chunks) if chunks else pd.DataFrame()
            if df.empty:
                logger.warning("No returns data loaded in fallback")
                return pd.DataFrame()
            pivoted = df.pivot(index="Date", columns="SymbolCUSIP", values="ReturnValue")
            for col in pivoted.columns:
                pivoted[col] = pd.to_numeric(pivoted[col], errors='coerce')
            return pivoted
        raise
    except Exception as e:
        logger.error(f"Unexpected error loading returns: {e}")
        raise

@timer
def load_factors(factor_config, region="Global", asset_class=None):
    source = factor_config.get("source")
    try:
        if source == "db":
            factor_in_clause = ','.join([f"'{f}'" for f in factor_config["factors"]])
            query = f"""
            SELECT date AS Date, factor AS Factor, value AS Value
            FROM {factor_config.get('table', 'factor_returns')}
            WHERE factor IN ({factor_in_clause})
            """
            params = []
            if region and not any(f.startswith('TSM-') or f == 'RF' for f in factor_config["factors"]):
                query += " AND region = ?"
                params.append(region)
            elif 'RF' in factor_config["factors"]:
                query += " AND region = 'USA'"
            if asset_class:
                query += " AND asset_class = ?"
                params.append(asset_class)
            df = pd.read_sql(query, engine, params=params, parse_dates=['Date'])
            if df.empty:
                logger.warning(f"No data for factors {factor_config['factors']}")
                return pd.DataFrame()
            if df.duplicated(subset=['Date', 'Factor']).sum() > 0:
                logger.error(f"Duplicate factors {factor_config['factors']}")
                raise ValueError("Duplicate factor data")
            pivoted_df = df.pivot(index="Date", columns="Factor", values="Value").rename(
                columns={'MKT': 'mkt', 'RF': 'rf'}
            )
            return pivoted_df
        else:
            logger.warning(f"Factor source {source} not implemented")
            return pd.DataFrame()
    except Exception as e:
        logger.error(f"Error loading factors {factor_config.get('factors', [])}: {e}")
        return pd.DataFrame()

# Section 4: Regression Functions
def run_rolling_regression(fund, returns, factors, regression_type, factor_set):
    results = []
    try:
        returns = pd.Series(returns).dropna()
        factors = pd.DataFrame(factors).dropna()
        returns.index = pd.to_datetime(returns.index, errors='coerce')
        factors.index = pd.to_datetime(factors.index, errors='coerce')
        returns = returns[returns.index.notnull()]
        factors = factors[factors.index.notnull()]
        
        if returns.empty or factors.empty:
            logger.warning(f"Empty data for {fund} ({factor_set})")
            return results
        
        viable_periods = [w for w in ROLLING_PERIODS if (returns.index.max() - relativedelta(months=w)) >= returns.index.min()]
        for window in viable_periods:
            min_obs = int(window * MIN_OBSERVATIONS)
            rolling_windows = returns.loc[returns.index >= (returns.index.min() + relativedelta(months=window))].rolling(window=f"{window}M", min_periods=min_obs)
            for end_date, y in rolling_windows:
                if y.index[0] < returns.index.min():
                    continue
                X = factors.loc[y.index]
                X, y = X.align(y, join="inner", axis=0)
                if len(y) < min_obs or y.isnull().any() or X.isnull().any().any():
                    continue
                X_const = add_constant(X)
                model = OLS(y, X_const).fit()
                for factor in X.columns:
                    results.append({
                        "SymbolCUSIP": fund,
                        "MonthEndDate": end_date,
                        "RollPeriod": f"{window}m",
                        "Factor_Name": factor,
                        "Coefficient": model.params.get(factor, np.nan),
                        "P_Value": model.pvalues.get(factor, np.nan),
                        "T_Stat": model.tvalues.get(factor, np.nan),
                        "Standard_Error": model.bse.get(factor, np.nan),
                        "CI_Lower": model.conf_int().loc[factor][0] if factor in model.params else np.nan,
                        "CI_Upper": model.conf_int().loc[factor][1] if factor in model.params else np.nan,
                        "Adj_R2": model.rsquared_adj,
                        "Correlation": np.corrcoef(y, model.fittedvalues)[0, 1] if len(y) > 1 else np.nan,
                        "Regression_Type": regression_type,
                        "Factor_Set": factor_set
                    })
    except Exception as e:
        logger.error(f"Regression error for {fund} ({factor_set}): {e}")
    return results

# Section 5: Processing Functions
def process_regression(symbol, returns, factor_set_key):
    records = []
    factor_configs = FACTOR_CONFIGS.get(factor_set_key, [])
    if not factor_configs:
        logger.warning(f"No config for {factor_set_key}")
        return records
    
    try:
        factors_list = [load_factors(config, region=config.get("region", "Global")) for config in factor_configs]
        factors = pd.concat([f for f in factors_list if not f.empty], axis=1).dropna()
        if factors.empty:
            logger.warning(f"No factors for {symbol} ({factor_set_key})")
            return records
        
        if 'mkt' in factors.columns and 'rf' in factors.columns:
            factors['mkt-rf'] = factors['mkt'] - factors['rf']
        
        factors, returns_aligned = factors.align(returns, join="inner", axis=0)
        if returns_aligned.empty:
            logger.warning(f"No overlapping data for {symbol} ({factor_set_key})")
            return records
        
        desired_factors = factor_configs[0].get("desired_factors", factors.columns.tolist())
        available_factors = [f for f in desired_factors if f in factors.columns]
        if not available_factors:
            logger.warning(f"No valid factors for {symbol} ({factor_set_key})")
            return records
        
        records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", factor_set_key))
    except Exception as e:
        logger.error(f"Error processing {symbol} ({factor_set_key}): {e}")
    
    return records

def process_fund(fund_data):
    records = []
    symbol = fund_data["SymbolCUSIP"]
    category = fund_data["Global_Category_Name"]
    returns = pd.Series(fund_data["returns"]).dropna()
    
    logger.debug(f"Processing fund {symbol}")
    
    if returns.empty:
        logger.warning(f"No returns for {symbol}")
        return records
    
    regression_sets = ["Equity_USA_1"] if category in [k for k, v in category_to_region().items() if v[0] == "USA"] else []
    for factor_set in regression_sets:
        records.extend(process_regression(symbol, returns, factor_set))
    
    if records and DRY_RUN:
        pd.DataFrame(records).to_csv(f"dry_run_{symbol}_{uuid.uuid4()}.csv", index=False)
        logger.info(f"Saved {len(records)} records for {symbol}")
    
    return records

def process_region(region, fund_data_list):
    records = []
    logger.info(f"Processing {len(fund_data_list)} funds in {region}")
    
    with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
        future_to_fund = {executor.submit(process_fund, fund_data): fund_data["SymbolCUSIP"] for fund_data in fund_data_list}
        for future in tqdm(future_to_fund, total=len(fund_data_list), desc=f"Processing {region}", file=sys.stdout):
            try:
                records.extend(future.result())
            except Exception as e:
                logger.error(f"Error processing {future_to_fund[future]}: {e}")
    
    if records and DRY_RUN:
        pd.DataFrame(records).to_csv(f"dry_run_{region}_{uuid.uuid4()}.csv", index=False)
        logger.info(f"Dry run: Saved {len(records)} records for {region}")
    
    return records

# Section 6: Main Pipeline
@timer
def main():
    logger.info("Starting main pipeline")
    try:
        fund_meta = load_fund_metadata()
    except Exception as e:
        logger.error(f"Failed to load metadata: {e}")
        return {"error": str(e)}
    
    regions = fund_meta["Region"].unique()
    logger.info(f"Total funds: {len(fund_meta)}, Regions: {regions}")
    
    fund_ids = fund_meta["SymbolCUSIP"].tolist()
    if SAMPLE_DRY_RUN:
        fund_ids = random.sample(fund_ids, min(SAMPLE_SIZE, len(fund_ids)))
        logger.info(f"Sampled {len(fund_ids)} funds")
    
    try:
        returns = load_fund_returns(fund_ids)
    except Exception as e:
        logger.error(f"Failed to load returns: {e}")
        return {"error": str(e)}
    
    fund_data_list = [
        {
            "SymbolCUSIP": row["SymbolCUSIP"],
            "Global_Category_Name": row["Global_Category_Name"],
            "returns": returns[row["SymbolCUSIP"]].to_dict()
        }
        for _, row in fund_meta.iterrows() if row["SymbolCUSIP"] in returns.columns
    ]
    
    summary = {"total_funds": len(fund_data_list), "regions": {}, "errors": 0}
    for region in regions:
        region_funds = [fd for fd in fund_data_list if fund_meta[fund_meta["SymbolCUSIP"] == fd["SymbolCUSIP"]]["Region"].iloc[0] == region]
        if SAMPLE_DRY_RUN and len(region_funds) > SAMPLE_SIZE:
            region_funds = random.sample(region_funds, SAMPLE_SIZE)
            logger.info(f"Sampled {len(region_funds)} funds for {region}")
        records = process_region(region, region_funds)
        summary["regions"][region] = {"funds_processed": len(region_funds), "records": len(records)}
    
    logger.info(f"Pipeline summary: {summary}")
    return summary

# Section 7: Database Output
def insert_batch(records):
    try:
        df = pd.DataFrame(records)
        with database_transaction() as connection:
            df.to_sql("AQRR_Factor_Attribution", connection, if_exists="append", index=False, method="multi")
        logger.info(f"Inserted {len(df)} records")
    except Exception as e:
        logger.error(f"Error inserting batch: {e}")
        raise

if __name__ == "__main__":
    try:
        main()
    except Exception as e:
        logger.error(f"Main execution failed: {e}")
        raise
# Out:
# 2025-04-13 19:59:06,725 - INFO - Starting main pipeline
# 2025-04-13 19:59:06,849 - INFO - Loaded metadata for 5584 funds
# 2025-04-13 19:59:07,131 - INFO - load_fund_metadata took 0.41 seconds
# 2025-04-13 19:59:07,133 - INFO - Total funds: 5584, Regions: ['Global' 'USA' 'Unknown' 'International']
# 2025-04-13 19:59:07,133 - INFO - Sampled 10 funds
# 2025-04-13 19:59:07,148 - ERROR - Unexpected error loading returns: List argument must consist only of tuples or dictionaries
# 2025-04-13 19:59:07,148 - ERROR - Failed to load returns: List argument must consist only of tuples or dictionaries
# 2025-04-13 19:59:07,150 - INFO - main took 0.42 seconds

# %%
import pandas as pd
import numpy as np
import os
import random
import logging
from datetime import timedelta, datetime
from dateutil.relativedelta import relativedelta
from concurrent.futures import ThreadPoolExecutor
from sqlalchemy import create_engine
from tqdm import tqdm
from statsmodels.regression.linear_model import OLS
from statsmodels.tools.tools import add_constant
import statsmodels.api as sm
import time
import functools
from contextlib import contextmanager
import sys

# Section 1: Configuration and Setup
CONFIG = {
    "database": {
        "server": "JULIANS_LAPTOP\\SQLEXPRESS",
        "database": "CWA_Fund_Database",
        "driver": "ODBC Driver 18 for SQL Server"
    },
    "return_metric": "1 Month Return",
    "rolling_periods": [12],
    "dry_run": True,
    "sample_dry_run": True,
    "sample_size": 10,
    "chunk_size": 1000,
    "batch_insert_size": 5000,
    "max_workers": 8,
    "use_threads": True,
    "min_observations": 0.8,
    "query_timeout": 30
}

CONNECTION_STRING = (
    f"mssql+pyodbc://{CONFIG['database']['server']}/{CONFIG['database']['database']}"
    f"?driver={CONFIG['database']['driver']}&trusted_connection=yes&TrustServerCertificate=yes"
)
try:
    engine = create_engine(CONNECTION_STRING, connect_args={"timeout": CONFIG["query_timeout"]})
except Exception as e:
    print(f"Database connection failed: {e}")
    raise

RETURN_METRIC = CONFIG["return_metric"]
ROLLING_PERIODS = CONFIG["rolling_periods"]
DRY_RUN = CONFIG["dry_run"]
SAMPLE_DRY_RUN = CONFIG["sample_dry_run"]
SAMPLE_SIZE = CONFIG["sample_size"]
CHUNK_SIZE = CONFIG["chunk_size"]
BATCH_INSERT_SIZE = CONFIG["batch_insert_size"]
MAX_WORKERS = min(CONFIG["max_workers"], psutil.cpu_count(logical=False))
USE_THREADS = CONFIG["use_threads"]
MIN_OBSERVATIONS = CONFIG["min_observations"]

# Factor configuration for all regions
FACTOR_CONFIGS = {
    "Equity_USA_1": [
        {"source": "db", "factors": ["MKT", "RF"], "region": "USA", "desired_factors": ["mkt-rf"]}
    ],
    "Equity_Global_1": [
        {"source": "db", "factors": ["MKT", "RF"], "region": "Global", "desired_factors": ["mkt-rf"]}
    ],
    "Equity_International_1": [
        {"source": "db", "factors": ["MKT", "RF"], "region": "International", "desired_factors": ["mkt-rf"]}
    ]
}

# Logging setup
logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler("factor_attribution.log"),
        logging.StreamHandler(sys.stdout)
    ],
    force=True
)
logger = logging.getLogger()
logger.handlers[1].stream = sys.stdout
logger.handlers[1].setLevel(logging.INFO)

# Section 2: Helper Functions
def category_to_region(category):
    mapping = {
        "US Equity Large Cap Blend": ("USA", "US Equity Large Cap Blend"),
        "US Equity Large Cap Growth": ("USA", "US Equity Large Cap Growth"),
        "US Equity Large Cap Value": ("USA", "US Equity Large Cap Value"),
        "US Equity Mid Cap": ("USA", "US Equity Mid Cap"),
        "US Equity Small Cap": ("USA", "US Equity Small Cap"),
        "Global Equity Large Cap": ("Global", "Global Equity Large Cap"),
        "Global Equity Mid/Small Cap": ("Global", "Global Equity Mid/Small Cap"),
        "Global Emerging Markets Equity": ("Global", "Global Emerging Markets Equity"),
        "Europe Equity Large Cap": ("International", "Europe Equity Large Cap"),
        "Asia Equity": ("International", "Asia Equity"),
        "Japan Equity": ("International", "Japan Equity"),
        "Emerging Markets Fixed Income": ("International", "Emerging Markets Fixed Income"),
        "US Fixed Income": ("USA", "US Fixed Income"),
        "US Municipal Fixed Income": ("USA", "US Municipal Fixed Income"),
        "Global Fixed Income": ("Global", "Global Fixed Income"),
        "Flexible Allocation": ("Global", "Flexible Allocation"),
        "Aggressive Allocation": ("Global", "Aggressive Allocation"),
        "Moderate Allocation": ("Global", "Moderate Allocation"),
        "Cautious Allocation": ("Global", "Cautious Allocation"),
        "Commodities Broad Basket": ("Global", "Commodities Broad Basket"),
        "Commodities Specified": ("Global", "Commodities Specified"),
        "Options Trading": ("USA", "Options Trading"),
        "Multialternative": ("Global", "Multialternative"),
        "Market Neutral": ("Global", "Market Neutral"),
        "Long/Short Equity": ("Global", "Long/Short Equity"),
        "Alternative Miscellaneous": ("Global", "Alternative Miscellaneous"),
        "Energy Sector Equity": ("USA", "Energy Sector Equity"),
        "Equity Miscellaneous": ("USA", "Equity Miscellaneous"),
        "Financials Sector Equity": ("USA", "Financials Sector Equity"),
        "Healthcare Sector Equity": ("USA", "Healthcare Sector Equity"),
        "Consumer Goods & Services Sector Equity": ("USA", "Consumer Goods & Services Sector Equity"),
        "Communications Sector Equity": ("USA", "Communications Sector Equity"),
        "Industrials Sector Equity": ("USA", "Industrials Sector Equity"),
        "Other Sector Equity": ("USA", "Other Sector Equity"),
        "Real Estate Sector Equity": ("USA", "Real Estate Sector Equity"),
        "Precious Metals Sector Equity": ("USA", "Precious Metals Sector Equity"),
        "Technology Sector Equity": ("USA", "Technology Sector Equity"),
        "Utilities Sector Equity": ("USA", "Utilities Sector Equity"),
        "Asia ex-Japan Equity": ("International", "Asia ex-Japan Equity"),
        "Australia & New Zealand Equity": ("International", "Australia & New Zealand Equity"),
        "Canadian Equity Large Cap": ("International", "Canadian Equity Large Cap"),
        "Europe Equity Mid/Small Cap": ("International", "Europe Equity Mid/Small Cap"),
        "Greater China Equity": ("International", "Greater China Equity"),
        "India Equity": ("International", "India Equity"),
        "Mexico Equity": ("International", "Mexico Equity"),
        "Korea Equity": ("International", "Korea Equity"),
        "Latin America Equity": ("International", "Latin America Equity"),
        "UK Equity Large Cap": ("International", "UK Equity Large Cap"),
        "Thailand Equity": ("International", "Thailand Equity"),
        "Convertibles": ("USA", "Convertibles"),
        "Fixed Income Miscellaneous": ("USA", "Fixed Income Miscellaneous"),
        "Allocation Miscellaneous": ("Global", "Allocation Miscellaneous")
    }
    result = mapping.get(category, ("USA", "Unknown"))
    if result[0] == "Unknown":
        logger.warning(f"Unmapped category '{category}' for fund; defaulting to USA")
    return result

@contextmanager
def database_transaction():
    connection = engine.connect()
    transaction = connection.begin()
    try:
        yield connection
        transaction.commit()
    except Exception as e:
        transaction.rollback()
        logger.error(f"Transaction failed: {e}")
        raise
    finally:
        connection.close()

def timer(func):
    @functools.wraps(func)
    def wrapper(*args, **kwargs):
        start_time = time.time()
        logger.debug(f"Starting {func.__name__}")
        result = func(*args, **kwargs)
        logger.info(f"{func.__name__} took {time.time() - start_time:.2f} seconds")
        return result
    return wrapper

# Section 3: Data Loading Functions
@timer
def load_fund_metadata():
    query = """
    SELECT 
        f.SymbolCUSIP, 
        f.Region, 
        f.YC_Global_Category_ID, 
        c.Global_Category_Name,
        f.YC_Category_ID,
        y.Category_Name,
        f.CWA_Broad_Category_ID,
        b.CWA_Broad_Category_Name
    FROM Funds_to_Screen f
    JOIN YC_Global_Category_List c ON f.YC_Global_Category_ID = c.ID
    JOIN YC_Category_List y ON f.YC_Category_ID = y.ID
    LEFT JOIN CWA_Broad_Category_List b ON f.CWA_Broad_Category_ID = b.ID
    """
    try:
        df = pd.read_sql(query, engine)
        logger.info(f"Loaded metadata for {len(df)} funds")
        df[["Region", "FactorProfile"]] = df["Global_Category_Name"].map(category_to_region).apply(pd.Series)
        if df["CWA_Broad_Category_Name"].isnull().all():
            logger.warning("CWA_Broad_Category_Name missing; some regressions may be skipped")
        return df.dropna(subset=["Region", "FactorProfile"])
    except Exception as e:
        logger.error(f"Error loading metadata: {e}")
        raise

@timer
def load_fund_returns(fund_ids=None):
    try:
        if not fund_ids:
            query = f"""
            SELECT SymbolCUSIP, Date, ReturnValue
            FROM Fund_Returns_Timeseries
            WHERE Metric = '{RETURN_METRIC.replace("'", "")}'
            """
        else:
            fund_ids = [fid for fid in fund_ids if isinstance(fid, str) and fid.strip()]
            if not fund_ids:
                logger.warning("No valid fund IDs provided")
                return pd.DataFrame()
            placeholders = ",".join([f"'{fid.replace('\'', '')}'" for fid in fund_ids])
            query = f"""
            SELECT SymbolCUSIP, Date, ReturnValue
            FROM Fund_Returns_Timeseries
            WHERE Metric = '{RETURN_METRIC.replace("'", "")}'
            AND SymbolCUSIP IN ({placeholders})
            """
            logger.debug(f"Querying returns for funds: {fund_ids}")
        
        chunks = []
        for chunk in pd.read_sql(query, engine, parse_dates=["Date"], chunksize=CHUNK_SIZE):
            logger.debug(f"Loaded chunk of {len(chunk)} rows")
            chunks.append(chunk)
        df = pd.concat(chunks) if chunks else pd.DataFrame()
        if df.empty:
            logger.warning("No returns data loaded")
            return pd.DataFrame()
        
        logger.info(f"Loaded returns for {len(df['SymbolCUSIP'].unique())} funds")
        pivoted = df.pivot(index="Date", columns="SymbolCUSIP", values="ReturnValue")
        # Enforce month-end dates and frequency
        pivoted.index = pd.to_datetime(pivoted.index) + pd.offsets.MonthEnd(0)
        pivoted = pivoted.asfreq('ME')
        for col in pivoted.columns:
            if not pd.api.types.is_numeric_dtype(pivoted[col]):
                logger.warning(f"Non-numeric returns for {col}; converting")
                pivoted[col] = pd.to_numeric(pivoted[col], errors='coerce')
        return pivoted
    except Exception as e:
        logger.error(f"Error loading returns: {e}")
        if fund_ids:
            logger.info("Attempting individual fund queries")
            chunks = []
            for fid in fund_ids:
                try:
                    query = f"""
                    SELECT SymbolCUSIP, Date, ReturnValue
                    FROM Fund_Returns_Timeseries
                    WHERE Metric = '{RETURN_METRIC.replace("'", "")}'
                    AND SymbolCUSIP = '{fid.replace("'", "")}'
                    """
                    chunk = pd.read_sql(query, engine, parse_dates=["Date"])
                    chunks.append(chunk)
                    logger.debug(f"Loaded returns for {fid}")
                except Exception as e2:
                    logger.warning(f"Failed to load returns for {fid}: {e2}")
            df = pd.concat(chunks) if chunks else pd.DataFrame()
            if df.empty:
                logger.warning("No returns data loaded in fallback")
                return pd.DataFrame()
            pivoted = df.pivot(index="Date", columns="SymbolCUSIP", values="ReturnValue")
            pivoted.index = pd.to_datetime(pivoted.index) + pd.offsets.MonthEnd(0)
            pivoted = pivoted.asfreq('ME')
            for col in pivoted.columns:
                pivoted[col] = pd.to_numeric(pivoted[col], errors='coerce')
            return pivoted
        raise

@timer
def load_factors(factor_config, region="Global", asset_class=None):
    source = factor_config.get("source")
    try:
        if source == "db":
            factor_in_clause = ','.join([f"'{f}'" for f in factor_config["factors"]])
            query = f"""
            SELECT date AS Date, factor AS Factor, value AS Value
            FROM {factor_config.get('table', 'factor_returns')}
            WHERE factor IN ({factor_in_clause})
            """
            params = []
            if region and not any(f.startswith('TSM-') or f == 'RF' for f in factor_config["factors"]):
                query += " AND region = ?"
                params.append(region)
            elif 'RF' in factor_config["factors"]:
                query += " AND region = 'USA'"
            if asset_class:
                query += " AND asset_class = ?"
                params.append(asset_class)
            df = pd.read_sql(query, engine, params=params, parse_dates=['Date'])
            if df.empty:
                logger.warning(f"No data for factors {factor_config['factors']} in region {region}")
                return pd.DataFrame()
            if df.duplicated(subset=['Date', 'Factor']).sum() > 0:
                logger.error(f"Duplicate factors {factor_config['factors']}")
                raise ValueError("Duplicate factor data")
            pivoted_df = df.pivot(index="Date", columns="Factor", values="Value").rename(
                columns={'MKT': 'mkt', 'RF': 'rf'}
            )
            # Enforce month-end dates and frequency
            pivoted_df.index = pd.to_datetime(pivoted_df.index) + pd.offsets.MonthEnd(0)
            pivoted_df = pivoted_df.asfreq('ME')
            logger.debug(f"Factors loaded: {pivoted_df.columns.tolist()}, dates: {pivoted_df.index.min()} to {pivoted_df.index.max()}")
            return pivoted_df
        else:
            logger.warning(f"Factor source {source} not implemented")
            return pd.DataFrame()
    except Exception as e:
        logger.error(f"Error loading factors {factor_config.get('factors', [])}: {e}")
        return pd.DataFrame()

# Section 4: Regression Functions
def run_rolling_regression(fund, returns, factors, regression_type, factor_set):
    results = []
    try:
        returns = pd.Series(returns).dropna()
        factors = pd.DataFrame(factors).dropna()
        returns.index = pd.to_datetime(returns.index, errors='coerce')
        factors.index = pd.to_datetime(factors.index, errors='coerce')
        returns = returns[returns.index.notnull()]
        factors = factors[factors.index.notnull()]
        
        if returns.empty or factors.empty:
            logger.warning(f"Empty data for {fund} ({factor_set})")
            return results
        
        # Data integrity check
        min_obs = int(min(ROLLING_PERIODS) * MIN_OBSERVATIONS)
        overlap_dates = returns.index.intersection(factors.index)
        if len(overlap_dates) < min_obs:
            logger.warning(f"Insufficient overlapping data for {fund} ({factor_set}): {len(overlap_dates)} < {min_obs}")
            return results
        
        logger.debug(f"Fund {fund}: {len(returns)} returns, {len(factors)} factors, {len(overlap_dates)} overlapping month-end dates")
        
        # Align indices
        factors = factors.loc[overlap_dates]
        returns = returns.loc[overlap_dates]
        
        for window in ROLLING_PERIODS:
            if len(returns) < min_obs:
                logger.warning(f"Insufficient data for {fund} ({factor_set}, window={window}): {len(returns)} < {min_obs}")
                continue
            
            # Roll over fixed periods
            for start_idx in range(len(returns) - window + 1):
                end_idx = start_idx + window
                y = returns.iloc[start_idx:end_idx]
                X = factors.iloc[start_idx:end_idx]
                if len(y) < min_obs or y.isnull().any() or X.isnull().any().any():
                    continue
                X_const = add_constant(X)
                model = OLS(y, X_const).fit()
                for factor in X.columns:
                    result = {
                        "SymbolCUSIP": fund,
                        "MonthEndDate": y.index[-1],
                        "RollPeriod": f"{window}m",
                        "Factor_Name": factor,
                        "Coefficient": model.params.get(factor, np.nan),
                        "P_Value": model.pvalues.get(factor, np.nan),
                        "T_Stat": model.tvalues.get(factor, np.nan),
                        "Standard_Error": model.bse.get(factor, np.nan),
                        "CI_Lower": model.conf_int().loc[factor][0] if factor in model.params else np.nan,
                        "CI_Upper": model.conf_int().loc[factor][1] if factor in model.params else np.nan,
                        "Adj_R2": model.rsquared_adj,
                        "Correlation": np.corrcoef(y, model.fittedvalues)[0, 1] if len(y) > 1 else np.nan,
                        "Regression_Type": regression_type,
                        "Factor_Set": factor_set
                    }
                    results.append(result)
                # Log sample result
                if results:
                    logger.debug(f"Sample regression for {fund}: Factor={results[-1]['Factor_Name']}, "
                                 f"Coefficient={results[-1]['Coefficient']:.4f}, P_Value={results[-1]['P_Value']:.4f}")
        
    except Exception as e:
        logger.error(f"Regression error for {fund} ({factor_set}): {e}")
    return results

# Section 5: Processing Functions
def process_regression(symbol, returns, factor_set_key):
    records = []
    factor_configs = FACTOR_CONFIGS.get(factor_set_key, [])
    if not factor_configs:
        logger.warning(f"No config for {factor_set_key}")
        return records
    
    try:
        factors_list = [load_factors(config, region=config.get("region", "Global")) for config in factor_configs]
        factors = pd.concat([f for f in factors_list if not f.empty], axis=1).dropna()
        if factors.empty:
            logger.warning(f"No factors for {symbol} ({factor_set_key})")
            return records
        
        if 'mkt' in factors.columns and 'rf' in factors.columns:
            factors['mkt-rf'] = factors['mkt'] - factors['rf']
        
        records.extend(run_rolling_regression(symbol, returns, factors, "OLS", factor_set_key))
    except Exception as e:
        logger.error(f"Error processing {symbol} ({factor_set_key}): {e}")
    
    return records

def process_fund(fund_data):
    records = []
    symbol = fund_data["SymbolCUSIP"]
    category = fund_data["Global_Category_Name"]
    returns = pd.Series(fund_data["returns"]).dropna()
    
    logger.debug(f"Processing fund {symbol}, category: {category}")
    
    if returns.empty:
        logger.info(f"No returns for {symbol}")
        return records
    
    region, profile = category_to_region(category)
    logger.debug(f"Fund {symbol} mapped to region: {region}, profile: {profile}")
    
    # Assign regression set based on region
    regression_sets = {
        "USA": ["Equity_USA_1"],
        "Global": ["Equity_Global_1"],
        "International": ["Equity_International_1"]
    }.get(region, ["Equity_USA_1"])  # Default Unknown to USA
    
    for factor_set in regression_sets:
        records.extend(process_regression(symbol, returns, factor_set))
    
    logger.info(f"Generated {len(records)} regression records for {symbol}")
    return records

def process_region(region, fund_data_list):
    records = []
    logger.info(f"Processing {len(fund_data_list)} funds in {region}")
    
    with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
        future_to_fund = {executor.submit(process_fund, fund_data): fund_data["SymbolCUSIP"] for fund_data in fund_data_list}
        for future in tqdm(future_to_fund, total=len(fund_data_list), desc=f"Processing {region}", file=sys.stdout):
            try:
                records.extend(future.result())
            except Exception as e:
                logger.error(f"Error processing {future_to_fund[future]}: {e}")
    
    logger.info(f"Region {region} generated {len(records)} total records")
    if not DRY_RUN:
        insert_batch(records)
    
    return records

# Section 6: Main Pipeline
@timer
def main():
    logger.info("Starting main pipeline")
    try:
        fund_meta = load_fund_metadata()
    except Exception as e:
        logger.error(f"Failed to load metadata: {e}")
        return {"error": str(e)}
    
    regions = fund_meta["Region"].unique()
    logger.info(f"Total funds: {len(fund_meta)}, Regions: {regions}")
    
    fund_ids = fund_meta["SymbolCUSIP"].tolist()
    if SAMPLE_DRY_RUN:
        fund_ids = random.sample(fund_ids, min(SAMPLE_SIZE, len(fund_ids)))
        logger.info(f"Sampled {len(fund_ids)} funds: {fund_ids}")
    
    try:
        returns = load_fund_returns(fund_ids)
    except Exception as e:
        logger.error(f"Failed to load returns: {e}")
        return {"error": str(e)}
    
    fund_data_list = [
        {
            "SymbolCUSIP": row["SymbolCUSIP"],
            "Global_Category_Name": row["Global_Category_Name"],
            "returns": returns[row["SymbolCUSIP"]].to_dict()
        }
        for _, row in fund_meta.iterrows() if row["SymbolCUSIP"] in returns.columns
    ]
    
    summary = {"total_funds": len(fund_data_list), "regions": {}, "errors": 0}
    for region in sorted(set(regions) - {'Unknown'} | {'USA'}):  # Exclude Unknown, ensure USA
        region_funds = [fd for fd in fund_data_list if fund_meta[fund_meta["SymbolCUSIP"] == fd["SymbolCUSIP"]]["Region"].iloc[0] == region]
        if SAMPLE_DRY_RUN and len(region_funds) > SAMPLE_SIZE:
            region_funds = random.sample(region_funds, SAMPLE_SIZE)
            logger.info(f"Sampled {len(region_funds)} funds for {region}")
        records = process_region(region, region_funds)
        summary["regions"][region] = {"funds_processed": len(region_funds), "records": len(records)}
    
    logger.info(f"Pipeline summary: {summary}")
    return summary

# Section 7: Database Output
def insert_batch(records):
    try:
        df = pd.DataFrame(records)
        with database_transaction() as connection:
            df.to_sql("AQRR_Factor_Attribution", connection, if_exists="append", index=False, method="multi")
        logger.info(f"Inserted {len(df)} records to database")
    except Exception as e:
        logger.error(f"Error inserting batch: {e}")
        raise

if __name__ == "__main__":
    try:
        main()
    except Exception as e:
        logger.error(f"Main execution failed: {e}")
        raise
# Out:
# 2025-04-13 20:56:37,116 - INFO - Starting main pipeline
# 2025-04-13 20:56:37,297 - INFO - Loaded metadata for 5584 funds
# 2025-04-13 20:56:37,573 - INFO - load_fund_metadata took 0.46 seconds
# 2025-04-13 20:56:37,574 - INFO - Total funds: 5584, Regions: ['Global' 'USA' 'International']
# 2025-04-13 20:56:37,574 - INFO - Sampled 10 funds: ['FPRO', 'SPEU', 'BFGIX', 'PCGYX', 'CGIIX', 'FIBR', 'FUSAX', 'BFIX', 'MBNE', 'RVER']
# 2025-04-13 20:56:37,603 - INFO - Loaded returns for 10 funds
# 2025-04-13 20:56:37,608 - INFO - load_fund_returns took 0.03 seconds
# 2025-04-13 20:56:37,733 - INFO - Processing 1 funds in Global
# Processing Global:   0%|          | 0/1 [00:00<?, ?it/s]2025-04-13 20:56:37,763 - INFO - load_factors took 0.03 seconds
# 2025-04-13 20:56:38,227 - INFO - Generated 327 regression records for CGIIX
# Processing Global: 100%|██████████| 1/1 [00:00<00:00,  2.03it/s]
# 2025-04-13 20:56:38,231 - INFO - Region Global generated 327 total records
# 2025-04-13 20:56:38,235 - INFO - Processing 1 funds in International
# Processing International:   0%|          | 0/1 [00:00<?, ?it/s]2025-04-13 20:56:38,261 - INFO - load_factors took 0.02 seconds
# 2025-04-13 20:56:38,744 - INFO - Generated 327 regression records for SPEU
# Processing International: 100%|██████████| 1/1 [00:00<00:00,  1.98it/s]
# 2025-04-13 20:56:38,746 - INFO - Region International generated 327 total records
# 2025-04-13 20:56:38,753 - INFO - Processing 8 funds in USA
# Processing USA:   0%|          | 0/8 [00:00<?, ?it/s]2025-04-13 20:56:39,049 - INFO - load_factors took 0.28 seconds
# 2025-04-13 20:56:39,127 - INFO - load_factors took 0.37 seconds
# 2025-04-13 20:56:39,171 - INFO - load_factors took 0.41 seconds
# 2025-04-13 20:56:39,343 - INFO - load_factors took 0.57 seconds
# 2025-04-13 20:56:39,561 - INFO - load_factors took 0.80 seconds
# 2025-04-13 20:56:39,671 - INFO - Generated 63 regression records for MBNE
# Processing USA:  12%|█▎        | 1/8 [00:00<00:06,  1.08it/s]2025-04-13 20:56:39,700 - INFO - load_factors took 0.93 seconds
# 2025-04-13 20:56:39,734 - INFO - load_factors took 0.97 seconds
# 2025-04-13 20:56:40,294 - INFO - Generated 69 regression records for BFIX
# 2025-04-13 20:56:40,329 - INFO - load_factors took 1.56 seconds
# 2025-04-13 20:56:40,360 - WARNING - Insufficient overlapping data for RVER (Equity_USA_1): 8 < 9
# 2025-04-13 20:56:40,380 - INFO - Generated 0 regression records for RVER
# 2025-04-13 20:56:40,693 - INFO - Generated 105 regression records for FPRO
# 2025-04-13 20:56:41,386 - INFO - Generated 327 regression records for FUSAX
# 2025-04-13 20:56:41,548 - INFO - Generated 324 regression records for BFGIX
# Processing USA:  25%|██▌       | 2/8 [00:02<00:08,  1.47s/it]2025-04-13 20:56:41,638 - INFO - Generated 327 regression records for PCGYX
# 2025-04-13 20:56:41,718 - INFO - Generated 321 regression records for FIBR
# Processing USA: 100%|██████████| 8/8 [00:02<00:00,  2.72it/s]
# 2025-04-13 20:56:41,719 - INFO - Region USA generated 1536 total records
# 2025-04-13 20:56:41,720 - INFO - Pipeline summary: {'total_funds': 10, 'regions': {'Global': {'funds_processed': 1, 'records': 327}, 'International': {'funds_processed': 1, 'records': 327}, 'USA': {'funds_processed': 8, 'records': 1536}}, 'errors': 0}
# 2025-04-13 20:56:41,722 - INFO - main took 4.61 seconds

# %%
import pandas as pd
import numpy as np
import os
import random
import logging
from datetime import timedelta, datetime
from dateutil.relativedelta import relativedelta
from concurrent.futures import ThreadPoolExecutor
from sqlalchemy import create_engine
from tqdm import tqdm
from statsmodels.regression.linear_model import OLS
from statsmodels.tools.tools import add_constant
import statsmodels.api as sm
import time
import functools
from contextlib import contextmanager
import sys

# Section 1: Configuration and Setup
CONFIG = {
    "database": {
        "server": "JULIANS_LAPTOP\\SQLEXPRESS",
        "database": "CWA_Fund_Database",
        "driver": "ODBC Driver 18 for SQL Server"
    },
    "return_metric": "1 Month Return",
    "rolling_periods": [12, 24, 36, 48, 60],
    "dry_run": True,
    "sample_dry_run": True,
    "sample_size": 10,
    "chunk_size": 1000,
    "batch_insert_size": 5000,
    "max_workers": 8,
    "use_threads": True,
    "query_timeout": 30
}

CONNECTION_STRING = (
    f"mssql+pyodbc://{CONFIG['database']['server']}/{CONFIG['database']['database']}"
    f"?driver={CONFIG['database']['driver']}&trusted_connection=yes&TrustServerCertificate=yes"
)
try:
    engine = create_engine(CONNECTION_STRING, connect_args={"timeout": CONFIG["query_timeout"]})
except Exception as e:
    print(f"Database connection failed: {e}")
    raise

RETURN_METRIC = CONFIG["return_metric"]
ROLLING_PERIODS = CONFIG["rolling_periods"]
DRY_RUN = CONFIG["dry_run"]
SAMPLE_DRY_RUN = CONFIG["sample_dry_run"]
SAMPLE_SIZE = CONFIG["sample_size"]
CHUNK_SIZE = CONFIG["chunk_size"]
BATCH_INSERT_SIZE = CONFIG["batch_insert_size"]
MAX_WORKERS = min(CONFIG["max_workers"], psutil.cpu_count(logical=False))
USE_THREADS = CONFIG["use_threads"]

# Factor configuration for all regions
FACTOR_CONFIGS = {
    "Equity_USA_1": [
        {"source": "db", "factors": ["MKT", "RF"], "region": "USA", "desired_factors": ["mkt-rf"]}
    ],
    "Equity_Global_1": [
        {"source": "db", "factors": ["MKT", "RF"], "region": "Global", "desired_factors": ["mkt-rf"]}
    ],
    "Equity_International_1": [
        {"source": "db", "factors": ["MKT", "RF"], "region": "International", "desired_factors": ["mkt-rf"]}
    ]
}

# Logging setup
logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler("factor_attribution.log"),
        logging.StreamHandler(sys.stdout)
    ],
    force=True
)
logger = logging.getLogger()
logger.handlers[1].stream = sys.stdout
logger.handlers[1].setLevel(logging.INFO)

# Section 2: Helper Functions
def category_to_region(category):
    mapping = {
        "US Equity Large Cap Blend": ("USA", "US Equity Large Cap Blend"),
        "US Equity Large Cap Growth": ("USA", "US Equity Large Cap Growth"),
        "US Equity Large Cap Value": ("USA", "US Equity Large Cap Value"),
        "US Equity Mid Cap": ("USA", "US Equity Mid Cap"),
        "US Equity Small Cap": ("USA", "US Equity Small Cap"),
        "Global Equity Large Cap": ("Global", "Global Equity Large Cap"),
        "Global Equity Mid/Small Cap": ("Global", "Global Equity Mid/Small Cap"),
        "Global Emerging Markets Equity": ("Global", "Global Emerging Markets Equity"),
        "Europe Equity Large Cap": ("International", "Europe Equity Large Cap"),
        "Asia Equity": ("International", "Asia Equity"),
        "Japan Equity": ("International", "Japan Equity"),
        "Emerging Markets Fixed Income": ("International", "Emerging Markets Fixed Income"),
        "US Fixed Income": ("USA", "US Fixed Income"),
        "US Municipal Fixed Income": ("USA", "US Municipal Fixed Income"),
        "Global Fixed Income": ("Global", "Global Fixed Income"),
        "Flexible Allocation": ("Global", "Flexible Allocation"),
        "Aggressive Allocation": ("Global", "Aggressive Allocation"),
        "Moderate Allocation": ("Global", "Moderate Allocation"),
        "Cautious Allocation": ("Global", "Cautious Allocation"),
        "Commodities Broad Basket": ("Global", "Commodities Broad Basket"),
        "Commodities Specified": ("Global", "Commodities Specified"),
        "Options Trading": ("USA", "Options Trading"),
        "Multialternative": ("Global", "Multialternative"),
        "Market Neutral": ("Global", "Market Neutral"),
        "Long/Short Equity": ("Global", "Long/Short Equity"),
        "Alternative Miscellaneous": ("Global", "Alternative Miscellaneous"),
        "Energy Sector Equity": ("USA", "Energy Sector Equity"),
        "Equity Miscellaneous": ("USA", "Equity Miscellaneous"),
        "Financials Sector Equity": ("USA", "Financials Sector Equity"),
        "Healthcare Sector Equity": ("USA", "Healthcare Sector Equity"),
        "Consumer Goods & Services Sector Equity": ("USA", "Consumer Goods & Services Sector Equity"),
        "Communications Sector Equity": ("USA", "Communications Sector Equity"),
        "Industrials Sector Equity": ("USA", "Industrials Sector Equity"),
        "Other Sector Equity": ("USA", "Other Sector Equity"),
        "Real Estate Sector Equity": ("USA", "Real Estate Sector Equity"),
        "Precious Metals Sector Equity": ("USA", "Precious Metals Sector Equity"),
        "Technology Sector Equity": ("USA", "Technology Sector Equity"),
        "Utilities Sector Equity": ("USA", "Utilities Sector Equity"),
        "Natural Resources Sector Equity": ("USA", "Natural Resources Sector Equity"),
        "Infrastructure Sector Equity": ("USA", "Infrastructure Sector Equity"),
        "Trading Tools": ("USA", "Trading Tools"),
        "Asia ex-Japan Equity": ("International", "Asia ex-Japan Equity"),
        "Australia & New Zealand Equity": ("International", "Australia & New Zealand Equity"),
        "Canadian Equity Large Cap": ("International", "Canadian Equity Large Cap"),
        "Europe Equity Mid/Small Cap": ("International", "Europe Equity Mid/Small Cap"),
        "Greater China Equity": ("International", "Greater China Equity"),
        "India Equity": ("International", "India Equity"),
        "Mexico Equity": ("International", "Mexico Equity"),
        "Korea Equity": ("International", "Korea Equity"),
        "Latin America Equity": ("International", "Latin America Equity"),
        "UK Equity Large Cap": ("International", "UK Equity Large Cap"),
        "Thailand Equity": ("International", "Thailand Equity"),
        "Convertibles": ("USA", "Convertibles"),
        "Fixed Income Miscellaneous": ("USA", "Fixed Income Miscellaneous"),
        "Allocation Miscellaneous": ("Global", "Allocation Miscellaneous")
    }
    result = mapping.get(category, ("USA", "Unknown"))
    if result[1] == "Unknown":
        logger.warning(f"UnMapped category '{category}' for fund; defaulting to USA")
    return result

@contextmanager
def database_transaction():
    connection = engine.connect()
    transaction = connection.begin()
    try:
        yield connection
        transaction.commit()
    except Exception as e:
        transaction.rollback()
        logger.error(f"Transaction failed: {e}")
        raise
    finally:
        connection.close()

def timer(func):
    @functools.wraps(func)
    def wrapper(*args, **kwargs):
        start_time = time.time()
        logger.debug(f"Starting {func.__name__}")
        result = func(*args, **kwargs)
        logger.info(f"{func.__name__} took {time.time() - start_time:.2f} seconds")
        return result
    return wrapper

# Section 3: Data Loading Functions
@timer
def load_fund_metadata():
    query = """
    SELECT 
        f.SymbolCUSIP, 
        f.Region, 
        f.YC_Global_Category_ID, 
        c.Global_Category_Name,
        f.YC_Category_ID,
        y.Category_Name,
        f.CWA_Broad_Category_ID,
        b.CWA_Broad_Category_Name
    FROM Funds_to_Screen f
    JOIN YC_Global_Category_List c ON f.YC_Global_Category_ID = c.ID
    JOIN YC_Category_List y ON f.YC_Category_ID = y.ID
    LEFT JOIN CWA_Broad_Category_List b ON f.CWA_Broad_Category_ID = b.ID
    """
    try:
        df = pd.read_sql(query, engine)
        logger.info(f"Loaded metadata for {len(df)} funds")
        df[["Region", "FactorProfile"]] = df["Global_Category_Name"].map(category_to_region).apply(pd.Series)
        if df["CWA_Broad_Category_Name"].isnull().all():
            logger.warning("CWA_Broad_Category_Name missing; some regressions may be skipped")
        return df.dropna(subset=["Region", "FactorProfile"])
    except Exception as e:
        logger.error(f"Error loading metadata: {e}")
        raise

@timer
def load_fund_returns(fund_ids=None):
    try:
        if not fund_ids:
            query = f"""
            SELECT SymbolCUSIP, Date, ReturnValue
            FROM Fund_Returns_Timeseries
            WHERE Metric = '{RETURN_METRIC.replace("'", "")}'
            """
        else:
            fund_ids = [fid for fid in fund_ids if isinstance(fid, str) and fid.strip()]
            if not fund_ids:
                logger.warning("No valid fund IDs provided")
                return pd.DataFrame()
            placeholders = ",".join([f"'{fid.replace('\'', '')}'" for fid in fund_ids])
            query = f"""
            SELECT SymbolCUSIP, Date, ReturnValue
            FROM Fund_Returns_Timeseries
            WHERE Metric = '{RETURN_METRIC.replace("'", "")}'
            AND SymbolCUSIP IN ({placeholders})
            """
            logger.debug(f"Querying returns for funds: {fund_ids}")
        
        chunks = []
        for chunk in pd.read_sql(query, engine, parse_dates=["Date"], chunksize=CHUNK_SIZE):
            logger.debug(f"Loaded chunk of {len(chunk)} rows")
            chunks.append(chunk)
        df = pd.concat(chunks) if chunks else pd.DataFrame()
        if df.empty:
            logger.warning("No returns data loaded")
            return pd.DataFrame()
        
        logger.info(f"Loaded returns for {len(df['SymbolCUSIP'].unique())} funds")
        pivoted = df.pivot(index="Date", columns="SymbolCUSIP", values="ReturnValue")
        # Enforce month-end dates and frequency
        pivoted.index = pd.to_datetime(pivoted.index) + pd.offsets.MonthEnd(0)
        pivoted.index = pivoted.index.drop_duplicates()
        pivoted = pivoted.asfreq('ME')
        for col in pivoted.columns:
            if not pd.api.types.is_numeric_dtype(pivoted[col]):
                logger.warning(f"Non-numeric returns for {col}; converting")
                pivoted[col] = pd.to_numeric(pivoted[col], errors='coerce')
        return pivoted
    except Exception as e:
        logger.error(f"Error loading returns: {e}")
        if fund_ids:
            logger.info("Attempting individual fund queries")
            chunks = []
            for fid in fund_ids:
                try:
                    query = f"""
                    SELECT SymbolCUSIP, Date, ReturnValue
                    FROM Fund_Returns_Timeseries
                    WHERE Metric = '{RETURN_METRIC.replace("'", "")}'
                    AND SymbolCUSIP = '{fid.replace("'", "")}'
                    """
                    chunk = pd.read_sql(query, engine, parse_dates=["Date"])
                    chunks.append(chunk)
                    logger.debug(f"Loaded returns for {fid}")
                except Exception as e2:
                    logger.warning(f"Failed to load returns for {fid}: {e2}")
            df = pd.concat(chunks) if chunks else pd.DataFrame()
            if df.empty:
                logger.warning("No returns data loaded in fallback")
                return pd.DataFrame()
            pivoted = df.pivot(index="Date", columns="SymbolCUSIP", values="ReturnValue")
            pivoted.index = pd.to_datetime(pivoted.index) + pd.offsets.MonthEnd(0)
            pivoted.index = pivoted.index.drop_duplicates()
            pivoted = pivoted.asfreq('ME')
            for col in pivoted.columns:
                pivoted[col] = pd.to_numeric(pivoted[col], errors='coerce')
            return pivoted
        raise

@timer
def load_factors(factor_config, region="Global", asset_class=None):
    source = factor_config.get("source")
    try:
        if source == "db":
            factor_in_clause = ','.join([f"'{f}'" for f in factor_config["factors"]])
            query = f"""
            SELECT date AS Date, factor AS Factor, value AS Value
            FROM {factor_config.get('table', 'factor_returns')}
            WHERE factor IN ({factor_in_clause})
            """
            params = []
            if region and not any(f.startswith('TSM-') or f == 'RF' for f in factor_config["factors"]):
                query += " AND region = ?"
                params.append(region)
            elif 'RF' in factor_config["factors"]:
                query += " AND region = 'USA'"
            if asset_class:
                query += " AND asset_class = ?"
                params.append(asset_class)
            df = pd.read_sql(query, engine, params=params, parse_dates=['Date'])
            if df.empty:
                logger.warning(f"No data for factors {factor_config['factors']} in region {region}")
                return pd.DataFrame()
            if df.duplicated(subset=['Date', 'Factor']).sum() > 0:
                logger.error(f"Duplicate factors {factor_config['factors']}")
                raise ValueError("Duplicate factor data")
            pivoted_df = df.pivot(index="Date", columns="Factor", values="Value").rename(
                columns={'MKT': 'mkt', 'RF': 'rf'}
            )
            # Enforce month-end dates and frequency
            pivoted_df.index = pd.to_datetime(pivoted_df.index) + pd.offsets.MonthEnd(0)
            pivoted_df.index = pivoted_df.index.drop_duplicates()
            pivoted_df = pivoted_df.asfreq('ME')
            logger.debug(f"Factors loaded: {pivoted_df.columns.tolist()}, dates: {pivoted_df.index.min()} to {pivoted_df.index.max()}")
            return pivoted_df
        else:
            logger.warning(f"Factor source {source} not implemented")
            return pd.DataFrame()
    except Exception as e:
        logger.error(f"Error loading factors {factor_config.get('factors', [])}: {e}")
        return pd.DataFrame()

# Section 4: Regression Functions
def run_rolling_regression(fund, returns, factors, regression_type, factor_set):
    results = []
    try:
        returns = pd.Series(returns).dropna()
        factors = pd.DataFrame(factors).dropna()
        returns.index = pd.to_datetime(returns.index, errors='coerce')
        factors.index = pd.to_datetime(factors.index, errors='coerce')
        returns = returns[returns.index.notnull()]
        factors = factors[factors.index.notnull()]
        
        if returns.empty or factors.empty:
            logger.warning(f"Empty data for {fund} ({factor_set})")
            return results
        
        # Data integrity check
        overlap_dates = returns.index.intersection(factors.index)
        months_available = len(overlap_dates)
        date_start = overlap_dates.min().strftime('%Y-%m-%d') if months_available > 0 else "none"
        date_end = overlap_dates.max().strftime('%Y-%m-%d') if months_available > 0 else "none"
        
        # Check for smallest window
        min_window = min(ROLLING_PERIODS)
        if months_available < min_window:
            logger.warning(f"Fund {fund} ({factor_set}) skipped: {months_available} months available "
                           f"from {date_start} to {date_end}, need {min_window} for smallest window")
            return results
        
        # Log index details for debugging
        logger.debug(f"Fund {fund}: {len(returns)} returns, {len(factors)} factors, {len(overlap_dates)} overlapping dates")
        
        # Align indices with reindex
        factors = factors.reindex(overlap_dates)
        returns = returns.reindex(overlap_dates)
        
        for window in ROLLING_PERIODS:
            if months_available < window:
                logger.warning(f"Fund {fund} ({factor_set}, window={window}m) skipped: {months_available} months available "
                               f"from {date_start} to {date_end}, need {window}")
                continue
            
            # Roll over fixed periods
            for start_idx in range(len(returns) - window + 1):
                end_idx = start_idx + window
                y = returns.iloc[start_idx:end_idx]
                X = factors.iloc[start_idx:end_idx]
                if len(y) < window or y.isnull().any() or X.isnull().any().any():
                    continue
                X_const = add_constant(X)
                model = OLS(y, X_const).fit()
                for factor in X.columns:
                    result = {
                        "SymbolCUSIP": fund,
                        "MonthEndDate": y.index[-1],
                        "RollPeriod": f"{window}m",
                        "Factor_Name": factor,
                        "Coefficient": model.params.get(factor, np.nan),
                        "P_Value": model.pvalues.get(factor, np.nan),
                        "T_Stat": model.tvalues.get(factor, np.nan),
                        "Standard_Error": model.bse.get(factor, np.nan),
                        "CI_Lower": model.conf_int().loc[factor][0] if factor in model.params else np.nan,
                        "CI_Upper": model.conf_int().loc[factor][1] if factor in model.params else np.nan,
                        "Adj_R2": model.rsquared_adj,
                        "Correlation": np.corrcoef(y, model.fittedvalues)[0, 1] if len(y) > 1 else np.nan,
                        "Regression_Type": regression_type,
                        "Factor_Set": factor_set
                    }
                    results.append(result)
                # Log sample result
                if results:
                    logger.debug(f"Sample regression for {fund}: Factor={results[-1]['Factor_Name']}, "
                                 f"Coefficient={results[-1]['Coefficient']:.4f}, P_Value={results[-1]['P_Value']:.4f}")
        
    except Exception as e:
        logger.error(f"Regression error for {fund} ({factor_set}): {e}")
    return results

# Section 5: Processing Functions
def process_regression(symbol, returns, factor_set_key):
    records = []
    factor_configs = FACTOR_CONFIGS.get(factor_set_key, [])
    if not factor_configs:
        logger.warning(f"No config for {factor_set_key}")
        return records
    
    try:
        factors_list = [load_factors(config, region=config.get("region", "Global")) for config in factor_configs]
        factors = pd.concat([f for f in factors_list if not f.empty], axis=1).dropna()
        if factors.empty:
            logger.warning(f"No factors for {symbol} ({factor_set_key})")
            return records
        
        if 'mkt' in factors.columns and 'rf' in factors.columns:
            factors['mkt-rf'] = factors['mkt'] - factors['rf']
        
        records.extend(run_rolling_regression(symbol, returns, factors, "OLS", factor_set_key))
    except Exception as e:
        logger.error(f"Error processing {symbol} ({factor_set_key}): {e}")
    
    return records

def process_fund(fund_data):
    records = []
    symbol = fund_data["SymbolCUSIP"]
    category = fund_data["Global_Category_Name"]
    returns = pd.Series(fund_data["returns"]).dropna()
    
    logger.debug(f"Processing fund {symbol}, category: {category}")
    
    if returns.empty:
        logger.info(f"No returns for {symbol}")
        return records
    
    region, profile = category_to_region(category)
    logger.debug(f"Fund {symbol} mapped to region: {region}, profile: {profile}")
    
    # Assign regression set based on region
    regression_sets = {
        "USA": ["Equity_USA_1"],
        "Global": ["Equity_Global_1"],
        "International": ["Equity_International_1"]
    }.get(region, ["Equity_USA_1"])  # Default Unknown to USA
    
    for factor_set in regression_sets:
        records.extend(process_regression(symbol, returns, factor_set))
    
    logger.info(f"Generated {len(records)} regression records for {symbol}")
    return records

def process_region(region, fund_data_list):
    records = []
    logger.info(f"Processing {len(fund_data_list)} funds in {region}")
    
    with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
        future_to_fund = {executor.submit(process_fund, fund_data): fund_data["SymbolCUSIP"] for fund_data in fund_data_list}
        for future in tqdm(future_to_fund, total=len(fund_data_list), desc=f"Processing {region}", file=sys.stdout):
            try:
                records.extend(future.result())
            except Exception as e:
                logger.error(f"Error processing {future_to_fund[future]}: {e}")
    
    logger.info(f"Region {region} generated {len(records)} total records")
    if not DRY_RUN:
        insert_batch(records)
    
    return records

# Section 6: Main Pipeline
@timer
def main():
    logger.info("Starting main pipeline")
    try:
        fund_meta = load_fund_metadata()
    except Exception as e:
        logger.error(f"Failed to load metadata: {e}")
        return {"error": str(e)}
    
    regions = fund_meta["Region"].unique()
    logger.info(f"Total funds: {len(fund_meta)}, Regions: {regions}")
    
    fund_ids = fund_meta["SymbolCUSIP"].tolist()
    if SAMPLE_DRY_RUN:
        fund_ids = random.sample(fund_ids, min(SAMPLE_SIZE, len(fund_ids)))
        logger.info(f"Sampled {len(fund_ids)} funds: {fund_ids}")
    
    try:
        returns = load_fund_returns(fund_ids)
    except Exception as e:
        logger.error(f"Failed to load returns: {e}")
        return {"error": str(e)}
    
    fund_data_list = [
        {
            "SymbolCUSIP": row["SymbolCUSIP"],
            "Global_Category_Name": row["Global_Category_Name"],
            "returns": returns[row["SymbolCUSIP"]].to_dict()
        }
        for _, row in fund_meta.iterrows() if row["SymbolCUSIP"] in returns.columns
    ]
    
    summary = {"total_funds": len(fund_data_list), "regions": {}, "errors": 0}
    for region in ['Global', 'USA', 'International']:  # Explicitly process only these regions
        region_funds = [fd for fd in fund_data_list if fund_meta[fund_meta["SymbolCUSIP"] == fd["SymbolCUSIP"]]["Region"].iloc[0] == region]
        if SAMPLE_DRY_RUN and len(region_funds) > SAMPLE_SIZE:
            region_funds = random.sample(region_funds, SAMPLE_SIZE)
            logger.info(f"Sampled {len(region_funds)} funds for {region}")
        records = process_region(region, region_funds)
        summary["regions"][region] = {"funds_processed": len(region_funds), "records": len(records)}
    
    logger.info(f"Pipeline summary: {summary}")
    return summary

# Section 7: Database Output
def insert_batch(records):
    try:
        df = pd.DataFrame(records)
        with database_transaction() as connection:
            df.to_sql("AQRR_Factor_Attribution", connection, if_exists="append", index=False, method="multi")
        logger.info(f"Inserted {len(df)} records to database")
    except Exception as e:
        logger.error(f"Error inserting batch: {e}")
        raise

if __name__ == "__main__":
    try:
        main()
    except Exception as e:
        logger.error(f"Main execution failed: {e}")
        raise
# Out:
# 2025-04-13 21:59:46,933 - INFO - Starting main pipeline
# 2025-04-13 21:59:47,067 - INFO - Loaded metadata for 5584 funds
# 2025-04-13 21:59:47,382 - INFO - load_fund_metadata took 0.45 seconds
# 2025-04-13 21:59:47,383 - INFO - Total funds: 5584, Regions: ['Global' 'USA' 'International']
# 2025-04-13 21:59:47,384 - INFO - Sampled 10 funds: ['RHRX', 'HYDB', 'LPXIX', 'UFO', 'MNOIX', 'KNOW', 'VEVIX', 'QUAYX', 'RSHO', 'JIESX']
# 2025-04-13 21:59:47,412 - INFO - Loaded returns for 10 funds
# 2025-04-13 21:59:47,416 - INFO - load_fund_returns took 0.03 seconds
# 2025-04-13 21:59:47,561 - INFO - Processing 3 funds in Global
# Processing Global:   0%|          | 0/3 [00:00<?, ?it/s]2025-04-13 21:59:47,687 - INFO - load_factors took 0.12 seconds
# 2025-04-13 21:59:47,714 - WARNING - Fund KNOW (Equity_Global_1) skipped: 10 months available from 2024-03-31 to 2024-12-31, need 12 for smallest window
# 2025-04-13 21:59:47,725 - INFO - Generated 0 regression records for KNOW
# 2025-04-13 21:59:47,725 - INFO - load_factors took 0.16 seconds
# 2025-04-13 21:59:47,741 - INFO - load_factors took 0.17 seconds
# 2025-04-13 21:59:48,147 - WARNING - Fund RHRX (Equity_Global_1, window=48m) skipped: 37 months available from 2021-12-31 to 2024-12-31, need 48
# 2025-04-13 21:59:48,156 - WARNING - Fund RHRX (Equity_Global_1, window=60m) skipped: 37 months available from 2021-12-31 to 2024-12-31, need 60
# 2025-04-13 21:59:48,165 - INFO - Generated 126 regression records for RHRX
# Processing Global:  33%|███▎      | 1/3 [00:00<00:01,  1.66it/s]2025-04-13 21:59:49,959 - INFO - Generated 1275 regression records for JIESX
# Processing Global: 100%|██████████| 3/3 [00:02<00:00,  1.25it/s]
# 2025-04-13 21:59:49,962 - INFO - Region Global generated 1401 total records
# 2025-04-13 21:59:49,967 - INFO - Processing 7 funds in USA
# Processing USA:   0%|          | 0/7 [00:00<?, ?it/s]2025-04-13 21:59:50,246 - INFO - load_factors took 0.27 seconds
# 2025-04-13 21:59:50,263 - INFO - load_factors took 0.29 seconds
# 2025-04-13 21:59:50,277 - INFO - load_factors took 0.30 seconds
# 2025-04-13 21:59:50,376 - INFO - load_factors took 0.39 seconds
# 2025-04-13 21:59:50,456 - INFO - load_factors took 0.48 seconds
# 2025-04-13 21:59:50,459 - WARNING - Fund RSHO (Equity_USA_1, window=24m) skipped: 19 months available from 2023-06-30 to 2024-12-31, need 24
# 2025-04-13 21:59:50,476 - WARNING - Fund RSHO (Equity_USA_1, window=36m) skipped: 19 months available from 2023-06-30 to 2024-12-31, need 36
# 2025-04-13 21:59:50,487 - WARNING - Fund RSHO (Equity_USA_1, window=48m) skipped: 19 months available from 2023-06-30 to 2024-12-31, need 48
# 2025-04-13 21:59:50,503 - WARNING - Fund RSHO (Equity_USA_1, window=60m) skipped: 19 months available from 2023-06-30 to 2024-12-31, need 60
# 2025-04-13 21:59:50,521 - INFO - Generated 24 regression records for RSHO
# 2025-04-13 21:59:50,628 - INFO - load_factors took 0.65 seconds
# 2025-04-13 21:59:50,646 - INFO - load_factors took 0.67 seconds
# 2025-04-13 21:59:55,300 - INFO - Generated 495 regression records for UFO
# Processing USA:  14%|█▍        | 1/7 [00:05<00:31,  5.33s/it]2025-04-13 21:59:57,872 - INFO - Generated 810 regression records for HYDB
# Processing USA:  43%|████▎     | 3/7 [00:07<00:09,  2.33s/it]2025-04-13 22:00:00,451 - INFO - Generated 1110 regression records for LPXIX
# 2025-04-13 22:00:01,001 - INFO - Generated 1275 regression records for MNOIX
# 2025-04-13 22:00:01,074 - INFO - Generated 1275 regression records for VEVIX
# 2025-04-13 22:00:01,117 - INFO - Generated 1275 regression records for QUAYX
# Processing USA: 100%|██████████| 7/7 [00:11<00:00,  1.59s/it]
# 2025-04-13 22:00:01,120 - INFO - Region USA generated 6264 total records
# 2025-04-13 22:00:01,127 - INFO - Processing 0 funds in International
# Processing International: 0it [00:00, ?it/s]
# 2025-04-13 22:00:01,130 - INFO - Region International generated 0 total records
# 2025-04-13 22:00:01,133 - INFO - Pipeline summary: {'total_funds': 10, 'regions': {'Global': {'funds_processed': 3, 'records': 1401}, 'USA': {'funds_processed': 7, 'records': 6264}, 'International': {'funds_processed': 0, 'records': 0}}, 'errors': 0}
# 2025-04-13 22:00:01,136 - INFO - main took 14.20 seconds

# %%
import pandas as pd
import numpy as np
import os
import random
import logging
from datetime import timedelta, datetime
from dateutil.relativedelta import relativedelta
from concurrent.futures import ThreadPoolExecutor
from sqlalchemy import create_engine
from tqdm import tqdm
from statsmodels.regression.linear_model import OLS
from statsmodels.tools.tools import add_constant
import statsmodels.api as sm
import time
import functools
from contextlib import contextmanager
import sys

# Section 1: Configuration and Setup
CONFIG = {
    "database": {
        "server": "JULIANS_LAPTOP\\SQLEXPRESS",
        "database": "CWA_Fund_Database",
        "driver": "ODBC Driver 18 for SQL Server"
    },
    "return_metric": "1 Month Return",
    "rolling_periods": [12, 24, 36, 48, 60],
    "dry_run": True,
    "sample_dry_run": True,
    "sample_size": 10,
    "chunk_size": 1000,
    "batch_insert_size": 5000,
    "max_workers": 8,
    "use_threads": True,
    "query_timeout": 30
}

CONNECTION_STRING = (
    f"mssql+pyodbc://{CONFIG['database']['server']}/{CONFIG['database']['database']}"
    f"?driver={CONFIG['database']['driver']}&trusted_connection=yes&TrustServerCertificate=yes"
)
try:
    engine = create_engine(CONNECTION_STRING, connect_args={"timeout": CONFIG["query_timeout"]})
except Exception as e:
    print(f"Database connection failed: {e}")
    raise

RETURN_METRIC = CONFIG["return_metric"]
ROLLING_PERIODS = CONFIG["rolling_periods"]
DRY_RUN = CONFIG["dry_run"]
SAMPLE_DRY_RUN = CONFIG["sample_dry_run"]
SAMPLE_SIZE = CONFIG["sample_size"]
CHUNK_SIZE = CONFIG["chunk_size"]
BATCH_INSERT_SIZE = CONFIG["batch_insert_size"]
MAX_WORKERS = min(CONFIG["max_workers"], psutil.cpu_count(logical=False))
USE_THREADS = CONFIG["use_threads"]

# Factor configuration for all regions
FACTOR_CONFIGS = {
    "Equity_USA_1": [
        {"source": "db", "factors": ["MKT", "RF"], "region": "USA", "desired_factors": ["mkt-rf"]}
    ],
    "Equity_Global_1": [
        {"source": "db", "factors": ["MKT", "RF"], "region": "Global", "desired_factors": ["mkt-rf"]}
    ],
    "Equity_International_1": [
        {"source": "db", "factors": ["MKT", "RF"], "region": "International", "desired_factors": ["mkt-rf"]}
    ]
}

# Logging setup
logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler("factor_attribution.log"),
        logging.StreamHandler(sys.stdout)
    ],
    force=True
)
logger = logging.getLogger()
logger.handlers[1].stream = sys.stdout
logger.handlers[1].setLevel(logging.INFO)

# Section 2: Helper Functions
def category_to_region(category):
    mapping = {
        "US Equity Large Cap Blend": ("USA", "US Equity Large Cap Blend"),
        "US Equity Large Cap Growth": ("USA", "US Equity Large Cap Growth"),
        "US Equity Large Cap Value": ("USA", "US Equity Large Cap Value"),
        "US Equity Mid Cap": ("USA", "US Equity Mid Cap"),
        "US Equity Small Cap": ("USA", "US Equity Small Cap"),
        "Global Equity Large Cap": ("Global", "Global Equity Large Cap"),
        "Global Equity Mid/Small Cap": ("Global", "Global Equity Mid/Small Cap"),
        "Global Emerging Markets Equity": ("Global", "Global Emerging Markets Equity"),
        "Europe Equity Large Cap": ("International", "Europe Equity Large Cap"),
        "Asia Equity": ("International", "Asia Equity"),
        "Japan Equity": ("International", "Japan Equity"),
        "Emerging Markets Fixed Income": ("International", "Emerging Markets Fixed Income"),
        "US Fixed Income": ("USA", "US Fixed Income"),
        "US Municipal Fixed Income": ("USA", "US Municipal Fixed Income"),
        "Global Fixed Income": ("Global", "Global Fixed Income"),
        "Flexible Allocation": ("Global", "Flexible Allocation"),
        "Aggressive Allocation": ("Global", "Aggressive Allocation"),
        "Moderate Allocation": ("Global", "Moderate Allocation"),
        "Cautious Allocation": ("Global", "Cautious Allocation"),
        "Commodities Broad Basket": ("Global", "Commodities Broad Basket"),
        "Commodities Specified": ("Global", "Commodities Specified"),
        "Options Trading": ("USA", "Options Trading"),
        "Multialternative": ("Global", "Multialternative"),
        "Market Neutral": ("Global", "Market Neutral"),
        "Long/Short Equity": ("Global", "Long/Short Equity"),
        "Alternative Miscellaneous": ("Global", "Alternative Miscellaneous"),
        "Energy Sector Equity": ("USA", "Energy Sector Equity"),
        "Equity Miscellaneous": ("USA", "Equity Miscellaneous"),
        "Financials Sector Equity": ("USA", "Financials Sector Equity"),
        "Healthcare Sector Equity": ("USA", "Healthcare Sector Equity"),
        "Consumer Goods & Services Sector Equity": ("USA", "Consumer Goods & Services Sector Equity"),
        "Communications Sector Equity": ("USA", "Communications Sector Equity"),
        "Industrials Sector Equity": ("USA", "Industrials Sector Equity"),
        "Other Sector Equity": ("USA", "Other Sector Equity"),
        "Real Estate Sector Equity": ("USA", "Real Estate Sector Equity"),
        "Precious Metals Sector Equity": ("USA", "Precious Metals Sector Equity"),
        "Technology Sector Equity": ("USA", "Technology Sector Equity"),
        "Utilities Sector Equity": ("USA", "Utilities Sector Equity"),
        "Natural Resources Sector Equity": ("USA", "Natural Resources Sector Equity"),
        "Infrastructure Sector Equity": ("USA", "Infrastructure Sector Equity"),
        "Trading Tools": ("USA", "Trading Tools"),
        "Asia ex-Japan Equity": ("International", "Asia ex-Japan Equity"),
        "Australia & New Zealand Equity": ("International", "Australia & New Zealand Equity"),
        "Canadian Equity Large Cap": ("International", "Canadian Equity Large Cap"),
        "Europe Equity Mid/Small Cap": ("International", "Europe Equity Mid/Small Cap"),
        "Greater China Equity": ("International", "Greater China Equity"),
        "India Equity": ("International", "India Equity"),
        "Mexico Equity": ("International", "Mexico Equity"),
        "Korea Equity": ("International", "Korea Equity"),
        "Latin America Equity": ("International", "Latin America Equity"),
        "UK Equity Large Cap": ("International", "UK Equity Large Cap"),
        "Thailand Equity": ("International", "Thailand Equity"),
        "Convertibles": ("USA", "Convertibles"),
        "Fixed Income Miscellaneous": ("USA", "Fixed Income Miscellaneous"),
        "Allocation Miscellaneous": ("Global", "Allocation Miscellaneous")
    }
    result = mapping.get(category, ("USA", "Unknown"))
    if result[1] == "Unknown":
        logger.warning(f"Unmapped category '{category}' for fund; defaulting to USA")
    return result

@contextmanager
def database_transaction():
    connection = engine.connect()
    transaction = connection.begin()
    try:
        yield connection
        transaction.commit()
    except Exception as e:
        transaction.rollback()
        logger.error(f"Transaction failed: {e}")
        raise
    finally:
        connection.close()

def timer(func):
    @functools.wraps(func)
    def wrapper(*args, **kwargs):
        start_time = time.time()
        logger.debug(f"Starting {func.__name__}")
        result = func(*args, **kwargs)
        logger.info(f"{func.__name__} took {time.time() - start_time:.2f} seconds")
        return result
    return wrapper

# Section 3: Data Loading Functions
@timer
def load_fund_metadata():
    query = """
    SELECT 
        f.SymbolCUSIP, 
        f.Region, 
        f.YC_Global_Category_ID, 
        c.Global_Category_Name,
        f.YC_Category_ID,
        y.Category_Name,
        f.CWA_Broad_Category_ID,
        b.CWA_Broad_Category_Name
    FROM Funds_to_Screen f
    JOIN YC_Global_Category_List c ON f.YC_Global_Category_ID = c.ID
    JOIN YC_Category_List y ON f.YC_Category_ID = y.ID
    LEFT JOIN CWA_Broad_Category_List b ON f.CWA_Broad_Category_ID = b.ID
    """
    try:
        df = pd.read_sql(query, engine)
        logger.info(f"Loaded metadata for {len(df)} funds")
        df[["Region", "FactorProfile"]] = df["Global_Category_Name"].map(category_to_region).apply(pd.Series)
        if df["CWA_Broad_Category_Name"].isnull().all():
            logger.warning("CWA_Broad_Category_Name missing; some regressions may be skipped")
        return df.dropna(subset=["Region", "FactorProfile"])
    except Exception as e:
        logger.error(f"Error loading metadata: {e}")
        raise

@timer
def load_fund_returns(fund_ids=None):
    try:
        if not fund_ids:
            query = f"""
            SELECT SymbolCUSIP, Date, ReturnValue
            FROM Fund_Returns_Timeseries
            WHERE Metric = '{RETURN_METRIC.replace("'", "")}'
            """
        else:
            fund_ids = [fid for fid in fund_ids if isinstance(fid, str) and fid.strip()]
            if not fund_ids:
                logger.warning("No valid fund IDs provided")
                return pd.DataFrame()
            placeholders = ",".join([f"'{fid.replace('\'', '')}'" for fid in fund_ids])
            query = f"""
            SELECT SymbolCUSIP, Date, ReturnValue
            FROM Fund_Returns_Timeseries
            WHERE Metric = '{RETURN_METRIC.replace("'", "")}'
            AND SymbolCUSIP IN ({placeholders})
            """
            logger.debug(f"Querying returns for funds: {fund_ids}")
        
        chunks = []
        for chunk in pd.read_sql(query, engine, parse_dates=["Date"], chunksize=CHUNK_SIZE):
            logger.debug(f"Loaded chunk of {len(chunk)} rows")
            chunks.append(chunk)
        df = pd.concat(chunks) if chunks else pd.DataFrame()
        if df.empty:
            logger.warning("No returns data loaded")
            return pd.DataFrame()
        
        logger.info(f"Loaded returns for {len(df['SymbolCUSIP'].unique())} funds")
        pivoted = df.pivot(index="Date", columns="SymbolCUSIP", values="ReturnValue")
        # Enforce month-end dates and frequency
        pivoted.index = pd.to_datetime(pivoted.index) + pd.offsets.MonthEnd(0)
        pivoted.index = pivoted.index.drop_duplicates()
        pivoted = pivoted.asfreq('ME')
        for col in pivoted.columns:
            if not pd.api.types.is_numeric_dtype(pivoted[col]):
                logger.warning(f"Non-numeric returns for {col}; converting")
                pivoted[col] = pd.to_numeric(pivoted[col], errors='coerce')
        return pivoted
    except Exception as e:
        logger.error(f"Error loading returns: {e}")
        if fund_ids:
            logger.info("Attempting individual fund queries")
            chunks = []
            for fid in fund_ids:
                try:
                    query = f"""
                    SELECT SymbolCUSIP, Date, ReturnValue
                    FROM Fund_Returns_Timeseries
                    WHERE Metric = '{RETURN_METRIC.replace("'", "")}'
                    AND SymbolCUSIP = '{fid.replace("'", "")}'
                    """
                    chunk = pd.read_sql(query, engine, parse_dates=["Date"])
                    chunks.append(chunk)
                    logger.debug(f"Loaded returns for {fid}")
                except Exception as e2:
                    logger.warning(f"Failed to load returns for {fid}: {e2}")
            df = pd.concat(chunks) if chunks else pd.DataFrame()
            if df.empty:
                logger.warning("No returns data loaded in fallback")
                return pd.DataFrame()
            pivoted = df.pivot(index="Date", columns="SymbolCUSIP", values="ReturnValue")
            pivoted.index = pd.to_datetime(pivoted.index) + pd.offsets.MonthEnd(0)
            pivoted.index = pivoted.index.drop_duplicates()
            pivoted = pivoted.asfreq('ME')
            for col in pivoted.columns:
                pivoted[col] = pd.to_numeric(pivoted[col], errors='coerce')
            return pivoted
        raise

@timer
def load_factors(factor_config, region="Global", asset_class=None):
    source = factor_config.get("source")
    try:
        if source == "db":
            factor_in_clause = ','.join([f"'{f}'" for f in factor_config["factors"]])
            query = f"""
            SELECT date AS Date, factor AS Factor, value AS Value
            FROM {factor_config.get('table', 'factor_returns')}
            WHERE factor IN ({factor_in_clause})
            """
            params = []
            if region and not any(f.startswith('TSM-') or f == 'RF' for f in factor_config["factors"]):
                query += " AND region = ?"
                params.append(region)
            elif 'RF' in factor_config["factors"]:
                query += " AND region = 'USA'"
            if asset_class:
                query += " AND asset_class = ?"
                params.append(asset_class)
            df = pd.read_sql(query, engine, params=params, parse_dates=['Date'])
            if df.empty:
                logger.warning(f"No data for factors {factor_config['factors']} in region {region}")
                return pd.DataFrame()
            if df.duplicated(subset=['Date', 'Factor']).sum() > 0:
                logger.error(f"Duplicate factors {factor_config['factors']}")
                raise ValueError("Duplicate factor data")
            pivoted_df = df.pivot(index="Date", columns="Factor", values="Value").rename(
                columns={'MKT': 'mkt', 'RF': 'rf'}
            )
            # Enforce month-end dates and frequency
            pivoted_df.index = pd.to_datetime(pivoted_df.index) + pd.offsets.MonthEnd(0)
            pivoted_df.index = pivoted_df.index.drop_duplicates()
            pivoted_df = pivoted_df.asfreq('ME')
            logger.debug(f"Factors loaded: {pivoted_df.columns.tolist()}, dates: {pivoted_df.index.min()} to {pivoted_df.index.max()}")
            return pivoted_df
        else:
            logger.warning(f"Factor source {source} not implemented")
            return pd.DataFrame()
    except Exception as e:
        logger.error(f"Error loading factors {factor_config.get('factors', [])}: {e}")
        return pd.DataFrame()

# Section 4: Regression Functions
# Section 4: Regression Functions
def run_rolling_regression(fund, returns, factors, regression_type, factor_set):
    results = []
    try:
        returns = pd.Series(returns).dropna()
        factors = pd.DataFrame(factors).dropna()
        returns.index = pd.to_datetime(returns.index, errors='coerce')
        factors.index = pd.to_datetime(factors.index, errors='coerce')
        returns = returns[returns.index.notnull()]
        factors = factors[factors.index.notnull()]
        
        if returns.empty or factors.empty:
            logger.warning(f"Empty data for {fund} ({factor_set})")
            return results
        
        # Data integrity check
        overlap_dates = returns.index.intersection(factors.index)
        months_available = len(overlap_dates)
        date_start = overlap_dates.min().strftime('%Y-%m-%d') if months_available > 0 else "none"
        date_end = overlap_dates.max().strftime('%Y-%m-%d') if months_available > 0 else "none"
        
        # Check for smallest window
        min_window = min(ROLLING_PERIODS)
        if months_available < min_window:
            skipped_windows = [f"{w}m" for w in ROLLING_PERIODS]
            logger.warning(f"Fund {fund} ({factor_set}) skipped for windows {skipped_windows}: "
                           f"{months_available} months available from {date_start} to {date_end}, need {min_window}")
            return results
        
        logger.debug(f"Fund {fund}: {len(returns)} returns, {len(factors)} factors, {len(overlap_dates)} overlapping dates")
        
        # Align indices with reindex
        factors = factors.reindex(overlap_dates)
        returns = returns.reindex(overlap_dates)
        
        for window in ROLLING_PERIODS:
            window_results = []
            if months_available < window:
                logger.warning(f"Fund {fund} ({factor_set}, window={window}m) skipped: {months_available} months available "
                               f"from {date_start} to {date_end}, need {window}")
                continue
            
            # Roll over fixed periods
            expected_rolls = max(0, len(returns) - window + 1)
            for start_idx in range(expected_rolls):
                end_idx = start_idx + window
                y = returns.iloc[start_idx:end_idx]
                X = factors.iloc[start_idx:end_idx]
                if len(y) != window or y.isnull().any() or X.isnull().any().any():
                    continue
                X_const = add_constant(X)
                model = OLS(y, X_const).fit()
                for factor in X.columns:
                    result = {
                        "SymbolCUSIP": fund,
                        "MonthEndDate": y.index[-1],
                        "RollPeriod": f"{window}m",
                        "Factor_Name": factor,
                        "Coefficient": model.params.get(factor, np.nan),
                        "P_Value": model.pvalues.get(factor, np.nan),
                        "T_Stat": model.tvalues.get(factor, np.nan),
                        "Standard_Error": model.bse.get(factor, np.nan),
                        "CI_Lower": model.conf_int().loc[factor][0] if factor in model.params else np.nan,
                        "CI_Upper": model.conf_int().loc[factor][1] if factor in model.params else np.nan,
                        "Adj_R2": model.rsquared_adj,
                        "Correlation": np.corrcoef(y, model.fittedvalues)[0, 1] if len(y) > 1 else np.nan,
                        "Regression_Type": regression_type,
                        "Factor_Set": factor_set
                    }
                    window_results.append(result)
                # Log sample result
                if window_results:
                    logger.debug(f"Sample regression for {fund}: Factor={window_results[-1]['Factor_Name']}, "
                                 f"Coefficient={window_results[-1]['Coefficient']:.4f}, P_Value={window_results[-1]['P_Value']:.4f}")
            
            if window_results:
                logger.info(f"Fund {fund} succeeded for window {window}m with factor {X.columns.tolist()}, generated {len(window_results)} records")
                results.extend(window_results)
        
    except Exception as e:
        logger.error(f"Regression error for {fund} ({factor_set}): {e}")
    return results

# Section 5: Processing Functions
def process_regression(symbol, returns, factor_set_key):
    records = []
    factor_configs = FACTOR_CONFIGS.get(factor_set_key, [])
    if not factor_configs:
        logger.warning(f"No config for {factor_set_key}")
        return records
    
    try:
        factors_list = [load_factors(config, region=config.get("region", "Global")) for config in factor_configs]
        factors = pd.concat([f for f in factors_list if not f.empty], axis=1).dropna()
        if factors.empty:
            logger.warning(f"No factors for {symbol} ({factor_set_key})")
            return records
        
        if 'mkt' in factors.columns and 'rf' in factors.columns:
            factors['mkt-rf'] = factors['mkt'] - factors['rf']
        
        records.extend(run_rolling_regression(symbol, returns, factors, "OLS", factor_set_key))
    except Exception as e:
        logger.error(f"Error processing {symbol} ({factor_set_key}): {e}")
    
    return records

def process_fund(fund_data):
    records = []
    symbol = fund_data["SymbolCUSIP"]
    category = fund_data["Global_Category_Name"]
    returns = pd.Series(fund_data["returns"]).dropna()
    
    logger.debug(f"Processing fund {symbol}, category: {category}")
    
    if returns.empty:
        logger.info(f"No returns for {symbol}")
        return records
    
    region, profile = category_to_region(category)
    logger.debug(f"Fund {symbol} mapped to region: {region}, profile: {profile}")
    
    # Assign regression set based on region
    regression_sets = {
        "USA": ["Equity_USA_1"],
        "Global": ["Equity_Global_1"],
        "International": ["Equity_International_1"]
    }.get(region, ["Equity_USA_1"])  # Default Unknown to USA
    
    for factor_set in regression_sets:
        records.extend(process_regression(symbol, returns, factor_set))
    
    logger.info(f"Generated {len(records)} regression records for {symbol}")
    return records

def process_region(region, fund_data_list):
    records = []
    logger.info(f"Processing {len(fund_data_list)} funds in {region}")
    
    with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
        future_to_fund = {executor.submit(process_fund, fund_data): fund_data["SymbolCUSIP"] for fund_data in fund_data_list}
        for future in tqdm(future_to_fund, total=len(fund_data_list), desc=f"Processing {region}", file=sys.stdout):
            try:
                records.extend(future.result())
            except Exception as e:
                logger.error(f"Error processing {future_to_fund[future]}: {e}")
    
    logger.info(f"Region {region} generated {len(records)} total records")
    if not DRY_RUN:
        insert_batch(records)
    
    return records

# Section 6: Main Pipeline
@timer
def main():
    logger.info("Starting main pipeline")
    try:
        fund_meta = load_fund_metadata()
    except Exception as e:
        logger.error(f"Failed to load metadata: {e}")
        return {"error": str(e)}
    
    regions = fund_meta["Region"].unique()
    logger.info(f"Total funds: {len(fund_meta)}, Regions: {regions}")
    
    fund_ids = fund_meta["SymbolCUSIP"].tolist()
    if SAMPLE_DRY_RUN:
        fund_ids = random.sample(fund_ids, min(SAMPLE_SIZE, len(fund_ids)))
        logger.info(f"Sampled {len(fund_ids)} funds: {fund_ids}")
    
    try:
        returns = load_fund_returns(fund_ids)
    except Exception as e:
        logger.error(f"Failed to load returns: {e}")
        return {"error": str(e)}
    
    fund_data_list = [
        {
            "SymbolCUSIP": row["SymbolCUSIP"],
            "Global_Category_Name": row["Global_Category_Name"],
            "returns": returns[row["SymbolCUSIP"]].to_dict()
        }
        for _, row in fund_meta.iterrows() if row["SymbolCUSIP"] in returns.columns
    ]
    
    summary = {"total_funds": len(fund_data_list), "regions": {}, "errors": 0}
    for region in ['Global', 'USA', 'International']:  # Explicitly process only these regions
        region_funds = [fd for fd in fund_data_list if fund_meta[fund_meta["SymbolCUSIP"] == fd["SymbolCUSIP"]]["Region"].iloc[0] == region]
        if SAMPLE_DRY_RUN and len(region_funds) > SAMPLE_SIZE:
            region_funds = random.sample(region_funds, SAMPLE_SIZE)
            logger.info(f"Sampled {len(region_funds)} funds for {region}")
        records = process_region(region, region_funds)
        summary["regions"][region] = {"funds_processed": len(region_funds), "records": len(records)}
    
    logger.info(f"Pipeline summary: {summary}")
    return summary

# Section 7: Database Output
def insert_batch(records):
    try:
        df = pd.DataFrame(records)
        with database_transaction() as connection:
            df.to_sql("AQRR_Factor_Attribution", connection, if_exists="append", index=False, method="multi")
        logger.info(f"Inserted {len(df)} records to database")
    except Exception as e:
        logger.error(f"Error inserting batch: {e}")
        raise

if __name__ == "__main__":
    try:
        main()
    except Exception as e:
        logger.error(f"Main execution failed: {e}")
        raise
# Out:
# 2025-04-13 22:14:20,079 - INFO - Starting main pipeline
# 2025-04-13 22:14:20,213 - INFO - Loaded metadata for 5584 funds
# 2025-04-13 22:14:20,520 - INFO - load_fund_metadata took 0.44 seconds
# 2025-04-13 22:14:20,521 - INFO - Total funds: 5584, Regions: ['Global' 'USA' 'International']
# 2025-04-13 22:14:20,522 - INFO - Sampled 10 funds: ['JDESX', 'GTEK', 'RWK', 'ONGFX', 'XRLV', 'METV', 'CPII', 'ETEC', 'DTAN', 'PLDR']
# 2025-04-13 22:14:20,548 - INFO - Loaded returns for 10 funds
# 2025-04-13 22:14:20,552 - INFO - load_fund_returns took 0.03 seconds
# 2025-04-13 22:14:20,719 - INFO - Processing 2 funds in Global
# Processing Global:   0%|          | 0/2 [00:00<?, ?it/s]2025-04-13 22:14:20,784 - INFO - load_factors took 0.06 seconds
# 2025-04-13 22:14:20,797 - INFO - load_factors took 0.08 seconds
# 2025-04-13 22:14:20,807 - WARNING - Fund DTAN (Equity_Global_1) skipped for windows ['12m', '24m', '36m', '48m', '60m']: 3 months available from 2024-10-31 to 2024-12-31, need 12
# 2025-04-13 22:14:20,814 - INFO - Generated 0 regression records for DTAN
# 2025-04-13 22:14:21,337 - INFO - Fund ONGFX succeeded for window 12m with factor ['mkt', 'rf', 'mkt-rf'], generated 327 records
# 2025-04-13 22:14:21,806 - INFO - Fund ONGFX succeeded for window 24m with factor ['mkt', 'rf', 'mkt-rf'], generated 291 records
# 2025-04-13 22:14:22,226 - INFO - Fund ONGFX succeeded for window 36m with factor ['mkt', 'rf', 'mkt-rf'], generated 255 records
# 2025-04-13 22:14:22,570 - INFO - Fund ONGFX succeeded for window 48m with factor ['mkt', 'rf', 'mkt-rf'], generated 219 records
# 2025-04-13 22:14:22,873 - INFO - Fund ONGFX succeeded for window 60m with factor ['mkt', 'rf', 'mkt-rf'], generated 183 records
# 2025-04-13 22:14:22,874 - INFO - Generated 1275 regression records for ONGFX
# Processing Global: 100%|██████████| 2/2 [00:02<00:00,  1.08s/it]
# 2025-04-13 22:14:22,876 - INFO - Region Global generated 1275 total records
# 2025-04-13 22:14:22,881 - INFO - Processing 8 funds in USA
# Processing USA:   0%|          | 0/8 [00:00<?, ?it/s]2025-04-13 22:14:23,176 - INFO - load_factors took 0.29 seconds
# 2025-04-13 22:14:23,200 - INFO - load_factors took 0.31 seconds
# 2025-04-13 22:14:23,328 - INFO - Fund ETEC succeeded for window 12m with factor ['mkt', 'rf', 'mkt-rf'], generated 30 records
# 2025-04-13 22:14:23,336 - WARNING - Fund ETEC (Equity_USA_1, window=24m) skipped: 21 months available from 2023-04-30 to 2024-12-31, need 24
# 2025-04-13 22:14:23,344 - WARNING - Fund ETEC (Equity_USA_1, window=36m) skipped: 21 months available from 2023-04-30 to 2024-12-31, need 36
# 2025-04-13 22:14:23,350 - WARNING - Fund ETEC (Equity_USA_1, window=48m) skipped: 21 months available from 2023-04-30 to 2024-12-31, need 48
# 2025-04-13 22:14:23,354 - WARNING - Fund ETEC (Equity_USA_1, window=60m) skipped: 21 months available from 2023-04-30 to 2024-12-31, need 60
# 2025-04-13 22:14:23,358 - INFO - Generated 30 regression records for ETEC
# 2025-04-13 22:14:23,472 - INFO - Fund PLDR succeeded for window 12m with factor ['mkt', 'rf', 'mkt-rf'], generated 96 records
# 2025-04-13 22:14:23,600 - INFO - load_factors took 0.71 seconds
# 2025-04-13 22:14:23,610 - INFO - load_factors took 0.73 seconds
# 2025-04-13 22:14:23,701 - INFO - load_factors took 0.81 seconds
# 2025-04-13 22:14:23,741 - INFO - Fund PLDR succeeded for window 24m with factor ['mkt', 'rf', 'mkt-rf'], generated 60 records
# 2025-04-13 22:14:23,767 - INFO - load_factors took 0.88 seconds
# 2025-04-13 22:14:23,972 - INFO - Fund PLDR succeeded for window 36m with factor ['mkt', 'rf', 'mkt-rf'], generated 24 records
# 2025-04-13 22:14:23,983 - WARNING - Fund PLDR (Equity_USA_1, window=48m) skipped: 43 months available from 2021-06-30 to 2024-12-31, need 48
# 2025-04-13 22:14:24,004 - WARNING - Fund PLDR (Equity_USA_1, window=60m) skipped: 43 months available from 2021-06-30 to 2024-12-31, need 60
# 2025-04-13 22:14:24,021 - INFO - Generated 180 regression records for PLDR
# 2025-04-13 22:14:24,053 - INFO - load_factors took 1.16 seconds
# 2025-04-13 22:14:24,246 - INFO - load_factors took 1.36 seconds
# 2025-04-13 22:14:24,279 - INFO - Fund CPII succeeded for window 12m with factor ['mkt', 'rf', 'mkt-rf'], generated 57 records
# 2025-04-13 22:14:24,405 - INFO - Fund GTEK succeeded for window 12m with factor ['mkt', 'rf', 'mkt-rf'], generated 84 records
# 2025-04-13 22:14:24,492 - INFO - Fund METV succeeded for window 12m with factor ['mkt', 'rf', 'mkt-rf'], generated 93 records
# 2025-04-13 22:14:24,570 - INFO - Fund CPII succeeded for window 24m with factor ['mkt', 'rf', 'mkt-rf'], generated 21 records
# 2025-04-13 22:14:24,605 - WARNING - Fund CPII (Equity_USA_1, window=36m) skipped: 30 months available from 2022-07-31 to 2024-12-31, need 36
# 2025-04-13 22:14:24,621 - WARNING - Fund CPII (Equity_USA_1, window=48m) skipped: 30 months available from 2022-07-31 to 2024-12-31, need 48
# 2025-04-13 22:14:24,634 - WARNING - Fund CPII (Equity_USA_1, window=60m) skipped: 30 months available from 2022-07-31 to 2024-12-31, need 60
# 2025-04-13 22:14:24,652 - INFO - Generated 78 regression records for CPII
# 2025-04-13 22:14:24,881 - INFO - Fund GTEK succeeded for window 24m with factor ['mkt', 'rf', 'mkt-rf'], generated 48 records
# 2025-04-13 22:14:25,001 - INFO - Fund GTEK succeeded for window 36m with factor ['mkt', 'rf', 'mkt-rf'], generated 12 records
# 2025-04-13 22:14:25,011 - WARNING - Fund GTEK (Equity_USA_1, window=48m) skipped: 39 months available from 2021-10-31 to 2024-12-31, need 48
# 2025-04-13 22:14:25,025 - WARNING - Fund GTEK (Equity_USA_1, window=60m) skipped: 39 months available from 2021-10-31 to 2024-12-31, need 60
# 2025-04-13 22:14:25,034 - INFO - Generated 144 regression records for GTEK
# 2025-04-13 22:14:25,040 - INFO - Fund METV succeeded for window 24m with factor ['mkt', 'rf', 'mkt-rf'], generated 57 records
# Processing USA:  12%|█▎        | 1/8 [00:02<00:15,  2.15s/it]2025-04-13 22:14:25,185 - INFO - Fund METV succeeded for window 36m with factor ['mkt', 'rf', 'mkt-rf'], generated 21 records
# 2025-04-13 22:14:25,190 - WARNING - Fund METV (Equity_USA_1, window=48m) skipped: 42 months available from 2021-07-31 to 2024-12-31, need 48
# 2025-04-13 22:14:25,199 - WARNING - Fund METV (Equity_USA_1, window=60m) skipped: 42 months available from 2021-07-31 to 2024-12-31, need 60
# 2025-04-13 22:14:25,203 - INFO - Generated 171 regression records for METV
# Processing USA:  25%|██▌       | 2/8 [00:02<00:05,  1.01it/s]2025-04-13 22:14:26,025 - INFO - Fund RWK succeeded for window 12m with factor ['mkt', 'rf', 'mkt-rf'], generated 327 records
# 2025-04-13 22:14:26,195 - INFO - Fund JDESX succeeded for window 12m with factor ['mkt', 'rf', 'mkt-rf'], generated 327 records
# 2025-04-13 22:14:26,232 - INFO - Fund XRLV succeeded for window 12m with factor ['mkt', 'rf', 'mkt-rf'], generated 315 records
# 2025-04-13 22:14:27,499 - INFO - Fund RWK succeeded for window 24m with factor ['mkt', 'rf', 'mkt-rf'], generated 291 records
# 2025-04-13 22:14:27,609 - INFO - Fund XRLV succeeded for window 24m with factor ['mkt', 'rf', 'mkt-rf'], generated 279 records
# 2025-04-13 22:14:27,616 - INFO - Fund JDESX succeeded for window 24m with factor ['mkt', 'rf', 'mkt-rf'], generated 291 records
# 2025-04-13 22:14:28,816 - INFO - Fund XRLV succeeded for window 36m with factor ['mkt', 'rf', 'mkt-rf'], generated 243 records
# 2025-04-13 22:14:28,850 - INFO - Fund RWK succeeded for window 36m with factor ['mkt', 'rf', 'mkt-rf'], generated 255 records
# 2025-04-13 22:14:28,948 - INFO - Fund JDESX succeeded for window 36m with factor ['mkt', 'rf', 'mkt-rf'], generated 255 records
# 2025-04-13 22:14:29,784 - INFO - Fund XRLV succeeded for window 48m with factor ['mkt', 'rf', 'mkt-rf'], generated 207 records
# 2025-04-13 22:14:29,930 - INFO - Fund RWK succeeded for window 48m with factor ['mkt', 'rf', 'mkt-rf'], generated 219 records
# 2025-04-13 22:14:30,061 - INFO - Fund JDESX succeeded for window 48m with factor ['mkt', 'rf', 'mkt-rf'], generated 219 records
# 2025-04-13 22:14:30,679 - INFO - Fund XRLV succeeded for window 60m with factor ['mkt', 'rf', 'mkt-rf'], generated 171 records
# 2025-04-13 22:14:30,687 - INFO - Generated 1215 regression records for XRLV
# Processing USA:  50%|█████     | 4/8 [00:07<00:08,  2.08s/it]2025-04-13 22:14:30,768 - INFO - Fund RWK succeeded for window 60m with factor ['mkt', 'rf', 'mkt-rf'], generated 183 records
# 2025-04-13 22:14:30,776 - INFO - Generated 1275 regression records for RWK
# 2025-04-13 22:14:30,813 - INFO - Fund JDESX succeeded for window 60m with factor ['mkt', 'rf', 'mkt-rf'], generated 183 records
# 2025-04-13 22:14:30,814 - INFO - Generated 1275 regression records for JDESX
# Processing USA: 100%|██████████| 8/8 [00:07<00:00,  1.01it/s]
# 2025-04-13 22:14:30,817 - INFO - Region USA generated 4368 total records
# 2025-04-13 22:14:30,824 - INFO - Processing 0 funds in International
# Processing International: 0it [00:00, ?it/s]
# 2025-04-13 22:14:30,826 - INFO - Region International generated 0 total records
# 2025-04-13 22:14:30,829 - INFO - Pipeline summary: {'total_funds': 10, 'regions': {'Global': {'funds_processed': 2, 'records': 1275}, 'USA': {'funds_processed': 8, 'records': 4368}, 'International': {'funds_processed': 0, 'records': 0}}, 'errors': 0}
# 2025-04-13 22:14:30,830 - INFO - main took 10.75 seconds

# %%
import pandas as pd
import numpy as np
import os
import random
import logging
from datetime import timedelta, datetime
from dateutil.relativedelta import relativedelta
from concurrent.futures import ProcessPoolExecutor, ThreadPoolExecutor
from sqlalchemy import create_engine
from tqdm import tqdm
from statsmodels.regression.linear_model import OLS
from statsmodels.tools.tools import add_constant
import statsmodels.api as sm
import time
import pickle

# Section 1: Configuration and Setup
CONFIG = {
    "database": {
        "server": "JULIANS_LAPTOP\\SQLEXPRESS",
        "database": "CWA_Fund_Database",
        "driver": "ODBC Driver 18 for SQL Server"
    },
    "return_metric": "1 Month Return",
    "rolling_periods": [12, 24, 36, 48, 60],
    "dry_run": True,
    "sample_dry_run": True,
    "sample_size": 50,
    "chunk_size": 5600,
    "batch_insert_size": 10000,
    "max_workers": 20,
    "use_threads": False
}

CONNECTION_STRING = (
    f"mssql+pyodbc://{CONFIG['database']['server']}/{CONFIG['database']['database']}"
    f"?driver={CONFIG['database']['driver']}&trusted_connection=yes&TrustServerCertificate=yes"
)
try:
    engine = create_engine(CONNECTION_STRING)
except Exception as e:
    print(f"Database connection failed: {e}")
    raise

RETURN_METRIC = CONFIG["return_metric"]
ROLLING_PERIODS = CONFIG["rolling_periods"]
DRY_RUN = CONFIG["dry_run"]
SAMPLE_DRY_RUN = CONFIG["sample_dry_run"]
SAMPLE_SIZE = CONFIG["sample_size"]
CHUNK_SIZE = CONFIG["chunk_size"]
BATCH_INSERT_SIZE = CONFIG["batch_insert_size"]
MAX_WORKERS = CONFIG["max_workers"]
USE_THREADS = CONFIG["use_threads"]

# Logging setup
logging.basicConfig(
    level=logging.WARNING,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler("factor_attribution.log"),
        logging.StreamHandler(sys.stdout)
    ],
    force=True
)
logger = logging.getLogger()

# Section 2: Helper Functions
def category_to_region(category):
    mapping = {
        "US Equity Large Cap Blend": ("USA", "US Equity Large Cap Blend"),
        "US Equity Large Cap Growth": ("USA", "US Equity Large Cap Growth"),
        "US Equity Large Cap Value": ("USA", "US Equity Large Cap Value"),
        "US Equity Mid Cap": ("USA", "US Equity Mid Cap"),
        "US Equity Small Cap": ("USA", "US Equity Small Cap"),
        "Global Equity Large Cap": ("Global", "Global Equity Large Cap"),
        "Global Equity Mid/Small Cap": ("Global", "Global Equity Mid/Small Cap"),
        "Global Emerging Markets Equity": ("Global", "Global Emerging Markets Equity"),
        "Europe Equity Large Cap": ("International", "Europe Equity Large Cap"),
        "Asia Equity": ("International", "Asia Equity"),
        "Japan Equity": ("International", "Japan Equity"),
        "Emerging Markets Fixed Income": ("International", "Emerging Markets Fixed Income"),
        "US Fixed Income": ("USA", "US Fixed Income"),
        "US Municipal Fixed Income": ("USA", "US Municipal Fixed Income"),
        "Global Fixed Income": ("Global", "Global Fixed Income"),
        "Flexible Allocation": ("Global", "Flexible Allocation"),
        "Aggressive Allocation": ("Global", "Aggressive Allocation"),
        "Moderate Allocation": ("Global", "Moderate Allocation"),
        "Cautious Allocation": ("Global", "Cautious Allocation"),
        "Commodities Broad Basket": ("Global", "Commodities Broad Basket"),
        "Commodities Specified": ("Global", "Commodities Specified"),
        "Options Trading": ("USA", "Options Trading"),
        "Multialternative": ("Global", "Multialternative"),
        "Market Neutral": ("Global", "Market Neutral"),
        "Long/Short Equity": ("Global", "Long/Short Equity"),
        "Alternative Miscellaneous": ("Global", "Alternative Miscellaneous"),
        "Energy Sector Equity": ("USA", "Energy Sector Equity"),
        "Equity Miscellaneous": ("USA", "Equity Miscellaneous"),
        "Financials Sector Equity": ("USA", "Financials Sector Equity"),
        "Healthcare Sector Equity": ("USA", "Healthcare Sector Equity"),
        "Consumer Goods & Services Sector Equity": ("USA", "Consumer Goods & Services Sector Equity"),
        "Communications Sector Equity": ("USA", "Communications Sector Equity"),
        "Industrials Sector Equity": ("USA", "Industrials Sector Equity"),
        "Other Sector Equity": ("USA", "Other Sector Equity"),
        "Real Estate Sector Equity": ("USA", "Real Estate Sector Equity"),
        "Precious Metals Sector Equity": ("USA", "Precious Metals Sector Equity"),
        "Technology Sector Equity": ("USA", "Technology Sector Equity"),
        "Utilities Sector Equity": ("USA", "Utilities Sector Equity"),
        "Natural Resources Sector Equity": ("USA", "Natural Resources Sector Equity"),
        "Infrastructure Sector Equity": ("USA", "Infrastructure Sector Equity"),
        "Trading Tools": ("USA", "Trading Tools"),
        "Asia ex-Japan Equity": ("International", "Asia ex-Japan Equity"),
        "Australia & New Zealand Equity": ("International", "Australia & New Zealand Equity"),
        "Canadian Equity Large Cap": ("International", "Canadian Equity Large Cap"),
        "Europe Equity Mid/Small Cap": ("International", "Europe Equity Mid/Small Cap"),
        "Greater China Equity": ("International", "Greater China Equity"),
        "India Equity": ("International", "India Equity"),
        "Mexico Equity": ("International", "Mexico Equity"),
        "Korea Equity": ("International", "Korea Equity"),
        "Latin America Equity": ("International", "Latin America Equity"),
        "UK Equity Large Cap": ("International", "UK Equity Large Cap"),
        "Thailand Equity": ("International", "Thailand Equity"),
        "Convertibles": ("USA", "Convertibles"),
        "Fixed Income Miscellaneous": ("USA", "Fixed Income Miscellaneous"),
        "Allocation Miscellaneous": ("Global", "Allocation Miscellaneous")
    }
    return mapping.get(category, ("USA", "Unknown"))

@contextmanager
def database_transaction():
    connection = engine.connect()
    transaction = connection.begin()
    try:
        yield connection
        transaction.commit()
    except Exception as e:
        transaction.rollback()
        logger.error(f"Transaction failed: {e}")
        raise
    finally:
        connection.close()

def timer(func):
    @functools.wraps(func)
    def wrapper(*args, **kwargs):
        start_time = time.time()
        logger.debug(f"Starting {func.__name__}")
        result = func(*args, **kwargs)
        logger.info(f"{func.__name__} took {time.time() - start_time:.2f} seconds")
        return result
    return wrapper

# Section 3: Data Loading Functions
@timer
def load_fund_metadata():
    query = """
    SELECT 
        f.SymbolCUSIP, 
        f.Region, 
        f.YC_Global_Category_ID, 
        c.Global_Category_Name,
        f.YC_Category_ID,
        y.Category_Name,
        f.CWA_Broad_Category_ID,
        b.CWA_Broad_Category_Name
    FROM Funds_to_Screen f
    JOIN YC_Global_Category_List c ON f.YC_Global_Category_ID = c.ID
    JOIN YC_Category_List y ON f.YC_Category_ID = y.ID
    LEFT JOIN CWA_Broad_Category_List b ON f.CWA_Broad_Category_ID = b.ID
    """
    try:
        df = pd.read_sql(query, engine)
        logger.info(f"Loaded metadata for {len(df)} funds")
        df[["Region", "FactorProfile"]] = df["Global_Category_Name"].map(category_to_region).apply(pd.Series)
        if df["CWA_Broad_Category_Name"].isnull().all():
            logger.warning("CWA_Broad_Category_Name missing; Equity regressions 5-7 will be skipped")
        return df.dropna(subset=["Region", "FactorProfile"])
    except Exception as e:
        logger.error(f"Error loading metadata: {e}")
        raise

@timer
def load_fund_returns(fund_ids=None):
    try:
        if not fund_ids:
            query = f"""
            SELECT SymbolCUSIP, Date, ReturnValue
            FROM Fund_Returns_Timeseries
            WHERE Metric = '{RETURN_METRIC.replace("'", "")}'
            """
        else:
            fund_ids = [fid for fid in fund_ids if isinstance(fid, str) and fid.strip()]
            if not fund_ids:
                logger.warning("No valid fund IDs provided")
                return pd.DataFrame()
            placeholders = ",".join([f"'{fid.replace('\'', '')}'" for fid in fund_ids])
            query = f"""
            SELECT SymbolCUSIP, Date, ReturnValue
            FROM Fund_Returns_Timeseries
            WHERE Metric = '{RETURN_METRIC.replace("'", "")}'
            AND SymbolCUSIP IN ({placeholders})
            """
            logger.debug(f"Querying returns for funds: {fund_ids}")
        
        chunks = []
        for chunk in pd.read_sql(query, engine, parse_dates=["Date"], chunksize=CHUNK_SIZE):
            logger.debug(f"Loaded chunk of {len(chunk)} rows")
            chunks.append(chunk)
        df = pd.concat(chunks) if chunks else pd.DataFrame()
        if df.empty:
            logger.warning("No returns data loaded")
            return pd.DataFrame()
        
        logger.info(f"Loaded returns for {len(df['SymbolCUSIP'].unique())} funds")
        pivoted = df.pivot(index="Date", columns="SymbolCUSIP", values="ReturnValue")
        pivoted.index = pd.to_datetime(pivoted.index) + pd.offsets.MonthEnd(0)
        pivoted.index = pivoted.index.drop_duplicates()
        pivoted = pivoted.asfreq('ME')
        for col in pivoted.columns:
            if not pd.api.types.is_numeric_dtype(pivoted[col]):
                logger.warning(f"Non-numeric returns for {col}; converting")
                pivoted[col] = pd.to_numeric(pivoted[col], errors='coerce')
        return pivoted
    except Exception as e:
        logger.error(f"Error loading returns: {e}")
        if fund_ids:
            logger.info("Attempting individual fund queries")
            chunks = []
            for fid in fund_ids:
                try:
                    query = f"""
                    SELECT SymbolCUSIP, Date, ReturnValue
                    FROM Fund_Returns_Timeseries
                    WHY Metric = '{RETURN_METRIC.replace("'", "")}'
                    AND SymbolCUSIP = '{fid.replace("'", "")}'
                    """
                    chunk = pd.read_sql(query, engine, parse_dates=["Date"])
                    chunks.append(chunk)
                    logger.debug(f"Loaded returns for {fid}")
                except Exception as e2:
                    logger.warning(f"Failed to load returns for {fid}: {e2}")
            df = pd.concat(chunks) if chunks else pd.DataFrame()
            if df.empty:
                logger.warning("No returns data loaded in fallback")
                return pd.DataFrame()
            pivoted = df.pivot(index="Date", columns="SymbolCUSIP", values="ReturnValue")
            pivoted.index = pd.to_datetime(pivoted.index) + pd.offsets.MonthEnd(0)
            pivoted.index = pivoted.index.drop_duplicates()
            pivoted = pivoted.asfreq('ME')
            for col in pivoted.columns:
                pivoted[col] = pd.to_numeric(pivoted[col], errors='coerce')
            return pivoted
        raise

@timer
def load_db_factors(factor_list, region="Global", table="factor_returns", asset_class=None):
    factor_in_clause = ','.join([f"'{f}'" for f in factor_list])
    query = f"""
        SELECT date AS Date, factor AS Factor, value AS Value
        FROM {table}
        WHERE factor IN ({factor_in_clause})
    """
    params = []
    if region and not any(f.startswith('TSM-') or f == 'RF' for f in factor_list):
        query += " AND region = ?"
        params.append(region)
    elif 'RF' in factor_list:
        query += " AND region = 'USA'"
    if asset_class:
        query += " AND asset_class = ?"
        params.append(asset_class)
    df = pd.read_sql(query, engine, params=params, parse_dates=['Date'])
    if df.empty:
        logger.warning(f"No data for factors {factor_list} in {table} (region: {region}, asset_class: {asset_class})")
        return pd.DataFrame()
    
    duplicates = df.duplicated(subset=['Date', 'Factor']).sum()
    if duplicates > 0:
        logger.warning(f"Found {duplicates} duplicate Date-Factor pairs in {table} for {factor_list}; aggregating by mean")
        df = df.groupby(['Date', 'Factor'])['Value'].mean().reset_index()
    
    pivoted_df = df.pivot(index="Date", columns="Factor", values="Value").rename(
        columns={
            'MKT': 'mkt', 'SMB': 'smb', 'HML_Devil': 'hml', 'UMD': 'umd', 'QMJ': 'qmj',
            'BAB': 'bab', 'RF': 'rf', 'TSM-Com': 'tsm-com', 'TSM-EQ': 'tsm-eq',
            'TSM-FI': 'tsm-fi', 'TSM-FX': 'tsm-fx', 'TSM-MA': 'tsm-ma'
        }
    )
    pivoted_df.index = pd.to_datetime(pivoted_df.index) + pd.offsets.MonthEnd(0)
    pivoted_df.index = pivoted_df.index.drop_duplicates()
    pivoted_df = pivoted_df.asfreq('ME')
    missing_factors = [f for f in factor_list if f.lower() not in pivoted_df.columns]
    if missing_factors:
        logger.warning(f"Missing factors in {table} (region: {region}): {missing_factors}")
    return pivoted_df

@timer
def load_fixed_income_factors(factor_list):
    factor_in_clause = ','.join([f"'{f}'" for f in factor_list])
    query = f"""
        SELECT Date, Factor_Name, ReturnValue
        FROM Fixed_Income_Factor_Returns
        WHERE Factor_Name IN ({factor_in_clause})
    """
    df = pd.read_sql(query, engine, parse_dates=["Date"])
    if df.empty:
        logger.warning(f"No fixed income factors for {factor_list}")
        return pd.DataFrame()
    pivoted_df = df.pivot(index="Date", columns="Factor_Name", values="ReturnValue")
    pivoted_df.index = pd.to_datetime(pivoted_df.index) + pd.offsets.MonthEnd(0)
    pivoted_df.index = pivoted_df.index.drop_duplicates()
    pivoted_df = pivoted_df.asfreq('ME')
    return pivoted_df

@timer
def load_century_factors(factor_list, portfolio_base, factor, asset_class=None, region="Global"):
    factor_in_clause = ','.join([f"'{f}'" for f in factor_list])
    portfolio = f"{portfolio_base} {factor}"
    query = f"""
        SELECT date AS Date, factor AS Factor, value AS Value
        FROM aqr_century_factors
        WHERE factor IN ({factor_in_clause})
        AND portfolio = ?
    """
    params = [portfolio]
    if asset_class:
        query += " AND asset_class = ?"
        params.append(asset_class)
    if region != "Global":
        query += " AND region = ?"
        params.append(region)
    df = pd.read_sql(query, engine, params=params, parse_dates=['Date'])
    if df.empty:
        logger.warning(f"No data for factors {factor_list} in aqr_century_factors (portfolio: {portfolio}, region: {region})")
        return pd.DataFrame()
    pivoted_df = df.pivot(index="Date", columns="Factor", values="Value")
    pivoted_df.index = pd.to_datetime(pivoted_df.index) + pd.offsets.MonthEnd(0)
    pivoted_df.index = pivoted_df.index.drop_duplicates()
    pivoted_df = pivoted_df.asfreq('ME')
    return pivoted_df

@timer
def load_commodity_factors():
    query = """
        SELECT date AS Date, 
               excess_return_eqwt, 
               excess_spot_return_eqwt, 
               ir_adjusted_carry_eqwt, 
               spot_return_eqwt, 
               carry_eqwt, 
               excess_return_long_short, 
               excess_spot_return_long_short, 
               ir_adjusted_carry_long_short, 
               aggregate_backwardation_contango
        FROM aqr_cmdty_factors
    """
    df = pd.read_sql(query, engine, parse_dates=['Date'])
    if df.empty:
        logger.warning("No commodity factors loaded")
        return pd.DataFrame()
    pivoted_df = df.set_index("Date")
    pivoted_df.index = pd.to_datetime(pivoted_df.index) + pd.offsets.MonthEnd(0)
    pivoted_df.index = pivoted_df.index.drop_duplicates()
    pivoted_df = pivoted_df.asfreq('ME')
    return pivoted_df

# Section 4: Regression Functions
def run_rolling_regression(fund, returns, factors, regression_type, factor_set):
    results = []
    try:
        returns = pd.Series(returns).dropna()
        factors = pd.DataFrame(factors).dropna()
        returns.index = pd.to_datetime(returns.index, errors='coerce')
        factors.index = pd.to_datetime(factors.index, errors='coerce')
        returns = returns[returns.index.notnull()]
        factors = factors[factors.index.notnull()]
        
        if returns.empty or factors.empty:
            logger.warning(f"Empty data for {fund} ({factor_set})")
            return results
        
        overlap_dates = returns.index.intersection(factors.index)
        months_available = len(overlap_dates)
        date_start = overlap_dates.min().strftime('%Y-%m-%d') if months_available > 0 else "none"
        date_end = overlap_dates.max().strftime('%Y-%m-%d') if months_available > 0 else "none"
        
        min_window = min(ROLLING_PERIODS)
        if months_available < min_window:
            skipped_windows = [f"{w}m" for w in ROLLING_PERIODS]
            logger.warning(f"Fund {fund} ({factor_set}) skipped for windows {skipped_windows}: "
                           f"{months_available} months available from {date_start} to {date_end}, need {min_window}")
            return results
        
        logger.debug(f"Fund {fund}: {len(returns)} returns, {len(factors)} factors, {len(overlap_dates)} overlapping dates")
        
        factors = factors.reindex(overlap_dates)
        returns = returns.reindex(overlap_dates)
        
        for window in ROLLING_PERIODS:
            window_results = []
            if months_available < window:
                logger.warning(f"Fund {fund} ({factor_set}, window={window}m) skipped: {months_available} months available "
                               f"from {date_start} to {date_end}, need {window}")
                continue
            
            expected_rolls = max(0, len(returns) - window + 1)
            logger.debug(f"Fund {fund}: Expected {expected_rolls} rolls for window {window}m with factors {factors.columns.tolist()}")
            for start_idx in range(expected_rolls):
                end_idx = start_idx + window
                y = returns.iloc[start_idx:end_idx]
                X = factors.iloc[start_idx:end_idx]
                if len(y) != window or y.isnull().any() or X.isnull().any().any():
                    continue
                X_const = add_constant(X)
                model = OLS(y, X_const).fit()
                for factor in X.columns:
                    result = {
                        "SymbolCUSIP": fund,
                        "MonthEndDate": y.index[-1],
                        "RollPeriod": f"{window}m",
                        "Factor_Name": factor,
                        "Coefficient": model.params.get(factor, np.nan),
                        "P_Value": model.pvalues.get(factor, np.nan),
                        "T_Stat": model.tvalues.get(factor, np.nan),
                        "Standard_Error": model.bse.get(factor, np.nan),
                        "CI_Lower": model.conf_int().loc[factor][0] if factor in model.params else np.nan,
                        "CI_Upper": model.conf_int().loc[factor][1] if factor in model.params else np.nan,
                        "Adj_R2": model.rsquared_adj,
                        "Correlation": np.corrcoef(y, model.fittedvalues)[0, 1] if len(y) > 1 else np.nan,
                        "Regression_Type": regression_type,
                        "Factor_Set": factor_set
                    }
                    window_results.append(result)
            
            if window_results:
                factor_counts = {factor: len([r for r in window_results if r["Factor_Name"] == factor]) for factor in factors.columns}
                logger.info(f"Fund {fund} succeeded for window {window}m with factors {factor_counts}, total {len(window_results)} records")
                results.extend(window_results)
        
    except Exception as e:
        logger.error(f"Regression error for {fund} ({factor_set}): {e}")
    return results

# Section 5: Processing Functions
def process_fund(fund_data):
    records = []
    symbol = fund_data["SymbolCUSIP"]
    category = fund_data["Global_Category_Name"]
    broad_category = fund_data["CWA_Broad_Category_Name"]
    returns = pd.Series(fund_data["returns"]).dropna()
    
    logger.debug(f"Starting process_fund for {symbol}")
    
    try:
        if returns.empty:
            logger.warning(f"No valid returns for {symbol}")
            return records

        # Equity (USA)
        if category in [
            "Energy Sector Equity", "Equity Miscellaneous", "Financials Sector Equity",
            "Healthcare Sector Equity", "Consumer Goods & Services Sector Equity",
            "Communications Sector Equity", "Industrials Sector Equity", "Other Sector Equity",
            "Real Estate Sector Equity", "Precious Metals Sector Equity", "Technology Sector Equity",
            "Utilities Sector Equity", "US Equity Large Cap Blend", "US Equity Large Cap Growth",
            "US Equity Large Cap Value", "US Equity Mid Cap", "US Equity Small Cap", "Options Trading",
            "Natural Resources Sector Equity", "Infrastructure Sector Equity"
        ]:
            # Regression 1: USA, MKT-RF, HML-Devil, QMJ, SMB, UMD, BAB
            factors_eq = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB'], "USA")
            rf_factors = load_db_factors(['RF'], "USA")
            factors = pd.concat([factors_eq, rf_factors], axis=1).dropna()
            if factors.empty:
                logger.warning(f"No valid factors for {symbol} (Equity_USA_1)")
            else:
                if 'mkt' in factors.columns and 'rf' in factors.columns:
                    factors['mkt-rf'] = factors['mkt'] - factors['rf']
                factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                if returns_aligned.empty:
                    logger.warning(f"No overlapping dates for {symbol} (Equity_USA_1)")
                else:
                    desired_factors = ['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'hml', 'qmj', 'smb', 'umd', 'bab']
                    available_factors = [f for f in desired_factors if f in factors.columns]
                    if available_factors:
                        records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "Equity_USA_1"))
                    else:
                        logger.warning(f"No valid factors for {symbol} (Equity_USA_1)")

            # Regression 2-4: Century Factors
            for portfolio_base, factor_set in [
                ("US Stock Selection", "Equity_USA_2"),
                ("All Macro", "Equity_USA_3"),
                ("Equity indices", "Equity_USA_4")
            ]:
                for factor in ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value']:
                    factors = load_century_factors([factor], portfolio_base, factor, region="USA")
                    if factors.empty:
                        logger.warning(f"No century factors for {symbol} ({factor_set}, factor: {factor})")
                        continue
                    factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                    if returns_aligned.empty:
                        logger.warning(f"No overlapping dates for {symbol} ({factor_set}, factor: {factor})")
                        continue
                    records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", factor_set))

            if broad_category in ["Quantitative/Tactical", "Strategic", "Nontraditional"]:
                # Regression 5
                factors_eq = load_db_factors(['MKT', 'BAB'], "USA")
                factors_fi = load_db_factors(['TSM-FI'])
                factors_fx = load_db_factors(['TSM-FX'])
                rf_factors = load_db_factors(['RF'], "USA")
                fi_factors = load_fixed_income_factors(['TERM', 'CREDIT'])
                cmdty_factors = load_commodity_factors()
                factors = pd.concat([factors_eq, factors_fi, factors_fx, rf_factors, fi_factors, cmdty_factors[['excess_return_eqwt']]], axis=1).dropna()
                if factors.empty:
                    logger.warning(f"No valid factors for {symbol} (Equity_USA_5)")
                else:
                    if 'mkt' in factors.columns and 'rf' in factors.columns:
                        factors['mkt-rf'] = factors['mkt'] - factors['rf']
                    factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                    if returns_aligned.empty:
                        logger.warning(f"No overlapping dates for {symbol} (Equity_USA_5)")
                    else:
                        desired_factors = ['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'tsm-fx', 'tsm-fi', 'bab', 'TERM', 'CREDIT', 'excess_return_eqwt']
                        available_factors = [f for f in desired_factors if f in factors.columns]
                        if available_factors:
                            records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "Equity_USA_5"))

                # Regression 6
                factors_eq = load_db_factors(['MKT', 'SMB', 'BAB'], "USA")
                factors_com = load_db_factors(['TSM-Com'])
                rf_factors = load_db_factors(['RF'], "USA")
                fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT_HY'])
                factors = pd.concat([factors_eq, factors_com, rf_factors, fi_factors], axis=1).dropna()
                if factors.empty:
                    logger.warning(f"No valid factors for {symbol} (Equity_USA_6)")
                else:
                    if 'mkt' in factors.columns and 'rf' in factors.columns:
                        factors['mkt-rf'] = factors['mkt'] - factors['rf']
                    factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                    if returns_aligned.empty:
                        logger.warning(f"No overlapping dates for {symbol} (Equity_USA_6)")
                    else:
                        desired_factors = ['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'smb', 'bab', 'TERM_Int', 'TERM_Long', 'CREDIT_HY', 'tsm-com']
                        available_factors = [f for f in desired_factors if f in factors.columns]
                        if available_factors:
                            records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "Equity_USA_6"))

                # Regression 7
                factors_eq = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'UMD', 'SMB', 'BAB'], "USA")
                factors_com = load_db_factors(['TSM-Com'])
                factors_fi = load_db_factors(['TSM-FI'])
                factors_fx = load_db_factors(['TSM-FX'])
                rf_factors = load_db_factors(['RF'], "USA")
                fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY'])
                factors = pd.concat([factors_eq, factors_com, factors_fi, factors_fx, rf_factors, fi_factors], axis=1).dropna()
                if factors.empty:
                    logger.warning(f"No valid factors for {symbol} (Equity_USA_7)")
                else:
                    if 'mkt' in factors.columns and 'rf' in factors.columns:
                        factors['mkt-rf'] = factors['mkt'] - factors['rf']
                    factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                    if returns_aligned.empty:
                        logger.warning(f"No overlapping dates for {symbol} (Equity_USA_7)")
                    else:
                        desired_factors = ['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'hml', 'qmj', 'umd', 'smb', 'bab', 'TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY', 'tsm-com', 'tsm-fi', 'tsm-fx']
                        available_factors = [f for f in desired_factors if f in factors.columns]
                        if available_factors:
                            records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "Equity_USA_7"))

        # Equity (International)
        elif category in [
            "Asia ex-Japan Equity", "Australia & New Zealand Equity", "Canadian Equity Large Cap",
            "Europe Equity Large Cap", "Europe Equity Mid/Small Cap", "Greater China Equity",
            "India Equity", "Mexico Equity", "Japan Equity", "Korea Equity", "Latin America Equity",
            "UK Equity Large Cap", "Thailand Equity"
        ]:
            # Regression 1
            factors_eq = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB'], "Intl")
            rf_factors = load_db_factors(['RF'], "USA")
            factors = pd.concat([factors_eq, rf_factors], axis=1).dropna()
            if factors.empty:
                logger.warning(f"No valid factors for {symbol} (Equity_Intl_1)")
            else:
                if 'mkt' in factors.columns and 'rf' in factors.columns:
                    factors['mkt-rf'] = factors['mkt'] - factors['rf']
                factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                if returns_aligned.empty:
                    logger.warning(f"No overlapping dates for {symbol} (Equity_Intl_1)")
                else:
                    desired_factors = ['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'hml', 'qmj', 'smb', 'umd', 'tsm-eq', 'bab']
                    available_factors = [f for f in desired_factors if f in factors.columns]
                    if available_factors:
                        records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "Equity_Intl_1"))

            # Regression 2-4
            for portfolio_base, factor_set in [
                ("Intl Stock Selection", "Equity_Intl_2"),
                ("All Macro", "Equity_Intl_3"),
                ("Equity indices", "Equity_Intl_4")
            ]:
                for factor in ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value']:
                    factors = load_century_factors([factor], portfolio_base, factor, region="International")
                    if factors.empty:
                        logger.warning(f"No century factors for {symbol} ({factor_set}, factor: {factor})")
                        continue
                    factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                    if returns_aligned.empty:
                        logger.warning(f"No overlapping dates for {symbol} ({factor_set}, factor: {factor})")
                        continue
                    records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", factor_set))

        # Equity (Global)
        elif category in ["Global Emerging Markets Equity", "Global Equity Large Cap", "Global Equity Mid/Small Cap"]:
            # Regression 1
            factors_eq = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB'], "Global")
            rf_factors = load_db_factors(['RF'], "USA")
            factors = pd.concat([factors_eq, rf_factors], axis=1).dropna()
            if factors.empty:
                logger.warning(f"No valid factors for {symbol} (Equity_Global_1)")
            else:
                if 'mkt' in factors.columns and 'rf' in factors.columns:
                    factors['mkt-rf'] = factors['mkt'] - factors['rf']
                factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                if returns_aligned.empty:
                    logger.warning(f"No overlapping dates for {symbol} (Equity_Global_1)")
                else:
                    desired_factors = ['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'hml', 'qmj', 'smb', 'umd', 'tsm-eq', 'bab']
                    available_factors = [f for f in desired_factors if f in factors.columns]
                    if available_factors:
                        records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "Equity_Global_1"))

            # Regression 2-4
            for portfolio_base, factor_set in [
                ("All Stock Selection", "Equity_Global_2"),
                ("All Macro", "Equity_Global_3"),
                ("Equity indices", "Equity_Global_4")
            ]:
                for factor in ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value']:
                    factors = load_century_factors([factor], portfolio_base, factor)
                    if factors.empty:
                        logger.warning(f"No century factors for {symbol} ({factor_set}, factor: {factor})")
                        continue
                    factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                    if returns_aligned.empty:
                        logger.warning(f"No overlapping dates for {symbol} ({factor_set}, factor: {factor})")
                        continue
                    records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", factor_set))

        # Fixed Income
        elif category in [
            "Convertibles", "Emerging Markets Fixed Income", "Fixed Income Miscellaneous",
            "US Fixed Income", "US Municipal Fixed Income"
        ]:
            # Regression 1
            factors_fi = load_db_factors(['TSM-FI'])
            factors_fx = load_db_factors(['TSM-FX'])
            fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY'])
            factors = pd.concat([factors_fi, factors_fx, fi_factors], axis=1).dropna()
            if factors.empty:
                logger.warning(f"No valid factors for {symbol} (FI_1)")
            else:
                factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                if returns_aligned.empty:
                    logger.warning(f"No overlapping dates for {symbol} (FI_1)")
                else:
                    desired_factors = ['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY', 'tsm-fi', 'tsm-fx']
                    available_factors = [f for f in desired_factors if f in factors.columns]
                    if available_factors:
                        records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "FI_1"))

            # Regression 2-4
            for portfolio_base, factor_set in [
                ("Fixed income", "FI_2"),
                ("All Macro", "FI_3"),
                ("Equity indices", "FI_4")
            ]:
                for factor in ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value']:
                    factors = load_century_factors([factor], portfolio_base, factor)
                    if factors.empty:
                        logger.warning(f"No century factors for {symbol} ({factor_set}, factor: {factor})")
                        continue
                    factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                    if returns_aligned.empty:
                        logger.warning(f"No overlapping dates for {symbol} ({factor_set}, factor: {factor})")
                        continue
                    records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", factor_set))

        # Allocation
        elif category in [
            "Aggressive Allocation", "Allocation Miscellaneous", "Cautious Allocation",
            "Flexible Allocation", "Moderate Allocation"
        ]:
            # Regression 1
            factors_eq = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ'], "Global")
            factors_fi = load_db_factors(['TSM-FI'])
            rf_factors = load_db_factors(['RF'], "USA")
            fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY'])
            factors = pd.concat([factors_eq, factors_fi, rf_factors, fi_factors], axis=1).dropna()
            if factors.empty:
                logger.warning(f"No valid factors for {symbol} (Allocation_1)")
            else:
                if 'mkt' in factors.columns and 'rf' in factors.columns:
                    factors['mkt-rf'] = factors['mkt'] - factors['rf']
                factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                if returns_aligned.empty:
                    logger.warning(f"No overlapping dates for {symbol} (Allocation_1)")
                else:
                    desired_factors = ['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'hml', 'qmj', 'smb', 'umd', 'bab', 'tsm-eq', 'tsm-fi', 'TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY']
                    available_factors = [f for f in desired_factors if f in factors.columns]
                    if available_factors:
                        records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "Allocation_1"))

            # Regression 2
            for factor in ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value']:
                fi_factors = load_century_factors([factor], "Fixed income", factor)
                stock_factors = load_century_factors([factor], "All Stock Selection", factor)
                factors = pd.concat([fi_factors, stock_factors], axis=1).dropna()
                if factors.empty:
                    logger.warning(f"No valid factors for {symbol} (Allocation_2, factor: {factor})")
                    continue
                factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                if returns_aligned.empty:
                    logger.warning(f"No overlapping dates for {symbol} (Allocation_2, factor: {factor})")
                    continue
                records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", "Allocation_2"))

            # Regression 3-4
            for portfolio_base, factor_set in [
                ("All Macro", "Allocation_3"),
                ("Equity indices", "Allocation_4")
            ]:
                for factor in ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value']:
                    factors = load_century_factors([factor], portfolio_base, factor)
                    if factors.empty:
                        logger.warning(f"No century factors for {symbol} ({factor_set}, factor: {factor})")
                        continue
                    factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                    if returns_aligned.empty:
                        logger.warning(f"No overlapping dates for {symbol} ({factor_set}, factor: {factor})")
                        continue
                    records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", factor_set))

        # Alternatives
        elif category in [
            "Alternative Miscellaneous", "Long/Short Equity", "Market Neutral", "Multialternative"
        ]:
            # Regression 1
            factors_eq = load_db_factors(['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ'], "Global")
            factors_com = load_db_factors(['TSM-Com'])
            factors_fi = load_db_factors(['TSM-FI'])
            factors_fx = load_db_factors(['TSM-FX'])
            rf_factors = load_db_factors(['RF'], "USA")
            fi_factors = load_fixed_income_factors(['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY'])
            factors = pd.concat([factors_eq, factors_com, factors_fi, factors_fx, rf_factors, fi_factors], axis=1).dropna()
            if factors.empty:
                logger.warning(f"No valid factors for {symbol} (Alternative_1)")
            else:
                if 'mkt' in factors.columns and 'rf' in factors.columns:
                    factors['mkt-rf'] = factors['mkt'] - factors['rf']
                factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                if returns_aligned.empty:
                    logger.warning(f"No overlapping dates for {symbol} (Alternative_1)")
                else:
                    desired_factors = ['mkt-rf' if 'mkt-rf' in factors.columns else 'mkt', 'hml', 'qmj', 'smb', 'umd', 'bab', 'tsm-eq', 'tsm-fi', 'TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY', 'tsm-com', 'tsm-fx']
                    available_factors = [f for f in desired_factors if f in factors.columns]
                    if available_factors:
                        records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "Alternative_1"))

            # Regression 2
            for factor in ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value']:
                fi_factors = load_century_factors([factor], "Fixed income", factor)
                stock_factors = load_century_factors([factor], "All Stock Selection", factor)
                cmdty_factors = load_century_factors([factor], "Commodities", factor)
                factors = pd.concat([fi_factors, stock_factors, cmdty_factors], axis=1).dropna()
                if factors.empty:
                    logger.warning(f"No valid factors for {symbol} (Alternative_2, factor: {factor})")
                    continue
                factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                if returns_aligned.empty:
                    logger.warning(f"No overlapping dates for {symbol} (Alternative_2, factor: {factor})")
                    continue
                records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", "Alternative_2"))

            # Regression 3-4
            for portfolio_base, factor_set in [
                ("All Macro", "Alternative_3"),
                ("Equity indices", "Alternative_4")
            ]:
                for factor in ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value']:
                    factors = load_century_factors([factor], portfolio_base, factor)
                    if factors.empty:
                        logger.warning(f"No century factors for {symbol} ({factor_set}, factor: {factor})")
                        continue
                    factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                    if returns_aligned.empty:
                        logger.warning(f"No overlapping dates for {symbol} ({factor_set}, factor: {factor})")
                        continue
                    records.extend(run_rolling_regression(symbol, returns_aligned, factors, "OLS", factor_set))

        # Commodities
        elif category in ["Commodities Broad Basket", "Commodities Specified"]:
            # Regression 1
            factors = load_commodity_factors()
            if factors.empty:
                logger.warning(f"No commodity factors for {symbol} (Commodity_1)")
            else:
                factors, returns_aligned = factors.align(returns, join="inner", axis=0)
                if returns_aligned.empty:
                    logger.warning(f"No overlapping dates for {symbol} (Commodity_1)")
                else:
                    desired_factors = [
                        'excess_return_eqwt', 'excess_spot_return_eqwt', 'ir_adjusted_carry_eqwt',
                        'spot_return_eqwt', 'carry_eqwt', 'excess_return_long_short',
                        'excess_spot_return_long_short', 'ir_adjusted_carry_long_short',
                        'aggregate_backwardation_contango'
                    ]
                    available_factors = [f for f in desired_factors if f in factors.columns]
                    if available_factors:
                        records.extend(run_rolling_regression(symbol, returns_aligned, factors[available_factors], "OLS", "Commodity_1"))

        else:
            logger.warning(f"Skipping regressions for {symbol}: Category {category} not mapped")

    except Exception as e:
        logger.warning(f"Error processing fund {symbol}: {e}")
        return records
    
    logger.info(f"Generated {len(records)} regression records for {symbol}")
    return records

def process_region(region, fund_data_list):
    records = []
    logger.info(f"Processing {len(fund_data_list)} funds in {region}")
    
    executor_class = ThreadPoolExecutor if USE_THREADS else ProcessPoolExecutor
    with executor_class(max_workers=MAX_WORKERS) as executor:
        future_to_fund = {executor.submit(process_fund, fund_data): fund_data["SymbolCUSIP"] for fund_data in fund_data_list}
        for future in tqdm(future_to_fund, total=len(fund_data_list), desc=f"Processing {region}", file=sys.stdout):
            try:
                records.extend(future.result())
            except Exception as e:
                logger.error(f"Error processing {future_to_fund[future]}: {e}")
    
    logger.info(f"Region {region} generated {len(records)} total records")
    if not DRY_RUN:
        insert_batch(records)
    
    return records

# Section 6: Main Pipeline
@timer
def main():
    logger.info("Starting main pipeline")
    try:
        fund_meta = load_fund_metadata()
    except Exception as e:
        logger.error(f"Failed to load metadata: {e}")
        return {"error": str(e)}
    
    regions = fund_meta["Region"].unique()
    logger.info(f"Total funds: {len(fund_meta)}, Regions: {regions}")
    
    fund_ids = fund_meta["SymbolCUSIP"].tolist()
    if SAMPLE_DRY_RUN:
        fund_ids = random.sample(fund_ids, min(SAMPLE_SIZE, len(fund_ids)))
        logger.info(f"Sampled {len(fund_ids)} funds: {fund_ids}")
    
    try:
        returns = load_fund_returns(fund_ids)
    except Exception as e:
        logger.error(f"Failed to load returns: {e}")
        return {"error": str(e)}
    
    fund_data_list = [
        {
            "SymbolCUSIP": row["SymbolCUSIP"],
            "Global_Category_Name": row["Global_Category_Name"],
            "CWA_Broad_Category_Name": row.get("CWA_Broad_Category_Name", None),
            "returns": returns[row["SymbolCUSIP"]].to_dict()
        }
        for _, row in fund_meta.iterrows() if row["SymbolCUSIP"] in returns.columns
    ]
    
    summary = {"total_funds": len(fund_data_list), "regions": {}, "errors": 0}
    for region in sorted(set(regions) - {'Unknown'} | {'USA'}):
        region_funds = [fd for fd in fund_data_list if fund_meta[fund_meta["SymbolCUSIP"] == fd["SymbolCUSIP"]]["Region"].iloc[0] == region]
        if SAMPLE_DRY_RUN and len(region_funds) > SAMPLE_SIZE:
            region_funds = random.sample(region_funds, SAMPLE_SIZE)
            logger.info(f"Sampled {len(region_funds)} funds for {region}")
        records = process_region(region, region_funds)
        summary["regions"][region] = {"funds_processed": len(region_funds), "records": len(records)}
    
    logger.info(f"Pipeline summary: {summary}")
    return summary

# Section 7: Database Output
def insert_batch(records):
    try:
        df = pd.DataFrame(records)
        with database_transaction() as connection:
            df.to_sql("AQRR_Factor_Attribution", connection, if_exists="append", index=False, method="multi")
        logger.info(f"Inserted {len(df)} records to database")
    except Exception as e:
        logger.error(f"Error inserting batch: {e}")
        raise

if __name__ == "__main__":
    try:
        main()
    except Exception as e:
        logger.error(f"Main execution failed: {e}")
        raise
# Out:
# Processing Global:   0%|          | 0/10 [00:00<?, ?it/s]2025-04-13 22:30:52,563 - ERROR - Error processing HERIX: A process in the process pool was terminated abruptly while the future was running or pending.
# Processing Global:  10%|█         | 1/10 [00:00<00:03,  2.95it/s]2025-04-13 22:30:52,565 - ERROR - Error processing PCCIX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,566 - ERROR - Error processing ROAM: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,567 - ERROR - Error processing CGXU: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,568 - ERROR - Error processing FYLG: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,569 - ERROR - Error processing CGCIX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,569 - ERROR - Error processing CFIZX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,570 - ERROR - Error processing CAAYX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,570 - ERROR - Error processing MGBJX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,571 - ERROR - Error processing EIISX: A process in the process pool was terminated abruptly while the future was running or pending.
# Processing Global: 100%|██████████| 10/10 [00:00<00:00, 28.83it/s]
# Processing International:   0%|          | 0/5 [00:00<?, ?it/s]2025-04-13 22:30:52,751 - ERROR - Error processing PCCE: A process in the process pool was terminated abruptly while the future was running or pending.
# Processing International:  20%|██        | 1/5 [00:00<00:00,  8.00it/s]2025-04-13 22:30:52,752 - ERROR - Error processing FPXE: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,753 - ERROR - Error processing KGRN: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,753 - ERROR - Error processing INCO: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,755 - ERROR - Error processing KTEC: A process in the process pool was terminated abruptly while the future was running or pending.
# Processing International: 100%|██████████| 5/5 [00:00<00:00, 39.14it/s]
# Processing USA:   0%|          | 0/35 [00:00<?, ?it/s]2025-04-13 22:30:52,974 - ERROR - Error processing PBDC: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,976 - ERROR - Error processing RSSY: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,977 - ERROR - Error processing SEIQ: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,978 - ERROR - Error processing QGRW: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,980 - ERROR - Error processing AVMC: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,981 - ERROR - Error processing PTIAX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,981 - ERROR - Error processing TABGX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,982 - ERROR - Error processing SPIN: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,983 - ERROR - Error processing KRE: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,984 - ERROR - Error processing COPX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,985 - ERROR - Error processing URNM: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,986 - ERROR - Error processing AREA: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,986 - ERROR - Error processing TINY: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,987 - ERROR - Error processing FLCV: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,987 - ERROR - Error processing NYF: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,988 - ERROR - Error processing FLBL: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,989 - ERROR - Error processing WTBN: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,989 - ERROR - Error processing GTO: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,990 - ERROR - Error processing LFAF: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,991 - ERROR - Error processing LIAO: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,992 - ERROR - Error processing GBIL: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,992 - ERROR - Error processing JBBB: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,993 - ERROR - Error processing WHYIX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,993 - ERROR - Error processing AIAHX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,994 - ERROR - Error processing CLDIX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,995 - ERROR - Error processing GEGTX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,995 - ERROR - Error processing EISMX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,996 - ERROR - Error processing FGUSX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,997 - ERROR - Error processing FUSAX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,997 - ERROR - Error processing OMSYX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,998 - ERROR - Error processing JTBDX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,998 - ERROR - Error processing CBFSX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:52,999 - ERROR - Error processing MTALX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:53,000 - ERROR - Error processing NBMLX: A process in the process pool was terminated abruptly while the future was running or pending.
# 2025-04-13 22:30:53,000 - ERROR - Error processing NMHIX: A process in the process pool was terminated abruptly while the future was running or pending.
# Processing USA: 100%|██████████| 35/35 [00:00<00:00, 405.85it/s]

# %%
#new grok review with some fixes

# %%
import pandas as pd
import numpy as np
import os
import random
import logging
from datetime import timedelta, datetime
from dateutil.relativedelta import relativedelta
from concurrent.futures import ProcessPoolExecutor, ThreadPoolExecutor
from sqlalchemy import create_engine
from tqdm import tqdm
from statsmodels.regression.linear_model import OLS
from statsmodels.tools.tools import add_constant
import statsmodels.api as sm
import time
import pickle
import sys
from contextlib import contextmanager
from functools import wraps


# Section 1: Configuration and Setup
CONFIG = {
    "database": {
        "server": "JULIANS_LAPTOP\\SQLEXPRESS",
        "database": "CWA_Fund_Database",
        "driver": "ODBC Driver 18 for SQL Server"
    },
    "return_metric": "1 Month Return",
    "rolling_periods": [12, 24, 36, 48, 60],
    "dry_run": True,
    "sample_dry_run": True,
    "sample_size": 50,
    "chunk_size": 5600,
    "batch_insert_size": 10000,
    "max_workers_cpu": min(13, os.cpu_count()),  # 14 workers for CPU-bound tasks
    "max_workers_io": 30,  # 30 workers for I/O-bound tasks
    "use_threads": False,
    "unmapped_category_behavior": "allocation"  # Options: "allocation", "all"
}

CONNECTION_STRING = (
    f"mssql+pyodbc://{CONFIG['database']['server']}/{CONFIG['database']['database']}"
    f"?driver={CONFIG['database']['driver']}&trusted_connection=yes&TrustServerCertificate=yes"
)
try:
    engine = create_engine(CONNECTION_STRING)
except Exception as e:
    print(f"Database connection failed: {e}")
    raise

RETURN_METRIC = CONFIG["return_metric"]
ROLLING_PERIODS = CONFIG["rolling_periods"]
DRY_RUN = CONFIG["dry_run"]
SAMPLE_DRY_RUN = CONFIG["sample_dry_run"]
SAMPLE_SIZE = CONFIG["sample_size"]
CHUNK_SIZE = CONFIG["chunk_size"]
BATCH_INSERT_SIZE = CONFIG["batch_insert_size"]
MAX_WORKERS_CPU = CONFIG["max_workers_cpu"]
MAX_WORKERS_IO = CONFIG["max_workers_io"]
USE_THREADS = CONFIG["use_threads"]
UNMAPPED_CATEGORY_BEHAVIOR = CONFIG["unmapped_category_behavior"]

# Logging setup
SUMMARY_LOG = "factor_attribution_summary.log"
logging.basicConfig(
    level=logging.INFO,  # Use INFO to reduce verbosity
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler("factor_attribution.log"),
        logging.StreamHandler(sys.stdout)
    ],
    force=True
)
logger = logging.getLogger()

def log_summary(message):
    with open(SUMMARY_LOG, 'a') as f:
        f.write(f"{datetime.now()}: {message}\n")

# Section 2: Helper Functions

def category_to_region(category):
    mapping = {
        "US Equity Large Cap Blend": ("USA", "US Equity Large Cap Blend"),
        "US Equity Large Cap Growth": ("USA", "US Equity Large Cap Growth"),
        "US Equity Large Cap Value": ("USA", "US Equity Large Cap Value"),
        "US Equity Mid Cap": ("USA", "US Equity Mid Cap"),
        "US Equity Small Cap": ("USA", "US Equity Small Cap"),
        "Global Equity Large Cap": ("Global", "Global Equity Large Cap"),
        "Global Equity Mid/Small Cap": ("Global", "Global Equity Mid/Small Cap"),
        "Global Emerging Markets Equity": ("Global", "Global Emerging Markets Equity"),
        "Europe Equity Large Cap": ("International", "Europe Equity Large Cap"),
        "Asia Equity": ("International", "Asia Equity"),
        "Japan Equity": ("International", "Japan Equity"),
        "Emerging Markets Fixed Income": ("International", "Emerging Markets Fixed Income"),
        "US Fixed Income": ("USA", "US Fixed Income"),
        "US Municipal Fixed Income": ("USA", "US Municipal Fixed Income"),
        "Global Fixed Income": ("Global", "Global Fixed Income"),
        "Flexible Allocation": ("Global", "Flexible Allocation"),
        "Aggressive Allocation": ("Global", "Aggressive Allocation"),
        "Moderate Allocation": ("Global", "Moderate Allocation"),
        "Cautious Allocation": ("Global", "Cautious Allocation"),
        "Commodities Broad Basket": ("Global", "Commodities Broad Basket"),
        "Commodities Specified": ("Global", "Commodities Specified"),
        "Options Trading": ("USA", "Options Trading"),
        "Multialternative": ("Global", "Multialternative"),
        "Market Neutral": ("Global", "Market Neutral"),
        "Long/Short Equity": ("Global", "Long/Short Equity"),
        "Alternative Miscellaneous": ("Global", "Alternative Miscellaneous"),
        "Energy Sector Equity": ("USA", "Energy Sector Equity"),
        "Equity Miscellaneous": ("USA", "Equity Miscellaneous"),
        "Financials Sector Equity": ("USA", "Financials Sector Equity"),
        "Healthcare Sector Equity": ("USA", "Healthcare Sector Equity"),
        "Consumer Goods & Services Sector Equity": ("USA", "Consumer Goods & Services Sector Equity"),
        "Communications Sector Equity": ("USA", "Communications Sector Equity"),
        "Industrials Sector Equity": ("USA", "Industrials Sector Equity"),
        "Other Sector Equity": ("USA", "Other Sector Equity"),
        "Real Estate Sector Equity": ("USA", "Real Estate Sector Equity"),
        "Precious Metals Sector Equity": ("USA", "Precious Metals Sector Equity"),
        "Technology Sector Equity": ("USA", "Technology Sector Equity"),
        "Utilities Sector Equity": ("USA", "Utilities Sector Equity"),
        "Natural Resources Sector Equity": ("USA", "Natural Resources Sector Equity"),
        "Infrastructure Sector Equity": ("USA", "Infrastructure Sector Equity"),
        "Trading Tools": ("USA", "Trading Tools"),
        "Asia ex-Japan Equity": ("International", "Asia ex-Japan Equity"),
        "Australia & New Zealand Equity": ("International", "Australia & New Zealand Equity"),
        "Canadian Equity Large Cap": ("International", "Canadian Equity Large Cap"),
        "Europe Equity Mid/Small Cap": ("International", "Europe Equity Mid/Small Cap"),
        "Greater China Equity": ("International", "Greater China Equity"),
        "India Equity": ("International", "India Equity"),
        "Mexico Equity": ("International", "Mexico Equity"),
        "Korea Equity": ("International", "Korea Equity"),
        "Latin America Equity": ("International", "Latin America Equity"),
        "UK Equity Large Cap": ("International", "UK Equity Large Cap"),
        "Thailand Equity": ("International", "Thailand Equity"),
        "Convertibles": ("USA", "Convertibles"),
        "Fixed Income Miscellaneous": ("USA", "Fixed Income Miscellaneous"),
        "Allocation Miscellaneous": ("Global", "Allocation Miscellaneous")
    }
    return mapping.get(category, ("USA", "Unknown"))

@contextmanager
def database_transaction():
    connection = engine.connect()
    transaction = connection.begin()
    try:
        yield connection
        transaction.commit()
    except Exception as e:
        transaction.rollback()
        logger.error(f"Transaction failed: {e}")
        raise
    finally:
        connection.close()

def timer(func):
    @wraps(func)
    def wrapper(*args, **kwargs):
        start_time = time.time()
        logger.debug(f"Starting {func.__name__}")
        result = func(*args, **kwargs)
        logger.info(f"{func.__name__} took {time.time() - start_time:.2f} seconds")
        return result
    return wrapper

# Section 3: Data Loading Functions
@timer
def load_fund_metadata():
    query = """
    SELECT 
        f.SymbolCUSIP, 
        f.Region, 
        f.YC_Global_Category_ID, 
        c.Global_Category_Name,
        f.YC_Category_ID,
        y.Category_Name,
        f.CWA_Broad_Category_ID,
        b.CWA_Broad_Category_Name
    FROM Funds_to_Screen f
    JOIN YC_Global_Category_List c ON f.YC_Global_Category_ID = c.ID
    JOIN YC_Category_List y ON f.YC_Category_ID = y.ID
    LEFT JOIN CWA_Broad_Category_List b ON f.CWA_Broad_Category_ID = b.ID
    """
    try:
        df = pd.read_sql(query, engine)
        logger.info(f"Loaded metadata for {len(df)} funds")
        df[["Region", "FactorProfile"]] = df["Global_Category_Name"].map(category_to_region).apply(pd.Series)
        if df["CWA_Broad_Category_Name"].isnull().all():
            logger.warning("CWA_Broad_Category_Name missing; Equity regressions 5-7 will be skipped")
        return df.dropna(subset=["Region", "FactorProfile"])
    except Exception as e:
        logger.error(f"Error loading metadata: {e}")
        raise

# Global cache for factor data
FACTOR_CACHE = {}

@timer
def load_db_factors(factor_list, region="Global", table="factor_returns", asset_class=None):
    cache_key = (tuple(factor_list), region, table, asset_class)
    if cache_key in FACTOR_CACHE:
        logger.debug(f"Using cached factors for {cache_key}")
        return FACTOR_CACHE[cache_key]
    
    factor_in_clause = ','.join([f"'{f}'" for f in factor_list])
    query = f"""
        SELECT date AS Date, factor AS Factor, value AS Value
        FROM {table}
        WHERE factor IN ({factor_in_clause})
    """
    if region and not any(f.startswith('TSM-') or f == 'RF' for f in factor_list):
        query += f" AND region = '{region}'"
    elif 'RF' in factor_list:
        query += " AND region = 'USA'"
    if asset_class:
        query += f" AND asset_class = '{asset_class}'"
    
    logger.debug(f"Executing query: {query}")
    df = pd.read_sql_query(query, engine, parse_dates=['Date'])
    if df.empty:
        logger.warning(f"No data for factors {factor_list} in {table} (region: {region}, asset_class: {asset_class})")
        return pd.DataFrame()
    
    duplicates = df.duplicated(subset=['Date', 'Factor']).sum()
    if duplicates > 0:
        logger.warning(f"Found {duplicates} duplicate Date-Factor pairs in {table} for {factor_list}; dropping duplicates")
        df = df.drop_duplicates(subset=['Date', 'Factor'], keep='first')
    
    pivoted_df = df.pivot(index="Date", columns="Factor", values="Value").rename(
        columns={
            'MKT': 'mkt', 'SMB': 'smb', 'HML_Devil': 'hml', 'UMD': 'umd', 'QMJ': 'qmj',
            'BAB': 'bab', 'RF': 'rf', 'TSM-Com': 'tsm-com', 'TSM-EQ': 'tsm-eq',
            'TSM-FI': 'tsm-fi', 'TSM-FX': 'tsm-fx', 'TSM-MA': 'tsm-ma'
        }
    )
    pivoted_df.index = pd.to_datetime(pivoted_df.index) + pd.offsets.MonthEnd(0)
    pivoted_df.index = pivoted_df.index.drop_duplicates()
    pivoted_df = pivoted_df.asfreq('ME')
    missing_factors = [f for f in factor_list if f.lower() not in pivoted_df.columns]
    if missing_factors:
        logger.warning(f"Missing factors in {table} (region: {region}): {missing_factors}")
    
    FACTOR_CACHE[cache_key] = pivoted_df
    return pivoted_df

@timer
def load_fund_returns(fund_ids=None):
    try:
        query = """
        SELECT SymbolCUSIP, Date, ReturnValue
        FROM Fund_Returns_Timeseries
        WHERE Metric = '1 Month Return' AND ReturnValue IS NOT NULL AND Date IS NOT NULL
        """
        if fund_ids:
            fund_ids = [fid for fid in fund_ids if isinstance(fid, str) and fid.strip()]
            if not fund_ids:
                logger.warning("No valid SymbolCUSIP provided")
                return pd.DataFrame()
            fund_ids_str = ",".join([f"'{fid}'" for fid in fund_ids])
            query += f" AND SymbolCUSIP IN ({fund_ids_str})"
        
        logger.debug(f"Executing query: {query}")
        chunks = []
        for chunk in pd.read_sql_query(query, engine, parse_dates=["Date"], chunksize=CHUNK_SIZE):
            logger.debug(f"Loaded chunk of {len(chunk)} rows")
            chunks.append(chunk)
        df = pd.concat(chunks) if chunks else pd.DataFrame()
        if df.empty:
            logger.warning(f"No returns data loaded for SymbolCUSIP: {fund_ids}")
            return pd.DataFrame()
        
        logger.info(f"Loaded returns for {len(df['SymbolCUSIP'].unique())} funds")
        pivoted = df.pivot(index="Date", columns="SymbolCUSIP", values="ReturnValue")
        pivoted.index = pd.to_datetime(pivoted.index) + pd.offsets.MonthEnd(0)
        pivoted.index = pivoted.index.drop_duplicates()
        pivoted = pivoted.asfreq('ME')
        for col in pivoted.columns:
            if not pd.api.types.is_numeric_dtype(pivoted[col]):
                logger.warning(f"Non-numeric returns for {col}; converting")
                pivoted[col] = pd.to_numeric(pivoted[col], errors='coerce')
        return pivoted
    except Exception as e:
        logger.error(f"Error loading returns: {e}")
        raise

@timer
def load_century_factors(factor_list, portfolio_base, factor, asset_class=None, region="Global"):
    factor_in_clause = ','.join([f"'{f}'" for f in factor_list])
    portfolio = f"{portfolio_base} {factor}"
    query = f"""
        SELECT date AS Date, factor AS Factor, value AS Value
        FROM aqr_century_factors
        WHERE factor IN ({factor_in_clause})
        AND portfolio = ?
    """
    params = [portfolio]
    if asset_class:
        query += " AND asset_class = ?"
        params.append(asset_class)
    if region != "Global":
        query += " AND region = ?"
        params.append(region)
    df = pd.read_sql(query, engine, params=params, parse_dates=['Date'])
    if df.empty:
        logger.warning(f"No data for factors {factor_list} in aqr_century_factors (portfolio: {portfolio}, region: {region})")
        return pd.DataFrame()
    pivoted_df = df.pivot(index="Date", columns="Factor", values="Value")
    pivoted_df.index = pd.to_datetime(pivoted_df.index) + pd.offsets.MonthEnd(0)
    pivoted_df.index = pivoted_df.index.drop_duplicates()
    pivoted_df = pivoted_df.asfreq('ME')
    return pivoted_df

@timer
def load_commodity_factors():
    query = """
        SELECT date AS Date, 
               excess_return_eqwt, 
               excess_spot_return_eqwt, 
               ir_adjusted_carry_eqwt, 
               spot_return_eqwt, 
               carry_eqwt, 
               excess_return_long_short, 
               excess_spot_return_long_short, 
               ir_adjusted_carry_long_short, 
               aggregate_backwardation_contango
        FROM aqr_cmdty_factors
    """
    df = pd.read_sql(query, engine, parse_dates=['Date'])
    if df.empty:
        logger.warning("No commodity factors loaded")
        return pd.DataFrame()
    pivoted_df = df.set_index("Date")
    pivoted_df.index = pd.to_datetime(pivoted_df.index) + pd.offsets.MonthEnd(0)
    pivoted_df.index = pivoted_df.index.drop_duplicates()
    pivoted_df = pivoted_df.asfreq('ME')
    return pivoted_df

@timer
def load_fixed_income_factors(factor_list):
    factor_in_clause = ','.join([f"'{f}'" for f in factor_list])
    query = f"""
        SELECT Date, Factor_Name, ReturnValue
        FROM Fixed_Income_Factor_Returns
        WHERE Factor_Name IN ({factor_in_clause})
    """
    logger.debug(f"Executing query: {query}")
    df = pd.read_sql_query(query, engine, parse_dates=["Date"])
    if df.empty:
        logger.warning(f"No fixed income factors for {factor_list}")
        return pd.DataFrame()
    pivoted_df = df.pivot(index="Date", columns="Factor_Name", values="ReturnValue")
    pivoted_df.index = pd.to_datetime(pivoted_df.index) + pd.offsets.MonthEnd(0)
    pivoted_df.index = pivoted_df.index.drop_duplicates()
    pivoted_df = pivoted_df.asfreq('ME')
    return pivoted_df

# Section 4: Regression Functions
def run_rolling_regression(fund, returns, factors, regression_type, factor_set):
    results = []
    try:
        returns = pd.Series(returns).dropna()
        factors = pd.DataFrame(factors).dropna()
        returns.index = pd.to_datetime(returns.index, errors='coerce')
        factors.index = pd.to_datetime(factors.index, errors='coerce')
        returns = returns[returns.index.notnull()]
        factors = factors[factors.index.notnull()]
        
        if returns.empty or factors.empty:
            logger.warning(f"Empty data for {fund} ({factor_set})")
            return results
        
        overlap_dates = returns.index.intersection(factors.index)
        months_available = len(overlap_dates)
        date_start = overlap_dates.min().strftime('%Y-%m-%d') if months_available > 0 else "none"
        date_end = overlap_dates.max().strftime('%Y-%m-%d') if months_available > 0 else "none"
        
        min_window = min(ROLLING_PERIODS)
        if months_available < min_window:
            skipped_windows = [f"{w}m" for w in ROLLING_PERIODS]
            logger.warning(f"Fund {fund} ({factor_set}) skipped for windows {skipped_windows}: "
                           f"{months_available} months available from {date_start} to {date_end}, need {min_window}")
            return results
        
        logger.debug(f"Fund {fund}: {len(returns)} returns, {len(factors)} factors, {len(overlap_dates)} overlapping dates")
        
        factors = factors.reindex(overlap_dates)
        returns = returns.reindex(overlap_dates)
        
        for window in ROLLING_PERIODS:
            window_results = []
            if months_available < window:
                logger.warning(f"Fund {fund} ({factor_set}, window={window}m) skipped: {months_available} months available "
                               f"from {date_start} to {date_end}, need {window}")
                continue
            
            expected_rolls = max(0, len(returns) - window + 1)
            logger.debug(f"Fund {fund}: Expected {expected_rolls} rolls for window {window}m with factors {factors.columns.tolist()}")
            for start_idx in range(expected_rolls):
                end_idx = start_idx + window
                y = returns.iloc[start_idx:end_idx]
                X = factors.iloc[start_idx:end_idx]
                if len(y) != window or y.isnull().any() or X.isnull().any().any():
                    continue
                X_const = add_constant(X)
                model = OLS(y, X_const).fit()
                for factor in X.columns:
                    result = {
                        "SymbolCUSIP": fund,
                        "MonthEndDate": y.index[-1],
                        "RollPeriod": f"{window}m",
                        "Factor_Name": factor,
                        "Coefficient": model.params.get(factor, np.nan),
                        "P_Value": model.pvalues.get(factor, np.nan),
                        "T_Stat": model.tvalues.get(factor, np.nan),
                        "Standard_Error": model.bse.get(factor, np.nan),
                        "CI_Lower": model.conf_int().loc[factor][0] if factor in model.params else np.nan,
                        "CI_Upper": model.conf_int().loc[factor][1] if factor in model.params else np.nan,
                        "Adj_R2": model.rsquared_adj,
                        "Correlation": np.corrcoef(y, model.fittedvalues)[0, 1] if len(y) > 1 else np.nan,
                        "Regression_Type": regression_type,
                        "Factor_Set": factor_set
                    }
                    window_results.append(result)
            
            if window_results:
                factor_counts = {factor: len([r for r in window_results if r["Factor_Name"] == factor]) for factor in factors.columns}
                logger.info(f"Fund {fund} succeeded for window {window}m with factors {factor_counts}, total {len(window_results)} records")
                results.extend(window_results)
        
    except Exception as e:
        logger.error(f"Regression error for {fund} ({factor_set}): {e}")
    return results

# Section 5: Processing Functions
def process_fund(fund_data):
    records = []
    symbol = fund_data["SymbolCUSIP"]
    category = fund_data["Global_Category_Name"]
    broad_category = fund_data["CWA_Broad_Category_Name"]
    returns = pd.Series(fund_data["returns"]).dropna()
    
    logger.debug(f"Starting process_fund for {symbol}")
    
    try:
        if returns.empty:
            logger.warning(f"No valid returns for {symbol}")
            return records

        # Define regression sets
        regression_sets = {
            "Equity_USA": [
                ("Equity_USA_1", ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB'], "USA", None),
                ("Equity_USA_2", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "USA", "US Stock Selection"),
                ("Equity_USA_3", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "USA", "All Macro"),
                ("Equity_USA_4", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "USA", "Equity indices"),
                ("Equity_USA_5", ['MKT', 'BAB', 'TSM-FI', 'TSM-FX', 'excess_return_eqwt'], "USA", None),
                ("Equity_USA_6", ['MKT', 'SMB', 'BAB', 'TSM-Com'], "USA", None),
                ("Equity_USA_7", ['MKT', 'HML_Devil', 'QMJ', 'UMD', 'SMB', 'BAB', 'TSM-Com', 'TSM-FI', 'TSM-FX'], "USA", None)
            ],
            "Equity_Intl": [
                ("Equity_Intl_1", ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB'], "Intl", None),
                ("Equity_Intl_2", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "International", "Intl Stock Selection"),
                ("Equity_Intl_3", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "International", "All Macro"),
                ("Equity_Intl_4", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "International", "Equity indices")
            ],
            "Equity_Global": [
                ("Equity_Global_1", ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB'], "Global", None),
                ("Equity_Global_2", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "All Stock Selection"),
                ("Equity_Global_3", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "All Macro"),
                ("Equity_Global_4", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "Equity indices")
            ],
            "Fixed_Income": [
                ("FI_1", ['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY', 'TSM-FI', 'TSM-FX'], "Global", None),
                ("FI_2", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "Fixed income"),
                ("FI_3", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "All Macro"),
                ("FI_4", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "Equity indices")
            ],
            "Allocation": [
                ("Allocation_1", ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ', 'TSM-FI'], "Global", None),
                ("Allocation_2", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", None),
                ("Allocation_3", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "All Macro"),
                ("Allocation_4", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "Equity indices")
            ],
            "Alternative": [
                ("Alternative_1", ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ', 'TSM-FI', 'TSM-Com', 'TSM-FX'], "Global", None),
                ("Alternative_2", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", None),
                ("Alternative_3", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "All Macro"),
                ("Alternative_4", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "Equity indices")
            ],
            "Commodity": [
                ("Commodity_1", ['excess_return_eqwt', 'excess_spot_return_eqwt', 'ir_adjusted_carry_eqwt', 'spot_return_eqwt', 'carry_eqwt', 'excess_return_long_short', 'excess_spot_return_long_short', 'ir_adjusted_carry_long_short', 'aggregate_backwardation_contango'], "Global", None)
            ]
        }

        # Map categories to regression sets
        category_to_regressions = {
            "Energy Sector Equity": "Equity_USA",
            "Equity Miscellaneous": "Equity_USA",
            "Financials Sector Equity": "Equity_USA",
            "Healthcare Sector Equity": "Equity_USA",
            "Consumer Goods & Services Sector Equity": "Equity_USA",
            "Communications Sector Equity": "Equity_USA",
            "Industrials Sector Equity": "Equity_USA",
            "Other Sector Equity": "Equity_USA",
            "Real Estate Sector Equity": "Equity_USA",
            "Precious Metals Sector Equity": "Equity_USA",
            "Technology Sector Equity": "Equity_USA",
            "Utilities Sector Equity": "Equity_USA",
            "US Equity Large Cap Blend": "Equity_USA",
            "US Equity Large Cap Growth": "Equity_USA",
            "US Equity Large Cap Value": "Equity_USA",
            "US Equity Mid Cap": "Equity_USA",
            "US Equity Small Cap": "Equity_USA",
            "Options Trading": "Equity_USA",
            "Natural Resources Sector Equity": "Equity_USA",
            "Infrastructure Sector Equity": "Equity_USA",
            "Asia ex-Japan Equity": "Equity_Intl",
            "Australia & New Zealand Equity": "Equity_Intl",
            "Canadian Equity Large Cap": "Equity_Intl",
            "Europe Equity Large Cap": "Equity_Intl",
            "Europe Equity Mid/Small Cap": "Equity_Intl",
            "Greater China Equity": "Equity_Intl",
            "India Equity": "Equity_Intl",
            "Mexico Equity": "Equity_Intl",
            "Japan Equity": "Equity_Intl",
            "Korea Equity": "Equity_Intl",
            "Latin America Equity": "Equity_Intl",
            "UK Equity Large Cap": "Equity_Intl",
            "Thailand Equity": "Equity_Intl",
            "Global Emerging Markets Equity": "Equity_Global",
            "Global Equity Large Cap": "Equity_Global",
            "Global Equity Mid/Small Cap": "Equity_Global",
            "Global Fixed Income": "Fixed_Income",
            "Convertibles": "Fixed_Income",
            "Emerging Markets Fixed Income": "Fixed_Income",
            "Fixed Income Miscellaneous": "Fixed_Income",
            "US Fixed Income": "Fixed_Income",
            "US Municipal Fixed Income": "Fixed_Income",
            "Aggressive Allocation": "Allocation",
            "Allocation Miscellaneous": "Allocation",
            "Cautious Allocation": "Allocation",
            "Flexible Allocation": "Allocation",
            "Moderate Allocation": "Allocation",
            "Alternative Miscellaneous": "Alternative",
            "Long/Short Equity": "Alternative",
            "Market Neutral": "Alternative",
            "Multialternative": "Alternative",
            "Commodities Broad Basket": "Commodity",
            "Commodities Specified": "Commodity"
        }

        # Determine regression sets to run
        regression_category = category_to_regressions.get(category)
        if not regression_category:
            if UNMAPPED_CATEGORY_BEHAVIOR == "allocation":
                regression_category = "Allocation"
                logger.warning(f"Unmapped category {category} for {symbol}; defaulting to Allocation regressions")
            else:  # "all"
                regression_category = "all"
                logger.warning(f"Unmapped category {category} for {symbol}; running all regressions")

        # Run regressions
        if regression_category == "all":
            for reg_set in regression_sets.values():
                for reg_name, factors, region, portfolio_base in reg_set:
                    try:
                        if portfolio_base:
                            for factor in factors:
                                factor_data = load_century_factors([factor], portfolio_base, factor, region=region)
                                if factor_data.empty:
                                    logger.warning(f"No factors for {symbol} ({reg_name}, factor: {factor})")
                                    continue
                                factor_data, returns_aligned = factor_data.align(returns, join="inner", axis=0)
                                if returns_aligned.empty:
                                    logger.warning(f"No overlapping dates for {symbol} ({reg_name}, factor: {factor})")
                                    continue
                                records.extend(run_rolling_regression(symbol, returns_aligned, factor_data, "OLS", reg_name))
                        else:
                            if reg_name.startswith("Commodity"):
                                factor_data = load_commodity_factors()
                            elif reg_name.startswith("FI"):
                                factor_data = pd.concat([
                                    load_db_factors([f for f in factors if f not in ['TERM', 'TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY']], region),
                                    load_fixed_income_factors([f for f in factors if f in ['TERM', 'TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY']])
                                ], axis=1).dropna()
                            else:
                                factor_data = load_db_factors(factors, region)
                            if factor_data.empty:
                                logger.warning(f"No factors for {symbol} ({reg_name})")
                                continue
                            if 'mkt' in factor_data.columns and 'rf' in factor_data.columns:
                                factor_data['mkt-rf'] = factor_data['mkt'] - factor_data['rf']
                            factor_data, returns_aligned = factor_data.align(returns, join="inner", axis=0)
                            if returns_aligned.empty:
                                logger.warning(f"No overlapping dates for {symbol} ({reg_name})")
                                continue
                            desired_factors = [f if f != 'MKT' else ('mkt-rf' if 'mkt-rf' in factor_data.columns else 'mkt') for f in factors]
                            available_factors = [f for f in desired_factors if f in factor_data.columns]
                            if available_factors:
                                records.extend(run_rolling_regression(symbol, returns_aligned, factor_data[available_factors], "OLS", reg_name))
                    except Exception as e:
                        logger.warning(f"Error in regression for {symbol} ({reg_name}): {str(e)}")
                        continue
        else:
            for reg_name, factors, region, portfolio_base in regression_sets[regression_category]:
                try:
                    if portfolio_base:
                        for factor in factors:
                            factor_data = load_century_factors([factor], portfolio_base, factor, region=region)
                            if factor_data.empty:
                                logger.warning(f"No factors for {symbol} ({reg_name}, factor: {factor})")
                                continue
                            factor_data, returns_aligned = factor_data.align(returns, join="inner", axis=0)
                            if returns_aligned.empty:
                                logger.warning(f"No overlapping dates for {symbol} ({reg_name}, factor: {factor})")
                                continue
                            records.extend(run_rolling_regression(symbol, returns_aligned, factor_data, "OLS", reg_name))
                    else:
                        if reg_name.startswith("Commodity"):
                            factor_data = load_commodity_factors()
                        elif reg_name.startswith("FI"):
                            factor_data = pd.concat([
                                load_db_factors([f for f in factors if f not in ['TERM', 'TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY']], region),
                                load_fixed_income_factors([f for f in factors if f in ['TERM', 'TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY']])
                            ], axis=1).dropna()
                        else:
                            factor_data = load_db_factors(factors, region)
                        if factor_data.empty:
                            logger.warning(f"No factors for {symbol} ({reg_name})")
                            continue
                        if 'mkt' in factor_data.columns and 'rf' in factor_data.columns:
                            factor_data['mkt-rf'] = factor_data['mkt'] - factor_data['rf']
                        factor_data, returns_aligned = factor_data.align(returns, join="inner", axis=0)
                        if returns_aligned.empty:
                            logger.warning(f"No overlapping dates for {symbol} ({reg_name})")
                            continue
                        desired_factors = [f if f != 'MKT' else ('mkt-rf' if 'mkt-rf' in factor_data.columns else 'mkt') for f in factors]
                        available_factors = [f for f in desired_factors if f in factor_data.columns]
                        if available_factors:
                            records.extend(run_rolling_regression(symbol, returns_aligned, factor_data[available_factors], "OLS", reg_name))
                except Exception as e:
                    logger.warning(f"Error in regression for {symbol} ({reg_name}): {str(e)}")
                    continue

    except Exception as e:
        logger.warning(f"Error processing fund {symbol}: {str(e)}")
        return records
    
    logger.info(f"Generated {len(records)} regression records for {symbol}")
    return records

def process_region(region, fund_data_list):
    from concurrent.futures import ThreadPoolExecutor
    records = []
    errors = 0
    logger.info(f"Processing {len(fund_data_list)} funds in {region}")
    
    with ThreadPoolExecutor(max_workers=8) as executor:
        future_to_fund = {
            executor.submit(process_fund, fund_data): fund_data["SymbolCUSIP"]
            for fund_data in fund_data_list
        }
        for future in tqdm(future_to_fund, total=len(fund_data_list), desc=f"Processing {region}", file=sys.stdout):
            try:
                records.extend(future.result())
            except Exception as e:
                logger.error(f"Error processing {future_to_fund[future]}: {str(e)}")
                errors += 1
    
    logger.info(f"Region {region} generated {len(records)} total records with {errors} errors")
    log_summary(f"Region {region}: {len(fund_data_list)} funds, {len(records)} records, {errors} errors")
    if not DRY_RUN:
        insert_batch(records)
    
    return records, errors

# Section 6: Main Pipeline
@timer
def main():
    logger.info("Starting main pipeline")
    log_summary("Pipeline started")
    try:
        fund_meta = load_fund_metadata()
    except Exception as e:
        logger.error(f"Failed to load metadata: {e}")
        log_summary(f"Error: Failed to load metadata: {e}")
        return {"error": str(e)}
    
    regions = fund_meta["Region"].unique()
    logger.info(f"Total funds: {len(fund_meta)}, Regions: {regions}")
    log_summary(f"Total funds: {len(fund_meta)}, Regions: {regions}")
    
    fund_ids = fund_meta["SymbolCUSIP"].tolist()
    if SAMPLE_DRY_RUN:
        fund_ids = random.sample(fund_ids, min(SAMPLE_SIZE, len(fund_ids)))
        logger.info(f"Sampled {len(fund_ids)} funds")
        log_summary(f"Sampled {len(fund_ids)} funds")
    
    summary = {"total_funds": len(fund_ids), "regions": {}, "errors": 0}
    for region in sorted(set(regions) - {'Unknown'} | {'USA'}):
        region_fund_ids = fund_meta[fund_meta["Region"] == region]["SymbolCUSIP"].tolist()
        if not region_fund_ids:
            logger.warning(f"No SymbolCUSIP found for region {region}")
            summary["regions"][region] = {"funds_processed": 0, "records": 0, "errors": 0}
            continue
        if SAMPLE_DRY_RUN:
            region_fund_ids = random.sample(region_fund_ids, min(SAMPLE_SIZE, len(region_fund_ids)))
            logger.info(f"Sampled {len(region_fund_ids)} SymbolCUSIP for {region}")
        
        try:
            returns = load_fund_returns(region_fund_ids)
        except Exception as e:
            logger.error(f"Failed to load returns for {region} with SymbolCUSIP {region_fund_ids[:5]}...: {e}")
            log_summary(f"Error: Failed to load returns for {region}: {e}")
            summary["regions"][region] = {"funds_processed": 0, "records": 0, "errors": 1}
            summary["errors"] += 1
            continue
        
        region_funds = [
            {
                "SymbolCUSIP": row["SymbolCUSIP"],
                "Global_Category_Name": row["Global_Category_Name"],
                "CWA_Broad_Category_Name": row.get("CWA_Broad_Category_Name", None),
                "returns": returns[row["SymbolCUSIP"]].to_dict()
            }
            for _, row in fund_meta.iterrows() if row["SymbolCUSIP"] in returns.columns
        ]
        if not region_funds:
            logger.warning(f"No valid returns data for {region} with SymbolCUSIP {region_fund_ids[:5]}...")
            summary["regions"][region] = {"funds_processed": 0, "records": 0, "errors": 0}
            continue
        
        records, errors = process_region(region, region_funds)
        summary["regions"][region] = {"funds_processed": len(region_funds), "records": len(records), "errors": errors}
        summary["errors"] += errors
    
    logger.info(f"Pipeline summary: {summary}")
    log_summary(f"Pipeline completed: {summary}")
    return summary

# Section 7: Database Output
def insert_batch(records):
    try:
        df = pd.DataFrame(records)
        with database_transaction() as connection:
            df.to_sql("AQRR_Factor_Attribution", connection, if_exists="append", index=False, method="multi")
        logger.info(f"Inserted {len(df)} records to database")
    except Exception as e:
        logger.error(f"Error inserting batch: {e}")
        raise

if __name__ == "__main__":
    try:
        main()
    except Exception as e:
        logger.error(f"Main execution failed: {e}")
        raise
# Out:
# 2025-04-16 16:44:16,557 - INFO - Starting main pipeline
# 2025-04-16 16:44:16,696 - INFO - Loaded metadata for 5584 funds
# 2025-04-16 16:44:17,031 - INFO - load_fund_metadata took 0.47 seconds
# 2025-04-16 16:44:17,032 - INFO - Total funds: 5584, Regions: ['Global' 'USA' 'International']
# 2025-04-16 16:44:17,033 - INFO - Sampled 50 funds
# 2025-04-16 16:44:17,035 - INFO - Sampled 50 SymbolCUSIP for Global
# 2025-04-16 16:44:17,083 - INFO - Loaded returns for 50 funds
# 2025-04-16 16:44:17,089 - INFO - load_fund_returns took 0.05 seconds
# 2025-04-16 16:44:17,252 - INFO - Processing 50 funds in Global
# Processing Global:   0%|          | 0/50 [00:00<?, ?it/s]2025-04-16 16:44:18,840 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB']; dropping duplicates
# 2025-04-16 16:44:18,878 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB']; dropping duplicates
# 2025-04-16 16:44:18,885 - WARNING - Error in regression for DFAI (Equity_Global_1): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:44:18,902 - WARNING - Error in regression for DFAI (Equity_Global_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:18,920 - WARNING - Error in regression for APDJX (Equity_Global_1): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:44:18,920 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB']; dropping duplicates
# 2025-04-16 16:44:18,924 - WARNING - Error in regression for DFAI (Equity_Global_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:18,958 - WARNING - Error in regression for APDJX (Equity_Global_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:18,963 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB']; dropping duplicates
# 2025-04-16 16:44:18,966 - WARNING - Error in regression for DFAI (Equity_Global_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:18,967 - WARNING - Error in regression for APDJX (Equity_Global_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:18,971 - INFO - Generated 0 regression records for DFAI
# 2025-04-16 16:44:18,980 - WARNING - Error in regression for APDJX (Equity_Global_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:18,983 - WARNING - Error in regression for GXUS (Equity_Global_1): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:44:18,984 - INFO - Generated 0 regression records for APDJX
# 2025-04-16 16:44:18,987 - WARNING - Error in regression for DFIC (Equity_Global_1): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:44:18,992 - WARNING - Error in regression for GXUS (Equity_Global_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:18,994 - WARNING - Error in regression for DFIC (Equity_Global_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:18,996 - WARNING - Error in regression for GXUS (Equity_Global_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:18,999 - WARNING - Error in regression for DFIC (Equity_Global_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:19,000 - WARNING - Error in regression for GXUS (Equity_Global_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:19,002 - INFO - Generated 0 regression records for GXUS
# 2025-04-16 16:44:19,005 - WARNING - Error in regression for DFIC (Equity_Global_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:19,005 - INFO - Generated 0 regression records for DFIC
# 2025-04-16 16:44:19,121 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ', 'TSM-FI']; dropping duplicates
# 2025-04-16 16:44:19,133 - WARNING - Error in regression for EAOA (Allocation_1): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:44:19,141 - WARNING - No data for factors ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'] in factor_returns (region: Global, asset_class: None)
# 2025-04-16 16:44:19,142 - INFO - load_db_factors took 0.01 seconds
# 2025-04-16 16:44:19,143 - WARNING - No factors for EAOA (Allocation_2)
# 2025-04-16 16:44:19,147 - WARNING - Error in regression for EAOA (Allocation_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:19,173 - WARNING - Error in regression for EAOA (Allocation_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:19,173 - INFO - Generated 0 regression records for EAOA
# Processing Global:   2%|▏         | 1/50 [00:01<01:33,  1.91s/it]2025-04-16 16:44:19,177 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ', 'TSM-FI']; dropping duplicates
# 2025-04-16 16:44:19,208 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ', 'TSM-FI']; dropping duplicates
# 2025-04-16 16:44:19,215 - WARNING - Error in regression for RHRX (Allocation_1): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:44:19,222 - WARNING - No data for factors ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'] in factor_returns (region: Global, asset_class: None)
# 2025-04-16 16:44:19,224 - INFO - load_db_factors took 0.01 seconds
# 2025-04-16 16:44:19,225 - WARNING - No factors for RHRX (Allocation_2)
# 2025-04-16 16:44:19,253 - WARNING - Error in regression for AOR (Allocation_1): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:44:19,255 - WARNING - Error in regression for RHRX (Allocation_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:19,255 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ', 'TSM-FI']; dropping duplicates
# 2025-04-16 16:44:19,261 - WARNING - No data for factors ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'] in factor_returns (region: Global, asset_class: None)
# 2025-04-16 16:44:19,262 - INFO - load_db_factors took 0.01 seconds
# 2025-04-16 16:44:19,264 - WARNING - Error in regression for RHRX (Allocation_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:19,265 - WARNING - No factors for AOR (Allocation_2)
# 2025-04-16 16:44:19,266 - INFO - Generated 0 regression records for RHRX
# 2025-04-16 16:44:19,274 - WARNING - Error in regression for AOR (Allocation_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:19,279 - WARNING - Error in regression for MPRO (Allocation_1): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:44:19,280 - WARNING - Error in regression for AOR (Allocation_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:19,282 - INFO - Generated 0 regression records for AOR
# 2025-04-16 16:44:19,284 - WARNING - No data for factors ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'] in factor_returns (region: Global, asset_class: None)
# Processing Global:   4%|▍         | 2/50 [00:02<00:40,  1.18it/s]2025-04-16 16:44:19,287 - INFO - load_db_factors took 0.01 seconds
# 2025-04-16 16:44:19,288 - WARNING - No factors for MPRO (Allocation_2)
# 2025-04-16 16:44:19,291 - WARNING - Error in regression for MPRO (Allocation_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:19,294 - WARNING - Error in regression for MPRO (Allocation_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:19,295 - INFO - Generated 0 regression records for MPRO
# 2025-04-16 16:44:20,707 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB']; dropping duplicates
# 2025-04-16 16:44:20,790 - WARNING - Error in regression for CEMFX (Equity_Global_1): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:44:20,792 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB']; dropping duplicates
# 2025-04-16 16:44:20,795 - WARNING - Error in regression for CEMFX (Equity_Global_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:20,802 - WARNING - Error in regression for CEMFX (Equity_Global_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:20,805 - WARNING - Error in regression for CEMFX (Equity_Global_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:20,806 - INFO - Generated 0 regression records for CEMFX
# 2025-04-16 16:44:20,808 - WARNING - Error in regression for NMIEX (Equity_Global_1): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# Processing Global:  18%|█▊        | 9/50 [00:03<00:12,  3.23it/s]2025-04-16 16:44:20,814 - WARNING - Error in regression for NMIEX (Equity_Global_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:20,817 - WARNING - Error in regression for NMIEX (Equity_Global_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:20,820 - WARNING - Error in regression for NMIEX (Equity_Global_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:20,822 - INFO - Generated 0 regression records for NMIEX
# 2025-04-16 16:44:20,847 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB']; dropping duplicates
# 2025-04-16 16:44:20,857 - WARNING - Error in regression for SEMNX (Equity_Global_1): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:44:20,861 - WARNING - Error in regression for SEMNX (Equity_Global_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:20,863 - WARNING - Error in regression for SEMNX (Equity_Global_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:20,866 - WARNING - Error in regression for SEMNX (Equity_Global_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:20,867 - INFO - Generated 0 regression records for SEMNX
# 2025-04-16 16:44:20,937 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ', 'TSM-FI']; dropping duplicates
# 2025-04-16 16:44:20,947 - WARNING - Error in regression for TBFC (Allocation_1): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:44:20,951 - WARNING - No data for factors ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'] in factor_returns (region: Global, asset_class: None)
# 2025-04-16 16:44:20,952 - INFO - load_db_factors took 0.00 seconds
# 2025-04-16 16:44:20,953 - WARNING - No factors for TBFC (Allocation_2)
# 2025-04-16 16:44:20,976 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB']; dropping duplicates
# 2025-04-16 16:44:20,977 - WARNING - Error in regression for TBFC (Allocation_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:21,005 - WARNING - Error in regression for TBFC (Allocation_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:21,007 - INFO - Generated 0 regression records for TBFC
# 2025-04-16 16:44:21,008 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB']; dropping duplicates
# Processing Global:  24%|██▍       | 12/50 [00:03<00:08,  4.42it/s]2025-04-16 16:44:21,016 - WARNING - Error in regression for EDIV (Equity_Global_1): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:44:21,021 - WARNING - Error in regression for EDIV (Equity_Global_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:21,026 - WARNING - Error in regression for KEM (Equity_Global_1): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:44:21,029 - WARNING - Error in regression for EDIV (Equity_Global_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:21,032 - WARNING - Error in regression for KEM (Equity_Global_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:21,033 - WARNING - Error in regression for EDIV (Equity_Global_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:21,035 - INFO - Generated 0 regression records for EDIV
# 2025-04-16 16:44:21,037 - WARNING - Error in regression for KEM (Equity_Global_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:21,042 - WARNING - Error in regression for KEM (Equity_Global_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:21,043 - INFO - Generated 0 regression records for KEM
# 2025-04-16 16:44:21,154 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ', 'TSM-FI']; dropping duplicates
# 2025-04-16 16:44:21,166 - WARNING - Error in regression for DALI (Allocation_1): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:44:21,169 - WARNING - No data for factors ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'] in factor_returns (region: Global, asset_class: None)
# 2025-04-16 16:44:21,170 - INFO - load_db_factors took 0.00 seconds
# 2025-04-16 16:44:21,171 - WARNING - No factors for DALI (Allocation_2)
# 2025-04-16 16:44:21,174 - WARNING - Error in regression for DALI (Allocation_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:21,177 - WARNING - Error in regression for DALI (Allocation_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:21,178 - INFO - Generated 0 regression records for DALI
# Processing Global:  26%|██▌       | 13/50 [00:03<00:08,  4.58it/s]2025-04-16 16:44:21,348 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ', 'TSM-FI', 'TSM-Com', 'TSM-FX']; dropping duplicates
# 2025-04-16 16:44:21,358 - WARNING - Error in regression for LSEQ (Alternative_1): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:44:21,361 - WARNING - No data for factors ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'] in factor_returns (region: Global, asset_class: None)
# 2025-04-16 16:44:21,363 - INFO - load_db_factors took 0.00 seconds
# 2025-04-16 16:44:21,363 - WARNING - No factors for LSEQ (Alternative_2)
# 2025-04-16 16:44:21,367 - WARNING - Error in regression for LSEQ (Alternative_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:21,370 - WARNING - Error in regression for LSEQ (Alternative_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:21,372 - INFO - Generated 0 regression records for LSEQ
# Processing Global:  28%|██▊       | 14/50 [00:04<00:07,  4.67it/s]2025-04-16 16:44:22,613 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB']; dropping duplicates
# 2025-04-16 16:44:22,616 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB']; dropping duplicates
# 2025-04-16 16:44:22,629 - WARNING - Error in regression for ILOW (Equity_Global_1): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:44:22,633 - WARNING - Error in regression for IEFA (Equity_Global_1): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:44:22,636 - WARNING - Error in regression for ILOW (Equity_Global_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:22,638 - WARNING - Error in regression for IEFA (Equity_Global_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:22,640 - WARNING - Error in regression for ILOW (Equity_Global_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:22,643 - WARNING - Error in regression for IEFA (Equity_Global_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:22,644 - WARNING - Error in regression for ILOW (Equity_Global_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:22,646 - INFO - Generated 0 regression records for ILOW
# 2025-04-16 16:44:22,649 - WARNING - Error in regression for IEFA (Equity_Global_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:22,650 - INFO - Generated 0 regression records for IEFA
# Processing Global:  34%|███▍      | 17/50 [00:05<00:09,  3.30it/s]2025-04-16 16:44:22,712 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB']; dropping duplicates
# 2025-04-16 16:44:22,721 - WARNING - Error in regression for OSEA (Equity_Global_1): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:44:22,725 - WARNING - Error in regression for OSEA (Equity_Global_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:22,728 - WARNING - Error in regression for OSEA (Equity_Global_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:22,732 - WARNING - Error in regression for OSEA (Equity_Global_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:22,733 - INFO - Generated 0 regression records for OSEA
# 2025-04-16 16:44:22,822 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB']; dropping duplicates
# 2025-04-16 16:44:22,833 - WARNING - Error in regression for IQDF (Equity_Global_1): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:44:22,838 - WARNING - Error in regression for IQDF (Equity_Global_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:22,841 - WARNING - Error in regression for IQDF (Equity_Global_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:22,844 - WARNING - Error in regression for IQDF (Equity_Global_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:22,846 - INFO - Generated 0 regression records for IQDF
# Processing Global:  40%|████      | 20/50 [00:05<00:06,  4.67it/s]2025-04-16 16:44:22,880 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB']; dropping duplicates
# 2025-04-16 16:44:22,889 - WARNING - Error in regression for JPIN (Equity_Global_1): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:44:22,893 - WARNING - Error in regression for JPIN (Equity_Global_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:22,896 - WARNING - Error in regression for JPIN (Equity_Global_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:22,899 - WARNING - Error in regression for JPIN (Equity_Global_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:22,900 - INFO - Generated 0 regression records for JPIN
# 2025-04-16 16:44:22,953 - INFO - load_db_factors took 0.30 seconds
# 2025-04-16 16:44:23,010 - INFO - load_db_factors took 0.27 seconds
# 2025-04-16 16:44:23,032 - INFO - load_db_factors took 0.18 seconds
# 2025-04-16 16:44:23,055 - INFO - load_db_factors took 0.15 seconds
# 2025-04-16 16:44:23,063 - INFO - load_fixed_income_factors took 0.11 seconds
# 2025-04-16 16:44:23,520 - INFO - load_fixed_income_factors took 0.51 seconds
# 2025-04-16 16:44:23,681 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ', 'TSM-FI', 'TSM-Com', 'TSM-FX']; dropping duplicates
# 2025-04-16 16:44:23,689 - INFO - load_fixed_income_factors took 0.66 seconds
# 2025-04-16 16:44:23,813 - WARNING - Error in regression for CVRD (Alternative_1): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:44:23,836 - WARNING - No data for factors ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'] in factor_returns (region: Global, asset_class: None)
# 2025-04-16 16:44:23,846 - INFO - load_db_factors took 0.03 seconds
# 2025-04-16 16:44:23,858 - WARNING - No factors for CVRD (Alternative_2)
# 2025-04-16 16:44:23,885 - WARNING - Error in regression for CVRD (Alternative_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:23,907 - WARNING - Error in regression for CVRD (Alternative_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:23,917 - INFO - Generated 0 regression records for CVRD
# Processing Global:  44%|████▍     | 22/50 [00:06<00:08,  3.34it/s]2025-04-16 16:44:24,252 - INFO - load_fixed_income_factors took 1.20 seconds
# 2025-04-16 16:44:24,465 - INFO - Fund WIP succeeded for window 12m with factors {'TERM_Int': 110, 'TERM_Long': 110, 'CREDIT': 110, 'CREDIT_HY': 110}, total 440 records
# 2025-04-16 16:44:25,330 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ', 'TSM-FI', 'TSM-Com', 'TSM-FX']; dropping duplicates
# 2025-04-16 16:44:25,485 - WARNING - Error in regression for BCDF (Alternative_1): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:44:25,524 - WARNING - No data for factors ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'] in factor_returns (region: Global, asset_class: None)
# 2025-04-16 16:44:25,547 - INFO - load_db_factors took 0.05 seconds
# 2025-04-16 16:44:25,568 - WARNING - No factors for BCDF (Alternative_2)
# 2025-04-16 16:44:25,600 - WARNING - Error in regression for BCDF (Alternative_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:25,601 - INFO - Fund SPSK succeeded for window 12m with factors {'TERM_Int': 50, 'TERM_Long': 50, 'CREDIT': 50, 'CREDIT_HY': 50}, total 200 records
# 2025-04-16 16:44:25,636 - WARNING - Error in regression for BCDF (Alternative_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:25,640 - INFO - Generated 0 regression records for BCDF
# Processing Global:  46%|████▌     | 23/50 [00:08<00:14,  1.90it/s]2025-04-16 16:44:26,253 - INFO - Fund ISHG succeeded for window 12m with factors {'TERM_Int': 110, 'TERM_Long': 110, 'CREDIT': 110, 'CREDIT_HY': 110}, total 440 records
# 2025-04-16 16:44:26,594 - INFO - Fund SPSK succeeded for window 24m with factors {'TERM_Int': 38, 'TERM_Long': 38, 'CREDIT': 38, 'CREDIT_HY': 38}, total 152 records
# 2025-04-16 16:44:26,601 - INFO - Fund IBND succeeded for window 12m with factors {'TERM_Int': 110, 'TERM_Long': 110, 'CREDIT': 110, 'CREDIT_HY': 110}, total 440 records
# 2025-04-16 16:44:27,032 - INFO - Fund WIP succeeded for window 24m with factors {'TERM_Int': 98, 'TERM_Long': 98, 'CREDIT': 98, 'CREDIT_HY': 98}, total 392 records
# 2025-04-16 16:44:27,224 - INFO - Fund SPSK succeeded for window 36m with factors {'TERM_Int': 26, 'TERM_Long': 26, 'CREDIT': 26, 'CREDIT_HY': 26}, total 104 records
# 2025-04-16 16:44:27,633 - INFO - Fund SPSK succeeded for window 48m with factors {'TERM_Int': 14, 'TERM_Long': 14, 'CREDIT': 14, 'CREDIT_HY': 14}, total 56 records
# 2025-04-16 16:44:27,691 - INFO - Fund SPSK succeeded for window 60m with factors {'TERM_Int': 2, 'TERM_Long': 2, 'CREDIT': 2, 'CREDIT_HY': 2}, total 8 records
# 2025-04-16 16:44:27,729 - WARNING - Error in regression for SPSK (FI_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:27,767 - WARNING - Error in regression for SPSK (FI_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:27,792 - WARNING - Error in regression for SPSK (FI_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:27,805 - INFO - Generated 520 regression records for SPSK
# 2025-04-16 16:44:28,548 - INFO - Fund ISHG succeeded for window 24m with factors {'TERM_Int': 98, 'TERM_Long': 98, 'CREDIT': 98, 'CREDIT_HY': 98}, total 392 records
# 2025-04-16 16:44:28,894 - INFO - Fund IBND succeeded for window 24m with factors {'TERM_Int': 98, 'TERM_Long': 98, 'CREDIT': 98, 'CREDIT_HY': 98}, total 392 records
# 2025-04-16 16:44:29,001 - INFO - Fund WIP succeeded for window 36m with factors {'TERM_Int': 86, 'TERM_Long': 86, 'CREDIT': 86, 'CREDIT_HY': 86}, total 344 records
# 2025-04-16 16:44:30,314 - INFO - Fund ISHG succeeded for window 36m with factors {'TERM_Int': 86, 'TERM_Long': 86, 'CREDIT': 86, 'CREDIT_HY': 86}, total 344 records
# 2025-04-16 16:44:30,464 - INFO - Fund WIP succeeded for window 48m with factors {'TERM_Int': 74, 'TERM_Long': 74, 'CREDIT': 74, 'CREDIT_HY': 74}, total 296 records
# 2025-04-16 16:44:30,670 - INFO - Fund IBND succeeded for window 36m with factors {'TERM_Int': 86, 'TERM_Long': 86, 'CREDIT': 86, 'CREDIT_HY': 86}, total 344 records
# 2025-04-16 16:44:30,914 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ', 'TSM-FI', 'TSM-Com', 'TSM-FX']; dropping duplicates
# 2025-04-16 16:44:31,063 - WARNING - Error in regression for SDVD (Alternative_1): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:44:31,096 - WARNING - No data for factors ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'] in factor_returns (region: Global, asset_class: None)
# 2025-04-16 16:44:31,114 - INFO - load_db_factors took 0.05 seconds
# 2025-04-16 16:44:31,127 - WARNING - No factors for SDVD (Alternative_2)
# 2025-04-16 16:44:31,157 - WARNING - Error in regression for SDVD (Alternative_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:31,184 - WARNING - Error in regression for SDVD (Alternative_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:31,199 - INFO - Generated 0 regression records for SDVD
# Processing Global:  48%|████▊     | 24/50 [00:13<00:37,  1.45s/it]2025-04-16 16:44:31,792 - INFO - Fund WIP succeeded for window 60m with factors {'TERM_Int': 62, 'TERM_Long': 62, 'CREDIT': 62, 'CREDIT_HY': 62}, total 248 records
# 2025-04-16 16:44:31,816 - WARNING - Error in regression for WIP (FI_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:31,854 - WARNING - Error in regression for WIP (FI_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:31,867 - WARNING - Error in regression for WIP (FI_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:31,882 - INFO - Generated 1720 regression records for WIP
# 2025-04-16 16:44:31,885 - INFO - Fund ISHG succeeded for window 48m with factors {'TERM_Int': 74, 'TERM_Long': 74, 'CREDIT': 74, 'CREDIT_HY': 74}, total 296 records
# 2025-04-16 16:44:32,141 - INFO - Fund IBND succeeded for window 48m with factors {'TERM_Int': 74, 'TERM_Long': 74, 'CREDIT': 74, 'CREDIT_HY': 74}, total 296 records
# 2025-04-16 16:44:32,805 - INFO - Fund ISHG succeeded for window 60m with factors {'TERM_Int': 62, 'TERM_Long': 62, 'CREDIT': 62, 'CREDIT_HY': 62}, total 248 records
# 2025-04-16 16:44:32,823 - WARNING - Error in regression for ISHG (FI_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:32,847 - WARNING - Error in regression for ISHG (FI_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:32,862 - WARNING - Error in regression for ISHG (FI_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:32,865 - INFO - Generated 1720 regression records for ISHG
# 2025-04-16 16:44:32,947 - INFO - Fund IBND succeeded for window 60m with factors {'TERM_Int': 62, 'TERM_Long': 62, 'CREDIT': 62, 'CREDIT_HY': 62}, total 248 records
# 2025-04-16 16:44:32,950 - WARNING - Error in regression for IBND (FI_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:32,953 - WARNING - Error in regression for IBND (FI_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:32,956 - WARNING - Error in regression for IBND (FI_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:32,957 - INFO - Generated 1720 regression records for IBND
# 2025-04-16 16:44:33,999 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ', 'TSM-FI']; dropping duplicates
# 2025-04-16 16:44:34,008 - WARNING - Error in regression for MSMR (Allocation_1): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:44:34,013 - WARNING - No data for factors ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'] in factor_returns (region: Global, asset_class: None)
# 2025-04-16 16:44:34,015 - INFO - load_db_factors took 0.01 seconds
# 2025-04-16 16:44:34,015 - WARNING - No factors for MSMR (Allocation_2)
# 2025-04-16 16:44:34,019 - WARNING - Error in regression for MSMR (Allocation_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:34,022 - WARNING - Error in regression for MSMR (Allocation_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:34,023 - INFO - Generated 0 regression records for MSMR
# Processing Global:  50%|█████     | 25/50 [00:16<00:43,  1.73s/it]2025-04-16 16:44:34,314 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ', 'TSM-FI']; dropping duplicates
# 2025-04-16 16:44:34,324 - WARNING - Error in regression for WABIX (Allocation_1): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:44:34,328 - WARNING - No data for factors ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'] in factor_returns (region: Global, asset_class: None)
# 2025-04-16 16:44:34,329 - INFO - load_db_factors took 0.00 seconds
# 2025-04-16 16:44:34,330 - WARNING - No factors for WABIX (Allocation_2)
# 2025-04-16 16:44:34,333 - WARNING - Error in regression for WABIX (Allocation_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:34,336 - WARNING - Error in regression for WABIX (Allocation_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:34,337 - INFO - Generated 0 regression records for WABIX
# Processing Global:  60%|██████    | 30/50 [00:17<00:14,  1.36it/s]2025-04-16 16:44:34,432 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ', 'TSM-FI']; dropping duplicates
# 2025-04-16 16:44:34,442 - WARNING - Error in regression for ABINX (Allocation_1): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:44:34,447 - WARNING - No data for factors ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'] in factor_returns (region: Global, asset_class: None)
# 2025-04-16 16:44:34,449 - INFO - load_db_factors took 0.01 seconds
# 2025-04-16 16:44:34,450 - WARNING - No factors for ABINX (Allocation_2)
# 2025-04-16 16:44:34,453 - WARNING - Error in regression for ABINX (Allocation_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:34,456 - WARNING - Error in regression for ABINX (Allocation_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:34,458 - INFO - Generated 0 regression records for ABINX
# Processing Global:  62%|██████▏   | 31/50 [00:17<00:12,  1.55it/s]2025-04-16 16:44:34,561 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB']; dropping duplicates
# 2025-04-16 16:44:34,570 - WARNING - Error in regression for MFQTX (Equity_Global_1): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:44:34,574 - WARNING - Error in regression for MFQTX (Equity_Global_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:34,577 - WARNING - Error in regression for MFQTX (Equity_Global_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:34,580 - WARNING - Error in regression for MFQTX (Equity_Global_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:34,582 - INFO - Generated 0 regression records for MFQTX
# 2025-04-16 16:44:34,621 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ', 'TSM-FI']; dropping duplicates
# 2025-04-16 16:44:34,633 - WARNING - Error in regression for GBLFX (Allocation_1): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:44:34,637 - WARNING - No data for factors ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'] in factor_returns (region: Global, asset_class: None)
# 2025-04-16 16:44:34,638 - INFO - load_db_factors took 0.00 seconds
# 2025-04-16 16:44:34,639 - WARNING - No factors for GBLFX (Allocation_2)
# 2025-04-16 16:44:34,642 - WARNING - Error in regression for GBLFX (Allocation_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:34,646 - WARNING - Error in regression for GBLFX (Allocation_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:34,646 - INFO - Generated 0 regression records for GBLFX
# Processing Global:  64%|██████▍   | 32/50 [00:17<00:10,  1.77it/s]2025-04-16 16:44:34,735 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ', 'TSM-FI']; dropping duplicates
# 2025-04-16 16:44:34,744 - WARNING - Error in regression for POEDX (Allocation_1): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:44:34,747 - WARNING - No data for factors ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'] in factor_returns (region: Global, asset_class: None)
# 2025-04-16 16:44:34,749 - INFO - load_db_factors took 0.00 seconds
# 2025-04-16 16:44:34,750 - WARNING - No factors for POEDX (Allocation_2)
# 2025-04-16 16:44:34,753 - WARNING - Error in regression for POEDX (Allocation_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:34,756 - WARNING - Error in regression for POEDX (Allocation_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:34,758 - INFO - Generated 0 regression records for POEDX
# Processing Global:  68%|██████▊   | 34/50 [00:17<00:06,  2.51it/s]2025-04-16 16:44:34,815 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB']; dropping duplicates
# 2025-04-16 16:44:34,828 - WARNING - Error in regression for APDHX (Equity_Global_1): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:44:34,832 - WARNING - Error in regression for APDHX (Equity_Global_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:34,835 - WARNING - Error in regression for APDHX (Equity_Global_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:34,839 - WARNING - Error in regression for APDHX (Equity_Global_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:34,840 - INFO - Generated 0 regression records for APDHX
# 2025-04-16 16:44:34,938 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB']; dropping duplicates
# 2025-04-16 16:44:34,951 - WARNING - Error in regression for FHESX (Equity_Global_1): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:44:34,955 - WARNING - Error in regression for FHESX (Equity_Global_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:34,959 - WARNING - Error in regression for FHESX (Equity_Global_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:34,962 - WARNING - Error in regression for FHESX (Equity_Global_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:34,963 - INFO - Generated 0 regression records for FHESX
# Processing Global:  72%|███████▏  | 36/50 [00:17<00:04,  3.30it/s]2025-04-16 16:44:36,019 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ', 'TSM-FI']; dropping duplicates
# 2025-04-16 16:44:36,029 - WARNING - Error in regression for FEVIX (Allocation_1): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:44:36,034 - WARNING - No data for factors ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'] in factor_returns (region: Global, asset_class: None)
# 2025-04-16 16:44:36,035 - INFO - load_db_factors took 0.01 seconds
# 2025-04-16 16:44:36,036 - WARNING - No factors for FEVIX (Allocation_2)
# 2025-04-16 16:44:36,039 - WARNING - Error in regression for FEVIX (Allocation_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:36,042 - WARNING - Error in regression for FEVIX (Allocation_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:36,043 - INFO - Generated 0 regression records for FEVIX
# Processing Global:  74%|███████▍  | 37/50 [00:18<00:05,  2.23it/s]2025-04-16 16:44:36,351 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ', 'TSM-FI']; dropping duplicates
# 2025-04-16 16:44:36,361 - WARNING - Error in regression for MUTHX (Allocation_1): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:44:36,365 - WARNING - No data for factors ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'] in factor_returns (region: Global, asset_class: None)
# 2025-04-16 16:44:36,366 - INFO - load_db_factors took 0.00 seconds
# 2025-04-16 16:44:36,367 - WARNING - No factors for MUTHX (Allocation_2)
# 2025-04-16 16:44:36,371 - WARNING - Error in regression for MUTHX (Allocation_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:36,374 - WARNING - Error in regression for MUTHX (Allocation_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:36,375 - INFO - Generated 0 regression records for MUTHX
# 2025-04-16 16:44:36,438 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB']; dropping duplicates
# 2025-04-16 16:44:36,447 - WARNING - Error in regression for HEOIX (Equity_Global_1): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:44:36,481 - WARNING - Error in regression for HEOIX (Equity_Global_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:36,482 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ', 'TSM-FI']; dropping duplicates
# 2025-04-16 16:44:36,486 - WARNING - Error in regression for HEOIX (Equity_Global_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:36,493 - WARNING - Error in regression for HEOIX (Equity_Global_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:36,496 - WARNING - Error in regression for MQIFX (Allocation_1): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:44:36,497 - INFO - Generated 0 regression records for HEOIX
# 2025-04-16 16:44:36,502 - WARNING - No data for factors ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'] in factor_returns (region: Global, asset_class: None)
# 2025-04-16 16:44:36,503 - INFO - load_db_factors took 0.00 seconds
# 2025-04-16 16:44:36,504 - WARNING - No factors for MQIFX (Allocation_2)
# 2025-04-16 16:44:36,507 - WARNING - Error in regression for MQIFX (Allocation_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:36,511 - WARNING - Error in regression for MQIFX (Allocation_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:36,511 - INFO - Generated 0 regression records for MQIFX
# Processing Global:  76%|███████▌  | 38/50 [00:19<00:05,  2.21it/s]2025-04-16 16:44:36,514 - INFO - load_db_factors took 0.00 seconds
# 2025-04-16 16:44:36,655 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB']; dropping duplicates
# 2025-04-16 16:44:36,666 - WARNING - Error in regression for MSILX (Equity_Global_1): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:44:36,670 - WARNING - Error in regression for MSILX (Equity_Global_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:36,672 - WARNING - Error in regression for MSILX (Equity_Global_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:36,675 - WARNING - Error in regression for MSILX (Equity_Global_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:36,676 - INFO - Generated 0 regression records for MSILX
# Processing Global:  82%|████████▏ | 41/50 [00:19<00:02,  3.79it/s]2025-04-16 16:44:36,714 - INFO - load_fixed_income_factors took 0.20 seconds
# 2025-04-16 16:44:37,048 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB']; dropping duplicates
# 2025-04-16 16:44:37,085 - WARNING - Error in regression for JIESX (Equity_Global_1): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:44:37,098 - WARNING - Error in regression for JIESX (Equity_Global_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:37,107 - WARNING - Error in regression for JIESX (Equity_Global_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:37,120 - WARNING - Error in regression for JIESX (Equity_Global_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:37,125 - INFO - Generated 0 regression records for JIESX
# 2025-04-16 16:44:37,517 - INFO - Fund PCGLX succeeded for window 12m with factors {'TERM_Int': 110, 'TERM_Long': 110, 'CREDIT': 110, 'CREDIT_HY': 110}, total 440 records
# 2025-04-16 16:44:37,615 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB']; dropping duplicates
# 2025-04-16 16:44:37,678 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ', 'TSM-FI']; dropping duplicates
# 2025-04-16 16:44:37,707 - WARNING - Error in regression for BRXIX (Equity_Global_1): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:44:37,727 - WARNING - Error in regression for BRXIX (Equity_Global_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:37,732 - WARNING - Error in regression for OYCIX (Allocation_1): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:44:37,748 - WARNING - Error in regression for BRXIX (Equity_Global_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:37,753 - WARNING - No data for factors ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'] in factor_returns (region: Global, asset_class: None)
# 2025-04-16 16:44:37,758 - INFO - load_db_factors took 0.01 seconds
# 2025-04-16 16:44:37,762 - WARNING - No factors for OYCIX (Allocation_2)
# 2025-04-16 16:44:37,764 - WARNING - Error in regression for BRXIX (Equity_Global_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:37,773 - INFO - Generated 0 regression records for BRXIX
# 2025-04-16 16:44:37,774 - WARNING - Error in regression for OYCIX (Allocation_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:37,789 - WARNING - Error in regression for OYCIX (Allocation_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:37,797 - INFO - Generated 0 regression records for OYCIX
# Processing Global:  84%|████████▍ | 42/50 [00:20<00:03,  2.37it/s]2025-04-16 16:44:38,305 - INFO - Fund PCGLX succeeded for window 24m with factors {'TERM_Int': 98, 'TERM_Long': 98, 'CREDIT': 98, 'CREDIT_HY': 98}, total 392 records
# 2025-04-16 16:44:38,895 - INFO - Fund PCGLX succeeded for window 36m with factors {'TERM_Int': 86, 'TERM_Long': 86, 'CREDIT': 86, 'CREDIT_HY': 86}, total 344 records
# 2025-04-16 16:44:39,396 - INFO - Fund PCGLX succeeded for window 48m with factors {'TERM_Int': 74, 'TERM_Long': 74, 'CREDIT': 74, 'CREDIT_HY': 74}, total 296 records
# 2025-04-16 16:44:39,820 - INFO - Fund PCGLX succeeded for window 60m with factors {'TERM_Int': 62, 'TERM_Long': 62, 'CREDIT': 62, 'CREDIT_HY': 62}, total 248 records
# 2025-04-16 16:44:39,824 - WARNING - Error in regression for PCGLX (FI_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:39,828 - WARNING - Error in regression for PCGLX (FI_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:39,830 - WARNING - Error in regression for PCGLX (FI_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:39,831 - INFO - Generated 1720 regression records for PCGLX
# 2025-04-16 16:44:40,403 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ', 'TSM-FI']; dropping duplicates
# 2025-04-16 16:44:40,413 - WARNING - Error in regression for ETFWX (Allocation_1): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:44:40,417 - WARNING - No data for factors ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'] in factor_returns (region: Global, asset_class: None)
# 2025-04-16 16:44:40,418 - INFO - load_db_factors took 0.00 seconds
# 2025-04-16 16:44:40,419 - WARNING - No factors for ETFWX (Allocation_2)
# 2025-04-16 16:44:40,422 - WARNING - Error in regression for ETFWX (Allocation_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:40,425 - WARNING - Error in regression for ETFWX (Allocation_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:44:40,426 - INFO - Generated 0 regression records for ETFWX
# Processing Global:  90%|█████████ | 45/50 [00:23<00:03,  1.61it/s]2025-04-16 16:44:40,611 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB']; dropping duplicates
# 2025-04-16 16:44:40,619 - WARNING - Error in regression for TIOSX (Equity_Global_1): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:44:40,622 - WARNING - Error in regression for TIOSX (Equity_Global_2): List argument must consist only of tuples or dictionaries
# ...
# 2025-04-16 16:46:28,605 - WARNING - Error in regression for JSHIX (FI_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:46:28,606 - WARNING - Found 2864 duplicate Date-Factor pairs in factor_returns for ['MKT', 'SMB', 'BAB', 'TSM-Com']; dropping duplicates
# 2025-04-16 16:46:28,610 - WARNING - Error in regression for JSHIX (FI_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:46:28,611 - INFO - Generated 1720 regression records for JSHIX
# 2025-04-16 16:46:28,613 - INFO - load_db_factors took 0.00 seconds
# 2025-04-16 16:46:28,620 - WARNING - Error in regression for DHANX (Equity_USA_6): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:46:28,708 - INFO - load_fixed_income_factors took 0.10 seconds
# 2025-04-16 16:46:29,523 - INFO - Fund NWJJX succeeded for window 12m with factors {'TERM_Int': 110, 'TERM_Long': 110, 'CREDIT': 110, 'CREDIT_HY': 110}, total 440 records
# 2025-04-16 16:46:30,196 - INFO - Fund NWJJX succeeded for window 24m with factors {'TERM_Int': 98, 'TERM_Long': 98, 'CREDIT': 98, 'CREDIT_HY': 98}, total 392 records
# 2025-04-16 16:46:30,790 - INFO - Fund NWJJX succeeded for window 36m with factors {'TERM_Int': 86, 'TERM_Long': 86, 'CREDIT': 86, 'CREDIT_HY': 86}, total 344 records
# 2025-04-16 16:46:31,302 - INFO - Fund NWJJX succeeded for window 48m with factors {'TERM_Int': 74, 'TERM_Long': 74, 'CREDIT': 74, 'CREDIT_HY': 74}, total 296 records
# 2025-04-16 16:46:31,764 - INFO - Fund NWJJX succeeded for window 60m with factors {'TERM_Int': 62, 'TERM_Long': 62, 'CREDIT': 62, 'CREDIT_HY': 62}, total 248 records
# 2025-04-16 16:46:31,767 - WARNING - Error in regression for NWJJX (FI_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:46:31,770 - WARNING - Error in regression for NWJJX (FI_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:46:31,773 - WARNING - Error in regression for NWJJX (FI_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:46:31,774 - INFO - Generated 1720 regression records for NWJJX
# 2025-04-16 16:46:31,775 - INFO - load_db_factors took 0.00 seconds
# 2025-04-16 16:46:31,870 - INFO - load_fixed_income_factors took 0.09 seconds
# 2025-04-16 16:46:32,757 - INFO - Fund NHFIX succeeded for window 12m with factors {'TERM_Int': 110, 'TERM_Long': 110, 'CREDIT': 110, 'CREDIT_HY': 110}, total 440 records
# 2025-04-16 16:46:33,330 - WARNING - Found 2864 duplicate Date-Factor pairs in factor_returns for ['MKT', 'SMB', 'BAB', 'TSM-Com']; dropping duplicates
# 2025-04-16 16:46:33,377 - WARNING - Error in regression for FLUIX (Equity_USA_6): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:46:33,522 - INFO - Fund NHFIX succeeded for window 24m with factors {'TERM_Int': 98, 'TERM_Long': 98, 'CREDIT': 98, 'CREDIT_HY': 98}, total 392 records
# 2025-04-16 16:46:34,215 - INFO - Fund NHFIX succeeded for window 36m with factors {'TERM_Int': 86, 'TERM_Long': 86, 'CREDIT': 86, 'CREDIT_HY': 86}, total 344 records
# 2025-04-16 16:46:34,654 - WARNING - Found 2864 duplicate Date-Factor pairs in factor_returns for ['MKT', 'SMB', 'BAB', 'TSM-Com']; dropping duplicates
# 2025-04-16 16:46:34,701 - WARNING - Error in regression for GSQTX (Equity_USA_6): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:46:34,895 - INFO - Fund NHFIX succeeded for window 48m with factors {'TERM_Int': 74, 'TERM_Long': 74, 'CREDIT': 74, 'CREDIT_HY': 74}, total 296 records
# 2025-04-16 16:46:35,400 - INFO - Fund NHFIX succeeded for window 60m with factors {'TERM_Int': 62, 'TERM_Long': 62, 'CREDIT': 62, 'CREDIT_HY': 62}, total 248 records
# 2025-04-16 16:46:35,404 - WARNING - Error in regression for NHFIX (FI_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:46:35,408 - WARNING - Error in regression for NHFIX (FI_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:46:35,410 - WARNING - Error in regression for NHFIX (FI_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:46:35,412 - INFO - Generated 1720 regression records for NHFIX
# 2025-04-16 16:46:35,414 - INFO - load_db_factors took 0.00 seconds
# 2025-04-16 16:46:35,802 - INFO - Fund EPLCX succeeded for window 12m with factors {'mkt': 109}, total 109 records
# 2025-04-16 16:46:36,160 - INFO - Fund EPLCX succeeded for window 24m with factors {'mkt': 97}, total 97 records
# 2025-04-16 16:46:36,461 - INFO - Fund EPLCX succeeded for window 36m with factors {'mkt': 85}, total 85 records
# 2025-04-16 16:46:36,729 - INFO - Fund EPLCX succeeded for window 48m with factors {'mkt': 73}, total 73 records
# 2025-04-16 16:46:36,950 - INFO - Fund EPLCX succeeded for window 60m with factors {'mkt': 61}, total 61 records
# 2025-04-16 16:46:36,954 - WARNING - Error in regression for EPLCX (Equity_USA_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:46:36,957 - WARNING - Error in regression for EPLCX (Equity_USA_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:46:36,961 - WARNING - Error in regression for EPLCX (Equity_USA_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:46:37,714 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'UMD', 'SMB', 'BAB', 'TSM-Com', 'TSM-FI', 'TSM-FX']; dropping duplicates
# 2025-04-16 16:46:37,730 - WARNING - Error in regression for MYLD (Equity_USA_7): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:46:37,733 - INFO - Generated 0 regression records for MYLD
# 2025-04-16 16:46:37,735 - INFO - load_db_factors took 0.00 seconds
# 2025-04-16 16:46:37,903 - WARNING - Found 1894 duplicate Date-Factor pairs in factor_returns for ['MKT', 'BAB', 'TSM-FI', 'TSM-FX', 'excess_return_eqwt']; dropping duplicates
# 2025-04-16 16:46:37,957 - WARNING - Error in regression for EPLCX (Equity_USA_5): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:46:38,124 - INFO - Fund PMDIX succeeded for window 12m with factors {'mkt': 109}, total 109 records
# 2025-04-16 16:46:38,402 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'UMD', 'SMB', 'BAB', 'TSM-Com', 'TSM-FI', 'TSM-FX']; dropping duplicates
# 2025-04-16 16:46:38,467 - WARNING - Error in regression for CDVZX (Equity_USA_7): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:46:38,473 - INFO - Generated 425 regression records for CDVZX
# 2025-04-16 16:46:38,476 - INFO - load_db_factors took 0.00 seconds
# 2025-04-16 16:46:38,500 - INFO - Fund PMDIX succeeded for window 24m with factors {'mkt': 97}, total 97 records
# 2025-04-16 16:46:38,915 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'UMD', 'SMB', 'BAB', 'TSM-Com', 'TSM-FI', 'TSM-FX']; dropping duplicates
# 2025-04-16 16:46:38,982 - WARNING - Error in regression for VOE (Equity_USA_7): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:46:38,988 - INFO - Generated 425 regression records for VOE
# 2025-04-16 16:46:38,991 - INFO - load_db_factors took 0.00 seconds
# Processing USA:  58%|█████▊    | 29/50 [01:13<02:43,  7.77s/it]2025-04-16 16:46:39,024 - INFO - Fund PMDIX succeeded for window 36m with factors {'mkt': 85}, total 85 records
# 2025-04-16 16:46:39,277 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'UMD', 'SMB', 'BAB', 'TSM-Com', 'TSM-FI', 'TSM-FX']; dropping duplicates
# 2025-04-16 16:46:39,390 - WARNING - Error in regression for DHANX (Equity_USA_7): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:46:39,417 - INFO - Generated 425 regression records for DHANX
# 2025-04-16 16:46:39,607 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'UMD', 'SMB', 'BAB', 'TSM-Com', 'TSM-FI', 'TSM-FX']; dropping duplicates
# 2025-04-16 16:46:39,627 - INFO - Fund PMDIX succeeded for window 48m with factors {'mkt': 73}, total 73 records
# 2025-04-16 16:46:39,701 - WARNING - Error in regression for AISZX (Equity_USA_7): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:46:39,714 - INFO - Fund PRSGX succeeded for window 12m with factors {'mkt': 109}, total 109 records
# 2025-04-16 16:46:39,718 - INFO - Generated 425 regression records for AISZX
# Processing USA:  66%|██████▌   | 33/50 [01:14<01:02,  3.66s/it]2025-04-16 16:46:40,052 - INFO - load_fixed_income_factors took 1.57 seconds
# 2025-04-16 16:46:40,115 - INFO - Fund PMDIX succeeded for window 60m with factors {'mkt': 61}, total 61 records
# 2025-04-16 16:46:40,134 - WARNING - Error in regression for PMDIX (Equity_USA_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:46:40,170 - WARNING - Error in regression for PMDIX (Equity_USA_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:46:40,207 - WARNING - Error in regression for PMDIX (Equity_USA_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:46:40,406 - INFO - Fund PRSGX succeeded for window 24m with factors {'mkt': 97}, total 97 records
# 2025-04-16 16:46:41,008 - INFO - Fund PRSGX succeeded for window 36m with factors {'mkt': 85}, total 85 records
# 2025-04-16 16:46:41,486 - INFO - Fund PRSGX succeeded for window 48m with factors {'mkt': 73}, total 73 records
# 2025-04-16 16:46:41,548 - INFO - Fund PMOYX succeeded for window 12m with factors {'TERM_Int': 106, 'TERM_Long': 106, 'CREDIT': 106, 'CREDIT_HY': 106}, total 424 records
# 2025-04-16 16:46:41,876 - INFO - Fund PRSGX succeeded for window 60m with factors {'mkt': 61}, total 61 records
# 2025-04-16 16:46:41,892 - WARNING - Error in regression for PRSGX (Equity_USA_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:46:41,907 - WARNING - Error in regression for PRSGX (Equity_USA_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:46:41,918 - WARNING - Error in regression for PRSGX (Equity_USA_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:46:42,459 - INFO - Fund PMOYX succeeded for window 24m with factors {'TERM_Int': 94, 'TERM_Long': 94, 'CREDIT': 94, 'CREDIT_HY': 94}, total 376 records
# 2025-04-16 16:46:43,103 - INFO - Fund PMOYX succeeded for window 36m with factors {'TERM_Int': 82, 'TERM_Long': 82, 'CREDIT': 82, 'CREDIT_HY': 82}, total 328 records
# 2025-04-16 16:46:43,635 - INFO - Fund PMOYX succeeded for window 48m with factors {'TERM_Int': 70, 'TERM_Long': 70, 'CREDIT': 70, 'CREDIT_HY': 70}, total 280 records
# 2025-04-16 16:46:44,050 - INFO - Fund PMOYX succeeded for window 60m with factors {'TERM_Int': 58, 'TERM_Long': 58, 'CREDIT': 58, 'CREDIT_HY': 58}, total 232 records
# 2025-04-16 16:46:44,054 - WARNING - Error in regression for PMOYX (FI_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:46:44,057 - WARNING - Error in regression for PMOYX (FI_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:46:44,060 - WARNING - Error in regression for PMOYX (FI_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 16:46:44,061 - INFO - Generated 1640 regression records for PMOYX
# 2025-04-16 16:46:44,290 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'UMD', 'SMB', 'BAB', 'TSM-Com', 'TSM-FI', 'TSM-FX']; dropping duplicates
# 2025-04-16 16:46:44,301 - WARNING - Error in regression for FLUIX (Equity_USA_7): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:46:44,302 - INFO - Generated 425 regression records for FLUIX
# Processing USA:  82%|████████▏ | 41/50 [01:19<00:16,  1.78s/it]2025-04-16 16:46:44,355 - WARNING - Found 1894 duplicate Date-Factor pairs in factor_returns for ['MKT', 'BAB', 'TSM-FI', 'TSM-FX', 'excess_return_eqwt']; dropping duplicates
# 2025-04-16 16:46:44,363 - WARNING - Error in regression for PMDIX (Equity_USA_5): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:46:44,403 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'UMD', 'SMB', 'BAB', 'TSM-Com', 'TSM-FI', 'TSM-FX']; dropping duplicates
# 2025-04-16 16:46:44,413 - WARNING - Error in regression for GSQTX (Equity_USA_7): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:46:44,415 - INFO - Generated 425 regression records for GSQTX
# Processing USA:  84%|████████▍ | 42/50 [01:19<00:12,  1.62s/it]2025-04-16 16:46:44,550 - WARNING - Found 1894 duplicate Date-Factor pairs in factor_returns for ['MKT', 'BAB', 'TSM-FI', 'TSM-FX', 'excess_return_eqwt']; dropping duplicates
# 2025-04-16 16:46:44,557 - WARNING - Error in regression for PRSGX (Equity_USA_5): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:46:44,573 - WARNING - Found 2864 duplicate Date-Factor pairs in factor_returns for ['MKT', 'SMB', 'BAB', 'TSM-Com']; dropping duplicates
# 2025-04-16 16:46:44,581 - WARNING - Error in regression for EPLCX (Equity_USA_6): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:46:44,843 - WARNING - Found 2864 duplicate Date-Factor pairs in factor_returns for ['MKT', 'SMB', 'BAB', 'TSM-Com']; dropping duplicates
# 2025-04-16 16:46:44,851 - WARNING - Error in regression for PMDIX (Equity_USA_6): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:46:44,911 - WARNING - Found 2864 duplicate Date-Factor pairs in factor_returns for ['MKT', 'SMB', 'BAB', 'TSM-Com']; dropping duplicates
# 2025-04-16 16:46:44,920 - WARNING - Error in regression for PRSGX (Equity_USA_6): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:46:45,208 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'UMD', 'SMB', 'BAB', 'TSM-Com', 'TSM-FI', 'TSM-FX']; dropping duplicates
# 2025-04-16 16:46:45,215 - WARNING - Error in regression for EPLCX (Equity_USA_7): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:46:45,216 - INFO - Generated 425 regression records for EPLCX
# Processing USA:  94%|█████████▍| 47/50 [01:20<00:03,  1.02s/it]2025-04-16 16:46:45,320 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'UMD', 'SMB', 'BAB', 'TSM-Com', 'TSM-FI', 'TSM-FX']; dropping duplicates
# 2025-04-16 16:46:45,328 - WARNING - Error in regression for PMDIX (Equity_USA_7): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:46:45,330 - INFO - Generated 425 regression records for PMDIX
# Processing USA:  96%|█████████▌| 48/50 [01:20<00:01,  1.08it/s]2025-04-16 16:46:45,355 - WARNING - Found 5221 duplicate Date-Factor pairs in factor_returns for ['MKT', 'HML_Devil', 'QMJ', 'UMD', 'SMB', 'BAB', 'TSM-Com', 'TSM-FI', 'TSM-FX']; dropping duplicates
# 2025-04-16 16:46:45,361 - WARNING - Error in regression for PRSGX (Equity_USA_7): Length mismatch: Expected axis has 1321 elements, new values have 1183 elements
# 2025-04-16 16:46:45,362 - INFO - Generated 425 regression records for PRSGX
# Processing USA: 100%|██████████| 50/50 [01:20<00:00,  1.61s/it]
# 2025-04-16 16:46:45,365 - INFO - Region USA generated 29754 total records with 0 errors
# 2025-04-16 16:46:45,375 - INFO - Pipeline summary: {'total_funds': 50, 'regions': {'Global': {'funds_processed': 50, 'records': 7400, 'errors': 0}, 'International': {'funds_processed': 50, 'records': 21072, 'errors': 0}, 'USA': {'funds_processed': 50, 'records': 29754, 'errors': 0}}, 'errors': 0}
# 2025-04-16 16:46:45,387 - INFO - main took 148.83 seconds

# %%
import pandas as pd
import numpy as np
import os
import random
import logging
from datetime import timedelta, datetime
from dateutil.relativedelta import relativedelta
from concurrent.futures import ProcessPoolExecutor, ThreadPoolExecutor
from sqlalchemy import create_engine
from tqdm import tqdm
from statsmodels.regression.linear_model import OLS
from statsmodels.tools.tools import add_constant
import statsmodels.api as sm
import time
import pickle
import sys
from contextlib import contextmanager
from functools import wraps


# Section 1: Configuration and Setup
CONFIG = {
    "database": {
        "server": "JULIANS_LAPTOP\\SQLEXPRESS",
        "database": "CWA_Fund_Database",
        "driver": "ODBC Driver 18 for SQL Server"
    },
    "return_metric": "1 Month Return",
    "rolling_periods": [12, 24, 36, 48, 60],
    "dry_run": True,
    "sample_dry_run": True,
    "sample_size": 10,
    "chunk_size": 5600,
    "batch_insert_size": 10000,
    "max_workers_cpu": min(13, os.cpu_count()),  # 14 workers for CPU-bound tasks
    "max_workers_io": 30,  # 30 workers for I/O-bound tasks
    "use_threads": False,
    "unmapped_category_behavior": "allocation"  # Options: "allocation", "all"
}

CONNECTION_STRING = (
    f"mssql+pyodbc://{CONFIG['database']['server']}/{CONFIG['database']['database']}"
    f"?driver={CONFIG['database']['driver']}&trusted_connection=yes&TrustServerCertificate=yes"
)
try:
    engine = create_engine(CONNECTION_STRING)
except Exception as e:
    print(f"Database connection failed: {e}")
    raise

RETURN_METRIC = CONFIG["return_metric"]
ROLLING_PERIODS = CONFIG["rolling_periods"]
DRY_RUN = CONFIG["dry_run"]
SAMPLE_DRY_RUN = CONFIG["sample_dry_run"]
SAMPLE_SIZE = CONFIG["sample_size"]
CHUNK_SIZE = CONFIG["chunk_size"]
BATCH_INSERT_SIZE = CONFIG["batch_insert_size"]
MAX_WORKERS_CPU = CONFIG["max_workers_cpu"]
MAX_WORKERS_IO = CONFIG["max_workers_io"]
USE_THREADS = CONFIG["use_threads"]
UNMAPPED_CATEGORY_BEHAVIOR = CONFIG["unmapped_category_behavior"]

# Logging setup
SUMMARY_LOG = "factor_attribution_summary.log"
logging.basicConfig(
    level=logging.INFO,  # Use INFO to reduce verbosity
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler("factor_attribution.log"),
        logging.StreamHandler(sys.stdout)
    ],
    force=True
)
logger = logging.getLogger()

def log_summary(message):
    with open(SUMMARY_LOG, 'a') as f:
        f.write(f"{datetime.now()}: {message}\n")

# Section 2: Helper Functions

def category_to_region(category):
    mapping = {
        "US Equity Large Cap Blend": ("USA", "US Equity Large Cap Blend"),
        "US Equity Large Cap Growth": ("USA", "US Equity Large Cap Growth"),
        "US Equity Large Cap Value": ("USA", "US Equity Large Cap Value"),
        "US Equity Mid Cap": ("USA", "US Equity Mid Cap"),
        "US Equity Small Cap": ("USA", "US Equity Small Cap"),
        "Global Equity Large Cap": ("Global", "Global Equity Large Cap"),
        "Global Equity Mid/Small Cap": ("Global", "Global Equity Mid/Small Cap"),
        "Global Emerging Markets Equity": ("Global", "Global Emerging Markets Equity"),
        "Europe Equity Large Cap": ("International", "Europe Equity Large Cap"),
        "Asia Equity": ("International", "Asia Equity"),
        "Japan Equity": ("International", "Japan Equity"),
        "Emerging Markets Fixed Income": ("International", "Emerging Markets Fixed Income"),
        "US Fixed Income": ("USA", "US Fixed Income"),
        "US Municipal Fixed Income": ("USA", "US Municipal Fixed Income"),
        "Global Fixed Income": ("Global", "Global Fixed Income"),
        "Flexible Allocation": ("Global", "Flexible Allocation"),
        "Aggressive Allocation": ("Global", "Aggressive Allocation"),
        "Moderate Allocation": ("Global", "Moderate Allocation"),
        "Cautious Allocation": ("Global", "Cautious Allocation"),
        "Commodities Broad Basket": ("Global", "Commodities Broad Basket"),
        "Commodities Specified": ("Global", "Commodities Specified"),
        "Options Trading": ("USA", "Options Trading"),
        "Multialternative": ("Global", "Multialternative"),
        "Market Neutral": ("Global", "Market Neutral"),
        "Long/Short Equity": ("Global", "Long/Short Equity"),
        "Alternative Miscellaneous": ("Global", "Alternative Miscellaneous"),
        "Energy Sector Equity": ("USA", "Energy Sector Equity"),
        "Equity Miscellaneous": ("USA", "Equity Miscellaneous"),
        "Financials Sector Equity": ("USA", "Financials Sector Equity"),
        "Healthcare Sector Equity": ("USA", "Healthcare Sector Equity"),
        "Consumer Goods & Services Sector Equity": ("USA", "Consumer Goods & Services Sector Equity"),
        "Communications Sector Equity": ("USA", "Communications Sector Equity"),
        "Industrials Sector Equity": ("USA", "Industrials Sector Equity"),
        "Other Sector Equity": ("USA", "Other Sector Equity"),
        "Real Estate Sector Equity": ("USA", "Real Estate Sector Equity"),
        "Precious Metals Sector Equity": ("USA", "Precious Metals Sector Equity"),
        "Technology Sector Equity": ("USA", "Technology Sector Equity"),
        "Utilities Sector Equity": ("USA", "Utilities Sector Equity"),
        "Natural Resources Sector Equity": ("USA", "Natural Resources Sector Equity"),
        "Infrastructure Sector Equity": ("USA", "Infrastructure Sector Equity"),
        "Trading Tools": ("USA", "Trading Tools"),
        "Asia ex-Japan Equity": ("International", "Asia ex-Japan Equity"),
        "Australia & New Zealand Equity": ("International", "Australia & New Zealand Equity"),
        "Canadian Equity Large Cap": ("International", "Canadian Equity Large Cap"),
        "Europe Equity Mid/Small Cap": ("International", "Europe Equity Mid/Small Cap"),
        "Greater China Equity": ("International", "Greater China Equity"),
        "India Equity": ("International", "India Equity"),
        "Mexico Equity": ("International", "Mexico Equity"),
        "Korea Equity": ("International", "Korea Equity"),
        "Latin America Equity": ("International", "Latin America Equity"),
        "UK Equity Large Cap": ("International", "UK Equity Large Cap"),
        "Thailand Equity": ("International", "Thailand Equity"),
        "Convertibles": ("USA", "Convertibles"),
        "Fixed Income Miscellaneous": ("USA", "Fixed Income Miscellaneous"),
        "Allocation Miscellaneous": ("Global", "Allocation Miscellaneous")
    }
    return mapping.get(category, ("USA", "Unknown"))

@contextmanager
def database_transaction():
    connection = engine.connect()
    transaction = connection.begin()
    try:
        yield connection
        transaction.commit()
    except Exception as e:
        transaction.rollback()
        logger.error(f"Transaction failed: {e}")
        raise
    finally:
        connection.close()

def timer(func):
    @wraps(func)
    def wrapper(*args, **kwargs):
        start_time = time.time()
        logger.debug(f"Starting {func.__name__}")
        result = func(*args, **kwargs)
        logger.info(f"{func.__name__} took {time.time() - start_time:.2f} seconds")
        return result
    return wrapper

# Section 3: Data Loading Functions
@timer
def load_fund_metadata():
    query = """
    SELECT 
        f.SymbolCUSIP, 
        f.Region, 
        f.YC_Global_Category_ID, 
        c.Global_Category_Name,
        f.YC_Category_ID,
        y.Category_Name,
        f.CWA_Broad_Category_ID,
        b.CWA_Broad_Category_Name
    FROM Funds_to_Screen f
    JOIN YC_Global_Category_List c ON f.YC_Global_Category_ID = c.ID
    JOIN YC_Category_List y ON f.YC_Category_ID = y.ID
    LEFT JOIN CWA_Broad_Category_List b ON f.CWA_Broad_Category_ID = b.ID
    """
    try:
        df = pd.read_sql(query, engine)
        logger.info(f"Loaded metadata for {len(df)} funds")
        df[["Region", "FactorProfile"]] = df["Global_Category_Name"].map(category_to_region).apply(pd.Series)
        if df["CWA_Broad_Category_Name"].isnull().all():
            logger.warning("CWA_Broad_Category_Name missing; Equity regressions 5-7 will be skipped")
        return df.dropna(subset=["Region", "FactorProfile"])
    except Exception as e:
        logger.error(f"Error loading metadata: {e}")
        raise

# Global cache for factor data
FACTOR_CACHE = {}

@timer
def load_db_factors(factor_list, region="Global", table="factor_returns", asset_class=None):
    cache_key = (tuple(factor_list), region, table, asset_class)
    if cache_key in FACTOR_CACHE:
        logger.debug(f"Using cached factors for {cache_key}")
        return FACTOR_CACHE[cache_key]
    
    factor_in_clause = ','.join([f"'{f}'" for f in factor_list])
    query = f"""
        SELECT date AS Date, factor AS Factor, value AS Value, region
        FROM {table}
        WHERE factor IN ({factor_in_clause})
        AND date >= '2015-01-01'
    """
    if region and not any(f.startswith('TSM-') or f == 'RF' for f in factor_list):
        query += f" AND region = '{region}'"
    elif 'RF' in factor_list:
        query += " AND region = 'USA'"
    if asset_class:
        query += f" AND asset_class = '{asset_class}'"
    
    logger.debug(f"Executing query: {query}")
    df = pd.read_sql_query(query, engine, parse_dates=['Date'])
    if df.empty:
        logger.warning(f"No data for factors {factor_list} in {table} (region: {region})")
        return pd.DataFrame()
    
    df['Factor'] = df['Factor'].str.strip()
    df['region'] = df['region'].str.strip()
    duplicates = df.duplicated(subset=['Date', 'Factor', 'region']).sum()
    if duplicates > 0:
        logger.warning(f"Found {duplicates} duplicates in {table} for {factor_list}; aggregating mean")
        df = df.groupby(['Date', 'Factor', 'region'])['Value'].mean().reset_index()
    
    pivoted_df = df.pivot(index="Date", columns="Factor", values="Value")
    pivoted_df.index = pd.to_datetime(pivoted_df.index) + pd.offsets.MonthEnd(0)
    pivoted_df = pivoted_df[~pivoted_df.index.duplicated(keep='first')]
    pivoted_df = pivoted_df.asfreq('ME')
    if pivoted_df.empty or not any(f in pivoted_df.columns for f in factor_list):
        logger.warning(f"No valid factors in {table} (region: {region}): {factor_list}")
        return pd.DataFrame()
    
    FACTOR_CACHE[cache_key] = pivoted_df
    return pivoted_df

@timer
def load_fund_returns(fund_ids=None):
    try:
        query = """
        SELECT SymbolCUSIP, Date, ReturnValue
        FROM Fund_Returns_Timeseries
        WHERE Metric = '1 Month Return' AND ReturnValue IS NOT NULL AND Date IS NOT NULL
        """
        if fund_ids:
            fund_ids = [fid for fid in fund_ids if isinstance(fid, str) and fid.strip()]
            if not fund_ids:
                logger.warning("No valid SymbolCUSIP provided")
                return pd.DataFrame()
            fund_ids_str = ",".join([f"'{fid}'" for fid in fund_ids])
            query += f" AND SymbolCUSIP IN ({fund_ids_str})"
        
        logger.debug(f"Executing query: {query}")
        chunks = []
        for chunk in pd.read_sql_query(query, engine, parse_dates=["Date"], chunksize=CHUNK_SIZE):
            logger.debug(f"Loaded chunk of {len(chunk)} rows")
            chunks.append(chunk)
        df = pd.concat(chunks) if chunks else pd.DataFrame()
        if df.empty:
            logger.warning(f"No returns data loaded for SymbolCUSIP: {fund_ids}")
            return pd.DataFrame()
        
        logger.info(f"Loaded returns for {len(df['SymbolCUSIP'].unique())} funds")
        pivoted = df.pivot(index="Date", columns="SymbolCUSIP", values="ReturnValue")
        pivoted.index = pd.to_datetime(pivoted.index) + pd.offsets.MonthEnd(0)
        pivoted.index = pivoted.index.drop_duplicates()
        pivoted = pivoted.asfreq('ME')
        for col in pivoted.columns:
            if not pd.api.types.is_numeric_dtype(pivoted[col]):
                logger.warning(f"Non-numeric returns for {col}; converting")
                pivoted[col] = pd.to_numeric(pivoted[col], errors='coerce')
        return pivoted
    except Exception as e:
        logger.error(f"Error loading returns: {e}")
        raise

@timer
def load_century_factors(factor_list, portfolio_base, factor, asset_class=None, region="Global"):
    factor_in_clause = ','.join([f"'{f}'" for f in factor_list])
    portfolio = f"{portfolio_base} {factor}"
    query = f"""
        SELECT date AS Date, factor AS Factor, value AS Value
        FROM aqr_century_factors
        WHERE factor IN ({factor_in_clause})
        AND portfolio = ?
    """
    params = [portfolio]
    if asset_class:
        query += " AND asset_class = ?"
        params.append(asset_class)
    if region != "Global":
        query += " AND region = ?"
        params.append(region)
    df = pd.read_sql(query, engine, params=params, parse_dates=['Date'])
    if df.empty:
        logger.warning(f"No data for factors {factor_list} in aqr_century_factors (portfolio: {portfolio}, region: {region})")
        return pd.DataFrame()
    pivoted_df = df.pivot(index="Date", columns="Factor", values="Value")
    pivoted_df.index = pd.to_datetime(pivoted_df.index) + pd.offsets.MonthEnd(0)
    pivoted_df.index = pivoted_df.index.drop_duplicates()
    pivoted_df = pivoted_df.asfreq('ME')
    return pivoted_df

@timer
def load_commodity_factors():
    query = """
        SELECT date AS Date, 
               excess_return_eqwt, 
               excess_spot_return_eqwt, 
               ir_adjusted_carry_eqwt, 
               spot_return_eqwt, 
               carry_eqwt, 
               excess_return_long_short, 
               excess_spot_return_long_short, 
               ir_adjusted_carry_long_short, 
               aggregate_backwardation_contango
        FROM aqr_cmdty_factors
    """
    df = pd.read_sql(query, engine, parse_dates=['Date'])
    if df.empty:
        logger.warning("No commodity factors loaded")
        return pd.DataFrame()
    pivoted_df = df.set_index("Date")
    pivoted_df.index = pd.to_datetime(pivoted_df.index) + pd.offsets.MonthEnd(0)
    pivoted_df.index = pivoted_df.index.drop_duplicates()
    pivoted_df = pivoted_df.asfreq('ME')
    return pivoted_df

@timer
def load_fixed_income_factors(factor_list):
    factor_in_clause = ','.join([f"'{f}'" for f in factor_list])
    query = f"""
        SELECT Date, Factor_Name, ReturnValue
        FROM Fixed_Income_Factor_Returns
        WHERE Factor_Name IN ({factor_in_clause})
    """
    logger.debug(f"Executing query: {query}")
    df = pd.read_sql_query(query, engine, parse_dates=["Date"])
    if df.empty:
        logger.warning(f"No fixed income factors for {factor_list}")
        return pd.DataFrame()
    pivoted_df = df.pivot(index="Date", columns="Factor_Name", values="ReturnValue")
    pivoted_df.index = pd.to_datetime(pivoted_df.index) + pd.offsets.MonthEnd(0)
    pivoted_df.index = pivoted_df.index.drop_duplicates()
    pivoted_df = pivoted_df.asfreq('ME')
    return pivoted_df

# Section 4: Regression Functions
def run_rolling_regression(symbol, returns, factor_data, regression_type, regression_name, window_months):
    records = []
    months_needed = window_months
    
    # Ensure indices are datetime and sorted
    returns = returns.sort_index()
    factor_data = factor_data.sort_index()
    
    # Find overlapping dates
    available_dates = returns.index.intersection(factor_data.index)
    if len(available_dates) < months_needed:
        logger.warning(f"Fund {symbol} ({regression_name}, window={window_months}m) skipped: {len(available_dates)} months available, need {months_needed}")
        return records
    
    # Iterate over possible window end dates, stepping one month
    for end_date in available_dates[months_needed-1::1]:
        start_date = end_date - pd.offsets.MonthEnd(months_needed)
        if start_date < available_dates[0]:
            continue
        
        # Slice data for the window
        window_returns = returns.loc[start_date:end_date]
        window_factors = factor_data.loc[start_date:end_date]
        
        # Reindex to ensure alignment
        window_returns = window_returns.reindex(window_factors.index)
        
        if len(window_returns.dropna()) < months_needed or len(window_factors.dropna()) < months_needed:
            logger.debug(f"Skipping regression for {symbol} ({regression_name}, window={window_months}m, end_date={end_date}): insufficient data")
            continue
        
        try:
            if regression_type == "OLS":
                X = sm.add_constant(window_factors)
                model = sm.OLS(window_returns, X, missing='drop').fit()
                coefficients = model.params.to_dict()
                tvalues = model.tvalues.to_dict()
                pvalues = model.pvalues.to_dict()
                r_squared = model.rsquared
                record = {
                    "SymbolCUSIP": symbol,
                    "RegressionName": regression_name,
                    "Window": f"{window_months}m",
                    "EndDate": end_date,
                    "R_Squared": r_squared
                }
                for factor in coefficients:
                    record[f"{factor}_beta"] = coefficients[factor]
                    record[f"{factor}_tvalue"] = tvalues.get(factor, None)
                    record[f"{factor}_pvalue"] = pvalues.get(factor, None)
                records.append(record)
        except Exception as e:
            logger.warning(f"Regression failed for {symbol} ({regression_name}, window={window_months}m, end_date={end_date}): {str(e)}")
            continue
    
    if not records:
        logger.info(f"No regressions completed for {symbol} ({regression_name}, window={window_months}m)")
    return records

# Section 5: Processing Functions
def process_fund(fund_data):
    records = []
    symbol = fund_data["SymbolCUSIP"]
    category = fund_data["Global_Category_Name"]
    returns = pd.Series(fund_data["returns"]).dropna()
    
    if returns.empty:
        logger.warning(f"No valid returns for {symbol}")
        return records

    regression_sets = {
        "Equity_USA": [
            ("Equity_USA_1", ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB'], "USA", None),
            ("Equity_USA_2", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "USA", "US Stock Selection"),
            ("Equity_USA_3", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "USA", "All Macro"),
            ("Equity_USA_4", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "USA", "Equity indices"),
            ("Equity_USA_5", ['MKT', 'BAB', 'TSM-FI', 'TSM-FX', 'excess_return_eqwt'], "USA", None),
            ("Equity_USA_6", ['MKT', 'SMB', 'BAB', 'TSM-Com'], "USA", None),
            ("Equity_USA_7", ['MKT', 'HML_Devil', 'QMJ', 'UMD', 'SMB', 'BAB', 'TSM-Com', 'TSM-FI', 'TSM-FX'], "USA", None)
        ],
        "Equity_Intl": [
            ("Equity_Intl_1", ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB'], "Intl", None),
            ("Equity_Intl_2", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "International", "Intl Stock Selection"),
            ("Equity_Intl_3", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "International", "All Macro"),
            ("Equity_Intl_4", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "International", "Equity indices")
        ],
        "Equity_Global": [
            ("Equity_Global_1", ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB'], "Global", None),
            ("Equity_Global_2", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "All Stock Selection"),
            ("Equity_Global_3", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "All Macro"),
            ("Equity_Global_4", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "Equity indices")
        ],
        "Fixed_Income": [
            ("FI_1", ['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY', 'TSM-FI', 'TSM-FX'], "Global", None),
            ("FI_2", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "Fixed income"),
            ("FI_3", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "All Macro"),
            ("FI_4", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "Equity indices")
        ],
        "Allocation": [
            ("Allocation_1", ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ', 'TSM-FI'], "Global", None),
            ("Allocation_2", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", None),
            ("Allocation_3", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "All Macro"),
            ("Allocation_4", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "Equity indices")
        ],
        "Alternative": [
            ("Alternative_1", ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ', 'TSM-FI', 'TSM-Com', 'TSM-FX'], "Global", None),
            ("Allocation_2", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", None),
            ("Allocation_3", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "All Macro"),
            ("Allocation_4", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "Equity indices")
        ],
        "Commodity": [
            ("Commodity_1", ['excess_return_eqwt', 'excess_spot_return_eqwt', 'ir_adjusted_carry_eqwt', 'spot_return_eqwt', 'carry_eqwt', 'excess_return_long_short', 'excess_spot_return_long_short', 'ir_adjusted_carry_long_short', 'aggregate_backwardation_contango'], "Global", None)
        ]
    }

    category_to_regressions = {
        "Energy Sector Equity": "Equity_USA",
        "Equity Miscellaneous": "Equity_USA",
        "Financials Sector Equity": "Equity_USA",
        "Healthcare Sector Equity": "Equity_USA",
        "Consumer Goods & Services Sector Equity": "Equity_USA",
        "Communications Sector Equity": "Equity_USA",
        "Industrials Sector Equity": "Equity_USA",
        "Other Sector Equity": "Equity_USA",
        "Real Estate Sector Equity": "Equity_USA",
        "Precious Metals Sector Equity": "Equity_USA",
        "Technology Sector Equity": "Equity_USA",
        "Utilities Sector Equity": "Equity_USA",
        "US Equity Large Cap Blend": "Equity_USA",
        "US Equity Large Cap Growth": "Equity_USA",
        "US Equity Large Cap Value": "Equity_USA",
        "US Equity Mid Cap": "Equity_USA",
        "US Equity Small Cap": "Equity_USA",
        "Options Trading": "Equity_USA",
        "Natural Resources Sector Equity": "Equity_USA",
        "Infrastructure Sector Equity": "Equity_USA",
        "Asia ex-Japan Equity": "Equity_Intl",
        "Australia & New Zealand Equity": "Equity_Intl",
        "Canadian Equity Large Cap": "Equity_Intl",
        "Europe Equity Large Cap": "Equity_Intl",
        "Europe Equity Mid/Small Cap": "Equity_Intl",
        "Greater China Equity": "Equity_Intl",
        "India Equity": "Equity_Intl",
        "Mexico Equity": "Equity_Intl",
        "Japan Equity": "Equity_Intl",
        "Korea Equity": "Equity_Intl",
        "Latin America Equity": "Equity_Intl",
        "UK Equity Large Cap": "Equity_Intl",
        "Thailand Equity": "Equity_Intl",
        "Global Emerging Markets Equity": "Equity_Global",
        "Global Equity Large Cap": "Equity_Global",
        "Global Equity Mid/Small Cap": "Equity_Global",
        "Global Fixed Income": "Fixed_Income",
        "Convertibles": "Fixed_Income",
        "Emerging Markets Fixed Income": "Fixed_Income",
        "Fixed Income Miscellaneous": "Fixed_Income",
        "US Fixed Income": "Fixed_Income",
        "US Municipal Fixed Income": "Fixed_Income",
        "Aggressive Allocation": "Allocation",
        "Allocation Miscellaneous": "Allocation",
        "Cautious Allocation": "Allocation",
        "Flexible Allocation": "Allocation",
        "Moderate Allocation": "Allocation",
        "Alternative Miscellaneous": "Alternative",
        "Long/Short Equity": "Alternative",
        "Market Neutral": "Alternative",
        "Multialternative": "Alternative",
        "Commodities Broad Basket": "Commodity",
        "Commodities Specified": "Commodity"
    }

    regression_category = category_to_regressions.get(category, "Allocation")
    if regression_category == "Allocation" and category not in category_to_regressions:
        logger.warning(f"Unmapped category {category} for {symbol}; using Allocation")

    windows = [12, 24, 36, 48, 60]
    
    for reg_name, factors, region, portfolio_base in regression_sets[regression_category]:
        try:
            if any(f in factors for f in ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value']):
                factor_data = load_century_factors(factors, portfolio_base or "All Stock Selection", None, region=region)
            elif reg_name.startswith("Commodity"):
                factor_data = load_commodity_factors()
            elif reg_name.startswith("FI"):
                fi_factors = [f for f in factors if f in ['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY']]
                other_factors = [f for f in factors if f not in fi_factors]
                factor_data = pd.concat([
                    load_db_factors(other_factors, region) if other_factors else pd.DataFrame(index=returns.index),
                    load_fixed_income_factors(fi_factors) if fi_factors else pd.DataFrame(index=returns.index)
                ], axis=1).dropna()
            else:
                factor_data = load_db_factors(factors, region)
            if factor_data.empty:
                logger.warning(f"No factors for {symbol} ({reg_name})")
                continue
            factor_data = factor_data[factor_data.index >= '2015-01-01']
            for window in windows:
                records.extend(run_rolling_regression(symbol, returns, factor_data, "OLS", reg_name, window))
        except Exception as e:
            logger.warning(f"Error in regression for {symbol} ({reg_name}): {str(e)}")
    
    logger.info(f"Generated {len(records)} regression records for {symbol}")
    return records

def process_region(region, fund_data_list):
    from concurrent.futures import ThreadPoolExecutor
    records = []
    errors = 0
    logger.info(f"Processing {len(fund_data_list)} funds in {region}")
    
    with ThreadPoolExecutor(max_workers=8) as executor:
        future_to_fund = {
            executor.submit(process_fund, fund_data): fund_data["SymbolCUSIP"]
            for fund_data in fund_data_list
        }
        for future in tqdm(future_to_fund, total=len(fund_data_list), desc=f"Processing {region}", file=sys.stdout):
            try:
                records.extend(future.result())
            except Exception as e:
                logger.error(f"Error processing {future_to_fund[future]}: {str(e)}")
                errors += 1
    
    logger.info(f"Region {region} generated {len(records)} total records with {errors} errors")
    log_summary(f"Region {region}: {len(fund_data_list)} funds, {len(records)} records, {errors} errors")
    if not DRY_RUN:
        insert_batch(records)
    
    return records, errors

# Section 6: Main Pipeline
@timer
def main():
    logger.info("Starting main pipeline")
    log_summary("Pipeline started")
    try:
        fund_meta = load_fund_metadata()
    except Exception as e:
        logger.error(f"Failed to load metadata: {e}")
        log_summary(f"Error: Failed to load metadata: {e}")
        return {"error": str(e)}
    
    regions = fund_meta["Region"].unique()
    logger.info(f"Total funds: {len(fund_meta)}, Regions: {regions}")
    log_summary(f"Total funds: {len(fund_meta)}, Regions: {regions}")
    
    fund_ids = fund_meta["SymbolCUSIP"].tolist()
    if SAMPLE_DRY_RUN:
        fund_ids = random.sample(fund_ids, min(SAMPLE_SIZE, len(fund_ids)))
        logger.info(f"Sampled {len(fund_ids)} funds")
        log_summary(f"Sampled {len(fund_ids)} funds")
    
    summary = {"total_funds": len(fund_ids), "regions": {}, "errors": 0}
    for region in sorted(set(regions) - {'Unknown'} | {'USA'}):
        region_fund_ids = fund_meta[fund_meta["Region"] == region]["SymbolCUSIP"].tolist()
        if not region_fund_ids:
            logger.warning(f"No SymbolCUSIP found for region {region}")
            summary["regions"][region] = {"funds_processed": 0, "records": 0, "errors": 0}
            continue
        if SAMPLE_DRY_RUN:
            region_fund_ids = random.sample(region_fund_ids, min(SAMPLE_SIZE, len(region_fund_ids)))
            logger.info(f"Sampled {len(region_fund_ids)} SymbolCUSIP for {region}")
        
        try:
            returns = load_fund_returns(region_fund_ids)
        except Exception as e:
            logger.error(f"Failed to load returns for {region} with SymbolCUSIP {region_fund_ids[:5]}...: {e}")
            log_summary(f"Error: Failed to load returns for {region}: {e}")
            summary["regions"][region] = {"funds_processed": 0, "records": 0, "errors": 1}
            summary["errors"] += 1
            continue
        
        region_funds = [
            {
                "SymbolCUSIP": row["SymbolCUSIP"],
                "Global_Category_Name": row["Global_Category_Name"],
                "CWA_Broad_Category_Name": row.get("CWA_Broad_Category_Name", None),
                "returns": returns[row["SymbolCUSIP"]].to_dict()
            }
            for _, row in fund_meta.iterrows() if row["SymbolCUSIP"] in returns.columns
        ]
        if not region_funds:
            logger.warning(f"No valid returns data for {region} with SymbolCUSIP {region_fund_ids[:5]}...")
            summary["regions"][region] = {"funds_processed": 0, "records": 0, "errors": 0}
            continue
        
        records, errors = process_region(region, region_funds)
        summary["regions"][region] = {"funds_processed": len(region_funds), "records": len(records), "errors": errors}
        summary["errors"] += errors
    
    logger.info(f"Pipeline summary: {summary}")
    log_summary(f"Pipeline completed: {summary}")
    return summary

# Section 7: Database Output
def insert_batch(records):
    try:
        df = pd.DataFrame(records)
        with database_transaction() as connection:
            df.to_sql("AQRR_Factor_Attribution", connection, if_exists="append", index=False, method="multi")
        logger.info(f"Inserted {len(df)} records to database")
    except Exception as e:
        logger.error(f"Error inserting batch: {e}")
        raise

if __name__ == "__main__":
    try:
        main()
    except Exception as e:
        logger.error(f"Main execution failed: {e}")
        raise
# Out:
# 2025-04-16 17:50:13,714 - INFO - Starting main pipeline
# 2025-04-16 17:50:13,906 - INFO - Loaded metadata for 5584 funds
# 2025-04-16 17:50:14,293 - INFO - load_fund_metadata took 0.58 seconds
# 2025-04-16 17:50:14,295 - INFO - Total funds: 5584, Regions: ['Global' 'USA' 'International']
# 2025-04-16 17:50:14,296 - INFO - Sampled 10 funds
# 2025-04-16 17:50:14,298 - INFO - Sampled 10 SymbolCUSIP for Global
# 2025-04-16 17:50:14,319 - INFO - Loaded returns for 10 funds
# 2025-04-16 17:50:14,323 - INFO - load_fund_returns took 0.02 seconds
# 2025-04-16 17:50:14,471 - INFO - Processing 10 funds in Global
# Processing Global:   0%|          | 0/10 [00:00<?, ?it/s]2025-04-16 17:50:14,839 - WARNING - Error in regression for SCIEX (Equity_Global_1): Index contains duplicate entries, cannot reshape
# 2025-04-16 17:50:14,867 - WARNING - Error in regression for SCIEX (Equity_Global_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:14,867 - WARNING - Error in regression for VIDI (Equity_Global_1): Index contains duplicate entries, cannot reshape
# 2025-04-16 17:50:14,873 - WARNING - Error in regression for SCIEX (Equity_Global_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:14,874 - WARNING - Error in regression for VIDI (Equity_Global_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:14,878 - WARNING - Error in regression for SCIEX (Equity_Global_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:14,879 - INFO - Generated 0 regression records for SCIEX
# 2025-04-16 17:50:14,879 - WARNING - Error in regression for VIDI (Equity_Global_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:14,885 - WARNING - Error in regression for VIDI (Equity_Global_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:14,886 - INFO - Generated 0 regression records for VIDI
# 2025-04-16 17:50:14,911 - WARNING - Error in regression for PIVYX (Equity_Global_1): Index contains duplicate entries, cannot reshape
# 2025-04-16 17:50:14,921 - WARNING - Error in regression for PIVYX (Equity_Global_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:14,927 - WARNING - Error in regression for CIHIX (Equity_Global_1): Index contains duplicate entries, cannot reshape
# 2025-04-16 17:50:14,929 - WARNING - Error in regression for PIVYX (Equity_Global_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:14,933 - WARNING - Error in regression for CIHIX (Equity_Global_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:14,933 - WARNING - Error in regression for PIVYX (Equity_Global_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:14,943 - INFO - Generated 0 regression records for PIVYX
# 2025-04-16 17:50:14,946 - WARNING - Error in regression for CIHIX (Equity_Global_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:14,949 - WARNING - Error in regression for DWCR (Equity_Global_1): Index contains duplicate entries, cannot reshape
# 2025-04-16 17:50:14,953 - WARNING - Error in regression for CIHIX (Equity_Global_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:14,954 - INFO - Generated 0 regression records for CIHIX
# 2025-04-16 17:50:14,955 - WARNING - Error in regression for DWCR (Equity_Global_2): List argument must consist only of tuples or dictionaries
# Processing Global:  10%|█         | 1/10 [00:00<00:04,  2.11it/s]2025-04-16 17:50:14,960 - WARNING - Error in regression for DWCR (Equity_Global_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:14,963 - WARNING - Error in regression for DWCR (Equity_Global_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:14,965 - INFO - Generated 0 regression records for DWCR
# 2025-04-16 17:50:14,982 - WARNING - Error in regression for MTRIX (Allocation_1): Index contains duplicate entries, cannot reshape
# 2025-04-16 17:50:14,992 - WARNING - Error in regression for MTRIX (Allocation_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:14,996 - WARNING - Error in regression for GKIRX (Allocation_1): Index contains duplicate entries, cannot reshape
# 2025-04-16 17:50:15,014 - WARNING - Error in regression for MTRIX (Allocation_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:15,017 - WARNING - Error in regression for GKIRX (Allocation_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:15,019 - WARNING - Error in regression for MTRIX (Allocation_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:15,020 - INFO - Generated 0 regression records for MTRIX
# 2025-04-16 17:50:15,021 - WARNING - Error in regression for GKIRX (Allocation_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:15,024 - WARNING - Error in regression for GKIRX (Allocation_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:15,025 - INFO - Generated 0 regression records for GKIRX
# 2025-04-16 17:50:15,131 - INFO - load_commodity_factors took 0.66 seconds
# 2025-04-16 17:50:15,134 - WARNING - Fund CCRV (Commodity_1, window=12m) skipped: 0 months available, need 12
# 2025-04-16 17:50:15,135 - WARNING - Fund CCRV (Commodity_1, window=24m) skipped: 0 months available, need 24
# 2025-04-16 17:50:15,136 - WARNING - Fund CCRV (Commodity_1, window=36m) skipped: 0 months available, need 36
# 2025-04-16 17:50:15,137 - WARNING - Fund CCRV (Commodity_1, window=48m) skipped: 0 months available, need 48
# 2025-04-16 17:50:15,137 - WARNING - Fund CCRV (Commodity_1, window=60m) skipped: 0 months available, need 60
# 2025-04-16 17:50:15,138 - INFO - Generated 0 regression records for CCRV
# Processing Global:  30%|███       | 3/10 [00:00<00:01,  5.25it/s]2025-04-16 17:50:15,157 - WARNING - Error in regression for TROSX (Equity_Global_1): Index contains duplicate entries, cannot reshape
# 2025-04-16 17:50:15,157 - WARNING - Error in regression for PABFX (Allocation_1): Index contains duplicate entries, cannot reshape
# 2025-04-16 17:50:15,160 - WARNING - Error in regression for TROSX (Equity_Global_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:15,161 - WARNING - Error in regression for PABFX (Allocation_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:15,162 - WARNING - Error in regression for TROSX (Equity_Global_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:15,164 - WARNING - Error in regression for PABFX (Allocation_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:15,165 - WARNING - Error in regression for TROSX (Equity_Global_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:15,166 - INFO - Generated 0 regression records for TROSX
# 2025-04-16 17:50:15,166 - WARNING - Error in regression for PABFX (Allocation_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:15,167 - INFO - Generated 0 regression records for PABFX
# Processing Global: 100%|██████████| 10/10 [00:00<00:00, 14.57it/s]
# 2025-04-16 17:50:15,170 - INFO - Region Global generated 0 total records with 0 errors
# 2025-04-16 17:50:15,172 - INFO - Sampled 10 SymbolCUSIP for International
# 2025-04-16 17:50:15,200 - INFO - Loaded returns for 10 funds
# 2025-04-16 17:50:15,202 - INFO - load_fund_returns took 0.03 seconds
# 2025-04-16 17:50:15,331 - INFO - Processing 10 funds in International
# Processing International:   0%|          | 0/10 [00:00<?, ?it/s]2025-04-16 17:50:15,386 - INFO - load_db_factors took 0.05 seconds
# 2025-04-16 17:50:15,390 - INFO - load_db_factors took 0.05 seconds
# 2025-04-16 17:50:15,456 - INFO - load_fixed_income_factors took 0.07 seconds
# 2025-04-16 17:50:15,473 - INFO - load_fixed_income_factors took 0.08 seconds
# 2025-04-16 17:50:17,593 - WARNING - Error in regression for CBON (FI_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:17,604 - WARNING - Error in regression for CBON (FI_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:17,621 - WARNING - Error in regression for CBON (FI_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:17,624 - WARNING - Error in regression for SZEIX (FI_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:17,624 - INFO - Generated 425 regression records for CBON
# 2025-04-16 17:50:17,627 - INFO - load_db_factors took 0.00 seconds
# 2025-04-16 17:50:17,629 - WARNING - Error in regression for SZEIX (FI_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:17,633 - WARNING - Error in regression for SZEIX (FI_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:17,633 - INFO - Generated 425 regression records for SZEIX
# 2025-04-16 17:50:17,635 - INFO - load_db_factors took 0.00 seconds
# 2025-04-16 17:50:17,705 - INFO - load_fixed_income_factors took 0.08 seconds
# 2025-04-16 17:50:17,745 - INFO - load_fixed_income_factors took 0.11 seconds
# 2025-04-16 17:50:18,200 - WARNING - Error in regression for GSAEX (Equity_Intl_1): Index contains duplicate entries, cannot reshape
# 2025-04-16 17:50:18,229 - WARNING - Error in regression for GSAEX (Equity_Intl_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:18,251 - WARNING - Error in regression for PRJPX (Equity_Intl_1): Index contains duplicate entries, cannot reshape
# 2025-04-16 17:50:18,260 - WARNING - Error in regression for GSAEX (Equity_Intl_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:18,261 - WARNING - Error in regression for BRF (Equity_Intl_1): Index contains duplicate entries, cannot reshape
# 2025-04-16 17:50:18,289 - WARNING - Error in regression for PRJPX (Equity_Intl_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:18,298 - WARNING - Error in regression for GSAEX (Equity_Intl_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:18,301 - WARNING - Error in regression for BRF (Equity_Intl_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:18,308 - INFO - Generated 0 regression records for GSAEX
# 2025-04-16 17:50:18,311 - WARNING - Error in regression for EIDO (Equity_Intl_1): Index contains duplicate entries, cannot reshape
# 2025-04-16 17:50:18,315 - WARNING - Error in regression for PRJPX (Equity_Intl_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:18,325 - WARNING - Error in regression for BRF (Equity_Intl_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:18,348 - WARNING - Error in regression for EIDO (Equity_Intl_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:18,351 - WARNING - Error in regression for PRJPX (Equity_Intl_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:18,368 - WARNING - Error in regression for EIDO (Equity_Intl_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:18,376 - WARNING - Error in regression for BRF (Equity_Intl_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:18,387 - INFO - Generated 0 regression records for PRJPX
# 2025-04-16 17:50:18,402 - WARNING - Error in regression for EWG (Equity_Intl_1): Index contains duplicate entries, cannot reshape
# 2025-04-16 17:50:18,409 - WARNING - Error in regression for CAEZX (Equity_Intl_1): Index contains duplicate entries, cannot reshape
# 2025-04-16 17:50:18,410 - INFO - Generated 0 regression records for BRF
# 2025-04-16 17:50:18,426 - WARNING - Error in regression for EIDO (Equity_Intl_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:18,449 - WARNING - Error in regression for EWG (Equity_Intl_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:18,461 - WARNING - Error in regression for CAEZX (Equity_Intl_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:18,482 - INFO - Generated 0 regression records for EIDO
# 2025-04-16 17:50:18,508 - WARNING - Error in regression for EWG (Equity_Intl_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:18,508 - WARNING - Error in regression for CAEZX (Equity_Intl_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:18,538 - WARNING - Error in regression for EWG (Equity_Intl_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:18,550 - WARNING - Error in regression for CAEZX (Equity_Intl_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:18,558 - INFO - Generated 0 regression records for EWG
# 2025-04-16 17:50:18,563 - INFO - Generated 0 regression records for CAEZX
# Processing International:  10%|█         | 1/10 [00:03<00:29,  3.24s/it]2025-04-16 17:50:20,038 - WARNING - Error in regression for LCDIX (FI_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:20,054 - WARNING - Error in regression for LCDIX (FI_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:20,070 - WARNING - Error in regression for LCDIX (FI_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:20,071 - INFO - Generated 425 regression records for LCDIX
# Processing International:  90%|█████████ | 9/10 [00:04<00:00,  2.31it/s]2025-04-16 17:50:20,072 - WARNING - Error in regression for MEDIX (FI_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:20,074 - WARNING - Error in regression for MEDIX (FI_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:20,076 - WARNING - Error in regression for MEDIX (FI_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:20,076 - INFO - Generated 425 regression records for MEDIX
# Processing International: 100%|██████████| 10/10 [00:04<00:00,  2.11it/s]
# 2025-04-16 17:50:20,078 - INFO - Region International generated 1700 total records with 0 errors
# 2025-04-16 17:50:20,082 - INFO - Sampled 10 SymbolCUSIP for USA
# 2025-04-16 17:50:20,106 - INFO - Loaded returns for 10 funds
# 2025-04-16 17:50:20,110 - INFO - load_fund_returns took 0.03 seconds
# 2025-04-16 17:50:20,243 - INFO - Processing 10 funds in USA
# 2025-04-16 17:50:20,246 - INFO - load_db_factors took 0.00 seconds
# 2025-04-16 17:50:20,251 - INFO - load_db_factors took 0.00 seconds
# Processing USA:   0%|          | 0/10 [00:00<?, ?it/s]2025-04-16 17:50:20,329 - INFO - load_fixed_income_factors took 0.08 seconds
# 2025-04-16 17:50:20,333 - WARNING - Fund EVSM (FI_1, window=12m) skipped: 10 months available, need 12
# 2025-04-16 17:50:20,336 - WARNING - Fund EVSM (FI_1, window=24m) skipped: 10 months available, need 24
# 2025-04-16 17:50:20,338 - INFO - load_fixed_income_factors took 0.08 seconds
# 2025-04-16 17:50:20,340 - WARNING - Fund EVSM (FI_1, window=36m) skipped: 10 months available, need 36
# 2025-04-16 17:50:20,348 - WARNING - Fund EVSM (FI_1, window=48m) skipped: 10 months available, need 48
# 2025-04-16 17:50:20,353 - WARNING - Fund EVSM (FI_1, window=60m) skipped: 10 months available, need 60
# 2025-04-16 17:50:20,366 - WARNING - Error in regression for EVSM (FI_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:20,383 - WARNING - Error in regression for EVSM (FI_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:20,403 - WARNING - Error in regression for EVSM (FI_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:20,412 - INFO - Generated 0 regression records for EVSM
# 2025-04-16 17:50:20,419 - INFO - load_db_factors took 0.00 seconds
# 2025-04-16 17:50:20,718 - INFO - load_db_factors took 0.47 seconds
# 2025-04-16 17:50:20,824 - INFO - load_db_factors took 0.58 seconds
# 2025-04-16 17:50:20,866 - INFO - load_db_factors took 0.62 seconds
# 2025-04-16 17:50:20,897 - WARNING - Fund TSLP (Equity_USA_1, window=24m) skipped: 14 months available, need 24
# 2025-04-16 17:50:20,914 - WARNING - Fund TSLP (Equity_USA_1, window=36m) skipped: 14 months available, need 36
# 2025-04-16 17:50:20,922 - WARNING - Fund TSLP (Equity_USA_1, window=48m) skipped: 14 months available, need 48
# 2025-04-16 17:50:20,930 - WARNING - Fund TSLP (Equity_USA_1, window=60m) skipped: 14 months available, need 60
# 2025-04-16 17:50:20,990 - WARNING - Error in regression for TSLP (Equity_USA_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:21,046 - INFO - load_db_factors took 0.79 seconds
# 2025-04-16 17:50:21,046 - WARNING - Error in regression for TSLP (Equity_USA_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:21,083 - INFO - load_db_factors took 0.83 seconds
# 2025-04-16 17:50:21,155 - WARNING - Error in regression for TSLP (Equity_USA_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:21,304 - INFO - load_db_factors took 1.05 seconds
# 2025-04-16 17:50:23,129 - WARNING - Error in regression for KORP (FI_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:23,211 - WARNING - Error in regression for KORP (FI_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:23,267 - WARNING - Error in regression for KORP (FI_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:23,286 - INFO - Generated 240 regression records for KORP
# 2025-04-16 17:50:23,313 - INFO - load_db_factors took 0.00 seconds
# 2025-04-16 17:50:24,005 - INFO - load_fixed_income_factors took 3.59 seconds
# 2025-04-16 17:50:26,573 - WARNING - Error in regression for IWC (Equity_USA_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:26,631 - WARNING - Error in regression for IWC (Equity_USA_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:26,709 - WARNING - Error in regression for IWC (Equity_USA_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:26,752 - WARNING - Error in regression for FINFX (Equity_USA_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:26,805 - WARNING - Error in regression for FINFX (Equity_USA_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:26,851 - WARNING - Error in regression for ICTEX (Equity_USA_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:26,867 - WARNING - Error in regression for FINFX (Equity_USA_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:26,895 - WARNING - Error in regression for ICTEX (Equity_USA_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:26,924 - WARNING - Error in regression for ACIZX (Equity_USA_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:26,933 - WARNING - Error in regression for ICTEX (Equity_USA_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:26,968 - WARNING - Error in regression for ACIZX (Equity_USA_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:26,983 - WARNING - Error in regression for ACIZX (Equity_USA_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:26,983 - WARNING - Error in regression for PRUZX (Equity_USA_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:27,002 - WARNING - Error in regression for PRUZX (Equity_USA_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:27,028 - WARNING - Error in regression for PRUZX (Equity_USA_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:27,207 - INFO - load_fixed_income_factors took 3.85 seconds
# 2025-04-16 17:50:28,381 - WARNING - Error in regression for TSLP (Equity_USA_5): Index contains duplicate entries, cannot reshape
# 2025-04-16 17:50:28,409 - WARNING - Error in regression for HYSZX (FI_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:28,421 - WARNING - Error in regression for HYSZX (FI_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:28,434 - WARNING - Error in regression for HYSZX (FI_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:28,436 - INFO - Generated 425 regression records for HYSZX
# 2025-04-16 17:50:29,043 - WARNING - Error in regression for TSLP (Equity_USA_6): Index contains duplicate entries, cannot reshape
# 2025-04-16 17:50:29,044 - WARNING - Error in regression for PCTPX (FI_2): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:29,048 - WARNING - Error in regression for IWC (Equity_USA_5): Index contains duplicate entries, cannot reshape
# 2025-04-16 17:50:29,049 - WARNING - Error in regression for PCTPX (FI_3): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:29,053 - WARNING - Error in regression for PCTPX (FI_4): List argument must consist only of tuples or dictionaries
# 2025-04-16 17:50:29,054 - INFO - Generated 425 regression records for PCTPX
# 2025-04-16 17:50:29,084 - WARNING - Error in regression for FINFX (Equity_USA_5): Index contains duplicate entries, cannot reshape
# 2025-04-16 17:50:29,084 - WARNING - Error in regression for ACIZX (Equity_USA_5): Index contains duplicate entries, cannot reshape
# 2025-04-16 17:50:29,087 - WARNING - Error in regression for PRUZX (Equity_USA_5): Index contains duplicate entries, cannot reshape
# 2025-04-16 17:50:29,087 - WARNING - Error in regression for ICTEX (Equity_USA_5): Index contains duplicate entries, cannot reshape
# 2025-04-16 17:50:29,242 - WARNING - Error in regression for ACIZX (Equity_USA_6): Index contains duplicate entries, cannot reshape
# 2025-04-16 17:50:29,244 - WARNING - Error in regression for PRUZX (Equity_USA_6): Index contains duplicate entries, cannot reshape
# 2025-04-16 17:50:29,263 - WARNING - Error in regression for ICTEX (Equity_USA_6): Index contains duplicate entries, cannot reshape
# 2025-04-16 17:50:29,266 - WARNING - Error in regression for FINFX (Equity_USA_6): Index contains duplicate entries, cannot reshape
# 2025-04-16 17:50:29,284 - WARNING - Error in regression for IWC (Equity_USA_6): Index contains duplicate entries, cannot reshape
# 2025-04-16 17:50:29,373 - WARNING - Error in regression for TSLP (Equity_USA_7): Index contains duplicate entries, cannot reshape
# 2025-04-16 17:50:29,373 - INFO - Generated 2 regression records for TSLP
# Processing USA:  10%|█         | 1/10 [00:09<01:22,  9.12s/it]2025-04-16 17:50:29,520 - WARNING - Error in regression for PRUZX (Equity_USA_7): Index contains duplicate entries, cannot reshape
# 2025-04-16 17:50:29,521 - INFO - Generated 420 regression records for PRUZX
# 2025-04-16 17:50:29,541 - WARNING - Error in regression for ICTEX (Equity_USA_7): Index contains duplicate entries, cannot reshape
# 2025-04-16 17:50:29,549 - INFO - Generated 420 regression records for ICTEX
# 2025-04-16 17:50:29,552 - WARNING - Error in regression for ACIZX (Equity_USA_7): Index contains duplicate entries, cannot reshape
# 2025-04-16 17:50:29,554 - INFO - Generated 420 regression records for ACIZX
# 2025-04-16 17:50:29,555 - WARNING - Error in regression for FINFX (Equity_USA_7): Index contains duplicate entries, cannot reshape
# 2025-04-16 17:50:29,556 - INFO - Generated 420 regression records for FINFX
# Processing USA:  30%|███       | 3/10 [00:09<00:17,  2.43s/it]2025-04-16 17:50:29,567 - WARNING - Error in regression for IWC (Equity_USA_7): Index contains duplicate entries, cannot reshape
# 2025-04-16 17:50:29,567 - INFO - Generated 420 regression records for IWC
# Processing USA: 100%|██████████| 10/10 [00:09<00:00,  1.07it/s]
# 2025-04-16 17:50:29,569 - INFO - Region USA generated 3192 total records with 0 errors
# 2025-04-16 17:50:29,573 - INFO - Pipeline summary: {'total_funds': 10, 'regions': {'Global': {'funds_processed': 10, 'records': 0, 'errors': 0}, 'International': {'funds_processed': 10, 'records': 1700, 'errors': 0}, 'USA': {'funds_processed': 10, 'records': 3192, 'errors': 0}}, 'errors': 0}
# 2025-04-16 17:50:29,580 - INFO - main took 15.86 seconds

# %%
import pandas as pd
import numpy as np
import os
import random
import logging
from datetime import timedelta, datetime
from dateutil.relativedelta import relativedelta
from concurrent.futures import ProcessPoolExecutor
from sqlalchemy import create_engine
from tqdm import tqdm
import statsmodels.api as sm
import time
import sys
from contextlib import contextmanager
from functools import wraps

# Section 1: Configuration and Logging
CONFIG = {
    "database": {
        "server": "JULIANS_LAPTOP\\SQLEXPRESS",
        "database": "CWA_Fund_Database",
        "driver": "ODBC Driver 18 for SQL Server"
    },
    "return_metric": "1 Month Return",
    "rolling_periods": [12, 24, 36, 48, 60],
    "dry_run": True,
    "sample_dry_run": True,
    "sample_size": 10,
    "chunk_size": 5600,
    "batch_insert_size": 10000,
    "max_workers_cpu": 16,  # Optimized for 16-core i9 Ultra
    "batch_size": 100,  # Process 100 funds per batch
}

CONNECTION_STRING = (
    f"mssql+pyodbc://{CONFIG['database']['server']}/{CONFIG['database']['database']}"
    f"?driver={CONFIG['database']['driver']}&trusted_connection=yes&TrustServerCertificate=yes"
)
engine = create_engine(CONNECTION_STRING, pool_size=20, max_overflow=10)

RETURN_METRIC = CONFIG["return_metric"]
ROLLING_PERIODS = CONFIG["rolling_periods"]
DRY_RUN = CONFIG["dry_run"]
SAMPLE_DRY_RUN = CONFIG["sample_dry_run"]
SAMPLE_SIZE = CONFIG["sample_size"]
CHUNK_SIZE = CONFIG["chunk_size"]
BATCH_INSERT_SIZE = CONFIG["batch_insert_size"]
MAX_WORKERS_CPU = CONFIG["max_workers_cpu"]
BATCH_SIZE = CONFIG["batch_size"]

# Logging setup
SUMMARY_LOG = "factor_attribution_summary.log"
logging.basicConfig(
    level=logging.WARNING,  # WARNING for production, DEBUG for targeted sections
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler("factor_attribution.log"),
        logging.StreamHandler(sys.stdout)
    ],
    force=True
)
logger = logging.getLogger()

def log_summary(message):
    with open(SUMMARY_LOG, 'a') as f:
        f.write(f"{datetime.now()}: {message}\n")

# Section 2: Helper Functions
def category_to_region(category):
    mapping = {
        "US Equity Large Cap Blend": ("USA", "US Equity Large Cap Blend"),
        "US Equity Large Cap Growth": ("USA", "US Equity Large Cap Growth"),
        "US Equity Large Cap Value": ("USA", "US Equity Large Cap Value"),
        "US Equity Mid Cap": ("USA", "US Equity Mid Cap"),
        "US Equity Small Cap": ("USA", "US Equity Small Cap"),
        "Global Equity Large Cap": ("Global", "Global Equity Large Cap"),
        "Global Equity Mid/Small Cap": ("Global", "Global Equity Mid/Small Cap"),
        "Global Emerging Markets Equity": ("Global", "Global Emerging Markets Equity"),
        "Europe Equity Large Cap": ("International", "Europe Equity Large Cap"),
        "Asia Equity": ("International", "Asia Equity"),
        "Japan Equity": ("International", "Japan Equity"),
        "Emerging Markets Fixed Income": ("International", "Emerging Markets Fixed Income"),
        "US Fixed Income": ("USA", "US Fixed Income"),
        "US Municipal Fixed Income": ("USA", "US Municipal Fixed Income"),
        "Global Fixed Income": ("Global", "Global Fixed Income"),
        "Flexible Allocation": ("Global", "Flexible Allocation"),
        "Aggressive Allocation": ("Global", "Aggressive Allocation"),
        "Moderate Allocation": ("Global", "Moderate Allocation"),
        "Cautious Allocation": ("Global", "Cautious Allocation"),
        "Commodities Broad Basket": ("Global", "Commodities Broad Basket"),
        "Commodities Specified": ("Global", "Commodities Specified"),
        "Options Trading": ("USA", "Options Trading"),
        "Multialternative": ("Global", "Multialternative"),
        "Market Neutral": ("Global", "Market Neutral"),
        "Long/Short Equity": ("Global", "Long/Short Equity"),
        "Alternative Miscellaneous": ("Global", "Alternative Miscellaneous"),
        "Energy Sector Equity": ("USA", "Energy Sector Equity"),
        "Equity Miscellaneous": ("USA", "Equity Miscellaneous"),
        "Financials Sector Equity": ("USA", "Financials Sector Equity"),
        "Healthcare Sector Equity": ("USA", "Healthcare Sector Equity"),
        "Consumer Goods & Services Sector Equity": ("USA", "Consumer Goods & Services Sector Equity"),
        "Communications Sector Equity": ("USA", "Communications Sector Equity"),
        "Industrials Sector Equity": ("USA", "Industrials Sector Equity"),
        "Other Sector Equity": ("USA", "Other Sector Equity"),
        "Real Estate Sector Equity": ("USA", "Real Estate Sector Equity"),
        "Precious Metals Sector Equity": ("USA", "Precious Metals Sector Equity"),
        "Technology Sector Equity": ("USA", "Technology Sector Equity"),
        "Utilities Sector Equity": ("USA", "Utilities Sector Equity"),
        "Natural Resources Sector Equity": ("USA", "Natural Resources Sector Equity"),
        "Infrastructure Sector Equity": ("USA", "Infrastructure Sector Equity"),
        "Trading Tools": ("USA", "Trading Tools"),
        "Asia ex-Japan Equity": ("International", "Asia ex-Japan Equity"),
        "Australia & New Zealand Equity": ("International", "Australia & New Zealand Equity"),
        "Canadian Equity Large Cap": ("International", "Canadian Equity Large Cap"),
        "Europe Equity Mid/Small Cap": ("International", "Europe Equity Mid/Small Cap"),
        "Greater China Equity": ("International", "Greater China Equity"),
        "India Equity": ("International", "India Equity"),
        "Mexico Equity": ("International", "Mexico Equity"),
        "Korea Equity": ("International", "Korea Equity"),
        "Latin America Equity": ("International", "Latin America Equity"),
        "UK Equity Large Cap": ("International", "UK Equity Large Cap"),
        "Thailand Equity": ("International", "Thailand Equity"),
        "Convertibles": ("USA", "Convertibles"),
        "Fixed Income Miscellaneous": ("USA", "Fixed Income Miscellaneous"),
        "Allocation Miscellaneous": ("Global", "Allocation Miscellaneous")
    }
    return mapping.get(category, ("USA", "Unknown"))

@contextmanager
def database_transaction():
    with engine.connect() as connection:
        transaction = connection.begin()
        try:
            yield connection
            transaction.commit()
        except Exception as e:
            transaction.rollback()
            logger.error(f"Transaction failed: {e}")
            raise

def timer(func):
    @wraps(func)
    def wrapper(*args, **kwargs):
        start_time = time.time()
        logger.debug(f"Starting {func.__name__}")
        result = func(*args, **kwargs)
        logger.info(f"{func.__name__} took {time.time() - start_time:.2f} seconds")
        return result
    return wrapper

# Section 3: Data Loading
FACTOR_CACHE = {}

@timer
def load_db_factors(factor_list, region="Global", table="factor_returns", asset_class=None):
    cache_key = (tuple(factor_list), region, table, asset_class)
    if cache_key in FACTOR_CACHE:
        logger.debug(f"Using cached factors for {cache_key}")
        return FACTOR_CACHE[cache_key]
    
    factor_dfs = []
    for factor in factor_list:
        query = f"""
            SELECT Date, Factor, Value, region
            FROM {table}
            WHERE Factor = '{factor}'
            AND Date >= '2015-01-01'
            AND UPPER(region) = UPPER('{region}')
        """
        if factor == 'RF':
            query = query.replace(f"region = '{region}'", "region = 'USA'")
        if asset_class:
            query += f" AND asset_class = '{asset_class}'"
        logger.debug(f"Executing query: {query}")
        df = pd.read_sql_query(query, engine, parse_dates=['Date'])
        if df.empty:
            logger.warning(f"No data for factor {factor} in {region}")
            continue
        if df[['Date', 'Factor']].duplicated().any():
            logger.error(f"Non-unique Date-Factor pairs for {factor}: {df[df[['Date', 'Factor']].duplicated()]}")
            return pd.DataFrame()
        factor_dfs.append(df)
    
    if not factor_dfs:
        logger.warning(f"No data for factors {factor_list} in {table} (region: {region})")
        return pd.DataFrame()
    
    df = pd.concat(factor_dfs)
    logger.debug(f"Raw factor data shape: {df.shape}, sample:\n{df.head()}")
    
    pivoted_df = df.pivot(index="Date", columns="Factor", values="Value")
    pivoted_df.index = pd.to_datetime(pivoted_df.index) + pd.offsets.MonthEnd(0)
    pivoted_df = pivoted_df[~pivoted_df.index.duplicated(keep='first')]
    pivoted_df = pivoted_df.asfreq('ME')
    FACTOR_CACHE[cache_key] = pivoted_df
    return pivoted_df

@timer
def load_century_factors(factor_list, portfolio_base, asset_class=None, region="Global"):
    factor_in_clause = ','.join([f"'{f}'" for f in factor_list])
    query = f"""
        SELECT date AS Date, factor AS Factor, value AS Value, portfolio
        FROM aqr_century_factors
        WHERE factor IN ({factor_in_clause})
        AND portfolio = ?
        AND date >= '2015-01-01'
    """
    params = [portfolio_base]
    if asset_class:
        query += " AND asset_class = ?"
        params.append(asset_class)
    if region != "Global":
        query += " AND region = ?"
        params.append(region)
    logger.debug(f"Executing query: {query}, params: {params}")
    df = pd.read_sql(query, engine, params=params, parse_dates=['Date'])
    if df.empty:
        logger.warning(f"No data for factors {factor_list} in aqr_century_factors (portfolio: {portfolio_base}, region: {region})")
        return pd.DataFrame()
    if df[['Date', 'Factor']].duplicated().any():
        logger.error(f"Non-unique Date-Factor pairs in aqr_century_factors: {df[df[['Date', 'Factor']].duplicated()]}")
        return pd.DataFrame()
    logger.debug(f"Raw century factors shape: {df.shape}, portfolio: {df['portfolio'].unique()}, sample:\n{df.head()}")
    pivoted_df = df.pivot(index="Date", columns="Factor", values="Value")
    pivoted_df.index = pd.to_datetime(pivoted_df.index) + pd.offsets.MonthEnd(0)
    pivoted_df = pivoted_df[~pivoted_df.index.duplicated(keep='first')]
    pivoted_df = pivoted_df.asfreq('ME')
    if pivoted_df.empty or pivoted_df.shape[1] == 0:
        logger.warning(f"Empty pivoted data for factors {factor_list} (portfolio: {portfolio_base})")
        return pd.DataFrame()
    return pivoted_df

@timer
def load_fund_metadata():
    query = """
    SELECT 
        f.SymbolCUSIP, 
        f.Region, 
        f.YC_Global_Category_ID, 
        c.Global_Category_Name,
        f.YC_Category_ID,
        y.Category_Name,
        f.CWA_Broad_Category_ID,
        b.CWA_Broad_Category_Name
    FROM Funds_to_Screen f
    JOIN YC_Global_Category_List c ON f.YC_Global_Category_ID = c.ID
    JOIN YC_Category_List y ON f.YC_Category_ID = y.ID
    LEFT JOIN CWA_Broad_Category_List b ON f.CWA_Broad_Category_ID = b.ID
    """
    df = pd.read_sql(query, engine)
    logger.info(f"Loaded metadata for {len(df)} funds")
    df[["Region", "FactorProfile"]] = df["Global_Category_Name"].map(category_to_region).apply(pd.Series)
    if df["CWA_Broad_Category_Name"].isnull().all():
        logger.warning("CWA_Broad_Category_Name missing; Equity regressions 5-7 will be skipped")
    return df.dropna(subset=["Region", "FactorProfile"])

@timer
def load_fund_returns(fund_ids=None):
    query = """
    SELECT SymbolCUSIP, Date, ReturnValue
    FROM Fund_Returns_Timeseries
    WHERE Metric = '1 Month Return' AND ReturnValue IS NOT NULL AND Date IS NOT NULL
    """
    if fund_ids:
        fund_ids = [fid for fid in fund_ids if isinstance(fid, str) and fid.strip()]
        if not fund_ids:
            logger.warning("No valid SymbolCUSIP provided")
            return pd.DataFrame()
        fund_ids_str = ",".join([f"'{fid}'" for fid in fund_ids])
        query += f" AND SymbolCUSIP IN ({fund_ids_str})"
    
    logger.debug(f"Executing query: {query}")
    chunks = []
    for chunk in pd.read_sql_query(query, engine, parse_dates=["Date"], chunksize=CHUNK_SIZE):
        logger.debug(f"Loaded chunk of {len(chunk)} rows")
        chunks.append(chunk)
    df = pd.concat(chunks) if chunks else pd.DataFrame()
    if df.empty:
        logger.warning(f"No returns data loaded for SymbolCUSIP: {fund_ids}")
        return pd.DataFrame()
    
    logger.info(f"Loaded returns for {len(df['SymbolCUSIP'].unique())} funds")
    pivoted = df.pivot(index="Date", columns="SymbolCUSIP", values="ReturnValue")
    pivoted.index = pd.to_datetime(pivoted.index) + pd.offsets.MonthEnd(0)
    pivoted.index = pivoted.index.drop_duplicates()
    pivoted = pivoted.asfreq('ME')
    for col in pivoted.columns:
        if not pd.api.types.is_numeric_dtype(pivoted[col]):
            logger.warning(f"Non-numeric returns for {col}; converting")
            pivoted[col] = pd.to_numeric(pivoted[col], errors='coerce')
    return pivoted

@timer
def load_commodity_factors():
    query = """
        SELECT date AS Date, 
               excess_return_eqwt, 
               excess_spot_return_eqwt, 
               ir_adjusted_carry_eqwt, 
               spot_return_eqwt, 
               carry_eqwt, 
               excess_return_long_short, 
               excess_spot_return_long_short, 
               ir_adjusted_carry_long_short, 
               aggregate_backwardation_contango
        FROM aqr_cmdty_factors
    """
    df = pd.read_sql(query, engine, parse_dates=['Date'])
    if df.empty:
        logger.warning("No commodity factors loaded")
        return pd.DataFrame()
    pivoted_df = df.set_index("Date")
    pivoted_df.index = pd.to_datetime(pivoted_df.index) + pd.offsets.MonthEnd(0)
    pivoted_df.index = pivoted_df.index.drop_duplicates()
    pivoted_df = pivoted_df.asfreq('ME')
    return pivoted_df

@timer
def load_fixed_income_factors(factor_list):
    factor_in_clause = ','.join([f"'{f}'" for f in factor_list])
    query = f"""
        SELECT Date, Factor_Name, ReturnValue
        FROM Fixed_Income_Factor_Returns
        WHERE Factor_Name IN ({factor_in_clause})
    """
    logger.debug(f"Executing query: {query}")
    df = pd.read_sql_query(query, engine, parse_dates=["Date"])
    if df.empty:
        logger.warning(f"No fixed income factors for {factor_list}")
        return pd.DataFrame()
    pivoted_df = df.pivot(index="Date", columns="Factor_Name", values="ReturnValue")
    pivoted_df.index = pd.to_datetime(pivoted_df.index) + pd.offsets.MonthEnd(0)
    pivoted_df.index = pivoted_df.index.drop_duplicates()
    pivoted_df = pivoted_df.asfreq('ME')
    return pivoted_df

# Section 4: Regression Processing
def run_rolling_regression(symbol, returns, factor_data, regression_type, regression_name, window_months):
    records = []
    months_needed = window_months
    
    returns = returns.sort_index()
    factor_data = factor_data.sort_index()
    
    available_dates = returns.index.intersection(factor_data.index)
    if len(available_dates) < months_needed:
        logger.warning(f"Fund {symbol} ({regression_name}, window={window_months}m) skipped: {len(available_dates)} months available")
        return records
    
    for end_date in available_dates[months_needed-1::1]:
        start_date = end_date - pd.offsets.MonthEnd(months_needed)
        if start_date < available_dates[0]:
            continue
        
        window_returns = returns.loc[start_date:end_date]
        window_factors = factor_data.loc[start_date:end_date]
        
        window_returns = window_returns.reindex(window_factors.index)
        
        if len(window_returns.dropna()) < months_needed * 0.8 or len(window_factors.dropna()) < months_needed * 0.8:
            logger.debug(f"Skipping regression for {symbol} ({regression_name}, window={window_months}m, end_date={end_date}): insufficient data")
            continue
        
        try:
            if regression_type == "OLS":
                X = sm.add_constant(window_factors)
                model = sm.OLS(window_returns, X, missing='drop').fit()
                coefficients = model.params.to_dict()
                tvalues = model.tvalues.to_dict()
                pvalues = model.pvalues.to_dict()
                r_squared = model.rsquared
                record = {
                    "SymbolCUSIP": symbol,
                    "RegressionName": regression_name,
                    "Window": f"{window_months}m",
                    "EndDate": end_date,
                    "R_Squared": r_squared
                }
                for factor in coefficients:
                    record[f"{factor}_beta"] = coefficients[factor]
                    record[f"{factor}_tvalue"] = tvalues.get(factor, None)
                    record[f"{factor}_pvalue"] = pvalues.get(factor, None)
                records.append(record)
        except Exception as e:
            logger.warning(f"Regression failed for {symbol} ({regression_name}, window={window_months}m, end_date={end_date}): {str(e)}")
            continue
    
    if not records:
        logger.info(f"No regressions completed for {symbol} ({regression_name}, window={window_months}m)")
    return records

# Section 5: Fund Processing
category_to_regressions = {
    "Energy Sector Equity": "Equity_USA",
    "Equity Miscellaneous": "Equity_USA",
    "Financials Sector Equity": "Equity_USA",
    "Healthcare Sector Equity": "Equity_USA",
    "Consumer Goods & Services Sector Equity": "Equity_USA",
    "Communications Sector Equity": "Equity_USA",
    "Industrials Sector Equity": "Equity_USA",
    "Other Sector Equity": "Equity_USA",
    "Real Estate Sector Equity": "Equity_USA",
    "Precious Metals Sector Equity": "Equity_USA",
    "Technology Sector Equity": "Equity_USA",
    "Utilities Sector Equity": "Equity_USA",
    "US Equity Large Cap Blend": "Equity_USA",
    "US Equity Large Cap Growth": "Equity_USA",
    "US Equity Large Cap Value": "Equity_USA",
    "US Equity Mid Cap": "Equity_USA",
    "US Equity Small Cap": "Equity_USA",
    "Options Trading": "Equity_USA",
    "Natural Resources Sector Equity": "Equity_USA",
    "Infrastructure Sector Equity": "Equity_USA",
    "Asia ex-Japan Equity": "Equity_Intl",
    "Australia & New Zealand Equity": "Equity_Intl",
    "Canadian Equity Large Cap": "Equity_Intl",
    "Europe Equity Large Cap": "Equity_Intl",
    "Europe Equity Mid/Small Cap": "Equity_Intl",
    "Greater China Equity": "Equity_Intl",
    "India Equity": "Equity_Intl",
    "Mexico Equity": "Equity_Intl",
    "Japan Equity": "Equity_Intl",
    "Korea Equity": "Equity_Intl",
    "Latin America Equity": "Equity_Intl",
    "UK Equity Large Cap": "Equity_Intl",
    "Thailand Equity": "Equity_Intl",
    "Global Emerging Markets Equity": "Equity_Global",
    "Global Equity Large Cap": "Equity_Global",
    "Global Equity Mid/Small Cap": "Equity_Global",
    "Global Fixed Income": "Fixed_Income",
    "Convertibles": "Fixed_Income",
    "Emerging Markets Fixed Income": "Fixed_Income",
    "Fixed Income Miscellaneous": "Fixed_Income",
    "US Fixed Income": "Fixed_Income",
    "US Municipal Fixed Income": "Fixed_Income",
    "Aggressive Allocation": "Allocation",
    "Allocation Miscellaneous": "Allocation",
    "Cautious Allocation": "Allocation",
    "Flexible Allocation": "Allocation",
    "Moderate Allocation": "Allocation",
    "Alternative Miscellaneous": "Alternative",
    "Long/Short Equity": "Alternative",
    "Market Neutral": "Alternative",
    "Multialternative": "Alternative",
    "Commodities Broad Basket": "Commodity",
    "Commodities Specified": "Commodity"
}

regression_sets = {
    "Equity_USA": [
        ("Equity_USA_1", ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB'], "USA", None),
        ("Equity_USA_2", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "USA", "US Stock Selection"),
        ("Equity_USA_3", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "USA", "All Macro"),
        ("Equity_USA_4", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "USA", "Equity indices"),
        ("Equity_USA_5", ['MKT', 'BAB', 'TSM-FI', 'TSM-FX', 'excess_return_eqwt'], "USA", None),
        ("Equity_USA_6", ['MKT', 'SMB', 'BAB', 'TSM-Com'], "USA", None),
        ("Equity_USA_7", ['MKT', 'HML_Devil', 'QMJ', 'UMD', 'SMB', 'BAB', 'TSM-Com', 'TSM-FI', 'TSM-FX'], "USA", None)
    ],
    "Equity_Intl": [
        ("Equity_Intl_1", ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB'], "Intl", None),
        ("Equity_Intl_2", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "International", "Intl Stock Selection"),
        ("Equity_Intl_3", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "International", "All Macro"),
        ("Equity_Intl_4", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "International", "Equity indices")
    ],
    "Equity_Global": [
        ("Equity_Global_1", ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB'], "Global", None),
        ("Equity_Global_2", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "All Stock Selection"),
        ("Equity_Global_3", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "All Macro"),
        ("Equity_Global_4", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "Equity indices")
    ],
    "Fixed_Income": [
        ("FI_1", ['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY', 'TSM-FI', 'TSM-FX'], "Global", None),
        ("FI_2", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "Fixed income"),
        ("FI_3", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "All Macro"),
        ("FI_4", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "Equity indices")
    ],
    "Allocation": [
        ("Allocation_1", ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ', 'TSM-FI'], "Global", None),
        ("Allocation_2", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "All Stock Selection"),
        ("Allocation_3", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "All Macro"),
        ("Allocation_4", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "Equity indices")
    ],
    "Alternative": [
        ("Alternative_1", ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ', 'TSM-FI', 'TSM-Com', 'TSM-FX'], "Global", None),
        ("Allocation_2", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "All Stock Selection"),
        ("Allocation_3", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "All Macro"),
        ("Allocation_4", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "Equity indices")
    ],
    "Commodity": [
        ("Commodity_1", ['excess_return_eqwt', 'excess_spot_return_eqwt', 'ir_adjusted_carry_eqwt', 'spot_return_eqwt', 'carry_eqwt', 'excess_return_long_short', 'excess_spot_return_long_short', 'ir_adjusted_carry_long_short', 'aggregate_backwardation_contango'], "Global", None)
    ]
}

def process_fund(fund_data):
    records = []
    symbol = fund_data["SymbolCUSIP"]
    category = fund_data["Global_Category_Name"]
    returns = pd.Series(fund_data["returns"]).dropna()
    
    if returns.empty:
        logger.warning(f"No valid returns for {symbol}")
        return records
    
    regression_category = category_to_regressions.get(category, "Allocation")
    if regression_category == "Allocation" and category not in category_to_regressions:
        logger.warning(f"Unmapped category {category} for {symbol}; using Allocation")
    
    factor_data_cache = {}
    for reg_name, factors, region, portfolio_base in regression_sets[regression_category]:
        try:
            logger.debug(f"Loading factors for {symbol} ({reg_name}): factors {factors}, region {region}, portfolio_base {portfolio_base}")
            if any(f in factors for f in ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value']):
                if not portfolio_base:
                    logger.warning(f"Skipping {reg_name} for {symbol}: portfolio_base missing")
                    continue
                factor_data = load_century_factors(factors, portfolio_base, region=region)
            elif reg_name.startswith("Commodity"):
                factor_data = load_commodity_factors()
            elif reg_name.startswith("FI"):
                fi_factors = [f for f in factors if f in ['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY']]
                other_factors = [f for f in factors if f not in fi_factors]
                factor_data = pd.concat([
                    load_db_factors(other_factors, region) if other_factors else pd.DataFrame(index=returns.index),
                    load_fixed_income_factors(fi_factors) if fi_factors else pd.DataFrame(index=returns.index)
                ], axis=1).dropna()
            else:
                factor_data = load_db_factors(factors, region)
            if not isinstance(factor_data, pd.DataFrame):
                logger.error(f"Invalid factor data type for {reg_name} ({symbol}): {type(factor_data)}")
                continue
            if factor_data.empty or factor_data.shape[1] == 0:
                logger.warning(f"Empty factor data for {reg_name} ({symbol}): factors {factors}")
                continue
            logger.debug(f"Factor data for {reg_name} ({symbol}): shape {factor_data.shape}, columns {factor_data.columns.tolist()}")
            factor_data = factor_data[factor_data.index >= '2015-01-01']
            factor_data_cache[(reg_name, region)] = factor_data
        except Exception as e:
            logger.warning(f"Error loading factors for {symbol} ({reg_name}): {str(e)}")
            continue
    
    for reg_name, factors, region, portfolio_base in regression_sets[regression_category]:
        factor_data = factor_data_cache.get((reg_name, region))
        if factor_data is None:
            continue
        for window in ROLLING_PERIODS:
            records.extend(run_rolling_regression(symbol, returns, factor_data, "OLS", reg_name, window))
    
    logger.info(f"Generated {len(records)} regression records for {symbol}")
    return records

def process_region(region, fund_data_list):
    records = []
    errors = 0
    logger.info(f"Processing {len(fund_data_list)} funds in {region}")
    
    if SAMPLE_DRY_RUN:
        # Sequential processing for debugging
        for fund_data in tqdm(fund_data_list, total=len(fund_data_list), desc=f"Processing {region}", file=sys.stdout):
            try:
                records.extend(process_fund(fund_data))
            except Exception as e:
                logger.error(f"Error processing {fund_data['SymbolCUSIP']}: {str(e)}")
                errors += 1
    else:
        # Parallel processing for production
        for i in range(0, len(fund_data_list), BATCH_SIZE):
            batch = fund_data_list[i:i + BATCH_SIZE]
            with ProcessPoolExecutor(max_workers=MAX_WORKERS_CPU) as executor:
                future_to_fund = {
                    executor.submit(process_fund, fund_data): fund_data["SymbolCUSIP"]
                    for fund_data in batch
                }
                for future in tqdm(future_to_fund, total=len(batch), desc=f"Processing {region} batch", file=sys.stdout):
                    try:
                        records.extend(future.result())
                    except Exception as e:
                        logger.error(f"Error processing {future_to_fund[future]}: {str(e)}")
                        errors += 1
    
    logger.info(f"Region {region} generated {len(records)} total records with {errors} errors")
    log_summary(f"Region {region}: {len(fund_data_list)} funds, {len(records)} records, {errors} errors")
    if not DRY_RUN:
        insert_batch(records)
    
    return records, errors

# Section 6: Database Output
def insert_batch(records):
    if DRY_RUN:
        logger.info(f"Dry run: Would insert {len(records)} records")
        return
    try:
        df = pd.DataFrame(records)
        with database_transaction() as connection:
            df.to_sql("AQRR_Factor_Attribution", connection, if_exists="append", index=False, method="multi")
        logger.info(f"Inserted {len(df)} records to database")
    except Exception as e:
        logger.error(f"Error inserting batch: {e}")
        raise

# Section 7: Main Pipeline
@timer
def main():
    logger.info("Starting main pipeline")
    log_summary("Pipeline started")
    try:
        fund_meta = load_fund_metadata()
    except Exception as e:
        logger.error(f"Failed to load metadata: {e}")
        log_summary(f"Error: Failed to load metadata: {e}")
        return {"error": str(e)}
    
    regions = fund_meta["Region"].unique()
    logger.info(f"Total funds: {len(fund_meta)}, Regions: {regions}")
    log_summary(f"Total funds: {len(fund_meta)}, Regions: {regions}")
    
    fund_ids = fund_meta["SymbolCUSIP"].tolist()
    if SAMPLE_DRY_RUN:
        fund_ids = random.sample(fund_ids, min(SAMPLE_SIZE, len(fund_ids)))
        logger.info(f"Sampled {len(fund_ids)} funds")
        log_summary(f"Sampled {len(fund_ids)} funds")
    
    summary = {"total_funds": len(fund_ids), "regions": {}, "errors": 0}
    for region in sorted(set(regions) - {'Unknown'} | {'USA'}):
        region_fund_ids = fund_meta[fund_meta["Region"] == region]["SymbolCUSIP"].tolist()
        if not region_fund_ids:
            logger.warning(f"No SymbolCUSIP found for region {region}")
            summary["regions"][region] = {"funds_processed": 0, "records": 0, "errors": 0}
            continue
        if SAMPLE_DRY_RUN:
            region_fund_ids = random.sample(region_fund_ids, min(SAMPLE_SIZE, len(region_fund_ids)))
            logger.info(f"Sampled {len(region_fund_ids)} SymbolCUSIP for {region}")
        
        try:
            returns = load_fund_returns(region_fund_ids)
        except Exception as e:
            logger.error(f"Failed to load returns for {region}: {e}")
            log_summary(f"Error: Failed to load returns for {region}: {e}")
            summary["regions"][region] = {"funds_processed": 0, "records": 0, "errors": 1}
            summary["errors"] += 1
            continue
        
        region_funds = [
            {
                "SymbolCUSIP": row["SymbolCUSIP"],
                "Global_Category_Name": row["Global_Category_Name"],
                "CWA_Broad_Category_Name": row.get("CWA_Broad_Category_Name", None),
                "returns": returns[row["SymbolCUSIP"]].to_dict()
            }
            for _, row in fund_meta.iterrows() if row["SymbolCUSIP"] in returns.columns
        ]
        if not region_funds:
            logger.warning(f"No valid returns data for {region}")
            summary["regions"][region] = {"funds_processed": 0, "records": 0, "errors": 0}
            continue
        
        records, errors = process_region(region, region_funds)
        summary["regions"][region] = {"funds_processed": len(region_funds), "records": len(records), "errors": errors}
        summary["errors"] += errors
    
    logger.info(f"Pipeline summary: {summary}")
    log_summary(f"Pipeline completed: {summary}")
    return summary

if __name__ == "__main__":
    try:
        main()
    except Exception as e:
        logger.error(f"Main execution failed: {e}")
        raise
# Out:
# Processing Global:   0%|          | 0/10 [00:00<?, ?it/s]2025-04-20 13:22:18,676 - WARNING - Error loading factors for WGBIX (Allocation_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:18,679 - WARNING - Error loading factors for WGBIX (Allocation_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:18,681 - WARNING - Error loading factors for WGBIX (Allocation_4): List argument must consist only of tuples or dictionaries
# Processing Global:  10%|█         | 1/10 [00:00<00:03,  2.44it/s]2025-04-20 13:22:19,070 - WARNING - Error loading factors for MEMIX (Equity_Global_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:19,072 - WARNING - Error loading factors for MEMIX (Equity_Global_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:19,074 - WARNING - Error loading factors for MEMIX (Equity_Global_4): List argument must consist only of tuples or dictionaries
# Processing Global:  20%|██        | 2/10 [00:00<00:03,  2.41it/s]2025-04-20 13:22:19,465 - WARNING - Error loading factors for MPAY (Allocation_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:19,467 - WARNING - Error loading factors for MPAY (Allocation_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:19,469 - WARNING - Error loading factors for MPAY (Allocation_4): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:19,515 - WARNING - Fund MPAY (Allocation_1, window=36m) skipped: 32 months available
# 2025-04-20 13:22:19,516 - WARNING - Fund MPAY (Allocation_1, window=48m) skipped: 32 months available
# 2025-04-20 13:22:19,518 - WARNING - Fund MPAY (Allocation_1, window=60m) skipped: 32 months available
# 2025-04-20 13:22:19,748 - WARNING - Fund PDBC (Commodity_1, window=60m) skipped: 48 months available
# Processing Global:  40%|████      | 4/10 [00:01<00:01,  4.09it/s]2025-04-20 13:22:19,752 - WARNING - Error loading factors for PABD (Equity_Global_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:19,754 - WARNING - Error loading factors for PABD (Equity_Global_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:19,756 - WARNING - Error loading factors for PABD (Equity_Global_4): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:19,758 - WARNING - Fund PABD (Equity_Global_1, window=24m) skipped: 12 months available
# 2025-04-20 13:22:19,760 - WARNING - Fund PABD (Equity_Global_1, window=36m) skipped: 12 months available
# 2025-04-20 13:22:19,761 - WARNING - Fund PABD (Equity_Global_1, window=48m) skipped: 12 months available
# 2025-04-20 13:22:19,762 - WARNING - Fund PABD (Equity_Global_1, window=60m) skipped: 12 months available
# 2025-04-20 13:22:19,768 - WARNING - Error loading factors for AGQI (Equity_Global_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:19,771 - WARNING - Error loading factors for AGQI (Equity_Global_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:19,773 - WARNING - Error loading factors for AGQI (Equity_Global_4): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:19,777 - WARNING - Fund AGQI (Equity_Global_1, window=24m) skipped: 14 months available
# 2025-04-20 13:22:19,778 - WARNING - Fund AGQI (Equity_Global_1, window=36m) skipped: 14 months available
# 2025-04-20 13:22:19,780 - WARNING - Fund AGQI (Equity_Global_1, window=48m) skipped: 14 months available
# 2025-04-20 13:22:19,781 - WARNING - Fund AGQI (Equity_Global_1, window=60m) skipped: 14 months available
# 2025-04-20 13:22:19,784 - WARNING - Error loading factors for NFFFX (Equity_Global_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:19,786 - WARNING - Error loading factors for NFFFX (Equity_Global_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:19,788 - WARNING - Error loading factors for NFFFX (Equity_Global_4): List argument must consist only of tuples or dictionaries
# Processing Global:  70%|███████   | 7/10 [00:01<00:00,  5.52it/s]2025-04-20 13:22:20,153 - WARNING - Error loading factors for SMYIX (Equity_Global_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:20,154 - WARNING - Error loading factors for SMYIX (Equity_Global_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:20,156 - WARNING - Error loading factors for SMYIX (Equity_Global_4): List argument must consist only of tuples or dictionaries
# Processing Global:  80%|████████  | 8/10 [00:01<00:00,  4.51it/s]2025-04-20 13:22:20,523 - WARNING - Error loading factors for JTQIX (Equity_Global_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:20,525 - WARNING - Error loading factors for JTQIX (Equity_Global_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:20,527 - WARNING - Error loading factors for JTQIX (Equity_Global_4): List argument must consist only of tuples or dictionaries
# Processing Global:  90%|█████████ | 9/10 [00:02<00:00,  4.27it/s]2025-04-20 13:22:20,798 - WARNING - Error loading factors for PALPX (Allocation_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:20,802 - WARNING - Error loading factors for PALPX (Allocation_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:20,803 - WARNING - Error loading factors for PALPX (Allocation_4): List argument must consist only of tuples or dictionaries
# Processing Global: 100%|██████████| 10/10 [00:02<00:00,  3.96it/s]
# Processing International:   0%|          | 0/10 [00:00<?, ?it/s]2025-04-20 13:22:21,315 - WARNING - Unmapped category Asia Equity for VPL; using Allocation
# 2025-04-20 13:22:21,318 - WARNING - Error loading factors for VPL (Allocation_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:21,320 - WARNING - Error loading factors for VPL (Allocation_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:21,322 - WARNING - Error loading factors for VPL (Allocation_4): List argument must consist only of tuples or dictionaries
# Processing International:  10%|█         | 1/10 [00:00<00:03,  2.62it/s]2025-04-20 13:22:21,709 - WARNING - No data for factor QMJ in Intl
# 2025-04-20 13:22:21,721 - WARNING - No data for factor TSM-EQ in Intl
# 2025-04-20 13:22:21,732 - WARNING - Error loading factors for EZU (Equity_Intl_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:21,734 - WARNING - Error loading factors for EZU (Equity_Intl_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:21,736 - WARNING - Error loading factors for EZU (Equity_Intl_4): List argument must consist only of tuples or dictionaries
# Processing International:  20%|██        | 2/10 [00:01<00:05,  1.41it/s]2025-04-20 13:22:22,633 - WARNING - Error loading factors for EUDG (Equity_Intl_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:22,634 - WARNING - Error loading factors for EUDG (Equity_Intl_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:22,636 - WARNING - Error loading factors for EUDG (Equity_Intl_4): List argument must consist only of tuples or dictionaries
# Processing International:  30%|███       | 3/10 [00:02<00:05,  1.23it/s]2025-04-20 13:22:23,578 - WARNING - Error loading factors for IEV (Equity_Intl_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:23,579 - WARNING - Error loading factors for IEV (Equity_Intl_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:23,582 - WARNING - Error loading factors for IEV (Equity_Intl_4): List argument must consist only of tuples or dictionaries
# Processing International:  40%|████      | 4/10 [00:03<00:05,  1.15it/s]2025-04-20 13:22:24,527 - WARNING - Error loading factors for EWN (Equity_Intl_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:24,528 - WARNING - Error loading factors for EWN (Equity_Intl_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:24,530 - WARNING - Error loading factors for EWN (Equity_Intl_4): List argument must consist only of tuples or dictionaries
# Processing International:  50%|█████     | 5/10 [00:04<00:04,  1.14it/s]2025-04-20 13:22:25,427 - WARNING - Error loading factors for JCHI (Equity_Intl_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:25,429 - WARNING - Error loading factors for JCHI (Equity_Intl_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:25,430 - WARNING - Error loading factors for JCHI (Equity_Intl_4): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:25,456 - WARNING - Fund JCHI (Equity_Intl_1, window=24m) skipped: 21 months available
# 2025-04-20 13:22:25,457 - WARNING - Fund JCHI (Equity_Intl_1, window=36m) skipped: 21 months available
# 2025-04-20 13:22:25,458 - WARNING - Fund JCHI (Equity_Intl_1, window=48m) skipped: 21 months available
# 2025-04-20 13:22:25,459 - WARNING - Fund JCHI (Equity_Intl_1, window=60m) skipped: 21 months available
# 2025-04-20 13:22:25,462 - WARNING - Error loading factors for DXJ (Equity_Intl_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:25,463 - WARNING - Error loading factors for DXJ (Equity_Intl_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:25,465 - WARNING - Error loading factors for DXJ (Equity_Intl_4): List argument must consist only of tuples or dictionaries
# Processing International:  70%|███████   | 7/10 [00:05<00:02,  1.48it/s]2025-04-20 13:22:26,381 - WARNING - Error loading factors for CQQQ (Equity_Intl_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:26,383 - WARNING - Error loading factors for CQQQ (Equity_Intl_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:26,385 - WARNING - Error loading factors for CQQQ (Equity_Intl_4): List argument must consist only of tuples or dictionaries
# Processing International:  80%|████████  | 8/10 [00:05<00:01,  1.36it/s]2025-04-20 13:22:27,293 - WARNING - Error loading factors for PCY (FI_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:27,295 - WARNING - Error loading factors for PCY (FI_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:27,297 - WARNING - Error loading factors for PCY (FI_4): List argument must consist only of tuples or dictionaries
# Processing International:  90%|█████████ | 9/10 [00:06<00:00,  1.24it/s]2025-04-20 13:22:28,276 - WARNING - Error loading factors for EGIIX (Equity_Intl_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:28,278 - WARNING - Error loading factors for EGIIX (Equity_Intl_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:28,279 - WARNING - Error loading factors for EGIIX (Equity_Intl_4): List argument must consist only of tuples or dictionaries
# Processing International: 100%|██████████| 10/10 [00:07<00:00,  1.27it/s]
# Processing USA:   0%|          | 0/10 [00:00<?, ?it/s]2025-04-20 13:22:29,399 - WARNING - Error loading factors for EDOW (Equity_USA_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:29,401 - WARNING - Error loading factors for EDOW (Equity_USA_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:29,403 - WARNING - Error loading factors for EDOW (Equity_USA_4): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:29,412 - WARNING - No data for factor TSM-FI in USA
# 2025-04-20 13:22:29,416 - WARNING - No data for factor TSM-FX in USA
# 2025-04-20 13:22:29,421 - WARNING - No data for factor excess_return_eqwt in USA
# 2025-04-20 13:22:29,440 - WARNING - No data for factor TSM-Com in USA
# 2025-04-20 13:22:29,464 - WARNING - No data for factor TSM-Com in USA
# 2025-04-20 13:22:29,466 - WARNING - No data for factor TSM-FI in USA
# 2025-04-20 13:22:29,468 - WARNING - No data for factor TSM-FX in USA
# Processing USA:  10%|█         | 1/10 [00:02<00:20,  2.33s/it]2025-04-20 13:22:31,701 - WARNING - Error loading factors for SPHB (Equity_USA_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:31,703 - WARNING - Error loading factors for SPHB (Equity_USA_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:31,705 - WARNING - Error loading factors for SPHB (Equity_USA_4): List argument must consist only of tuples or dictionaries
# Processing USA:  20%|██        | 2/10 [00:05<00:24,  3.07s/it]2025-04-20 13:22:35,285 - WARNING - Error loading factors for FRTY (Equity_USA_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:35,287 - WARNING - Error loading factors for FRTY (Equity_USA_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:35,289 - WARNING - Error loading factors for FRTY (Equity_USA_4): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:35,440 - WARNING - Fund FRTY (Equity_USA_1, window=48m) skipped: 45 months available
# 2025-04-20 13:22:35,441 - WARNING - Fund FRTY (Equity_USA_1, window=60m) skipped: 45 months available
# 2025-04-20 13:22:35,573 - WARNING - Fund FRTY (Equity_USA_5, window=48m) skipped: 45 months available
# 2025-04-20 13:22:35,573 - WARNING - Fund FRTY (Equity_USA_5, window=60m) skipped: 45 months available
# 2025-04-20 13:22:35,710 - WARNING - Fund FRTY (Equity_USA_6, window=48m) skipped: 45 months available
# 2025-04-20 13:22:35,711 - WARNING - Fund FRTY (Equity_USA_6, window=60m) skipped: 45 months available
# 2025-04-20 13:22:35,856 - WARNING - Fund FRTY (Equity_USA_7, window=48m) skipped: 45 months available
# 2025-04-20 13:22:35,857 - WARNING - Fund FRTY (Equity_USA_7, window=60m) skipped: 45 months available
# Processing USA:  30%|███       | 3/10 [00:06<00:13,  1.93s/it]2025-04-20 13:22:35,867 - WARNING - Error loading factors for SHYD (FI_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:35,869 - WARNING - Error loading factors for SHYD (FI_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:35,872 - WARNING - Error loading factors for SHYD (FI_4): List argument must consist only of tuples or dictionaries
# Processing USA:  40%|████      | 4/10 [00:07<00:09,  1.55s/it]2025-04-20 13:22:36,837 - WARNING - Error loading factors for RATE (FI_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:36,839 - WARNING - Error loading factors for RATE (FI_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:36,841 - WARNING - Error loading factors for RATE (FI_4): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:36,895 - WARNING - Fund RATE (FI_1, window=36m) skipped: 30 months available
# 2025-04-20 13:22:36,896 - WARNING - Fund RATE (FI_1, window=48m) skipped: 30 months available
# 2025-04-20 13:22:36,897 - WARNING - Fund RATE (FI_1, window=60m) skipped: 30 months available
# 2025-04-20 13:22:36,904 - WARNING - Error loading factors for LIAM (FI_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:36,906 - WARNING - Error loading factors for LIAM (FI_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:36,908 - WARNING - Error loading factors for LIAM (FI_4): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:36,909 - WARNING - Fund LIAM (FI_1, window=12m) skipped: 4 months available
# 2025-04-20 13:22:36,910 - WARNING - Fund LIAM (FI_1, window=24m) skipped: 4 months available
# 2025-04-20 13:22:36,911 - WARNING - Fund LIAM (FI_1, window=36m) skipped: 4 months available
# 2025-04-20 13:22:36,912 - WARNING - Fund LIAM (FI_1, window=48m) skipped: 4 months available
# 2025-04-20 13:22:36,913 - WARNING - Fund LIAM (FI_1, window=60m) skipped: 4 months available
# 2025-04-20 13:22:36,915 - WARNING - Error loading factors for FEGIX (Equity_USA_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:36,918 - WARNING - Error loading factors for FEGIX (Equity_USA_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:36,920 - WARNING - Error loading factors for FEGIX (Equity_USA_4): List argument must consist only of tuples or dictionaries
# Processing USA:  70%|███████   | 7/10 [00:11<00:03,  1.32s/it]2025-04-20 13:22:40,388 - WARNING - Error loading factors for JIMIX (FI_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:40,392 - WARNING - Error loading factors for JIMIX (FI_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:40,394 - WARNING - Error loading factors for JIMIX (FI_4): List argument must consist only of tuples or dictionaries
# Processing USA:  80%|████████  | 8/10 [00:12<00:02,  1.25s/it]2025-04-20 13:22:41,385 - WARNING - Error loading factors for ORDNX (FI_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:41,387 - WARNING - Error loading factors for ORDNX (FI_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:41,390 - WARNING - Error loading factors for ORDNX (FI_4): List argument must consist only of tuples or dictionaries
# Processing USA:  90%|█████████ | 9/10 [00:12<00:01,  1.18s/it]2025-04-20 13:22:42,370 - WARNING - Error loading factors for PMTPX (FI_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:42,373 - WARNING - Error loading factors for PMTPX (FI_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 13:22:42,375 - WARNING - Error loading factors for PMTPX (FI_4): List argument must consist only of tuples or dictionaries
# Processing USA: 100%|██████████| 10/10 [00:14<00:00,  1.40s/it]

# %%
#chat gpt help

# %%
#this attempts to find the version inbetween above, and below when the code worked reasonably well except century factors

# %%
import pandas as pd
import numpy as np
import os
import random
import logging
from datetime import timedelta, datetime
from dateutil.relativedelta import relativedelta
from concurrent.futures import ProcessPoolExecutor
from sqlalchemy import create_engine
from tqdm import tqdm
import statsmodels.api as sm
import time
import sys
from contextlib import contextmanager
from functools import wraps

# Section 1: Configuration and Logging
CONFIG = {
    "database": {
        "server": "JULIANS_LAPTOP\\SQLEXPRESS",
        "database": "CWA_Fund_Database",
        "driver": "ODBC Driver 18 for SQL Server"
    },
    "return_metric": "1 Month Return",
    "rolling_periods": [12, 24, 36, 48, 60],
    "dry_run": True,
    "sample_dry_run": True,
    "sample_size": 10,
    "chunk_size": 5600,
    "batch_insert_size": 10000,
    "max_workers_cpu": 16,  # Optimized for 16-core i9 Ultra
    "batch_size": 100,  # Process 100 funds per batch
}

CONNECTION_STRING = (
    f"mssql+pyodbc://{CONFIG['database']['server']}/{CONFIG['database']['database']}"
    f"?driver={CONFIG['database']['driver']}&trusted_connection=yes&TrustServerCertificate=yes"
)
engine = create_engine(CONNECTION_STRING, pool_size=20, max_overflow=10)

RETURN_METRIC = CONFIG["return_metric"]
ROLLING_PERIODS = CONFIG["rolling_periods"]
DRY_RUN = CONFIG["dry_run"]
SAMPLE_DRY_RUN = CONFIG["sample_dry_run"]
SAMPLE_SIZE = CONFIG["sample_size"]
CHUNK_SIZE = CONFIG["chunk_size"]
BATCH_INSERT_SIZE = CONFIG["batch_insert_size"]
MAX_WORKERS_CPU = CONFIG["max_workers_cpu"]
BATCH_SIZE = CONFIG["batch_size"]

# Logging setup
SUMMARY_LOG = "factor_attribution_summary.log"
logging.basicConfig(
    level=logging.WARNING,  # WARNING for production, DEBUG for targeted sections
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler("factor_attribution.log"),
        logging.StreamHandler(sys.stdout)
    ],
    force=True
)
logger = logging.getLogger()

def log_summary(message):
    with open(SUMMARY_LOG, 'a') as f:
        f.write(f"{datetime.now()}: {message}\n")

# Section 2: Helper Functions
def category_to_region(category):
    mapping = {
        "US Equity Large Cap Blend": ("USA", "US Equity Large Cap Blend"),
        "US Equity Large Cap Growth": ("USA", "US Equity Large Cap Growth"),
        "US Equity Large Cap Value": ("USA", "US Equity Large Cap Value"),
        "US Equity Mid Cap": ("USA", "US Equity Mid Cap"),
        "US Equity Small Cap": ("USA", "US Equity Small Cap"),
        "Global Equity Large Cap": ("Global", "Global Equity Large Cap"),
        "Global Equity Mid/Small Cap": ("Global", "Global Equity Mid/Small Cap"),
        "Global Emerging Markets Equity": ("Global", "Global Emerging Markets Equity"),
        "Europe Equity Large Cap": ("International", "Europe Equity Large Cap"),
        "Asia Equity": ("International", "Asia Equity"),
        "Japan Equity": ("International", "Japan Equity"),
        "Emerging Markets Fixed Income": ("International", "Emerging Markets Fixed Income"),
        "US Fixed Income": ("USA", "US Fixed Income"),
        "US Municipal Fixed Income": ("USA", "US Municipal Fixed Income"),
        "Global Fixed Income": ("Global", "Global Fixed Income"),
        "Flexible Allocation": ("Global", "Flexible Allocation"),
        "Aggressive Allocation": ("Global", "Aggressive Allocation"),
        "Moderate Allocation": ("Global", "Moderate Allocation"),
        "Cautious Allocation": ("Global", "Cautious Allocation"),
        "Commodities Broad Basket": ("Global", "Commodities Broad Basket"),
        "Commodities Specified": ("Global", "Commodities Specified"),
        "Options Trading": ("USA", "Options Trading"),
        "Multialternative": ("Global", "Multialternative"),
        "Market Neutral": ("Global", "Market Neutral"),
        "Long/Short Equity": ("Global", "Long/Short Equity"),
        "Alternative Miscellaneous": ("Global", "Alternative Miscellaneous"),
        "Energy Sector Equity": ("USA", "Energy Sector Equity"),
        "Equity Miscellaneous": ("USA", "Equity Miscellaneous"),
        "Financials Sector Equity": ("USA", "Financials Sector Equity"),
        "Healthcare Sector Equity": ("USA", "Healthcare Sector Equity"),
        "Consumer Goods & Services Sector Equity": ("USA", "Consumer Goods & Services Sector Equity"),
        "Communications Sector Equity": ("USA", "Communications Sector Equity"),
        "Industrials Sector Equity": ("USA", "Industrials Sector Equity"),
        "Other Sector Equity": ("USA", "Other Sector Equity"),
        "Real Estate Sector Equity": ("USA", "Real Estate Sector Equity"),
        "Precious Metals Sector Equity": ("USA", "Precious Metals Sector Equity"),
        "Technology Sector Equity": ("USA", "Technology Sector Equity"),
        "Utilities Sector Equity": ("USA", "Utilities Sector Equity"),
        "Natural Resources Sector Equity": ("USA", "Natural Resources Sector Equity"),
        "Infrastructure Sector Equity": ("USA", "Infrastructure Sector Equity"),
        "Trading Tools": ("USA", "Trading Tools"),
        "Asia ex-Japan Equity": ("International", "Asia ex-Japan Equity"),
        "Australia & New Zealand Equity": ("International", "Australia & New Zealand Equity"),
        "Canadian Equity Large Cap": ("International", "Canadian Equity Large Cap"),
        "Europe Equity Mid/Small Cap": ("International", "Europe Equity Mid/Small Cap"),
        "Greater China Equity": ("International", "Greater China Equity"),
        "India Equity": ("International", "India Equity"),
        "Mexico Equity": ("International", "Mexico Equity"),
        "Korea Equity": ("International", "Korea Equity"),
        "Latin America Equity": ("International", "Latin America Equity"),
        "UK Equity Large Cap": ("International", "UK Equity Large Cap"),
        "Thailand Equity": ("International", "Thailand Equity"),
        "Convertibles": ("USA", "Convertibles"),
        "Fixed Income Miscellaneous": ("USA", "Fixed Income Miscellaneous"),
        "Allocation Miscellaneous": ("Global", "Allocation Miscellaneous")
    }
    return mapping.get(category, ("USA", "Unknown"))

@contextmanager
def database_transaction():
    with engine.connect() as connection:
        transaction = connection.begin()
        try:
            yield connection
            transaction.commit()
        except Exception as e:
            transaction.rollback()
            logger.error(f"Transaction failed: {e}")
            raise

def timer(func):
    @wraps(func)
    def wrapper(*args, **kwargs):
        start_time = time.time()
        logger.debug(f"Starting {func.__name__}")
        result = func(*args, **kwargs)
        logger.info(f"{func.__name__} took {time.time() - start_time:.2f} seconds")
        return result
    return wrapper

# Section 3: Data Loading
FACTOR_CACHE = {}

@timer
def load_db_factors(factor_list, region="Global", table="factor_returns", asset_class=None):
    # Adding basic caching mechanism
    cache_key = (tuple(factor_list), region, table, asset_class)
    if cache_key in FACTOR_CACHE:
        logger.debug(f"Using cached factors for {cache_key}")
        return FACTOR_CACHE[cache_key]
    
    factor_dfs = []
    for factor in factor_list:
        query = f"""
            SELECT Date, Factor, Value, region
            FROM {table}
            WHERE Factor = '{factor}'
            AND Date >= '2015-01-01'
            AND UPPER(region) = UPPER('{region}')
        """
        if factor == 'RF':
            query = query.replace(f"region = '{region}'", "region = 'USA'")
        if asset_class:
            query += f" AND asset_class = '{asset_class}'"
        logger.debug(f"Executing query: {query}")
        df = pd.read_sql_query(query, engine, parse_dates=['Date'])
        if df.empty:
            logger.warning(f"No data for factor {factor} in {region}")
            continue
        if df[['Date', 'Factor']].duplicated().any():
            logger.error(f"Non-unique Date-Factor pairs for {factor}: {df[df[['Date', 'Factor']].duplicated()]}")
            return pd.DataFrame()
        factor_dfs.append(df)
    
    if not factor_dfs:
        logger.warning(f"No data for factors {factor_list} in {table} (region: {region})")
        return pd.DataFrame()
    
    df = pd.concat(factor_dfs)
    logger.debug(f"Raw factor data shape: {df.shape}, sample:\n{df.head()}")
    
    pivoted_df = df.pivot(index="Date", columns="Factor", values="Value")
    pivoted_df.index = pd.to_datetime(pivoted_df.index) + pd.offsets.MonthEnd(0)
    pivoted_df = pivoted_df[~pivoted_df.index.duplicated(keep='first')]
    pivoted_df = pivoted_df.asfreq('ME')
    FACTOR_CACHE[cache_key] = pivoted_df
    return pivoted_df

@timer
def load_century_factors(factor_list, portfolio_base, asset_class=None, region="Global"):
    factor_in_clause = ','.join([f"'{f}'" for f in factor_list])
    query = f"""
        SELECT date AS Date, factor AS Factor, value AS Value, portfolio
        FROM aqr_century_factors
        WHERE factor IN ({factor_in_clause})
        AND portfolio = ?
        AND date >= '2015-01-01'
    """
    params = [portfolio_base]
    if asset_class:
        query += " AND asset_class = ?"
        params.append(asset_class)
    if region != "Global":
        query += " AND region = ?"
        params.append(region)
    logger.debug(f"Executing query: {query}, params: {params}")
    df = pd.read_sql(query, engine, params=params, parse_dates=['Date'])
    if df.empty:
        logger.warning(f"No data for factors {factor_list} in aqr_century_factors (portfolio: {portfolio_base}, region: {region})")
        return pd.DataFrame()
    if df[['Date', 'Factor']].duplicated().any():
        logger.error(f"Non-unique Date-Factor pairs in aqr_century_factors: {df[df[['Date', 'Factor']].duplicated()]}")
        return pd.DataFrame()
    logger.debug(f"Raw century factors shape: {df.shape}, portfolio: {df['portfolio'].unique()}, sample:\n{df.head()}")
    pivoted_df = df.pivot(index="Date", columns="Factor", values="Value")
    pivoted_df.index = pd.to_datetime(pivoted_df.index) + pd.offsets.MonthEnd(0)
    pivoted_df = pivoted_df[~pivoted_df.index.duplicated(keep='first')]
    pivoted_df = pivoted_df.asfreq('ME')
    if pivoted_df.empty or pivoted_df.shape[1] == 0:
        logger.warning(f"Empty pivoted data for factors {factor_list} (portfolio: {portfolio_base})")
        return pd.DataFrame()
    return pivoted_df

# Section 4: Fund Processing
category_to_regressions = {
    "Energy Sector Equity": "Equity_USA",
    "Equity Miscellaneous": "Equity_USA",
    "Financials Sector Equity": "Equity_USA",
    "Healthcare Sector Equity": "Equity_USA",
    "Consumer Goods & Services Sector Equity": "Equity_USA",
    "Communications Sector Equity": "Equity_USA",
    "Industrials Sector Equity": "Equity_USA",
    "Other Sector Equity": "Equity_USA",
    "Real Estate Sector Equity": "Equity_USA",
    "Precious Metals Sector Equity": "Equity_USA",
    "Technology Sector Equity": "Equity_USA",
    "Utilities Sector Equity": "Equity_USA",
    "US Equity Large Cap Blend": "Equity_USA",
    "US Equity Large Cap Growth": "Equity_USA",
    "US Equity Large Cap Value": "Equity_USA",
    "US Equity Mid Cap": "Equity_USA",
    "US Equity Small Cap": "Equity_USA",
    "Options Trading": "Equity_USA",
    "Natural Resources Sector Equity": "Equity_USA",
    "Infrastructure Sector Equity": "Equity_USA",
    "Asia ex-Japan Equity": "Equity_Intl",
    "Australia & New Zealand Equity": "Equity_Intl",
    "Canadian Equity Large Cap": "Equity_Intl",
    "Europe Equity Large Cap": "Equity_Intl",
    "Europe Equity Mid/Small Cap": "Equity_Intl",
    "Greater China Equity": "Equity_Intl",
    "India Equity": "Equity_Intl",
    "Mexico Equity": "Equity_Intl",
    "Japan Equity": "Equity_Intl",
    "Korea Equity": "Equity_Intl",
    "Latin America Equity": "Equity_Intl",
    "UK Equity Large Cap": "Equity_Intl",
    "Thailand Equity": "Equity_Intl",
    "Global Emerging Markets Equity": "Equity_Global",
    "Global Equity Large Cap": "Equity_Global",
    "Global Equity Mid/Small Cap": "Equity_Global",
    "Global Fixed Income": "Fixed_Income",
    "Convertibles": "Fixed_Income",
    "Emerging Markets Fixed Income": "Fixed_Income",
    "Fixed Income Miscellaneous": "Fixed_Income",
    "US Fixed Income": "Fixed_Income",
    "US Municipal Fixed Income": "Fixed_Income",
    "Aggressive Allocation": "Allocation",
    "Allocation Miscellaneous": "Allocation",
    "Cautious Allocation": "Allocation",
    "Flexible Allocation": "Allocation",
    "Moderate Allocation": "Allocation",
    "Alternative Miscellaneous": "Alternative",
    "Long/Short Equity": "Alternative",
    "Market Neutral": "Alternative",
    "Multialternative": "Alternative",
    "Commodities Broad Basket": "Commodity",
    "Commodities Specified": "Commodity"
}

regression_sets = {
    "Equity_USA": [
        ("Equity_USA_1", ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB'], "USA", None),
        ("Equity_USA_2", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "USA", "US Stock Selection"),
        ("Equity_USA_3", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "USA", "All Macro"),
        ("Equity_USA_4", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "USA", "Equity indices"),
        ("Equity_USA_5", ['MKT', 'BAB', 'TSM-FI', 'TSM-FX', 'excess_return_eqwt'], "USA", None),
        ("Equity_USA_6", ['MKT', 'SMB', 'BAB', 'TSM-Com'], "USA", None),
        ("Equity_USA_7", ['MKT', 'HML_Devil', 'QMJ', 'UMD', 'SMB', 'BAB', 'TSM-Com', 'TSM-FI', 'TSM-FX'], "USA", None)
    ],
    "Equity_Intl": [
        ("Equity_Intl_1", ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB'], "Intl", None),
        ("Equity_Intl_2", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "International", "Intl Stock Selection"),
        ("Equity_Intl_3", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "International", "All Macro"),
        ("Equity_Intl_4", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "International", "Equity indices")
    ],
    "Equity_Global": [
        ("Equity_Global_1", ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB'], "Global", None),
        ("Equity_Global_2", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "All Stock Selection"),
        ("Equity_Global_3", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "All Macro"),
        ("Equity_Global_4", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "Equity indices")
    ],
    "Fixed_Income": [
        ("FI_1", ['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY', 'TSM-FI', 'TSM-FX'], "Global", None),
        ("FI_2", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "Fixed income"),
        ("FI_3", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "All Macro"),
        ("FI_4", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "Equity indices")
    ],
    "Allocation": [
        ("Allocation_1", ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ', 'TSM-FI'], "Global", None),
        ("Allocation_2", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "All Stock Selection"),
        ("Allocation_3", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "All Macro"),
        ("Allocation_4", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "Equity indices")
    ],
    "Alternative": [
        ("Alternative_1", ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ', 'TSM-FI', 'TSM-Com', 'TSM-FX'], "Global", None),
        ("Allocation_2", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "All Stock Selection"),
        ("Allocation_3", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "All Macro"),
        ("Allocation_4", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "Equity indices")
    ],
    "Commodity": [
        ("Commodity_1", ['excess_return_eqwt', 'excess_spot_return_eqwt', 'ir_adjusted_carry_eqwt', 'spot_return_eqwt', 'carry_eqwt', 'excess_return_long_short', 'excess_spot_return_long_short', 'ir_adjusted_carry_long_short', 'aggregate_backwardation_contango'], "Global", None)
    ]
}

# Section 5: Fund Processing & Database Insertion remains the same...
# Section 5: Fund Processing


def process_fund(fund_data):
    records = []
    symbol = fund_data["SymbolCUSIP"]
    category = fund_data["Global_Category_Name"]
    returns = pd.Series(fund_data["returns"]).dropna()
    
    if returns.empty:
        logger.warning(f"No valid returns for {symbol}")
        return records
    
    regression_category = category_to_regressions.get(category, "Allocation")
    if regression_category == "Allocation" and category not in category_to_regressions:
        logger.warning(f"Unmapped category {category} for {symbol}; using Allocation")
    
    factor_data_cache = {}
    for reg_name, factors, region, portfolio_base in regression_sets[regression_category]:
        try:
            logger.debug(f"Loading factors for {symbol} ({reg_name}): factors {factors}, region {region}, portfolio_base {portfolio_base}")
            if any(f in factors for f in ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value']):
                if not portfolio_base:
                    logger.warning(f"Skipping {reg_name} for {symbol}: portfolio_base missing")
                    continue
                factor_data = load_century_factors(factors, portfolio_base, region=region)
            elif reg_name.startswith("Commodity"):
                factor_data = load_commodity_factors()
            elif reg_name.startswith("FI"):
                fi_factors = [f for f in factors if f in ['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY']]
                other_factors = [f for f in factors if f not in fi_factors]
                factor_data = pd.concat([
                    load_db_factors(other_factors, region) if other_factors else pd.DataFrame(index=returns.index),
                    load_fixed_income_factors(fi_factors) if fi_factors else pd.DataFrame(index=returns.index)
                ], axis=1).dropna()
            else:
                factor_data = load_db_factors(factors, region)
            if not isinstance(factor_data, pd.DataFrame):
                logger.error(f"Invalid factor data type for {reg_name} ({symbol}): {type(factor_data)}")
                continue
            if factor_data.empty or factor_data.shape[1] == 0:
                logger.warning(f"Empty factor data for {reg_name} ({symbol}): factors {factors}")
                continue
            logger.debug(f"Factor data for {reg_name} ({symbol}): shape {factor_data.shape}, columns {factor_data.columns.tolist()}")
            factor_data = factor_data[factor_data.index >= '2015-01-01']
            factor_data_cache[(reg_name, region)] = factor_data
        except Exception as e:
            logger.warning(f"Error loading factors for {symbol} ({reg_name}): {str(e)}")
            continue
    
    for reg_name, factors, region, portfolio_base in regression_sets[regression_category]:
        factor_data = factor_data_cache.get((reg_name, region))
        if factor_data is None:
            continue
        for window in ROLLING_PERIODS:
            records.extend(run_rolling_regression(symbol, returns, factor_data, "OLS", reg_name, window))
    
    logger.info(f"Generated {len(records)} regression records for {symbol}")
    return records

def process_region(region, fund_data_list):
    records = []
    errors = 0
    logger.info(f"Processing {len(fund_data_list)} funds in {region}")
    
    if SAMPLE_DRY_RUN:
        # Sequential processing for debugging
        for fund_data in tqdm(fund_data_list, total=len(fund_data_list), desc=f"Processing {region}", file=sys.stdout):
            try:
                records.extend(process_fund(fund_data))
            except Exception as e:
                logger.error(f"Error processing {fund_data['SymbolCUSIP']}: {str(e)}")
                errors += 1
    else:
        # Parallel processing for production
        for i in range(0, len(fund_data_list), BATCH_SIZE):
            batch = fund_data_list[i:i + BATCH_SIZE]
            with ProcessPoolExecutor(max_workers=MAX_WORKERS_CPU) as executor:
                future_to_fund = {
                    executor.submit(process_fund, fund_data): fund_data["SymbolCUSIP"]
                    for fund_data in batch
                }
                for future in tqdm(future_to_fund, total=len(batch), desc=f"Processing {region} batch", file=sys.stdout):
                    try:
                        records.extend(future.result())
                    except Exception as e:
                        logger.error(f"Error processing {future_to_fund[future]}: {str(e)}")
                        errors += 1
    
    logger.info(f"Region {region} generated {len(records)} total records with {errors} errors")
    log_summary(f"Region {region}: {len(fund_data_list)} funds, {len(records)} records, {errors} errors")
    if not DRY_RUN:
        insert_batch(records)
    
    return records, errors

# Section 6: Database Output
def insert_batch(records):
    if DRY_RUN:
        logger.info(f"Dry run: Would insert {len(records)} records")
        return
    try:
        df = pd.DataFrame(records)
        with database_transaction() as connection:
            df.to_sql("AQRR_Factor_Attribution", connection, if_exists="append", index=False, method="multi")
        logger.info(f"Inserted {len(df)} records to database")
    except Exception as e:
        logger.error(f"Error inserting batch: {e}")
        raise

# Section 7: Main Pipeline
@timer
def main():
    logger.info("Starting main pipeline")
    log_summary("Pipeline started")
    try:
        fund_meta = load_fund_metadata()
    except Exception as e:
        logger.error(f"Failed to load metadata: {e}")
        log_summary(f"Error: Failed to load metadata: {e}")
        return {"error": str(e)}
    
    regions = fund_meta["Region"].unique()
    logger.info(f"Total funds: {len(fund_meta)}, Regions: {regions}")
    log_summary(f"Total funds: {len(fund_meta)}, Regions: {regions}")
    
    fund_ids = fund_meta["SymbolCUSIP"].tolist()
    if SAMPLE_DRY_RUN:
        fund_ids = random.sample(fund_ids, min(SAMPLE_SIZE, len(fund_ids)))
        logger.info(f"Sampled {len(fund_ids)} funds")
        log_summary(f"Sampled {len(fund_ids)} funds")
    
    summary = {"total_funds": len(fund_ids), "regions": {}, "errors": 0}
    for region in sorted(set(regions) - {'Unknown'} | {'USA'}):
        region_fund_ids = fund_meta[fund_meta["Region"] == region]["SymbolCUSIP"].tolist()
        if not region_fund_ids:
            logger.warning(f"No SymbolCUSIP found for region {region}")
            summary["regions"][region] = {"funds_processed": 0, "records": 0, "errors": 0}
            continue
        if SAMPLE_DRY_RUN:
            region_fund_ids = random.sample(region_fund_ids, min(SAMPLE_SIZE, len(region_fund_ids)))
            logger.info(f"Sampled {len(region_fund_ids)} SymbolCUSIP for {region}")
        
        try:
            returns = load_fund_returns(region_fund_ids)
        except Exception as e:
            logger.error(f"Failed to load returns for {region}: {e}")
            log_summary(f"Error: Failed to load returns for {region}: {e}")
            summary["regions"][region] = {"funds_processed": 0, "records": 0, "errors": 1}
            summary["errors"] += 1
            continue
        
        region_funds = [
            {
                "SymbolCUSIP": row["SymbolCUSIP"],
                "Global_Category_Name": row["Global_Category_Name"],
                "CWA_Broad_Category_Name": row.get("CWA_Broad_Category_Name", None),
                "returns": returns[row["SymbolCUSIP"]].to_dict()
            }
            for _, row in fund_meta.iterrows() if row["SymbolCUSIP"] in returns.columns
        ]
        if not region_funds:
            logger.warning(f"No valid returns data for {region}")
            summary["regions"][region] = {"funds_processed": 0, "records": 0, "errors": 0}
            continue
        
        records, errors = process_region(region, region_funds)
        summary["regions"][region] = {"funds_processed": len(region_funds), "records": len(records), "errors": errors}
        summary["errors"] += errors
    
    logger.info(f"Pipeline summary: {summary}")
    log_summary(f"Pipeline completed: {summary}")
    return summary

if __name__ == "__main__":
    try:
        main()
    except Exception as e:
        logger.error(f"Main execution failed: {e}")
        raise
# Out:
# 2025-04-21 15:47:04,802 - ERROR - Failed to load metadata: name 'load_fund_metadata' is not defined

# %%
#this was the last code before we swapt to a "new" and things broke

# %%
import pandas as pd
import numpy as np
import os
import random
import logging
from datetime import timedelta, datetime
from dateutil.relativedelta import relativedelta
from concurrent.futures import ProcessPoolExecutor
from sqlalchemy import create_engine
from tqdm import tqdm
import statsmodels.api as sm
import time
import sys
from contextlib import contextmanager
from functools import wraps
from sqlalchemy import text


# Section 1: Configuration and Logging
CONFIG = {
    "database": {
        "server": "JULIANS_LAPTOP\\SQLEXPRESS",
        "database": "CWA_Fund_Database",
        "driver": "ODBC Driver 18 for SQL Server"
    },
    "return_metric": "1 Month Return",
    "rolling_periods": [12, 24, 36, 48, 60],
    "dry_run": True,
    "sample_dry_run": True,
    "sample_size": 10,
    "chunk_size": 5600,
    "batch_insert_size": 10000,
    "max_workers_cpu": 16,  # Optimized for 16-core i9 Ultra
    "batch_size": 100,  # Process 100 funds per batch
}

CONNECTION_STRING = (
    f"mssql+pyodbc://{CONFIG['database']['server']}/{CONFIG['database']['database']}"
    f"?driver={CONFIG['database']['driver']}&trusted_connection=yes&TrustServerCertificate=yes"
)
engine = create_engine(CONNECTION_STRING, pool_size=20, max_overflow=10)

RETURN_METRIC = CONFIG["return_metric"]
ROLLING_PERIODS = CONFIG["rolling_periods"]
DRY_RUN = CONFIG["dry_run"]
SAMPLE_DRY_RUN = CONFIG["sample_dry_run"]
SAMPLE_SIZE = CONFIG["sample_size"]
CHUNK_SIZE = CONFIG["chunk_size"]
BATCH_INSERT_SIZE = CONFIG["batch_insert_size"]
MAX_WORKERS_CPU = CONFIG["max_workers_cpu"]
BATCH_SIZE = CONFIG["batch_size"]

# Logging setup
SUMMARY_LOG = "factor_attribution_summary.log"
logging.basicConfig(
    level=logging.WARNING,  # WARNING for production, DEBUG for targeted sections
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler("factor_attribution.log"),
        logging.StreamHandler(sys.stdout)
    ],
    force=True
)
logger = logging.getLogger()

def log_summary(message):
    with open(SUMMARY_LOG, 'a') as f:
        f.write(f"{datetime.now()}: {message}\n")

# Section 2: Helper Functions
def category_to_region(category):
    mapping = {
        "US Equity Large Cap Blend": ("USA", "US Equity Large Cap Blend"),
        "US Equity Large Cap Growth": ("USA", "US Equity Large Cap Growth"),
        "US Equity Large Cap Value": ("USA", "US Equity Large Cap Value"),
        "US Equity Mid Cap": ("USA", "US Equity Mid Cap"),
        "US Equity Small Cap": ("USA", "US Equity Small Cap"),
        "Global Equity Large Cap": ("Global", "Global Equity Large Cap"),
        "Global Equity Mid/Small Cap": ("Global", "Global Equity Mid/Small Cap"),
        "Global Emerging Markets Equity": ("Global", "Global Emerging Markets Equity"),
        "Europe Equity Large Cap": ("International", "Europe Equity Large Cap"),
        "Asia Equity": ("International", "Asia Equity"),
        "Japan Equity": ("International", "Japan Equity"),
        "Emerging Markets Fixed Income": ("International", "Emerging Markets Fixed Income"),
        "US Fixed Income": ("USA", "US Fixed Income"),
        "US Municipal Fixed Income": ("USA", "US Municipal Fixed Income"),
        "Global Fixed Income": ("Global", "Global Fixed Income"),
        "Flexible Allocation": ("Global", "Flexible Allocation"),
        "Aggressive Allocation": ("Global", "Aggressive Allocation"),
        "Moderate Allocation": ("Global", "Moderate Allocation"),
        "Cautious Allocation": ("Global", "Cautious Allocation"),
        "Commodities Broad Basket": ("Global", "Commodities Broad Basket"),
        "Commodities Specified": ("Global", "Commodities Specified"),
        "Options Trading": ("USA", "Options Trading"),
        "Multialternative": ("Global", "Multialternative"),
        "Market Neutral": ("Global", "Market Neutral"),
        "Long/Short Equity": ("Global", "Long/Short Equity"),
        "Alternative Miscellaneous": ("Global", "Alternative Miscellaneous"),
        "Energy Sector Equity": ("USA", "Energy Sector Equity"),
        "Equity Miscellaneous": ("USA", "Equity Miscellaneous"),
        "Financials Sector Equity": ("USA", "Financials Sector Equity"),
        "Healthcare Sector Equity": ("USA", "Healthcare Sector Equity"),
        "Consumer Goods & Services Sector Equity": ("USA", "Consumer Goods & Services Sector Equity"),
        "Communications Sector Equity": ("USA", "Communications Sector Equity"),
        "Industrials Sector Equity": ("USA", "Industrials Sector Equity"),
        "Other Sector Equity": ("USA", "Other Sector Equity"),
        "Real Estate Sector Equity": ("USA", "Real Estate Sector Equity"),
        "Precious Metals Sector Equity": ("USA", "Precious Metals Sector Equity"),
        "Technology Sector Equity": ("USA", "Technology Sector Equity"),
        "Utilities Sector Equity": ("USA", "Utilities Sector Equity"),
        "Natural Resources Sector Equity": ("USA", "Natural Resources Sector Equity"),
        "Infrastructure Sector Equity": ("USA", "Infrastructure Sector Equity"),
        "Trading Tools": ("USA", "Trading Tools"),
        "Asia ex-Japan Equity": ("International", "Asia ex-Japan Equity"),
        "Australia & New Zealand Equity": ("International", "Australia & New Zealand Equity"),
        "Canadian Equity Large Cap": ("International", "Canadian Equity Large Cap"),
        "Europe Equity Mid/Small Cap": ("International", "Europe Equity Mid/Small Cap"),
        "Greater China Equity": ("International", "Greater China Equity"),
        "India Equity": ("International", "India Equity"),
        "Mexico Equity": ("International", "Mexico Equity"),
        "Korea Equity": ("International", "Korea Equity"),
        "Latin America Equity": ("International", "Latin America Equity"),
        "UK Equity Large Cap": ("International", "UK Equity Large Cap"),
        "Thailand Equity": ("International", "Thailand Equity"),
        "Convertibles": ("USA", "Convertibles"),
        "Fixed Income Miscellaneous": ("USA", "Fixed Income Miscellaneous"),
        "Allocation Miscellaneous": ("Global", "Allocation Miscellaneous")
    }
    return mapping.get(category, ("USA", "Unknown"))

@contextmanager
def database_transaction():
    with engine.connect() as connection:
        transaction = connection.begin()
        try:
            yield connection
            transaction.commit()
        except Exception as e:
            transaction.rollback()
            logger.error(f"Transaction failed: {e}")
            raise

def timer(func):
    @wraps(func)
    def wrapper(*args, **kwargs):
        start_time = time.time()
        logger.debug(f"Starting {func.__name__}")
        result = func(*args, **kwargs)
        logger.info(f"{func.__name__} took {time.time() - start_time:.2f} seconds")
        return result
    return wrapper

# Section 3: Data Loading
FACTOR_CACHE = {}


#Section4: Load Factors from Database
def load_DB_Factors(engine, region: str, factor_list: list) -> pd.DataFrame:
    """
    Loads factor returns from the correct database tables for a given region and factor list.

    Parameters:
        engine: SQLAlchemy engine
        region: 'Global', 'USA', or 'International'
        factor_list: List of factor names to retrieve

    Returns:
        DataFrame with columns: ['Date', 'Factor', 'Value']
    """
    import pandas as pd

    queries = []
    for factor in factor_list:
        query = f"""
            SELECT
                date AS Date,
                '{factor}' AS Factor,
                value AS Value
            FROM aqr_century_factors
            WHERE region = :region
              AND factor = :factor
        """
        queries.append((query, {"region": region, "factor": factor}))

    all_data = []
    with engine.begin() as conn:
        for sql_text, params in queries:
            df = pd.read_sql(sql_text, conn, params=params)
            if not df.empty:
                all_data.append(df)

    if not all_data:
        print(f"⚠️ No Century factor data returned for region: {region}")
        return pd.DataFrame()

    combined = pd.concat(all_data, ignore_index=True)
    combined["Date"] = pd.to_datetime(combined["Date"])
    return combined.sort_values(["Date", "Factor"]).reset_index(drop=True)


@timer
def load_century_factors(engine, factors, portfolio, region):
    import pandas as pd
    import sqlalchemy as sa
    from datetime import datetime

    placeholders = ",".join(["?"] * len(factors))
    query = f"""
        SELECT factor, portfolio, region, date, value
        FROM aqr_century_factors
        WHERE factor IN ({placeholders})
          AND portfolio LIKE ?
          AND region = ?
    """

    # Bind factors, like-pattern for portfolio, and region
    bind_params = factors + [f"{portfolio}%", region]

    with engine.begin() as conn:
        df = pd.read_sql_query(sa.text(query), conn, params=bind_params)

    if df.empty:
        print(f"⚠️ No data loaded from aqr_century_factors for: "
              f"region={region}, portfolio LIKE {portfolio}%, factors={factors}")
        return pd.DataFrame()

    df["date"] = pd.to_datetime(df["date"])
    df = df.pivot_table(index="date", columns="factor", values="value").sort_index()

    return df

@timer
def load_fund_metadata():
    query = """
    SELECT 
        f.SymbolCUSIP, 
        f.Region, 
        f.YC_Global_Category_ID, 
        c.Global_Category_Name,
        f.YC_Category_ID,
        y.Category_Name,
        f.CWA_Broad_Category_ID,
        b.CWA_Broad_Category_Name
    FROM Funds_to_Screen f
    JOIN YC_Global_Category_List c ON f.YC_Global_Category_ID = c.ID
    JOIN YC_Category_List y ON f.YC_Category_ID = y.ID
    LEFT JOIN CWA_Broad_Category_List b ON f.CWA_Broad_Category_ID = b.ID
    """
    df = pd.read_sql(query, engine)
    logger.info(f"Loaded metadata for {len(df)} funds")
    df[["Region", "FactorProfile"]] = df["Global_Category_Name"].map(category_to_region).apply(pd.Series)
    if df["CWA_Broad_Category_Name"].isnull().all():
        logger.warning("CWA_Broad_Category_Name missing; Equity regressions 5-7 will be skipped")
    return df.dropna(subset=["Region", "FactorProfile"])

@timer
def load_fund_returns(fund_ids=None):
    query = """
    SELECT SymbolCUSIP, Date, ReturnValue
    FROM Fund_Returns_Timeseries
    WHERE Metric = '1 Month Return' AND ReturnValue IS NOT NULL AND Date IS NOT NULL
    """
    if fund_ids:
        fund_ids = [fid for fid in fund_ids if isinstance(fid, str) and fid.strip()]
        if not fund_ids:
            logger.warning("No valid SymbolCUSIP provided")
            return pd.DataFrame()
        fund_ids_str = ",".join([f"'{fid}'" for fid in fund_ids])
        query += f" AND SymbolCUSIP IN ({fund_ids_str})"
    
    logger.debug(f"Executing query: {query}")
    chunks = []
    for chunk in pd.read_sql_query(query, engine, parse_dates=["Date"], chunksize=CHUNK_SIZE):
        logger.debug(f"Loaded chunk of {len(chunk)} rows")
        chunks.append(chunk)
    df = pd.concat(chunks) if chunks else pd.DataFrame()
    if df.empty:
        logger.warning(f"No returns data loaded for SymbolCUSIP: {fund_ids}")
        return pd.DataFrame()
    
    logger.info(f"Loaded returns for {len(df['SymbolCUSIP'].unique())} funds")
    pivoted = df.pivot(index="Date", columns="SymbolCUSIP", values="ReturnValue")
    pivoted.index = pd.to_datetime(pivoted.index) + pd.offsets.MonthEnd(0)
    pivoted.index = pivoted.index.drop_duplicates()
    pivoted = pivoted.asfreq('ME')
    for col in pivoted.columns:
        if not pd.api.types.is_numeric_dtype(pivoted[col]):
            logger.warning(f"Non-numeric returns for {col}; converting")
            pivoted[col] = pd.to_numeric(pivoted[col], errors='coerce')
    return pivoted

@timer
def load_commodity_factors():
    query = """
        SELECT date AS Date, 
               excess_return_eqwt, 
               excess_spot_return_eqwt, 
               ir_adjusted_carry_eqwt, 
               spot_return_eqwt, 
               carry_eqwt, 
               excess_return_long_short, 
               excess_spot_return_long_short, 
               ir_adjusted_carry_long_short, 
               aggregate_backwardation_contango
        FROM aqr_cmdty_factors
    """
    df = pd.read_sql(query, engine, parse_dates=['Date'])
    if df.empty:
        logger.warning("No commodity factors loaded")
        return pd.DataFrame()
    pivoted_df = df.set_index("Date")
    pivoted_df.index = pd.to_datetime(pivoted_df.index) + pd.offsets.MonthEnd(0)
    pivoted_df.index = pivoted_df.index.drop_duplicates()
    pivoted_df = pivoted_df.asfreq('ME')
    return pivoted_df

@timer
def load_fixed_income_factors(factor_list):
    factor_in_clause = ','.join([f"'{f}'" for f in factor_list])
    query = f"""
        SELECT Date, Factor_Name, ReturnValue
        FROM Fixed_Income_Factor_Returns
        WHERE Factor_Name IN ({factor_in_clause})
    """
    logger.debug(f"Executing query: {query}")
    df = pd.read_sql_query(query, engine, parse_dates=["Date"])
    if df.empty:
        logger.warning(f"No fixed income factors for {factor_list}")
        return pd.DataFrame()
    pivoted_df = df.pivot(index="Date", columns="Factor_Name", values="ReturnValue")
    pivoted_df.index = pd.to_datetime(pivoted_df.index) + pd.offsets.MonthEnd(0)
    pivoted_df.index = pivoted_df.index.drop_duplicates()
    pivoted_df = pivoted_df.asfreq('ME')
    return pivoted_df

# Section 4: Regression Processing
def run_rolling_regression(symbol, returns, factor_data, regression_type, regression_name, window_months):
    records = []
    months_needed = window_months
    
    returns = returns.sort_index()
    factor_data = factor_data.sort_index()
    
    available_dates = returns.index.intersection(factor_data.index)
    if len(available_dates) < months_needed:
        logger.warning(f"Fund {symbol} ({regression_name}, window={window_months}m) skipped: {len(available_dates)} months available")
        return records
    
    for end_date in available_dates[months_needed-1::1]:
        start_date = end_date - pd.offsets.MonthEnd(months_needed)
        if start_date < available_dates[0]:
            continue
        
        window_returns = returns.loc[start_date:end_date]
        window_factors = factor_data.loc[start_date:end_date]
        
        window_returns = window_returns.reindex(window_factors.index)
        
        if len(window_returns.dropna()) < months_needed * 0.8 or len(window_factors.dropna()) < months_needed * 0.8:
            logger.debug(f"Skipping regression for {symbol} ({regression_name}, window={window_months}m, end_date={end_date}): insufficient data")
            continue
        
        try:
            if regression_type == "OLS":
                X = sm.add_constant(window_factors)
                model = sm.OLS(window_returns, X, missing='drop').fit()
                coefficients = model.params.to_dict()
                tvalues = model.tvalues.to_dict()
                pvalues = model.pvalues.to_dict()
                r_squared = model.rsquared
                record = {
                    "SymbolCUSIP": symbol,
                    "RegressionName": regression_name,
                    "Window": f"{window_months}m",
                    "EndDate": end_date,
                    "R_Squared": r_squared
                }
                for factor in coefficients:
                    record[f"{factor}_beta"] = coefficients[factor]
                    record[f"{factor}_tvalue"] = tvalues.get(factor, None)
                    record[f"{factor}_pvalue"] = pvalues.get(factor, None)
                records.append(record)
        except Exception as e:
            logger.warning(f"Regression failed for {symbol} ({regression_name}, window={window_months}m, end_date={end_date}): {str(e)}")
            continue
    
    if not records:
        logger.info(f"No regressions completed for {symbol} ({regression_name}, window={window_months}m)")
    return records

# Section 5: Fund Processing
category_to_regressions = {
    "Energy Sector Equity": "Equity_USA",
    "Equity Miscellaneous": "Equity_USA",
    "Financials Sector Equity": "Equity_USA",
    "Healthcare Sector Equity": "Equity_USA",
    "Consumer Goods & Services Sector Equity": "Equity_USA",
    "Communications Sector Equity": "Equity_USA",
    "Industrials Sector Equity": "Equity_USA",
    "Other Sector Equity": "Equity_USA",
    "Real Estate Sector Equity": "Equity_USA",
    "Precious Metals Sector Equity": "Equity_USA",
    "Technology Sector Equity": "Equity_USA",
    "Utilities Sector Equity": "Equity_USA",
    "US Equity Large Cap Blend": "Equity_USA",
    "US Equity Large Cap Growth": "Equity_USA",
    "US Equity Large Cap Value": "Equity_USA",
    "US Equity Mid Cap": "Equity_USA",
    "US Equity Small Cap": "Equity_USA",
    "Options Trading": "Equity_USA",
    "Natural Resources Sector Equity": "Equity_USA",
    "Infrastructure Sector Equity": "Equity_USA",
    "Asia ex-Japan Equity": "Equity_Intl",
    "Australia & New Zealand Equity": "Equity_Intl",
    "Canadian Equity Large Cap": "Equity_Intl",
    "Europe Equity Large Cap": "Equity_Intl",
    "Europe Equity Mid/Small Cap": "Equity_Intl",
    "Greater China Equity": "Equity_Intl",
    "India Equity": "Equity_Intl",
    "Mexico Equity": "Equity_Intl",
    "Japan Equity": "Equity_Intl",
    "Korea Equity": "Equity_Intl",
    "Latin America Equity": "Equity_Intl",
    "UK Equity Large Cap": "Equity_Intl",
    "Thailand Equity": "Equity_Intl",
    "Global Emerging Markets Equity": "Equity_Global",
    "Global Equity Large Cap": "Equity_Global",
    "Global Equity Mid/Small Cap": "Equity_Global",
    "Global Fixed Income": "Fixed_Income",
    "Convertibles": "Fixed_Income",
    "Emerging Markets Fixed Income": "Fixed_Income",
    "Fixed Income Miscellaneous": "Fixed_Income",
    "US Fixed Income": "Fixed_Income",
    "US Municipal Fixed Income": "Fixed_Income",
    "Aggressive Allocation": "Allocation",
    "Allocation Miscellaneous": "Allocation",
    "Cautious Allocation": "Allocation",
    "Flexible Allocation": "Allocation",
    "Moderate Allocation": "Allocation",
    "Alternative Miscellaneous": "Alternative",
    "Long/Short Equity": "Alternative",
    "Market Neutral": "Alternative",
    "Multialternative": "Alternative",
    "Commodities Broad Basket": "Commodity",
    "Commodities Specified": "Commodity"
}

regression_sets = {
    "Equity_USA": [
        ("Equity_USA_1", ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB'], "USA", None),
        ("Equity_USA_2", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "USA", "US Stock Selection"),
        ("Equity_USA_3", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "USA", "All Macro"),
        ("Equity_USA_4", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "USA", "Equity indices"),
        ("Equity_USA_5", ['MKT', 'BAB', 'TSM-FI', 'TSM-FX', 'excess_return_eqwt'], "USA", None),
        ("Equity_USA_6", ['MKT', 'SMB', 'BAB', 'TSM-Com'], "USA", None),
        ("Equity_USA_7", ['MKT', 'HML_Devil', 'QMJ', 'UMD', 'SMB', 'BAB', 'TSM-Com', 'TSM-FI', 'TSM-FX'], "USA", None)
    ],
    "Equity_Intl": [
        ("Equity_Intl_1", ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB'], "Intl", None),
        ("Equity_Intl_2", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "International", "Intl Stock Selection"),
        ("Equity_Intl_3", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "International", "All Macro"),
        ("Equity_Intl_4", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "International", "Equity indices")
    ],
    "Equity_Global": [
        ("Equity_Global_1", ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'TSM-EQ', 'BAB'], "Global", None),
        ("Equity_Global_2", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "All Stock Selection"),
        ("Equity_Global_3", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "All Macro"),
        ("Equity_Global_4", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "Equity indices")
    ],
    "Fixed_Income": [
        ("FI_1", ['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY', 'TSM-FI', 'TSM-FX'], "Global", None),
        ("FI_2", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "Fixed income"),
        ("FI_3", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "All Macro"),
        ("FI_4", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "Equity indices")
    ],
    "Allocation": [
        ("Allocation_1", ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ', 'TSM-FI'], "Global", None),
        ("Allocation_2", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "All Stock Selection"),
        ("Allocation_3", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "All Macro"),
        ("Allocation_4", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "Equity indices")
    ],
    "Alternative": [
        ("Alternative_1", ['MKT', 'HML_Devil', 'QMJ', 'SMB', 'UMD', 'BAB', 'TSM-EQ', 'TSM-FI', 'TSM-Com', 'TSM-FX'], "Global", None),
        ("Allocation_2", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "All Stock Selection"),
        ("Allocation_3", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "All Macro"),
        ("Allocation_4", ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value'], "Global", "Equity indices")
    ],
    "Commodity": [
        ("Commodity_1", ['excess_return_eqwt', 'excess_spot_return_eqwt', 'ir_adjusted_carry_eqwt', 'spot_return_eqwt', 'carry_eqwt', 'excess_return_long_short', 'excess_spot_return_long_short', 'ir_adjusted_carry_long_short', 'aggregate_backwardation_contango'], "Global", None)
    ]
}

def process_fund(fund_data):
    records = []
    symbol = fund_data["SymbolCUSIP"]
    category = fund_data["Global_Category_Name"]
    returns = pd.Series(fund_data["returns"]).dropna()
    
    if returns.empty:
        logger.warning(f"No valid returns for {symbol}")
        return records
    
    regression_category = category_to_regressions.get(category, "Allocation")
    if regression_category == "Allocation" and category not in category_to_regressions:
        logger.warning(f"Unmapped category {category} for {symbol}; using Allocation")
    
    CENTURY_FACTORS = ['Carry', 'Defensive', 'Market', 'Momentum', 'Multi-Style', 'Value']
    factor_data_cache = {}
    
    for reg_name, factors, region, portfolio_base in regression_sets[regression_category]:
        try:
            logger.debug(f"Loading factors for {symbol} ({reg_name}): factors {factors}, region {region}, portfolio_base {portfolio_base}")
            
            if reg_name.startswith("Commodity"):
                factor_data = load_commodity_factors()
            elif reg_name.startswith("FI"):
                fi_factors = [f for f in factors if f in ['TERM_Int', 'TERM_Long', 'CREDIT', 'CREDIT_HY']]
                century_factors = [f for f in factors if f in CENTURY_FACTORS]
                other_factors = [f for f in factors if f not in fi_factors and f not in century_factors]
                
                factor_data_parts = []
                if century_factors:
                    if not portfolio_base:
                        logger.warning(f"Skipping century factors {century_factors} for {reg_name} ({symbol}): portfolio_base missing")
                    else:
                        factor_data_parts.append(load_century_factors(engine, century_factors, portfolio_base, region))
                if other_factors:
                    factor_data_parts.append(load_DB_Factors(engine, region, other_factors))
                if fi_factors:
                    factor_data_parts.append(load_fixed_income_factors(fi_factors))
                
                factor_data = pd.concat([df for df in factor_data_parts if not df.empty], axis=1).dropna()
            else:
                century_factors = [f for f in factors if f in CENTURY_FACTORS]
                other_factors = [f for f in factors if f not in CENTURY_FACTORS]
                
                factor_data_parts = []
                if century_factors:
                    if not portfolio_base:
                        logger.warning(f"Skipping century factors {century_factors} for {reg_name} ({symbol}): portfolio_base missing")
                    else:
                        factor_data_parts.append(load_century_factors(engine, century_factors, portfolio_base, region))
                if other_factors:
                    factor_data_parts.append(load_DB_Factors(engine, region, other_factors))
                
                factor_data = pd.concat([df for df in factor_data_parts if not df.empty], axis=1).dropna()
            
            if not isinstance(factor_data, pd.DataFrame):
                logger.error(f"Invalid factor data type for {reg_name} ({symbol}): {type(factor_data)}")
                continue
            if factor_data.empty or factor_data.shape[1] == 0:
                logger.warning(f"Empty factor data for {reg_name} ({symbol}): factors {factors}")
                continue
            logger.debug(f"Factor data for {reg_name} ({symbol}): shape {factor_data.shape}, columns {factor_data.columns.tolist()}")
            factor_data = factor_data[factor_data.index >= '2015-01-01']
            factor_data_cache[(reg_name, region)] = factor_data
        except Exception as e:
            logger.warning(f"Error loading factors for {symbol} ({reg_name}): {str(e)}")
            continue
    
    for reg_name, factors, region, portfolio_base in regression_sets[regression_category]:
        factor_data = factor_data_cache.get((reg_name, region))
        if factor_data is None:
            continue
        for window in ROLLING_PERIODS:
            records.extend(run_rolling_regression(symbol, returns, factor_data, "OLS", reg_name, window))
    
    logger.info(f"Generated {len(records)} regression records for {symbol}")
    return records

def process_region(region, fund_data_list):
    records = []
    errors = 0
    logger.info(f"Processing {len(fund_data_list)} funds in {region}")
    
    if SAMPLE_DRY_RUN:
        # Sequential processing for debugging
        for fund_data in tqdm(fund_data_list, total=len(fund_data_list), desc=f"Processing {region}", file=sys.stdout):
            try:
                records.extend(process_fund(fund_data))
            except Exception as e:
                logger.error(f"Error processing {fund_data['SymbolCUSIP']}: {str(e)}")
                errors += 1
    else:
        # Parallel processing for production
        for i in range(0, len(fund_data_list), BATCH_SIZE):
            batch = fund_data_list[i:i + BATCH_SIZE]
            with ProcessPoolExecutor(max_workers=MAX_WORKERS_CPU) as executor:
                future_to_fund = {
                    executor.submit(process_fund, fund_data): fund_data["SymbolCUSIP"]
                    for fund_data in batch
                }
                for future in tqdm(future_to_fund, total=len(batch), desc=f"Processing {region} batch", file=sys.stdout):
                    try:
                        records.extend(future.result())
                    except Exception as e:
                        logger.error(f"Error processing {future_to_fund[future]}: {str(e)}")
                        errors += 1
    
    logger.info(f"Region {region} generated {len(records)} total records with {errors} errors")
    log_summary(f"Region {region}: {len(fund_data_list)} funds, {len(records)} records, {errors} errors")
    if not DRY_RUN:
        insert_batch(records)
    
    return records, errors

# Section 6: Database Output
def insert_batch(records):
    if DRY_RUN:
        logger.info(f"Dry run: Would insert {len(records)} records")
        return
    try:
        df = pd.DataFrame(records)
        with database_transaction() as connection:
            df.to_sql("AQRR_Factor_Attribution", connection, if_exists="append", index=False, method="multi")
        logger.info(f"Inserted {len(df)} records to database")
    except Exception as e:
        logger.error(f"Error inserting batch: {e}")
        raise

# Section 7: Main Pipeline
@timer
def main():
    logger.info("Starting main pipeline")
    log_summary("Pipeline started")
    try:
        fund_meta = load_fund_metadata()
    except Exception as e:
        logger.error(f"Failed to load metadata: {e}")
        log_summary(f"Error: Failed to load metadata: {e}")
        return {"error": str(e)}
    
    regions = fund_meta["Region"].unique()
    logger.info(f"Total funds: {len(fund_meta)}, Regions: {regions}")
    log_summary(f"Total funds: {len(fund_meta)}, Regions: {regions}")
    
    fund_ids = fund_meta["SymbolCUSIP"].tolist()
    if SAMPLE_DRY_RUN:
        fund_ids = random.sample(fund_ids, min(SAMPLE_SIZE, len(fund_ids)))
        logger.info(f"Sampled {len(fund_ids)} funds")
        log_summary(f"Sampled {len(fund_ids)} funds")
    
    summary = {"total_funds": len(fund_ids), "regions": {}, "errors": 0}
    for region in sorted(set(regions) - {'Unknown'} | {'USA'}):
        region_fund_ids = fund_meta[fund_meta["Region"] == region]["SymbolCUSIP"].tolist()
        if not region_fund_ids:
            logger.warning(f"No SymbolCUSIP found for region {region}")
            summary["regions"][region] = {"funds_processed": 0, "records": 0, "errors": 0}
            continue
        if SAMPLE_DRY_RUN:
            region_fund_ids = random.sample(region_fund_ids, min(SAMPLE_SIZE, len(region_fund_ids)))
            logger.info(f"Sampled {len(region_fund_ids)} SymbolCUSIP for {region}")
        
        try:
            returns = load_fund_returns(region_fund_ids)
        except Exception as e:
            logger.error(f"Failed to load returns for {region}: {e}")
            log_summary(f"Error: Failed to load returns for {region}: {e}")
            summary["regions"][region] = {"funds_processed": 0, "records": 0, "errors": 1}
            summary["errors"] += 1
            continue
        
        region_funds = [
            {
                "SymbolCUSIP": row["SymbolCUSIP"],
                "Global_Category_Name": row["Global_Category_Name"],
                "CWA_Broad_Category_Name": row.get("CWA_Broad_Category_Name", None),
                "returns": returns[row["SymbolCUSIP"]].to_dict()
            }
            for _, row in fund_meta.iterrows() if row["SymbolCUSIP"] in returns.columns
        ]
        if not region_funds:
            logger.warning(f"No valid returns data for {region}")
            summary["regions"][region] = {"funds_processed": 0, "records": 0, "errors": 0}
            continue
        
        records, errors = process_region(region, region_funds)
        summary["regions"][region] = {"funds_processed": len(region_funds), "records": len(records), "errors": errors}
        summary["errors"] += errors
    
    logger.info(f"Pipeline summary: {summary}")
    log_summary(f"Pipeline completed: {summary}")
    return summary

if __name__ == "__main__":
    try:
        main()
    except Exception as e:
        logger.error(f"Main execution failed: {e}")
        raise
# Out:
# Processing Global:   0%|          | 0/10 [00:00<?, ?it/s]2025-04-20 17:52:18,659 - WARNING - Fund AAAU (Commodity_1, window=12m) skipped: 5 months available
# 2025-04-20 17:52:18,660 - WARNING - Fund AAAU (Commodity_1, window=24m) skipped: 5 months available
# 2025-04-20 17:52:18,661 - WARNING - Fund AAAU (Commodity_1, window=36m) skipped: 5 months available
# 2025-04-20 17:52:18,662 - WARNING - Fund AAAU (Commodity_1, window=48m) skipped: 5 months available
# 2025-04-20 17:52:18,663 - WARNING - Fund AAAU (Commodity_1, window=60m) skipped: 5 months available
# 2025-04-20 17:52:18,912 - WARNING - Fund USL (Commodity_1, window=60m) skipped: 48 months available
# Processing Global:  20%|██        | 2/10 [00:00<00:01,  6.64it/s]2025-04-20 17:52:18,917 - WARNING - Error loading factors for GSEE (Equity_Global_1): (pyodbc.ProgrammingError) ('The SQL contains 0 parameter markers, but 1 parameters were supplied', 'HY000')
# [SQL:
#             SELECT
#                 date AS Date,
#                 'MKT' AS Factor,
#                 value AS Value
#             FROM aqr_century_factors
#             WHERE region = :region
#               AND factor = :factor
#         ]
# [parameters: {'region': 'Global', 'factor': 'MKT'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# 2025-04-20 17:52:18,918 - WARNING - Error loading factors for GSEE (Equity_Global_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:18,919 - WARNING - Error loading factors for GSEE (Equity_Global_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:18,920 - WARNING - Error loading factors for GSEE (Equity_Global_4): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:18,924 - WARNING - Error loading factors for PIEQ (Equity_Global_1): (pyodbc.ProgrammingError) ('The SQL contains 0 parameter markers, but 1 parameters were supplied', 'HY000')
# [SQL:
#             SELECT
#                 date AS Date,
#                 'MKT' AS Factor,
#                 value AS Value
#             FROM aqr_century_factors
#             WHERE region = :region
#               AND factor = :factor
#         ]
# [parameters: {'region': 'Global', 'factor': 'MKT'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# 2025-04-20 17:52:18,925 - WARNING - Error loading factors for PIEQ (Equity_Global_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:18,926 - WARNING - Error loading factors for PIEQ (Equity_Global_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:18,927 - WARNING - Error loading factors for PIEQ (Equity_Global_4): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:18,930 - WARNING - Error loading factors for FNGZX (Equity_Global_1): (pyodbc.ProgrammingError) ('The SQL contains 0 parameter markers, but 1 parameters were supplied', 'HY000')
# [SQL:
#             SELECT
#                 date AS Date,
#                 'MKT' AS Factor,
#                 value AS Value
#             FROM aqr_century_factors
#             WHERE region = :region
#               AND factor = :factor
#         ]
# [parameters: {'region': 'Global', 'factor': 'MKT'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# 2025-04-20 17:52:18,932 - WARNING - Error loading factors for FNGZX (Equity_Global_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:18,933 - WARNING - Error loading factors for FNGZX (Equity_Global_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:18,934 - WARNING - Error loading factors for FNGZX (Equity_Global_4): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:18,937 - WARNING - Error loading factors for GIPTX (Allocation_1): (pyodbc.ProgrammingError) ('The SQL contains 0 parameter markers, but 1 parameters were supplied', 'HY000')
# [SQL:
#             SELECT
#                 date AS Date,
#                 'MKT' AS Factor,
#                 value AS Value
#             FROM aqr_century_factors
#             WHERE region = :region
#               AND factor = :factor
#         ]
# [parameters: {'region': 'Global', 'factor': 'MKT'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# 2025-04-20 17:52:18,938 - WARNING - Error loading factors for GIPTX (Allocation_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:18,939 - WARNING - Error loading factors for GIPTX (Allocation_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:18,941 - WARNING - Error loading factors for GIPTX (Allocation_4): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:18,949 - WARNING - Error loading factors for JTOIX (Allocation_1): (pyodbc.ProgrammingError) ('The SQL contains 0 parameter markers, but 1 parameters were supplied', 'HY000')
# [SQL:
#             SELECT
#                 date AS Date,
#                 'MKT' AS Factor,
#                 value AS Value
#             FROM aqr_century_factors
#             WHERE region = :region
#               AND factor = :factor
#         ]
# [parameters: {'region': 'Global', 'factor': 'MKT'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# 2025-04-20 17:52:18,951 - WARNING - Error loading factors for JTOIX (Allocation_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:18,953 - WARNING - Error loading factors for JTOIX (Allocation_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:18,954 - WARNING - Error loading factors for JTOIX (Allocation_4): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:18,957 - WARNING - Error loading factors for NOIYX (Equity_Global_1): (pyodbc.ProgrammingError) ('The SQL contains 0 parameter markers, but 1 parameters were supplied', 'HY000')
# [SQL:
#             SELECT
#                 date AS Date,
#                 'MKT' AS Factor,
#                 value AS Value
#             FROM aqr_century_factors
#             WHERE region = :region
#               AND factor = :factor
#         ]
# [parameters: {'region': 'Global', 'factor': 'MKT'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# 2025-04-20 17:52:18,958 - WARNING - Error loading factors for NOIYX (Equity_Global_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:18,959 - WARNING - Error loading factors for NOIYX (Equity_Global_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:18,960 - WARNING - Error loading factors for NOIYX (Equity_Global_4): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:18,965 - WARNING - Error loading factors for PACYX (Allocation_1): (pyodbc.ProgrammingError) ('The SQL contains 0 parameter markers, but 1 parameters were supplied', 'HY000')
# [SQL:
#             SELECT
#                 date AS Date,
#                 'MKT' AS Factor,
#                 value AS Value
#             FROM aqr_century_factors
#             WHERE region = :region
#               AND factor = :factor
#         ]
# [parameters: {'region': 'Global', 'factor': 'MKT'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# 2025-04-20 17:52:18,967 - WARNING - Error loading factors for PACYX (Allocation_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:18,968 - WARNING - Error loading factors for PACYX (Allocation_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:18,968 - WARNING - Error loading factors for PACYX (Allocation_4): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:18,973 - WARNING - Error loading factors for TFFAX (Equity_Global_1): (pyodbc.ProgrammingError) ('The SQL contains 0 parameter markers, but 1 parameters were supplied', 'HY000')
# [SQL:
#             SELECT
#                 date AS Date,
#                 'MKT' AS Factor,
#                 value AS Value
#             FROM aqr_century_factors
#             WHERE region = :region
#               AND factor = :factor
#         ]
# [parameters: {'region': 'Global', 'factor': 'MKT'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# 2025-04-20 17:52:18,974 - WARNING - Error loading factors for TFFAX (Equity_Global_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:18,975 - WARNING - Error loading factors for TFFAX (Equity_Global_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:18,975 - WARNING - Error loading factors for TFFAX (Equity_Global_4): List argument must consist only of tuples or dictionaries
# Processing Global: 100%|██████████| 10/10 [00:00<00:00, 27.42it/s]
# Processing International:   0%|          | 0/10 [00:00<?, ?it/s]2025-04-20 17:52:19,134 - WARNING - Error loading factors for DGIN (Equity_Intl_1): (pyodbc.ProgrammingError) ('The SQL contains 0 parameter markers, but 1 parameters were supplied', 'HY000')
# [SQL:
#             SELECT
#                 date AS Date,
#                 'MKT' AS Factor,
#                 value AS Value
#             FROM aqr_century_factors
#             WHERE region = :region
#               AND factor = :factor
#         ]
# [parameters: {'region': 'Intl', 'factor': 'MKT'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# 2025-04-20 17:52:19,136 - WARNING - Error loading factors for DGIN (Equity_Intl_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,136 - WARNING - Error loading factors for DGIN (Equity_Intl_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,137 - WARNING - Error loading factors for DGIN (Equity_Intl_4): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,141 - WARNING - Error loading factors for PRLAX (Equity_Intl_1): (pyodbc.ProgrammingError) ('The SQL contains 0 parameter markers, but 1 parameters were supplied', 'HY000')
# [SQL:
#             SELECT
#                 date AS Date,
#                 'MKT' AS Factor,
#                 value AS Value
#             FROM aqr_century_factors
#             WHERE region = :region
#               AND factor = :factor
#         ]
# [parameters: {'region': 'Intl', 'factor': 'MKT'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# 2025-04-20 17:52:19,142 - WARNING - Error loading factors for PRLAX (Equity_Intl_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,143 - WARNING - Error loading factors for PRLAX (Equity_Intl_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,144 - WARNING - Error loading factors for PRLAX (Equity_Intl_4): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,147 - WARNING - Error loading factors for AIA (Equity_Intl_1): (pyodbc.ProgrammingError) ('The SQL contains 0 parameter markers, but 1 parameters were supplied', 'HY000')
# [SQL:
#             SELECT
#                 date AS Date,
#                 'MKT' AS Factor,
#                 value AS Value
#             FROM aqr_century_factors
#             WHERE region = :region
#               AND factor = :factor
#         ]
# [parameters: {'region': 'Intl', 'factor': 'MKT'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# 2025-04-20 17:52:19,148 - WARNING - Error loading factors for AIA (Equity_Intl_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,149 - WARNING - Error loading factors for AIA (Equity_Intl_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,150 - WARNING - Error loading factors for AIA (Equity_Intl_4): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,153 - WARNING - Error loading factors for ASIA (Equity_Intl_1): (pyodbc.ProgrammingError) ('The SQL contains 0 parameter markers, but 1 parameters were supplied', 'HY000')
# [SQL:
#             SELECT
#                 date AS Date,
#                 'MKT' AS Factor,
#                 value AS Value
#             FROM aqr_century_factors
#             WHERE region = :region
#               AND factor = :factor
#         ]
# [parameters: {'region': 'Intl', 'factor': 'MKT'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# 2025-04-20 17:52:19,153 - WARNING - Error loading factors for ASIA (Equity_Intl_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,154 - WARNING - Error loading factors for ASIA (Equity_Intl_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,155 - WARNING - Error loading factors for ASIA (Equity_Intl_4): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,158 - WARNING - Error loading factors for ASEA (Equity_Intl_1): (pyodbc.ProgrammingError) ('The SQL contains 0 parameter markers, but 1 parameters were supplied', 'HY000')
# [SQL:
#             SELECT
#                 date AS Date,
#                 'MKT' AS Factor,
#                 value AS Value
#             FROM aqr_century_factors
#             WHERE region = :region
#               AND factor = :factor
#         ]
# [parameters: {'region': 'Intl', 'factor': 'MKT'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# 2025-04-20 17:52:19,159 - WARNING - Error loading factors for ASEA (Equity_Intl_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,160 - WARNING - Error loading factors for ASEA (Equity_Intl_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,161 - WARNING - Error loading factors for ASEA (Equity_Intl_4): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,164 - WARNING - Error loading factors for DBEU (Equity_Intl_1): (pyodbc.ProgrammingError) ('The SQL contains 0 parameter markers, but 1 parameters were supplied', 'HY000')
# [SQL:
#             SELECT
#                 date AS Date,
#                 'MKT' AS Factor,
#                 value AS Value
#             FROM aqr_century_factors
#             WHERE region = :region
#               AND factor = :factor
#         ]
# [parameters: {'region': 'Intl', 'factor': 'MKT'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# 2025-04-20 17:52:19,164 - WARNING - Error loading factors for DBEU (Equity_Intl_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,165 - WARNING - Error loading factors for DBEU (Equity_Intl_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,165 - WARNING - Error loading factors for DBEU (Equity_Intl_4): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,167 - WARNING - Error loading factors for FLHK (Equity_Intl_1): (pyodbc.ProgrammingError) ('The SQL contains 0 parameter markers, but 1 parameters were supplied', 'HY000')
# [SQL:
#             SELECT
#                 date AS Date,
#                 'MKT' AS Factor,
#                 value AS Value
#             FROM aqr_century_factors
#             WHERE region = :region
#               AND factor = :factor
#         ]
# [parameters: {'region': 'Intl', 'factor': 'MKT'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# 2025-04-20 17:52:19,168 - WARNING - Error loading factors for FLHK (Equity_Intl_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,170 - WARNING - Error loading factors for FLHK (Equity_Intl_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,171 - WARNING - Error loading factors for FLHK (Equity_Intl_4): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,174 - WARNING - Error loading factors for ASHS (Equity_Intl_1): (pyodbc.ProgrammingError) ('The SQL contains 0 parameter markers, but 1 parameters were supplied', 'HY000')
# [SQL:
#             SELECT
#                 date AS Date,
#                 'MKT' AS Factor,
#                 value AS Value
#             FROM aqr_century_factors
#             WHERE region = :region
#               AND factor = :factor
#         ]
# [parameters: {'region': 'Intl', 'factor': 'MKT'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# 2025-04-20 17:52:19,175 - WARNING - Error loading factors for ASHS (Equity_Intl_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,175 - WARNING - Error loading factors for ASHS (Equity_Intl_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,176 - WARNING - Error loading factors for ASHS (Equity_Intl_4): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,180 - WARNING - Error loading factors for FLN (Equity_Intl_1): (pyodbc.ProgrammingError) ('The SQL contains 0 parameter markers, but 1 parameters were supplied', 'HY000')
# [SQL:
#             SELECT
#                 date AS Date,
#                 'MKT' AS Factor,
#                 value AS Value
#             FROM aqr_century_factors
#             WHERE region = :region
#               AND factor = :factor
#         ]
# [parameters: {'region': 'Intl', 'factor': 'MKT'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# 2025-04-20 17:52:19,180 - WARNING - Error loading factors for FLN (Equity_Intl_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,181 - WARNING - Error loading factors for FLN (Equity_Intl_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,182 - WARNING - Error loading factors for FLN (Equity_Intl_4): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,184 - WARNING - Error loading factors for KHYB (FI_1): (pyodbc.ProgrammingError) ('The SQL contains 0 parameter markers, but 1 parameters were supplied', 'HY000')
# [SQL:
#             SELECT
#                 date AS Date,
#                 'TSM-FI' AS Factor,
#                 value AS Value
#             FROM aqr_century_factors
#             WHERE region = :region
#               AND factor = :factor
#         ]
# [parameters: {'region': 'Global', 'factor': 'TSM-FI'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# 2025-04-20 17:52:19,186 - WARNING - Error loading factors for KHYB (FI_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,186 - WARNING - Error loading factors for KHYB (FI_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,187 - WARNING - Error loading factors for KHYB (FI_4): List argument must consist only of tuples or dictionaries
# Processing International: 100%|██████████| 10/10 [00:00<00:00, 179.24it/s]
# Processing USA:   0%|          | 0/10 [00:00<?, ?it/s]2025-04-20 17:52:19,344 - WARNING - Error loading factors for FLTR (FI_1): (pyodbc.ProgrammingError) ('The SQL contains 0 parameter markers, but 1 parameters were supplied', 'HY000')
# [SQL:
#             SELECT
#                 date AS Date,
#                 'TSM-FI' AS Factor,
#                 value AS Value
#             FROM aqr_century_factors
#             WHERE region = :region
#               AND factor = :factor
#         ]
# [parameters: {'region': 'Global', 'factor': 'TSM-FI'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# 2025-04-20 17:52:19,345 - WARNING - Error loading factors for FLTR (FI_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,346 - WARNING - Error loading factors for FLTR (FI_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,346 - WARNING - Error loading factors for FLTR (FI_4): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,349 - WARNING - Error loading factors for BDFIX (Equity_USA_1): (pyodbc.ProgrammingError) ('The SQL contains 0 parameter markers, but 1 parameters were supplied', 'HY000')
# [SQL:
#             SELECT
#                 date AS Date,
#                 'MKT' AS Factor,
#                 value AS Value
#             FROM aqr_century_factors
#             WHERE region = :region
#               AND factor = :factor
#         ]
# [parameters: {'region': 'USA', 'factor': 'MKT'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# 2025-04-20 17:52:19,350 - WARNING - Error loading factors for BDFIX (Equity_USA_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,351 - WARNING - Error loading factors for BDFIX (Equity_USA_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,352 - WARNING - Error loading factors for BDFIX (Equity_USA_4): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,355 - WARNING - Error loading factors for BDFIX (Equity_USA_5): (pyodbc.ProgrammingError) ('The SQL contains 0 parameter markers, but 1 parameters were supplied', 'HY000')
# [SQL:
#             SELECT
#                 date AS Date,
#                 'MKT' AS Factor,
#                 value AS Value
#             FROM aqr_century_factors
#             WHERE region = :region
#               AND factor = :factor
#         ]
# [parameters: {'region': 'USA', 'factor': 'MKT'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# 2025-04-20 17:52:19,358 - WARNING - Error loading factors for BDFIX (Equity_USA_6): (pyodbc.ProgrammingError) ('The SQL contains 0 parameter markers, but 1 parameters were supplied', 'HY000')
# [SQL:
#             SELECT
#                 date AS Date,
#                 'MKT' AS Factor,
#                 value AS Value
#             FROM aqr_century_factors
#             WHERE region = :region
#               AND factor = :factor
#         ]
# [parameters: {'region': 'USA', 'factor': 'MKT'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# 2025-04-20 17:52:19,360 - WARNING - Error loading factors for BDFIX (Equity_USA_7): (pyodbc.ProgrammingError) ('The SQL contains 0 parameter markers, but 1 parameters were supplied', 'HY000')
# [SQL:
#             SELECT
#                 date AS Date,
#                 'MKT' AS Factor,
#                 value AS Value
#             FROM aqr_century_factors
#             WHERE region = :region
#               AND factor = :factor
#         ]
# [parameters: {'region': 'USA', 'factor': 'MKT'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# 2025-04-20 17:52:19,363 - WARNING - Error loading factors for QDVO (Equity_USA_1): (pyodbc.ProgrammingError) ('The SQL contains 0 parameter markers, but 1 parameters were supplied', 'HY000')
# [SQL:
#             SELECT
#                 date AS Date,
#                 'MKT' AS Factor,
#                 value AS Value
#             FROM aqr_century_factors
#             WHERE region = :region
#               AND factor = :factor
#         ]
# [parameters: {'region': 'USA', 'factor': 'MKT'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# 2025-04-20 17:52:19,364 - WARNING - Error loading factors for QDVO (Equity_USA_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,365 - WARNING - Error loading factors for QDVO (Equity_USA_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,366 - WARNING - Error loading factors for QDVO (Equity_USA_4): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,368 - WARNING - Error loading factors for QDVO (Equity_USA_5): (pyodbc.ProgrammingError) ('The SQL contains 0 parameter markers, but 1 parameters were supplied', 'HY000')
# [SQL:
#             SELECT
#                 date AS Date,
#                 'MKT' AS Factor,
#                 value AS Value
#             FROM aqr_century_factors
#             WHERE region = :region
#               AND factor = :factor
#         ]
# [parameters: {'region': 'USA', 'factor': 'MKT'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# 2025-04-20 17:52:19,369 - WARNING - Error loading factors for QDVO (Equity_USA_6): (pyodbc.ProgrammingError) ('The SQL contains 0 parameter markers, but 1 parameters were supplied', 'HY000')
# [SQL:
#             SELECT
#                 date AS Date,
#                 'MKT' AS Factor,
#                 value AS Value
#             FROM aqr_century_factors
#             WHERE region = :region
#               AND factor = :factor
#         ]
# [parameters: {'region': 'USA', 'factor': 'MKT'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# 2025-04-20 17:52:19,372 - WARNING - Error loading factors for QDVO (Equity_USA_7): (pyodbc.ProgrammingError) ('The SQL contains 0 parameter markers, but 1 parameters were supplied', 'HY000')
# [SQL:
#             SELECT
#                 date AS Date,
#                 'MKT' AS Factor,
#                 value AS Value
#             FROM aqr_century_factors
#             WHERE region = :region
#               AND factor = :factor
#         ]
# [parameters: {'region': 'USA', 'factor': 'MKT'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# 2025-04-20 17:52:19,375 - WARNING - Error loading factors for XHYC (FI_1): (pyodbc.ProgrammingError) ('The SQL contains 0 parameter markers, but 1 parameters were supplied', 'HY000')
# [SQL:
#             SELECT
#                 date AS Date,
#                 'TSM-FI' AS Factor,
#                 value AS Value
#             FROM aqr_century_factors
#             WHERE region = :region
#               AND factor = :factor
#         ]
# [parameters: {'region': 'Global', 'factor': 'TSM-FI'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# 2025-04-20 17:52:19,376 - WARNING - Error loading factors for XHYC (FI_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,377 - WARNING - Error loading factors for XHYC (FI_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,378 - WARNING - Error loading factors for XHYC (FI_4): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,381 - WARNING - Error loading factors for XFIX (FI_1): (pyodbc.ProgrammingError) ('The SQL contains 0 parameter markers, but 1 parameters were supplied', 'HY000')
# [SQL:
#             SELECT
#                 date AS Date,
#                 'TSM-FI' AS Factor,
#                 value AS Value
#             FROM aqr_century_factors
#             WHERE region = :region
#               AND factor = :factor
#         ]
# [parameters: {'region': 'Global', 'factor': 'TSM-FI'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# 2025-04-20 17:52:19,382 - WARNING - Error loading factors for XFIX (FI_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,383 - WARNING - Error loading factors for XFIX (FI_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,383 - WARNING - Error loading factors for XFIX (FI_4): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,386 - WARNING - Error loading factors for TBUX (FI_1): (pyodbc.ProgrammingError) ('The SQL contains 0 parameter markers, but 1 parameters were supplied', 'HY000')
# [SQL:
#             SELECT
#                 date AS Date,
#                 'TSM-FI' AS Factor,
#                 value AS Value
#             FROM aqr_century_factors
#             WHERE region = :region
#               AND factor = :factor
#         ]
# [parameters: {'region': 'Global', 'factor': 'TSM-FI'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# 2025-04-20 17:52:19,387 - WARNING - Error loading factors for TBUX (FI_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,387 - WARNING - Error loading factors for TBUX (FI_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,388 - WARNING - Error loading factors for TBUX (FI_4): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,391 - WARNING - Error loading factors for BSCMX (Equity_USA_1): (pyodbc.ProgrammingError) ('The SQL contains 0 parameter markers, but 1 parameters were supplied', 'HY000')
# [SQL:
#             SELECT
#                 date AS Date,
#                 'MKT' AS Factor,
#                 value AS Value
#             FROM aqr_century_factors
#             WHERE region = :region
#               AND factor = :factor
#         ]
# [parameters: {'region': 'USA', 'factor': 'MKT'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# 2025-04-20 17:52:19,392 - WARNING - Error loading factors for BSCMX (Equity_USA_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,393 - WARNING - Error loading factors for BSCMX (Equity_USA_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,394 - WARNING - Error loading factors for BSCMX (Equity_USA_4): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,396 - WARNING - Error loading factors for BSCMX (Equity_USA_5): (pyodbc.ProgrammingError) ('The SQL contains 0 parameter markers, but 1 parameters were supplied', 'HY000')
# [SQL:
#             SELECT
#                 date AS Date,
#                 'MKT' AS Factor,
#                 value AS Value
#             FROM aqr_century_factors
#             WHERE region = :region
#               AND factor = :factor
#         ]
# [parameters: {'region': 'USA', 'factor': 'MKT'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# 2025-04-20 17:52:19,399 - WARNING - Error loading factors for BSCMX (Equity_USA_6): (pyodbc.ProgrammingError) ('The SQL contains 0 parameter markers, but 1 parameters were supplied', 'HY000')
# [SQL:
#             SELECT
#                 date AS Date,
#                 'MKT' AS Factor,
#                 value AS Value
#             FROM aqr_century_factors
#             WHERE region = :region
#               AND factor = :factor
#         ]
# [parameters: {'region': 'USA', 'factor': 'MKT'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# 2025-04-20 17:52:19,401 - WARNING - Error loading factors for BSCMX (Equity_USA_7): (pyodbc.ProgrammingError) ('The SQL contains 0 parameter markers, but 1 parameters were supplied', 'HY000')
# [SQL:
#             SELECT
#                 date AS Date,
#                 'MKT' AS Factor,
#                 value AS Value
#             FROM aqr_century_factors
#             WHERE region = :region
#               AND factor = :factor
#         ]
# [parameters: {'region': 'USA', 'factor': 'MKT'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# 2025-04-20 17:52:19,403 - WARNING - Error loading factors for FBDAX (FI_1): (pyodbc.ProgrammingError) ('The SQL contains 0 parameter markers, but 1 parameters were supplied', 'HY000')
# [SQL:
#             SELECT
#                 date AS Date,
#                 'TSM-FI' AS Factor,
#                 value AS Value
#             FROM aqr_century_factors
#             WHERE region = :region
#               AND factor = :factor
#         ]
# [parameters: {'region': 'Global', 'factor': 'TSM-FI'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# 2025-04-20 17:52:19,405 - WARNING - Error loading factors for FBDAX (FI_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,406 - WARNING - Error loading factors for FBDAX (FI_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,407 - WARNING - Error loading factors for FBDAX (FI_4): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,410 - WARNING - Error loading factors for BSCIX (FI_1): (pyodbc.ProgrammingError) ('The SQL contains 0 parameter markers, but 1 parameters were supplied', 'HY000')
# [SQL:
#             SELECT
#                 date AS Date,
#                 'TSM-FI' AS Factor,
#                 value AS Value
#             FROM aqr_century_factors
#             WHERE region = :region
#               AND factor = :factor
#         ]
# [parameters: {'region': 'Global', 'factor': 'TSM-FI'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# 2025-04-20 17:52:19,411 - WARNING - Error loading factors for BSCIX (FI_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,412 - WARNING - Error loading factors for BSCIX (FI_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,412 - WARNING - Error loading factors for BSCIX (FI_4): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,415 - WARNING - Error loading factors for THIIX (FI_1): (pyodbc.ProgrammingError) ('The SQL contains 0 parameter markers, but 1 parameters were supplied', 'HY000')
# [SQL:
#             SELECT
#                 date AS Date,
#                 'TSM-FI' AS Factor,
#                 value AS Value
#             FROM aqr_century_factors
#             WHERE region = :region
#               AND factor = :factor
#         ]
# [parameters: {'region': 'Global', 'factor': 'TSM-FI'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# 2025-04-20 17:52:19,416 - WARNING - Error loading factors for THIIX (FI_2): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,417 - WARNING - Error loading factors for THIIX (FI_3): List argument must consist only of tuples or dictionaries
# 2025-04-20 17:52:19,418 - WARNING - Error loading factors for THIIX (FI_4): List argument must consist only of tuples or dictionaries
# Processing USA: 100%|██████████| 10/10 [00:00<00:00, 128.83it/s]

# %%
# AQRR Attribution Pipeline - Modular Factor Loading Version
import pandas as pd
import numpy as np
import os
import random
import logging
from datetime import timedelta, datetime
from dateutil.relativedelta import relativedelta
from concurrent.futures import ProcessPoolExecutor
from sqlalchemy import create_engine, text
from tqdm import tqdm
import statsmodels.api as sm
import time
import sys
from contextlib import contextmanager
from functools import wraps

# Section 1: Configuration and Logging
CONFIG = {
    "database": {
        "server": "JULIANS_LAPTOP\\SQLEXPRESS",
        "database": "CWA_Fund_Database",
        "driver": "ODBC Driver 18 for SQL Server"
    },
    "return_metric": "1 Month Return",
    "rolling_periods": [12, 24, 36, 48, 60],
    "dry_run": True,
    "sample_dry_run": True,
    "sample_size": 10,
    "chunk_size": 5600,
    "batch_insert_size": 10000,
    "max_workers_cpu": 16,
    "batch_size": 100,
}

CONNECTION_STRING = (
    f"mssql+pyodbc://{CONFIG['database']['server']}/{CONFIG['database']['database']}"
    f"?driver={CONFIG['database']['driver']}&trusted_connection=yes&TrustServerCertificate=yes"
)
engine = create_engine(CONNECTION_STRING, pool_size=20, max_overflow=10)

RETURN_METRIC = CONFIG["return_metric"]
ROLLING_PERIODS = CONFIG["rolling_periods"]
DRY_RUN = CONFIG["dry_run"]
SAMPLE_DRY_RUN = CONFIG["sample_dry_run"]
SAMPLE_SIZE = CONFIG["sample_size"]
CHUNK_SIZE = CONFIG["chunk_size"]
BATCH_INSERT_SIZE = CONFIG["batch_insert_size"]
MAX_WORKERS_CPU = CONFIG["max_workers_cpu"]
BATCH_SIZE = CONFIG["batch_size"]

logging.basicConfig(
    level=logging.WARNING,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler("factor_attribution.log"),
        logging.StreamHandler(sys.stdout)
    ],
    force=True
)
logger = logging.getLogger()
SUMMARY_LOG = "factor_attribution_summary.log"

def log_summary(message):
    with open(SUMMARY_LOG, 'a') as f:
        f.write(f"{datetime.now()}: {message}\n")

@contextmanager
def database_transaction():
    with engine.connect() as connection:
        transaction = connection.begin()
        try:
            yield connection
            transaction.commit()
        except Exception as e:
            transaction.rollback()
            logger.error(f"Transaction failed: {e}")
            raise

def timer(func):
    @wraps(func)
    def wrapper(*args, **kwargs):
        start_time = time.time()
        logger.debug(f"Starting {func.__name__}")
        result = func(*args, **kwargs)
        logger.info(f"{func.__name__} took {time.time() - start_time:.2f} seconds")
        return result
    return wrapper

# Section 2: Factor Loaders
@timer
def load_db_factors_standard(engine, region: str, factors: list):
    placeholders = ', '.join([f":factor{i}" for i in range(len(factors))])
    params = {f"factor{i}": f for i, f in enumerate(factors)}
    params["region"] = region
    query = f"""
        SELECT date AS Date, factor AS Factor, value AS Value
        FROM Factor_Returns
        WHERE region = :region AND factor IN ({placeholders})
    """
    df = pd.read_sql_query(text(query), engine, params=params, parse_dates=["Date"])
    if df.empty:
        logger.warning(f"No standard factors for region={region}, factors={factors}")
        return pd.DataFrame()
    return df.pivot(index="Date", columns="Factor", values="Value")

@timer
def load_century_factors(engine, factors: list, portfolio: str, region: str):
    placeholders = ', '.join([f":factor{i}" for i in range(len(factors))])
    params = {f"factor{i}": f for i, f in enumerate(factors)}
    params["portfolio"] = f"{portfolio}%"
    params["region"] = region
    query = f"""
        SELECT date, factor, value
        FROM aqr_century_factors
        WHERE region = :region AND portfolio LIKE :portfolio AND factor IN ({placeholders})
    """
    df = pd.read_sql_query(text(query), engine, params=params, parse_dates=["date"])
    if df.empty:
        logger.warning(f"No century factors for {portfolio} ({region})")
        return pd.DataFrame()
    return df.pivot(index="date", columns="factor", values="value")

@timer
def load_fixed_income_factors(engine, factors: list):
    placeholders = ', '.join([f":factor{i}" for i in range(len(factors))])
    params = {f"factor{i}": f for i, f in enumerate(factors)}
    query = f"""
        SELECT Date, Factor_Name, ReturnValue
        FROM Fixed_Income_Factor_Returns
        WHERE Factor_Name IN ({placeholders})
    """
    df = pd.read_sql_query(text(query), engine, params=params, parse_dates=["Date"])
    if df.empty:
        logger.warning(f"No fixed income factors for: {factors}")
        return pd.DataFrame()
    return df.pivot(index="Date", columns="Factor_Name", values="ReturnValue")

@timer
def load_commodity_factors(engine):
    query = """
        SELECT date AS Date,
               excess_return_eqwt, excess_spot_return_eqwt,
               ir_adjusted_carry_eqwt, spot_return_eqwt, carry_eqwt,
               excess_return_long_short, excess_spot_return_long_short,
               ir_adjusted_carry_long_short, aggregate_backwardation_contango
        FROM aqr_cmdty_factors
    """
    df = pd.read_sql_query(query, engine, parse_dates=["Date"])
    if df.empty:
        logger.warning("No commodity factors loaded")
        return pd.DataFrame()
    return df.set_index("Date")
# ... [PREVIOUS CONTENT ABOVE UNCHANGED] ...

    return df.set_index("Date")

# Section 3: Fund Metadata and Returns
@timer
def load_fund_metadata():
    query = """
        SELECT 
            f.SymbolCUSIP, 
            f.Region, 
            f.YC_Global_Category_ID, 
            c.Global_Category_Name,
            f.YC_Category_ID,
            y.Category_Name,
            f.CWA_Broad_Category_ID,
            b.CWA_Broad_Category_Name
        FROM Funds_to_Screen f
        JOIN YC_Global_Category_List c ON f.YC_Global_Category_ID = c.ID
        JOIN YC_Category_List y ON f.YC_Category_ID = y.ID
        LEFT JOIN CWA_Broad_Category_List b ON f.CWA_Broad_Category_ID = b.ID
    """
    df = pd.read_sql(query, engine)
    logger.info(f"Loaded metadata for {len(df)} funds")
    return df.dropna(subset=["SymbolCUSIP", "Global_Category_Name"])

@timer
def load_fund_returns(fund_ids=None):
    base_query = """
        SELECT SymbolCUSIP, Date, ReturnValue
        FROM Fund_Returns_Timeseries
        WHERE Metric = :metric AND ReturnValue IS NOT NULL AND Date IS NOT NULL
    """
    params = {"metric": RETURN_METRIC}

    if fund_ids:
        fund_ids = [fid for fid in fund_ids if isinstance(fid, str) and fid.strip()]
        if not fund_ids:
            logger.warning("No valid SymbolCUSIP provided")
            return pd.DataFrame()

        symbol_placeholders = ','.join([f":id{i}" for i in range(len(fund_ids))])
        symbol_dict = {f"id{i}": fid for i, fid in enumerate(fund_ids)}
        params.update(symbol_dict)

        query = base_query + f" AND SymbolCUSIP IN ({symbol_placeholders})"
    else:
        query = base_query

    chunks = []
    for chunk in pd.read_sql_query(text(query), engine, params=params, parse_dates=["Date"], chunksize=CHUNK_SIZE):
        chunks.append(chunk)

    df = pd.concat(chunks) if chunks else pd.DataFrame()
    if df.empty:
        logger.warning("No returns data loaded")
        return pd.DataFrame()

    pivoted = df.pivot(index="Date", columns="SymbolCUSIP", values="ReturnValue")
    pivoted.index = pd.to_datetime(pivoted.index) + pd.offsets.MonthEnd(0)
    pivoted.index = pivoted.index.drop_duplicates()
    pivoted = pivoted.asfreq('ME')
    for col in pivoted.columns:
        if not pd.api.types.is_numeric_dtype(pivoted[col]):
            pivoted[col] = pd.to_numeric(pivoted[col], errors='coerce')
    return pivoted

# Section 4: Fund Processing Logic

def run_rolling_regression(symbol, returns, factor_data, regression_type, regression_name, window_months):
    records = []
    returns = returns.sort_index()
    factor_data = factor_data.sort_index()
    aligned_dates = returns.index.intersection(factor_data.index)
    if len(aligned_dates) < window_months:
        return records

    for end_date in aligned_dates[window_months - 1:]:
        start_date = end_date - pd.offsets.MonthEnd(window_months)
        window_returns = returns.loc[start_date:end_date].dropna()
        window_factors = factor_data.loc[start_date:end_date].dropna()
        if len(window_returns) < window_months * 0.8 or len(window_factors) < window_months * 0.8:
            continue
        try:
            X = sm.add_constant(window_factors)
            model = sm.OLS(window_returns, X, missing='drop').fit()
            rec = {
                "SymbolCUSIP": symbol,
                "RegressionName": regression_name,
                "Window": f"{window_months}m",
                "EndDate": end_date,
                "R_Squared": model.rsquared
            }
            for var in model.params.index:
                rec[f"{var}_beta"] = model.params[var]
                rec[f"{var}_tvalue"] = model.tvalues.get(var)
                rec[f"{var}_pvalue"] = model.pvalues.get(var)
            records.append(rec)
        except Exception as e:
            logger.warning(f"Regression failed for {symbol} ({regression_name}): {e}")
            continue
    return records

@timer
def process_fund(fund_data):
    symbol = fund_data["SymbolCUSIP"]
    category = fund_data["Global_Category_Name"]
    returns = pd.Series(fund_data["returns"]).dropna()
    if returns.empty:
        logger.warning(f"No returns for {symbol}")
        return []

    category_map = {
        "Equity_USA": [...],
        "Equity_Intl": [...],
        "Equity_Global": [...],
        "Fixed_Income": [...],
        "Allocation": [...],
        "Alternative": [...],
        "Commodity": [...]
    }  # Define or import from a config if external

    regression_category = category_to_regressions.get(category, "Allocation")
    reg_set = regression_sets.get(regression_category, [])
    results = []

    for reg_name, factors, region, portfolio in reg_set:
        factor_df_parts = []
        try:
            if reg_name.startswith("Commodity"):
                factor_df_parts.append(load_commodity_factors(engine))
            else:
                if any(f in factors for f in ["TERM_Int", "TERM_Long", "CREDIT", "CREDIT_HY"]):
                    fi_factors = [f for f in factors if f.startswith("TERM") or f.startswith("CREDIT")]
                    factor_df_parts.append(load_fixed_income_factors(engine, fi_factors))
                if any(f in factors for f in ["Carry", "Defensive", "Market", "Momentum", "Multi-Style", "Value"]):
                    if portfolio:
                        cen_factors = [f for f in factors if f in ["Carry", "Defensive", "Market", "Momentum", "Multi-Style", "Value"]]
                        factor_df_parts.append(load_century_factors(engine, cen_factors, portfolio, region))
                other_factors = [f for f in factors if f not in ["Carry", "Defensive", "Market", "Momentum", "Multi-Style", "Value"] and not f.startswith("TERM") and not f.startswith("CREDIT")]
                if other_factors:
                    factor_df_parts.append(load_db_factors_standard(engine, region, other_factors))
            if not factor_df_parts:
                continue
            factor_df = pd.concat([df for df in factor_df_parts if not df.empty], axis=1).dropna()
            if factor_df.empty:
                continue
            for window in ROLLING_PERIODS:
                results.extend(run_rolling_regression(symbol, returns, factor_df, "OLS", reg_name, window))
        except Exception as e:
            logger.warning(f"Error loading factors for {symbol} ({reg_name}): {e}")
            continue
    return results


# Section 5: Region Processing and DB Insert

def process_region(region, fund_data_list):
    records = []
    errors = 0
    logger.info(f"Processing {len(fund_data_list)} funds in {region}")
    if SAMPLE_DRY_RUN:
        for fund_data in tqdm(fund_data_list, desc=f"Processing {region}", file=sys.stdout):
            try:
                records.extend(process_fund(fund_data))
            except Exception as e:
                logger.error(f"Error processing {fund_data['SymbolCUSIP']}: {e}")
                errors += 1
    else:
        for i in range(0, len(fund_data_list), BATCH_SIZE):
            batch = fund_data_list[i:i+BATCH_SIZE]
            with ProcessPoolExecutor(max_workers=MAX_WORKERS_CPU) as executor:
                futures = {executor.submit(process_fund, f): f["SymbolCUSIP"] for f in batch}
                for future in tqdm(futures, total=len(futures), desc=f"{region} batch", file=sys.stdout):
                    try:
                        records.extend(future.result())
                    except Exception as e:
                        logger.error(f"Error processing {futures[future]}: {e}")
                        errors += 1
    logger.info(f"{region}: {len(records)} records with {errors} errors")
    log_summary(f"{region}: {len(fund_data_list)} funds, {len(records)} records, {errors} errors")
    if not DRY_RUN:
        insert_batch(records)
    return records, errors

def insert_batch(records):
    if DRY_RUN:
        logger.info(f"Dry run: {len(records)} records would be inserted")
        return
    try:
        df = pd.DataFrame(records)
        with database_transaction() as connection:
            df.to_sql("AQRR_Factor_Attribution", con=connection, if_exists="append", index=False, method="multi")
        logger.info(f"Inserted {len(df)} records into database")
    except Exception as e:
        logger.error(f"Batch insert failed: {e}")
        raise

# Section 6: Main Pipeline
@timer
def main():
    logger.info("Starting AQRR Attribution Pipeline")
    log_summary("Pipeline started")
    try:
        fund_meta = load_fund_metadata()
    except Exception as e:
        logger.error(f"Metadata load failed: {e}")
        log_summary(f"Error loading metadata: {e}")
        return {"error": str(e)}

    fund_ids = fund_meta["SymbolCUSIP"].tolist()
    if SAMPLE_DRY_RUN:
        fund_ids = random.sample(fund_ids, min(SAMPLE_SIZE, len(fund_ids)))
        logger.info(f"Sampled {len(fund_ids)} funds for dry run")
        log_summary(f"Sampled {len(fund_ids)} funds")

    regions = fund_meta["Region"].unique()
    summary = {"total_funds": len(fund_ids), "regions": {}, "errors": 0}

    for region in sorted(set(regions) - {"Unknown"} | {"USA"}):
        region_funds_meta = fund_meta[fund_meta["Region"] == region]
        region_fund_ids = region_funds_meta["SymbolCUSIP"].tolist()
        if SAMPLE_DRY_RUN:
            region_fund_ids = random.sample(region_fund_ids, min(SAMPLE_SIZE, len(region_fund_ids)))

        try:
            returns = load_fund_returns(region_fund_ids)
        except Exception as e:
            logger.error(f"Returns load failed for {region}: {e}")
            summary["regions"][region] = {"funds_processed": 0, "records": 0, "errors": 1}
            summary["errors"] += 1
            continue

        region_funds = [
            {
                "SymbolCUSIP": row["SymbolCUSIP"],
                "Global_Category_Name": row["Global_Category_Name"],
                "returns": returns[row["SymbolCUSIP"]] if row["SymbolCUSIP"] in returns.columns else pd.Series()
            }
            for _, row in region_funds_meta.iterrows()
        ]

        if not region_funds:
            logger.warning(f"No valid return data for {region}")
            summary["regions"][region] = {"funds_processed": 0, "records": 0, "errors": 0}
            continue

        records, errors = process_region(region, region_funds)
        summary["regions"][region] = {"funds_processed": len(region_funds), "records": len(records), "errors": errors}
        summary["errors"] += errors

    logger.info(f"Pipeline complete: {summary}")
    log_summary(f"Pipeline complete: {summary}")
    return summary

if __name__ == "__main__":
    try:
        main()
    except Exception as e:
        logger.error(f"Fatal error: {e}")
        raise
# Out:
# Processing Global:   0%|          | 0/1208 [00:00<?, ?it/s]2025-04-20 18:45:27,308 - WARNING - No returns for EAOA
# 2025-04-20 18:45:27,308 - WARNING - No returns for AOM
# 2025-04-20 18:45:27,309 - WARNING - No returns for AOK
# 2025-04-20 18:45:27,311 - WARNING - No returns for EAOM
# 2025-04-20 18:45:27,312 - WARNING - No returns for TFPN
# 2025-04-20 18:45:27,312 - WARNING - No returns for BAMY
# 2025-04-20 18:45:27,313 - WARNING - No returns for AOR
# 2025-04-20 18:45:27,314 - WARNING - No returns for EAOR
# 2025-04-20 18:45:27,314 - WARNING - No returns for GHTA
# 2025-04-20 18:45:27,315 - WARNING - No returns for SPAX
# 2025-04-20 18:45:27,316 - WARNING - No returns for VEGA
# 2025-04-20 18:45:27,317 - WARNING - No returns for AMPD
# 2025-04-20 18:45:27,317 - WARNING - No returns for SOFR
# 2025-04-20 18:45:27,317 - WARNING - No returns for CERY
# 2025-04-20 18:45:27,319 - WARNING - No returns for EDGH
# 2025-04-20 18:45:27,320 - WARNING - No returns for AAAU
# 2025-04-20 18:45:27,321 - WARNING - No returns for GLDM
# 2025-04-20 18:45:27,322 - WARNING - No returns for CORN
# 2025-04-20 18:45:27,323 - WARNING - No returns for SOYB
# 2025-04-20 18:45:27,323 - WARNING - No returns for WEAT
# 2025-04-20 18:45:27,324 - WARNING - No returns for CANE
# 2025-04-20 18:45:27,324 - WARNING - No returns for TAGS
# 2025-04-20 18:45:27,325 - WARNING - No returns for FGDL
# 2025-04-20 18:45:27,326 - WARNING - No returns for KOLD
# 2025-04-20 18:45:27,326 - WARNING - No returns for FLRU
# 2025-04-20 18:45:27,328 - WARNING - No returns for KLMT
# 2025-04-20 18:45:27,328 - WARNING - No returns for ACWV
# 2025-04-20 18:45:27,329 - WARNING - No returns for TOK
# 2025-04-20 18:45:27,330 - WARNING - No returns for CRBN
# 2025-04-20 18:45:27,330 - WARNING - No returns for GLOF
# 2025-04-20 18:45:27,331 - WARNING - No returns for WRND
# 2025-04-20 18:45:27,332 - WARNING - No returns for KOCG
# 2025-04-20 18:45:27,332 - WARNING - No returns for DWLD
# 2025-04-20 18:45:27,334 - WARNING - No returns for HEWJ
# 2025-04-20 18:45:27,335 - WARNING - No returns for BBJP
# 2025-04-20 18:45:27,335 - WARNING - No returns for EWJV
# 2025-04-20 18:45:27,336 - WARNING - No returns for GMET
# 2025-04-20 18:45:27,337 - WARNING - No returns for HSBH
# 2025-04-20 18:45:27,338 - WARNING - No returns for KSEA
# 2025-04-20 18:45:27,339 - WARNING - No returns for YOLO
# 2025-04-20 18:45:27,340 - WARNING - No returns for TOKE
# 2025-04-20 18:45:27,341 - WARNING - No returns for SHEH
# 2025-04-20 18:45:27,341 - WARNING - No returns for AZNH
# 2025-04-20 18:45:27,342 - WARNING - No returns for HAP
# 2025-04-20 18:45:27,343 - WARNING - No returns for MOO
# 2025-04-20 18:45:27,344 - WARNING - No returns for REET
# 2025-04-20 18:45:27,345 - WARNING - No returns for TTEQ
# 2025-04-20 18:45:27,346 - WARNING - No returns for CHPS
# 2025-04-20 18:45:27,347 - WARNING - No returns for SOXQ
# 2025-04-20 18:45:27,348 - WARNING - No returns for WUGI
# 2025-04-20 18:45:27,348 - WARNING - No returns for ODDS
# 2025-04-20 18:45:27,349 - WARNING - No returns for PSWD
# 2025-04-20 18:45:27,350 - WARNING - No returns for PRNT
# 2025-04-20 18:45:27,351 - WARNING - No returns for KOMP
# 2025-04-20 18:45:27,352 - WARNING - No returns for CVY
# 2025-04-20 18:45:27,352 - WARNING - No returns for EATV
# 2025-04-20 18:45:27,353 - WARNING - No returns for WBIF
# 2025-04-20 18:45:27,354 - WARNING - No returns for NXTE
# 2025-04-20 18:45:27,355 - WARNING - No returns for RSSY
# 2025-04-20 18:45:27,356 - WARNING - No returns for FFND
# 2025-04-20 18:45:27,357 - WARNING - No returns for FDLS
# 2025-04-20 18:45:27,357 - WARNING - No returns for QQQJ
# 2025-04-20 18:45:27,358 - WARNING - No returns for QQJG
# 2025-04-20 18:45:27,360 - WARNING - No returns for CBSE
# 2025-04-20 18:45:27,360 - WARNING - No returns for GRNB
# 2025-04-20 18:45:27,361 - WARNING - No returns for BGRN
# 2025-04-20 18:45:27,362 - WARNING - No returns for DGCB
# 2025-04-20 18:45:27,363 - WARNING - No returns for DFGX
# 2025-04-20 18:45:27,364 - WARNING - No returns for SKOR
# 2025-04-20 18:45:27,364 - WARNING - No returns for QLTA
# 2025-04-20 18:45:27,365 - WARNING - No returns for SUSC
# 2025-04-20 18:45:27,366 - WARNING - No returns for IGEB
# 2025-04-20 18:45:27,367 - WARNING - No returns for IG
# 2025-04-20 18:45:27,368 - WARNING - No returns for MIG
# 2025-04-20 18:45:27,369 - WARNING - No returns for LDRC
# 2025-04-20 18:45:27,370 - WARNING - No returns for SHYL
# 2025-04-20 18:45:27,371 - WARNING - No returns for HYRM
# 2025-04-20 18:45:27,372 - WARNING - No returns for HYUP
# 2025-04-20 18:45:27,373 - WARNING - No returns for UNIY
# 2025-04-20 18:45:27,374 - WARNING - No returns for VCRB
# 2025-04-20 18:45:27,375 - WARNING - No returns for VPLS
# 2025-04-20 18:45:27,376 - WARNING - No returns for XFLX
# 2025-04-20 18:45:27,377 - WARNING - No returns for DIAL
# 2025-04-20 18:45:27,377 - WARNING - No returns for AFIF
# 2025-04-20 18:45:27,377 - WARNING - No returns for RMIF
# 2025-04-20 18:45:27,379 - WARNING - No returns for BYLD
# 2025-04-20 18:45:27,380 - WARNING - No returns for GHMS
# 2025-04-20 18:45:27,382 - WARNING - No returns for OVT
# 2025-04-20 18:45:27,383 - WARNING - No returns for JSCP
# 2025-04-20 18:45:27,384 - WARNING - No returns for CLOA
# 2025-04-20 18:45:27,385 - WARNING - No returns for PAAA
# 2025-04-20 18:45:27,386 - WARNING - No returns for BILZ
# 2025-04-20 18:45:27,387 - WARNING - No returns for ICLO
# 2025-04-20 18:45:27,388 - WARNING - No returns for GSY
# 2025-04-20 18:45:27,390 - WARNING - No returns for FLRN
# 2025-04-20 18:45:27,391 - WARNING - No returns for FLTR
# 2025-04-20 18:45:27,391 - WARNING - No returns for ULST
# 2025-04-20 18:45:27,392 - WARNING - No returns for FLOT
# 2025-04-20 18:45:27,393 - WARNING - No returns for IGBH
# 2025-04-20 18:45:27,394 - WARNING - No returns for VNLA
# 2025-04-20 18:45:27,394 - WARNING - No returns for JPST
# 2025-04-20 18:45:27,394 - WARNING - No returns for PULS
# 2025-04-20 18:45:27,396 - WARNING - No returns for FLDR
# 2025-04-20 18:45:27,397 - WARNING - No returns for VUSB
# 2025-04-20 18:45:27,398 - WARNING - No returns for DUSB
# 2025-04-20 18:45:27,399 - WARNING - No returns for FLUD
# 2025-04-20 18:45:27,400 - WARNING - No returns for CLOX
# 2025-04-20 18:45:27,401 - WARNING - No returns for KCSH
# 2025-04-20 18:45:27,402 - WARNING - No returns for FLDB
# 2025-04-20 18:45:27,403 - WARNING - No returns for ARSYX
# 2025-04-20 18:45:27,404 - WARNING - No returns for CBSYX
# 2025-04-20 18:45:27,405 - WARNING - No returns for ADVDX
# 2025-04-20 18:45:27,406 - WARNING - No returns for ALZFX
# 2025-04-20 18:45:27,407 - WARNING - No returns for EKGIX
# Processing Global:   9%|▉         | 114/1208 [00:00<00:00, 1136.84it/s]2025-04-20 18:45:27,408 - WARNING - No returns for WGBIX
# 2025-04-20 18:45:27,409 - WARNING - No returns for LPEIX
# 2025-04-20 18:45:27,409 - WARNING - No returns for AOVIX
# 2025-04-20 18:45:27,410 - WARNING - No returns for ACCIX
# 2025-04-20 18:45:27,411 - WARNING - No returns for CAIFX
# 2025-04-20 18:45:27,412 - WARNING - No returns for FINFX
# 2025-04-20 18:45:27,413 - WARNING - No returns for SMCFX
# 2025-04-20 18:45:27,414 - WARNING - No returns for MEQFX
# 2025-04-20 18:45:27,414 - WARNING - No returns for YAFIX
# 2025-04-20 18:45:27,415 - WARNING - No returns for PLCDX
# 2025-04-20 18:45:27,416 - WARNING - No returns for APDGX
# 2025-04-20 18:45:27,417 - WARNING - No returns for APDJX
# 2025-04-20 18:45:27,419 - WARNING - No returns for BFTIX
# 2025-04-20 18:45:27,419 - WARNING - No returns for BICPX
# 2025-04-20 18:45:27,420 - WARNING - No returns for BIMPX
# 2025-04-20 18:45:27,421 - WARNING - No returns for BIGPX
# 2025-04-20 18:45:27,421 - WARNING - No returns for MAILX
# 2025-04-20 18:45:27,422 - WARNING - No returns for DGIGX
# 2025-04-20 18:45:27,422 - WARNING - No returns for DRLIX
# 2025-04-20 18:45:27,423 - WARNING - No returns for DFLIX
# 2025-04-20 18:45:27,424 - WARNING - No returns for BGVIX
# 2025-04-20 18:45:27,425 - WARNING - No returns for BGHIX
# 2025-04-20 18:45:27,426 - WARNING - No returns for BGLYX
# 2025-04-20 18:45:27,427 - WARNING - No returns for BAFLX
# 2025-04-20 18:45:27,427 - WARNING - No returns for CXGCX
# 2025-04-20 18:45:27,428 - WARNING - No returns for CIGEX
# 2025-04-20 18:45:27,429 - WARNING - No returns for CFAIX
# 2025-04-20 18:45:27,430 - WARNING - No returns for CAGIX
# 2025-04-20 18:45:27,430 - WARNING - No returns for CSUIX
# 2025-04-20 18:45:27,431 - WARNING - No returns for NBGPX
# 2025-04-20 18:45:27,432 - WARNING - No returns for FTOTX
# 2025-04-20 18:45:27,433 - WARNING - No returns for DPIIX
# 2025-04-20 18:45:27,433 - WARNING - No returns for TOLIX
# 2025-04-20 18:45:27,434 - WARNING - No returns for PPILX
# 2025-04-20 18:45:27,434 - WARNING - No returns for ETIEX
# 2025-04-20 18:45:27,435 - WARNING - No returns for SBFIX
# 2025-04-20 18:45:27,436 - WARNING - No returns for FFNIX
# 2025-04-20 18:45:27,436 - WARNING - No returns for SGIIX
# 2025-04-20 18:45:27,437 - WARNING - No returns for FDHIX
# 2025-04-20 18:45:27,438 - WARNING - No returns for FNRAX
# 2025-04-20 18:45:27,440 - WARNING - No returns for CCAPX
# 2025-04-20 18:45:27,440 - WARNING - No returns for GBMIX
# 2025-04-20 18:45:27,442 - WARNING - No returns for GCEJX
# 2025-04-20 18:45:27,443 - WARNING - No returns for GHIRX
# 2025-04-20 18:45:27,443 - WARNING - No returns for GPPOX
# 2025-04-20 18:45:27,444 - WARNING - No returns for HBLIX
# 2025-04-20 18:45:27,445 - WARNING - No returns for HFHIX
# 2025-04-20 18:45:27,446 - WARNING - No returns for HBAIX
# 2025-04-20 18:45:27,447 - WARNING - No returns for HRLIX
# 2025-04-20 18:45:27,448 - WARNING - No returns for MSEFX
# 2025-04-20 18:45:27,449 - WARNING - No returns for QGRYX
# 2025-04-20 18:45:27,449 - WARNING - No returns for AWSYX
# 2025-04-20 18:45:27,450 - WARNING - No returns for GLVYX
# 2025-04-20 18:45:27,450 - WARNING - No returns for ARGYX
# 2025-04-20 18:45:27,451 - WARNING - No returns for ASRYX
# 2025-04-20 18:45:27,451 - WARNING - No returns for OYAIX
# 2025-04-20 18:45:27,453 - WARNING - No returns for JMGRX
# 2025-04-20 18:45:27,454 - WARNING - No returns for JGCIX
# 2025-04-20 18:45:27,454 - WARNING - No returns for JEUIX
# 2025-04-20 18:45:27,455 - WARNING - No returns for JATIX
# 2025-04-20 18:45:27,455 - WARNING - No returns for JGEFX
# 2025-04-20 18:45:27,456 - WARNING - No returns for JSTIX
# 2025-04-20 18:45:27,457 - WARNING - No returns for JTAIX
# 2025-04-20 18:45:27,458 - WARNING - No returns for LCRIX
# 2025-04-20 18:45:27,459 - WARNING - No returns for ALFYX
# 2025-04-20 18:45:27,460 - WARNING - No returns for LAUYX
# 2025-04-20 18:45:27,460 - WARNING - No returns for LIFIX
# 2025-04-20 18:45:27,461 - WARNING - No returns for LUBYX
# 2025-04-20 18:45:27,462 - WARNING - No returns for MNHAX
# 2025-04-20 18:45:27,462 - WARNING - No returns for MNHIX
# 2025-04-20 18:45:27,463 - WARNING - No returns for MIAGX
# 2025-04-20 18:45:27,464 - WARNING - No returns for MFWIX
# 2025-04-20 18:45:27,464 - WARNING - No returns for MQLIX
# 2025-04-20 18:45:27,466 - WARNING - No returns for MVGIX
# 2025-04-20 18:45:27,466 - WARNING - No returns for MSSGX
# 2025-04-20 18:45:27,467 - WARNING - No returns for GILIX
# 2025-04-20 18:45:27,468 - WARNING - No returns for GIUIX
# 2025-04-20 18:45:27,469 - WARNING - No returns for PORYX
# 2025-04-20 18:45:27,469 - WARNING - No returns for TCBPX
# 2025-04-20 18:45:27,469 - WARNING - No returns for NQGIX
# 2025-04-20 18:45:27,471 - WARNING - No returns for TGROX
# 2025-04-20 18:45:27,471 - WARNING - No returns for NCOIX
# 2025-04-20 18:45:27,472 - WARNING - No returns for TSGHX
# 2025-04-20 18:45:27,473 - WARNING - No returns for TSMHX
# 2025-04-20 18:45:27,474 - WARNING - No returns for PREQX
# 2025-04-20 18:45:27,475 - WARNING - No returns for PYCBX
# 2025-04-20 18:45:27,476 - WARNING - No returns for PYACX
# 2025-04-20 18:45:27,476 - WARNING - No returns for PYGSX
# 2025-04-20 18:45:27,477 - WARNING - No returns for TAIBX
# 2025-04-20 18:45:27,478 - WARNING - No returns for PRPZX
# 2025-04-20 18:45:27,478 - WARNING - No returns for PGJZX
# 2025-04-20 18:45:27,479 - WARNING - No returns for PHSZX
# 2025-04-20 18:45:27,479 - WARNING - No returns for PUDZX
# 2025-04-20 18:45:27,481 - WARNING - No returns for SREZX
# 2025-04-20 18:45:27,482 - WARNING - No returns for PUCPX
# 2025-04-20 18:45:27,483 - WARNING - No returns for PELPX
# 2025-04-20 18:45:27,484 - WARNING - No returns for PEMPX
# 2025-04-20 18:45:27,484 - WARNING - No returns for PGSAX
# 2025-04-20 18:45:27,485 - WARNING - No returns for PGAPX
# 2025-04-20 18:45:27,485 - WARNING - No returns for PLRPX
# 2025-04-20 18:45:27,486 - WARNING - No returns for PMOPX
# 2025-04-20 18:45:27,486 - WARNING - No returns for PFPNX
# 2025-04-20 18:45:27,562 - WARNING - No returns for PEFPX
# 2025-04-20 18:45:27,562 - WARNING - No returns for TYHYX
# 2025-04-20 18:45:27,565 - WARNING - No returns for PMFYX
# 2025-04-20 18:45:27,565 - WARNING - No returns for PCCIX
# 2025-04-20 18:45:27,567 - WARNING - No returns for PSWIX
# 2025-04-20 18:45:27,567 - WARNING - No returns for PAGYX
# 2025-04-20 18:45:27,568 - WARNING - No returns for RGISX
# 2025-04-20 18:45:27,569 - WARNING - No returns for RRESX
# 2025-04-20 18:45:27,570 - WARNING - No returns for RELSX
# 2025-04-20 18:45:27,571 - WARNING - No returns for NEXIX
# 2025-04-20 18:45:27,573 - WARNING - No returns for SGISX
# 2025-04-20 18:45:27,573 - WARNING - No returns for PRJPX
# Processing Global:  19%|█▉        | 228/1208 [00:00<00:01, 824.01it/s] 2025-04-20 18:45:27,574 - WARNING - No returns for TGSAX
# 2025-04-20 18:45:27,575 - WARNING - No returns for TAREX
# 2025-04-20 18:45:27,576 - WARNING - No returns for TAVFX
# 2025-04-20 18:45:27,576 - WARNING - No returns for TAGIX
# 2025-04-20 18:45:27,577 - WARNING - No returns for TFLIX
# 2025-04-20 18:45:27,578 - WARNING - No returns for BPGLX
# 2025-04-20 18:45:27,579 - WARNING - No returns for GHAYX
# 2025-04-20 18:45:27,579 - WARNING - No returns for USBSX
# 2025-04-20 18:45:27,581 - WARNING - No returns for USCRX
# 2025-04-20 18:45:27,582 - WARNING - No returns for UCMCX
# 2025-04-20 18:45:27,582 - WARNING - No returns for RSNYX
# 2025-04-20 18:45:27,583 - WARNING - No returns for VBFIX
# 2025-04-20 18:45:27,584 - WARNING - No returns for UIWGX
# 2025-04-20 18:45:27,585 - WARNING - No returns for VGISX
# 2025-04-20 18:45:27,586 - WARNING - No returns for PICMX
# 2025-04-20 18:45:27,587 - WARNING - No returns for WCMIX
# 2025-04-20 18:45:27,587 - WARNING - No returns for SBSYX
# 2025-04-20 18:45:27,588 - WARNING - No returns for WAARX
# 2025-04-20 18:45:27,589 - WARNING - No returns for APGRX
# 2025-04-20 18:45:27,590 - WARNING - No returns for ROMO
# 2025-04-20 18:45:27,591 - WARNING - No returns for MAPP
# 2025-04-20 18:45:27,591 - WARNING - No returns for GAL
# 2025-04-20 18:45:27,592 - WARNING - No returns for AOA
# 2025-04-20 18:45:27,593 - WARNING - No returns for PPI
# 2025-04-20 18:45:27,594 - WARNING - No returns for PCEF
# 2025-04-20 18:45:27,595 - WARNING - No returns for GAA
# 2025-04-20 18:45:27,595 - WARNING - No returns for TWIO
# 2025-04-20 18:45:27,596 - WARNING - No returns for RLY
# 2025-04-20 18:45:27,597 - WARNING - No returns for TBFC
# 2025-04-20 18:45:27,597 - WARNING - No returns for TBFG
# 2025-04-20 18:45:27,598 - WARNING - No returns for MOOD
# 2025-04-20 18:45:27,599 - WARNING - No returns for TDSC
# 2025-04-20 18:45:27,600 - WARNING - No returns for CEFS
# 2025-04-20 18:45:27,644 - WARNING - Regression failed for TDSB (Allocation_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:27,646 - WARNING - Regression failed for TDSB (Allocation_1): operands could not be broadcast together with shapes (13,1) (11,1)
# 2025-04-20 18:45:27,650 - WARNING - Regression failed for TDSB (Allocation_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:27,653 - WARNING - Regression failed for TDSB (Allocation_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:27,655 - WARNING - Regression failed for TDSB (Allocation_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:27,657 - WARNING - Regression failed for TDSB (Allocation_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:27,659 - WARNING - Regression failed for TDSB (Allocation_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:27,663 - WARNING - Regression failed for TDSB (Allocation_1): operands could not be broadcast together with shapes (13,1) (11,1)
# 2025-04-20 18:45:27,665 - WARNING - Regression failed for TDSB (Allocation_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:27,668 - WARNING - Regression failed for TDSB (Allocation_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:27,671 - WARNING - Regression failed for TDSB (Allocation_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:27,674 - WARNING - Regression failed for TDSB (Allocation_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:27,676 - WARNING - Regression failed for TDSB (Allocation_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:27,680 - WARNING - Regression failed for TDSB (Allocation_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:27,682 - WARNING - Regression failed for TDSB (Allocation_1): operands could not be broadcast together with shapes (13,1) (11,1)
# 2025-04-20 18:45:27,685 - WARNING - Regression failed for TDSB (Allocation_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:27,688 - WARNING - Regression failed for TDSB (Allocation_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:27,690 - WARNING - Regression failed for TDSB (Allocation_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:27,693 - WARNING - Regression failed for TDSB (Allocation_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:27,698 - WARNING - Regression failed for TDSB (Allocation_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:27,705 - WARNING - Regression failed for TDSB (Allocation_1): operands could not be broadcast together with shapes (25,1) (20,1)
# 2025-04-20 18:45:27,710 - WARNING - Regression failed for TDSB (Allocation_1): operands could not be broadcast together with shapes (25,1) (20,1)
# 2025-04-20 18:45:27,760 - WARNING - Regression failed for TDSB (Allocation_2): operands could not be broadcast together with shapes (13,1) (12,1)
# 2025-04-20 18:45:27,764 - WARNING - Regression failed for TDSB (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,766 - WARNING - Regression failed for TDSB (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,768 - WARNING - Regression failed for TDSB (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,771 - WARNING - Regression failed for TDSB (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,774 - WARNING - Regression failed for TDSB (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,776 - WARNING - Regression failed for TDSB (Allocation_2): operands could not be broadcast together with shapes (13,1) (12,1)
# 2025-04-20 18:45:27,780 - WARNING - Regression failed for TDSB (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,783 - WARNING - Regression failed for TDSB (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,786 - WARNING - Regression failed for TDSB (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,790 - WARNING - Regression failed for TDSB (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,793 - WARNING - Regression failed for TDSB (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,795 - WARNING - Regression failed for TDSB (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,798 - WARNING - Regression failed for TDSB (Allocation_2): operands could not be broadcast together with shapes (13,1) (12,1)
# 2025-04-20 18:45:27,801 - WARNING - Regression failed for TDSB (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,804 - WARNING - Regression failed for TDSB (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,807 - WARNING - Regression failed for TDSB (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,810 - WARNING - Regression failed for TDSB (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,814 - WARNING - Regression failed for TDSB (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,817 - WARNING - Regression failed for TDSB (Allocation_2): operands could not be broadcast together with shapes (13,1) (12,1)
# 2025-04-20 18:45:27,819 - WARNING - Regression failed for TDSB (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,823 - WARNING - Regression failed for TDSB (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,825 - WARNING - Regression failed for TDSB (Allocation_2): operands could not be broadcast together with shapes (13,1) (12,1)
# 2025-04-20 18:45:27,828 - WARNING - Regression failed for TDSB (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,830 - WARNING - Regression failed for TDSB (Allocation_2): operands could not be broadcast together with shapes (13,1) (12,1)
# 2025-04-20 18:45:27,834 - WARNING - Regression failed for TDSB (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,837 - WARNING - Regression failed for TDSB (Allocation_2): operands could not be broadcast together with shapes (25,1) (24,1)
# 2025-04-20 18:45:27,839 - WARNING - Regression failed for TDSB (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,841 - WARNING - Regression failed for TDSB (Allocation_2): operands could not be broadcast together with shapes (25,1) (24,1)
# 2025-04-20 18:45:27,844 - WARNING - Regression failed for TDSB (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,846 - WARNING - Regression failed for TDSB (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,848 - WARNING - Regression failed for TDSB (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,850 - WARNING - Regression failed for TDSB (Allocation_2): operands could not be broadcast together with shapes (25,1) (24,1)
# 2025-04-20 18:45:27,853 - WARNING - Regression failed for TDSB (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,856 - WARNING - Regression failed for TDSB (Allocation_2): operands could not be broadcast together with shapes (25,1) (24,1)
# 2025-04-20 18:45:27,858 - WARNING - Regression failed for TDSB (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,861 - WARNING - Regression failed for TDSB (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,863 - WARNING - Regression failed for TDSB (Allocation_2): operands could not be broadcast together with shapes (25,1) (24,1)
# 2025-04-20 18:45:27,866 - WARNING - Regression failed for TDSB (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,928 - WARNING - Regression failed for TDSB (Allocation_3): operands could not be broadcast together with shapes (13,1) (12,1)
# 2025-04-20 18:45:27,930 - WARNING - Regression failed for TDSB (Allocation_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,933 - WARNING - Regression failed for TDSB (Allocation_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,935 - WARNING - Regression failed for TDSB (Allocation_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,937 - WARNING - Regression failed for TDSB (Allocation_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,940 - WARNING - Regression failed for TDSB (Allocation_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,943 - WARNING - Regression failed for TDSB (Allocation_3): operands could not be broadcast together with shapes (13,1) (12,1)
# 2025-04-20 18:45:27,946 - WARNING - Regression failed for TDSB (Allocation_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,948 - WARNING - Regression failed for TDSB (Allocation_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,951 - WARNING - Regression failed for TDSB (Allocation_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,954 - WARNING - Regression failed for TDSB (Allocation_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,957 - WARNING - Regression failed for TDSB (Allocation_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,960 - WARNING - Regression failed for TDSB (Allocation_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,963 - WARNING - Regression failed for TDSB (Allocation_3): operands could not be broadcast together with shapes (13,1) (12,1)
# 2025-04-20 18:45:27,966 - WARNING - Regression failed for TDSB (Allocation_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,969 - WARNING - Regression failed for TDSB (Allocation_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,971 - WARNING - Regression failed for TDSB (Allocation_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,974 - WARNING - Regression failed for TDSB (Allocation_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,978 - WARNING - Regression failed for TDSB (Allocation_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,980 - WARNING - Regression failed for TDSB (Allocation_3): operands could not be broadcast together with shapes (13,1) (12,1)
# 2025-04-20 18:45:27,983 - WARNING - Regression failed for TDSB (Allocation_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,986 - WARNING - Regression failed for TDSB (Allocation_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,989 - WARNING - Regression failed for TDSB (Allocation_3): operands could not be broadcast together with shapes (13,1) (12,1)
# 2025-04-20 18:45:27,991 - WARNING - Regression failed for TDSB (Allocation_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:27,994 - WARNING - Regression failed for TDSB (Allocation_3): operands could not be broadcast together with shapes (13,1) (12,1)
# 2025-04-20 18:45:27,996 - WARNING - Regression failed for TDSB (Allocation_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,000 - WARNING - Regression failed for TDSB (Allocation_3): operands could not be broadcast together with shapes (25,1) (24,1)
# 2025-04-20 18:45:28,003 - WARNING - Regression failed for TDSB (Allocation_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,005 - WARNING - Regression failed for TDSB (Allocation_3): operands could not be broadcast together with shapes (25,1) (24,1)
# 2025-04-20 18:45:28,008 - WARNING - Regression failed for TDSB (Allocation_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,010 - WARNING - Regression failed for TDSB (Allocation_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,013 - WARNING - Regression failed for TDSB (Allocation_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,016 - WARNING - Regression failed for TDSB (Allocation_3): operands could not be broadcast together with shapes (25,1) (24,1)
# 2025-04-20 18:45:28,018 - WARNING - Regression failed for TDSB (Allocation_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,020 - WARNING - Regression failed for TDSB (Allocation_3): operands could not be broadcast together with shapes (25,1) (24,1)
# 2025-04-20 18:45:28,023 - WARNING - Regression failed for TDSB (Allocation_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,026 - WARNING - Regression failed for TDSB (Allocation_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,029 - WARNING - Regression failed for TDSB (Allocation_3): operands could not be broadcast together with shapes (25,1) (24,1)
# 2025-04-20 18:45:28,031 - WARNING - Regression failed for TDSB (Allocation_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,094 - WARNING - Regression failed for TDSB (Allocation_4): operands could not be broadcast together with shapes (13,1) (12,1)
# 2025-04-20 18:45:28,098 - WARNING - Regression failed for TDSB (Allocation_4): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,101 - WARNING - Regression failed for TDSB (Allocation_4): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,103 - WARNING - Regression failed for TDSB (Allocation_4): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,105 - WARNING - Regression failed for TDSB (Allocation_4): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,108 - WARNING - Regression failed for TDSB (Allocation_4): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,111 - WARNING - Regression failed for TDSB (Allocation_4): operands could not be broadcast together with shapes (13,1) (12,1)
# 2025-04-20 18:45:28,115 - WARNING - Regression failed for TDSB (Allocation_4): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,118 - WARNING - Regression failed for TDSB (Allocation_4): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,121 - WARNING - Regression failed for TDSB (Allocation_4): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,124 - WARNING - Regression failed for TDSB (Allocation_4): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,127 - WARNING - Regression failed for TDSB (Allocation_4): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,129 - WARNING - Regression failed for TDSB (Allocation_4): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,131 - WARNING - Regression failed for TDSB (Allocation_4): operands could not be broadcast together with shapes (13,1) (12,1)
# 2025-04-20 18:45:28,134 - WARNING - Regression failed for TDSB (Allocation_4): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,138 - WARNING - Regression failed for TDSB (Allocation_4): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,140 - WARNING - Regression failed for TDSB (Allocation_4): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,143 - WARNING - Regression failed for TDSB (Allocation_4): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,147 - WARNING - Regression failed for TDSB (Allocation_4): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,150 - WARNING - Regression failed for TDSB (Allocation_4): operands could not be broadcast together with shapes (13,1) (12,1)
# 2025-04-20 18:45:28,154 - WARNING - Regression failed for TDSB (Allocation_4): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,156 - WARNING - Regression failed for TDSB (Allocation_4): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,159 - WARNING - Regression failed for TDSB (Allocation_4): operands could not be broadcast together with shapes (13,1) (12,1)
# 2025-04-20 18:45:28,162 - WARNING - Regression failed for TDSB (Allocation_4): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,166 - WARNING - Regression failed for TDSB (Allocation_4): operands could not be broadcast together with shapes (13,1) (12,1)
# 2025-04-20 18:45:28,169 - WARNING - Regression failed for TDSB (Allocation_4): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,171 - WARNING - Regression failed for TDSB (Allocation_4): operands could not be broadcast together with shapes (25,1) (24,1)
# 2025-04-20 18:45:28,174 - WARNING - Regression failed for TDSB (Allocation_4): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,178 - WARNING - Regression failed for TDSB (Allocation_4): operands could not be broadcast together with shapes (25,1) (24,1)
# 2025-04-20 18:45:28,181 - WARNING - Regression failed for TDSB (Allocation_4): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,183 - WARNING - Regression failed for TDSB (Allocation_4): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,186 - WARNING - Regression failed for TDSB (Allocation_4): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,188 - WARNING - Regression failed for TDSB (Allocation_4): operands could not be broadcast together with shapes (25,1) (24,1)
# 2025-04-20 18:45:28,192 - WARNING - Regression failed for TDSB (Allocation_4): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,194 - WARNING - Regression failed for TDSB (Allocation_4): operands could not be broadcast together with shapes (25,1) (24,1)
# 2025-04-20 18:45:28,197 - WARNING - Regression failed for TDSB (Allocation_4): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,200 - WARNING - Regression failed for TDSB (Allocation_4): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,202 - WARNING - Regression failed for TDSB (Allocation_4): operands could not be broadcast together with shapes (25,1) (24,1)
# 2025-04-20 18:45:28,207 - WARNING - Regression failed for TDSB (Allocation_4): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,209 - WARNING - No returns for ASET
# 2025-04-20 18:45:28,210 - WARNING - No returns for CCEF
# 2025-04-20 18:45:28,210 - WARNING - No returns for NDAA
# 2025-04-20 18:45:28,211 - WARNING - No returns for NDOW
# 2025-04-20 18:45:28,212 - WARNING - No returns for FCEF
# 2025-04-20 18:45:28,213 - WARNING - No returns for GYLD
# 2025-04-20 18:45:28,213 - WARNING - No returns for GDMA
# 2025-04-20 18:45:28,214 - WARNING - No returns for OCIO
# 2025-04-20 18:45:28,215 - WARNING - No returns for QVOY
# 2025-04-20 18:45:28,216 - WARNING - No returns for MPAY
# 2025-04-20 18:45:28,216 - WARNING - No returns for AVMA
# 2025-04-20 18:45:28,217 - WARNING - No returns for INKM
# 2025-04-20 18:45:28,218 - WARNING - No returns for YYY
# 2025-04-20 18:45:28,219 - WARNING - No returns for IQRA
# 2025-04-20 18:45:28,219 - WARNING - No returns for XNAV
# 2025-04-20 18:45:28,220 - WARNING - No returns for VRAI
# 2025-04-20 18:45:28,221 - WARNING - No returns for ALTY
# 2025-04-20 18:45:28,222 - WARNING - No returns for IYLD
# 2025-04-20 18:45:28,223 - WARNING - No returns for ASMF
# 2025-04-20 18:45:28,224 - WARNING - No returns for MFUT
# 2025-04-20 18:45:28,224 - WARNING - No returns for AHLT
# 2025-04-20 18:45:28,268 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:28,273 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:28,277 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:28,279 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:28,281 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:28,285 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:28,288 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:28,291 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (13,1) (11,1)
# 2025-04-20 18:45:28,293 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:28,297 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:28,302 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:28,305 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:28,308 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:28,314 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:28,317 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:28,321 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:28,324 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:28,328 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:28,331 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:28,339 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:28,343 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:28,349 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:28,355 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:28,358 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (13,1) (11,1)
# 2025-04-20 18:45:28,361 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:28,363 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:28,367 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:28,370 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:28,373 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:28,376 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (13,1) (11,1)
# 2025-04-20 18:45:28,378 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:28,382 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:28,384 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:28,387 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:28,390 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:28,394 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:28,397 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (13,1) (11,1)
# 2025-04-20 18:45:28,399 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:28,402 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:28,405 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:28,407 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:28,411 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (13,1) (10,1)
# 2025-04-20 18:45:28,445 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (25,1) (20,1)
# 2025-04-20 18:45:28,449 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (25,1) (20,1)
# 2025-04-20 18:45:28,452 - WARNING - Regression failed for WTMF (Alternative_1): operands could not be broadcast together with shapes (25,1) (20,1)
# 2025-04-20 18:45:28,560 - WARNING - Regression failed for WTMF (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,562 - WARNING - Regression failed for WTMF (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,565 - WARNING - Regression failed for WTMF (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,567 - WARNING - Regression failed for WTMF (Allocation_2): operands could not be broadcast together with shapes (13,1) (12,1)
# 2025-04-20 18:45:28,569 - WARNING - Regression failed for WTMF (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,573 - WARNING - Regression failed for WTMF (Allocation_2): operands could not be broadcast together with shapes (13,1) (12,1)
# 2025-04-20 18:45:28,574 - WARNING - Regression failed for WTMF (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,578 - WARNING - Regression failed for WTMF (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,580 - WARNING - Regression failed for WTMF (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,582 - WARNING - Regression failed for WTMF (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,585 - WARNING - Regression failed for WTMF (Allocation_2): operands could not be broadcast together with shapes (13,1) (12,1)
# 2025-04-20 18:45:28,588 - WARNING - Regression failed for WTMF (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,589 - WARNING - Regression failed for WTMF (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,591 - WARNING - Regression failed for WTMF (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,595 - WARNING - Regression failed for WTMF (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,597 - WARNING - Regression failed for WTMF (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,600 - WARNING - Regression failed for WTMF (Allocation_2): operands could not be broadcast together with shapes (13,1) (12,1)
# 2025-04-20 18:45:28,603 - WARNING - Regression failed for WTMF (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,606 - WARNING - Regression failed for WTMF (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,609 - WARNING - Regression failed for WTMF (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,612 - WARNING - Regression failed for WTMF (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,615 - WARNING - Regression failed for WTMF (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,618 - WARNING - Regression failed for WTMF (Allocation_2): operands could not be broadcast together with shapes (13,1) (12,1)
# 2025-04-20 18:45:28,620 - WARNING - Regression failed for WTMF (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,623 - WARNING - Regression failed for WTMF (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,627 - WARNING - Regression failed for WTMF (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,630 - WARNING - Regression failed for WTMF (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,634 - WARNING - Regression failed for WTMF (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,637 - WARNING - Regression failed for WTMF (Allocation_2): operands could not be broadcast together with shapes (13,1) (12,1)
# 2025-04-20 18:45:28,640 - WARNING - Regression failed for WTMF (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,644 - WARNING - Regression failed for WTMF (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,647 - WARNING - Regression failed for WTMF (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,650 - WARNING - Regression failed for WTMF (Allocation_2): operands could not be broadcast together with shapes (13,1) (12,1)
# 2025-04-20 18:45:28,655 - WARNING - Regression failed for WTMF (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,658 - WARNING - Regression failed for WTMF (Allocation_2): operands could not be broadcast together with shapes (13,1) (12,1)
# 2025-04-20 18:45:28,662 - WARNING - Regression failed for WTMF (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,664 - WARNING - Regression failed for WTMF (Allocation_2): operands could not be broadcast together with shapes (13,1) (12,1)
# 2025-04-20 18:45:28,666 - WARNING - Regression failed for WTMF (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,669 - WARNING - Regression failed for WTMF (Allocation_2): operands could not be broadcast together with shapes (13,1) (12,1)
# 2025-04-20 18:45:28,672 - WARNING - Regression failed for WTMF (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,675 - WARNING - Regression failed for WTMF (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,677 - WARNING - Regression failed for WTMF (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,680 - WARNING - Regression failed for WTMF (Allocation_2): operands could not be broadcast together with shapes (13,1) (12,1)
# 2025-04-20 18:45:28,683 - WARNING - Regression failed for WTMF (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,686 - WARNING - Regression failed for WTMF (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,689 - WARNING - Regression failed for WTMF (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,691 - WARNING - Regression failed for WTMF (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,694 - WARNING - Regression failed for WTMF (Allocation_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:28,697 - WARNING - Regression failed for WTMF (Allocation_2): operands could not be broadcast together with shapes (13,1) (12,1)
# ...
# 2025-04-20 18:45:48,688 - WARNING - Regression failed for IVFIX (Equity_Global_2): operands could not be broadcast together with shapes (37,1) (36,1)
# 2025-04-20 18:45:48,690 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,693 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,694 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,697 - WARNING - Regression failed for IVFIX (Equity_Global_2): operands could not be broadcast together with shapes (37,1) (36,1)
# 2025-04-20 18:45:48,699 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,701 - WARNING - Regression failed for IVFIX (Equity_Global_2): operands could not be broadcast together with shapes (37,1) (36,1)
# 2025-04-20 18:45:48,703 - WARNING - Regression failed for IVFIX (Equity_Global_2): operands could not be broadcast together with shapes (37,1) (36,1)
# 2025-04-20 18:45:48,706 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,708 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,711 - WARNING - Regression failed for IVFIX (Equity_Global_2): operands could not be broadcast together with shapes (37,1) (36,1)
# 2025-04-20 18:45:48,713 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,716 - WARNING - Regression failed for IVFIX (Equity_Global_2): operands could not be broadcast together with shapes (37,1) (36,1)
# 2025-04-20 18:45:48,719 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,722 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,725 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,728 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,730 - WARNING - Regression failed for IVFIX (Equity_Global_2): operands could not be broadcast together with shapes (49,1) (48,1)
# 2025-04-20 18:45:48,733 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,736 - WARNING - Regression failed for IVFIX (Equity_Global_2): operands could not be broadcast together with shapes (49,1) (48,1)
# 2025-04-20 18:45:48,738 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,740 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,743 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,745 - WARNING - Regression failed for IVFIX (Equity_Global_2): operands could not be broadcast together with shapes (49,1) (48,1)
# 2025-04-20 18:45:48,748 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,750 - WARNING - Regression failed for IVFIX (Equity_Global_2): operands could not be broadcast together with shapes (49,1) (48,1)
# 2025-04-20 18:45:48,753 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,756 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,759 - WARNING - Regression failed for IVFIX (Equity_Global_2): operands could not be broadcast together with shapes (49,1) (48,1)
# 2025-04-20 18:45:48,761 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,765 - WARNING - Regression failed for IVFIX (Equity_Global_2): operands could not be broadcast together with shapes (49,1) (48,1)
# 2025-04-20 18:45:48,768 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,771 - WARNING - Regression failed for IVFIX (Equity_Global_2): operands could not be broadcast together with shapes (49,1) (48,1)
# 2025-04-20 18:45:48,774 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,779 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,781 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,785 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,787 - WARNING - Regression failed for IVFIX (Equity_Global_2): operands could not be broadcast together with shapes (49,1) (48,1)
# 2025-04-20 18:45:48,789 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,791 - WARNING - Regression failed for IVFIX (Equity_Global_2): operands could not be broadcast together with shapes (49,1) (48,1)
# 2025-04-20 18:45:48,794 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,796 - WARNING - Regression failed for IVFIX (Equity_Global_2): operands could not be broadcast together with shapes (49,1) (48,1)
# 2025-04-20 18:45:48,799 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,801 - WARNING - Regression failed for IVFIX (Equity_Global_2): operands could not be broadcast together with shapes (49,1) (48,1)
# 2025-04-20 18:45:48,803 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,806 - WARNING - Regression failed for IVFIX (Equity_Global_2): operands could not be broadcast together with shapes (49,1) (48,1)
# 2025-04-20 18:45:48,808 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,812 - WARNING - Regression failed for IVFIX (Equity_Global_2): operands could not be broadcast together with shapes (49,1) (48,1)
# 2025-04-20 18:45:48,814 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,818 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,820 - WARNING - Regression failed for IVFIX (Equity_Global_2): operands could not be broadcast together with shapes (49,1) (48,1)
# 2025-04-20 18:45:48,823 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,826 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,828 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,831 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,834 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,836 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,839 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,842 - WARNING - Regression failed for IVFIX (Equity_Global_2): operands could not be broadcast together with shapes (61,1) (60,1)
# 2025-04-20 18:45:48,844 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,847 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,850 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,853 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,855 - WARNING - Regression failed for IVFIX (Equity_Global_2): operands could not be broadcast together with shapes (61,1) (60,1)
# 2025-04-20 18:45:48,857 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,860 - WARNING - Regression failed for IVFIX (Equity_Global_2): operands could not be broadcast together with shapes (61,1) (60,1)
# 2025-04-20 18:45:48,863 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,865 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,867 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,870 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,873 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,875 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,877 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,880 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,882 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,891 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,894 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,896 - WARNING - Regression failed for IVFIX (Equity_Global_2): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,947 - WARNING - Regression failed for IVFIX (Equity_Global_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,950 - WARNING - Regression failed for IVFIX (Equity_Global_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,952 - WARNING - Regression failed for IVFIX (Equity_Global_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,955 - WARNING - Regression failed for IVFIX (Equity_Global_3): operands could not be broadcast together with shapes (13,1) (12,1)
# 2025-04-20 18:45:48,958 - WARNING - Regression failed for IVFIX (Equity_Global_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,961 - WARNING - Regression failed for IVFIX (Equity_Global_3): operands could not be broadcast together with shapes (13,1) (12,1)
# 2025-04-20 18:45:48,965 - WARNING - Regression failed for IVFIX (Equity_Global_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,968 - WARNING - Regression failed for IVFIX (Equity_Global_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,971 - WARNING - Regression failed for IVFIX (Equity_Global_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,974 - WARNING - Regression failed for IVFIX (Equity_Global_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,976 - WARNING - Regression failed for IVFIX (Equity_Global_3): operands could not be broadcast together with shapes (13,1) (12,1)
# 2025-04-20 18:45:48,979 - WARNING - Regression failed for IVFIX (Equity_Global_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,983 - WARNING - Regression failed for IVFIX (Equity_Global_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,986 - WARNING - Regression failed for IVFIX (Equity_Global_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,989 - WARNING - Regression failed for IVFIX (Equity_Global_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,991 - WARNING - Regression failed for IVFIX (Equity_Global_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,994 - WARNING - Regression failed for IVFIX (Equity_Global_3): operands could not be broadcast together with shapes (13,1) (12,1)
# 2025-04-20 18:45:48,996 - WARNING - Regression failed for IVFIX (Equity_Global_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:48,998 - WARNING - Regression failed for IVFIX (Equity_Global_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:49,002 - WARNING - Regression failed for IVFIX (Equity_Global_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:49,004 - WARNING - Regression failed for IVFIX (Equity_Global_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:49,006 - WARNING - Regression failed for IVFIX (Equity_Global_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:49,008 - WARNING - Regression failed for IVFIX (Equity_Global_3): operands could not be broadcast together with shapes (13,1) (12,1)
# 2025-04-20 18:45:49,013 - WARNING - Regression failed for IVFIX (Equity_Global_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:49,015 - WARNING - Regression failed for IVFIX (Equity_Global_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:49,019 - WARNING - Regression failed for IVFIX (Equity_Global_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:49,022 - WARNING - Regression failed for IVFIX (Equity_Global_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:49,024 - WARNING - Regression failed for IVFIX (Equity_Global_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:49,027 - WARNING - Regression failed for IVFIX (Equity_Global_3): operands could not be broadcast together with shapes (13,1) (12,1)
# 2025-04-20 18:45:49,030 - WARNING - Regression failed for IVFIX (Equity_Global_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:49,032 - WARNING - Regression failed for IVFIX (Equity_Global_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:49,035 - WARNING - Regression failed for IVFIX (Equity_Global_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:49,037 - WARNING - Regression failed for IVFIX (Equity_Global_3): operands could not be broadcast together with shapes (13,1) (12,1)
# 2025-04-20 18:45:49,040 - WARNING - Regression failed for IVFIX (Equity_Global_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:49,042 - WARNING - Regression failed for IVFIX (Equity_Global_3): operands could not be broadcast together with shapes (13,1) (12,1)
# 2025-04-20 18:45:49,045 - WARNING - Regression failed for IVFIX (Equity_Global_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:49,048 - WARNING - Regression failed for IVFIX (Equity_Global_3): operands could not be broadcast together with shapes (13,1) (12,1)
# 2025-04-20 18:45:49,050 - WARNING - Regression failed for IVFIX (Equity_Global_3): The indices for endog and exog are not aligned
# 2025-04-20 18:45:49,053 - WARNING - Regression failed for IVFIX (Equity_Global_3): operands could not be broadcast together with shapes (13,1) (12,1)
